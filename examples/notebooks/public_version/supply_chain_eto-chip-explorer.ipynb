# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>
#         Example notebook - Supply chain
#     </h1>
#     <p>
#         Link to dataset : <a href="https://eto.tech/dataset-docs/chipexplorer/">dataset documentation link</a>
#     </p>
# </div>

# %% [markdown]
# # Import modules and functions

# %%
import os
import pandas as pd
import glob
import re
import numpy as np
import time
from tqdm.auto import tqdm

from turingdb_examples.graph import (
    create_graph_from_df,
    build_create_command_from_networkx,
    split_cypher_commands
)
from turingdb_examples.llm import natural_language_to_cypher
from turingdb_examples.utils import escape_for_cypher

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Check data files are available

# %%
example_name = "supply_chain_eto-chip-explorer"
path_data = f"{os.getcwd()}/data/{example_name}"
if not os.path.exists(path_data):
    raise ValueError(f"{path_data} does not exists")

list_csv_files = sorted(os.listdir(path_data))
if not all([file in list_csv_files for file in [
    "inputs.csv",
    "providers.csv",
    "provision.csv",
    "sequence.csv",
    "stages.csv",
]]):
    raise ValueError(
        f"At least one of the {len(list_csv_files)} csv files is not available in {path_data}"
    )

# %% [markdown]
# # Import and format data

# %%
dict_df = {}

for path_csv in glob.glob(f"{path_data}/*.csv"):
    print(100 * "-")
    key_name = re.sub(".csv", "", os.path.basename(path_csv))
    dict_df[key_name] = pd.read_csv(path_csv)

    print(f"--- {key_name}")

    display(dict_df[key_name])

print(100 * "-")
# Out:
# ----------------------------------------------------------------------------------------------------
# --- providers
#               provider_name          alias provider_id provider_type country
# 0                       USA  United States          P1       country     NaN
# 1                       CHN          China          P2       country     NaN
# 2                       KOR    South Korea          P4       country     NaN
# 3         Various countries            NaN          P5       country     NaN
# 4                       JPN          Japan          P7       country     NaN
# ..                      ...            ...         ...           ...     ...
# 392  Shenzhen Naso Tech Co.            NaN        P407  organization     CHN
# 393                 Intevac            NaN        P408  organization     USA
# 394    Palomar Technologies            NaN        P409  organization     USA
# 395                 PacTech            NaN        P410  organization     JPN
# 396    Component Technology            NaN        P411  organization     SGP
#
# [397 rows x 5 columns]
# ----------------------------------------------------------------------------------------------------
# --- inputs
#     input_id                              input_name               type  \
# 0         N0                             Chip design            process
# 1         N6                       Logic chip design    design_resource
# 2         N1                           Advanced CPUs    design_resource
# 3         N2                           Discrete GPUs    design_resource
# 4         N3                                   FPGAs    design_resource
# ..       ...                                     ...                ...
# 121     N126  Process-specific fabrication materials  material_resource
# 122     N127           Lithography tools (adv. pkg.)      tool_resource
# 123     N128            Deposition tools (adv. pkg.)      tool_resource
# 124     N129        Etch and clean tools (adv. pkg.)      tool_resource
# 125     N130        Direct write systems (adv. pkg.)      tool_resource
#
#     stage_name stage_id                                        description  \
# 0       Design       S1  Chip design involves specification, logic desi...
# 1          NaN      NaN  Logic chip design is the design of integrated ...
# 2          NaN      NaN  Central processing units ("CPUs") are the domi...
# 3          NaN      NaN  Discrete graphics processing units ("GPUs") ha...
# 4          NaN      NaN  Field-programmable gate arrays ("FPGAs"), unli...
# ..         ...      ...                                                ...
# 121        NaN      NaN  Process-specific fabrication materials are hig...
# 122        NaN      NaN  These tools are lithography tools designed and...
# 123        NaN      NaN  These tools are deposition tools designed and ...
# 124        NaN      NaN  These tools are etch and clean tools designed ...
# 125        NaN      NaN  These tools are direct write systems designed ...
#
#        year market_share_chart_global_market_size_info  \
# 0    2022.0                      $574.1 billion (2022)
# 1    2022.0                      $255.7 billion (2022)
# 2    2019.0     $56.2 billion (microprocessors) (2019)
# 3    2019.0                       $11.9 billion (2019)
# 4    2019.0                        $5.7 billion (2019)
# ..      ...                                        ...
# 121     NaN                                        NaN
# 122  2024.0                      $275.6 million (2024)
# 123  2024.0                        $2.6 billion (2024)
# 124  2024.0                        $1.2 billion (2024)
# 125  2024.0                       $48.1 million (2024)
#
#      market_share_chart_caption  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 121                         NaN
# 122                         NaN
# 123                         NaN
# 124                         NaN
# 125                         NaN
#
#                              market_share_chart_source
# 0    Worldwide semiconductor sales. [World Semicond...
# 1    Worldwide semiconductor sales for logic and mi...
# 2    [CSET](https://cset.georgetown.edu/publication...
# 3    [CSET](https://cset.georgetown.edu/publication...
# 4    [CSET](https://cset.georgetown.edu/publication...
# ..                                                 ...
# 121                                                NaN
# 122  CSET analysis of TechInsights data (2024). Dat...
# 123  CSET analysis of TechInsights data (2024). Dat...
# 124  CSET analysis of TechInsights data (2024). Dat...
# 125  CSET analysis of TechInsights data (2024). Dat...
#
# [126 rows x 10 columns]
# ----------------------------------------------------------------------------------------------------
# --- stages
#   stage_id                              stage_name  \
# 0       S1                                  Design
# 1       S2                             Fabrication
# 2       S3  Assembly, testing, and packaging (ATP)
#
#                                          description  \
# 0  Semiconductor design involves specification, d...
# 1  Fabrication turns designs into chips. Semicond...
# 2  At the end of the fabrication process, the fin...
#
#   market_share_chart_global_market_size_info  \
# 0                        $574 billion (2022)
# 1                                        NaN
# 2                         $95 billion (2022)
#
#                           market_share_chart_caption  \
# 0  Chart shows market shares for the overall glob...
# 1  Chart shows share of global fabrication capaci...
# 2          Chart shows ATP site capacity by country.
#
#                            market_share_chart_source
# 0  [Semiconductor Industry Association (SIA)](htt...
# 1  [Semiconductor Industry Association (SIA)](htt...
# 2  [Semiconductor Industry Association (SIA)](htt...
# ----------------------------------------------------------------------------------------------------
# --- provision
#            provider_name provider_id  \
# 0           ACM Research        P313
# 1           ACM Research        P313
# 2                   AMEC        P123
# 3                   AMEC        P123
# 4                   AMEC        P123
# ...                  ...         ...
# 1300           Zhonghuan        P231
# 1301            Zhongwei        P295
# 1302        Zhuhai Yueya        P301
# 1303            ZingSEMI        P237
# 1304  eMemory Technology        P204
#
#                                    provided_name provided_id  share_provided  \
# 0                 Wet etching and cleaning tools         N49            11.4
# 1                           Etch and clean tools         N55             3.0
# 2                  Dry etching tools (adv. pkg.)        N101            18.1
# 3                                 Dry etch tools        N103             5.5
# 4     Fabrication tools (for advanced packaging)        N109             2.5
# ...                                          ...         ...             ...
# 1300                                       Wafer         N26             NaN
# 1301                            Ceramic packages         N95             NaN
# 1302                                  Substrates         N96             NaN
# 1303                                       Wafer         N26             NaN
# 1304                  Core intellectual property         N85             NaN
#
#       year                                             source
# 0     2024  CSET analysis of TechInsights data (2024). Dat...
# 1     2024  CSET analysis of TechInsights data (2024). Dat...
# 2     2024  CSET analysis of TechInsights data (2024). Dat...
# 3     2024  CSET analysis of TechInsights data (2024). Dat...
# 4     2024  CSET analysis of TechInsights data (2024). Dat...
# ...    ...                                                ...
# 1300  2019  [CSET](https://cset.georgetown.edu/publication...
# 1301  2019                                                NaN
# 1302  2019                                                NaN
# 1303  2019  [CSET](https://cset.georgetown.edu/publication...
# 1304  2019  [CSET](https://cset.georgetown.edu/publication...
#
# [1305 rows x 7 columns]
# ----------------------------------------------------------------------------------------------------
# --- sequence
#                                 input_name input_id goes_into_name  \
# 0                 Crystal growing furnaces       N8          Wafer
# 1                  Crystal machining tools       N9          Wafer
# 2                    EUV lithography tools      N20            NaN
# 3          ArF dry (DUV) lithography tools      N21            NaN
# 4    ArF immersion (DUV) lithography tools      N22            NaN
# ..                                     ...      ...            ...
# 134               Auto ball bonders for IC     N134            NaN
# 135           Auto ball bonders for non-IC     N135            NaN
# 136                Automatic wedge bonders     N136            NaN
# 137               Wafer level stud bonders     N137            NaN
# 138        Other deposition tools (non-IC)     N138            NaN
#
#     goes_into_id     is_type_of_name is_type_of_id
# 0            N26                 NaN           NaN
# 1            N26                 NaN           NaN
# 2            NaN   Lithography tools           N19
# 3            NaN   Lithography tools           N19
# 4            NaN   Lithography tools           N19
# ..           ...                 ...           ...
# 134          NaN  Wire bonding tools           N74
# 135          NaN  Wire bonding tools           N74
# 136          NaN  Wire bonding tools           N74
# 137          NaN  Wire bonding tools           N74
# 138          NaN    Deposition tools           N36
#
# [139 rows x 6 columns]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Format `df_provision` and `df_providers` dataframes

# %%
df_provision = dict_df["provision"].copy()
df_provision = df_provision.rename(
    columns={"year": "year_share_provided", "source": "source_provider_provided"}
)
df_provision
# Out:
#            provider_name provider_id  \
# 0           ACM Research        P313
# 1           ACM Research        P313
# 2                   AMEC        P123
# 3                   AMEC        P123
# 4                   AMEC        P123
# ...                  ...         ...
# 1300           Zhonghuan        P231
# 1301            Zhongwei        P295
# 1302        Zhuhai Yueya        P301
# 1303            ZingSEMI        P237
# 1304  eMemory Technology        P204
#
#                                    provided_name provided_id  share_provided  \
# 0                 Wet etching and cleaning tools         N49            11.4
# 1                           Etch and clean tools         N55             3.0
# 2                  Dry etching tools (adv. pkg.)        N101            18.1
# 3                                 Dry etch tools        N103             5.5
# 4     Fabrication tools (for advanced packaging)        N109             2.5
# ...                                          ...         ...             ...
# 1300                                       Wafer         N26             NaN
# 1301                            Ceramic packages         N95             NaN
# 1302                                  Substrates         N96             NaN
# 1303                                       Wafer         N26             NaN
# 1304                  Core intellectual property         N85             NaN
#
#       year_share_provided                           source_provider_provided
# 0                    2024  CSET analysis of TechInsights data (2024). Dat...
# 1                    2024  CSET analysis of TechInsights data (2024). Dat...
# 2                    2024  CSET analysis of TechInsights data (2024). Dat...
# 3                    2024  CSET analysis of TechInsights data (2024). Dat...
# 4                    2024  CSET analysis of TechInsights data (2024). Dat...
# ...                   ...                                                ...
# 1300                 2019  [CSET](https://cset.georgetown.edu/publication...
# 1301                 2019                                                NaN
# 1302                 2019                                                NaN
# 1303                 2019  [CSET](https://cset.georgetown.edu/publication...
# 1304                 2019  [CSET](https://cset.georgetown.edu/publication...
#
# [1305 rows x 7 columns]

# %%
df_providers = dict_df["providers"].copy()
df_providers = df_providers.rename(
    columns={"alias": "provider_alias", "country": "provider_country"}
)
df_providers
# Out:
#               provider_name provider_alias provider_id provider_type  \
# 0                       USA  United States          P1       country
# 1                       CHN          China          P2       country
# 2                       KOR    South Korea          P4       country
# 3         Various countries            NaN          P5       country
# 4                       JPN          Japan          P7       country
# ..                      ...            ...         ...           ...
# 392  Shenzhen Naso Tech Co.            NaN        P407  organization
# 393                 Intevac            NaN        P408  organization
# 394    Palomar Technologies            NaN        P409  organization
# 395                 PacTech            NaN        P410  organization
# 396    Component Technology            NaN        P411  organization
#
#     provider_country
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 392              CHN
# 393              USA
# 394              USA
# 395              JPN
# 396              SGP
#
# [397 rows x 5 columns]

# %%
df_provision = pd.merge(
    df_provision, df_providers, on="provider_id", how="left", suffixes=("", "_y")
)
df_provision = df_provision.drop(df_provision.filter(regex="_y$").columns, axis=1)
df_provision = df_provision[
    [
        "provided_name",
        "provided_id",
        "provider_name",
        "provider_id",
        "provider_alias",
        "provider_type",
        "provider_country",
        "share_provided",
        "year_share_provided",
        "source_provider_provided",
    ]
]
df_provision
# Out:
#                                    provided_name provided_id  \
# 0                 Wet etching and cleaning tools         N49
# 1                           Etch and clean tools         N55
# 2                  Dry etching tools (adv. pkg.)        N101
# 3                                 Dry etch tools        N103
# 4     Fabrication tools (for advanced packaging)        N109
# ...                                          ...         ...
# 1328                                       Wafer         N26
# 1329                            Ceramic packages         N95
# 1330                                  Substrates         N96
# 1331                                       Wafer         N26
# 1332                  Core intellectual property         N85
#
#            provider_name provider_id  \
# 0           ACM Research        P313
# 1           ACM Research        P313
# 2                   AMEC        P123
# 3                   AMEC        P123
# 4                   AMEC        P123
# ...                  ...         ...
# 1328           Zhonghuan        P231
# 1329            Zhongwei        P295
# 1330        Zhuhai Yueya        P301
# 1331            ZingSEMI        P237
# 1332  eMemory Technology        P204
#
#                                        provider_alias provider_type  \
# 0                                                 NaN  organization
# 1                                                 NaN  organization
# 2     Advanced Micro-Fabrication Equipment Inc. China  organization
# 3     Advanced Micro-Fabrication Equipment Inc. China  organization
# 4     Advanced Micro-Fabrication Equipment Inc. China  organization
# ...                                               ...           ...
# 1328                                              NaN  organization
# 1329                                              NaN  organization
# 1330                                              NaN  organization
# 1331                                              NaN  organization
# 1332                                              NaN  organization
#
#      provider_country  share_provided  year_share_provided  \
# 0                 USA            11.4                 2024
# 1                 USA             3.0                 2024
# 2                 CHN            18.1                 2024
# 3                 CHN             5.5                 2024
# 4                 CHN             2.5                 2024
# ...               ...             ...                  ...
# 1328              CHN             NaN                 2019
# 1329              CHN             NaN                 2019
# 1330              CHN             NaN                 2019
# 1331              CHN             NaN                 2019
# 1332              TWN             NaN                 2019
#
#                                source_provider_provided
# 0     CSET analysis of TechInsights data (2024). Dat...
# 1     CSET analysis of TechInsights data (2024). Dat...
# 2     CSET analysis of TechInsights data (2024). Dat...
# 3     CSET analysis of TechInsights data (2024). Dat...
# 4     CSET analysis of TechInsights data (2024). Dat...
# ...                                                 ...
# 1328  [CSET](https://cset.georgetown.edu/publication...
# 1329                                                NaN
# 1330                                                NaN
# 1331  [CSET](https://cset.georgetown.edu/publication...
# 1332  [CSET](https://cset.georgetown.edu/publication...
#
# [1333 rows x 10 columns]

# %% [markdown]
# ## Format `df_stages` dataframe

# %%
# Apply to your dataframe
df_inputs = dict_df["inputs"].copy()
df_inputs = df_inputs.dropna(axis=1, how="all")

# Clean dataframe before creating the graph
for col in df_inputs.select_dtypes(include=["object"]).columns:
    df_inputs[col] = df_inputs[col].apply(escape_for_cypher)

df_inputs
# Out:
#     input_id                              input_name               type  \
# 0         N0                             Chip design            process
# 1         N6                       Logic chip design    design_resource
# 2         N1                           Advanced CPUs    design_resource
# 3         N2                           Discrete GPUs    design_resource
# 4         N3                                   FPGAs    design_resource
# ..       ...                                     ...                ...
# 121     N126  Process-specific fabrication materials  material_resource
# 122     N127           Lithography tools (adv. pkg.)      tool_resource
# 123     N128            Deposition tools (adv. pkg.)      tool_resource
# 124     N129        Etch and clean tools (adv. pkg.)      tool_resource
# 125     N130        Direct write systems (adv. pkg.)      tool_resource
#
#     stage_name stage_id                                        description  \
# 0       Design       S1  Chip design involves specification, logic desi...
# 1                        Logic chip design is the design of integrated ...
# 2                        Central processing units (\"CPUs\") are the do...
# 3                        Discrete graphics processing units (\"GPUs\") ...
# 4                        Field-programmable gate arrays (\"FPGAs\"), un...
# ..         ...      ...                                                ...
# 121                      Process-specific fabrication materials are hig...
# 122                      These tools are lithography tools designed and...
# 123                      These tools are deposition tools designed and ...
# 124                      These tools are etch and clean tools designed ...
# 125                      These tools are direct write systems designed ...
#
#        year market_share_chart_global_market_size_info  \
# 0    2022.0                      $574.1 billion (2022)
# 1    2022.0                      $255.7 billion (2022)
# 2    2019.0     $56.2 billion (microprocessors) (2019)
# 3    2019.0                       $11.9 billion (2019)
# 4    2019.0                        $5.7 billion (2019)
# ..      ...                                        ...
# 121     NaN
# 122  2024.0                      $275.6 million (2024)
# 123  2024.0                        $2.6 billion (2024)
# 124  2024.0                        $1.2 billion (2024)
# 125  2024.0                       $48.1 million (2024)
#
#                              market_share_chart_source
# 0    Worldwide semiconductor sales. [World Semicond...
# 1    Worldwide semiconductor sales for logic and mi...
# 2    [CSET](https://cset.georgetown.edu/publication...
# 3    [CSET](https://cset.georgetown.edu/publication...
# 4    [CSET](https://cset.georgetown.edu/publication...
# ..                                                 ...
# 121
# 122  CSET analysis of TechInsights data (2024). Dat...
# 123  CSET analysis of TechInsights data (2024). Dat...
# 124  CSET analysis of TechInsights data (2024). Dat...
# 125  CSET analysis of TechInsights data (2024). Dat...
#
# [126 rows x 9 columns]

# %%
df_stages = dict_df["stages"].copy()
df_stages = df_stages.rename(columns={"description": "stage_description"})
df_stages = df_stages.drop(
    ["market_share_chart_global_market_size_info", "market_share_chart_source"], axis=1
)
df_stages
# Out:
#   stage_id                              stage_name  \
# 0       S1                                  Design
# 1       S2                             Fabrication
# 2       S3  Assembly, testing, and packaging (ATP)
#
#                                    stage_description  \
# 0  Semiconductor design involves specification, d...
# 1  Fabrication turns designs into chips. Semicond...
# 2  At the end of the fabrication process, the fin...
#
#                           market_share_chart_caption
# 0  Chart shows market shares for the overall glob...
# 1  Chart shows share of global fabrication capaci...
# 2          Chart shows ATP site capacity by country.

# %% [markdown]
# ## Format `df_inputs` dataframe

# %%
df_inputs = pd.merge(
    df_inputs, df_stages, on="stage_id", how="left", suffixes=("", "_y")
)
df_inputs = df_inputs.drop(df_inputs.filter(regex="_y$").columns, axis=1)

df_inputs = df_inputs[
    [
        "input_id",
        "input_name",
        "type",
        "description",
        "stage_name",
        "stage_id",
        "stage_description",
        "year",
        "market_share_chart_caption",
        "market_share_chart_global_market_size_info",
        "market_share_chart_source",
    ]
]

df_inputs
# Out:
#     input_id                              input_name               type  \
# 0         N0                             Chip design            process
# 1         N6                       Logic chip design    design_resource
# 2         N1                           Advanced CPUs    design_resource
# 3         N2                           Discrete GPUs    design_resource
# 4         N3                                   FPGAs    design_resource
# ..       ...                                     ...                ...
# 121     N126  Process-specific fabrication materials  material_resource
# 122     N127           Lithography tools (adv. pkg.)      tool_resource
# 123     N128            Deposition tools (adv. pkg.)      tool_resource
# 124     N129        Etch and clean tools (adv. pkg.)      tool_resource
# 125     N130        Direct write systems (adv. pkg.)      tool_resource
#
#                                            description stage_name stage_id  \
# 0    Chip design involves specification, logic desi...     Design       S1
# 1    Logic chip design is the design of integrated ...
# 2    Central processing units (\"CPUs\") are the do...
# 3    Discrete graphics processing units (\"GPUs\") ...
# 4    Field-programmable gate arrays (\"FPGAs\"), un...
# ..                                                 ...        ...      ...
# 121  Process-specific fabrication materials are hig...
# 122  These tools are lithography tools designed and...
# 123  These tools are deposition tools designed and ...
# 124  These tools are etch and clean tools designed ...
# 125  These tools are direct write systems designed ...
#
#                                      stage_description    year  \
# 0    Semiconductor design involves specification, d...  2022.0
# 1                                                  NaN  2022.0
# 2                                                  NaN  2019.0
# 3                                                  NaN  2019.0
# 4                                                  NaN  2019.0
# ..                                                 ...     ...
# 121                                                NaN     NaN
# 122                                                NaN  2024.0
# 123                                                NaN  2024.0
# 124                                                NaN  2024.0
# 125                                                NaN  2024.0
#
#                             market_share_chart_caption  \
# 0    Chart shows market shares for the overall glob...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
#
#     market_share_chart_global_market_size_info  \
# 0                        $574.1 billion (2022)
# 1                        $255.7 billion (2022)
# 2       $56.2 billion (microprocessors) (2019)
# 3                         $11.9 billion (2019)
# 4                          $5.7 billion (2019)
# ..                                         ...
# 121
# 122                      $275.6 million (2024)
# 123                        $2.6 billion (2024)
# 124                        $1.2 billion (2024)
# 125                       $48.1 million (2024)
#
#                              market_share_chart_source
# 0    Worldwide semiconductor sales. [World Semicond...
# 1    Worldwide semiconductor sales for logic and mi...
# 2    [CSET](https://cset.georgetown.edu/publication...
# 3    [CSET](https://cset.georgetown.edu/publication...
# 4    [CSET](https://cset.georgetown.edu/publication...
# ..                                                 ...
# 121
# 122  CSET analysis of TechInsights data (2024). Dat...
# 123  CSET analysis of TechInsights data (2024). Dat...
# 124  CSET analysis of TechInsights data (2024). Dat...
# 125  CSET analysis of TechInsights data (2024). Dat...
#
# [126 rows x 11 columns]

# %%
df_inputs = pd.merge(
    df_inputs,
    df_provision,
    left_on="input_id",
    right_on="provided_id",
    how="left",
    suffixes=("", "_y"),
)
df_inputs = df_inputs.drop(["provided_name", "provided_id"], axis=1)
df_inputs
# Out:
#      input_id                        input_name           type  \
# 0          N0                       Chip design        process
# 1          N0                       Chip design        process
# 2          N0                       Chip design        process
# 3          N0                       Chip design        process
# 4          N0                       Chip design        process
# ...       ...                               ...            ...
# 1315     N129  Etch and clean tools (adv. pkg.)  tool_resource
# 1316     N129  Etch and clean tools (adv. pkg.)  tool_resource
# 1317     N129  Etch and clean tools (adv. pkg.)  tool_resource
# 1318     N130  Direct write systems (adv. pkg.)  tool_resource
# 1319     N130  Direct write systems (adv. pkg.)  tool_resource
#
#                                             description stage_name stage_id  \
# 0     Chip design involves specification, logic desi...     Design       S1
# 1     Chip design involves specification, logic desi...     Design       S1
# 2     Chip design involves specification, logic desi...     Design       S1
# 3     Chip design involves specification, logic desi...     Design       S1
# 4     Chip design involves specification, logic desi...     Design       S1
# ...                                                 ...        ...      ...
# 1315  These tools are etch and clean tools designed ...
# 1316  These tools are etch and clean tools designed ...
# 1317  These tools are etch and clean tools designed ...
# 1318  These tools are direct write systems designed ...
# 1319  These tools are direct write systems designed ...
#
#                                       stage_description    year  \
# 0     Semiconductor design involves specification, d...  2022.0
# 1     Semiconductor design involves specification, d...  2022.0
# 2     Semiconductor design involves specification, d...  2022.0
# 3     Semiconductor design involves specification, d...  2022.0
# 4     Semiconductor design involves specification, d...  2022.0
# ...                                                 ...     ...
# 1315                                                NaN  2024.0
# 1316                                                NaN  2024.0
# 1317                                                NaN  2024.0
# 1318                                                NaN  2024.0
# 1319                                                NaN  2024.0
#
#                              market_share_chart_caption  \
# 0     Chart shows market shares for the overall glob...
# 1     Chart shows market shares for the overall glob...
# 2     Chart shows market shares for the overall glob...
# 3     Chart shows market shares for the overall glob...
# 4     Chart shows market shares for the overall glob...
# ...                                                 ...
# 1315                                                NaN
# 1316                                                NaN
# 1317                                                NaN
# 1318                                                NaN
# 1319                                                NaN
#
#      market_share_chart_global_market_size_info  \
# 0                         $574.1 billion (2022)
# 1                         $574.1 billion (2022)
# 2                         $574.1 billion (2022)
# 3                         $574.1 billion (2022)
# 4                         $574.1 billion (2022)
# ...                                         ...
# 1315                        $1.2 billion (2024)
# 1316                        $1.2 billion (2024)
# 1317                        $1.2 billion (2024)
# 1318                       $48.1 million (2024)
# 1319                       $48.1 million (2024)
#
#                               market_share_chart_source      provider_name  \
# 0     Worldwide semiconductor sales. [World Semicond...                CHN
# 1     Worldwide semiconductor sales. [World Semicond...                EUR
# 2     Worldwide semiconductor sales. [World Semicond...                JPN
# 3     Worldwide semiconductor sales. [World Semicond...                KOR
# 4     Worldwide semiconductor sales. [World Semicond...                TWN
# ...                                                 ...                ...
# 1315  CSET analysis of TechInsights data (2024). Dat...                USA
# 1316  CSET analysis of TechInsights data (2024). Dat...  Various companies
# 1317  CSET analysis of TechInsights data (2024). Dat...              Veeco
# 1318  CSET analysis of TechInsights data (2024). Dat...  Applied Materials
# 1319  CSET analysis of TechInsights data (2024). Dat...                USA
#
#      provider_id provider_alias provider_type   provider_country  \
# 0             P2          China       country                NaN
# 1           P312         Europe       country                EUR
# 2             P7          Japan       country                NaN
# 3             P4    South Korea       country                NaN
# 4             P8         Taiwan       country                NaN
# ...          ...            ...           ...                ...
# 1315          P1  United States       country                NaN
# 1316        P370            NaN  organization  Various countries
# 1317        P121            NaN  organization                USA
# 1318         P81            NaN  organization                USA
# 1319          P1  United States       country                NaN
#
#       share_provided  year_share_provided  \
# 0                5.0               2022.0
# 1                9.0               2022.0
# 2                4.0               2022.0
# 3                3.0               2022.0
# 4               11.0               2022.0
# ...              ...                  ...
# 1315            56.4               2024.0
# 1316             0.8               2024.0
# 1317             3.9               2024.0
# 1318           100.0               2024.0
# 1319           100.0               2024.0
#
#                                source_provider_provided
# 0     Worldwide semiconductor sales. [World Semicond...
# 1     Worldwide semiconductor sales. [World Semicond...
# 2     Worldwide semiconductor sales. [World Semicond...
# 3     Worldwide semiconductor sales. [World Semicond...
# 4     Worldwide semiconductor sales. [World Semicond...
# ...                                                 ...
# 1315  CSET analysis of TechInsights data (2024). Dat...
# 1316  CSET analysis of TechInsights data (2024). Dat...
# 1317  CSET analysis of TechInsights data (2024). Dat...
# 1318  CSET analysis of TechInsights data (2024). Dat...
# 1319  CSET analysis of TechInsights data (2024). Dat...
#
# [1320 rows x 19 columns]

# %% [markdown]
# ## Format `df_sequence` dataframe

# %%
df_sequence = dict_df["sequence"].copy()
df_sequence["output_name"] = df_sequence["goes_into_name"].combine_first(
    df_sequence["is_type_of_name"]
)
df_sequence["output_id"] = df_sequence["goes_into_id"].combine_first(
    df_sequence["is_type_of_id"]
)
df_sequence["type_link"] = np.where(
    df_sequence["goes_into_id"].notna(), "goes_into_id", "is_type_of_id"
)
df_sequence["type_link"] = df_sequence["type_link"].str.replace("_id", "")
df_sequence = df_sequence.drop(
    ["goes_into_name", "goes_into_id", "is_type_of_name", "is_type_of_id"], axis=1
)
df_sequence
# Out:
#                                 input_name input_id         output_name  \
# 0                 Crystal growing furnaces       N8               Wafer
# 1                  Crystal machining tools       N9               Wafer
# 2                    EUV lithography tools      N20   Lithography tools
# 3          ArF dry (DUV) lithography tools      N21   Lithography tools
# 4    ArF immersion (DUV) lithography tools      N22   Lithography tools
# ..                                     ...      ...                 ...
# 134               Auto ball bonders for IC     N134  Wire bonding tools
# 135           Auto ball bonders for non-IC     N135  Wire bonding tools
# 136                Automatic wedge bonders     N136  Wire bonding tools
# 137               Wafer level stud bonders     N137  Wire bonding tools
# 138        Other deposition tools (non-IC)     N138    Deposition tools
#
#     output_id   type_link
# 0         N26   goes_into
# 1         N26   goes_into
# 2         N19  is_type_of
# 3         N19  is_type_of
# 4         N19  is_type_of
# ..        ...         ...
# 134       N74  is_type_of
# 135       N74  is_type_of
# 136       N74  is_type_of
# 137       N74  is_type_of
# 138       N36  is_type_of
#
# [139 rows x 5 columns]

# %% [markdown]
# # Create graph from dataframe

# %%
G = create_graph_from_df(
    df_sequence,
    source_node_col={"id": "input_id", "displayName": "input_name"},
    target_node_col={"id": "output_id", "displayName": "output_name"},
    node_attributes_df=df_inputs,
    node_attributes_key_col="input_id",
    edge_col="type_link",
    edge_col_label="type",
)
print(f"Resulting graph : {G}")
# Out:
# Resulting graph : DiGraph with 126 nodes and 139 edges

# %%
n_first = 5

print("NODES :")
for node in list(G.nodes(data=True))[:n_first]:
    print(node[0])
    for key, val in node[1].items():
        print(f"   {key} : {val}")

    print()
print()

print("EDGES :")
for edge in list(G.edges(data=True))[:n_first]:
    print(edge)
# Out:
# NODES :
# N8
#    displayName : Crystal growing furnaces
#    input_name : Crystal growing furnaces
#    type : tool_resource
#    description : Crystal growing furnaces and machining tools are necessary to produce all wafers-thin, disc-shaped materials fabs used to produce chips. The furnace forms a cylindrical ingot of silicon from polycrystalline raw silicon; machining equipment then cuts the ingot into wafers used for chip fabrication. These tools have relatively low value and complexity relative to other semiconductor manufacturing equipment. Japan, Germany, and Switzerland are the main producers.
#    stage_name :
#    stage_id :
#    stage_description : nan
#    year : 2022.0
#    market_share_chart_caption : nan
#    market_share_chart_global_market_size_info : $44 million (2022)
#    market_share_chart_source : CSET analysis of TechInsights data (2022). Data used for analysis were published by TechInsights on May 5, 2025.
#    provider_name : DEU
#    provider_id : P32
#    provider_alias : Germany
#    provider_type : country
#    provider_country : nan
#    share_provided : 100.0
#    year_share_provided : 2022.0
#    source_provider_provided : CSET analysis of TechInsights data (2022). Data used for analysis were published by TechInsights on May 5, 2025.
#
# N26
#    displayName : Wafer
#    input_name : Wafer
#    type : material_resource
#    description : Silicon wafers are the basic building block for chip production. To produce them, a furnace forms a cylinder of silicon (or other semiconducting materials), which is then cut into disc-shaped wafers. These wafers are then processed, split and packaged into individual chips. Most wafers are made purely of silicon or another material, but others have more complex structures.  Dopants, such as boron, aluminum, phosphorous, platinum or other elements, may be added to alter the level of semiconductivity.\n\n300 mm wafers, produced by Japanese, Taiwanese, German, and Korean firms, are used to produce nearly all advanced chips today. Manufacturing the smoothest, high-purity 300 mm wafers-which are necessary for supporting the smallest chip feature sizes-requires considerable tacit know-how. Older-technology wafer sizes include 150 and 200 mm, used for chips with larger feature sizes.
#    stage_name :
#    stage_id :
#    stage_description : nan
#    year : 2019.0
#    market_share_chart_caption : nan
#    market_share_chart_global_market_size_info : $10.9 billion
#    market_share_chart_source : [CSET](https://cset.georgetown.edu/publication/the-semiconductor-supply-chain/) (citing CSET estimates based on financial statements and wafer production capacities)
#    provider_name : CHN
#    provider_id : P2
#    provider_alias : China
#    provider_type : country
#    provider_country : nan
#    share_provided : 4.0
#    year_share_provided : 2019.0
#    source_provider_provided : [CSET](https://cset.georgetown.edu/publication/the-semiconductor-supply-chain/) (citing CSET estimates based on financial statements and wafer production capacities)
#
# N9
#    displayName : Crystal machining tools
#    input_name : Crystal machining tools
#    type : tool_resource
#    description : Crystal growing furnaces and machining tools are necessary to produce all wafers-thin, disc-shaped materials fabs used to produce chips. The furnace forms a cylindrical ingot of silicon from polycrystalline raw silicon; machining equipment then cuts the ingot into wafers used for chip fabrication. These tools have relatively low value and complexity relative to other semiconductor manufacturing equipment.
#    stage_name :
#    stage_id :
#    stage_description : nan
#    year : 2024.0
#    market_share_chart_caption : nan
#    market_share_chart_global_market_size_info : $312.3 million (2024)
#    market_share_chart_source : CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.
#    provider_name : Accretech
#    provider_id : P60
#    provider_alias : ACCRETECH - Tokyo Seimitsu
#    provider_type : organization
#    provider_country : JPN
#    share_provided : 25.5
#    year_share_provided : 2024.0
#    source_provider_provided : CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.
#
# N20
#    displayName : EUV lithography tools
#    input_name : EUV lithography tools
#    type : tool_resource
#    description : EUV lithography tools are the most advanced photolithography equipment currently used in mass semiconductor production. They are the only tools combining leading-edge precision (by producing light with small wavelengths) with high throughput (by using photomasks), and are necessary for mass-producing the most advanced logic chips. They are exclusively produced by the Dutch firm ASML. A single EUV scanner costs well over $150 million, ships in 40 freight containers and contains about 100,000 individual parts.
#    stage_name :
#    stage_id :
#    stage_description : nan
#    year : 2024.0
#    market_share_chart_caption : nan
#    market_share_chart_global_market_size_info : $9 billion (2024)
#    market_share_chart_source : CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.
#    provider_name : ASML
#    provider_id : P88
#    provider_alias : nan
#    provider_type : organization
#    provider_country : NLD
#    share_provided : 100.0
#    year_share_provided : 2024.0
#    source_provider_provided : CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.
#
# N19
#    displayName : Lithography tools
#    input_name : Lithography tools
#    type : tool_resource
#    description : The Netherlands, Japan, and a small number of other countries are the dominant producers of lithography equipment, critical for the production of chips and photomasks. In particular, the Netherlands and Japan are exclusive providers of advanced photolithography scanners, necessary for mass-production of advanced chips.\n\nPhotolithography scanners use ultraviolet light to draw intricate, nanoscale patterns into semiconductor wafers, creating the billions of tiny circuits contained in a single advanced logic chip. An extreme ultraviolet (EUV) scanner refracts a beam of 13.5 nm ultraviolet light through a photomask, transferring that pattern to a photoresist chemical applied as a layer on the chip. The light dissolves parts of the photoresist in the circuit pattern. The newly created photoresist pattern is etched into a permanent chip substrate below the photoresist. Throughout this process, the scanner precisely moves the wafer and the photomask helps build the design.
#    stage_name :
#    stage_id :
#    stage_description : nan
#    year : 2024.0
#    market_share_chart_caption : nan
#    market_share_chart_global_market_size_info : $29.1 billion (2024)
#    market_share_chart_source : CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.
#    provider_name : ASML
#    provider_id : P88
#    provider_alias : nan
#    provider_type : organization
#    provider_country : NLD
#    share_provided : 78.5
#    year_share_provided : 2024.0
#    source_provider_provided : CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.
#
#
# EDGES :
# ('N8', 'N26', {'type': 'goes_into'})
# ('N26', 'N117', {'type': 'goes_into'})
# ('N9', 'N26', {'type': 'goes_into'})
# ('N20', 'N19', {'type': 'is_type_of'})
# ('N19', 'N25', {'type': 'goes_into'})

# %% [markdown]
# # Graph Creation in TuringDB

# %% [markdown]
# ## Build Cypher CREATE Commands

# %%
# Build CREATE command from networkx object
graph_CREATE_command = build_create_command_from_networkx(G, node_type_key="type")

print(f"""
Cypher CREATE command :
* size: {len(graph_CREATE_command.encode('utf-8'))/1024/1000:.4f} MB\n
{100 * '*'}
{graph_CREATE_command if len(graph_CREATE_command.split("\n")) < 10000 else "\n".join(graph_CREATE_command.split('\n')[:5]) + "\n...\n" + "\n".join(graph_CREATE_command.split('\n')[-5:])}
{100 * '*'}
""")
# Out:
# Cypher query will create graph with 126 nodes and 139 edges
#
# Cypher CREATE command :
# * size: 0.1569 MB
#
# ****************************************************************************************************
# CREATE (:ToolResource {id: "N8", displayName: "Crystal growing furnaces", input_name: "Crystal growing furnaces", type: "tool_resource", description: "Crystal growing furnaces and machining tools are necessary to produce all wafers-thin, disc-shaped materials fabs used to produce chips. The furnace forms a cylindrical ingot of silicon from polycrystalline raw silicon; machining equipment then cuts the ingot into wafers used for chip fabrication. These tools have relatively low value and complexity relative to other semiconductor manufacturing equipment. Japan, Germany, and Switzerland are the main producers.", stage_name: "", stage_id: "", stage_description: "nan", year: 2022.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$44 million (2022)", market_share_chart_source: "CSET analysis of TechInsights data (2022). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "DEU", provider_id: "P32", provider_alias: "Germany", provider_type: "country", provider_country: "nan", share_provided: 100.0, year_share_provided: 2022.0, source_provider_provided: "CSET analysis of TechInsights data (2022). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:MaterialResource {id: "N26", displayName: "Wafer", input_name: "Wafer", type: "material_resource", description: "Silicon wafers are the basic building block for chip production. To produce them, a furnace forms a cylinder of silicon (or other semiconducting materials), which is then cut into disc-shaped wafers. These wafers are then processed, split and packaged into individual chips. Most wafers are made purely of silicon or another material, but others have more complex structures. Dopants, such as boron, aluminum, phosphorous, platinum or other elements, may be added to alter the level of semiconductivity.nn300 mm wafers, produced by Japanese, Taiwanese, German, and Korean firms, are used to produce nearly all advanced chips today. Manufacturing the smoothest, high-purity 300 mm wafers-which are necessary for supporting the smallest chip feature sizes-requires considerable tacit know-how. Older-technology wafer sizes include 150 and 200 mm, used for chips with larger feature sizes.", stage_name: "", stage_id: "", stage_description: "nan", year: 2019.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$10.9 billion", market_share_chart_source: "[CSET](https://cset.georgetown.edu/publication/the-semiconductor-supply-chain/) (citing CSET estimates based on financial statements and wafer production capacities)", provider_name: "CHN", provider_id: "P2", provider_alias: "China", provider_type: "country", provider_country: "nan", share_provided: 4.0, year_share_provided: 2019.0, source_provider_provided: "[CSET](https://cset.georgetown.edu/publication/the-semiconductor-supply-chain/) (citing CSET estimates based on financial statements and wafer production capacities)"}),
# (:ToolResource {id: "N9", displayName: "Crystal machining tools", input_name: "Crystal machining tools", type: "tool_resource", description: "Crystal growing furnaces and machining tools are necessary to produce all wafers-thin, disc-shaped materials fabs used to produce chips. The furnace forms a cylindrical ingot of silicon from polycrystalline raw silicon; machining equipment then cuts the ingot into wafers used for chip fabrication. These tools have relatively low value and complexity relative to other semiconductor manufacturing equipment.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$312.3 million (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "Accretech", provider_id: "P60", provider_alias: "ACCRETECH - Tokyo Seimitsu", provider_type: "organization", provider_country: "JPN", share_provided: 25.5, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N20", displayName: "EUV lithography tools", input_name: "EUV lithography tools", type: "tool_resource", description: "EUV lithography tools are the most advanced photolithography equipment currently used in mass semiconductor production. They are the only tools combining leading-edge precision (by producing light with small wavelengths) with high throughput (by using photomasks), and are necessary for mass-producing the most advanced logic chips. They are exclusively produced by the Dutch firm ASML. A single EUV scanner costs well over $150 million, ships in 40 freight containers and contains about 100,000 individual parts.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$9 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ASML", provider_id: "P88", provider_alias: "nan", provider_type: "organization", provider_country: "NLD", share_provided: 100.0, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N19", displayName: "Lithography tools", input_name: "Lithography tools", type: "tool_resource", description: "The Netherlands, Japan, and a small number of other countries are the dominant producers of lithography equipment, critical for the production of chips and photomasks. In particular, the Netherlands and Japan are exclusive providers of advanced photolithography scanners, necessary for mass-production of advanced chips.nnPhotolithography scanners use ultraviolet light to draw intricate, nanoscale patterns into semiconductor wafers, creating the billions of tiny circuits contained in a single advanced logic chip. An extreme ultraviolet (EUV) scanner refracts a beam of 13.5 nm ultraviolet light through a photomask, transferring that pattern to a photoresist chemical applied as a layer on the chip. The light dissolves parts of the photoresist in the circuit pattern. The newly created photoresist pattern is etched into a permanent chip substrate below the photoresist. Throughout this process, the scanner precisely moves the wafer and the photomask helps build the design.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$29.1 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ASML", provider_id: "P88", provider_alias: "nan", provider_type: "organization", provider_country: "NLD", share_provided: 78.5, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N21", displayName: "ArF dry (DUV) lithography tools", input_name: "ArF dry (DUV) lithography tools", type: "tool_resource", description: "ArF dry lithography scanners are advanced deep ultraviolet (DUV) photolithography tools used in high-volume semiconductor manufacturing. ArF dry lithography tools use 193 nm wavelength light from argon fluoride (ArF) lasers to pattern critical non-immersion layers in chip production. Only the Dutch firm ASML and the Japanese firm Nikon produce ArF lithography tools capable of mass production.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$887.8 million (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ASML", provider_id: "P88", provider_alias: "nan", provider_type: "organization", provider_country: "NLD", share_provided: 94.3, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N22", displayName: "ArF immersion (DUV) lithography tools", input_name: "ArF immersion (DUV) lithography tools", type: "tool_resource", description: "ArF immersion lithography scanners are advanced deep ultraviolet (DUV) photolithography tools used in high-volume semiconductor manufacturing. ArF dry lithography tools use 193 nm wavelength light and a liquid medium to achieve high-resolution patterning for advanced semiconductors. EUV and ArF immersion scanners are the only lithography tools capable of mass-producing chips at near-cutting edge scale (the absolute cutting edge requires EUV). Only the Dutch firm ASML and the Japanese firm Nikon produce ArF scanners or ArF immersion scanners capable of mass production.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$10.6 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ASML", provider_id: "P88", provider_alias: "nan", provider_type: "organization", provider_country: "NLD", share_provided: 98.7, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:Process {id: "N25", displayName: "Photolithography", input_name: "Photolithography", type: "process", description: "In photolithography, light is used to draw patterns into semiconductor wafers, creating the tiny circuits that comprise logic chips. A photolithography tool passes light through a photomask-a transparent plate with a circuit pattern-to transfer that pattern to a wafer coated with photoresist chemical. (Photomasks are themselves made with lithography tools.) The light dissolves parts of the photoresist according to the circuit pattern.nnAdvanced photolithography is critical to mass production of cutting-edge semiconductors. It requires enormously complex, expensive equipment supplied by only a few vendors in Europe and Japan. The most sophisticated photolithography processes involve extreme ultraviolet (EUV) scanners, produced exclusively by the Dutch firm ASML.", stage_name: "Fabrication", stage_id: "S2", stage_description: "Fabrication turns designs into chips. Semiconductor fabrication facilities ( fabs ) make chips in these wafers in two steps: forming transistors and other electrical devices in material layers within silicon wafers; and forming metal interconnects between the electrical devices in insulating layers above the silicon. There are two business models for fabs: (1) fabs owned by integrated device manufacturers ( IDMs ), which manufacture chips based on their own designs; and (2) foundries, i.e., fabs operating independently and manufacturing chips for third-party customers. Firms headquartered in the United States, Taiwan, South Korea, Japan, and China control the vast majority of the world s fab market share. In 2022, fab capacity was concentrated in China, Taiwan, South Korea, and Japan (highest to lowest). Advanced logic fab capacity (<10nm) was located solely in Taiwan and South Korea controlled by TSMC and Samsung, respectively. As of 2024, two firms are newly capable of fabricating advanced logic: Intel (headquartered in the United States) and SMIC (headquartered in China). Advanced logic capacity is expected to diversify by 2032, with fabs located in the United States, Japan, Europe, and China.", market_share_chart_caption: "Chart shows share of global fabrication capacity (for logic, memory, and DAO devices) by site location.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:Process {id: "N16", displayName: "Ion implantation", input_name: "Ion implantation", type: "process", description: "Ion implanters embed dopant substances into silicon wafers to give different parts of the wafer different levels of semiconductivity to make functional transistors in chips. Different types of implanters are used for different purposes. Low-to-medium-current ion implanters and high-current ion implanters are most commonly used, with high-current ion implanters capable of greater throughput. Meanwhile, high-voltage ion implanters can implant ions deeply into silicon, and ultra-high-dose doping implanters can achieve greater dopant density than the other tools. The United States is the dominant producer of ion implanters, with Japan and Taiwan rounding out most of global market share.", stage_name: "Fabrication", stage_id: "S2", stage_description: "Fabrication turns designs into chips. Semiconductor fabrication facilities ( fabs ) make chips in these wafers in two steps: forming transistors and other electrical devices in material layers within silicon wafers; and forming metal interconnects between the electrical devices in insulating layers above the silicon. There are two business models for fabs: (1) fabs owned by integrated device manufacturers ( IDMs ), which manufacture chips based on their own designs; and (2) foundries, i.e., fabs operating independently and manufacturing chips for third-party customers. Firms headquartered in the United States, Taiwan, South Korea, Japan, and China control the vast majority of the world s fab market share. In 2022, fab capacity was concentrated in China, Taiwan, South Korea, and Japan (highest to lowest). Advanced logic fab capacity (<10nm) was located solely in Taiwan and South Korea controlled by TSMC and Samsung, respectively. As of 2024, two firms are newly capable of fabricating advanced logic: Intel (headquartered in the United States) and SMIC (headquartered in China). Advanced logic capacity is expected to diversify by 2032, with fabs located in the United States, Japan, Europe, and China.", market_share_chart_caption: "Chart shows share of global fabrication capacity (for logic, memory, and DAO devices) by site location.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:Process {id: "N57", displayName: "Chemical mechanical planarization", input_name: "Chemical mechanical planarization", type: "process", description: "After etching and cleaning, the wafer surface is flattened in a process called chemical mechanical planarization (CMP) to allow a new layer of features to be added. CMP tools are critical for chip fabrication, but not as complex as other tools, such as lithography and deposition tools.", stage_name: "Fabrication", stage_id: "S2", stage_description: "Fabrication turns designs into chips. Semiconductor fabrication facilities ( fabs ) make chips in these wafers in two steps: forming transistors and other electrical devices in material layers within silicon wafers; and forming metal interconnects between the electrical devices in insulating layers above the silicon. There are two business models for fabs: (1) fabs owned by integrated device manufacturers ( IDMs ), which manufacture chips based on their own designs; and (2) foundries, i.e., fabs operating independently and manufacturing chips for third-party customers. Firms headquartered in the United States, Taiwan, South Korea, Japan, and China control the vast majority of the world s fab market share. In 2022, fab capacity was concentrated in China, Taiwan, South Korea, and Japan (highest to lowest). Advanced logic fab capacity (<10nm) was located solely in Taiwan and South Korea controlled by TSMC and Samsung, respectively. As of 2024, two firms are newly capable of fabricating advanced logic: Intel (headquartered in the United States) and SMIC (headquartered in China). Advanced logic capacity is expected to diversify by 2032, with fabs located in the United States, Japan, Europe, and China.", market_share_chart_caption: "Chart shows share of global fabrication capacity (for logic, memory, and DAO devices) by site location.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:Process {id: "N46", displayName: "Etch and clean", input_name: "Etch and clean", type: "process", description: "After photolithography creates a pattern in the photoresist coating a wafer, specialized tools etch the pattern into the permanent layer below the photoresist. The photoresist is then removed and the etched material cleaned off of the layer.nnThe United States and Japan are the main producers of etch and clean equipment; South Korea and China are also significant suppliers.", stage_name: "Fabrication", stage_id: "S2", stage_description: "Fabrication turns designs into chips. Semiconductor fabrication facilities ( fabs ) make chips in these wafers in two steps: forming transistors and other electrical devices in material layers within silicon wafers; and forming metal interconnects between the electrical devices in insulating layers above the silicon. There are two business models for fabs: (1) fabs owned by integrated device manufacturers ( IDMs ), which manufacture chips based on their own designs; and (2) foundries, i.e., fabs operating independently and manufacturing chips for third-party customers. Firms headquartered in the United States, Taiwan, South Korea, Japan, and China control the vast majority of the world s fab market share. In 2022, fab capacity was concentrated in China, Taiwan, South Korea, and Japan (highest to lowest). Advanced logic fab capacity (<10nm) was located solely in Taiwan and South Korea controlled by TSMC and Samsung, respectively. As of 2024, two firms are newly capable of fabricating advanced logic: Intel (headquartered in the United States) and SMIC (headquartered in China). Advanced logic capacity is expected to diversify by 2032, with fabs located in the United States, Japan, Europe, and China.", market_share_chart_caption: "Chart shows share of global fabrication capacity (for logic, memory, and DAO devices) by site location.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:ToolResource {id: "N28", displayName: "Maskless lithography tools", input_name: "Maskless lithography tools", type: "tool_resource", description: "Maskless lithography equipment draws patterns in a substrate using laser light, electrons, or ions. Unlike photolithography equipment, maskless lithography tools work without masks. This allows them to quickly and cheaply make new patterns, but slows down the process of drawing patterns into the wafer. As a result, maskless lithography tools can cost-effectively produce low-volume items like photomasks, but are are ill-suited to mass chip production.", stage_name: "", stage_id: "", stage_description: "nan", market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:ToolResource {id: "N29", displayName: "Mask exposure systems - e-beam", input_name: "Mask exposure systems - e-beam", type: "tool_resource", description: "Electron-beam (or e-beam ) lithography tools draw patterns in a substrate using electrons. They are the dominant tools for photomask production, and are also infrequently used for low-volume chip production. Like other maskless lithography tools, e-beam tools can quickly and cheaply make new patterns, but are slow at drawing patterns into wafers, making them ill-suited to mass chip production.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$951.8 million (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "AUT", provider_id: "P80", provider_alias: "Austria", provider_type: "country", provider_country: "nan", share_provided: 46.4, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N30", displayName: "Mask exposure systems - laser beam", input_name: "Mask exposure systems - laser beam", type: "tool_resource", description: "Laser lithography tools draw patterns in a substrate using laser light. They are sometimes used to produce photomasks (though less often than e-beam tools). Like other maskless lithography tools, laser lithography tools can quickly and cheaply make new patterns, but are slow at drawing patterns into wafers, making them ill-suited to mass chip production.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$185 million (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "Applied Materials", provider_id: "P81", provider_alias: "nan", provider_type: "organization", provider_country: "USA", share_provided: 61.4, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:MaterialResource {id: "N33", displayName: "Photomasks", input_name: "Photomasks", type: "material_resource", description: "Photomasks are transparent plates containing a circuit pattern to be fabricated in a chip. Photolithography equipment produces light that passes through this pattern so that the photomask s pattern is transferred to the chip. Each photomask is specific to one chip design. Photomasks are produced by captive mask shops (businesses within large semiconductor manufacturing firms) or merchant mask shops (which sell to semiconductor manufacturers). Japan, the United States, and Taiwan lead production of leading-edge photomasks.", stage_name: "", stage_id: "", stage_description: "nan", year: 2019.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$4 billion (all photomasks)", market_share_chart_source: "[CSET](https://cset.georgetown.edu/publication/the-semiconductor-supply-chain/)", provider_name: "CHN", provider_id: "P2", provider_alias: "China", provider_type: "country", provider_country: "nan", year_share_provided: 2019.0, source_provider_provided: "[CSET](https://cset.georgetown.edu/publication/the-semiconductor-supply-chain/)"}),
# (:MaterialResource {id: "N31", displayName: "Photoresists", input_name: "Photoresists", type: "material_resource", description: "Photoresists are chemicals deposited on a wafer. When exposed to patterned light that has passed through a photomask, they selectively dissolve to form the circuit pattern. Etching is then performed in places where the photoresist has dissolved to transfer the circuit pattern permanently onto the wafer. Photoresists are specific to particular photolithography processes. Japanese firms are the leading producers.", stage_name: "", stage_id: "", stage_description: "nan", year: 2019.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$3.3 billion (all photoresists)", market_share_chart_source: "[CSET](https://cset.georgetown.edu/publication/the-semiconductor-supply-chain/)", provider_name: "CHN", provider_id: "P2", provider_alias: "China", provider_type: "country", provider_country: "nan", year_share_provided: 2019.0, source_provider_provided: "[CSET](https://cset.georgetown.edu/publication/the-semiconductor-supply-chain/)"}),
# (:ToolResource {id: "N32", displayName: "Resist processing tools", input_name: "Resist processing tools", type: "tool_resource", description: "Resist processing tools, also called tracks, coat photoresists on wafers (typically by spin-coating, which spins the wafer to spread deposited photoresist), develop them (dissolve portions hit by light), and bake them (harden undissolved photoresist to prepare for etching). Japan is the sole producer of the most advanced tracks for EUV and ArF immersion photolithography; Germany, South Korea, the United States, and China produce less advanced equipment.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$3.4 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "CHN", provider_id: "P2", provider_alias: "China", provider_type: "country", provider_country: "nan", share_provided: 0.6, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N36", displayName: "Deposition tools", input_name: "Deposition tools", type: "tool_resource", description: "Deposition tools are used to deposit thin films of materials on a silicon wafer. After lithography and etching, these films become different chip layers, including for transistors, interconnects (wires), and other elements. In addition to deposition tools for integrated circuit (IC) manufacturing, this section includes deposition tools for non-IC applications, specifically: compound semiconductors, MEMS, and other. Deposition tools for hard drive manufacturing are excluded.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$24.1 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ASM International", provider_id: "P112", provider_alias: "nan", provider_type: "organization", provider_country: "NLD", share_provided: 10.7, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:Process {id: "N35", displayName: "Deposition", input_name: "Deposition", type: "process", description: "In the deposition process, specialized tools are used to deposit thin films of materials on a silicon wafer. After lithography and etching, these films become different chip layers, including for transistors, interconnects (wires), and other elements.", stage_name: "Fabrication", stage_id: "S2", stage_description: "Fabrication turns designs into chips. Semiconductor fabrication facilities ( fabs ) make chips in these wafers in two steps: forming transistors and other electrical devices in material layers within silicon wafers; and forming metal interconnects between the electrical devices in insulating layers above the silicon. There are two business models for fabs: (1) fabs owned by integrated device manufacturers ( IDMs ), which manufacture chips based on their own designs; and (2) foundries, i.e., fabs operating independently and manufacturing chips for third-party customers. Firms headquartered in the United States, Taiwan, South Korea, Japan, and China control the vast majority of the world s fab market share. In 2022, fab capacity was concentrated in China, Taiwan, South Korea, and Japan (highest to lowest). Advanced logic fab capacity (<10nm) was located solely in Taiwan and South Korea controlled by TSMC and Samsung, respectively. As of 2024, two firms are newly capable of fabricating advanced logic: Intel (headquartered in the United States) and SMIC (headquartered in China). Advanced logic capacity is expected to diversify by 2032, with fabs located in the United States, Japan, Europe, and China.", market_share_chart_caption: "Chart shows share of global fabrication capacity (for logic, memory, and DAO devices) by site location.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:ToolResource {id: "N38", displayName: "Plasma CVD tools", input_name: "Plasma CVD tools", type: "tool_resource", description: "Plasma chemical vapor deposition tools are used to deposit for materials requiring low temperatures during the deposition process. They are mostly produced by American firms.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$6.3 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ASM International", provider_id: "P112", provider_alias: "nan", provider_type: "organization", provider_country: "NLD", share_provided: 1.6, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N47", displayName: "Chemical vapor deposition tools", input_name: "Chemical vapor deposition tools", type: "tool_resource", description: "Chemical vapor deposition (CVD) tools create a chemical vapor that deposits films on the wafer atom-by-atom or molecule-by-molecule. CVD is the most widely used deposition technique in chip fabrication. It is used to deposit most dielectrics (a type of insulator), silicon, and some metals.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$9.6 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ASM International", provider_id: "P112", provider_alias: "nan", provider_type: "organization", provider_country: "NLD", share_provided: 4.2, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N39", displayName: "Low-pressure CVD tools", input_name: "Low-pressure CVD tools", type: "tool_resource", description: "Low-pressure chemical vapor deposition tools are commonly used to deposit polysilicon, tungsten, titanium, and titanium nitride.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$1.8 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "AMEC", provider_id: "P123", provider_alias: "Advanced Micro-Fabrication Equipment Inc. China", provider_type: "organization", provider_country: "CHN", share_provided: 1.2, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N40", displayName: "High-temperature CVD tools", input_name: "High-temperature CVD tools", type: "tool_resource", description: "High-temperature chemical vapor deposition tools are used to deposit epitaxial layers (layers oriented in a particular way relative to underlying layers).", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$1.5 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ASM International", provider_id: "P112", provider_alias: "nan", provider_type: "organization", provider_country: "NLD", share_provided: 20.5, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N41", displayName: "Atomic layer deposition tools", input_name: "Atomic layer deposition tools", type: "tool_resource", description: "Atomic layer deposition (ALD) tools are particularly advanced chemical vapor deposition tools capable of depositing layers a single atom in thickness, and are essential for leading-edge chip designs.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$3.5 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ASM International", provider_id: "P112", provider_alias: "nan", provider_type: "organization", provider_country: "NLD", share_provided: 52.5, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N42", displayName: "Physical vapor deposition tools", input_name: "Physical vapor deposition tools", type: "tool_resource", description: "Physical vapor deposition (PVD) tools vaporize a solid or liquid material, which then condenses onto a substrate. The primary PVD method is called sputtering. The United States controls most of the PVD equipment market, followed by China and Japan.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$4.6 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "Applied Materials", provider_id: "P81", provider_alias: "nan", provider_type: "organization", provider_country: "USA", share_provided: 85.6, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N43", displayName: "Rapid thermal processing tools", input_name: "Rapid thermal processing tools", type: "tool_resource", description: "Rapid thermal processing (RTP) is critical to several steps in chip manufacturing. RTP tools include lamps, lasers, or other mechanisms to quickly increase the temperature of a wafer in order to change its properties. For instance, RTP tools are used to activate materials (such as dopants in transistors) to change their properties, modify materials, or make deposited films denser to improve their properties. Some RTP tools provide heat for as long as multiple seconds (solely produced by the United States and South Korea); others provide it only for milliseconds (solely produced by the United States and Japan).", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$1.4 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "AP Systems", provider_id: "P120", provider_alias: "nan", provider_type: "organization", provider_country: "KOR", share_provided: 1.2, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N44", displayName: "Tube-based diffusion and deposition tools", input_name: "Tube-based diffusion and deposition tools", type: "tool_resource", description: "Tube-based diffusion and deposition systems are called tube -based because substrates are loaded in cylindrical chambers for processing, either causing diffusion of dopants into a wafer (tube diffusion systems) or depositing materials for particular applications (tube deposition systems).", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$2.2 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ASM International", provider_id: "P112", provider_alias: "nan", provider_type: "organization", provider_country: "NLD", share_provided: 7.0, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N45", displayName: "Electrochemical plating tools", input_name: "Electrochemical plating tools", type: "tool_resource", description: "Electrochemical plating (ECP) tools use electrolysis to deposit materials. A common application is to deposit copper (used for wiring in chips) across a wafer. However, other techniques, such as chemical vapor deposition, can also deposit copper for some applications.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$688.7 million (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "Lam Research", provider_id: "P111", provider_alias: "nan", provider_type: "organization", provider_country: "USA", share_provided: 99.8, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:Process {id: "N0", displayName: "Chip design", input_name: "Chip design", type: "process", description: "Chip design involves specification, logic design, physical design, and validation and verification. Specification determines how the chip should operate in the system using it. Logic design creates a schematic model of interconnected electrical components. Physical design translates this model to a physical layout of electrical components and interconnects, the wires that connect components. Validation and verification ensure chips based on the design will operate as expected.", stage_name: "Design", stage_id: "S1", stage_description: "Semiconductor design involves specification, design, physical design, and validation and verification. Specification determines how the chip should operate in the system using it. Design creates a schematic model of interconnected electrical components. Physical design translates this model to a physical layout of electrical components and interconnects, the wires that connect components. Validation and verification ensure chips based on the design will operate as expected. Semiconductor design can be subdivided into three broad categories: logic, memory, and DAO (discrete, analog, and other).", year: 2022.0, market_share_chart_caption: "Chart shows market shares for the overall global semiconductor design market by country.", market_share_chart_global_market_size_info: "$574.1 billion (2022)", market_share_chart_source: "Worldwide semiconductor sales. [World Semiconductor Trade Statistics (WSTS)](https://perma.cc/Y773-9T3A) and [Semiconductor Industry Association (SIA)](https://perma.cc/MPN9-W8YS).", provider_name: "CHN", provider_id: "P2", provider_alias: "China", provider_type: "country", provider_country: "nan", share_provided: 5.0, year_share_provided: 2022.0, source_provider_provided: "Worldwide semiconductor sales. [World Semiconductor Trade Statistics (WSTS)](https://perma.cc/Y773-9T3A) and [Semiconductor Industry Association (SIA)](https://perma.cc/MPN9-W8YS)."}),
# (:ToolResource {id: "N48", displayName: "Dry etching and cleaning tools", input_name: "Dry etching and cleaning tools", type: "tool_resource", description: "Etching and cleaning tools have two main types: dry and wet. Dry etching tools-using gases to etch the substrate-are the most commonly used tool, and are especially necessary for circuit features in advanced chips. Dry etching tools have advantages over wet tools: they are fast and can etch differently depending on the direction of etch ( anisotropic etching ), which enables fine-grained features with complex shapes.nnThe most advanced dry etching tools are called atomic layer etching (ALE) tools. These tools are important for multiple etching applications in the most advanced chips, and are produced by leading U.S., Japanese, and British firms. Though it doesn t produce ALE tools, China s AMEC produces dry etching tools that are perhaps the most advanced SME tools sold by any Chinese firm. They are used for leading Taiwanese chipmaker TSMC s 7 and 5 nm nodes, though not for the finest features, such as in complex transistor structures. Recognizing China s competitiveness in dry etching tools, the United States removed these tools from the Commerce Control List in 2016.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$19.1 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "AMEC", provider_id: "P123", provider_alias: "Advanced Micro-Fabrication Equipment Inc. China", provider_type: "organization", provider_country: "CHN", share_provided: 5.3, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N55", displayName: "Etch and clean tools", input_name: "Etch and clean tools", type: "tool_resource", description: "After photolithography creates a pattern in the photoresist coating a wafer, specialized tools etch the pattern into the permanent layer below the photoresist. The photoresist is then removed and the etched material cleaned off of the layer.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$24.7 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ACM Research", provider_id: "P313", provider_alias: "nan", provider_type: "organization", provider_country: "USA", share_provided: 3.0, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N49", displayName: "Wet etching and cleaning tools", input_name: "Wet etching and cleaning tools", type: "tool_resource", description: "Etching and cleaning tools have two main types: dry and wet. Wet etching tools, using liquids, are less commonly used, and largely for cleaning wafers. Wet etching has advantages compared to dry etching-it is cheaper, risks less damage to substrates, and is more selective, i.e., it can etch a particular material without unintentionally etching nearby materials. However, it is slower and typically cannot etch differently depending on the direction of etch, making it difficult to form complex structures. Therefore, wet etching is not typically used for etching the smallest features in advanced chips.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$6.4 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ACM Research", provider_id: "P313", provider_alias: "nan", provider_type: "organization", provider_country: "USA", share_provided: 11.4, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N50", displayName: "Conductor etching tools", input_name: "Conductor etching tools", type: "tool_resource", description: "Conductor etching tools are used to carve the transistor electrodes and metal wiring into a chip. After a conductor such as copper, aluminum, tungsten, or silicon is deposited and coated with a layer of photoresist, the conductor etching tool removes the unwanted material, leaving the desired feature. U.S. firms are leading suppliers of conductor etching tools.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$9.9 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "AMEC", provider_id: "P123", provider_alias: "Advanced Micro-Fabrication Equipment Inc. China", provider_type: "organization", provider_country: "CHN", share_provided: 1.4, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# (:ToolResource {id: "N103", displayName: "Dry etch tools", input_name: "Dry etch tools", type: "tool_resource", description: "The main types of dry etching tools are used either for etching conductors or dielectrics. Major subtypes of conductor and dielectric dry etching tools include sputter etching and plasma etching; plasma etching is further divided into reactive ion etching and deep reactive ion etching (a form of reactive ion etching used to make deep wells). The most commonly used form is reactive ion etching.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$18.5 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "AMEC", provider_id: "P123", provider_alias: "Advanced Micro-Fabrication Equipment Inc. China", provider_type: "organization", provider_country: "CHN", share_provided: 5.5, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."}),
# ...
# (:ToolResource {id: "N136", displayName: "Automatic wedge bonders", input_name: "Automatic wedge bonders", type: "tool_resource", description: "Automatic wedge bonders are wire-bonding systems that form alumnium or copper wedge bonds to connect a device s die pads to a lead frame or substrate. These data exclude automatic wedge bonders designed for batteries.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$100 million (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 28, 2025.", provider_name: "ASM Pacific", provider_id: "P145", provider_alias: "ASMPT Limited", provider_type: "organization", provider_country: "SGP", share_provided: 27.2, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 28, 2025."}),
# (:ToolResource {id: "N137", displayName: "Wafer level stud bonders", input_name: "Wafer level stud bonders", type: "tool_resource", description: "Wafer level stud bonders are automated thermosonic bonding systems that fabricate gold or copper stud bumps on a wafer s bond pads.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$25.2 million (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 28, 2025.", provider_name: "ASM Pacific", provider_id: "P145", provider_alias: "ASMPT Limited", provider_type: "organization", provider_country: "SGP", share_provided: 62.2, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 28, 2025."}),
# (:ToolResource {id: "N138", displayName: "Other deposition tools (non-IC)", input_name: "Other deposition tools (non-IC)", type: "tool_resource", description: "Deposition tools for non-IC applications includes tools for compound semiconductors, MEMS, and other. Deposition tools for hard drive manufacturing are excluded.", stage_name: "", stage_id: "", stage_description: "nan", year: 2024.0, market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "$1.5 billion (2024)", market_share_chart_source: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025.", provider_name: "ASM International", provider_id: "P112", provider_alias: "nan", provider_type: "organization", provider_country: "NLD", share_provided: 12.4, year_share_provided: 2024.0, source_provider_provided: "CSET analysis of TechInsights data (2024). Data used for analysis were published by TechInsights on May 5, 2025."})
# MATCH (source {id: "N8"}), (target {id: "N26"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N26"}), (target {id: "N117"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N9"}), (target {id: "N26"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N20"}), (target {id: "N19"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N19"}), (target {id: "N25"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N21"}), (target {id: "N19"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N22"}), (target {id: "N19"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N25"}), (target {id: "N46"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N16"}), (target {id: "N57"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N57"}), (target {id: "N69"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N46"}), (target {id: "N16"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N28"}), (target {id: "N19"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N29"}), (target {id: "N28"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N30"}), (target {id: "N28"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N33"}), (target {id: "N25"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N33"}), (target {id: "N126"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N31"}), (target {id: "N25"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N31"}), (target {id: "N126"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N32"}), (target {id: "N25"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N36"}), (target {id: "N35"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N35"}), (target {id: "N25"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N38"}), (target {id: "N47"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N47"}), (target {id: "N36"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N39"}), (target {id: "N47"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N40"}), (target {id: "N47"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N41"}), (target {id: "N36"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N42"}), (target {id: "N36"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N43"}), (target {id: "N36"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N44"}), (target {id: "N36"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N45"}), (target {id: "N36"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N0"}), (target {id: "N35"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N48"}), (target {id: "N55"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N55"}), (target {id: "N46"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N49"}), (target {id: "N55"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N50"}), (target {id: "N103"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N103"}), (target {id: "N48"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N51"}), (target {id: "N103"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N86"}), (target {id: "N57"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N11"}), (target {id: "N59"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N59"}), (target {id: "N118"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N12"}), (target {id: "N59"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N10"}), (target {id: "N109"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N109"}), (target {id: "N69"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N118"}), (target {id: "N25"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N118"}), (target {id: "N46"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N118"}), (target {id: "N57"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N118"}), (target {id: "N16"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N118"}), (target {id: "N35"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N61"}), (target {id: "N60"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N60"}), (target {id: "N118"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N62"}), (target {id: "N60"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N63"}), (target {id: "N109"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N64"}), (target {id: "N60"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N65"}), (target {id: "N61"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N66"}), (target {id: "N61"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N67"}), (target {id: "N61"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N69"}), (target {id: "N78"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N70"}), (target {id: "N119"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N119"}), (target {id: "N69"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N71"}), (target {id: "N119"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N72"}), (target {id: "N119"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N73"}), (target {id: "N72"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N74"}), (target {id: "N72"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N75"}), (target {id: "N72"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N76"}), (target {id: "N69"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N77"}), (target {id: "N119"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N78"}), (target {id: "N99"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N80"}), (target {id: "N120"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N120"}), (target {id: "N78"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N81"}), (target {id: "N120"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N82"}), (target {id: "N120"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N83"}), (target {id: "N78"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N85"}), (target {id: "N7"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N7"}), (target {id: "N0"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N84"}), (target {id: "N7"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N90"}), (target {id: "N57"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N90"}), (target {id: "N126"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N88"}), (target {id: "N35"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N88"}), (target {id: "N126"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N117"}), (target {id: "N25"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N117"}), (target {id: "N46"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N117"}), (target {id: "N57"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N117"}), (target {id: "N16"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N117"}), (target {id: "N35"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N93"}), (target {id: "N100"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N100"}), (target {id: "N121"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N94"}), (target {id: "N100"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N95"}), (target {id: "N100"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N96"}), (target {id: "N100"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N97"}), (target {id: "N100"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N98"}), (target {id: "N100"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N1"}), (target {id: "N6"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N6"}), (target {id: "N0"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N2"}), (target {id: "N6"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N3"}), (target {id: "N6"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N4"}), (target {id: "N6"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N107"}), (target {id: "N19"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N105"}), (target {id: "N19"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N106"}), (target {id: "N19"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N108"}), (target {id: "N28"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N104"}), (target {id: "N36"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N102"}), (target {id: "N48"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N54"}), (target {id: "N103"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N52"}), (target {id: "N48"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N53"}), (target {id: "N48"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N114"}), (target {id: "N61"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N115"}), (target {id: "N61"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N116"}), (target {id: "N61"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N79"}), (target {id: "N120"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N101"}), (target {id: "N129"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N129"}), (target {id: "N109"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N110"}), (target {id: "N128"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N128"}), (target {id: "N109"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N111"}), (target {id: "N128"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N112"}), (target {id: "N128"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N113"}), (target {id: "N128"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N5"}), (target {id: "N0"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N13"}), (target {id: "N0"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N91"}), (target {id: "N117"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N91"}), (target {id: "N121"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N92"}), (target {id: "N117"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N17"}), (target {id: "N16"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N122"}), (target {id: "N127"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N127"}), (target {id: "N109"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N123"}), (target {id: "N19"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N124"}), (target {id: "N109"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N125"}), (target {id: "N129"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N121"}), (target {id: "N69"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N121"}), (target {id: "N78"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N126"}), (target {id: "N117"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N130"}), (target {id: "N127"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N131"}), (target {id: "N73"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N132"}), (target {id: "N73"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N133"}), (target {id: "N74"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N134"}), (target {id: "N74"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N135"}), (target {id: "N74"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N136"}), (target {id: "N74"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N137"}), (target {id: "N74"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# MATCH (source {id: "N138"}), (target {id: "N36"}) CREATE (source)-[:IS_TYPE_OF]->(target)
# ****************************************************************************************************

# %% [markdown]
# ## Split command into chunks

# %%
# %%time

chunks = split_cypher_commands(graph_CREATE_command, max_size_mb=1)

print(f"✓ Split into {len(chunks['node_chunks'])} node chunk(s) and {len(chunks['edge_chunks'])} edge chunk(s)")

print("\nNode chunks:")
for i, chunk in enumerate(chunks['node_chunks']):
    print(f"  Node chunk {i+1}: {len(chunk.encode('utf-8'))/1024:.1f} KB")
    if i == 10:
        print("  ...")
        break

print("\nEdge chunks:")
for i, chunk in enumerate(chunks['edge_chunks']):
    print(f"  Edge chunk {i+1}: {len(chunk.encode('utf-8'))/1024:.1f} KB")
    if i == 10:
        print("  ...")
        break
# Out:
# ✓ Split into 1 node chunk(s) and 139 edge chunk(s)
#
# Node chunks:
#   Node chunk 1: 144.8 KB
#
# Edge chunks:
#   Edge chunk 1: 0.1 KB
#   Edge chunk 2: 0.1 KB
#   Edge chunk 3: 0.1 KB
#   Edge chunk 4: 0.1 KB
#   Edge chunk 5: 0.1 KB
#   Edge chunk 6: 0.1 KB
#   Edge chunk 7: 0.1 KB
#   Edge chunk 8: 0.1 KB
#   Edge chunk 9: 0.1 KB
#   Edge chunk 10: 0.1 KB
#   Edge chunk 11: 0.1 KB
#   ...
# CPU times: user 21.3 ms, sys: 867 μs, total: 22.2 ms
# Wall time: 21.1 ms

# %% [markdown]
# # Create graph using `turingdb` python package

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         See <a href="https://docs.turingdb.ai/quickstart">TuringDB Get started documentation</a> for the important steps to follow :
#     </h2>
#     <h4>
#         <ul>
#             <li>Create your TuringDB account</li>
#             <li>Create your instance in the <a href="https://console.turingdb.ai/auth">TuringDB Cloud UI</a></li>
#             <li>Copy your Instance ID from the Database Instances management page</li>
#             <li>Get API Key from the Settings in UI</li>
#         </ul>
#         Remember to have your instance active while working in this notebook !
#     </h4>
# </div>

# %%
from turingdb import TuringDB

# Create TuringDB client
# set host parameter to the URL (as string) on which TuringDB is running,
# default "http://localhost:6666"
client = TuringDB(host="http://localhost:6666")
try:
    client.warmup()
except Exception as e:
    print(f"TuringDB not started, please run `uv run turingdb` in your terminal")

# %%
# Get list of available graphs
list_graphs = client.list_available_graphs()

# %%
client.list_loaded_graphs()
# Out:
# ['default']

# %%
# Set graph name
graph_name_prefix = example_name
graph_name_nb_suffix = str(
    max(
        [
            int(re.sub(graph_name_prefix, "", g))
            for g in list_graphs
            if g.startswith(graph_name_prefix)
            and re.sub(graph_name_prefix, "", g).isdigit()
        ]
        + [0]
    )
    + 1
)
graph_name = graph_name_prefix + graph_name_nb_suffix
graph_name = re.sub("-", "_", graph_name)
graph_name
# Out:
# 'supply_chain_eto_chip_explorer1'

# %%
from turingdb.exceptions import TuringDBException

# %%
# %%time

# Set graph
try:
    client.create_graph(graph_name)
except TuringDBException as e:
    print(e)

# Set working graph
client.set_graph(graph_name)
# Out:
# CPU times: user 3.46 ms, sys: 850 μs, total: 4.31 ms
# Wall time: 20.6 ms

# %%
# %%time

# Create a new change on the graph
client.checkout()
change = client.new_change()
print(f"Current change {change}")

# Checkout into the change
client.checkout(change=change)
# Out:
# Current change 0
# CPU times: user 2.61 ms, sys: 891 μs, total: 3.5 ms
# Wall time: 3.13 ms

# %%
# %%time

# Run CREATE command
print("\nExecuting query on TuringDB...")
start_time = time.time()

print(f"✓ Split into {len(chunks['node_chunks'])} node chunk(s) and {len(chunks['edge_chunks'])} edge chunk(s)")

# CREATE nodes
print("\nNode chunks:")
for i, chunk in enumerate(tqdm(chunks['node_chunks'])):
    result = client.query(chunk)
# Commit the change
client.query("COMMIT")
print(f"✓ {len(chunks['node_chunks'])} node chunks done")

# CREATE edges
print("\nEdge chunks:")
for i, chunk in enumerate(tqdm(chunks['edge_chunks'])):
    result = client.query(chunk)
# Commit the change
client.query("COMMIT")
print(f"✓ {len(chunks['edge_chunks'])} edge chunks done")

execution_time = time.time() - start_time
print(f"\n✓ Graph created successfully in {execution_time:.2f} seconds")

# Submit changes
start_time = time.time()
client.query("CHANGE SUBMIT")
execution_time = time.time() - start_time
print(f"\n✓ Changes successfully submitted in {execution_time:.2f} seconds")

# Checkout into main
client.checkout()
# Out:
# Executing query on TuringDB...
# ✓ Split into 1 node chunk(s) and 139 edge chunk(s)
#
# Node chunks:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✓ 1 node chunks done
#
# Edge chunks:
#   0%|          | 0/139 [00:00<?, ?it/s]
# ✓ 139 edge chunks done
#
# ✓ Graph created successfully in 0.32 seconds
#
# ✓ Changes successfully submitted in 0.08 seconds
# CPU times: user 131 ms, sys: 14 ms, total: 145 ms
# Wall time: 398 ms

# %%
# Returns the commit history
client.query("CALL db.history()")
# Out:
#              commit  nodeCount  edgeCount  partCount
# 0  e39049098531d32d          0          0          0
# 1  cfb0e77ecde4c857        126          0          1
# 2  e0549bf77a189832          0        139          1
# 3  1d70d1bcb578c6a6          0          0          0

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         Visualize your graph in TuringDB Graph Visualizer ! Now that your instance is running:
#     </h2>
#     <h3>
#         <ul>
#             <li>Go to <a href="https://console.turingdb.ai/databases">TuringDB Console - Database Instances</a></li>
#             <li>In your current instance panel, click on "Open Visualizer" button</li>
#             <li>Visualizer opens, now you can choose your graph in the dropdown menu at the top-right corner</li>
#         </ul>
#         You can then play with your graph and visualize the nodes you want !
#     </h3>
# </div>

# %% [markdown]
# # Query TuringDB

# %% [markdown]
# ## Use metaqueries to have insight on graph overall structure
#
# <h3>
#     To learn more about 📮 Metaqueries, please check TuringDB documentation on this <a href="https://turingdb.mintlify.app/query/cypher_subset#%F0%9F%93%AE-metaqueries">link</a>
# </h3>

# %%
# %%time

# CALL propertyTypes() - returns a column of all the different node and edge properties and their types in the database
command = """
CALL db.propertyTypes()
"""
df_propertyTypes = client.query(command)
if df_propertyTypes.empty:
    print("No result found")
else:
    display(df_propertyTypes)
# Out:
#     id                                propertyType valueType
# 0    0                    source_provider_provided    String
# 1    1                         year_share_provided    Double
# 2    2                              share_provided    Double
# 3    3                               provider_type    String
# 4    4                                 displayName    String
# 5    5                                  input_name    String
# 6    6                                        type    String
# 7    7                                  stage_name    String
# 8    8                           stage_description    String
# 9    9                   market_share_chart_source    String
# 10  10                                          id    String
# 11  11                                    stage_id    String
# 12  12                                 description    String
# 13  13                                        year    Double
# 14  14                              provider_alias    String
# 15  15                                 provider_id    String
# 16  16                               provider_name    String
# 17  17                            provider_country    String
# 18  18                  market_share_chart_caption    String
# 19  19  market_share_chart_global_market_size_info    String
# CPU times: user 10.1 ms, sys: 726 μs, total: 10.8 ms
# Wall time: 9.77 ms

# %%
# Get node properties
nodes_properties = df_propertyTypes["propertyType"].values.tolist()
print(f"Node properties: {nodes_properties}")
# Out:
# Node properties: ['source_provider_provided', 'year_share_provided', 'share_provided', 'provider_type', 'displayName', 'input_name', 'type', 'stage_name', 'stage_description', 'market_share_chart_source', 'id', 'stage_id', 'description', 'year', 'provider_alias', 'provider_id', 'provider_name', 'provider_country', 'market_share_chart_caption', 'market_share_chart_global_market_size_info']

# %%
# %%time

# CALL labels () - returns a column of all the different node labels
command = """
CALL db.labels()
"""
df_labels = client.query(command)
if df_labels.empty:
    print("No result found")
else:
    display(df_labels)
# Out:
#    id             label
# 0   0      ToolResource
# 1   1  MaterialResource
# 2   2           Process
# 3   3    UltimateOutput
# 4   4    DesignResource
# CPU times: user 7.14 ms, sys: 1.75 ms, total: 8.89 ms
# Wall time: 7.9 ms

# %%
# %%time

# CALL edgeTypes() - returns a column of all the different edge types (edge equivalent of node labels)
command = """
CALL db.edgeTypes()
"""
df_edgeTypes = client.query(command)
if df_edgeTypes.empty:
    print("No result found")
else:
    display(df_edgeTypes)
# Out:
#    id    edgeType
# 0   0   GOES_INTO
# 1   1  IS_TYPE_OF
# CPU times: user 8.1 ms, sys: 13 μs, total: 8.11 ms
# Wall time: 7.41 ms

# %% [markdown]
# ## Counts

# %%
# %%time

# Find number of nodes and number of edges in the graph
n_nodes = len(client.query("MATCH (n) RETURN n"))
n_edges = len(client.query("MATCH (n)-->(m) RETURN n, m"))
print(f"Graph: {n_nodes:,} nodes and {n_edges:,} edges\n")
# Out:
# Graph: 126 nodes and 139 edges
#
# CPU times: user 6 ms, sys: 0 ns, total: 6 ms
# Wall time: 5.54 ms

# %%
# %%time

# Count all nodes
command = """
MATCH (n)
RETURN COUNT(n)
"""
df_count_nodes = client.query(command)
display(df_count_nodes)

# Count all edges
command = """
MATCH (n)-->()
RETURN COUNT(n)
"""
df_count_edges = client.query(command)
display(df_count_edges)

# Find number of nodes and number of edges in the graph
n_nodes = int(df_count_nodes.loc[0, "COUNT(n)"])
n_edges = int(df_count_edges.loc[0, "COUNT(n)"])
print(f"Graph: {n_nodes:,} nodes and {n_edges:,} edges\n")
# Out:
#    COUNT(n)
# 0       126
#    COUNT(n)
# 0       139
# Graph: 126 nodes and 139 edges
#
# CPU times: user 14.1 ms, sys: 2.48 ms, total: 16.6 ms
# Wall time: 15.2 ms

# %%
# Count number of nodes for each label
for label in df_labels["label"]:
    print(100 * '-')
    print(f"label: {label}")
    df_curr_label = client.query(f"""
    MATCH (n:{label})
    RETURN n.displayName
    """)
    df_curr_label_count = client.query(f"""
    MATCH (n:{label})
    RETURN count(n)
    """)
    display(df_curr_label)
    display(df_curr_label_count)
    
    print()
print(100 * '-')
# Out:
# ----------------------------------------------------------------------------------------------------
# label: ToolResource
#                              n.displayName
# 0                  Overlay metrology tools
# 1                      Dry stripping tools
# 2                        Ion milling tools
# 3                     Misc. dry etch tools
# 4                          Dry clean tools
# ..                                     ...
# 85  Film, stack, and shape metrology tools
# 86     Critical dimensions metrology tools
# 87                 Defect inspection tools
# 88                  Wafer inspection tools
# 89                   Process control tools
#
# [90 rows x 1 columns]
#    count(n)
# 0        90
# ----------------------------------------------------------------------------------------------------
# label: MaterialResource
#                              n.displayName
# 0                             Photoresists
# 1                            ATP materials
# 2   Process-specific fabrication materials
# 3                         Electronic gases
# 4                            Wet chemicals
# 5                               Photomasks
# 6               Core intellectual property
# 7                            CMP materials
# 8                     Deposition materials
# 9                              Lead frames
# 10                     Packaging materials
# 11                              Bond wires
# 12                        Ceramic packages
# 13                                   Wafer
# 14                    Die attach materials
# 15                    Encapsulation resins
# 16                              Substrates
#    count(n)
# 0        17
# ----------------------------------------------------------------------------------------------------
# label: Process
#                         n.displayName
# 0                    Ion implantation
# 1                    Photolithography
# 2   Chemical mechanical planarization
# 3                      Etch and clean
# 4              Assembly and packaging
# 5        Process control and handling
# 6                             Testing
# 7                          Deposition
# 8                     EDA and Core IP
# 9                         Chip design
# 10              Fabrication materials
#    count(n)
# 0        11
# ----------------------------------------------------------------------------------------------------
# label: UltimateOutput
#          n.displayName
# 0  Finished logic chip
#    count(n)
# 0         1
# ----------------------------------------------------------------------------------------------------
# label: DesignResource
#         n.displayName
# 0     DAO chip design
# 1  Memory chip design
# 2            AI ASICs
# 3               FPGAs
# 4       Discrete GPUs
# 5   Logic chip design
# 6       Advanced CPUs
#    count(n)
# 0         7
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Queries

# %%
# %%time

# Match all edges and return them
command = """
MATCH (n)-[e]->(m)
RETURN n.displayName, e, m.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#                n.displayName    e                   m.displayName
# 0    Overlay metrology tools    0          Wafer inspection tools
# 1        Dry stripping tools    1  Dry etching and cleaning tools
# 2          Ion milling tools    2  Dry etching and cleaning tools
# 3       Misc. dry etch tools    3                  Dry etch tools
# 4            Dry clean tools    4  Dry etching and cleaning tools
# ..                       ...  ...                             ...
# 134                 AI ASICs  134               Logic chip design
# 135                    FPGAs  135               Logic chip design
# 136            Discrete GPUs  136               Logic chip design
# 137        Logic chip design  137                     Chip design
# 138            Advanced CPUs  138               Logic chip design
#
# [139 rows x 3 columns]
# CPU times: user 7.35 ms, sys: 801 μs, total: 8.16 ms
# Wall time: 7.45 ms

# %%
# %%time

# Find all materials
command = """
MATCH (n:MaterialResource)
RETURN n, n.displayName, n.type
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#       n                           n.displayName             n.type
# 0    90                            Photoresists  material_resource
# 1    91                           ATP materials  material_resource
# 2    92  Process-specific fabrication materials  material_resource
# 3    93                        Electronic gases  material_resource
# 4    94                           Wet chemicals  material_resource
# 5    95                              Photomasks  material_resource
# 6    96              Core intellectual property  material_resource
# 7    97                           CMP materials  material_resource
# 8    98                    Deposition materials  material_resource
# 9    99                             Lead frames  material_resource
# 10  100                     Packaging materials  material_resource
# 11  101                              Bond wires  material_resource
# 12  102                        Ceramic packages  material_resource
# 13  103                                   Wafer  material_resource
# 14  104                    Die attach materials  material_resource
# 15  105                    Encapsulation resins  material_resource
# 16  106                              Substrates  material_resource
# CPU times: user 10.5 ms, sys: 549 μs, total: 11.1 ms
# Wall time: 10.1 ms

# %%
# %%time

# Find all Tool Resources
command = """
MATCH (n:ToolResource)
RETURN n.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#                              n.displayName
# 0                  Overlay metrology tools
# 1                      Dry stripping tools
# 2                        Ion milling tools
# 3                     Misc. dry etch tools
# 4                          Dry clean tools
# ..                                     ...
# 85  Film, stack, and shape metrology tools
# 86     Critical dimensions metrology tools
# 87                 Defect inspection tools
# 88                  Wafer inspection tools
# 89                   Process control tools
#
# [90 rows x 1 columns]
# CPU times: user 9.04 ms, sys: 1 ms, total: 10 ms
# Wall time: 9.02 ms

# %%
# %%time

# Find all links between FPGAs and other nodes
command = """
MATCH (n)-[e]->(m)
WHERE n.displayName = "FPGAs"
RETURN n.displayName, e, m.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#   n.displayName    e      m.displayName
# 0         FPGAs  135  Logic chip design
# CPU times: user 8.72 ms, sys: 907 μs, total: 9.63 ms
# Wall time: 8.74 ms

# %%
# %%time

# Find all relationships between Tool_Resource nodes
command = """
MATCH (i1:ToolResource)-->(i2:ToolResource)
RETURN i1.displayName, i1.type, i1, i2.displayName, i2.type, i2
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#                             i1.displayName        i1.type  i1  \
# 0                  Overlay metrology tools  tool_resource   0
# 1                      Dry stripping tools  tool_resource   1
# 2                        Ion milling tools  tool_resource   2
# 3                     Misc. dry etch tools  tool_resource   3
# 4                          Dry clean tools  tool_resource   4
# ..                                     ...            ...  ..
# 69                Process monitoring tools  tool_resource  84
# 70  Film, stack, and shape metrology tools  tool_resource  85
# 71     Critical dimensions metrology tools  tool_resource  86
# 72                 Defect inspection tools  tool_resource  87
# 73                  Wafer inspection tools  tool_resource  88
#
#                     i2.displayName        i2.type  i2
# 0           Wafer inspection tools  tool_resource  88
# 1   Dry etching and cleaning tools  tool_resource  55
# 2   Dry etching and cleaning tools  tool_resource  55
# 3                   Dry etch tools  tool_resource  51
# 4   Dry etching and cleaning tools  tool_resource  55
# ..                             ...            ...  ..
# 69           Process control tools  tool_resource  89
# 70          Wafer inspection tools  tool_resource  88
# 71          Wafer inspection tools  tool_resource  88
# 72          Wafer inspection tools  tool_resource  88
# 73           Process control tools  tool_resource  89
#
# [74 rows x 6 columns]
# CPU times: user 7.06 ms, sys: 5 μs, total: 7.07 ms
# Wall time: 6.52 ms

# %%
# %%time

# Find all relationships between Tool_Resource nodes linked by a IS_TYPE_OF edge
command = """
MATCH (i1:ToolResource)-[e:IS_TYPE_OF]->(i2:ToolResource)
RETURN i1.displayName, i1.description, i2.displayName, i2.description
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#                             i1.displayName  \
# 0                  Overlay metrology tools
# 1                      Dry stripping tools
# 2                        Ion milling tools
# 3                     Misc. dry etch tools
# 4                          Dry clean tools
# ..                                     ...
# 67                Process monitoring tools
# 68  Film, stack, and shape metrology tools
# 69     Critical dimensions metrology tools
# 70                 Defect inspection tools
# 71                  Wafer inspection tools
#
#                                        i1.description  \
# 0   Overlay metrology tools are used to measure an...
# 1   Dry stripping tools use plasma to remove photo...
# 2   Ion milling tools are advanced semiconductor m...
# 3   Miscellaneous dry etch tools are specialized s...
# 4   Dry clean tools use plasma to remove films or ...
# ..                                                ...
# 67  Process monitoring tools, such as curve tracer...
# 68  Film and wafer measuring tools include tools t...
# 69  Critical dimensions measuring tools (including...
# 70  Defect inspection tools include brightfield in...
# 71  Even the tiniest imperfections can cause serio...
#
#                     i2.displayName  \
# 0           Wafer inspection tools
# 1   Dry etching and cleaning tools
# 2   Dry etching and cleaning tools
# 3                   Dry etch tools
# 4   Dry etching and cleaning tools
# ..                             ...
# 67           Process control tools
# 68          Wafer inspection tools
# 69          Wafer inspection tools
# 70          Wafer inspection tools
# 71           Process control tools
#
#                                        i2.description
# 0   Even the tiniest imperfections can cause serio...
# 1   Etching and cleaning tools have two main types...
# 2   Etching and cleaning tools have two main types...
# 3   The main types of dry etching tools are used e...
# 4   Etching and cleaning tools have two main types...
# ..                                                ...
# 67  In semiconductor fabrication, process control ...
# 68  Even the tiniest imperfections can cause serio...
# 69  Even the tiniest imperfections can cause serio...
# 70  Even the tiniest imperfections can cause serio...
# 71  In semiconductor fabrication, process control ...
#
# [72 rows x 4 columns]
# CPU times: user 12.2 ms, sys: 2.04 ms, total: 14.2 ms
# Wall time: 13.1 ms

# %%
# %%time

# Find all relationships between nodes at the Fabrication stage
command = """
MATCH (i1:Process)-->(i2:Process)
WHERE i1.stage_name = 'Fabrication'
AND i2.stage_name = 'Fabrication'
RETURN i1.displayName, i2.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#                   i1.displayName                     i2.displayName
# 0               Ion implantation  Chemical mechanical planarization
# 1               Photolithography                     Etch and clean
# 2                 Etch and clean                   Ion implantation
# 3   Process control and handling                   Photolithography
# 4   Process control and handling                   Ion implantation
# 5   Process control and handling                         Deposition
# 6   Process control and handling                     Etch and clean
# 7   Process control and handling  Chemical mechanical planarization
# 8                     Deposition                   Photolithography
# 9          Fabrication materials                         Deposition
# 10         Fabrication materials                   Ion implantation
# 11         Fabrication materials  Chemical mechanical planarization
# 12         Fabrication materials                     Etch and clean
# 13         Fabrication materials                   Photolithography
# CPU times: user 8.52 ms, sys: 1.15 ms, total: 9.67 ms
# Wall time: 8.91 ms

# %%
# %%time

# Find all nodes of type Tool_Resource provided by ASML provider
command = """
MATCH (n:ToolResource)
WHERE n.provider_name = 'ASML'
RETURN n, n.displayName, n.description, n.provider_name, n.provider_country
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#     n                          n.displayName  \
# 0   0                Overlay metrology tools
# 1   7               i-line lithography tools
# 2   8            KrF (DUV) lithography tools
# 3  49                 E-beam metrology tools
# 4  70  ArF immersion (DUV) lithography tools
# 5  71        ArF dry (DUV) lithography tools
# 6  72                      Lithography tools
# 7  73                  EUV lithography tools
# 8  89                  Process control tools
#
#                                        n.description n.provider_name  \
# 0  Overlay metrology tools are used to measure an...            ASML
# 1  i-line lithography tools are ultraviolet (UV) ...            ASML
# 2  KrF lithography tools are deep ultraviolet (DU...            ASML
# 3  E-beam metrology tools use focused electron be...            ASML
# 4  ArF immersion lithography scanners are advance...            ASML
# 5  ArF dry lithography scanners are advanced deep...            ASML
# 6  The Netherlands, Japan, and a small number of ...            ASML
# 7  EUV lithography tools are the most advanced ph...            ASML
# 8  In semiconductor fabrication, process control ...            ASML
#
#   n.provider_country
# 0                NLD
# 1                NLD
# 2                NLD
# 3                NLD
# 4                NLD
# 5                NLD
# 6                NLD
# 7                NLD
# 8                NLD
# CPU times: user 5.01 ms, sys: 1e+03 μs, total: 6.01 ms
# Wall time: 5.54 ms

# %%
# %%time

# Find direct relationships between tools
command = """
MATCH (n1:ToolResource)-[e]->(n2:ToolResource)
RETURN n1, n1.displayName, e, n2, n2.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#     n1                          n1.displayName   e  n2  \
# 0    0                 Overlay metrology tools   0  88
# 1    1                     Dry stripping tools   1  55
# 2    2                       Ion milling tools   2  55
# 3    3                    Misc. dry etch tools   3  51
# 4    4                         Dry clean tools   4  55
# ..  ..                                     ...  ..  ..
# 69  84                Process monitoring tools  84  89
# 70  85  Film, stack, and shape metrology tools  85  88
# 71  86     Critical dimensions metrology tools  86  88
# 72  87                 Defect inspection tools  87  88
# 73  88                  Wafer inspection tools  88  89
#
#                     n2.displayName
# 0           Wafer inspection tools
# 1   Dry etching and cleaning tools
# 2   Dry etching and cleaning tools
# 3                   Dry etch tools
# 4   Dry etching and cleaning tools
# ..                             ...
# 69           Process control tools
# 70          Wafer inspection tools
# 71          Wafer inspection tools
# 72          Wafer inspection tools
# 73           Process control tools
#
# [74 rows x 5 columns]
# CPU times: user 10.3 ms, sys: 82 μs, total: 10.4 ms
# Wall time: 9.69 ms

# %%
# %%time

# Find what goes into Photolithography process
command = """
MATCH (n:ToolResource)-[e:GOES_INTO]->(p:Process)
WHERE p.displayName = 'Photolithography'
RETURN n, n.displayName, e, p, p.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#     n            n.displayName   e    p     p.displayName
# 0  66  Resist processing tools  66  108  Photolithography
# 1  72        Lithography tools  72  108  Photolithography
# CPU times: user 10.2 ms, sys: 2.84 ms, total: 13.1 ms
# Wall time: 11.7 ms

# %%
# %%time

# Find EUV lithography and its connections
command = """
MATCH (n)-[e]->(m)
WHERE n.displayName = 'EUV lithography tools'
RETURN n, n.provider_name, n.share_provided, e, m, m.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#     n n.provider_name  n.share_provided   e   m      m.displayName
# 0  73            ASML             100.0  73  72  Lithography tools
# CPU times: user 10.9 ms, sys: 2.98 ms, total: 13.9 ms
# Wall time: 12.9 ms

# %%
# %%time

# Find all ASML products
command = """
MATCH (n)
WHERE n.provider_name = 'ASML'
RETURN n, n.provider_name, n.displayName, n.share_provided, n.year_share_provided
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#     n n.provider_name                          n.displayName  \
# 0   0            ASML                Overlay metrology tools
# 1   7            ASML               i-line lithography tools
# 2   8            ASML            KrF (DUV) lithography tools
# 3  49            ASML                 E-beam metrology tools
# 4  70            ASML  ArF immersion (DUV) lithography tools
# 5  71            ASML        ArF dry (DUV) lithography tools
# 6  72            ASML                      Lithography tools
# 7  73            ASML                  EUV lithography tools
# 8  89            ASML                  Process control tools
#
#    n.share_provided  n.year_share_provided
# 0              45.1                 2024.0
# 1              35.7                 2024.0
# 2              79.2                 2024.0
# 3              37.6                 2024.0
# 4              98.7                 2024.0
# 5              94.3                 2024.0
# 6              78.5                 2024.0
# 7             100.0                 2024.0
# 8               5.2                 2024.0
# CPU times: user 10.1 ms, sys: 3 μs, total: 10.1 ms
# Wall time: 9.42 ms

# %%
# %%time

# Find all 2-hop paths from Crystal growing furnaces to any processes
command = """
MATCH (first:ToolResource)-[e1]->(n1)-[e2]->(last:Process)
WHERE first.displayName = 'Crystal growing furnaces'
RETURN first, first.displayName, first.type, e1, n1, n1.displayName, n1.type, e2, last, last.displayName, last.type
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#    first         first.displayName     first.type  e1   n1 n1.displayName  \
# 0     75  Crystal growing furnaces  tool_resource  75  103          Wafer
#
#              n1.type   e2  last       last.displayName last.type
# 0  material_resource  109   117  Fabrication materials   process
# CPU times: user 16.2 ms, sys: 1.33 ms, total: 17.5 ms
# Wall time: 16.5 ms

# %%
# %%time

# Find all tools that go into Fabrication stage processes
command = """
MATCH (t:ToolResource)-[e:GOES_INTO]-(p:Process)
WHERE p.stage_id = 'S2'
RETURN t, t.displayName, t.provider_name, e, p, p.displayName, p.stage_name, p.stage_id
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#     t                 t.displayName    t.provider_name   e    p  \
# 0  39                Ion implanters  Applied Materials  39  107
# 1  54          Etch and clean tools       ACM Research  54  110
# 2  65              Deposition tools  ASM International  65  114
# 3  66       Resist processing tools                CHN  66  108
# 4  72             Lithography tools               ASML  72  108
# 5  77  Wafer and photomask handlers            Daifuku  77  112
# 6  78                     CMP tools  Applied Materials  78  109
# 7  89         Process control tools               ASML  89  112
#
#                        p.displayName p.stage_name p.stage_id
# 0                   Ion implantation  Fabrication         S2
# 1                     Etch and clean  Fabrication         S2
# 2                         Deposition  Fabrication         S2
# 3                   Photolithography  Fabrication         S2
# 4                   Photolithography  Fabrication         S2
# 5       Process control and handling  Fabrication         S2
# 6  Chemical mechanical planarization  Fabrication         S2
# 7       Process control and handling  Fabrication         S2
# CPU times: user 11.9 ms, sys: 253 μs, total: 12.2 ms
# Wall time: 11.2 ms

# %%
# %%time

# Find suppliers and their market share for lithography tools
command = """
MATCH (n:ToolResource)
WHERE n.input_name = 'Lithography tools'
RETURN n, n.provider_name, n.provider_country, n.provider_type, n.share_provided, n.year_share_provided
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#     n n.provider_name n.provider_country n.provider_type  n.share_provided  \
# 0  72            ASML                NLD    organization              78.5
#
#    n.year_share_provided
# 0                 2024.0
# CPU times: user 6.02 ms, sys: 0 ns, total: 6.02 ms
# Wall time: 5.47 ms

# %%
# %%time

# Find the supply chain path from wafers to fabrication using 2 hops
command = """
MATCH (w:MaterialResource)-[e1:GOES_INTO]-(f1)-[e2:GOES_INTO]-(p:Process)
WHERE w.displayName = 'Wafer'
RETURN w, w.displayName, e1, f1, f1.displayName, e2, p, p.displayName, p.stage_name
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#      w w.displayName   e1   f1         f1.displayName   e2    p  \
# 0  103         Wafer  109  117  Fabrication materials  127  114
# 1  103         Wafer  109  117  Fabrication materials  128  107
# 2  103         Wafer  109  117  Fabrication materials  129  109
# 3  103         Wafer  109  117  Fabrication materials  130  110
# 4  103         Wafer  109  117  Fabrication materials  131  108
#
#                        p.displayName p.stage_name
# 0                         Deposition  Fabrication
# 1                   Ion implantation  Fabrication
# 2  Chemical mechanical planarization  Fabrication
# 3                     Etch and clean  Fabrication
# 4                   Photolithography  Fabrication
# CPU times: user 7.32 ms, sys: 83 μs, total: 7.41 ms
# Wall time: 6.86 ms

# %%
# %%time

# Find all deposition tools and their types
command = """
MATCH (specific)-[e:IS_TYPE_OF]-(general:ToolResource)
WHERE general.displayName = 'Deposition tools'
RETURN specific, specific.displayName, specific.provider_name, e, general, general.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#    specific                       specific.displayName specific.provider_name  \
# 0         5                  Plasma modification tools      Applied Materials
# 1        25            Other deposition tools (non-IC)      ASM International
# 2        56              Electrochemical plating tools           Lam Research
# 3        57  Tube-based diffusion and deposition tools      ASM International
# 4        58             Rapid thermal processing tools             AP Systems
# 5        59            Physical vapor deposition tools      Applied Materials
# 6        60              Atomic layer deposition tools      ASM International
# 7        63            Chemical vapor deposition tools      ASM International
#
#     e  general general.displayName
# 0   5       65    Deposition tools
# 1  25       65    Deposition tools
# 2  56       65    Deposition tools
# 3  57       65    Deposition tools
# 4  58       65    Deposition tools
# 5  59       65    Deposition tools
# 6  60       65    Deposition tools
# 7  63       65    Deposition tools
# CPU times: user 12.4 ms, sys: 800 μs, total: 13.2 ms
# Wall time: 12.4 ms

# %%
# %%time

# Find complete hierarchy of CVD tools
command = """
MATCH (specific)-[e1:IS_TYPE_OF]-(intermediate)-[e2:IS_TYPE_OF]-(general)
RETURN specific, specific.displayName, e1, intermediate, intermediate.displayName, e2, general, general.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#      specific     specific.displayName   e1  intermediate  \
# 0           0  Overlay metrology tools    0            88
# 1           0  Overlay metrology tools    0            88
# 2           0  Overlay metrology tools    0            88
# 3           0  Overlay metrology tools    0            88
# 4           0  Overlay metrology tools    0            88
# ..        ...                      ...  ...           ...
# 565       124        Logic chip design  138           125
# 566       125            Advanced CPUs  138           124
# 567       125            Advanced CPUs  138           124
# 568       125            Advanced CPUs  138           124
# 569       125            Advanced CPUs  138           124
#
#     intermediate.displayName   e2  general  \
# 0     Wafer inspection tools   88       89
# 1     Wafer inspection tools   85       85
# 2     Wafer inspection tools   86       86
# 3     Wafer inspection tools   87       87
# 4     Wafer inspection tools   49       49
# ..                       ...  ...      ...
# 565            Advanced CPUs  138      124
# 566        Logic chip design  134      121
# 567        Logic chip design  135      122
# 568        Logic chip design  136      123
# 569        Logic chip design  138      125
#
#                         general.displayName
# 0                     Process control tools
# 1    Film, stack, and shape metrology tools
# 2       Critical dimensions metrology tools
# 3                   Defect inspection tools
# 4                    E-beam metrology tools
# ..                                      ...
# 565                       Logic chip design
# 566                                AI ASICs
# 567                                   FPGAs
# 568                           Discrete GPUs
# 569                           Advanced CPUs
#
# [570 rows x 8 columns]
# CPU times: user 17.5 ms, sys: 2.82 ms, total: 20.3 ms
# Wall time: 19.7 ms

# %%
# %%time

# Find all Chinese providers and what they supply
command = """
MATCH (n)
WHERE n.provider_country = 'CHN'
RETURN n, n.provider_name, n.displayName, n.share_provided, n.type
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#       n n.provider_name                               n.displayName  \
# 0    12        AccoTEST           Linear and discrete testing tools
# 1    14        AccoTEST                                  Test tools
# 2    45            AMEC            Etch and clean tools (adv. pkg.)
# 3    46            AMEC               Dry etching tools (adv. pkg.)
# 4    50            AMEC                     Insulator etching tools
# 5    51            AMEC                              Dry etch tools
# 6    52            AMEC                     Conductor etching tools
# 7    55            AMEC              Dry etching and cleaning tools
# 8    62            AMEC                      Low-pressure CVD tools
# 9    81            AMEC  Fabrication tools (for advanced packaging)
# 10   97            Anji                               CMP materials
# 11  106             AKM                                  Substrates
#
#     n.share_provided             n.type
# 0               36.9      tool_resource
# 1                1.9      tool_resource
# 2               12.2      tool_resource
# 3               18.1      tool_resource
# 4                9.7      tool_resource
# 5                5.5      tool_resource
# 6                1.4      tool_resource
# 7                5.3      tool_resource
# 8                1.2      tool_resource
# 9                2.5      tool_resource
# 10               NaN  material_resource
# 11               NaN  material_resource
# CPU times: user 9.67 ms, sys: 0 ns, total: 9.67 ms
# Wall time: 9 ms

# %%
# %%time

# Find assembly tools and their connections
command = """
MATCH (n:ToolResource)-[e]->(m)
WHERE n.displayName = 'Assembly tools'
RETURN n, n.displayName, e, m, m.displayName, m.type
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#     n   n.displayName   e    m           m.displayName   m.type
# 0  23  Assembly tools  23  111  Assembly and packaging  process
# CPU times: user 13 ms, sys: 994 μs, total: 14 ms
# Wall time: 12.9 ms

# %%
# %%time

# Find complete path from design to finished chip (3 hops)
command = """
MATCH (first:Process)-[e1]->(s1)-[e2]->(s2)-[e3]->(last)
WHERE first.displayName = 'Memory chip design'
RETURN first, first.displayName, e1, s1, s1.displayName, e2, s2, s2.displayName, e3, last, last.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
# No result found
# CPU times: user 8.39 ms, sys: 102 μs, total: 8.49 ms
# Wall time: 7.63 ms

# %% [markdown]
# ## Get maximum length chain for each process (set process at start node)

# %%
# %%time

# Find all Process nodes
command = """
MATCH (n:Process)
RETURN n, n.displayName, n.description
"""
df_processes = client.query(command)
display(df_processes)
list_processes = list(df_processes["n.displayName"])
print(list_processes)
# Out:
#       n                      n.displayName  \
# 0   107                   Ion implantation
# 1   108                   Photolithography
# 2   109  Chemical mechanical planarization
# 3   110                     Etch and clean
# 4   111             Assembly and packaging
# 5   112       Process control and handling
# 6   113                            Testing
# 7   114                         Deposition
# 8   115                    EDA and Core IP
# 9   116                        Chip design
# 10  117              Fabrication materials
#
#                                         n.description
# 0   Ion implanters embed dopant substances into si...
# 1   In photolithography, light is used to draw pat...
# 2   After etching and cleaning, the wafer surface ...
# 3   After photolithography creates a pattern in th...
# 4   At the end of the fabrication process, the fin...
# 5   Process control: In semiconductor fabrication,...
# 6   Chips undergo tests requiring a range of speci...
# 7   In the deposition process, specialized tools a...
# 8   Electronic design automation (EDA) software: U...
# 9   Chip design involves specification, logic desi...
# 10  Fabrication materials are a critical input in ...
# ['Ion implantation', 'Photolithography', 'Chemical mechanical planarization', 'Etch and clean', 'Assembly and packaging', 'Process control and handling', 'Testing', 'Deposition', 'EDA and Core IP', 'Chip design', 'Fabrication materials']
# CPU times: user 5.29 ms, sys: 1.08 ms, total: 6.37 ms
# Wall time: 5.53 ms

# %%
def build_query_process_chain(process_name: str, hop_count: int) -> str:
    """Build a query to find chains starting from a specific process"""
    query = "MATCH "
    query += f'(first:Process{{displayName:"{process_name}"}})'

    for k in range(1, hop_count + 1):
        query += f"-[e{k}]-(n{k})"

    query += " RETURN first, first.id, first.displayName, "
    for k in range(1, hop_count + 1):
        if k > 1:
            query += ", "
        query += f"e{k}, n{k}, n{k}.id, n{k}.displayName"

    return query

# %%
# %%time

# Maximum number of hops to try
max_hops = 7

# Save all dictionaries during the process
list_longest_df = []

# Get maximum length chain for each process (set process at start node)
for process in list_processes:
    print(100 * "*")
    print(f"Process: {process}")

    found_path = False
    longest_df = None
    longest_hop = 0

    # Try increasing hop counts until we find the longest path
    for hop_count in tqdm(range(1, max_hops + 1)):
        command = build_query_process_chain(process, hop_count)
        df = client.query(command)

        if not df.empty:
            longest_df = df
            longest_hop = hop_count
            found_path = True
        else:
            # If we get an empty result, we've reached the maximum path length
            break

    if found_path:
        print(f"Longest path found: {longest_hop} hops")
        display(longest_df)
        list_longest_df.append(longest_df)
    else:
        print("No paths found")

print(100 * "*")
# Out:
# ****************************************************************************************************
# Process: Ion implantation
#   0%|          | 0/7 [00:00<?, ?it/s]
# Longest path found: 7 hops
#        first first.id first.displayName   e1   n1 n1.id  \
# 0        107      N16  Ion implantation  113  109   N57
# 1        107      N16  Ion implantation  113  109   N57
# 2        107      N16  Ion implantation  113  109   N57
# 3        107      N16  Ion implantation  113  109   N57
# 4        107      N16  Ion implantation  113  109   N57
# ...      ...      ...               ...  ...  ...   ...
# 88060    107      N16  Ion implantation  119  112  N118
# 88061    107      N16  Ion implantation  119  112  N118
# 88062    107      N16  Ion implantation  119  112  N118
# 88063    107      N16  Ion implantation  119  112  N118
# 88064    107      N16  Ion implantation  119  112  N118
#
#                           n1.displayName   e2   n2 n2.id  ... n5.id  \
# 0      Chemical mechanical planarization  115  111   N69  ...   N78
# 1      Chemical mechanical planarization  115  111   N69  ...   N78
# 2      Chemical mechanical planarization  115  111   N69  ...   N78
# 3      Chemical mechanical planarization  115  111   N69  ...   N78
# 4      Chemical mechanical planarization  115  111   N69  ...   N78
# ...                                  ...  ...  ...   ...  ...   ...
# 88060       Process control and handling   77   77   N59  ...   N11
# 88061       Process control and handling   77   77   N59  ...   N11
# 88062       Process control and handling   77   77   N59  ...   N12
# 88063       Process control and handling   77   77   N59  ...   N12
# 88064       Process control and handling   77   77   N59  ...   N12
#
#            n5.displayName   e6   n6 n6.id                n6.displayName   e7  \
# 0                 Testing  123  118   N99           Finished logic chip  123
# 1                 Testing   14   14  N120                    Test tools   14
# 2                 Testing   14   14  N120                    Test tools   47
# 3                 Testing   14   14  N120                    Test tools   15
# 4                 Testing   14   14  N120                    Test tools   13
# ...                   ...  ...  ...   ...                           ...  ...
# 88060      Wafer handlers   76   77   N59  Wafer and photomask handlers   76
# 88061      Wafer handlers   76   77   N59  Wafer and photomask handlers   79
# 88062  Photomask handlers   79   77   N59  Wafer and photomask handlers   77
# 88063  Photomask handlers   79   77   N59  Wafer and photomask handlers   76
# 88064  Photomask handlers   79   77   N59  Wafer and photomask handlers   79
#
#         n7 n7.id                n7.displayName
# 0      113   N78                       Testing
# 1      113   N78                       Testing
# 2       47   N79             Memory test tools
# 3       15   N80                SoC test tools
# 4       13   N81            Burn-in test tools
# ...    ...   ...                           ...
# 88060   76   N11                Wafer handlers
# 88061   79   N12            Photomask handlers
# 88062  112  N118  Process control and handling
# 88063   76   N11                Wafer handlers
# 88064   79   N12            Photomask handlers
#
# [88065 rows x 31 columns]
# ****************************************************************************************************
# Process: Photolithography
#   0%|          | 0/7 [00:00<?, ?it/s]
# Longest path found: 7 hops
#         first first.id first.displayName   e1   n1 n1.id  \
# 0         108      N25  Photolithography  114  110   N46
# 1         108      N25  Photolithography  114  110   N46
# 2         108      N25  Photolithography  114  110   N46
# 3         108      N25  Photolithography  114  110   N46
# 4         108      N25  Photolithography  114  110   N46
# ...       ...      ...               ...  ...  ...   ...
# 112522    108      N25  Photolithography   66   66   N32
# 112523    108      N25  Photolithography   66   66   N32
# 112524    108      N25  Photolithography   66   66   N32
# 112525    108      N25  Photolithography   66   66   N32
# 112526    108      N25  Photolithography   66   66   N32
#
#                  n1.displayName   e2   n2 n2.id  ... n5.id  \
# 0                Etch and clean  116  107   N16  ...   N78
# 1                Etch and clean  116  107   N16  ...   N78
# 2                Etch and clean  116  107   N16  ...   N78
# 3                Etch and clean  116  107   N16  ...   N78
# 4                Etch and clean  116  107   N16  ...   N78
# ...                         ...  ...  ...   ...  ...   ...
# 112522  Resist processing tools   66  108   N25  ...   N32
# 112523  Resist processing tools   66  108   N25  ...   N32
# 112524  Resist processing tools   66  108   N25  ...   N32
# 112525  Resist processing tools   66  108   N25  ...   N32
# 112526  Resist processing tools   66  108   N25  ...   N32
#
#                  n5.displayName   e6   n6 n6.id       n6.displayName   e7  \
# 0                       Testing  123  118   N99  Finished logic chip  123
# 1                       Testing   14   14  N120           Test tools   14
# 2                       Testing   14   14  N120           Test tools   47
# 3                       Testing   14   14  N120           Test tools   15
# 4                       Testing   14   14  N120           Test tools   13
# ...                         ...  ...  ...   ...                  ...  ...
# 112522  Resist processing tools   66  108   N25     Photolithography   91
# 112523  Resist processing tools   66  108   N25     Photolithography  118
# 112524  Resist processing tools   66  108   N25     Photolithography   72
# 112525  Resist processing tools   66  108   N25     Photolithography  131
# 112526  Resist processing tools   66  108   N25     Photolithography   66
#
#          n7 n7.id                n7.displayName
# 0       113   N78                       Testing
# 1       113   N78                       Testing
# 2        47   N79             Memory test tools
# 3        15   N80                SoC test tools
# 4        13   N81            Burn-in test tools
# ...     ...   ...                           ...
# 112522   90   N31                  Photoresists
# 112523  112  N118  Process control and handling
# 112524   72   N19             Lithography tools
# 112525  117  N117         Fabrication materials
# 112526   66   N32       Resist processing tools
#
# [112527 rows x 31 columns]
# ****************************************************************************************************
# Process: Chemical mechanical planarization
#   0%|          | 0/7 [00:00<?, ?it/s]
# Longest path found: 7 hops
#        first first.id                  first.displayName   e1   n1 n1.id  \
# 0        109      N57  Chemical mechanical planarization  115  111   N69
# 1        109      N57  Chemical mechanical planarization  115  111   N69
# 2        109      N57  Chemical mechanical planarization  115  111   N69
# 3        109      N57  Chemical mechanical planarization  115  111   N69
# 4        109      N57  Chemical mechanical planarization  115  111   N69
# ...      ...      ...                                ...  ...  ...   ...
# 82896    109      N57  Chemical mechanical planarization   78   78   N86
# 82897    109      N57  Chemical mechanical planarization   78   78   N86
# 82898    109      N57  Chemical mechanical planarization   78   78   N86
# 82899    109      N57  Chemical mechanical planarization   78   78   N86
# 82900    109      N57  Chemical mechanical planarization   78   78   N86
#
#                n1.displayName   e2   n2 n2.id  ... n5.id       n5.displayName  \
# 0      Assembly and packaging  117  113   N78  ...   N99  Finished logic chip
# 1      Assembly and packaging  117  113   N78  ...   N99  Finished logic chip
# 2      Assembly and packaging  117  113   N78  ...   N99  Finished logic chip
# 3      Assembly and packaging  117  113   N78  ...   N99  Finished logic chip
# 4      Assembly and packaging  117  113   N78  ...   N99  Finished logic chip
# ...                       ...  ...  ...   ...  ...   ...                  ...
# 82896               CMP tools   78  109   N57  ...   N86            CMP tools
# 82897               CMP tools   78  109   N57  ...   N86            CMP tools
# 82898               CMP tools   78  109   N57  ...   N86            CMP tools
# 82899               CMP tools   78  109   N57  ...   N86            CMP tools
# 82900               CMP tools   78  109   N57  ...   N86            CMP tools
#
#         e6   n6 n6.id                     n6.displayName   e7   n7 n7.id  \
# 0      123  113   N78                            Testing  123  118   N99
# 1      123  113   N78                            Testing   14   14  N120
# 2      123  113   N78                            Testing   11   11   N83
# 3      123  113   N78                            Testing   92   91  N121
# 4      123  113   N78                            Testing  117  111   N69
# ...    ...  ...   ...                                ...  ...  ...   ...
# 82896   78  109   N57  Chemical mechanical planarization  122  112  N118
# 82897   78  109   N57  Chemical mechanical planarization  113  107   N16
# 82898   78  109   N57  Chemical mechanical planarization  102   97   N90
# 82899   78  109   N57  Chemical mechanical planarization  129  117  N117
# 82900   78  109   N57  Chemical mechanical planarization   78   78   N86
#
#                      n7.displayName
# 0               Finished logic chip
# 1                        Test tools
# 2              Handlers and probers
# 3                     ATP materials
# 4            Assembly and packaging
# ...                             ...
# 82896  Process control and handling
# 82897              Ion implantation
# 82898                 CMP materials
# 82899         Fabrication materials
# 82900                     CMP tools
#
# [82901 rows x 31 columns]
# ****************************************************************************************************
# Process: Etch and clean
#   0%|          | 0/7 [00:00<?, ?it/s]
# Longest path found: 7 hops
#        first first.id first.displayName   e1   n1 n1.id  \
# 0        110      N46    Etch and clean  116  107   N16
# 1        110      N46    Etch and clean  116  107   N16
# 2        110      N46    Etch and clean  116  107   N16
# 3        110      N46    Etch and clean  116  107   N16
# 4        110      N46    Etch and clean  116  107   N16
# ...      ...      ...               ...  ...  ...   ...
# 93940    110      N46    Etch and clean  130  117  N117
# 93941    110      N46    Etch and clean  130  117  N117
# 93942    110      N46    Etch and clean  130  117  N117
# 93943    110      N46    Etch and clean  130  117  N117
# 93944    110      N46    Etch and clean  130  117  N117
#
#               n1.displayName   e2   n2 n2.id  ... n5.id  \
# 0           Ion implantation  113  109   N57  ...   N99
# 1           Ion implantation  113  109   N57  ...   N99
# 2           Ion implantation  113  109   N57  ...   N99
# 3           Ion implantation  113  109   N57  ...   N99
# 4           Ion implantation  113  109   N57  ...   N99
# ...                      ...  ...  ...   ...  ...   ...
# 93940  Fabrication materials  109  103   N26  ...    N8
# 93941  Fabrication materials  109  103   N26  ...    N8
# 93942  Fabrication materials  109  103   N26  ...    N9
# 93943  Fabrication materials  109  103   N26  ...    N9
# 93944  Fabrication materials  109  103   N26  ...    N9
#
#                  n5.displayName   e6   n6 n6.id  n6.displayName   e7   n7  \
# 0           Finished logic chip  123  113   N78         Testing  123  118
# 1           Finished logic chip  123  113   N78         Testing   14   14
# 2           Finished logic chip  123  113   N78         Testing   11   11
# 3           Finished logic chip  123  113   N78         Testing   92   91
# 4           Finished logic chip  123  113   N78         Testing  117  111
# ...                         ...  ...  ...   ...             ...  ...  ...
# 93940  Crystal growing furnaces   75  103   N26           Wafer   75   75
# 93941  Crystal growing furnaces   75  103   N26           Wafer   74   74
# 93942   Crystal machining tools   74  103   N26           Wafer  109  117
# 93943   Crystal machining tools   74  103   N26           Wafer   75   75
# 93944   Crystal machining tools   74  103   N26           Wafer   74   74
#
#       n7.id            n7.displayName
# 0       N99       Finished logic chip
# 1      N120                Test tools
# 2       N83      Handlers and probers
# 3      N121             ATP materials
# 4       N69    Assembly and packaging
# ...     ...                       ...
# 93940    N8  Crystal growing furnaces
# 93941    N9   Crystal machining tools
# 93942  N117     Fabrication materials
# 93943    N8  Crystal growing furnaces
# 93944    N9   Crystal machining tools
#
# [93945 rows x 31 columns]
# ****************************************************************************************************
# Process: Assembly and packaging
#   0%|          | 0/7 [00:00<?, ?it/s]
# Longest path found: 7 hops
#        first first.id       first.displayName   e1   n1 n1.id n1.displayName  \
# 0        111      N69  Assembly and packaging  117  113   N78        Testing
# 1        111      N69  Assembly and packaging  117  113   N78        Testing
# 2        111      N69  Assembly and packaging  117  113   N78        Testing
# 3        111      N69  Assembly and packaging  117  113   N78        Testing
# 4        111      N69  Assembly and packaging  117  113   N78        Testing
# ...      ...      ...                     ...  ...  ...   ...            ...
# 34287    111      N69  Assembly and packaging   93   91  N121  ATP materials
# 34288    111      N69  Assembly and packaging   93   91  N121  ATP materials
# 34289    111      N69  Assembly and packaging   93   91  N121  ATP materials
# 34290    111      N69  Assembly and packaging   93   91  N121  ATP materials
# 34291    111      N69  Assembly and packaging   93   91  N121  ATP materials
#
#         e2   n2 n2.id  ... n5.id  n5.displayName   e6   n6 n6.id  \
# 0      123  118   N99  ...   N78         Testing  123  118   N99
# 1      123  118   N99  ...   N78         Testing   14   14  N120
# 2      123  118   N99  ...   N78         Testing   14   14  N120
# 3      123  118   N99  ...   N78         Testing   14   14  N120
# 4      123  118   N99  ...   N78         Testing   14   14  N120
# ...    ...  ...   ...  ...   ...             ...  ...  ...   ...
# 34287   96   93   N91  ...  N121   ATP materials  106  100  N100
# 34288   96   93   N91  ...  N121   ATP materials  106  100  N100
# 34289   96   93   N91  ...  N121   ATP materials  106  100  N100
# 34290   96   93   N91  ...  N121   ATP materials   96   93   N91
# 34291   96   93   N91  ...  N121   ATP materials   96   93   N91
#
#             n6.displayName   e7   n7 n7.id         n7.displayName
# 0      Finished logic chip  123  113   N78                Testing
# 1               Test tools   14  113   N78                Testing
# 2               Test tools   47   47   N79      Memory test tools
# 3               Test tools   15   15   N80         SoC test tools
# 4               Test tools   13   13   N81     Burn-in test tools
# ...                    ...  ...  ...   ...                    ...
# 34287  Packaging materials  110  104   N98   Die attach materials
# 34288  Packaging materials  111  105   N97   Encapsulation resins
# 34289  Packaging materials  112  106   N96             Substrates
# 34290     Electronic gases   95  117  N117  Fabrication materials
# 34291     Electronic gases   96   91  N121          ATP materials
#
# [34292 rows x 31 columns]
# ****************************************************************************************************
# Process: Process control and handling
#   0%|          | 0/7 [00:00<?, ?it/s]
# Longest path found: 7 hops
#         first first.id             first.displayName   e1   n1 n1.id  \
# 0         112     N118  Process control and handling  118  108   N25
# 1         112     N118  Process control and handling  118  108   N25
# 2         112     N118  Process control and handling  118  108   N25
# 3         112     N118  Process control and handling  118  108   N25
# 4         112     N118  Process control and handling  118  108   N25
# ...       ...      ...                           ...  ...  ...   ...
# 109084    112     N118  Process control and handling   77   77   N59
# 109085    112     N118  Process control and handling   77   77   N59
# 109086    112     N118  Process control and handling   77   77   N59
# 109087    112     N118  Process control and handling   77   77   N59
# 109088    112     N118  Process control and handling   77   77   N59
#
#                       n1.displayName   e2   n2 n2.id  ... n5.id  \
# 0                   Photolithography  114  110   N46  ...   N69
# 1                   Photolithography  114  110   N46  ...   N69
# 2                   Photolithography  114  110   N46  ...   N69
# 3                   Photolithography  114  110   N46  ...   N69
# 4                   Photolithography  114  110   N46  ...   N69
# ...                              ...  ...  ...   ...  ...   ...
# 109084  Wafer and photomask handlers   79   79   N12  ...   N59
# 109085  Wafer and photomask handlers   79   79   N12  ...   N59
# 109086  Wafer and photomask handlers   79   79   N12  ...   N59
# 109087  Wafer and photomask handlers   79   79   N12  ...   N59
# 109088  Wafer and photomask handlers   79   79   N12  ...   N59
#
#                       n5.displayName   e6   n6 n6.id  \
# 0             Assembly and packaging  117  113   N78
# 1             Assembly and packaging  117  113   N78
# 2             Assembly and packaging  117  113   N78
# 3             Assembly and packaging  117  113   N78
# 4             Assembly and packaging  117  113   N78
# ...                              ...  ...  ...   ...
# 109084  Wafer and photomask handlers   77  112  N118
# 109085  Wafer and photomask handlers   77  112  N118
# 109086  Wafer and photomask handlers   77  112  N118
# 109087  Wafer and photomask handlers   76   76   N11
# 109088  Wafer and photomask handlers   79   79   N12
#
#                       n6.displayName   e7   n7 n7.id  \
# 0                            Testing  123  118   N99
# 1                            Testing   14   14  N120
# 2                            Testing   11   11   N83
# 3                            Testing   92   91  N121
# 4                            Testing  117  111   N69
# ...                              ...  ...  ...   ...
# 109084  Process control and handling  122  109   N57
# 109085  Process control and handling   89   89   N60
# 109086  Process control and handling   77   77   N59
# 109087                Wafer handlers   76   77   N59
# 109088            Photomask handlers   79   77   N59
#
#                            n7.displayName
# 0                     Finished logic chip
# 1                              Test tools
# 2                    Handlers and probers
# 3                           ATP materials
# 4                  Assembly and packaging
# ...                                   ...
# 109084  Chemical mechanical planarization
# 109085              Process control tools
# 109086       Wafer and photomask handlers
# 109087       Wafer and photomask handlers
# 109088       Wafer and photomask handlers
#
# [109089 rows x 31 columns]
# ****************************************************************************************************
# Process: Testing
#   0%|          | 0/7 [00:00<?, ?it/s]
# Longest path found: 7 hops
#        first first.id first.displayName   e1   n1 n1.id  \
# 0        113      N78           Testing  123  118   N99
# 1        113      N78           Testing  123  118   N99
# 2        113      N78           Testing  123  118   N99
# 3        113      N78           Testing  123  118   N99
# 4        113      N78           Testing  123  118   N99
# ...      ...      ...               ...  ...  ...   ...
# 16065    113      N78           Testing  117  111   N69
# 16066    113      N78           Testing  117  111   N69
# 16067    113      N78           Testing  117  111   N69
# 16068    113      N78           Testing  117  111   N69
# 16069    113      N78           Testing  117  111   N69
#
#                n1.displayName   e2   n2 n2.id  ... n5.id       n5.displayName  \
# 0         Finished logic chip  123  113   N78  ...   N99  Finished logic chip
# 1         Finished logic chip  123  113   N78  ...   N99  Finished logic chip
# 2         Finished logic chip  123  113   N78  ...   N99  Finished logic chip
# 3         Finished logic chip  123  113   N78  ...   N99  Finished logic chip
# 4         Finished logic chip  123  113   N78  ...   N99  Finished logic chip
# ...                       ...  ...  ...   ...  ...   ...                  ...
# 16065  Assembly and packaging   93   91  N121  ...   N91     Electronic gases
# 16066  Assembly and packaging   93   91  N121  ...   N91     Electronic gases
# 16067  Assembly and packaging   93   91  N121  ...   N91     Electronic gases
# 16068  Assembly and packaging   93   91  N121  ...   N91     Electronic gases
# 16069  Assembly and packaging   93   91  N121  ...   N91     Electronic gases
#
#         e6   n6 n6.id         n6.displayName   e7   n7 n7.id  \
# 0      123  113   N78                Testing  123  118   N99
# 1      123  113   N78                Testing   14   14  N120
# 2      123  113   N78                Testing   11   11   N83
# 3      123  113   N78                Testing   92   91  N121
# 4      123  113   N78                Testing  117  111   N69
# ...    ...  ...   ...                    ...  ...  ...   ...
# 16065   95  117  N117  Fabrication materials  109  103   N26
# 16066   96   91  N121          ATP materials   92  113   N78
# 16067   96   91  N121          ATP materials   93  111   N69
# 16068   96   91  N121          ATP materials  106  100  N100
# 16069   96   91  N121          ATP materials   96   93   N91
#
#                n7.displayName
# 0         Finished logic chip
# 1                  Test tools
# 2        Handlers and probers
# 3               ATP materials
# 4      Assembly and packaging
# ...                       ...
# 16065                   Wafer
# 16066                 Testing
# 16067  Assembly and packaging
# 16068     Packaging materials
# 16069        Electronic gases
#
# [16070 rows x 31 columns]
# ****************************************************************************************************
# Process: Deposition
#   0%|          | 0/7 [00:00<?, ?it/s]
# Longest path found: 7 hops
#        first first.id first.displayName   e1   n1 n1.id        n1.displayName  \
# 0        114      N35        Deposition  124  108   N25      Photolithography
# 1        114      N35        Deposition  124  108   N25      Photolithography
# 2        114      N35        Deposition  124  108   N25      Photolithography
# 3        114      N35        Deposition  124  108   N25      Photolithography
# 4        114      N35        Deposition  124  108   N25      Photolithography
# ...      ...      ...               ...  ...  ...   ...                   ...
# 88429    114      N35        Deposition  103   98   N88  Deposition materials
# 88430    114      N35        Deposition  103   98   N88  Deposition materials
# 88431    114      N35        Deposition  103   98   N88  Deposition materials
# 88432    114      N35        Deposition  103   98   N88  Deposition materials
# 88433    114      N35        Deposition  103   98   N88  Deposition materials
#
#         e2   n2 n2.id  ... n5.id           n5.displayName   e6   n6 n6.id  \
# 0      114  110   N46  ...   N69   Assembly and packaging  117  113   N78
# 1      114  110   N46  ...   N69   Assembly and packaging  117  113   N78
# 2      114  110   N46  ...   N69   Assembly and packaging  117  113   N78
# 3      114  110   N46  ...   N69   Assembly and packaging  117  113   N78
# 4      114  110   N46  ...   N69   Assembly and packaging  117  113   N78
# ...    ...  ...   ...  ...   ...                      ...  ...  ...   ...
# 88429  104   92  N126  ...   N32  Resist processing tools   66  108   N25
# 88430  104   92  N126  ...   N32  Resist processing tools   66  108   N25
# 88431  104   92  N126  ...   N32  Resist processing tools   66  108   N25
# 88432  104   92  N126  ...   N32  Resist processing tools   66  108   N25
# 88433  104   92  N126  ...   N32  Resist processing tools   66  108   N25
#
#          n6.displayName   e7   n7 n7.id                n7.displayName
# 0               Testing  123  118   N99           Finished logic chip
# 1               Testing   14   14  N120                    Test tools
# 2               Testing   11   11   N83          Handlers and probers
# 3               Testing   92   91  N121                 ATP materials
# 4               Testing  117  111   N69        Assembly and packaging
# ...                 ...  ...  ...   ...                           ...
# 88429  Photolithography   91   90   N31                  Photoresists
# 88430  Photolithography  118  112  N118  Process control and handling
# 88431  Photolithography   72   72   N19             Lithography tools
# 88432  Photolithography  131  117  N117         Fabrication materials
# 88433  Photolithography   66   66   N32       Resist processing tools
#
# [88434 rows x 31 columns]
# ****************************************************************************************************
# Process: EDA and Core IP
#   0%|          | 0/7 [00:00<?, ?it/s]
# Longest path found: 7 hops
#       first first.id first.displayName   e1   n1 n1.id  \
# 0       115       N7   EDA and Core IP  125  116    N0
# 1       115       N7   EDA and Core IP  125  116    N0
# 2       115       N7   EDA and Core IP  125  116    N0
# 3       115       N7   EDA and Core IP  125  116    N0
# 4       115       N7   EDA and Core IP  125  116    N0
# ...     ...      ...               ...  ...  ...   ...
# 5592    115       N7   EDA and Core IP  100   96   N85
# 5593    115       N7   EDA and Core IP  100   96   N85
# 5594    115       N7   EDA and Core IP  100   96   N85
# 5595    115       N7   EDA and Core IP  100   96   N85
# 5596    115       N7   EDA and Core IP  100   96   N85
#
#                   n1.displayName   e2   n2 n2.id  ... n5.id  \
# 0                    Chip design  126  114   N35  ...   N16
# 1                    Chip design  126  114   N35  ...   N16
# 2                    Chip design  126  114   N35  ...   N16
# 3                    Chip design  126  114   N35  ...   N16
# 4                    Chip design  126  114   N35  ...   N16
# ...                          ...  ...  ...   ...  ...   ...
# 5592  Core intellectual property  100  115    N7  ...   N84
# 5593  Core intellectual property  100  115    N7  ...   N84
# 5594  Core intellectual property  100  115    N7  ...   N85
# 5595  Core intellectual property  100  115    N7  ...   N85
# 5596  Core intellectual property  100  115    N7  ...   N85
#
#                              n5.displayName   e6   n6 n6.id  \
# 0                          Ion implantation  113  109   N57
# 1                          Ion implantation  113  109   N57
# 2                          Ion implantation  113  109   N57
# 3                          Ion implantation  113  109   N57
# 4                          Ion implantation  113  109   N57
# ...                                     ...  ...  ...   ...
# 5592  Electronic design automation software   10  115    N7
# 5593  Electronic design automation software   10  115    N7
# 5594             Core intellectual property  100  115    N7
# 5595             Core intellectual property  100  115    N7
# 5596             Core intellectual property  100  115    N7
#
#                          n6.displayName   e7   n7 n7.id  \
# 0     Chemical mechanical planarization  115  111   N69
# 1     Chemical mechanical planarization  122  112  N118
# 2     Chemical mechanical planarization  113  107   N16
# 3     Chemical mechanical planarization  102   97   N90
# 4     Chemical mechanical planarization  129  117  N117
# ...                                 ...  ...  ...   ...
# 5592                    EDA and Core IP   10   10   N84
# 5593                    EDA and Core IP  100   96   N85
# 5594                    EDA and Core IP  125  116    N0
# 5595                    EDA and Core IP   10   10   N84
# 5596                    EDA and Core IP  100   96   N85
#
#                              n7.displayName
# 0                    Assembly and packaging
# 1              Process control and handling
# 2                          Ion implantation
# 3                             CMP materials
# 4                     Fabrication materials
# ...                                     ...
# 5592  Electronic design automation software
# 5593             Core intellectual property
# 5594                            Chip design
# 5595  Electronic design automation software
# 5596             Core intellectual property
#
# [5597 rows x 31 columns]
# ****************************************************************************************************
# Process: Chip design
#   0%|          | 0/7 [00:00<?, ?it/s]
# Longest path found: 7 hops
#        first first.id first.displayName   e1   n1 n1.id     n1.displayName  \
# 0        116       N0       Chip design  126  114   N35         Deposition
# 1        116       N0       Chip design  126  114   N35         Deposition
# 2        116       N0       Chip design  126  114   N35         Deposition
# 3        116       N0       Chip design  126  114   N35         Deposition
# 4        116       N0       Chip design  126  114   N35         Deposition
# ...      ...      ...               ...  ...  ...   ...                ...
# 24384    116       N0       Chip design  137  124    N6  Logic chip design
# 24385    116       N0       Chip design  137  124    N6  Logic chip design
# 24386    116       N0       Chip design  137  124    N6  Logic chip design
# 24387    116       N0       Chip design  137  124    N6  Logic chip design
# 24388    116       N0       Chip design  137  124    N6  Logic chip design
#
#         e2   n2 n2.id  ... n5.id                     n5.displayName   e6   n6  \
# 0      124  108   N25  ...   N57  Chemical mechanical planarization  115  111
# 1      124  108   N25  ...   N57  Chemical mechanical planarization  115  111
# 2      124  108   N25  ...   N57  Chemical mechanical planarization  115  111
# 3      124  108   N25  ...   N57  Chemical mechanical planarization  115  111
# 4      124  108   N25  ...   N57  Chemical mechanical planarization  115  111
# ...    ...  ...   ...  ...   ...                                ...  ...  ...
# 24384  138  125    N1  ...    N6                  Logic chip design  137  116
# 24385  138  125    N1  ...    N6                  Logic chip design  134  121
# 24386  138  125    N1  ...    N6                  Logic chip design  135  122
# 24387  138  125    N1  ...    N6                  Logic chip design  136  123
# 24388  138  125    N1  ...    N6                  Logic chip design  138  125
#
#       n6.id          n6.displayName   e7   n7 n7.id  \
# 0       N69  Assembly and packaging  117  113   N78
# 1       N69  Assembly and packaging  115  109   N57
# 2       N69  Assembly and packaging   23   23  N119
# 3       N69  Assembly and packaging   17   17   N76
# 4       N69  Assembly and packaging   81   81  N109
# ...     ...                     ...  ...  ...   ...
# 24384    N0             Chip design  137  124    N6
# 24385    N4                AI ASICs  134  124    N6
# 24386    N3                   FPGAs  135  124    N6
# 24387    N2           Discrete GPUs  136  124    N6
# 24388    N1           Advanced CPUs  138  124    N6
#
#                                    n7.displayName
# 0                                         Testing
# 1               Chemical mechanical planarization
# 2                                  Assembly tools
# 3                                 Packaging tools
# 4      Fabrication tools (for advanced packaging)
# ...                                           ...
# 24384                           Logic chip design
# 24385                           Logic chip design
# 24386                           Logic chip design
# 24387                           Logic chip design
# 24388                           Logic chip design
#
# [24389 rows x 31 columns]
# ****************************************************************************************************
# Process: Fabrication materials
#   0%|          | 0/7 [00:00<?, ?it/s]
# Longest path found: 7 hops
#         first first.id      first.displayName   e1   n1 n1.id n1.displayName  \
# 0         117     N117  Fabrication materials  127  114   N35     Deposition
# 1         117     N117  Fabrication materials  127  114   N35     Deposition
# 2         117     N117  Fabrication materials  127  114   N35     Deposition
# 3         117     N117  Fabrication materials  127  114   N35     Deposition
# 4         117     N117  Fabrication materials  127  114   N35     Deposition
# ...       ...      ...                    ...  ...  ...   ...            ...
# 126569    117     N117  Fabrication materials  109  103   N26          Wafer
# 126570    117     N117  Fabrication materials  109  103   N26          Wafer
# 126571    117     N117  Fabrication materials  109  103   N26          Wafer
# 126572    117     N117  Fabrication materials  109  103   N26          Wafer
# 126573    117     N117  Fabrication materials  109  103   N26          Wafer
#
#          e2   n2 n2.id  ... n5.id                     n5.displayName   e6  \
# 0       124  108   N25  ...   N57  Chemical mechanical planarization  115
# 1       124  108   N25  ...   N57  Chemical mechanical planarization  115
# 2       124  108   N25  ...   N57  Chemical mechanical planarization  115
# 3       124  108   N25  ...   N57  Chemical mechanical planarization  115
# 4       124  108   N25  ...   N57  Chemical mechanical planarization  115
# ...     ...  ...   ...  ...   ...                                ...  ...
# 126569   74   74    N9  ...   N26                              Wafer  109
# 126570   74   74    N9  ...   N26                              Wafer  109
# 126571   74   74    N9  ...   N26                              Wafer  109
# 126572   74   74    N9  ...   N26                              Wafer   75
# 126573   74   74    N9  ...   N26                              Wafer   74
#
#          n6 n6.id            n6.displayName   e7   n7 n7.id  \
# 0       111   N69    Assembly and packaging  117  113   N78
# 1       111   N69    Assembly and packaging  115  109   N57
# 2       111   N69    Assembly and packaging   23   23  N119
# 3       111   N69    Assembly and packaging   17   17   N76
# 4       111   N69    Assembly and packaging   81   81  N109
# ...     ...   ...                       ...  ...  ...   ...
# 126569  117  N117     Fabrication materials   95   93   N91
# 126570  117  N117     Fabrication materials   94   92  N126
# 126571  117  N117     Fabrication materials  109  103   N26
# 126572   75    N8  Crystal growing furnaces   75  103   N26
# 126573   74    N9   Crystal machining tools   74  103   N26
#
#                                     n7.displayName
# 0                                          Testing
# 1                Chemical mechanical planarization
# 2                                   Assembly tools
# 3                                  Packaging tools
# 4       Fabrication tools (for advanced packaging)
# ...                                            ...
# 126569                            Electronic gases
# 126570      Process-specific fabrication materials
# 126571                                       Wafer
# 126572                                       Wafer
# 126573                                       Wafer
#
# [126574 rows x 31 columns]
# ****************************************************************************************************
# CPU times: user 7.65 s, sys: 1.44 s, total: 9.09 s
# Wall time: 9.94 s

# %% [markdown]
# # Create subgraph to visualise

# %%
# Get subgraph
list_subset_nodes = []
for longest_df in list_longest_df:
    subset_nodes = longest_df.filter(regex="id$", axis=1).iloc[0].values.tolist()
    list_subset_nodes.extend(subset_nodes)

subG = G.subgraph(list_subset_nodes).copy()
print(subG)

# Build CREATE command from subgraph
create_command_subG = build_create_command_from_networkx(subG)
print(f"""
Cypher CREATE command :
* size: {len(create_command_subG.encode('utf-8'))/1024/1000:.4f} MB\n
{100 * '*'}
{create_command_subG \
if len(create_command_subG.split("\n")) < 10000 \
else "\n".join(create_command_subG.split('\n')[:5]) + "\n...\n" + "\n".join(create_command_subG.split('\n')[-5:])}
{100 * '*'}
""")
# Out:
# DiGraph with 12 nodes and 19 edges
# Cypher query will create graph with 12 nodes and 19 edges
#
# Cypher CREATE command :
# * size: 0.0250 MB
#
# ****************************************************************************************************
# CREATE (:Process {id: "N117", displayName: "Fabrication materials", input_name: "Fabrication materials", type: "process", description: "Fabrication materials are a critical input in the fabrication of chips. Fabrication materials include high-purity silicon wafers, chemicals, and gases.", stage_name: "Fabrication", stage_id: "S2", stage_description: "Fabrication turns designs into chips. Semiconductor fabrication facilities ( fabs ) make chips in these wafers in two steps: forming transistors and other electrical devices in material layers within silicon wafers; and forming metal interconnects between the electrical devices in insulating layers above the silicon. There are two business models for fabs: (1) fabs owned by integrated device manufacturers ( IDMs ), which manufacture chips based on their own designs; and (2) foundries, i.e., fabs operating independently and manufacturing chips for third-party customers. Firms headquartered in the United States, Taiwan, South Korea, Japan, and China control the vast majority of the world s fab market share. In 2022, fab capacity was concentrated in China, Taiwan, South Korea, and Japan (highest to lowest). Advanced logic fab capacity (<10nm) was located solely in Taiwan and South Korea controlled by TSMC and Samsung, respectively. As of 2024, two firms are newly capable of fabricating advanced logic: Intel (headquartered in the United States) and SMIC (headquartered in China). Advanced logic capacity is expected to diversify by 2032, with fabs located in the United States, Japan, Europe, and China.", year: 2022.0, market_share_chart_caption: "Chart shows share of global fabrication capacity (for logic, memory, and DAO devices) by site location.", market_share_chart_global_market_size_info: "$40 billion (2022)", market_share_chart_source: "[Semiconductor Industry Association (SIA)](https://perma.cc/GT6R-SWEM).", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:Process {id: "N16", displayName: "Ion implantation", input_name: "Ion implantation", type: "process", description: "Ion implanters embed dopant substances into silicon wafers to give different parts of the wafer different levels of semiconductivity to make functional transistors in chips. Different types of implanters are used for different purposes. Low-to-medium-current ion implanters and high-current ion implanters are most commonly used, with high-current ion implanters capable of greater throughput. Meanwhile, high-voltage ion implanters can implant ions deeply into silicon, and ultra-high-dose doping implanters can achieve greater dopant density than the other tools. The United States is the dominant producer of ion implanters, with Japan and Taiwan rounding out most of global market share.", stage_name: "Fabrication", stage_id: "S2", stage_description: "Fabrication turns designs into chips. Semiconductor fabrication facilities ( fabs ) make chips in these wafers in two steps: forming transistors and other electrical devices in material layers within silicon wafers; and forming metal interconnects between the electrical devices in insulating layers above the silicon. There are two business models for fabs: (1) fabs owned by integrated device manufacturers ( IDMs ), which manufacture chips based on their own designs; and (2) foundries, i.e., fabs operating independently and manufacturing chips for third-party customers. Firms headquartered in the United States, Taiwan, South Korea, Japan, and China control the vast majority of the world s fab market share. In 2022, fab capacity was concentrated in China, Taiwan, South Korea, and Japan (highest to lowest). Advanced logic fab capacity (<10nm) was located solely in Taiwan and South Korea controlled by TSMC and Samsung, respectively. As of 2024, two firms are newly capable of fabricating advanced logic: Intel (headquartered in the United States) and SMIC (headquartered in China). Advanced logic capacity is expected to diversify by 2032, with fabs located in the United States, Japan, Europe, and China.", market_share_chart_caption: "Chart shows share of global fabrication capacity (for logic, memory, and DAO devices) by site location.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:Process {id: "N7", displayName: "EDA and Core IP", input_name: "EDA and Core IP", type: "process", description: "Electronic design automation (EDA) software: Until the 1970s, when chips included few electric components, engineers drew designs manually. Today, chips include billions of interconnected transistors and other electrical components. To manage this complexity, chip designers use sophisticated electronic design automation (EDA) software to produce chip designs.nnCore intellectual property: Core IP consists of reusable, modular design blocks that chip design firms license for use in their designs. U.S. and U.K. vendors dominate the core IP market; some firms specialize exclusively on core IP, while others combine their offerings with EDA tools. The company ARM is the top core IP vendor, providing an instruction set architecture (ISA) and associated core IP underpinning most of the world s smartphone processors.", stage_name: "Design", stage_id: "S1", stage_description: "Semiconductor design involves specification, design, physical design, and validation and verification. Specification determines how the chip should operate in the system using it. Design creates a schematic model of interconnected electrical components. Physical design translates this model to a physical layout of electrical components and interconnects, the wires that connect components. Validation and verification ensure chips based on the design will operate as expected. Semiconductor design can be subdivided into three broad categories: logic, memory, and DAO (discrete, analog, and other).", year: 2019.0, market_share_chart_caption: "Chart shows market shares for the overall global semiconductor design market by country.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:Process {id: "N69", displayName: "Assembly and packaging", input_name: "Assembly and packaging", type: "process", description: "At the end of the fabrication process, the finished wafer contains dozens of chips in a grid pattern. During assembly and packaging, the wafer is separated into individual chips, or dies . Each chip is mounted on a frame with wires that connect the chip to external devices, and enclosed in a protective casing. This produces the familiar look of a dark gray rectangle with metal pins at the edges.", stage_name: "Assembly, testing, and packaging (ATP)", stage_id: "S3", stage_description: "At the end of the fabrication process, the finished wafer contains dozens of chips in a grid pattern. During assembly, testing, and packaging, the wafer is separated into individual chips, or dies. Each chip is mounted on a frame with wires that connect the chip to external devices, and enclosed in a protective casing. This produces the familiar look of a dark gray rectangle with metal pins at the edges. The chip is also tested to ensure it operates as intended. Although ATP was historically low value, as transistor densities in logic chips have increased exponentially, packaging has increasingly become a bottleneck on chip performance. ATP occurs under two business models: (1) as in-house ATP services performed by integrated device manufacturers (IDMs) and foundries after fabrication; and (2) by outsourced semiconductor assembly and test (OSAT) firms, which perform ATP for third-party customers. Facilities located in China, Taiwan, South Korea, and Japan have the largest site capacity to provide ATP services.", market_share_chart_caption: "Chart shows ATP site capacity by country.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:Process {id: "N35", displayName: "Deposition", input_name: "Deposition", type: "process", description: "In the deposition process, specialized tools are used to deposit thin films of materials on a silicon wafer. After lithography and etching, these films become different chip layers, including for transistors, interconnects (wires), and other elements.", stage_name: "Fabrication", stage_id: "S2", stage_description: "Fabrication turns designs into chips. Semiconductor fabrication facilities ( fabs ) make chips in these wafers in two steps: forming transistors and other electrical devices in material layers within silicon wafers; and forming metal interconnects between the electrical devices in insulating layers above the silicon. There are two business models for fabs: (1) fabs owned by integrated device manufacturers ( IDMs ), which manufacture chips based on their own designs; and (2) foundries, i.e., fabs operating independently and manufacturing chips for third-party customers. Firms headquartered in the United States, Taiwan, South Korea, Japan, and China control the vast majority of the world s fab market share. In 2022, fab capacity was concentrated in China, Taiwan, South Korea, and Japan (highest to lowest). Advanced logic fab capacity (<10nm) was located solely in Taiwan and South Korea controlled by TSMC and Samsung, respectively. As of 2024, two firms are newly capable of fabricating advanced logic: Intel (headquartered in the United States) and SMIC (headquartered in China). Advanced logic capacity is expected to diversify by 2032, with fabs located in the United States, Japan, Europe, and China.", market_share_chart_caption: "Chart shows share of global fabrication capacity (for logic, memory, and DAO devices) by site location.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:Process {id: "N0", displayName: "Chip design", input_name: "Chip design", type: "process", description: "Chip design involves specification, logic design, physical design, and validation and verification. Specification determines how the chip should operate in the system using it. Logic design creates a schematic model of interconnected electrical components. Physical design translates this model to a physical layout of electrical components and interconnects, the wires that connect components. Validation and verification ensure chips based on the design will operate as expected.", stage_name: "Design", stage_id: "S1", stage_description: "Semiconductor design involves specification, design, physical design, and validation and verification. Specification determines how the chip should operate in the system using it. Design creates a schematic model of interconnected electrical components. Physical design translates this model to a physical layout of electrical components and interconnects, the wires that connect components. Validation and verification ensure chips based on the design will operate as expected. Semiconductor design can be subdivided into three broad categories: logic, memory, and DAO (discrete, analog, and other).", year: 2022.0, market_share_chart_caption: "Chart shows market shares for the overall global semiconductor design market by country.", market_share_chart_global_market_size_info: "$574.1 billion (2022)", market_share_chart_source: "Worldwide semiconductor sales. [World Semiconductor Trade Statistics (WSTS)](https://perma.cc/Y773-9T3A) and [Semiconductor Industry Association (SIA)](https://perma.cc/MPN9-W8YS).", provider_name: "CHN", provider_id: "P2", provider_alias: "China", provider_type: "country", provider_country: "nan", share_provided: 5.0, year_share_provided: 2022.0, source_provider_provided: "Worldwide semiconductor sales. [World Semiconductor Trade Statistics (WSTS)](https://perma.cc/Y773-9T3A) and [Semiconductor Industry Association (SIA)](https://perma.cc/MPN9-W8YS)."}),
# (:Process {id: "N78", displayName: "Testing", input_name: "Testing", type: "process", description: "Chips undergo tests requiring a range of specialized equipment, including system-on-a-chip test tools, linear and discrete devices, burn-in tools, and handlers and probers.", stage_name: "Assembly, testing, and packaging (ATP)", stage_id: "S3", stage_description: "At the end of the fabrication process, the finished wafer contains dozens of chips in a grid pattern. During assembly, testing, and packaging, the wafer is separated into individual chips, or dies. Each chip is mounted on a frame with wires that connect the chip to external devices, and enclosed in a protective casing. This produces the familiar look of a dark gray rectangle with metal pins at the edges. The chip is also tested to ensure it operates as intended. Although ATP was historically low value, as transistor densities in logic chips have increased exponentially, packaging has increasingly become a bottleneck on chip performance. ATP occurs under two business models: (1) as in-house ATP services performed by integrated device manufacturers (IDMs) and foundries after fabrication; and (2) by outsourced semiconductor assembly and test (OSAT) firms, which perform ATP for third-party customers. Facilities located in China, Taiwan, South Korea, and Japan have the largest site capacity to provide ATP services.", market_share_chart_caption: "Chart shows ATP site capacity by country.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:UltimateOutput {id: "N99", displayName: "Finished logic chip", input_name: "Finished logic chip", type: "ultimate_output", description: "The production of a single logic chip often requires more than 1,000 steps, passing through international borders 70 or more times, before reaching an end customer. The result of this complex, $500 billion supply chain is a resource fundamental to virtually every aspect of modern life.", stage_name: "", stage_id: "", stage_description: "nan", market_share_chart_caption: "nan", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:Process {id: "N25", displayName: "Photolithography", input_name: "Photolithography", type: "process", description: "In photolithography, light is used to draw patterns into semiconductor wafers, creating the tiny circuits that comprise logic chips. A photolithography tool passes light through a photomask-a transparent plate with a circuit pattern-to transfer that pattern to a wafer coated with photoresist chemical. (Photomasks are themselves made with lithography tools.) The light dissolves parts of the photoresist according to the circuit pattern.nnAdvanced photolithography is critical to mass production of cutting-edge semiconductors. It requires enormously complex, expensive equipment supplied by only a few vendors in Europe and Japan. The most sophisticated photolithography processes involve extreme ultraviolet (EUV) scanners, produced exclusively by the Dutch firm ASML.", stage_name: "Fabrication", stage_id: "S2", stage_description: "Fabrication turns designs into chips. Semiconductor fabrication facilities ( fabs ) make chips in these wafers in two steps: forming transistors and other electrical devices in material layers within silicon wafers; and forming metal interconnects between the electrical devices in insulating layers above the silicon. There are two business models for fabs: (1) fabs owned by integrated device manufacturers ( IDMs ), which manufacture chips based on their own designs; and (2) foundries, i.e., fabs operating independently and manufacturing chips for third-party customers. Firms headquartered in the United States, Taiwan, South Korea, Japan, and China control the vast majority of the world s fab market share. In 2022, fab capacity was concentrated in China, Taiwan, South Korea, and Japan (highest to lowest). Advanced logic fab capacity (<10nm) was located solely in Taiwan and South Korea controlled by TSMC and Samsung, respectively. As of 2024, two firms are newly capable of fabricating advanced logic: Intel (headquartered in the United States) and SMIC (headquartered in China). Advanced logic capacity is expected to diversify by 2032, with fabs located in the United States, Japan, Europe, and China.", market_share_chart_caption: "Chart shows share of global fabrication capacity (for logic, memory, and DAO devices) by site location.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:Process {id: "N57", displayName: "Chemical mechanical planarization", input_name: "Chemical mechanical planarization", type: "process", description: "After etching and cleaning, the wafer surface is flattened in a process called chemical mechanical planarization (CMP) to allow a new layer of features to be added. CMP tools are critical for chip fabrication, but not as complex as other tools, such as lithography and deposition tools.", stage_name: "Fabrication", stage_id: "S2", stage_description: "Fabrication turns designs into chips. Semiconductor fabrication facilities ( fabs ) make chips in these wafers in two steps: forming transistors and other electrical devices in material layers within silicon wafers; and forming metal interconnects between the electrical devices in insulating layers above the silicon. There are two business models for fabs: (1) fabs owned by integrated device manufacturers ( IDMs ), which manufacture chips based on their own designs; and (2) foundries, i.e., fabs operating independently and manufacturing chips for third-party customers. Firms headquartered in the United States, Taiwan, South Korea, Japan, and China control the vast majority of the world s fab market share. In 2022, fab capacity was concentrated in China, Taiwan, South Korea, and Japan (highest to lowest). Advanced logic fab capacity (<10nm) was located solely in Taiwan and South Korea controlled by TSMC and Samsung, respectively. As of 2024, two firms are newly capable of fabricating advanced logic: Intel (headquartered in the United States) and SMIC (headquartered in China). Advanced logic capacity is expected to diversify by 2032, with fabs located in the United States, Japan, Europe, and China.", market_share_chart_caption: "Chart shows share of global fabrication capacity (for logic, memory, and DAO devices) by site location.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:Process {id: "N46", displayName: "Etch and clean", input_name: "Etch and clean", type: "process", description: "After photolithography creates a pattern in the photoresist coating a wafer, specialized tools etch the pattern into the permanent layer below the photoresist. The photoresist is then removed and the etched material cleaned off of the layer.nnThe United States and Japan are the main producers of etch and clean equipment; South Korea and China are also significant suppliers.", stage_name: "Fabrication", stage_id: "S2", stage_description: "Fabrication turns designs into chips. Semiconductor fabrication facilities ( fabs ) make chips in these wafers in two steps: forming transistors and other electrical devices in material layers within silicon wafers; and forming metal interconnects between the electrical devices in insulating layers above the silicon. There are two business models for fabs: (1) fabs owned by integrated device manufacturers ( IDMs ), which manufacture chips based on their own designs; and (2) foundries, i.e., fabs operating independently and manufacturing chips for third-party customers. Firms headquartered in the United States, Taiwan, South Korea, Japan, and China control the vast majority of the world s fab market share. In 2022, fab capacity was concentrated in China, Taiwan, South Korea, and Japan (highest to lowest). Advanced logic fab capacity (<10nm) was located solely in Taiwan and South Korea controlled by TSMC and Samsung, respectively. As of 2024, two firms are newly capable of fabricating advanced logic: Intel (headquartered in the United States) and SMIC (headquartered in China). Advanced logic capacity is expected to diversify by 2032, with fabs located in the United States, Japan, Europe, and China.", market_share_chart_caption: "Chart shows share of global fabrication capacity (for logic, memory, and DAO devices) by site location.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"}),
# (:Process {id: "N118", displayName: "Process control and handling", input_name: "Process control and handling", type: "process", description: "Process control: In semiconductor fabrication, process control involves precisely monitoring wafers, photomasks, and the overall chip manufacturing process to ensure consistency and low manufacturing error rates. Accordingly, process control tools are among the most essential and valuable semiconductor manufacturing equipment.nnHandling: Storing and transporting wafers and photomasks in a fab requires specific equipment. Although specialized, this equipment is less complex than other tools used in semiconductor manufacturing.", stage_name: "Fabrication", stage_id: "S2", stage_description: "Fabrication turns designs into chips. Semiconductor fabrication facilities ( fabs ) make chips in these wafers in two steps: forming transistors and other electrical devices in material layers within silicon wafers; and forming metal interconnects between the electrical devices in insulating layers above the silicon. There are two business models for fabs: (1) fabs owned by integrated device manufacturers ( IDMs ), which manufacture chips based on their own designs; and (2) foundries, i.e., fabs operating independently and manufacturing chips for third-party customers. Firms headquartered in the United States, Taiwan, South Korea, Japan, and China control the vast majority of the world s fab market share. In 2022, fab capacity was concentrated in China, Taiwan, South Korea, and Japan (highest to lowest). Advanced logic fab capacity (<10nm) was located solely in Taiwan and South Korea controlled by TSMC and Samsung, respectively. As of 2024, two firms are newly capable of fabricating advanced logic: Intel (headquartered in the United States) and SMIC (headquartered in China). Advanced logic capacity is expected to diversify by 2032, with fabs located in the United States, Japan, Europe, and China.", market_share_chart_caption: "Chart shows share of global fabrication capacity (for logic, memory, and DAO devices) by site location.", market_share_chart_global_market_size_info: "", market_share_chart_source: "", provider_name: "nan", provider_id: "nan", provider_alias: "nan", provider_type: "nan", provider_country: "nan", source_provider_provided: "nan"})
# MATCH (source {id: "N117"}), (target {id: "N25"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N117"}), (target {id: "N46"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N117"}), (target {id: "N57"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N117"}), (target {id: "N16"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N117"}), (target {id: "N35"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N16"}), (target {id: "N57"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N7"}), (target {id: "N0"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N69"}), (target {id: "N78"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N35"}), (target {id: "N25"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N0"}), (target {id: "N35"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N78"}), (target {id: "N99"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N25"}), (target {id: "N46"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N57"}), (target {id: "N69"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N46"}), (target {id: "N16"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N118"}), (target {id: "N25"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N118"}), (target {id: "N46"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N118"}), (target {id: "N57"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N118"}), (target {id: "N16"}) CREATE (source)-[:GOES_INTO]->(target)
# MATCH (source {id: "N118"}), (target {id: "N35"}) CREATE (source)-[:GOES_INTO]->(target)
# ****************************************************************************************************

# %%
subgraph_name = f"{graph_name}_subgraph"
subgraph_name
# Out:
# 'supply_chain_eto_chip_explorer1_subgraph'

# %%
# %%time

# Set graph
try:
    client.create_graph(subgraph_name)
except TuringDBException as e:
    print(e)

# Set working graph
client.set_graph(subgraph_name)

# Create a new change on the graph
client.checkout()
change = client.new_change()
print(f"Current change {change}")

# Checkout into the change
client.checkout(change=change)
# Out:
# Current change 0
# CPU times: user 4.83 ms, sys: 671 μs, total: 5.5 ms
# Wall time: 11.9 ms

# %%
# %%time

chunks = split_cypher_commands(create_command_subG, max_size_mb=1)

print(f"✓ Split into {len(chunks['node_chunks'])} node chunk(s) and {len(chunks['edge_chunks'])} edge chunk(s)")

print("\nNode chunks:")
for i, chunk in enumerate(chunks['node_chunks']):
    print(f"  Node chunk {i+1}: {len(chunk.encode('utf-8'))/1024:.1f} KB")
    if i == 10:
        print("  ...")
        break

print("\nEdge chunks:")
for i, chunk in enumerate(chunks['edge_chunks']):
    print(f"  Edge chunk {i+1}: {len(chunk.encode('utf-8'))/1024:.1f} KB")
    if i == 10:
        print("  ...")
        break
# Out:
# ✓ Split into 1 node chunk(s) and 19 edge chunk(s)
#
# Node chunks:
#   Node chunk 1: 23.4 KB
#
# Edge chunks:
#   Edge chunk 1: 0.1 KB
#   Edge chunk 2: 0.1 KB
#   Edge chunk 3: 0.1 KB
#   Edge chunk 4: 0.1 KB
#   Edge chunk 5: 0.1 KB
#   Edge chunk 6: 0.1 KB
#   Edge chunk 7: 0.1 KB
#   Edge chunk 8: 0.1 KB
#   Edge chunk 9: 0.1 KB
#   Edge chunk 10: 0.1 KB
#   Edge chunk 11: 0.1 KB
#   ...
# CPU times: user 4.27 ms, sys: 0 ns, total: 4.27 ms
# Wall time: 4.17 ms

# %%
# %%time

# Run CREATE command
print("\nExecuting query on TuringDB...")
start_time = time.time()

print(f"✓ Split into {len(chunks['node_chunks'])} node chunk(s) and {len(chunks['edge_chunks'])} edge chunk(s)")

# CREATE nodes
print("\nNode chunks:")
for i, chunk in enumerate(tqdm(chunks['node_chunks'])):
    result = client.query(chunk)
# Commit the change
client.query("COMMIT")
print(f"✓ {len(chunks['node_chunks'])} node chunks done")

# CREATE edges
print("\nEdge chunks:")
for i, chunk in enumerate(tqdm(chunks['edge_chunks'])):
    result = client.query(chunk)
# Commit the change
client.query("COMMIT")
print(f"✓ {len(chunks['edge_chunks'])} edge chunks done")

execution_time = time.time() - start_time
print(f"\n✓ Graph created successfully in {execution_time:.2f} seconds")

# Submit changes
start_time = time.time()
client.query("CHANGE SUBMIT")
execution_time = time.time() - start_time
print(f"\n✓ Changes successfully submitted in {execution_time:.2f} seconds")

# Checkout into main
client.checkout()
# Out:
# Executing query on TuringDB...
# ✓ Split into 1 node chunk(s) and 19 edge chunk(s)
#
# Node chunks:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✓ 1 node chunks done
#
# Edge chunks:
#   0%|          | 0/19 [00:00<?, ?it/s]
# ✓ 19 edge chunks done
#
# ✓ Graph created successfully in 0.15 seconds
#
# ✓ Changes successfully submitted in 0.08 seconds
# CPU times: user 58.9 ms, sys: 4.29 ms, total: 63.2 ms
# Wall time: 234 ms

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         You can visualise the subgraph directly in the notebook below. For more details on nodes and edges, you can go to TuringDB visualizer (running on your instance)
#     </h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         Visualize your graph in TuringDB Graph Visualizer ! Now that your instance is running:
#     </h2>
#     <h3>
#         <ul>
#             <li>Go to <a href="https://console.turingdb.ai/databases">TuringDB Console - Database Instances</a></li>
#             <li>In your current instance panel, click on "Open Visualizer" button</li>
#             <li>Visualizer opens, now you can choose your graph in the dropdown menu at the top-right corner</li>
#         </ul>
#         You can then play with your graph and visualize the nodes you want !
#     </h3>
# </div>

# %%
from pyvis.network import Network

net = Network(
    height="750px",
    width="100%",
    notebook=True,
    bgcolor="#f8f9fa",
    font_color="#212529",
    directed=True,
)

# Node type colors
type_colors = {
    "tool_resource": "#3498db",  # Blue for tools
    "material_resource": "#e74c3c",  # Red for materials
    "process": "#2ecc71",  # Green for processes
    "design_resource": "#9b59b6",  # Purple for design
    "ultimate_output": "#f39c12",  # Orange for output
}

for node, data in subG.nodes(data=True):
    node_type = data.get("type", "Unknown")
    color = type_colors.get(node_type, "#7f8c8d")

    label = data.get("displayName", str(node))

    # Build title with key information
    title_parts = [f"<b>{label}</b>", f"Type: {node_type}"]

    if data.get("provider_name"):
        title_parts.append(f"Provider: {data.get('provider_name')}")
    if data.get("share_provided"):
        title_parts.append(f"Market Share: {data.get('share_provided')}%")
    if data.get("stage_name") and data.get("stage_name") != "nan":
        title_parts.append(f"Stage: {data.get('stage_name')}")

    title = "<br>".join(title_parts)

    net.add_node(node, label=label, color=color, title=title, size=25)

# Edge type colors
edge_colors = {"GOES_INTO": "#27ae60", "IS_TYPE_OF": "#e67e22"}

for source, target, data in subG.edges(data=True):
    edge_type = list(data.keys())[0] if data else "CONNECTED"
    color = edge_colors.get(edge_type, "#95a5a6")
    net.add_edge(source, target, title=edge_type, color=color, width=2)

net.toggle_physics(True)
net.show(f"{example_name}_subgraph.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# supply_chain_eto-chip-explorer_subgraph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="supply_chain_eto-chip-explorer_subgraph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Use LLM to generate Cypher query

# %% [markdown]
# Before running this section, create a `.env` file in the project root with your API keys:
#
# ```env
# ANTHROPIC_API_KEY=your_key_here
# OPENAI_API_KEY=your_key_here
# MISTRAL_API_KEY=your_key_here

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv(override=True)
# Out:
# True

# %%
api_keys = {
    "Anthropic": os.getenv("ANTHROPIC_API_KEY"),
    "Mistral": os.getenv("MISTRAL_API_KEY"),
    "OpenAI": os.getenv("OPENAI_API_KEY"),
}

# %%
"""Build system prompt with TuringDB schema and examples"""

turingdb_cypher_system_prompt = """
You are an expert at converting natural language questions into TuringDB queries.

Your task is to generate syntactically correct TuringDB queries based on natural language input.

VERY IMPORTANT - YOU MUST FOLLOW THESE REQUESTS - TuringDB Syntax Guidelines:
1. Return ONLY the TuringDB query, no explanations or markdown formatting
2. Use MATCH, CREATE and WHERE operations only
3. Nodes: (n:Label {property = "value"}) or (n:Label {property: value})
4. Edges: Use DIRECTED syntax with ->
5. Pattern matching: MATCH (n)-[e]->(m)
6. Property matching: Use = operator for exact matching
7. Multiple constraints: (n:Person:Engineer {name = "John", age = 30})
8. Return all matched entities: RETURN n, e, m or use RETURN * for all
9. Filter using WHERE clause: MATCH (n:Person) WHERE n.name = 'John' RETURN n.firstname, n.lastname

VERY IMPORTANT - YOU ARE NOT ALLOWED TO USE THE FOLLOWING - FORBIDDEN in TuringDB:
- Do NOT use AS aliases
- Do NOT use LIMIT, SKIP clauses
- Do NOT use WITH clauses
- Do NOT use CALL (except for metaqueries)
- Do NOT use toLower() or other functions
- Do NOT use wildcard character (*)
- Do NOT use multi-hops pattern for edges: e.g. `-[e:CONNECTED*1..10]->`
- Do NOT use "end" or "s3" variable name

Supported TuringDB Operations:
- MATCH queries: MATCH (n:Label)-[e:Type]->(m) RETURN n, m
- CREATE queries: CREATE (n:Label{property="value"})-[e:Type]->(m:Label)
- Metaqueries: CALL db.propertyTypes(), CALL db.labels(), CALL db.edgeTypes()
- Property types: String ("text" or `text`), Boolean (true/false), Integer (20), Double (20.5)

Examples for few-shot learning:
- Find all persons: MATCH (n:Person) RETURN n
- Find connections: MATCH (n:Person)-[e]->(m:Person) RETURN n, e, m
- Create person: CREATE (n:Person{name="John", age=30})
- Match person with specific name: MATCH (p:Person) WHERE p.name = "John" RETURN p
- Path with 1 hop between Station Paddington and Blackfriars:  MATCH (first:Station{displayName:"Paddington"})-[e1:CONNECTED]->(last:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, last, last.displayName, last.Note
- Path with 2 hops between Station Paddington and Blackfriars: MATCH (first:Station{displayName:"Paddington"})-[e1:CONNECTED]->(s1:Station)-[e2:CONNECTED]->(last:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, last, last.displayName, last.Note
- Path with 8 hops between Station Paddington and Blackfriars: MATCH (first:Station{displayName:"Paddington"})-[e1:CONNECTED]->(s1:Station)-[e2:CONNECTED]->(s2:Station)-[e3:CONNECTED]->(s3:Station)-[e4:CONNECTED]->(s4:Station)-[e5:CONNECTED]->(s5:Station)-[e6:CONNECTED]->(s6:Station)-[e7:CONNECTED]->(s7:Station)-[e8:CONNECTED]->(last:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, s5, s5.displayName, s5.Note, e6.Line, s6, s6.displayName, s6.Note, e7.Line, s7, s7.displayName, s7.Note, e8.Line, last, last.displayName, last.Note
- Find all Chinese providers and what they supply: MATCH (n{provider_country:"CHN"}) RETURN n, n.provider_name, n.displayName, n.share_provided, n.type
- Find all deposition tools and their types: MATCH (specific)-[e:IS_TYPE_OF]->(general:Tool_Resource{displayName:"Deposition tools"}) RETURN specific, specific.displayName, specific.provider_name, e, general, general.displayName
"""

# %%
# Get subset of CREATE command to avoid exceeding context window
create_command_subset = create_command_subG.split("\n")[:5] + create_command_subG.split("\n")[-5:]

# Create system_prompt
system_prompt = f"""
TuringDB Cypher prompt :
{turingdb_cypher_system_prompt}

Here is a subset of the CREATE command used to create the graph, this way you know graph structure.
Only a subset is passed because the whole command is to long :
{create_command_subset}

Here is also the output of "CALL LABELS ()" command, showing the different node types of the graph :
{client.query("CALL db.labels()")}

Here is also the output of "CALL EDGETYPES ()" command, showing the different edge types of the graph :
{client.query("CALL db.edgeTypes()")}

Very important :
- You MUST follow current TuringDB Syntax Guidelines
- You MUST NOT USE what is FORBIDDEN in TuringDB
- By default, RETURN ALL THE MATCHED NODES AND EDGES AND THEIR PROPERTIES in the RETURN section (except contrary demand from user)
- Use the correct node and edge properties name in the MATCH section.
- Use the correct node and edge properties name in the RETURN section.
- Pay attention to which properties come from nodes or edges, to create a functioning query
- Pay attention to lower and uppercases in properties
- If some properties contain spaces, be careful to wrap them

Give me the query FOLLOWING TURINGDB GUIDELINES AND NOT USING WHAT IS FORBIDDEN for this specific question :
"""

# %%
## Find all deposition tools and their types
# command = """
# MATCH (specific)-[e:IS_TYPE_OF]-(general:Tool_Resource{displayName:"Deposition tools"}) RETURN specific, specific.displayName, specific.provider_name, e, general, general.displayName
# """
# client.query(command)

# Set natural language query
question = """
Find all deposition tools and their types
"""

# %%
## Find all Chinese providers and what they supply
# command = """
# MATCH (n{provider_country:"CHN"}) RETURN n, n.provider_name, n.displayName, n.share_provided, n.type
# """
# client.query(command)

# Set natural language query
question = """
Find all Chinese providers and what they supply
"""

# %%
## Find assembly tools and their connections
# command = """
# MATCH (n:Tool_Resource{displayName:"Assembly tools"})-[e]-(m) RETURN n, n.displayName, e, m, m.displayName, m.type
# """
# client.query(command)

# Set natural language query
question = """
Find assembly tools and their connections
"""

# %%
question = """
What are the other providers linked to ASML specifically for lithography tools in the supply chain ?
"""

# %%
# %%time

provider = "Anthropic"

cypher_query = natural_language_to_cypher(
    question=question,
    system_prompt=system_prompt,
    provider=provider,
    api_key=api_keys[provider],
    temperature=0.0,
    #model="claude-3-haiku-20240307",
)
print(f"cypher_query : {cypher_query}")
# Out:
# cypher_query : MATCH (n:Process{displayName:"Lithography"})<-[e:GOES_INTO]-(provider) RETURN provider, provider.provider_name, provider.provider_country, e, n
# CPU times: user 200 ms, sys: 19.8 ms, total: 219 ms
# Wall time: 2.53 s

# %%
# %%time

# Set original graph
client.set_graph(graph_name)

try:
    df_path = client.query(cypher_query)

    if df_path.empty:
        print("--> No result found\n")
    else:
        display(df_path)

except TuringDBException:
    print(f"Query generated by LLM not supported.")
# Out:
# --> No result found
#
# CPU times: user 4.23 ms, sys: 1.1 ms, total: 5.33 ms
# Wall time: 4.86 ms

# %%
print("Notebook finished !")
# Out:
# Notebook finished !
