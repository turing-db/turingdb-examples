# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>
#         Example notebook - London Tube
#     </h1>
#     <p>
#         Link to dataset : <a href="https://drive.google.com/drive/folders/1Tfl7D5Khh1uiQDMy20XngdFggaGyj6Vy?usp=drive_link">Google Drive</a>
#     </p>
# </div>

# %% [markdown]
# # Import modules and functions

# %%
import os
import pandas as pd
import re
from IPython.display import display, Markdown
import numpy as np
import time
from tqdm.auto import tqdm

from turingdb_examples.graph import (
    create_graph_from_df,
    build_create_command_from_networkx,
    split_cypher_commands
)
from turingdb_examples.llm import query_llm, natural_language_to_cypher

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Check data files are available

# %%
example_name = "london_transport_TfL"
path_data = f"{os.getcwd()}/data/{example_name}"
if not os.path.exists(path_data):
    raise ValueError(f"{path_data} does not exists")

list_csv_files = sorted(os.listdir(path_data))
if not all([file in list_csv_files for file in [
    "TfL_london_transport_tube.csv",
    "TfL_london_transport_tube_sightseeing.csv",
    "TfL_london_transport_tube_stations.csv",
]]):  
    raise ValueError(
        f"{filename} csv file is not available in {path_data}"
    )

# %% [markdown]
# # Import and format data

# %% [markdown]
# ## Import dataframe containing linkage between each station

# %%
df_link_stations = pd.read_csv(
    f"{path_data}/TfL_london_transport_tube.csv", decimal=","
)
display(df_link_stations)
df_link_stations = df_link_stations.apply(
    lambda x: x.str.strip() if x.dtype == "object" else x
)

# Remove two unrelevant lines 'Docklands Light Railway' and 'East London'
df_link_stations = df_link_stations[~df_link_stations["Line"].isin(['Docklands Light Railway', 'East London'])]

# Replace all "and" by "&" in all station names 
df_link_stations["From_Station"] = df_link_stations["From_Station"].str.replace(" and ", " & ")
df_link_stations["To_Station"] = df_link_stations["To_Station"].str.replace(" and ", " & ")

# Replace "Bank" by "Bank & Monument" for convenience
df_link_stations["From_Station"] = df_link_stations["From_Station"].str.replace("^Bank$", "Bank & Monument", regex=True)
df_link_stations["To_Station"] = df_link_stations["To_Station"].str.replace("^Bank$", "Bank & Monument", regex=True)

# Remove (B) and (C) from Edgware Road for convenience
df_link_stations["From_Station"] = df_link_stations["From_Station"].str.replace(r" \([B|C]\)", "", regex=True)
df_link_stations["To_Station"] = df_link_stations["To_Station"].str.replace(r" \([B|C]\)", "", regex=True)

# Add spaces in "Heathrow Terminals 123"
df_link_stations["From_Station"] = df_link_stations["From_Station"].str.replace("Heathrow Terminals 123", "Heathrow Terminals 1 2 3", regex=False)
df_link_stations["To_Station"] = df_link_stations["To_Station"].str.replace("Heathrow Terminals 123", "Heathrow Terminals 1 2 3", regex=False)

# Unique stations
unique_stations = list(np.unique(df_link_stations[["From_Station", "To_Station"]].values.flatten()))
print(f"Number of unique stations: {len(unique_stations)}")

df_link_stations
# Out:
#                 Line  Order        From_Station         To_Station   Total  \
# 0           Bakerloo      1  Elephant & Castle       Lambeth North  13.432
# 1           Bakerloo      2       Lambeth North          Waterloo   18.597
# 2           Bakerloo      3           Waterloo          Embankment  46.020
# 3           Bakerloo      4          Embankment     Charing Cross   55.475
# 4           Bakerloo      5      Charing Cross   Piccadilly Circus  63.929
# ..               ...    ...                 ...                ...     ...
# 859         Victoria     13             Pimlico          Vauxhall   94.853
# 860         Victoria     14           Vauxhall           Stockwell  66.561
# 861         Victoria     15           Stockwell           Brixton   41.178
# 862  Waterloo & City      1           Waterloo   Bank and Monument   5.554
# 863  Waterloo & City      1   Bank and Monument          Waterloo    6.348
#
#      PM Peak     Evening        Late
# 0         4.118       1.288  398.000
# 1         5.718       1.916  580.000
# 2        13.746       4.609    1.466
# 3        17.155       5.959    1.940
# 4        20.112       7.712    3.035
# ..          ...         ...      ...
# 859      37.711      24.553   10.574
# 860      27.117      18.342    7.992
# 861      15.972      11.553    5.361
# 862       5.197       1.465  386.000
# 863      18.237       6.517    1.374
#
# [864 rows x 8 columns]
# Number of unique stations: 266
#                 Line  Order       From_Station         To_Station   Total  \
# 0           Bakerloo      1  Elephant & Castle      Lambeth North  13.432
# 1           Bakerloo      2      Lambeth North           Waterloo  18.597
# 2           Bakerloo      3           Waterloo         Embankment  46.020
# 3           Bakerloo      4         Embankment      Charing Cross  55.475
# 4           Bakerloo      5      Charing Cross  Piccadilly Circus  63.929
# ..               ...    ...                ...                ...     ...
# 859         Victoria     13            Pimlico           Vauxhall  94.853
# 860         Victoria     14           Vauxhall          Stockwell  66.561
# 861         Victoria     15          Stockwell            Brixton  41.178
# 862  Waterloo & City      1           Waterloo    Bank & Monument   5.554
# 863  Waterloo & City      1    Bank & Monument           Waterloo   6.348
#
#      PM Peak     Evening        Late
# 0         4.118       1.288  398.000
# 1         5.718       1.916  580.000
# 2        13.746       4.609    1.466
# 3        17.155       5.959    1.940
# 4        20.112       7.712    3.035
# ..          ...         ...      ...
# 859      37.711      24.553   10.574
# 860      27.117      18.342    7.992
# 861      15.972      11.553    5.361
# 862       5.197       1.465  386.000
# 863      18.237       6.517    1.374
#
# [714 rows x 8 columns]

# %% [markdown]
# ## Import dataframe containing station information

# %%
df_stations = pd.read_csv(f"{path_data}/TfL_london_transport_tube_stations.csv")
display(df_stations)
df_stations = df_stations.drop(["Zone_original", "OS X", "OS Y"], axis=1)
df_stations = df_stations.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
df_stations["Station"] = df_stations["Station"].str.replace(" and ", " & ")

# Keep only first occurence of station info (e.g. "Edgware Road" appears twice)
count_stations = df_stations["Station"].value_counts()
duplicated_stations = count_stations[count_stations > 1]
print(f"Duplicated stations:\n{duplicated_stations}\n")
df_stations = df_stations.drop_duplicates("Station", keep="first")

# Replace "Bank" by "Bank & Monument" for convenience
df_stations["Station"] = df_stations["Station"].str.replace("^Bank$", "Bank & Monument", regex=True)
df_stations = df_stations.drop(df_stations[df_stations["Station"] == "Monument"].index, axis=0)

# Add apostrophe in "Earls Court", "Kings Cross St. Pancras", "Queen's Park",
# "Regent's Park", "Shepherd's Bush", "Shepherd's Bush Market", "St. John's Wood", "St. Paul's"
df_stations["Station"] = df_stations["Station"].str.replace("^Earls", "Earl's", regex=True)
df_stations["Station"] = df_stations["Station"].str.replace("^Kings Cross St. Pancras", "King's Cross St. Pancras", regex=True)
df_stations["Station"] = df_stations["Station"].str.replace("^Queens Park", "Queen's Park", regex=True)
df_stations["Station"] = df_stations["Station"].str.replace("^Regents Park", "Regent's Park", regex=True)
df_stations["Station"] = df_stations["Station"].str.replace("^Shepherds Bush", "Shepherd's Bush", regex=True)
df_stations["Station"] = df_stations["Station"].str.replace("^Shepherds Bush Market", "Shepherd's Bush Market", regex=True)
df_stations["Station"] = df_stations["Station"].str.replace("^St. Johns Wood", "St. John's Wood", regex=True)
df_stations["Station"] = df_stations["Station"].str.replace("^St. Pauls", "St. Paul's", regex=True)

# Add info about Kensington (Olympia) station
df_stations.loc[-1] = {
    "Station": "Kensington (Olympia)",
    "Latitude": 51.4979934,
    "Longitude": -0.2099576,
    "Zone": 2,
    "Postcode": "W14 0NE"
}

# Keep only stations present in linkage dataframe above
all_stations = df_stations["Station"].values.tolist()
df_stations = df_stations[df_stations["Station"].isin(unique_stations)]

# Set clean index and sort rows alphabetically
df_stations = df_stations.sort_values("Station")
df_stations.index = range(len(df_stations))

df_stations
# Out:
#                Station    OS X    OS Y   Latitude  Longitude  Zone  Postcode  \
# 0           Abbey Road  539081  183352  51.531952   0.003723     3   E15 3NB
# 1           Abbey Wood  547297  179002  51.490784   0.120272     4   SE2 9RH
# 2        Acton Central  520613  180299  51.508757  -0.263430     2    W3 6BH
# 3      Acton Main Line  520296  181196  51.516886  -0.267690     3    W3 9EH
# 4           Acton Town  519457  179639  51.503071  -0.280303     3    W3 8HN
# ..                 ...     ...     ...        ...        ...   ...       ...
# 648      Woodside Park  525725  192564  51.617868  -0.185426     4   N12 8SE
# 649           Woolwich  543931  178994  51.491578   0.071819     4  SE18 6EU
# 650   Woolwich Arsenal  543754  178803  51.489907   0.069194     4  SE18 6HX
# 651  Woolwich Dockyard  542738  178908  51.491108   0.054612     3  SE18 5JY
# 652     Worcester Park  522192  166133  51.381104  -0.245575     4   KT4 7ND
#
#     Zone_original
# 0               3
# 1               4
# 2               2
# 3               3
# 4               3
# ..            ...
# 648             4
# 649             4
# 650             4
# 651             3
# 652             4
#
# [653 rows x 8 columns]
# Duplicated stations:
# Station
# Hammersmith     2
# Edgware Road    2
# Name: count, dtype: int64
#             Station   Latitude  Longitude  Zone  Postcode
# 0        Acton Town  51.503071  -0.280303     3    W3 8HN
# 1           Aldgate  51.514342  -0.075627     1  EC3N 1AH
# 2      Aldgate East  51.515082  -0.073001     1    E1 7PT
# 3          Alperton  51.541209  -0.299516     4   HA0 4LL
# 4          Amersham  51.674128  -0.606514     9   HP6 5AZ
# ..              ...        ...        ...   ...       ...
# 261  Wimbledon Park  51.434581  -0.199186     3  SW19 7DZ
# 262      Wood Green  51.597454  -0.109527     3   N22 8HH
# 263       Wood Lane  51.509658  -0.224473     2   W12 7DS
# 264        Woodford  51.607202   0.034056     4   IG8 7QE
# 265   Woodside Park  51.617868  -0.185426     4   N12 8SE
#
# [266 rows x 5 columns]

# %%
#assert not (set(unique_stations) - set(all_stations)), "Some station information have not been found"

# %% [markdown]
# ## Import dataframe containing tube station information

# %%
df_sightseeing = pd.read_csv(
    f"{path_data}/TfL_london_transport_tube_sightseeing.csv", sep=";", header=1
)
df_sightseeing = df_sightseeing.T.drop_duplicates().T.rename(columns={"Blurb": "Note"})
df_sightseeing = df_sightseeing.apply(
    lambda x: x.str.strip() if x.dtype == "object" else x
)
df_sightseeing["Station"] = df_sightseeing["Station"].str.replace(" and ", " & ")

# Replace "Bank" by "Bank & Monument" for convenience
df_sightseeing["Station"] = df_sightseeing["Station"].str.replace("^Bank$", "Bank & Monument", regex=True)
df_sightseeing = df_sightseeing.drop(df_sightseeing[df_sightseeing["Station"] == "Monument"].index, axis=0)

# Remove lines from Docklands Light Railway (DLR) line
df_sightseeing = df_sightseeing[~df_sightseeing["Station"].isin([
    "Crossharbour", "Custom House for ExCeL"
])]

# Remove (B) and (C) from Edgware Road
df_sightseeing["Station"] = df_sightseeing["Station"].str.replace(r" \((Bakerloo|H & C)\)", "", regex=True)

# Remove (District & Picc) from Hammersmith
df_sightseeing["Station"] = df_sightseeing["Station"].str.replace(r" \(District & Picc\)", "", regex=True)

# Add dashes to Harrow on the Hill station
df_sightseeing["Station"] = df_sightseeing["Station"].str.replace("Harrow on the Hill", "Harrow-on-the-Hill", regex=True)

# Add spaces in "Heathrow Terminals 123"
df_sightseeing["Station"] = df_sightseeing["Station"].str.replace("Heathrow Terminals 123", "Heathrow Terminals 1 2 3", regex=False)

# Add dot in King's Cross St Pancras, St John's Wood and St Paul's
df_sightseeing["Station"] = df_sightseeing["Station"].str.replace("King's Cross St Pancras", "King's Cross St. Pancras", regex=False)
df_sightseeing["Station"] = df_sightseeing["Station"].str.replace("St John's Wood", "St. John's Wood", regex=False)
df_sightseeing["Station"] = df_sightseeing["Station"].str.replace("St Paul's", "St. Paul's", regex=False)

df_sightseeing
# Out:
#               Station                                               Note
# 0          Abbey Road  Explore the historic House Mill and the Three ...
# 1          Acton Town  Gunnersbury Park and Museum offer landscaped g...
# 2             Aldgate  See the historic Aldgate Pump and visit the ne...
# 3        Aldgate East  Head to Brick Lane for famous curry houses, vi...
# 4          All Saints  Chrisp Street Market and the Lansbury Estate s...
# ..                ...                                                ...
# 294    Wimbledon Park  Row on the lake at Wimbledon Park and watch te...
# 295        Wood Green  Take in the views from Alexandra Palace and sh...
# 296          Woodford  Explore Epping Forest and play golf at Woodfor...
# 297     Woodside Park  Walk the Dollis Valley Greenwalk and shop alon...
# 298  Woolwich Arsenal  Explore the Royal Arsenal Riverside and take t...
#
# [296 rows x 2 columns]

# %%
#assert not (set(df_sightseeing["Station"]) - set(df_stations["Station"])), "Some station information have not been found"

# %% [markdown]
# ## Merge station information

# %%
if "Note" not in df_stations.columns:
    df_stations = pd.merge(df_stations, df_sightseeing, on="Station", how="left")
df_stations
# Out:
#             Station   Latitude  Longitude  Zone  Postcode  \
# 0        Acton Town  51.503071  -0.280303     3    W3 8HN
# 1           Aldgate  51.514342  -0.075627     1  EC3N 1AH
# 2      Aldgate East  51.515082  -0.073001     1    E1 7PT
# 3          Alperton  51.541209  -0.299516     4   HA0 4LL
# 4          Amersham  51.674128  -0.606514     9   HP6 5AZ
# ..              ...        ...        ...   ...       ...
# 263  Wimbledon Park  51.434581  -0.199186     3  SW19 7DZ
# 264      Wood Green  51.597454  -0.109527     3   N22 8HH
# 265       Wood Lane  51.509658  -0.224473     2   W12 7DS
# 266        Woodford  51.607202   0.034056     4   IG8 7QE
# 267   Woodside Park  51.617868  -0.185426     4   N12 8SE
#
#                                                   Note
# 0    Gunnersbury Park and Museum offer landscaped g...
# 1    See the historic Aldgate Pump and visit the ne...
# 2    Head to Brick Lane for famous curry houses, vi...
# 3    Walk along the Grand Union Canal or explore th...
# 4    Wander through the picturesque old town of Ame...
# ..                                                 ...
# 263  Row on the lake at Wimbledon Park and watch te...
# 264  Take in the views from Alexandra Palace and sh...
# 265                                                NaN
# 266  Explore Epping Forest and play golf at Woodfor...
# 267  Walk the Dollis Valley Greenwalk and shop alon...
#
# [268 rows x 6 columns]

# %% [markdown]
# ## Compute distances between stations (using euclidian distance between station coordinates)

# %%
import numpy as np

def euclidean_distance_geo_coord(df_coordinates, latitude_deg=51.5):  # lat1, lon1, lat2, lon2):
    """
    Euclidean distance in meters.
    Accurate enough for distances < 5km.

    By default, latitude is set to London (51.5°)
    """
    # Meters per degree at London's latitude (51.5°)
    meters_per_lat = 111320  # Constant everywhere
    meters_per_lon = 111320 * np.cos(latitude_deg)
    
    dy = (df_coordinates.iloc[0, 0] - df_coordinates.iloc[1, 0]) * meters_per_lat
    dx = (df_coordinates.iloc[0, 1] - df_coordinates.iloc[1, 1]) * meters_per_lon
    
    return np.sqrt(dx**2 + dy**2)

# %%
def add_stations_distances(df_link_stations):
    list_dist_stations = []

    for row in tqdm(df_link_stations.itertuples(), total=len(df_link_stations)):
        # Get origin and destination stations
        from_station = row.From_Station
        to_station = row.To_Station
        #print(f"From {from_station} to {to_station}")
    
        # Get stations coordinates
        df_coordinates = df_stations[df_stations["Station"].isin([from_station, to_station])].loc[:, ["Latitude", "Longitude"]]
        
        # Compute euclidean distance between stations coordinates and get data in meters
        dist = int(euclidean_distance_geo_coord(df_coordinates))
        #print(f"Euclidean distance: {dist}")
    
        # Save for df_link_stations
        list_dist_stations.append(dist)
    
    assert len(list_dist_stations) == len(df_link_stations), "List of distances should be the same size as df_links_stations"

    # Add Distance column to df_link_stations
    df_link_stations["DistanceMeters"] = list_dist_stations

# %%
# Add Distance column to df_link_stations
if "DistanceMeters" not in df_link_stations.columns:
    add_stations_distances(df_link_stations)
    print("Euclidean distance successfully added")
# Out:
#   0%|          | 0/714 [00:00<?, ?it/s]
# Euclidean distance successfully added

# %%
df_link_stations
# Out:
#                 Line  Order       From_Station         To_Station   Total  \
# 0           Bakerloo      1  Elephant & Castle      Lambeth North  13.432
# 1           Bakerloo      2      Lambeth North           Waterloo  18.597
# 2           Bakerloo      3           Waterloo         Embankment  46.020
# 3           Bakerloo      4         Embankment      Charing Cross  55.475
# 4           Bakerloo      5      Charing Cross  Piccadilly Circus  63.929
# ..               ...    ...                ...                ...     ...
# 859         Victoria     13            Pimlico           Vauxhall  94.853
# 860         Victoria     14           Vauxhall          Stockwell  66.561
# 861         Victoria     15          Stockwell            Brixton  41.178
# 862  Waterloo & City      1           Waterloo    Bank & Monument   5.554
# 863  Waterloo & City      1    Bank & Monument           Waterloo   6.348
#
#      PM Peak     Evening        Late  DistanceMeters
# 0         4.118       1.288  398.000             545
# 1         5.718       1.916  580.000             450
# 2        13.746       4.609    1.466             571
# 3        17.155       5.959    1.940             146
# 4        20.112       7.712    3.035             359
# ..          ...         ...      ...             ...
# 859      37.711      24.553   10.574             544
# 860      27.117      18.342    7.992            1511
# 861      15.972      11.553    5.361            1092
# 862       5.197       1.465  386.000            1443
# 863      18.237       6.517    1.374            1443
#
# [714 rows x 9 columns]

# %% [markdown]
# # Create graph from dataframe

# %%
G = create_graph_from_df(
    df_link_stations,
    source_node_col={"id": "From_Station", "type": "Station"},
    target_node_col={"id": "To_Station", "type": "Station"},
    node_attributes_df=df_stations,
    node_attributes_key_col="Station",
    #edge_col="Line",
    attributes_edges=["Line", "DistanceMeters"]
)

# %%
# Show 10 first nodes
for node in list(G.nodes(data=True))[:10]:
    print(node)
# Out:
# ('Elephant & Castle', {'displayName': 'Elephant & Castle', 'type': 'Station', 'Latitude': 51.4958492200292, 'Longitude': -0.100738714256282, 'Zone': 1, 'Postcode': 'SE1 6LW', 'Note': 'Visit the Imperial War Museum or catch a show at Southwark Playhouse.'})
# ('Lambeth North', {'displayName': 'Lambeth North', 'type': 'Station', 'Latitude': 51.4991297653886, 'Longitude': -0.111768260460206, 'Zone': 1, 'Postcode': 'SE1 7XG', 'Note': 'Visit the Imperial War Museum and browse the Saturday market on Lower Marsh.'})
# ('Waterloo', {'displayName': 'Waterloo', 'type': 'Station', 'Latitude': 51.5031464567835, 'Longitude': -0.113259251258196, 'Zone': 1, 'Postcode': 'SE1 7NY', 'Note': 'Ride the London Eye, stroll along the South Bank and see a play at the National Theatre.'})
# ('Embankment', {'displayName': 'Embankment', 'type': 'Station', 'Latitude': 51.5073122969468, 'Longitude': -0.12236733566212, 'Zone': 1, 'Postcode': 'WC2N 6NS', 'Note': 'Relax in Victoria Embankment Gardens and see Cleopatra’s Needle along the Thames.'})
# ('Charing Cross', {'displayName': 'Charing Cross', 'type': 'Station', 'Latitude': 51.5083584281862, 'Longitude': -0.124802937233044, 'Zone': 1, 'Postcode': 'WC2N 5HS', 'Note': 'Stand in Trafalgar Square beneath Nelson’s Column and explore the National Gallery.'})
# ('Piccadilly Circus', {'displayName': 'Piccadilly Circus', 'type': 'Station', 'Latitude': 51.5096965321706, 'Longitude': -0.133711596159076, 'Zone': 1, 'Postcode': 'W1J 9HS', 'Note': 'See the bright lights of Piccadilly Circus, meet Eros at the Shaftesbury Memorial Fountain and visit the Criterion Theatre.'})
# ('Oxford Circus', {'displayName': 'Oxford Circus', 'type': 'Station', 'Latitude': 51.5152231744017, 'Longitude': -0.140836170133341, 'Zone': 1, 'Postcode': 'W1C 2JS', 'Note': 'Shop on Oxford Street and Regent Street and visit Hamleys, the world’s oldest toy store.'})
# ("Regent's Park", {'displayName': "Regent's Park", 'type': 'Station', 'Latitude': 51.5238104377728, 'Longitude': -0.145344409720596, 'Zone': 1, 'Postcode': 'NW1 5HA', 'Note': 'Explore Regent’s Park’s formal gardens and visit ZSL London Zoo.'})
# ('Baker Street', {'displayName': 'Baker Street', 'type': 'Station', 'Latitude': 51.5231293660588, 'Longitude': -0.156904192986185, 'Zone': 1, 'Postcode': 'NW1 5LA', 'Note': 'Step into Sherlock Holmes’ world at 221B Baker Street or meet wax celebrities at Madame\xa0Tussauds.'})
# ('Marylebone', {'displayName': 'Marylebone', 'type': 'Station', 'Latitude': 51.5223964032654, 'Longitude': -0.163492562310913, 'Zone': 1, 'Postcode': 'NW1 6JJ', 'Note': 'Shop on Marylebone High Street and tour Madame Tussauds.'})

# %%
# Show 10 first edges
for edge in list(G.edges(data=True))[:10]:
    print(edge)
# Out:
# ('Elephant & Castle', 'Lambeth North', {'Line': 'Bakerloo', 'DistanceMeters': 545})
# ('Elephant & Castle', 'Borough', {'Line': 'Northern', 'DistanceMeters': 626})
# ('Elephant & Castle', 'Kennington', {'Line': 'Northern', 'DistanceMeters': 815})
# ('Lambeth North', 'Waterloo', {'Line': 'Bakerloo', 'DistanceMeters': 450})
# ('Lambeth North', 'Elephant & Castle', {'Line': 'Bakerloo', 'DistanceMeters': 545})
# ('Waterloo', 'Embankment', {'Line': 'Northern', 'DistanceMeters': 571})
# ('Waterloo', 'Lambeth North', {'Line': 'Bakerloo', 'DistanceMeters': 450})
# ('Waterloo', 'Westminster', {'Line': 'Jubilee', 'DistanceMeters': 473})
# ('Waterloo', 'Southwark', {'Line': 'Jubilee', 'DistanceMeters': 285})
# ('Waterloo', 'Kennington', {'Line': 'Northern', 'DistanceMeters': 1640})

# %%
print(G)
# Out:
# DiGraph with 266 nodes and 614 edges

# %% [markdown]
# # Create Cypher CREATE command

# %% [markdown]
# ## Build CREATE command

# %%
# %%time

# Build CREATE command from networkx object
graph_CREATE_command = build_create_command_from_networkx(G, node_type_key='type', edge_type_key='CONNECTION')

print(f"""
Cypher CREATE command :
* size: {len(graph_CREATE_command.encode('utf-8'))/1024/1000:.4f} MB\n
{100 * '*'}
{graph_CREATE_command if len(graph_CREATE_command.split("\n")) < 1000 else "\n".join(graph_CREATE_command.split('\n')[:10]) + "\n...\n" + "\n".join(graph_CREATE_command.split('\n')[-10:])}
{100 * '*'}
""")
# Out:
# Cypher query will create graph with 266 nodes and 614 edges
#
# Cypher CREATE command :
# * size: 0.1528 MB
#
# ****************************************************************************************************
# CREATE (:Station {id: "Elephant & Castle", displayName: "Elephant & Castle", type: "Station", Latitude: 51.4958492200292, Longitude: -0.100738714256282, Zone: 1, Postcode: "SE1 6LW", Note: "Visit the Imperial War Museum or catch a show at Southwark Playhouse."}),
# (:Station {id: "Lambeth North", displayName: "Lambeth North", type: "Station", Latitude: 51.4991297653886, Longitude: -0.111768260460206, Zone: 1, Postcode: "SE1 7XG", Note: "Visit the Imperial War Museum and browse the Saturday market on Lower Marsh."}),
# (:Station {id: "Waterloo", displayName: "Waterloo", type: "Station", Latitude: 51.5031464567835, Longitude: -0.113259251258196, Zone: 1, Postcode: "SE1 7NY", Note: "Ride the London Eye, stroll along the South Bank and see a play at the National Theatre."}),
# (:Station {id: "Embankment", displayName: "Embankment", type: "Station", Latitude: 51.5073122969468, Longitude: -0.12236733566212, Zone: 1, Postcode: "WC2N 6NS", Note: "Relax in Victoria Embankment Gardens and see Cleopatra s Needle along the Thames."}),
# (:Station {id: "Charing Cross", displayName: "Charing Cross", type: "Station", Latitude: 51.5083584281862, Longitude: -0.124802937233044, Zone: 1, Postcode: "WC2N 5HS", Note: "Stand in Trafalgar Square beneath Nelson s Column and explore the National Gallery."}),
# (:Station {id: "Piccadilly Circus", displayName: "Piccadilly Circus", type: "Station", Latitude: 51.5096965321706, Longitude: -0.133711596159076, Zone: 1, Postcode: "W1J 9HS", Note: "See the bright lights of Piccadilly Circus, meet Eros at the Shaftesbury Memorial Fountain and visit the Criterion Theatre."}),
# (:Station {id: "Oxford Circus", displayName: "Oxford Circus", type: "Station", Latitude: 51.5152231744017, Longitude: -0.140836170133341, Zone: 1, Postcode: "W1C 2JS", Note: "Shop on Oxford Street and Regent Street and visit Hamleys, the world s oldest toy store."}),
# (:Station {id: "Regent's Park", displayName: "Regent s Park", type: "Station", Latitude: 51.5238104377728, Longitude: -0.145344409720596, Zone: 1, Postcode: "NW1 5HA", Note: "Explore Regent s Park s formal gardens and visit ZSL London Zoo."}),
# (:Station {id: "Baker Street", displayName: "Baker Street", type: "Station", Latitude: 51.5231293660588, Longitude: -0.156904192986185, Zone: 1, Postcode: "NW1 5LA", Note: "Step into Sherlock Holmes world at 221B Baker Street or meet wax celebrities at Madame Tussauds."}),
# (:Station {id: "Marylebone", displayName: "Marylebone", type: "Station", Latitude: 51.5223964032654, Longitude: -0.163492562310913, Zone: 1, Postcode: "NW1 6JJ", Note: "Shop on Marylebone High Street and tour Madame Tussauds."}),
# (:Station {id: "Edgware Road", displayName: "Edgware Road", type: "Station", Latitude: 51.5206450845361, Longitude: -0.17053954989974, Zone: 1, Postcode: "W2 1DY", Note: "Explore Little Venice s canals and visit the beautiful St Mary Magdalene church."}),
# (:Station {id: "Paddington", displayName: "Paddington", type: "Station", Latitude: 51.5153935002265, Longitude: -0.175736750265772, Zone: 1, Postcode: "W2 1RH", Note: "Stroll along the canals at Paddington Basin and say hello to the Paddington Bear statue."}),
# (:Station {id: "Warwick Avenue", displayName: "Warwick Avenue", type: "Station", Latitude: 51.5231041380791, Longitude: -0.182953291113456, Zone: 2, Postcode: "W9 2PT", Note: "Take a canal boat from Little Venice or watch a puppet show on the Puppet Theatre Barge."}),
# (:Station {id: "Maida Vale", displayName: "Maida Vale", type: "Station", Latitude: 51.5299947556212, Longitude: -0.185432644935856, Zone: 2, Postcode: "W9 1JS", Note: "Explore Little Venice s canals and visit the BBC Maida Vale Studios exterior."}),
# (:Station {id: "Kilburn Park", displayName: "Kilburn Park", type: "Station", Latitude: 51.5351352218434, Longitude: -0.193966054939706, Zone: 2, Postcode: "NW6 5AD", Note: "Walk to Maida Vale s canals or relax in Paddington Recreation Ground."}),
# (:Station {id: "Queen's Park", displayName: "Queen s Park", type: "Station", Latitude: 51.5343123177635, Longitude: -0.204798146950672, Zone: 2, Postcode: "NW6 6HJ", Note: "Enjoy Queens Park s bandstand and café or browse the farmers market on Sundays."}),
# (:Station {id: "Kensal Green", displayName: "Kensal Green", type: "Station", Latitude: 51.5305238487188, Longitude: -0.224713381138044, Zone: 2, Postcode: "NW10 5JT", Note: "Walk through the historic Kensal Green Cemetery or enjoy a drink at Paradise by way of Kensal Green pub."}),
# (:Station {id: "Willesden Junction", displayName: "Willesden Junction", type: "Station", Latitude: 51.532233566617, Longitude: -0.243909139837678, Zone: 3, Postcode: "NW10 4RA", Note: "Walk the Grand Union Canal and explore the industrial heritage of Old Oak Common."}),
# (:Station {id: "Harlesden", displayName: "Harlesden", type: "Station", Latitude: 51.5362579086204, Longitude: -0.257495670377017, Zone: 3, Postcode: "NW10 8UT", Note: "Drop into the legendary Ace Cafe or see the Jubilee Clock at Harlesden High Street."}),
# (:Station {id: "Stonebridge Park", displayName: "Stonebridge Park", type: "Station", Latitude: 51.5439861056564, Longitude: -0.275400437104679, Zone: 3, Postcode: "NW10 0RW", Note: "Walk along the Grand Union Canal by the Brent Reservoir (Welsh Harp) and stop at the Ace Cafe."}),
# (:Station {id: "Wembley Central", displayName: "Wembley Central", type: "Station", Latitude: 51.5518642975386, Longitude: -0.296392321916041, Zone: 4, Postcode: "HA9 6AG", Note: "Attend events at Wembley Arena or watch a match at Wembley Stadium and shop at London Designer Outlet."}),
# (:Station {id: "North Wembley", displayName: "North Wembley", type: "Station", Latitude: 51.5623957964433, Longitude: -0.303948213913291, Zone: 4, Postcode: "HA0 3NT", Note: "Walk to Wembley Stadium and the London Designer Outlet for shopping."}),
# (:Station {id: "South Kenton", displayName: "South Kenton", type: "Station", Latitude: 51.571043947551296, Longitude: -0.308142971762093, Zone: 4, Postcode: "HA9 8QT", Note: "Play sports at Northwick Park and enjoy a drink at The Windermere pub."}),
# (:Station {id: "Kenton", displayName: "Kenton", type: "Station", Latitude: 51.5814957703514, Longitude: -0.315216860826321, Zone: 4, Postcode: "HA3 0XS", Note: "Stroll around Northwick Park or relax in Kenton Recreation Ground."}),
# (:Station {id: "Harrow & Wealdstone", displayName: "Harrow & Wealdstone", type: "Station", Latitude: 51.5925940880877, Longitude: -0.334252678574127, Zone: 5, Postcode: "HA3 7RF", Note: "Explore Harrow School s historic buildings and visit St Mary s Church on the hill."}),
# (:Station {id: "West Ruislip", displayName: "West Ruislip", type: "Station", Latitude: 51.5695871570355, Longitude: -0.437860134374038, Zone: 6, Postcode: "HA4 7WD", Note: "Ride the miniature railway at Ruislip Lido and watch planes at RAF Northolt."}),
# (:Station {id: "Ruislip Gardens", displayName: "Ruislip Gardens", type: "Station", Latitude: 51.5599595105222, Longitude: -0.409294101374034, Zone: 5, Postcode: "HA4 6LG", Note: "Walk the Yeading Brook Nature Reserve and visit the nearby Polish War Memorial."}),
# (:Station {id: "South Ruislip", displayName: "South Ruislip", type: "Station", Latitude: 51.556889651478, Longitude: -0.399115901006822, Zone: 5, Postcode: "HA4 6TP", Note: "Visit the Polish War Memorial and watch planes at RAF Northolt."}),
# (:Station {id: "Northolt", displayName: "Northolt", type: "Station", Latitude: 51.5482123001801, Longitude: -0.36844058759762, Zone: 5, Postcode: "UB5 4AA", Note: "Explore Northala Fields with its four man made hills and lakes."}),
# (:Station {id: "Greenford", displayName: "Greenford", type: "Station", Latitude: 51.5419795070146, Longitude: -0.345878733131022, Zone: 4, Postcode: "UB6 8PR", Note: "Visit the London Motorcycle Museum or enjoy open space at Ravenor Park."}),
# (:Station {id: "Perivale", displayName: "Perivale", type: "Station", Latitude: 51.5363412946729, Longitude: -0.323070415901167, Zone: 4, Postcode: "UB6 7NP", Note: "Admire the Art Deco Hoover Building and enjoy green space in Perivale Park."}),
# (:Station {id: "Hanger Lane", displayName: "Hanger Lane", type: "Station", Latitude: 51.5300715563412, Longitude: -0.292996140557165, Zone: 3, Postcode: "W5 1DL", Note: "Marvel at the Hanger Lane gyratory and visit the nearby Ace Cafe, a motorcycling icon."}),
# (:Station {id: "North Acton", displayName: "North Acton", type: "Station", Latitude: 51.5234320046099, Longitude: -0.259729523922228, Zone: 2, Postcode: "W3 6UP", Note: "Relax in North Acton Playing Fields and explore the new mixed use development of Acton Gardens."}),
# (:Station {id: "Ealing Broadway", displayName: "Ealing Broadway", type: "Station", Latitude: 51.5148614827794, Longitude: -0.302010376133626, Zone: 3, Postcode: "W5 2NU", Note: "Visit Ealing Broadway Shopping Centre or relax in the landscaped Walpole Park."}),
# (:Station {id: "West Acton", displayName: "West Acton", type: "Station", Latitude: 51.517769693141, Longitude: -0.280657170904487, Zone: 3, Postcode: "W3 6UP", Note: "Relax in North Acton Playing Fields and explore the Gunnersbury Triangle Nature Reserve."}),
# (:Station {id: "East Acton", displayName: "East Acton", type: "Station", Latitude: 51.5162630104536, Longitude: -0.248112221281314, Zone: 2, Postcode: "W12 0BP", Note: "Stroll through Acton Park or head to Wormwood Scrubs for wide open spaces."}),
# (:Station {id: "White City", displayName: "White City", type: "Station", Latitude: 51.5122320722798, Longitude: -0.224631928515273, Zone: 2, Postcode: "W12 7RH", Note: "Shop at Westfield London and see the redeveloped BBC Television Centre."}),
# (:Station {id: "Shepherd's Bush", displayName: "Shepherd s Bush", type: "Station", Latitude: 51.50453179561391, Longitude: -0.218519156668849, Zone: 2, Postcode: "W12 8LH", Note: "Shop at Westfield London and watch a gig at the O2 Shepherd s Bush Empire."}),
# (:Station {id: "Holland Park", displayName: "Holland Park", type: "Station", Latitude: 51.5071461481404, Longitude: -0.206557775412328, Zone: 2, Postcode: "W11 3RB", Note: "Stroll through Holland Park and its Kyoto Garden for a Japanese oasis."}),
# (:Station {id: "Notting Hill Gate", displayName: "Notting Hill Gate", type: "Station", Latitude: 51.5093750180118, Longitude: -0.195921616226391, Zone: 1, Postcode: "W11 3HT", Note: "Browse antiques at Portobello Road Market and watch a film at the Electric Cinema."}),
# (:Station {id: "Queensway", displayName: "Queensway", type: "Station", Latitude: 51.5104489285477, Longitude: -0.187419901048369, Zone: 1, Postcode: "W2 4SS", Note: "Go ice skating at Queens Ice and Bowl or explore the redeveloped Whiteleys building."}),
# (:Station {id: "Lancaster Gate", displayName: "Lancaster Gate", type: "Station", Latitude: 51.511890658328305, Longitude: -0.175429926789792, Zone: 1, Postcode: "W2 4QH", Note: "Admire the Italian Gardens in Hyde Park and the Lancaster Gate Hotel façade."}),
# (:Station {id: "Marble Arch", displayName: "Marble Arch", type: "Station", Latitude: 51.5139652346594, Longitude: -0.158571214792758, Zone: 1, Postcode: "W1C 2JS", Note: "View the Marble Arch monument and Speaker s Corner at Hyde Park."}),
# (:Station {id: "Bond Street", displayName: "Bond Street", type: "Station", Latitude: 51.5137972823274, Longitude: -0.149613608531646, Zone: 1, Postcode: "W1C 2HU", Note: "Shop luxury boutiques on Bond Street or high street stores along Oxford Street."}),
# (:Station {id: "Tottenham Court Road", displayName: "Tottenham Court Road", type: "Station", Latitude: 51.5162106579362, Longitude: -0.131110437940232, Zone: 1, Postcode: "W1D 2DA", Note: "Watch a musical at the Dominion Theatre and browse electronics shops along Tottenham Court Road."}),
# (:Station {id: "Holborn", displayName: "Holborn", type: "Station", Latitude: 51.5172355413957, Longitude: -0.119840506602937, Zone: 1, Postcode: "WC2B 6AA", Note: "Visit the British Museum and the Sir John Soane s Museum near Lincoln s Inn Fields."}),
# (:Station {id: "Chancery Lane", displayName: "Chancery Lane", type: "Station", Latitude: 51.5184938358199, Longitude: -0.111962026762417, Zone: 1, Postcode: "WC1V 6DR", Note: "Visit the Sir John Soane s Museum or walk through the historic Inns of Court."}),
# (:Station {id: "St. Paul's", displayName: "St. Paul s", type: "Station", Latitude: 51.514835138739905, Longitude: -0.0975710001169854, Zone: 1, Postcode: "EC2V 6AA", Note: "Marvel at St Paul s Cathedral and wander around Paternoster Square."}),
# (:Station {id: "Bank & Monument", displayName: "Bank & Monument", type: "Station", Latitude: 51.5133469191418, Longitude: -0.0890001234943747, Zone: 1, Postcode: "EC3V 3LA", Note: "Explore the Bank of England Museum on Threadneedle Street and the Royal Exchange."}),
# (:Station {id: "Liverpool Street", displayName: "Liverpool Street", type: "Station", Latitude: 51.517598132254, Longitude: -0.0822496218888544, Zone: 1, Postcode: "EC2M 7PR", Note: "Browse Old Spitalfields Market for food and crafts and admire the City s skyscrapers."}),
# (:Station {id: "Bethnal Green", displayName: "Bethnal Green", type: "Station", Latitude: 51.527191653122095, Longitude: -0.055392111450162, Zone: 2, Postcode: "E2 0ET", Note: "The V&A Museum of Childhood displays toys and childhood culture in a charming hall."}),
# (:Station {id: "Mile End", displayName: "Mile End", type: "Station", Latitude: 51.5253109195645, Longitude: -0.0326660842711517, Zone: 2, Postcode: "E3 4DH", Note: "Cycle through Mile End Park and visit the campus of Queen Mary University of London."}),
# (:Station {id: "Stratford", displayName: "Stratford", type: "Station", Latitude: 51.541692575874, Longitude: -0.0037516410271907, Zone: 3, Postcode: "E15 1AZ", Note: "Explore Queen Elizabeth Olympic Park and shop at Westfield Stratford City."}),
# (:Station {id: "Leyton", displayName: "Leyton", type: "Station", Latitude: 51.5581322623127, Longitude: -0.006465331580603, Zone: 3, Postcode: "E10 5PS", Note: "Visit Leyton Orient s Brisbane Road stadium and enjoy green space at Coronation Gardens."}),
# (:Station {id: "Leytonstone", displayName: "Leytonstone", type: "Station", Latitude: 51.5685223067262, Longitude: 0.0091404519570612, Zone: 3, Postcode: "E11 1HE", Note: "Spot Hitchcock mosaics in the tube station and stroll through Epping Forest s southern edge."}),
# (:Station {id: "Snaresbrook", displayName: "Snaresbrook", type: "Station", Latitude: 51.5808913115707, Longitude: 0.021463927810755, Zone: 4, Postcode: "E11 1QE", Note: "Walk around Eagle Pond and the ornamental lake in Epping Forest near Snaresbrook."}),
# (:Station {id: "South Woodford", displayName: "South Woodford", type: "Station", Latitude: 51.5915526647549, Longitude: 0.0279430783744094, Zone: 4, Postcode: "E18 1JJ", Note: "Walk in Epping Forest and shop along George Lane."}),
# (:Station {id: "Woodford", displayName: "Woodford", type: "Station", Latitude: 51.6072019027903, Longitude: 0.034056202416626, Zone: 4, Postcode: "IG8 7QE", Note: "Explore Epping Forest and play golf at Woodford Golf Club."}),
# (:Station {id: "Buckhurst Hill", displayName: "Buckhurst Hill", type: "Station", Latitude: 51.6265767400473, Longitude: 0.0467125414287692, Zone: 5, Postcode: "IG9 5ET", Note: "Explore Roding Valley Park or wander through Linder s Field Nature Reserve."}),
# (:Station {id: "Loughton", displayName: "Loughton", type: "Station", Latitude: 51.641570570828, Longitude: 0.0552790792874479, Zone: 6, Postcode: "IG10 4PD", Note: "Visit Epping Forest and shop along Loughton High Road."}),
# (:Station {id: "Debden", displayName: "Debden", type: "Station", Latitude: 51.6454921415259, Longitude: 0.0838014752563246, Zone: 6, Postcode: "IG10 3TG", Note: "Camp at Debden House and hike through Epping Forest s woodland."}),
# (:Station {id: "Theydon Bois", displayName: "Theydon Bois", type: "Station", Latitude: 51.67255225418, Longitude: 0.102890736881682, Zone: 6, Postcode: "CM16 7EU", Note: "Walk through Epping Forest and enjoy village pubs like the Queen Victoria."}),
# (:Station {id: "Epping", displayName: "Epping", type: "Station", Latitude: 51.693686354978, Longitude: 0.113825553514212, Zone: 6, Postcode: "CM16 4HW", Note: "Wander the ancient woodland of Epping Forest at the very end of the line."}),
# (:Station {id: "Wanstead", displayName: "Wanstead", type: "Station", Latitude: 51.57490219957089, Longitude: 0.028760472436225, Zone: 4, Postcode: "E11 2NT", Note: "Walk through Wanstead Park and explore Christchurch Green in the village centre."}),
# (:Station {id: "Redbridge", displayName: "Redbridge", type: "Station", Latitude: 51.5763669943606, Longitude: 0.0453940440870774, Zone: 4, Postcode: "IG4 5BG", Note: "Cycle at Redbridge Cycling Centre or walk through Wanstead Park and the ornamental lakes."}),
# (:Station {id: "Gants Hill", displayName: "Gants Hill", type: "Station", Latitude: 51.5765530629417, Longitude: 0.0660840980631794, Zone: 4, Postcode: "IG2 6UD", Note: "Stroll through Valentines Park and admire the station s striking Art Deco design."}),
# (:Station {id: "Newbury Park", displayName: "Newbury Park", type: "Station", Latitude: 51.5756385064638, Longitude: 0.0903031581978967, Zone: 4, Postcode: "IG2 7RN", Note: "Admire the station s Grade II listed bus shelter and walk to Valentines Park."}),
# (:Station {id: "Barkingside", displayName: "Barkingside", type: "Station", Latitude: 51.5858507614628, Longitude: 0.0884766401059263, Zone: 4, Postcode: "IG6 1NB", Note: "Learn about Barnardo s history at the Barnardo s Garden Village and roam Fairlop Waters park."}),
# (:Station {id: "Fairlop", displayName: "Fairlop", type: "Station", Latitude: 51.5961096941749, Longitude: 0.0905932799159299, Zone: 4, Postcode: "IG6 3HD", Note: "Sail or cycle around Fairlop Waters Country Park and its lake."}),
# (:Station {id: "Hainault", displayName: "Hainault", type: "Station", Latitude: 51.602845483752304, Longitude: 0.0941085508301525, Zone: 4, Postcode: "IG6 3BD", Note: "Walk the trails of Hainault Forest Country Park and visit Fox Burrow Farm."}),
# (:Station {id: "Grange Hill", displayName: "Grange Hill", type: "Station", Latitude: 51.6134805793354, Longitude: 0.0922725301686921, Zone: 4, Postcode: "IG7 5QB", Note: "Explore Hainault Forest Country Park just east of the station."}),
# (:Station {id: "Chigwell", displayName: "Chigwell", type: "Station", Latitude: 51.6178579997418, Longitude: 0.0761792153523028, Zone: 4, Postcode: "IG7 6NT", Note: "Play a round at Chigwell Golf Club or walk in Epping Forest s southern reaches."}),
# (:Station {id: "Roding Valley", displayName: "Roding Valley", type: "Station", Latitude: 51.6169565208123, Longitude: 0.0440262071266385, Zone: 4, Postcode: "IG9 6LN", Note: "Discover Roding Valley Meadows nature reserve, a haven for wildlife."}),
# (:Station {id: "Ealing Common", displayName: "Ealing Common", type: "Station", Latitude: 51.5102481879337, Longitude: -0.287151413105322, Zone: 3, Postcode: "W5 3LD", Note: "Enjoy a picnic on Ealing Common and attend events at the annual Ealing Jazz and Blues festivals."}),
# (:Station {id: "Acton Town", displayName: "Acton Town", type: "Station", Latitude: 51.5030709863634, Longitude: -0.280302696832724, Zone: 3, Postcode: "W3 8HN", Note: "Gunnersbury Park and Museum offer landscaped gardens and local history a short walk from the station."}),
# (:Station {id: "Chiswick Park", displayName: "Chiswick Park", type: "Station", Latitude: 51.49437027794271, Longitude: -0.267736917992298, Zone: 3, Postcode: "W4 5NE", Note: "Tour the elegant Chiswick House and its beautiful gardens."}),
# (:Station {id: "Turnham Green", displayName: "Turnham Green", type: "Station", Latitude: 51.4951815268556, Longitude: -0.254524564284254, Zone: 2, Postcode: "W4 1LR", Note: "Visit Chiswick High Road s boutiques and Hogarth s House near the green."}),
# (:Station {id: "Richmond", displayName: "Richmond", type: "Station", Latitude: 51.4632323939592, Longitude: -0.301739128704929, Zone: 4, Postcode: "TW9 2AZ", Note: "Walk through Richmond Park to see the deer or along the riverside to Richmond Green."}),
# (:Station {id: "Kew Gardens", displayName: "Kew Gardens", type: "Station", Latitude: 51.4767886712304, Longitude: -0.285381006676174, Zone: 9, Postcode: "TW9 3PZ", Note: "Explore the Royal Botanic Gardens, Kew and the treetop walkway."}),
# (:Station {id: "Gunnersbury", displayName: "Gunnersbury", type: "Station", Latitude: 51.4918629632299, Longitude: -0.27516413141625, Zone: 3, Postcode: "W4 5RP", Note: "Relax in Gunnersbury Park and visit the London Transport Museum Depot."}),
# (:Station {id: "Stamford Brook", displayName: "Stamford Brook", type: "Station", Latitude: 51.4944495685697, Longitude: -0.245246306027922, Zone: 2, Postcode: "W6 0SB", Note: "Relax in Ravenscourt Park or explore Chiswick High Road s shops and cafes."}),
# (:Station {id: "Ravenscourt Park", displayName: "Ravenscourt Park", type: "Station", Latitude: 51.494067596546, Longitude: -0.235969229860143, Zone: 2, Postcode: "W6 0UG", Note: "Stroll through Ravenscourt Park and its walled garden and glasshouses."}),
# (:Station {id: "Hammersmith", displayName: "Hammersmith", type: "Station", Latitude: 51.4918194135572, Longitude: -0.222860925885304, Zone: 2, Postcode: "W6 9YA", Note: "See a show at the Eventim Apollo and shop at Kings Mall."}),
# (:Station {id: "Barons Court", displayName: "Barons Court", type: "Station", Latitude: 51.490228334902, Longitude: -0.213430142417892, Zone: 2, Postcode: "W14 9DP", Note: "Catch a tennis match at the Queen s Club or admire the Victorian architecture of St Paul s School."}),
# (:Station {id: "West Kensington", displayName: "West Kensington", type: "Station", Latitude: 51.4901090272106, Longitude: -0.206203692218027, Zone: 2, Postcode: "W14 9NL", Note: "Watch matches at the Queen s Club and explore the Olympia London Exhibition Centre."}),
# (:Station {id: "Earl's Court", displayName: "Earl s Court", type: "Station", Latitude: 51.4913563561976, Longitude: -0.194313807095143, Zone: 1, Postcode: "SW5 9QA", Note: "Explore the legacy of the Earls Court Exhibition Centre and dine at the historic Troubadour café."}),
# (:Station {id: "Wimbledon", displayName: "Wimbledon", type: "Station", Latitude: 51.4211075087935, Longitude: -0.206662833440053, Zone: 3, Postcode: "SW19 1PS", Note: "Visit the Wimbledon Lawn Tennis Museum at the All England Club and stroll through Wimbledon Village."}),
# (:Station {id: "Wimbledon Park", displayName: "Wimbledon Park", type: "Station", Latitude: 51.4345806287444, Longitude: -0.199186272973062, Zone: 3, Postcode: "SW19 7DZ", Note: "Row on the lake at Wimbledon Park and watch tennis at the Wimbledon Club."}),
# (:Station {id: "Southfields", displayName: "Southfields", type: "Station", Latitude: 51.44488297741, Longitude: -0.206609383090931, Zone: 3, Postcode: "SW18 5RJ", Note: "Visit the All England Lawn Tennis Club and its Wimbledon Lawn Tennis Museum."}),
# (:Station {id: "East Putney", displayName: "East Putney", type: "Station", Latitude: 51.4588794403538, Longitude: -0.210998231595942, Zone: 2, Postcode: "SW15 6SN", Note: "Follow the Thames Path through Wandsworth Park and enjoy river views."}),
# (:Station {id: "Putney Bridge", displayName: "Putney Bridge", type: "Station", Latitude: 51.4678649970564, Longitude: -0.209365414301954, Zone: 2, Postcode: "SW6 3UH", Note: "Visit the historic Fulham Palace and stroll through Bishops Park along the Thames."}),
# (:Station {id: "Parsons Green", displayName: "Parsons Green", type: "Station", Latitude: 51.4749598256595, Longitude: -0.201124490012253, Zone: 2, Postcode: "SW6 4HU", Note: "Relax on Parsons Green, dine at the White Horse pub and browse New King s Road boutiques."}),
# (:Station {id: "Fulham Broadway", displayName: "Fulham Broadway", type: "Station", Latitude: 51.4802605857463, Longitude: -0.195544161527897, Zone: 2, Postcode: "SW6 1BY", Note: "Tour Chelsea FC s Stamford Bridge stadium and museum."}),
# (:Station {id: "West Brompton", displayName: "West Brompton", type: "Station", Latitude: 51.4873285969614, Longitude: -0.195538809670428, Zone: 2, Postcode: "SW5 9JX", Note: "Walk through Brompton Cemetery and catch a match at Stamford Bridge stadium."}),
# (:Station {id: "Kensington (Olympia)", displayName: "Kensington (Olympia)", type: "Station", Latitude: 51.4979934, Longitude: -0.2099576, Zone: 2, Postcode: "W14 0NE", Note: "Attend exhibitions at Olympia London and tour the nearby Design Museum."}),
# (:Station {id: "High Street Kensington", displayName: "High Street Kensington", type: "Station", Latitude: 51.5007291341687, Longitude: -0.191566055496419, Zone: 1, Postcode: "W8 5SA", Note: "Visit Kensington Palace and stroll through Kensington Gardens."}),
# (:Station {id: "Bayswater", displayName: "Bayswater", type: "Station", Latitude: 51.5121109831796, Longitude: -0.187901571878205, Zone: 1, Postcode: "W2 4QH", Note: "nan"}),
# (:Station {id: "Gloucester Road", displayName: "Gloucester Road", type: "Station", Latitude: 51.4944992596252, Longitude: -0.183543557571591, Zone: 1, Postcode: "SW7 4SF", Note: "Walk to the Natural History Museum or Victoria & Albert Museum in nearby South Kensington."}),
# (:Station {id: "South Kensington", displayName: "South Kensington", type: "Station", Latitude: 51.4940710832552, Longitude: -0.17392302133764, Zone: 1, Postcode: "SW7 2NB", Note: "Visit the Natural History, Science and Victoria & Albert museums in the Exhibition Road area."}),
# (:Station {id: "Sloane Square", displayName: "Sloane Square", type: "Station", Latitude: 51.4923595104806, Longitude: -0.156488856057024, Zone: 1, Postcode: "SW1W 8BB", Note: "Browse the Saatchi Gallery and shop along the fashionable King s Road."}),
# (:Station {id: "Victoria", displayName: "Victoria", type: "Station", Latitude: 51.4964237195677, Longitude: -0.143920705126304, Zone: 1, Postcode: "SW1E 5JX", Note: "Tour Buckingham Palace and watch the Changing of the Guard on The Mall."}),
# (:Station {id: "St. James's Park", displayName: "St. James s Park", type: "Station", Latitude: 51.4996095777261, Longitude: -0.133878754341125, Zone: 1, Postcode: "SW1H 0BD", Note: "Walk through St James s Park to Buckingham Palace and watch the Changing of the Guard."}),
# (:Station {id: "Westminster", displayName: "Westminster", type: "Station", Latitude: 51.5014013891933, Longitude: -0.12500207834678, Zone: 1, Postcode: "SW1A 2JR", Note: "Marvel at the Houses of Parliament and Big Ben and visit Westminster Abbey."}),
# (:Station {id: "Temple", displayName: "Temple", type: "Station", Latitude: 51.5110404236047, Longitude: -0.113725749531254, Zone: 1, Postcode: "WC2R 2PH", Note: "Discover the historic Temple Church and stroll through Victoria Embankment Gardens."}),
# (:Station {id: "Blackfriars", displayName: "Blackfriars", type: "Station", Latitude: 51.511586761695, Longitude: -0.102995384624505, Zone: 1, Postcode: "EC4V 4DD", Note: "Cross the Blackfriars Bridge to the Tate Modern or explore the riverside walkways."}),
# (:Station {id: "Mansion House", displayName: "Mansion House", type: "Station", Latitude: 51.5120915984511, Longitude: -0.0941976572437842, Zone: 1, Postcode: "EC4N 6JD", Note: "See the Lord Mayor s official residence at Mansion House and walk to St Paul s Cathedral."}),
# (:Station {id: "Cannon Street", displayName: "Cannon Street", type: "Station", Latitude: 51.5113619437019, Longitude: -0.0902505264150348, Zone: 1, Postcode: "EC4N 6AP", Note: "See the medieval London Stone and explore the garden of St Stephen Walbrook church."}),
# (:Station {id: "Tower Hill", displayName: "Tower Hill", type: "Station", Latitude: 51.5103941502293, Longitude: -0.0767011981209769, Zone: 1, Postcode: "EC3N 4DJ", Note: "See the Crown Jewels at the Tower of London and join a Yeoman Warder tour."}),
# (:Station {id: "Aldgate East", displayName: "Aldgate East", type: "Station", Latitude: 51.5150815056987, Longitude: -0.0730014624207396, Zone: 1, Postcode: "E1 7PT", Note: "Head to Brick Lane for famous curry houses, vintage shops and colourful street art."}),
# (:Station {id: "Whitechapel", displayName: "Whitechapel", type: "Station", Latitude: 51.5195876908872, Longitude: -0.0594204849881092, Zone: 2, Postcode: "E1 1BY", Note: "See exhibitions at Whitechapel Gallery and eat along Brick Lane s curry mile."}),
# (:Station {id: "Stepney Green", displayName: "Stepney Green", type: "Station", Latitude: 51.5219957586155, Longitude: -0.0473825231948551, Zone: 2, Postcode: "E1 4AQ", Note: "Watch independent films at Genesis Cinema and meet animals at Stepney City Farm."}),
# (:Station {id: "Bow Road", displayName: "Bow Road", type: "Station", Latitude: 51.5270417695097, Longitude: -0.0243595906326814, Zone: 2, Postcode: "E3 4DH", Note: "Pop into the Bow Bells pub and learn local history at the Tower Hamlets Local History Library."}),
# (:Station {id: "Bromley-by-Bow", displayName: "Bromley-by-Bow", type: "Station", Latitude: 51.524840183700896, Longitude: -0.0116823743530454, Zone: 2, Postcode: "E3 3BT", Note: "See the 18th century House Mill and relax at Three Mills Green."}),
# (:Station {id: "West Ham", displayName: "West Ham", type: "Station", Latitude: 51.528525530727, Longitude: 0.0053173938327879, Zone: 3, Postcode: "E15 3BN", Note: "Cheer on West Ham United at the London Stadium and explore Queen Elizabeth Olympic Park."}),
# (:Station {id: "Plaistow", displayName: "Plaistow", type: "Station", Latitude: 51.5312883668178, Longitude: 0.0177806419969852, Zone: 3, Postcode: "E13 0DY", Note: "Swim at Newham Leisure Centre or relax in Plaistow Park."}),
# (:Station {id: "Upton Park", displayName: "Upton Park", type: "Station", Latitude: 51.53662825987809, Longitude: 0.0345418397236073, Zone: 3, Postcode: "E13 9AP", Note: "Browse Queen s Market on Green Street and remember the former Boleyn Ground."}),
# (:Station {id: "East Ham", displayName: "East Ham", type: "Station", Latitude: 51.5392462519437, Longitude: 0.0515162934805762, Zone: 3, Postcode: "E6 2JA", Note: "Visit the Grade II listed East Ham Town Hall and wander through Plashet Park."}),
# (:Station {id: "Barking", displayName: "Barking", type: "Station", Latitude: 51.5395212483974, Longitude: 0.0808316104030654, Zone: 4, Postcode: "IG11 8TU", Note: "Discover the medieval ruins of Barking Abbey and the Tudor Eastbury Manor House."}),
# (:Station {id: "Upney", displayName: "Upney", type: "Station", Latitude: 51.5384058166655, Longitude: 0.101531744664137, Zone: 4, Postcode: "IG11 9LS", Note: "Explore Eastbrookend Country Park and visit Barking Abbey remains nearby."}),
# (:Station {id: "Becontree", displayName: "Becontree", type: "Station", Latitude: 51.539585619744, Longitude: 0.126880292693594, Zone: 5, Postcode: "RM9 4TP", Note: "Check out the Valence House Museum and enjoy a stroll in Parsloes Park."}),
# (:Station {id: "Dagenham Heathway", displayName: "Dagenham Heathway", type: "Station", Latitude: 51.5412120355014, Longitude: 0.147679721474003, Zone: 5, Postcode: "RM9 5AN", Note: "Shop along Heathway or relax in Parsloes Park s open spaces."}),
# (:Station {id: "Dagenham East", displayName: "Dagenham East", type: "Station", Latitude: 51.5441876132896, Longitude: 0.165833433309167, Zone: 5, Postcode: "RM10 8AA", Note: "Spot wildlife in Beam Valley Country Park or stroll through The Chase Nature Reserve."}),
# (:Station {id: "Elm Park", displayName: "Elm Park", type: "Station", Latitude: 51.5491249099079, Longitude: 0.197252684283427, Zone: 6, Postcode: "RM12 4RW", Note: "Stroll around Harrow Lodge Park and the lake at this suburban stop."}),
# (:Station {id: "Hornchurch", displayName: "Hornchurch", type: "Station", Latitude: 51.55435547079, Longitude: 0.218926999411176, Zone: 6, Postcode: "RM12 6LS", Note: "Watch a play at the Queen s Theatre and walk around Hornchurch Country Park."}),
# (:Station {id: "Upminster Bridge", displayName: "Upminster Bridge", type: "Station", Latitude: 51.5577191878009, Longitude: 0.234541891929042, Zone: 6, Postcode: "RM12 6PL", Note: "Visit the restored Upminster Windmill and play at Upminster Golf Club."}),
# (:Station {id: "Upminster", displayName: "Upminster", type: "Station", Latitude: 51.5587637710015, Longitude: 0.251400804800992, Zone: 6, Postcode: "RM14 2TD", Note: "Tour the Upminster Windmill and the Tithe Barn Agricultural Museum."}),
# (:Station {id: "Moorgate", displayName: "Moorgate", type: "Station", Latitude: 51.5184369958311, Longitude: -0.0890176874196191, Zone: 1, Postcode: "EC2M 6TX", Note: "Tour the Guildhall Art Gallery or walk to the Museum of London at Barbican."}),
# (:Station {id: "Barbican", displayName: "Barbican", type: "Station", Latitude: 51.5202151261078, Longitude: -0.0977215780905023, Zone: 1, Postcode: "EC1A 4JA", Note: "Experience concerts, films and exhibitions at the Barbican Centre, Europe s largest arts venue."}),
# (:Station {id: "Farringdon", displayName: "Farringdon", type: "Station", Latitude: 51.5201955191978, Longitude: -0.104843061316764, Zone: 1, Postcode: "EC1M 6BY", Note: "Eat at historic Smithfield Market and explore the medieval Charterhouse complex."}),
# (:Station {id: "King's Cross St. Pancras", displayName: "King s Cross St. Pancras", type: "Station", Latitude: 51.5303122619463, Longitude: -0.123872128687034, Zone: 1, Postcode: "N1 9AL", Note: "Take a photo at Platform 9¾ and explore St Pancras International s Gothic architecture."}),
# (:Station {id: "Euston Square", displayName: "Euston Square", type: "Station", Latitude: 51.528664114832, Longitude: -0.133296470819151, Zone: 1, Postcode: "NW1 2BN", Note: "Discover exhibits at University College London and the Grant Museum of Zoology."}),
# (:Station {id: "Great Portland Street", displayName: "Great Portland Street", type: "Station", Latitude: 51.5237885627179, Longitude: -0.14396142408109, Zone: 1, Postcode: "W1W 5PP", Note: "Visit Regent s Park and the Royal Institute of British Architects on Portland Place."}),
# (:Station {id: "Royal Oak", displayName: "Royal Oak", type: "Station", Latitude: 51.5182940459234, Longitude: -0.188823671546854, Zone: 2, Postcode: "W2 6ET", Note: "nan"}),
# (:Station {id: "Westbourne Park", displayName: "Westbourne Park", type: "Station", Latitude: 51.5209885149093, Longitude: -0.200882512814746, Zone: 2, Postcode: "W11 1AB", Note: "nan"}),
# (:Station {id: "Ladbroke Grove", displayName: "Ladbroke Grove", type: "Station", Latitude: 51.5172103317528, Longitude: -0.210198169891793, Zone: 2, Postcode: "W10 6HJ", Note: "nan"}),
# (:Station {id: "Latimer Road", displayName: "Latimer Road", type: "Station", Latitude: 51.5139577448775, Longitude: -0.217459663317242, Zone: 2, Postcode: "W10 6SZ", Note: "nan"}),
# (:Station {id: "Wood Lane", displayName: "Wood Lane", type: "Station", Latitude: 51.5096578296917, Longitude: -0.224472605709939, Zone: 2, Postcode: "W12 7DS", Note: "nan"}),
# (:Station {id: "Shepherd's Bush Market", displayName: "Shepherd s Bush Market", type: "Station", Latitude: 51.5058803381902, Longitude: -0.227400490410209, Zone: 2, Postcode: "W12 7JD", Note: "nan"}),
# (:Station {id: "Goldhawk Road", displayName: "Goldhawk Road", type: "Station", Latitude: 51.5020765966368, Longitude: -0.227404003248823, Zone: 2, Postcode: "W12 8EG", Note: "nan"}),
# (:Station {id: "Aldgate", displayName: "Aldgate", type: "Station", Latitude: 51.5143422574978, Longitude: -0.0756269123224863, Zone: 1, Postcode: "EC3N 1AH", Note: "See the historic Aldgate Pump and visit the nearby Whitechapel Gallery for contemporary art."}),
# (:Station {id: "Canning Town", displayName: "Canning Town", type: "Station", Latitude: 51.5138703035051, Longitude: 0.0083056327487644, Zone: 3, Postcode: "E16 1DQ", Note: "Ride the Emirates Air Line cable car across the Thames or visit the Crystal sustainability exhibition."}),
# (:Station {id: "North Greenwich", displayName: "North Greenwich", type: "Station", Latitude: 51.5002551610895, Longitude: 0.0035862591259508, Zone: 2, Postcode: "SE10 0PH", Note: "Enjoy a concert at The O2 Arena or ride the Emirates Air Line cable car."}),
# (:Station {id: "Canary Wharf", displayName: "Canary Wharf", type: "Station", Latitude: 51.5035783751289, Longitude: -0.0194668401393244, Zone: 2, Postcode: "E14 4QS", Note: "Marvel at One Canada Square and wander through the Crossrail Place Roof Garden."}),
# (:Station {id: "Canada Water", displayName: "Canada Water", type: "Station", Latitude: 51.498168331250895, Longitude: -0.0508071208490972, Zone: 2, Postcode: "SE16 7BB", Note: "Read at the architecturally striking Canada Water Library or browse Surrey Quays Shopping Centre."}),
# (:Station {id: "Bermondsey", displayName: "Bermondsey", type: "Station", Latitude: 51.4979606775063, Longitude: -0.0643300898115236, Zone: 2, Postcode: "SE16 4RX", Note: "Explore Bermondsey Street s restaurants and the Fashion and Textile Museum."}),
# (:Station {id: "London Bridge", displayName: "London Bridge", type: "Station", Latitude: 51.5046742093043, Longitude: -0.0860055977481396, Zone: 1, Postcode: "SE1 2SW", Note: "Walk across London Bridge, explore The Shard and feast at Borough Market."}),
# (:Station {id: "Southwark", displayName: "Southwark", type: "Station", Latitude: 51.5038534497217, Longitude: -0.105794938925092, Zone: 1, Postcode: "SE1 8NW", Note: "Visit the Tate Modern and Shakespeare s Globe on the South Bank."}),
# (:Station {id: "Green Park", displayName: "Green Park", type: "Station", Latitude: 51.5067602537146, Longitude: -0.142477574422533, Zone: 1, Postcode: "W1J 7BX", Note: "Stroll through Green Park to Buckingham Palace or head to nearby Piccadilly."}),
# (:Station {id: "St. John's Wood", displayName: "St. John s Wood", type: "Station", Latitude: 51.5348541283933, Longitude: -0.17406483866207, Zone: 2, Postcode: "NW8 6DN", Note: "Watch a match at Lord s Cricket Ground and snap a photo at the Abbey Road crossing made famous by The Beatles."}),
# (:Station {id: "Swiss Cottage", displayName: "Swiss Cottage", type: "Station", Latitude: 51.5430345616616, Longitude: -0.175626602641138, Zone: 2, Postcode: "NW3 6HY", Note: "See a play at the Hampstead Theatre and swim at Swiss Cottage Leisure Centre."}),
# (:Station {id: "Finchley Road", displayName: "Finchley Road", type: "Station", Latitude: 51.5470959064344, Longitude: -0.180050558632494, Zone: 2, Postcode: "NW6 3BS", Note: "Shop and dine at the O2 Centre or walk to Freud Museum London."}),
# (:Station {id: "West Hampstead", displayName: "West Hampstead", type: "Station", Latitude: 51.5474740226727, Longitude: -0.191126583443095, Zone: 2, Postcode: "NW6 2LX", Note: "Dine and drink along West End Lane and visit Hampstead Theatre and nearby parks."}),
# (:Station {id: "Kilburn", displayName: "Kilburn", type: "Station", Latitude: 51.546944102866, Longitude: -0.204632716699255, Zone: 2, Postcode: "NW6 7QL", Note: "Watch a play at the Kiln Theatre (formerly Tricycle) and stroll along Kilburn High Road."}),
# (:Station {id: "Willesden Green", displayName: "Willesden Green", type: "Station", Latitude: 51.549372924827, Longitude: -0.222407601249647, Zone: 2, Postcode: "NW2 4QT", Note: "Explore Willesden Green Library and relax in Gladstone Park."}),
# (:Station {id: "Dollis Hill", displayName: "Dollis Hill", type: "Station", Latitude: 51.5518502022743, Longitude: -0.238797758364758, Zone: 3, Postcode: "NW10 5NB", Note: "Enjoy the open lawns, woods and rose garden in Gladstone Park."}),
# (:Station {id: "Neasden", displayName: "Neasden", type: "Station", Latitude: 51.5546273100412, Longitude: -0.250115041693612, Zone: 3, Postcode: "NW10 1PH", Note: "Marvel at the ornate Shri Swaminarayan Mandir (Neasden Temple)."}),
# (:Station {id: "Wembley Park", displayName: "Wembley Park", type: "Station", Latitude: 51.5633220034916, Longitude: -0.279242548111157, Zone: 4, Postcode: "HA9 9AA", Note: "Walk to Wembley Stadium and explore the colourful Wembley Park development with its art trail."}),
# (:Station {id: "Kingsbury", displayName: "Kingsbury", type: "Station", Latitude: 51.5848760634912, Longitude: -0.278601603713172, Zone: 4, Postcode: "NW9 9EG", Note: "Relax in Roe Green Park or watch a match at Silver Jubilee Park."}),
# (:Station {id: "Queensbury", displayName: "Queensbury", type: "Station", Latitude: 51.5938825093133, Longitude: -0.286331592620629, Zone: 4, Postcode: "HA8 5NP", Note: "Relax in Queensbury Park and visit Little Stanmore church to see Handel s organ."}),
# (:Station {id: "Canons Park", displayName: "Canons Park", type: "Station", Latitude: 51.6076500902854, Longitude: -0.294391591494146, Zone: 5, Postcode: "HA8 6RN", Note: "Stroll through the landscaped Canons Park and visit The Hive, home of Barnet F.C."}),
# (:Station {id: "Stanmore", displayName: "Stanmore", type: "Station", Latitude: 51.6196729504836, Longitude: -0.303099287595299, Zone: 5, Postcode: "HA7 4PD", Note: "Visit Bentley Priory Museum and stroll through Stanmore Country Park."}),
# (:Station {id: "Preston Road", displayName: "Preston Road", type: "Station", Latitude: 51.5721032477993, Longitude: -0.294972007483067, Zone: 4, Postcode: "HA3 0PS", Note: "nan"}),
# (:Station {id: "Northwick Park", displayName: "Northwick Park", type: "Station", Latitude: 51.578508169653, Longitude: -0.318199386013369, Zone: 4, Postcode: "HA3 0AT", Note: "Visit Northwick Park Hospital or play sports at the adjacent playing fields."}),
# (:Station {id: "Harrow-on-the-Hill", displayName: "Harrow-on-the-Hill", type: "Station", Latitude: 51.5793875695421, Longitude: -0.337001510706096, Zone: 5, Postcode: "HA1 1BB", Note: "Visit Harrow School and enjoy views from the village on the hill."}),
# (:Station {id: "North Harrow", displayName: "North Harrow", type: "Station", Latitude: 51.5846307078439, Longitude: -0.362632985599068, Zone: 5, Postcode: "HA2 7SR", Note: "Visit Headstone Manor and Museum or play a round at the Harrow Golf Course."}),
# (:Station {id: "Pinner", displayName: "Pinner", type: "Station", Latitude: 51.5923610566072, Longitude: -0.38122378173761, Zone: 5, Postcode: "HA5 5LZ", Note: "Stroll down Pinner s medieval high street and visit the Heath Robinson Museum."}),
# (:Station {id: "Northwood Hills", displayName: "Northwood Hills", type: "Station", Latitude: 51.6008019779143, Longitude: -0.409311348056893, Zone: 6, Postcode: "HA6 1NZ", Note: "Play golf at Haste Hill Golf Club and enjoy a pint at the Case Is Altered pub."}),
# (:Station {id: "Northwood", displayName: "Northwood", type: "Station", Latitude: 51.6112129195814, Longitude: -0.423837776195818, Zone: 6, Postcode: "HA6 2XL", Note: "Walk in Ruislip Woods National Nature Reserve or tee off at Northwood Golf Club."}),
# (:Station {id: "Moor Park", displayName: "Moor Park", type: "Station", Latitude: 51.6299299595336, Longitude: -0.432913016495897, Zone: 6, Postcode: "HA6 2JQ", Note: "Tee off at Moor Park Golf Club and wander through the estate s woodland."}),
# (:Station {id: "Croxley", displayName: "Croxley", type: "Station", Latitude: 51.6470045601112, Longitude: -0.441603786877926, Zone: 7, Postcode: "WD3 3DY", Note: "Walk along the Grand Union Canal or relax in Cassiobury Park nearby."}),
# (:Station {id: "Watford", displayName: "Watford", type: "Station", Latitude: 51.6576044159566, Longitude: -0.417269996729954, Zone: 7, Postcode: "WD18 7LE", Note: "Explore Cassiobury Park, visit Watford Museum and travel to the Warner Bros. Studio Tour nearby."}),
# (:Station {id: "Rickmansworth", displayName: "Rickmansworth", type: "Station", Latitude: 51.640322241933696, Longitude: -0.473684571012875, Zone: 7, Postcode: "WD3 1QY", Note: "Visit the wetlands of Rickmansworth Aquadrome and cruise along the Grand Union Canal."}),
# (:Station {id: "Chorleywood", displayName: "Chorleywood", type: "Station", Latitude: 51.6542650809277, Longitude: -0.518333910857157, Zone: 7, Postcode: "WD3 5ND", Note: "Enjoy a walk across Chorleywood Common and the surrounding Chilterns countryside."}),
# (:Station {id: "Chalfont & Latimer", displayName: "Chalfont & Latimer", type: "Station", Latitude: 51.6679065638921, Longitude: -0.561067758943182, Zone: 8, Postcode: "HP7 9PR", Note: "Discover the Chiltern Open Air Museum and quaint villages like Chalfont St Giles."}),
# (:Station {id: "Chesham", displayName: "Chesham", type: "Station", Latitude: 51.7053790233013, Longitude: -0.611429635297931, Zone: 9, Postcode: "HP5 1DH", Note: "nan"}),
# (:Station {id: "Amersham", displayName: "Amersham", type: "Station", Latitude: 51.674128328342704, Longitude: -0.606513767877791, Zone: 9, Postcode: "HP6 5AZ", Note: "Wander through the picturesque old town of Amersham and the surrounding Chiltern Hills."}),
# (:Station {id: "West Harrow", displayName: "West Harrow", type: "Station", Latitude: 51.5789236612617, Longitude: -0.353846689868431, Zone: 5, Postcode: "HA1 4HE", Note: "Stroll around Harrow Recreation Ground and visit St Peter s Church."}),
# (:Station {id: "Rayners Lane", displayName: "Rayners Lane", type: "Station", Latitude: 51.575396127388494, Longitude: -0.371060805748711, Zone: 5, Postcode: "HA5 5EG", Note: "Admire the station s Art Deco architecture and walk in Roxbourne Park."}),
# (:Station {id: "Eastcote", displayName: "Eastcote", type: "Station", Latitude: 51.5765511761409, Longitude: -0.396823290149802, Zone: 5, Postcode: "HA5 1QZ", Note: "Relax in Eastcote House Gardens with its walled garden and dovecote."}),
# (:Station {id: "Ruislip Manor", displayName: "Ruislip Manor", type: "Station", Latitude: 51.5734509011491, Longitude: -0.412849344431848, Zone: 6, Postcode: "HA4 9AA", Note: "Explore Manor Farm heritage site and browse Ruislip Manor Library."}),
# (:Station {id: "Ruislip", displayName: "Ruislip", type: "Station", Latitude: 51.5721612338762, Longitude: -0.421234915592132, Zone: 6, Postcode: "HA4 8LD", Note: "Swim at Ruislip Lido and take a ride on the miniature railway through the woods."}),
# (:Station {id: "Ickenham", displayName: "Ickenham", type: "Station", Latitude: 51.560824332912, Longitude: -0.441579501268799, Zone: 6, Postcode: "UB10 8PD", Note: "Visit Ickenham Pump and stroll around Swakeleys Park and its lake."}),
# (:Station {id: "Hillingdon", displayName: "Hillingdon", type: "Station", Latitude: 51.553776781763695, Longitude: -0.449897981623021, Zone: 6, Postcode: "UB10 9NR", Note: "Relax in Hillingdon Court Park or cycle along the Hillingdon Trail."}),
# (:Station {id: "Uxbridge", displayName: "Uxbridge", type: "Station", Latitude: 51.5464537278672, Longitude: -0.477101546420975, Zone: 6, Postcode: "UB8 1JZ", Note: "Visit the Battle of Britain Bunker and walk along the Grand Union Canal."}),
# (:Station {id: "Morden", displayName: "Morden", type: "Station", Latitude: 51.4021856447495, Longitude: -0.194851979519044, Zone: 4, Postcode: "SM4 5AZ", Note: "Relax in National Trust run Morden Hall Park with its historic mills."}),
# (:Station {id: "South Wimbledon", displayName: "South Wimbledon", type: "Station", Latitude: 51.4153603977999, Longitude: -0.191974544099057, Zone: 3, Postcode: "SW19 1DE", Note: "Shop and eat at Merton Abbey Mills and follow the Wandle Trail."}),
# (:Station {id: "Colliers Wood", displayName: "Colliers Wood", type: "Station", Latitude: 51.4187588995297, Longitude: -0.177415098049605, Zone: 3, Postcode: "SW19 2HR", Note: "Explore the craft stalls at Merton Abbey Mills and stroll along the Wandle Trail."}),
# (:Station {id: "Tooting Broadway", displayName: "Tooting Broadway", type: "Station", Latitude: 51.4270488709259, Longitude: -0.16868452577766, Zone: 3, Postcode: "SW17 0SU", Note: "Sample street food at Tooting Market and admire the art deco Gala Bingo hall."}),
# (:Station {id: "Tooting Bec", displayName: "Tooting Bec", type: "Station", Latitude: 51.435837804955504, Longitude: -0.159700490831738, Zone: 3, Postcode: "SW17 9AH", Note: "Take a dip in Tooting Bec Lido and enjoy the green space of Tooting Common."}),
# (:Station {id: "Balham", displayName: "Balham", type: "Station", Latitude: 51.443182314397, Longitude: -0.152685161993261, Zone: 3, Postcode: "SW12 9SG", Note: "Sample global food at Hildreth Street Market or catch live music at The Bedford pub."}),
# ...
# MATCH (source {id: "Finchley Central"}), (target {id: "West Finchley"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:943}]->(target)
# MATCH (source {id: "Finchley Central"}), (target {id: "East Finchley"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:1837}]->(target)
# MATCH (source {id: "Mill Hill East"}), (target {id: "Finchley Central"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:1027}]->(target)
# MATCH (source {id: "West Finchley"}), (target {id: "Woodside Park"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:966}]->(target)
# MATCH (source {id: "West Finchley"}), (target {id: "Finchley Central"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:943}]->(target)
# MATCH (source {id: "Woodside Park"}), (target {id: "Totteridge & Whetstone"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:1395}]->(target)
# MATCH (source {id: "Woodside Park"}), (target {id: "West Finchley"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:966}]->(target)
# MATCH (source {id: "Totteridge & Whetstone"}), (target {id: "High Barnet"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:2448}]->(target)
# MATCH (source {id: "Totteridge & Whetstone"}), (target {id: "Woodside Park"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:1395}]->(target)
# MATCH (source {id: "High Barnet"}), (target {id: "Totteridge & Whetstone"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:2448}]->(target)
# MATCH (source {id: "Chalk Farm"}), (target {id: "Belsize Park"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:770}]->(target)
# MATCH (source {id: "Chalk Farm"}), (target {id: "Camden Town"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:623}]->(target)
# MATCH (source {id: "Belsize Park"}), (target {id: "Hampstead"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:875}]->(target)
# MATCH (source {id: "Belsize Park"}), (target {id: "Chalk Farm"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:770}]->(target)
# MATCH (source {id: "Hampstead"}), (target {id: "Golders Green"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:1850}]->(target)
# MATCH (source {id: "Hampstead"}), (target {id: "Belsize Park"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:875}]->(target)
# MATCH (source {id: "Golders Green"}), (target {id: "Brent Cross"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:836}]->(target)
# MATCH (source {id: "Golders Green"}), (target {id: "Hampstead"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:1850}]->(target)
# MATCH (source {id: "Brent Cross"}), (target {id: "Hendon Central"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:878}]->(target)
# MATCH (source {id: "Brent Cross"}), (target {id: "Golders Green"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:836}]->(target)
# MATCH (source {id: "Hendon Central"}), (target {id: "Colindale"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:1600}]->(target)
# MATCH (source {id: "Hendon Central"}), (target {id: "Brent Cross"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:878}]->(target)
# MATCH (source {id: "Colindale"}), (target {id: "Burnt Oak"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:964}]->(target)
# MATCH (source {id: "Colindale"}), (target {id: "Hendon Central"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:1600}]->(target)
# MATCH (source {id: "Burnt Oak"}), (target {id: "Edgware"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:1358}]->(target)
# MATCH (source {id: "Burnt Oak"}), (target {id: "Colindale"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:964}]->(target)
# MATCH (source {id: "Edgware"}), (target {id: "Burnt Oak"}) CREATE (source)-[:CONNECTION {Line:"Northern", DistanceMeters:1358}]->(target)
# MATCH (source {id: "South Harrow"}), (target {id: "Sudbury Hill"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:995}]->(target)
# MATCH (source {id: "South Harrow"}), (target {id: "Rayners Lane"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1385}]->(target)
# MATCH (source {id: "Sudbury Hill"}), (target {id: "Sudbury Town"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:989}]->(target)
# MATCH (source {id: "Sudbury Hill"}), (target {id: "South Harrow"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:995}]->(target)
# MATCH (source {id: "Sudbury Town"}), (target {id: "Alperton"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1291}]->(target)
# MATCH (source {id: "Sudbury Town"}), (target {id: "Sudbury Hill"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:989}]->(target)
# MATCH (source {id: "Alperton"}), (target {id: "Park Royal"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1687}]->(target)
# MATCH (source {id: "Alperton"}), (target {id: "Sudbury Town"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1291}]->(target)
# MATCH (source {id: "Park Royal"}), (target {id: "North Ealing"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1036}]->(target)
# MATCH (source {id: "Park Royal"}), (target {id: "Alperton"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1687}]->(target)
# MATCH (source {id: "North Ealing"}), (target {id: "Ealing Common"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:823}]->(target)
# MATCH (source {id: "North Ealing"}), (target {id: "Park Royal"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1036}]->(target)
# MATCH (source {id: "Heathrow Terminal 5"}), (target {id: "Heathrow Terminals 1 2 3"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1411}]->(target)
# MATCH (source {id: "Heathrow Terminals 1 2 3"}), (target {id: "Hatton Cross"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1183}]->(target)
# MATCH (source {id: "Heathrow Terminals 1 2 3"}), (target {id: "Heathrow Terminal 5"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1411}]->(target)
# MATCH (source {id: "Heathrow Terminal 4"}), (target {id: "Heathrow Terminals 1 2 3"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1292}]->(target)
# MATCH (source {id: "Hatton Cross"}), (target {id: "Hounslow West"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1557}]->(target)
# MATCH (source {id: "Hatton Cross"}), (target {id: "Heathrow Terminal 4"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1179}]->(target)
# MATCH (source {id: "Hatton Cross"}), (target {id: "Heathrow Terminals 1 2 3"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1183}]->(target)
# MATCH (source {id: "Hounslow West"}), (target {id: "Hounslow Central"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:764}]->(target)
# MATCH (source {id: "Hounslow West"}), (target {id: "Hatton Cross"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1557}]->(target)
# MATCH (source {id: "Hounslow Central"}), (target {id: "Hounslow East"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:499}]->(target)
# MATCH (source {id: "Hounslow Central"}), (target {id: "Hounslow West"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:764}]->(target)
# MATCH (source {id: "Hounslow East"}), (target {id: "Osterley"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:844}]->(target)
# MATCH (source {id: "Hounslow East"}), (target {id: "Hounslow Central"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:499}]->(target)
# MATCH (source {id: "Osterley"}), (target {id: "Boston Manor"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1905}]->(target)
# MATCH (source {id: "Osterley"}), (target {id: "Hounslow East"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:844}]->(target)
# MATCH (source {id: "Boston Manor"}), (target {id: "Northfields"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:635}]->(target)
# MATCH (source {id: "Boston Manor"}), (target {id: "Osterley"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1905}]->(target)
# MATCH (source {id: "Northfields"}), (target {id: "South Ealing"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:321}]->(target)
# MATCH (source {id: "Northfields"}), (target {id: "Boston Manor"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:635}]->(target)
# MATCH (source {id: "South Ealing"}), (target {id: "Acton Town"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:994}]->(target)
# MATCH (source {id: "South Ealing"}), (target {id: "Northfields"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:321}]->(target)
# MATCH (source {id: "Knightsbridge"}), (target {id: "Hyde Park Corner"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:330}]->(target)
# MATCH (source {id: "Knightsbridge"}), (target {id: "South Kensington"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:945}]->(target)
# MATCH (source {id: "Hyde Park Corner"}), (target {id: "Green Park"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:592}]->(target)
# MATCH (source {id: "Hyde Park Corner"}), (target {id: "Knightsbridge"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:330}]->(target)
# MATCH (source {id: "Covent Garden"}), (target {id: "Holborn"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:526}]->(target)
# MATCH (source {id: "Covent Garden"}), (target {id: "Leicester Square"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:213}]->(target)
# MATCH (source {id: "Russell Square"}), (target {id: "King's Cross St. Pancras"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:813}]->(target)
# MATCH (source {id: "Russell Square"}), (target {id: "Holborn"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:666}]->(target)
# MATCH (source {id: "Caledonian Road"}), (target {id: "Holloway Road"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:583}]->(target)
# MATCH (source {id: "Caledonian Road"}), (target {id: "King's Cross St. Pancras"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1966}]->(target)
# MATCH (source {id: "Holloway Road"}), (target {id: "Arsenal"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:693}]->(target)
# MATCH (source {id: "Holloway Road"}), (target {id: "Caledonian Road"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:583}]->(target)
# MATCH (source {id: "Arsenal"}), (target {id: "Finsbury Park"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:678}]->(target)
# MATCH (source {id: "Arsenal"}), (target {id: "Holloway Road"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:693}]->(target)
# MATCH (source {id: "Finsbury Park"}), (target {id: "Manor House"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:776}]->(target)
# MATCH (source {id: "Finsbury Park"}), (target {id: "Arsenal"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:678}]->(target)
# MATCH (source {id: "Finsbury Park"}), (target {id: "Seven Sisters"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:2419}]->(target)
# MATCH (source {id: "Finsbury Park"}), (target {id: "Highbury & Islington"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:2020}]->(target)
# MATCH (source {id: "Manor House"}), (target {id: "Turnpike Lane"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:2198}]->(target)
# MATCH (source {id: "Manor House"}), (target {id: "Finsbury Park"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:776}]->(target)
# MATCH (source {id: "Turnpike Lane"}), (target {id: "Wood Green"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:827}]->(target)
# MATCH (source {id: "Turnpike Lane"}), (target {id: "Manor House"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:2198}]->(target)
# MATCH (source {id: "Wood Green"}), (target {id: "Bounds Green"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1194}]->(target)
# MATCH (source {id: "Wood Green"}), (target {id: "Turnpike Lane"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:827}]->(target)
# MATCH (source {id: "Bounds Green"}), (target {id: "Arnos Grove"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1088}]->(target)
# MATCH (source {id: "Bounds Green"}), (target {id: "Wood Green"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1194}]->(target)
# MATCH (source {id: "Arnos Grove"}), (target {id: "Southgate"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1813}]->(target)
# MATCH (source {id: "Arnos Grove"}), (target {id: "Bounds Green"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1088}]->(target)
# MATCH (source {id: "Southgate"}), (target {id: "Oakwood"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1705}]->(target)
# MATCH (source {id: "Southgate"}), (target {id: "Arnos Grove"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1813}]->(target)
# MATCH (source {id: "Oakwood"}), (target {id: "Cockfosters"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:823}]->(target)
# MATCH (source {id: "Oakwood"}), (target {id: "Southgate"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:1705}]->(target)
# MATCH (source {id: "Cockfosters"}), (target {id: "Oakwood"}) CREATE (source)-[:CONNECTION {Line:"Piccadilly", DistanceMeters:823}]->(target)
# MATCH (source {id: "Brixton"}), (target {id: "Stockwell"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:1092}]->(target)
# MATCH (source {id: "Vauxhall"}), (target {id: "Pimlico"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:544}]->(target)
# MATCH (source {id: "Vauxhall"}), (target {id: "Stockwell"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:1511}]->(target)
# MATCH (source {id: "Pimlico"}), (target {id: "Victoria"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:861}]->(target)
# MATCH (source {id: "Pimlico"}), (target {id: "Vauxhall"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:544}]->(target)
# MATCH (source {id: "Highbury & Islington"}), (target {id: "Finsbury Park"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:2020}]->(target)
# MATCH (source {id: "Highbury & Islington"}), (target {id: "King's Cross St. Pancras"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:1942}]->(target)
# MATCH (source {id: "Seven Sisters"}), (target {id: "Tottenham Hale"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:685}]->(target)
# MATCH (source {id: "Seven Sisters"}), (target {id: "Finsbury Park"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:2419}]->(target)
# MATCH (source {id: "Tottenham Hale"}), (target {id: "Blackhorse Road"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:794}]->(target)
# MATCH (source {id: "Tottenham Hale"}), (target {id: "Seven Sisters"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:685}]->(target)
# MATCH (source {id: "Blackhorse Road"}), (target {id: "Walthamstow Central"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:785}]->(target)
# MATCH (source {id: "Blackhorse Road"}), (target {id: "Tottenham Hale"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:794}]->(target)
# MATCH (source {id: "Walthamstow Central"}), (target {id: "Blackhorse Road"}) CREATE (source)-[:CONNECTION {Line:"Victoria", DistanceMeters:785}]->(target)
# ****************************************************************************************************
#
# CPU times: user 15.9 ms, sys: 0 ns, total: 15.9 ms
# Wall time: 15.5 ms

# %% [markdown]
# ## Split command into chunks

# %%
# %%time

chunks = split_cypher_commands(graph_CREATE_command, max_size_mb=1)

print(f"✓ Split into {len(chunks['node_chunks'])} node chunk(s) and {len(chunks['edge_chunks'])} edge chunk(s)")

print("\nNode chunks:")
for i, chunk in enumerate(chunks['node_chunks']):
    print(f"  Node chunk {i+1}: {len(chunk.encode('utf-8'))/1024:.1f} KB")
    if i == 10:
        print("  ...")
        break
        
print("\nEdge chunks:")
for i, chunk in enumerate(chunks['edge_chunks']):
    print(f"  Edge chunk {i+1}: {len(chunk.encode('utf-8'))/1024:.1f} KB")
    if i == 10:
        print("  ...")
        break
# Out:
# ✓ Split into 1 node chunk(s) and 614 edge chunk(s)
#
# Node chunks:
#   Node chunk 1: 65.3 KB
#
# Edge chunks:
#   Edge chunk 1: 0.1 KB
#   Edge chunk 2: 0.1 KB
#   Edge chunk 3: 0.1 KB
#   Edge chunk 4: 0.1 KB
#   Edge chunk 5: 0.1 KB
#   Edge chunk 6: 0.1 KB
#   Edge chunk 7: 0.1 KB
#   Edge chunk 8: 0.1 KB
#   Edge chunk 9: 0.1 KB
#   Edge chunk 10: 0.1 KB
#   Edge chunk 11: 0.1 KB
#   ...
# CPU times: user 9.35 ms, sys: 907 μs, total: 10.3 ms
# Wall time: 9.92 ms

# %% [markdown]
# # Create graph using `turingdb` python package

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         See <a href="https://docs.turingdb.ai/quickstart">TuringDB Get started documentation</a> for the important steps to follow :
#     </h2>
#     <h4>
#         <ul>
#             <li>Create your TuringDB account</li>
#             <li>Create your instance in the <a href="https://console.turingdb.ai/auth">TuringDB Cloud UI</a></li>
#             <li>Copy your Instance ID from the Database Instances management page</li>
#             <li>Get API Key from the Settings in UI</li>
#         </ul>
#         Remember to have your instance active while working in this notebook !
#     </h4>
# </div>

# %%
from turingdb import TuringDB

# Create TuringDB client
# set host parameter to the URL (as string) on which TuringDB is running,
# default "http://localhost:6666"
client = TuringDB(host="http://localhost:6666")
try:
    client.warmup()
except Exception as e:
    print(f"TuringDB not started, please run `uv run turingdb` in your terminal")

# %%
# Get list of available graphs
list_graphs = client.list_available_graphs()

# %%
# Get list of loaded graphs
#client.list_loaded_graphs()

# %%
# Set graph name
graph_name_prefix = example_name
graph_name_nb_suffix = str(
    max(
        [
            int(re.sub(graph_name_prefix, "", g))
            for g in list_graphs
            if g.startswith(graph_name_prefix)
            and re.sub(graph_name_prefix, "", g).isdigit()
        ]
        + [0]
    )
    + 1
)
graph_name = graph_name_prefix + graph_name_nb_suffix
graph_name = re.sub("-", "_", graph_name)
graph_name
# Out:
# 'london_transport_TfL2'

# %%
from turingdb.exceptions import TuringDBException

# %%
# %%time

# Set graph
try:
    client.create_graph(graph_name)
except TuringDBException as e:
    print(e)

# Set working graph
client.set_graph(graph_name)
# Out:
# CPU times: user 1.07 ms, sys: 2.52 ms, total: 3.59 ms
# Wall time: 9.99 ms

# %%
# %%time

# Create a new change on the graph
change = client.new_change()
print(f"Current change {change}")

# Checkout into the change
client.checkout(change=change)
# Out:
# Current change 0
# CPU times: user 3.51 ms, sys: 0 ns, total: 3.51 ms
# Wall time: 3.34 ms

# %%
# %%time

# Run CREATE command
print("\nExecuting query on TuringDB...")
start_time = time.time()

print(f"✓ Split into {len(chunks['node_chunks'])} node chunk(s) and {len(chunks['edge_chunks'])} edge chunk(s)")

# CREATE nodes
print("\nNode chunks:")
for i, chunk in enumerate(tqdm(chunks['node_chunks'])):
    result = client.query(chunk)
# Commit the change
client.query("COMMIT")
print(f"✓ {len(chunks['node_chunks'])} node chunks done")

# CREATE edges
print("\nEdge chunks:")
for i, chunk in enumerate(tqdm(chunks['edge_chunks'])):
    result = client.query(chunk)
# Commit the change
client.query("COMMIT")
print(f"✓ {len(chunks['edge_chunks'])} edge chunks done")

execution_time = time.time() - start_time
print(f"\n✓ Graph created successfully in {execution_time:.2f} seconds")

# Submit changes
start_time = time.time()
client.query("CHANGE SUBMIT")
execution_time = time.time() - start_time
print(f"\n✓ Changes successfully submitted in {execution_time:.2f} seconds")

# Checkout into main
client.checkout()
# Out:
# Executing query on TuringDB...
# ✓ Split into 1 node chunk(s) and 614 edge chunk(s)
#
# Node chunks:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✓ 1 node chunks done
#
# Edge chunks:
#   0%|          | 0/614 [00:00<?, ?it/s]
# ✓ 614 edge chunks done
#
# ✓ Graph created successfully in 0.61 seconds
#
# ✓ Changes successfully submitted in 0.08 seconds
# CPU times: user 512 ms, sys: 43 ms, total: 555 ms
# Wall time: 689 ms

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         Visualize your graph in TuringDB Graph Visualizer ! Now that your instance is running:
#     </h2>
#     <h3>
#         <ul>
#             <li>Go to <a href="https://console.turingdb.ai/databases">TuringDB Console - Database Instances</a></li>
#             <li>In your current instance panel, click on "Open Visualizer" button</li>
#             <li>Visualizer opens, now you can choose your graph in the dropdown menu at the top-right corner</li>
#         </ul>
#         You can then play with your graph and visualize the nodes you want !
#     </h3>
# </div>

# %% [markdown]
# # Query TuringDB

# %% [markdown]
# ## Use metaqueries to have insight on graph overall structure
#
# <h3>
#     To learn more about 📮 Metaqueries, please check TuringDB documentation on this <a href="https://turingdb.mintlify.app/query/cypher_subset#%F0%9F%93%AE-metaqueries">link</a>
# </h3>

# %%
# %%time

# CALL propertyTypes() - returns a column of all the different node and edge properties and their types in the database
command = """
CALL db.propertyTypes()
"""
df_propertyTypes = client.query(command)
if df_propertyTypes.empty:
    print("No result found")
else:
    display(df_propertyTypes)
# Out:
#   id    propertyType valueType
# 0  0            Note    String
# 1  1            Zone     Int64
# 2  2       Longitude    Double
# 3  3        Latitude    Double
# 4  4            type    String
# 5  5     displayName    String
# 6  6        Postcode    String
# 7  7              id    String
# 8  8  DistanceMeters     Int64
# 9  9            Line    String
# CPU times: user 7.43 ms, sys: 1.83 ms, total: 9.27 ms
# Wall time: 8.25 ms

# %%
# Get node properties
nodes_properties = df_propertyTypes["propertyType"].values.tolist()
print(f"Node properties: {nodes_properties}")
# Out:
# Node properties: ['Note', 'Zone', 'Longitude', 'Latitude', 'type', 'displayName', 'Postcode', 'id', 'DistanceMeters', 'Line']

# %%
# %%time

# CALL labels () - returns a column of all the different node labels
command = """
CALL db.labels()
"""
df_labels = client.query(command)
if df_labels.empty:
    print("No result found")
else:
    display(df_labels)
# Out:
#    id    label
# 0   0  Station
# CPU times: user 7.09 ms, sys: 1.01 ms, total: 8.1 ms
# Wall time: 7.36 ms

# %%
# %%time

# CALL edgeTypes() - returns a column of all the different edge types (edge equivalent of node labels)
command = """
CALL db.edgeTypes()
"""
df_edgeTypes = client.query(command)
if df_edgeTypes.empty:
    print("No result found")
else:
    display(df_edgeTypes)
# Out:
#    id    edgeType
# 0   0  CONNECTION
# CPU times: user 7.68 ms, sys: 91 μs, total: 7.77 ms
# Wall time: 7.14 ms

# %% [markdown]
# ## Counts

# %%
# %%time

# Find number of nodes and number of edges in the graph
n_nodes = len(client.query("MATCH (n) RETURN n"))
n_edges = len(client.query("MATCH (n)-->(m) RETURN n, m"))
print(f"Graph: {n_nodes:,} nodes and {n_edges:,} edges")
# Out:
# Graph: 266 nodes and 614 edges
# CPU times: user 5.75 ms, sys: 1.11 ms, total: 6.86 ms
# Wall time: 5.84 ms

# %%
# %%time

# Count all nodes
command = """
MATCH (n)
RETURN COUNT(n)
"""
df_count_nodes = client.query(command)
display(df_count_nodes)

# Count all edges
command = """
MATCH (n)-->()
RETURN COUNT(n)
"""
df_count_edges = client.query(command)
display(df_count_edges)

# Find number of nodes and number of edges in the graph
n_nodes = int(df_count_nodes.loc[0, "COUNT(n)"])
n_edges = int(df_count_edges.loc[0, "COUNT(n)"])
print(f"Graph: {n_nodes:,} nodes and {n_edges:,} edges")
# Out:
#    COUNT(n)
# 0       266
#    COUNT(n)
# 0       614
# Graph: 266 nodes and 614 edges
# CPU times: user 13.4 ms, sys: 2.05 ms, total: 15.4 ms
# Wall time: 13.9 ms

# %%
# Count number of nodes for each label
for label in df_labels["label"]:
    print(100 * '-')
    print(f"label: {label}")
    df_curr_label = client.query(f"""
    MATCH (n:{label})
    RETURN n.displayName
    """)
    df_curr_label_count = client.query(f"""
    MATCH (n:{label})
    RETURN count(n)
    """)
    display(df_curr_label)
    display(df_curr_label_count)
    
    print()
print(100 * '-')
# Out:
# ----------------------------------------------------------------------------------------------------
# label: Station
#        n.displayName
# 0    Northwood Hills
# 1          Northwood
# 2          Moor Park
# 3            Croxley
# 4            Watford
# ..               ...
# 261   Wimbledon Park
# 262        Wimbledon
# 263     Earl s Court
# 264  West Kensington
# 265     Barons Court
#
# [266 rows x 1 columns]
#    count(n)
# 0       266
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Queries

# %%
# %%time

# Match all edges and return them - all links between two stations
command = """
MATCH (n)-[e]->(m)
RETURN n.displayName, e.Line, m.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#        n.displayName        e.Line    m.displayName
# 0    Northwood Hills  Metropolitan        Northwood
# 1    Northwood Hills  Metropolitan           Pinner
# 2          Northwood  Metropolitan        Moor Park
# 3          Northwood  Metropolitan  Northwood Hills
# 4          Moor Park  Metropolitan          Croxley
# ..               ...           ...              ...
# 609  West Kensington      District     Earl s Court
# 610  West Kensington      District     Barons Court
# 611     Barons Court      District  West Kensington
# 612     Barons Court    Piccadilly      Hammersmith
# 613     Barons Court    Piccadilly     Earl s Court
#
# [614 rows x 3 columns]
# CPU times: user 9.43 ms, sys: 1.92 ms, total: 11.3 ms
# Wall time: 10.4 ms

# %%
# %%time

# Check if there exists a path between Hoxton Station and South Kensington in 1 hop
command = """
MATCH (departure)-[link]->(arrival)
WHERE departure.displayName = 'Hoxton Station'
AND arrival.displayName = 'South Kensington'
RETURN departure.displayName, link, arrival.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
# No result found
# CPU times: user 3.66 ms, sys: 0 ns, total: 3.66 ms
# Wall time: 3.31 ms

# %%
# %%time

# Check if there exists a path between Blackfriars and Mansion House in 1 hop
command = """
MATCH (departure)-[link]->(arrival)
WHERE departure.displayName = 'Blackfriars'
AND arrival.displayName = 'Mansion House'
RETURN departure.displayName, link.Line, link.DistanceMeters, arrival.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#   departure.displayName link.Line  link.DistanceMeters arrival.displayName
# 0           Blackfriars    Circle                  328       Mansion House
# CPU times: user 8.78 ms, sys: 964 μs, total: 9.75 ms
# Wall time: 8.99 ms

# %%
# %%time

# Check if there exists a path between Victoria and South Kensington in 2 hops
command = """
MATCH (departure)-->(intermediate)-->(arrival)
WHERE departure.displayName = 'Victoria'
AND arrival.displayName = 'South Kensington'
RETURN departure.displayName, intermediate.displayName, arrival.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#   departure.displayName intermediate.displayName arrival.displayName
# 0              Victoria            Sloane Square    South Kensington
# CPU times: user 7.67 ms, sys: 1.11 ms, total: 8.77 ms
# Wall time: 8.05 ms

# %%
# %%time

# Check if there exists a path between Victoria and South Kensington in 2 hops returning connections
command = """
MATCH (departure)-[l1:CONNECTION]->(intermediate)-[l2:CONNECTION]->(arrival)
WHERE departure.displayName = 'Victoria'
AND arrival.displayName = 'South Kensington'
RETURN departure.displayName, l1.Line, intermediate.displayName, l2.Line, arrival.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#   departure.displayName l1.Line intermediate.displayName l2.Line  \
# 0              Victoria  Circle            Sloane Square  Circle
#
#   arrival.displayName
# 0    South Kensington
# CPU times: user 8.71 ms, sys: 950 μs, total: 9.66 ms
# Wall time: 9.07 ms

# %%
# %%time

# Check if there exists a path between Victoria and South Kensington in 2 hops using District Line only
command = """
MATCH (departure)-[l1:CONNECTION]->(intermediate)-[l2:CONNECTION]->(arrival)
WHERE departure.displayName = 'Victoria'
AND arrival.displayName = 'South Kensington'
AND l1.Line = 'District Line'
AND l2.Line = 'District Line'
RETURN departure.displayName, l1.Line, intermediate.displayName, l2.Line, arrival.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
# No result found
# CPU times: user 4.28 ms, sys: 44 μs, total: 4.32 ms
# Wall time: 3.52 ms

# %%
# %%time

# Check if there exists a path between Victoria and South Kensington in 2 hops using Circle Line only
command = """
MATCH (departure)-[l1:CONNECTION]->(intermediate)-[l2:CONNECTION]->(arrival)
WHERE departure.displayName = 'Victoria'
AND arrival.displayName = 'South Kensington'
AND l1.Line = 'Circle'
AND l2.Line = 'Circle'
RETURN departure.displayName, l1.Line, intermediate.displayName, l2.Line, arrival.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#   departure.displayName l1.Line intermediate.displayName l2.Line  \
# 0              Victoria  Circle            Sloane Square  Circle
#
#   arrival.displayName
# 0    South Kensington
# CPU times: user 10.5 ms, sys: 85 μs, total: 10.6 ms
# Wall time: 9.7 ms

# %%
# %%time

# Get route between Stratford and Liverpool Street getting distances between stations
command = """
MATCH (departure)-[l1:CONNECTION]->(i1)-[l2:CONNECTION]->(i2)-[l3:CONNECTION]->(arrival)
WHERE departure.displayName = 'Stratford'
AND arrival.displayName = 'Liverpool Street'
RETURN departure.displayName, l1.Line, l1.DistanceMeters,
i1.displayName, l2.Line, l2.DistanceMeters,
i2.displayName, l3.Line, l3.DistanceMeters,
arrival.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#   departure.displayName  l1.Line  l1.DistanceMeters i1.displayName  l2.Line  \
# 0             Stratford  Central               2110       Mile End  Central
#
#    l2.DistanceMeters i2.displayName  l3.Line  l3.DistanceMeters  \
# 0                860  Bethnal Green  Central               1453
#
#   arrival.displayName
# 0    Liverpool Street
# CPU times: user 14.1 ms, sys: 1.18 ms, total: 15.3 ms
# Wall time: 14.2 ms

# %% [markdown]
# # Python functions to construct Cypher queries

# %%
# Define build_query_hops_with_edge function
def build_query_hops_with_edge(
    departure_station: str, arrival_station: str, hopCount: int
) -> tuple[str, list[str]]:
    """
    Build query string and corresponding column names.

    Returns:
        tuple: (query_string, column_names)
    """
    #query = "MATCH "
    #query += '(departure:Station{displayName:"'
    #query += departure_station
    #query += '"})'
    query = "MATCH (departure:Station)"

    for k in range(1, hopCount):
        query += f"-[c{k}:CONNECTION]->(st{k}:Station)"

    query += f"""-[c{hopCount}:CONNECTION]->(arrival:Station)\n
    WHERE departure.displayName = '{departure_station}'
    AND arrival.displayName = '{arrival_station}'
    """

    #query += (
    #    "-[c"
    #    + str(hopCount)
    #    + ':CONNECTED]-(arrival:Station{displayName="'
    #    + arrival_station
    #    + '"})'
    #)

    query += " RETURN departure, departure.displayName, departure.Note, "
    for k in range(1, hopCount):
        query += f"c{k}.Line, st{k}, st{k}.displayName, st{k}.Note, "
    query += f"c{hopCount}.Line, arrival, arrival.displayName, arrival.Note"

    return re.sub(' +', ' ', query.replace('\n', ''))

# %%
departure_station = "Paddington"
arrival_station = "Blackfriars"

distmax = 14

# %%
#%%time

# Loop over distance (number of hops) until we find a path between requested start and end stations
for k in range(1, distmax + 1):
    print(100 * "*")
    print(f"*** k = {k}\n")

    # We get a query and column names
    query_str = build_query_hops_with_edge(departure_station, arrival_station, k)
    print(f"query_str :\n{query_str}")
    df_path = client.query(query_str)

    if not df_path.empty:
        display(df_path)
        break

print(100 * "*")
# Out:
# ****************************************************************************************************
# *** k = 1
#
# query_str :
# MATCH (departure:Station)-[c1:CONNECTION]->(arrival:Station) WHERE departure.displayName = 'Paddington' AND arrival.displayName = 'Blackfriars' RETURN departure, departure.displayName, departure.Note, c1.Line, arrival, arrival.displayName, arrival.Note
# ****************************************************************************************************
# *** k = 2
#
# query_str :
# MATCH (departure:Station)-[c1:CONNECTION]->(st1:Station)-[c2:CONNECTION]->(arrival:Station) WHERE departure.displayName = 'Paddington' AND arrival.displayName = 'Blackfriars' RETURN departure, departure.displayName, departure.Note, c1.Line, st1, st1.displayName, st1.Note, c2.Line, arrival, arrival.displayName, arrival.Note
# ****************************************************************************************************
# *** k = 3
#
# query_str :
# MATCH (departure:Station)-[c1:CONNECTION]->(st1:Station)-[c2:CONNECTION]->(st2:Station)-[c3:CONNECTION]->(arrival:Station) WHERE departure.displayName = 'Paddington' AND arrival.displayName = 'Blackfriars' RETURN departure, departure.displayName, departure.Note, c1.Line, st1, st1.displayName, st1.Note, c2.Line, st2, st2.displayName, st2.Note, c3.Line, arrival, arrival.displayName, arrival.Note
# ****************************************************************************************************
# *** k = 4
#
# query_str :
# MATCH (departure:Station)-[c1:CONNECTION]->(st1:Station)-[c2:CONNECTION]->(st2:Station)-[c3:CONNECTION]->(st3:Station)-[c4:CONNECTION]->(arrival:Station) WHERE departure.displayName = 'Paddington' AND arrival.displayName = 'Blackfriars' RETURN departure, departure.displayName, departure.Note, c1.Line, st1, st1.displayName, st1.Note, c2.Line, st2, st2.displayName, st2.Note, c3.Line, st3, st3.displayName, st3.Note, c4.Line, arrival, arrival.displayName, arrival.Note
# ****************************************************************************************************
# *** k = 5
#
# query_str :
# MATCH (departure:Station)-[c1:CONNECTION]->(st1:Station)-[c2:CONNECTION]->(st2:Station)-[c3:CONNECTION]->(st3:Station)-[c4:CONNECTION]->(st4:Station)-[c5:CONNECTION]->(arrival:Station) WHERE departure.displayName = 'Paddington' AND arrival.displayName = 'Blackfriars' RETURN departure, departure.displayName, departure.Note, c1.Line, st1, st1.displayName, st1.Note, c2.Line, st2, st2.displayName, st2.Note, c3.Line, st3, st3.displayName, st3.Note, c4.Line, st4, st4.displayName, st4.Note, c5.Line, arrival, arrival.displayName, arrival.Note
# ****************************************************************************************************
# *** k = 6
#
# query_str :
# MATCH (departure:Station)-[c1:CONNECTION]->(st1:Station)-[c2:CONNECTION]->(st2:Station)-[c3:CONNECTION]->(st3:Station)-[c4:CONNECTION]->(st4:Station)-[c5:CONNECTION]->(st5:Station)-[c6:CONNECTION]->(arrival:Station) WHERE departure.displayName = 'Paddington' AND arrival.displayName = 'Blackfriars' RETURN departure, departure.displayName, departure.Note, c1.Line, st1, st1.displayName, st1.Note, c2.Line, st2, st2.displayName, st2.Note, c3.Line, st3, st3.displayName, st3.Note, c4.Line, st4, st4.displayName, st4.Note, c5.Line, st5, st5.displayName, st5.Note, c6.Line, arrival, arrival.displayName, arrival.Note
# ****************************************************************************************************
# *** k = 7
#
# query_str :
# MATCH (departure:Station)-[c1:CONNECTION]->(st1:Station)-[c2:CONNECTION]->(st2:Station)-[c3:CONNECTION]->(st3:Station)-[c4:CONNECTION]->(st4:Station)-[c5:CONNECTION]->(st5:Station)-[c6:CONNECTION]->(st6:Station)-[c7:CONNECTION]->(arrival:Station) WHERE departure.displayName = 'Paddington' AND arrival.displayName = 'Blackfriars' RETURN departure, departure.displayName, departure.Note, c1.Line, st1, st1.displayName, st1.Note, c2.Line, st2, st2.displayName, st2.Note, c3.Line, st3, st3.displayName, st3.Note, c4.Line, st4, st4.displayName, st4.Note, c5.Line, st5, st5.displayName, st5.Note, c6.Line, st6, st6.displayName, st6.Note, c7.Line, arrival, arrival.displayName, arrival.Note
# ****************************************************************************************************
# *** k = 8
#
# query_str :
# MATCH (departure:Station)-[c1:CONNECTION]->(st1:Station)-[c2:CONNECTION]->(st2:Station)-[c3:CONNECTION]->(st3:Station)-[c4:CONNECTION]->(st4:Station)-[c5:CONNECTION]->(st5:Station)-[c6:CONNECTION]->(st6:Station)-[c7:CONNECTION]->(st7:Station)-[c8:CONNECTION]->(arrival:Station) WHERE departure.displayName = 'Paddington' AND arrival.displayName = 'Blackfriars' RETURN departure, departure.displayName, departure.Note, c1.Line, st1, st1.displayName, st1.Note, c2.Line, st2, st2.displayName, st2.Note, c3.Line, st3, st3.displayName, st3.Note, c4.Line, st4, st4.displayName, st4.Note, c5.Line, st5, st5.displayName, st5.Note, c6.Line, st6, st6.displayName, st6.Note, c7.Line, st7, st7.displayName, st7.Note, c8.Line, arrival, arrival.displayName, arrival.Note
#    departure departure.displayName  \
# 0        177            Paddington
#
#                                       departure.Note c1.Line  st1  \
# 0  Stroll along the canals at Paddington Basin an...  Circle  176
#
#   st1.displayName                                           st1.Note c2.Line  \
# 0    Edgware Road  Explore Little Venice s canals and visit the b...  Circle
#
#    st2 st2.displayName  ... st6.displayName  \
# 0  174    Baker Street  ...      Embankment
#
#                                             st6.Note  c7.Line  st7  \
# 0  Relax in Victoria Embankment Gardens and see C...   Circle  202
#
#   st7.displayName                                           st7.Note  c8.Line  \
# 0          Temple  Discover the historic Temple Church and stroll...   Circle
#
#   arrival arrival.displayName  \
# 0     203         Blackfriars
#
#                                         arrival.Note
# 0  Cross the Blackfriars Bridge to the Tate Moder...
#
# [1 rows x 35 columns]
# ****************************************************************************************************

# %% [markdown]
# # Process returned dataframe

# %%
# Define create_journey_string function
def create_journey_string(row):
    """Create journey string from DataFrame row - safer version"""
    # Start with departure station
    result = f"({row['departure.displayName']})"

    # Find all available segment numbers
    line_cols = [
        col for col in row.index if col.startswith("c") and col.endswith(".Line")
    ]
    segment_numbers = sorted([int(col.split(".")[0][1:]) for col in line_cols])

    # Process each available segment
    for i in segment_numbers:
        line_col = f"c{i}.Line"
        station_col = f"st{i}.displayName"

        # Only process if both columns exist and have values
        if (
            line_col in row.index
            and station_col in row.index
            and not pd.isna(row[line_col])
            and not pd.isna(row[station_col])
        ):
            line = row[line_col]
            station = row[station_col]
            result += f"--[{line}]-->({station})"

    # Add arrival station if it exists
    if "arrival.displayName" in row.index and not pd.isna(row["arrival.displayName"]):
        # Check if there's a final line segment to the arrival
        max_segment = max(segment_numbers) if segment_numbers else 0
        final_line_col = f"l{max_segment}.Line"
        if final_line_col in row.index and not pd.isna(row[final_line_col]):
            result += f"--[{row[final_line_col]}]-->({row['arrival.displayName']})"

    return result

# %%
# Show journey strings (multiple paths of the same length can exist between two stations)
for i in range(min(len(df_path), 10)):
    journey_path = create_journey_string(
        df_path.filter(regex="displayName$|Line$", axis=1).iloc[i]
    )
    print(f"Path n°{i}: {journey_path}\n")
# Out:
# Path n°0: (Paddington)--[Circle]-->(Edgware Road)--[Circle]-->(Baker Street)--[Jubilee]-->(Bond Street)--[Jubilee]-->(Green Park)--[Jubilee]-->(Westminster)--[Circle]-->(Embankment)--[Circle]-->(Temple)

# %% [markdown]
# # Create subgraph to visualise

# %%
def get_subgraph(G, df):
    subset_nodes = df.filter(regex="displayName$", axis=1).iloc[0].values.tolist()
    subG = G.subgraph(subset_nodes).copy()

    return subG

# %%
# Get subgraph with stations from matched path
subG = get_subgraph(G, df_path)
print(subG)

# Build CREATE command from subgraph
create_command_subG = build_create_command_from_networkx(subG)
print(f"""
Cypher CREATE command :
* size: {len(create_command_subG.encode('utf-8'))/1024/1000:.4f} MB\n
{100 * '*'}
{create_command_subG \
if len(create_command_subG.split("\n")) < 10000 \
else "\n".join(create_command_subG.split('\n')[:5]) + "\n...\n" + "\n".join(create_command_subG.split('\n')[-5:])}
{100 * '*'}
""")
# Out:
# DiGraph with 9 nodes and 16 edges
# Cypher query will create graph with 9 nodes and 16 edges
#
# Cypher CREATE command :
# * size: 0.0044 MB
#
# ****************************************************************************************************
# CREATE (:Node {id: "Embankment", displayName: "Embankment", type: "Station", Latitude: 51.5073122969468, Longitude: -0.12236733566212, Zone: 1, Postcode: "WC2N 6NS", Note: "Relax in Victoria Embankment Gardens and see Cleopatra s Needle along the Thames."}),
# (:Node {id: "Blackfriars", displayName: "Blackfriars", type: "Station", Latitude: 51.511586761695, Longitude: -0.102995384624505, Zone: 1, Postcode: "EC4V 4DD", Note: "Cross the Blackfriars Bridge to the Tate Modern or explore the riverside walkways."}),
# (:Node {id: "Edgware Road", displayName: "Edgware Road", type: "Station", Latitude: 51.5206450845361, Longitude: -0.17053954989974, Zone: 1, Postcode: "W2 1DY", Note: "Explore Little Venice s canals and visit the beautiful St Mary Magdalene church."}),
# (:Node {id: "Baker Street", displayName: "Baker Street", type: "Station", Latitude: 51.5231293660588, Longitude: -0.156904192986185, Zone: 1, Postcode: "NW1 5LA", Note: "Step into Sherlock Holmes world at 221B Baker Street or meet wax celebrities at Madame Tussauds."}),
# (:Node {id: "Bond Street", displayName: "Bond Street", type: "Station", Latitude: 51.5137972823274, Longitude: -0.149613608531646, Zone: 1, Postcode: "W1C 2HU", Note: "Shop luxury boutiques on Bond Street or high street stores along Oxford Street."}),
# (:Node {id: "Paddington", displayName: "Paddington", type: "Station", Latitude: 51.5153935002265, Longitude: -0.175736750265772, Zone: 1, Postcode: "W2 1RH", Note: "Stroll along the canals at Paddington Basin and say hello to the Paddington Bear statue."}),
# (:Node {id: "Westminster", displayName: "Westminster", type: "Station", Latitude: 51.5014013891933, Longitude: -0.12500207834678, Zone: 1, Postcode: "SW1A 2JR", Note: "Marvel at the Houses of Parliament and Big Ben and visit Westminster Abbey."}),
# (:Node {id: "Green Park", displayName: "Green Park", type: "Station", Latitude: 51.5067602537146, Longitude: -0.142477574422533, Zone: 1, Postcode: "W1J 7BX", Note: "Stroll through Green Park to Buckingham Palace or head to nearby Piccadilly."}),
# (:Node {id: "Temple", displayName: "Temple", type: "Station", Latitude: 51.5110404236047, Longitude: -0.113725749531254, Zone: 1, Postcode: "WC2R 2PH", Note: "Discover the historic Temple Church and stroll through Victoria Embankment Gardens."})
# MATCH (source {id: "Embankment"}), (target {id: "Temple"}) CREATE (source)-[:CONNECTED {Line:"Circle", DistanceMeters:522}]->(target)
# MATCH (source {id: "Embankment"}), (target {id: "Westminster"}) CREATE (source)-[:CONNECTED {Line:"Circle", DistanceMeters:665}]->(target)
# MATCH (source {id: "Blackfriars"}), (target {id: "Temple"}) CREATE (source)-[:CONNECTED {Line:"Circle", DistanceMeters:398}]->(target)
# MATCH (source {id: "Edgware Road"}), (target {id: "Paddington"}) CREATE (source)-[:CONNECTED {Line:"Circle", DistanceMeters:0}]->(target)
# MATCH (source {id: "Edgware Road"}), (target {id: "Baker Street"}) CREATE (source)-[:CONNECTED {Line:"Circle", DistanceMeters:572}]->(target)
# MATCH (source {id: "Baker Street"}), (target {id: "Edgware Road"}) CREATE (source)-[:CONNECTED {Line:"Circle", DistanceMeters:572}]->(target)
# MATCH (source {id: "Baker Street"}), (target {id: "Bond Street"}) CREATE (source)-[:CONNECTED {Line:"Jubilee", DistanceMeters:1072}]->(target)
# MATCH (source {id: "Bond Street"}), (target {id: "Baker Street"}) CREATE (source)-[:CONNECTED {Line:"Jubilee", DistanceMeters:1072}]->(target)
# MATCH (source {id: "Bond Street"}), (target {id: "Green Park"}) CREATE (source)-[:CONNECTED {Line:"Jubilee", DistanceMeters:826}]->(target)
# MATCH (source {id: "Paddington"}), (target {id: "Edgware Road"}) CREATE (source)-[:CONNECTED {Line:"Circle", DistanceMeters:0}]->(target)
# MATCH (source {id: "Westminster"}), (target {id: "Embankment"}) CREATE (source)-[:CONNECTED {Line:"Circle", DistanceMeters:665}]->(target)
# MATCH (source {id: "Westminster"}), (target {id: "Green Park"}) CREATE (source)-[:CONNECTED {Line:"Jubilee", DistanceMeters:876}]->(target)
# MATCH (source {id: "Green Park"}), (target {id: "Bond Street"}) CREATE (source)-[:CONNECTED {Line:"Jubilee", DistanceMeters:826}]->(target)
# MATCH (source {id: "Green Park"}), (target {id: "Westminster"}) CREATE (source)-[:CONNECTED {Line:"Jubilee", DistanceMeters:876}]->(target)
# MATCH (source {id: "Temple"}), (target {id: "Blackfriars"}) CREATE (source)-[:CONNECTED {Line:"Circle", DistanceMeters:398}]->(target)
# MATCH (source {id: "Temple"}), (target {id: "Embankment"}) CREATE (source)-[:CONNECTED {Line:"Circle", DistanceMeters:522}]->(target)
# ****************************************************************************************************

# %%
subgraph_name = f"{graph_name}_subgraph"
subgraph_name
# Out:
# 'london_transport_TfL2_subgraph'

# %%
# %%time

# Set graph
try:
    client.create_graph(subgraph_name)
except TuringDBException as e:
    print(e)

# Set working graph
client.set_graph(subgraph_name)

# Create a new change on the graph
client.checkout()
change = client.new_change()
print(f"Current change {change}")

# Checkout into the change
client.checkout(change=change)
# Out:
# Current change 0
# CPU times: user 3.91 ms, sys: 1.18 ms, total: 5.09 ms
# Wall time: 15.4 ms

# %%
# %%time

chunks = split_cypher_commands(create_command_subG, max_size_mb=1)

print(f"✓ Split into {len(chunks['node_chunks'])} node chunk(s) and {len(chunks['edge_chunks'])} edge chunk(s)")

print("\nNode chunks:")
for i, chunk in enumerate(chunks['node_chunks']):
    print(f"  Node chunk {i+1}: {len(chunk.encode('utf-8'))/1024:.1f} KB")
    if i == 10:
        print("  ...")
        break

print("\nEdge chunks:")
for i, chunk in enumerate(chunks['edge_chunks']):
    print(f"  Edge chunk {i+1}: {len(chunk.encode('utf-8'))/1024:.1f} KB")
    if i == 10:
        print("  ...")
        break
# Out:
# ✓ Split into 1 node chunk(s) and 16 edge chunk(s)
#
# Node chunks:
#   Node chunk 1: 2.2 KB
#
# Edge chunks:
#   Edge chunk 1: 0.1 KB
#   Edge chunk 2: 0.1 KB
#   Edge chunk 3: 0.1 KB
#   Edge chunk 4: 0.1 KB
#   Edge chunk 5: 0.1 KB
#   Edge chunk 6: 0.1 KB
#   Edge chunk 7: 0.1 KB
#   Edge chunk 8: 0.1 KB
#   Edge chunk 9: 0.1 KB
#   Edge chunk 10: 0.1 KB
#   Edge chunk 11: 0.1 KB
#   ...
# CPU times: user 770 μs, sys: 0 ns, total: 770 μs
# Wall time: 714 μs

# %%
# %%time

# Run CREATE command
print("\nExecuting query on TuringDB...")
start_time = time.time()

print(f"✓ Split into {len(chunks['node_chunks'])} node chunk(s) and {len(chunks['edge_chunks'])} edge chunk(s)")

# CREATE nodes
print("\nNode chunks:")
for i, chunk in enumerate(tqdm(chunks['node_chunks'])):
    result = client.query(chunk)
# Commit the change
client.query("COMMIT")
print(f"✓ {len(chunks['node_chunks'])} node chunks done")

# CREATE edges
print("\nEdge chunks:")
for i, chunk in enumerate(tqdm(chunks['edge_chunks'])):
    result = client.query(chunk)
# Commit the change
client.query("COMMIT")
print(f"✓ {len(chunks['edge_chunks'])} edge chunks done")

execution_time = time.time() - start_time
print(f"\n✓ Graph created successfully in {execution_time:.2f} seconds")

# Submit changes
start_time = time.time()
client.query("CHANGE SUBMIT")
execution_time = time.time() - start_time
print(f"\n✓ Changes successfully submitted in {execution_time:.2f} seconds")

# Checkout into main
client.checkout()
# Out:
# Executing query on TuringDB...
# ✓ Split into 1 node chunk(s) and 16 edge chunk(s)
#
# Node chunks:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✓ 1 node chunks done
#
# Edge chunks:
#   0%|          | 0/16 [00:00<?, ?it/s]
# ✓ 16 edge chunks done
#
# ✓ Graph created successfully in 0.04 seconds
#
# ✓ Changes successfully submitted in 0.07 seconds
# CPU times: user 39.8 ms, sys: 7.42 ms, total: 47.2 ms
# Wall time: 107 ms

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         You can visualise the subgraph directly in the notebook below. For more details on nodes and edges, you can go to TuringDB visualizer (running on your instance)
#     </h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         Visualize your graph in TuringDB Graph Visualizer ! Now that your instance is running:
#     </h2>
#     <h3>
#         <ul>
#             <li>Go to <a href="https://console.turingdb.ai/databases">TuringDB Console - Database Instances</a></li>
#             <li>In your current instance panel, click on "Open Visualizer" button</li>
#             <li>Visualizer opens, now you can choose your graph in the dropdown menu at the top-right corner</li>
#         </ul>
#         You can then play with your graph and visualize the nodes you want !
#     </h3>
# </div>

# %%
from pyvis.network import Network

net = Network(
    height="750px",
    width="100%",
    notebook=True,
    bgcolor="#ffffff",
    font_color="#000000",
    directed=True,
)

# Line colors (official TfL colors)
line_colors = {
    "Circle": "#FFD329",
    "Jubilee": "#A1A5A7",
    "Central": "#DC241F",
    "District": "#00782A",
    "Metropolitan": "#9B0058",
}

for node, data in subG.nodes(data=True):
    net.add_node(
        node,
        label=data.get("displayName", str(node)),
        title=f"{data.get('displayName', '')}<br>{data.get('Note', '')}",
        color="#3498db",
        size=25,
    )

for source, target, data in subG.edges(data=True):
    line = data.get("Line", "")
    color = line_colors.get(line, "#95a5a6")
    net.add_edge(source, target, title=line, label=line, color=color, width=3)

net.toggle_physics(True)
net.show(f"{example_name}_subgraph.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# london_transport_TfL_subgraph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="london_transport_TfL_subgraph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Use LLM to generate Cypher query

# %% [markdown]
# Before running this section, create a `.env` file in the project root with your API keys:
#
# ```env
# ANTHROPIC_API_KEY=your_key_here
# OPENAI_API_KEY=your_key_here
# MISTRAL_API_KEY=your_key_here

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
api_keys = {
    "Anthropic": os.getenv("ANTHROPIC_API_KEY"),
    "Mistral": os.getenv("MISTRAL_API_KEY"),
    "OpenAI": os.getenv("OPENAI_API_KEY"),
}

# %%
# %%time

system_prompt = """
Only base your response on the data provided.
Do not add knowledge but describe it in a natural way as if you were a touristic guide, be friendly !
You can add forms but not content.
Format the output with nice Markdown format and emojis.
"""

prompt = f"""
Here is the path I got from stations {departure_station} to {arrival_station} : {df_path.to_dict()}.
Describe the path between these two stations.
Give me an itinerary of things I could visit on the way.
"""

provider = "Anthropic"

result = query_llm(
    prompt=prompt,
    system_prompt=system_prompt,
    provider=provider,
    model="claude-haiku-4-5-20251001",
    api_key=api_keys[provider],
    temperature=0.2,
)

# %%
display(Markdown(result))
# Out:
# # 🚇 Your Journey: Paddington to Blackfriars
#
# Welcome! Let me guide you through this wonderful route across London's iconic Underground network!
#
# ---
#
# ## 📍 Your Complete Route
#
# **Starting Point:** 🚂 **Paddington** → **Destination:** 🏛️ **Blackfriars**
#
# You'll be traveling through **3 different Underground lines**: Circle, Jubilee, and back to Circle!
#
# ---
#
# ## 🎫 Stop-by-Stop Itinerary
#
# ### 1️⃣ **Paddington** (Circle Line)
# 🐻 *Your starting point!*
# - Stroll along the charming canals at **Paddington Basin**
# - Say hello to the famous **Paddington Bear statue**
#
# ### 2️⃣ **Edgware Road** (Circle Line)
# 🏘️ *A hidden gem!*
# - Explore the picturesque canals of **Little Venice**
# - Visit the beautiful **St Mary Magdalene Church**
#
# ### 3️⃣ **Baker Street** (Circle Line)
# 🔍 *Step into literary history!*
# - Discover **221B Baker Street** - Sherlock Holmes' world
# - Meet wax celebrities at **Madame Tussauds**
#
# ### 4️⃣ **Bond Street** (Switch to Jubilee Line)
# 💎 *Shopper's paradise!*
# - Browse luxury boutiques on **Bond Street**
# - Explore high street stores along **Oxford Street**
#
# ### 5️⃣ **Green Park** (Jubilee Line)
# 🌳 *Royal London awaits!*
# - Stroll through the elegant **Green Park**
# - Head towards **Buckingham Palace**
# - Visit nearby **Piccadilly**
#
# ### 6️⃣ **Westminster** (Jubilee Line)
# 🏰 *The heart of British politics!*
# - Marvel at the **Houses of Parliament** and **Big Ben**
# - Visit the magnificent **Westminster Abbey**
#
# ### 7️⃣ **Embankment** (Switch back to Circle Line)
# 🌊 *Riverside relaxation!*
# - Relax in **Victoria Embankment Gardens**
# - See the iconic **Cleopatra's Needle** along the Thames
#
# ### 8️⃣ **Temple** (Circle Line)
# ⛪ *Historic treasures!*
# - Discover the historic **Temple Church**
# - Stroll through **Victoria Embankment Gardens** again
#
# ### 🎯 **Blackfriars** (Final Destination!)
# 🎨 *Your journey ends here!*
# - Cross the **Blackfriars Bridge** to the **Tate Modern**
# - Explore the beautiful **riverside walkways**
#
# ---
#
# ## ✨ Pro Tips for Your Journey
#
# - 📸 Don't miss photo opportunities at Westminster with Big Ben!
# - 👜 Allow extra time at Bond Street if you love shopping
# - 🚶 Consider exiting at Embankment or Temple to walk along the Thames
# - 🎭 The Tate Modern at Blackfriars is perfect for art lovers!
#
# **Enjoy your London adventure!** 🇬🇧✨

# %% [markdown]
# # Use LLM to generate Cypher query

# %%
"""Build system prompt with TuringDB schema and examples"""

turingdb_cypher_system_prompt = """
You are an expert at converting natural language questions into TuringDB queries.

Your task is to generate syntactically correct TuringDB queries based on natural language input.

VERY IMPORTANT - YOU MUST FOLLOW THESE REQUESTS - TuringDB Syntax Guidelines:
1. Return ONLY the TuringDB query, no explanations or markdown formatting
2. Use MATCH, CREATE and WHERE operations only
3. Nodes: (n:Label {property = "value"}) or (n:Label {property: value})
4. Edges: Use DIRECTED syntax with ->
5. Pattern matching: MATCH (n)-[e]->(m)
6. Property matching: Use = operator for exact matching
7. Multiple constraints: (n:Person:Engineer {name = "John", age = 30})
8. Return all matched entities: RETURN n, e, m or use RETURN * for all
9. Filter using WHERE clause: MATCH (n:Person) WHERE n.name = 'John' RETURN n.firstname, n.lastname

VERY IMPORTANT - YOU ARE NOT ALLOWED TO USE THE FOLLOWING - FORBIDDEN in TuringDB:
- Do NOT use AS aliases
- Do NOT use LIMIT, SKIP clauses
- Do NOT use WITH clauses
- Do NOT use CALL (except for metaqueries)
- Do NOT use toLower() or other functions
- Do NOT use wildcard character (*)
- Do NOT use multi-hops pattern for edges: e.g. `-[e:CONNECTED*1..10]->`
- Do NOT use "end" or "s3" variable name

Supported TuringDB Operations:
- MATCH queries: MATCH (n:Label)-[e:Type]->(m) RETURN n, m
- CREATE queries: CREATE (n:Label{property="value"})-[e:Type]->(m:Label)
- Metaqueries: CALL db.propertyTypes(), CALL db.labels(), CALL db.edgeTypes()
- Property types: String ("text" or `text`), Boolean (true/false), Integer (20), Double (20.5)

Examples for few-shot learning:
- Find all persons: MATCH (n:Person) RETURN n
- Find connections: MATCH (n:Person)-[e]->(m:Person) RETURN n, e, m
- Create person: CREATE (n:Person{name="John", age=30})
- Match person with specific name: MATCH (p:Person) WHERE p.name = "John" RETURN p
- Path with 1 hop between Station Paddington and Blackfriars:  MATCH (first:Station{displayName:"Paddington"})-[e1:CONNECTED]->(last:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, last, last.displayName, last.Note
- Path with 2 hops between Station Paddington and Blackfriars: MATCH (first:Station{displayName:"Paddington"})-[e1:CONNECTED]->(s1:Station)-[e2:CONNECTED]->(last:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, last, last.displayName, last.Note
- Path with 8 hops between Station Paddington and Blackfriars: MATCH (first:Station{displayName:"Paddington"})-[e1:CONNECTED]->(s1:Station)-[e2:CONNECTED]->(s2:Station)-[e3:CONNECTED]->(s3:Station)-[e4:CONNECTED]->(s4:Station)-[e5:CONNECTED]->(s5:Station)-[e6:CONNECTED]->(s6:Station)-[e7:CONNECTED]->(s7:Station)-[e8:CONNECTED]->(last:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, s5, s5.displayName, s5.Note, e6.Line, s6, s6.displayName, s6.Note, e7.Line, s7, s7.displayName, s7.Note, e8.Line, last, last.displayName, last.Note
- Find all Chinese providers and what they supply: MATCH (n{provider_country:"CHN"}) RETURN n, n.provider_name, n.displayName, n.share_provided, n.type
- Find all deposition tools and their types: MATCH (specific)-[e:IS_TYPE_OF]->(general:Tool_Resource{displayName:"Deposition tools"}) RETURN specific, specific.displayName, specific.provider_name, e, general, general.displayName
"""

# %%
# %%time

# Define maximum number of hops between two
distmax = 20

# Get subset of CREATE command to avoid exceeding context window
graph_CREATE_command_subset = "\n".join(
    graph_CREATE_command.split("\n")[:5] + graph_CREATE_command.split("\n")[-5:]
)

for k in range(1, distmax + 1):
    print(100 * "*")
    print(f"*** k = {k}\n")

    #########################################################################################################
    question = f"""
    Give me the Cypher query to find the path using London Tube between stations {departure_station} and {arrival_station}.
    The path between the two stations has to contain {k} hops.
    Very important :
    - Make sure you respect the number of hops and stations required between the two stations.
    - Pay attention to use the correct node and edge properties name in the MATCH section.
    - Pay attention to use the correct node and edge properties name in the RETURN section.
    - If no contrary information is asked by the user :
        - return all the matched nodes and edges and their properties in the RETURN section.
    """

    system_prompt = f"""
    TuringDB Cypher prompt :
    {turingdb_cypher_system_prompt}
    
    Here is a subset of the CREATE command used to create the graph, this way you know graph structure.
    Only a subset is passed because the whole command is too long. Please use this as the most relevant source of information :
    {graph_CREATE_command_subset}
    
    Here is also the output of "CALL LABELS ()" command, showing the different node types of the graph :
    {client.query("CALL db.labels()")}
    
    Here is also the output of "CALL EDGETYPES ()" command, showing the different edge types of the graph :
    {client.query("CALL db.edgeTypes()")}
    
    Very important :
    - You MUST follow current TuringDB Syntax Guidelines
    - You MUST NOT USE what is FORBIDDEN in TuringDB
    - By default, RETURN ALL THE MATCHED NODES AND EDGES AND THEIR PROPERTIES in the RETURN section (except contrary demand from user)
    - Use the correct node and edge properties name in the MATCH section.
    - Use the correct node and edge properties name in the RETURN section.
    - Pay attention to which properties come from nodes or edges, to create a functioning query
    - Pay attention to lower and uppercases in properties
    - If some properties contain spaces, be careful to wrap them
    
    Give me the query FOLLOWING TURINGDB GUIDELINES AND NOT USING WHAT IS FORBIDDEN for this specific question :
    """

    cypher_query = natural_language_to_cypher(
        question=question,
        system_prompt=system_prompt,
        provider=provider,
        model="claude-haiku-4-5-20251001",
        api_key=api_keys[provider],
    )
    print(f"cypher_query : {cypher_query}")

    #########################################################################################################

    ## Build column names to exactly match the RETURN clause
    # column_names = ['start', 'start.displayName', 'start.Note']
    #
    # for k_ in range(1, k):
    #    column_names.extend([
    #        f'e{k_}.Line',
    #        f's{k_}',
    #        f's{k_}.displayName',
    #        f's{k_}.Note'
    #    ])
    #
    # column_names.extend([
    #    f'e{k}.Line',
    #    'end',
    #    'end.displayName',
    #    'end.Note'
    # ])
    cypher_query

    #########################################################################################################

    try:
        df_path = client.query(cypher_query)
        if df_path.empty:
            print("--> No result found\n")
        else:
            display(df_path)
    except TuringDBException:
        print(f"Query generated by LLM failed.")

    break
    
print(100 * "*")
# Out:
# ****************************************************************************************************
# *** k = 1
#
# cypher_query : MATCH (first:Station{displayName:"Paddington"})-[e1:CONNECTED]->(last:Station{displayName:"Blackfriars"}) RETURN first, first.displayName, first.Note, e1, last, last.displayName, last.Note
# Query generated by LLM failed.
# ****************************************************************************************************
# CPU times: user 41.6 ms, sys: 1.86 ms, total: 43.5 ms
# Wall time: 1.21 s

# %%
# Show journey strings (multiple paths of the same length can exist between two stations)
for i in range(len(df_path)):
    journey_path = create_journey_string(
        df_path.filter(regex="displayName$|Line$", axis=1).iloc[0]
    )
    print(f"Path n°{i}: {journey_path}")
# Out:
# Path n°0: (Paddington)--[Circle]-->(Edgware Road)--[Circle]-->(Baker Street)--[Jubilee]-->(Bond Street)--[Jubilee]-->(Green Park)--[Jubilee]-->(Westminster)--[Circle]-->(Embankment)--[Circle]-->(Temple)

# %%
print("Notebook finished !")
# Out:
# Notebook finished !
