# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>
#         Example notebook - London Tube
#     </h1>
#     <p>
#         Link to dataset : <a href="https://drive.google.com/drive/folders/1Tfl7D5Khh1uiQDMy20XngdFggaGyj6Vy?usp=drive_link">Google Drive</a>
#     </p>
# </div>

# %% [markdown]
# # Import modules and functions

# %%
import os
import pandas as pd
import re
from IPython.display import display, Markdown

from turingdb_examples.graph import (
    create_graph_from_df,
    build_create_command_from_networkx,
)
from turingdb_examples.llm import query_llm, natural_language_to_cypher
from turingdb_examples.utils import get_return_statements

# %% [markdown]
# # Check data files are available

# %%
example_name = "london_transport_TfL"
path_data = f"{os.getcwd()}/data/{example_name}"
if not os.path.exists(path_data):
    raise ValueError(f"{path_data} does not exists")

list_csv_files = sorted(os.listdir(path_data))
if not list_csv_files == [
    "TfL_london_transport_tube.csv",
    "TfL_london_transport_tube_sightseeing.csv",
    "TfL_london_transport_tube_stations.csv",
]:
    raise ValueError(
        f"At least one of the {len(list_csv_files)} csv files is not available in {path_data}"
    )

# %% [markdown]
# # Import and format data

# %%
df_link_stations = pd.read_csv(
    f"{path_data}/TfL_london_transport_tube.csv", decimal=","
)
df_link_stations = df_link_stations.apply(
    lambda x: x.str.strip() if x.dtype == "object" else x
)
df_link_stations
# Out:
#                 Line  Order       From_Station         To_Station   Total  \
# 0           Bakerloo      1  Elephant & Castle      Lambeth North  13.432
# 1           Bakerloo      2      Lambeth North           Waterloo  18.597
# 2           Bakerloo      3           Waterloo         Embankment  46.020
# 3           Bakerloo      4         Embankment      Charing Cross  55.475
# 4           Bakerloo      5      Charing Cross  Piccadilly Circus  63.929
# ..               ...    ...                ...                ...     ...
# 859         Victoria     13            Pimlico           Vauxhall  94.853
# 860         Victoria     14           Vauxhall          Stockwell  66.561
# 861         Victoria     15          Stockwell            Brixton  41.178
# 862  Waterloo & City      1           Waterloo  Bank and Monument   5.554
# 863  Waterloo & City      1  Bank and Monument           Waterloo   6.348
#
#      PM Peak     Evening        Late
# 0         4.118       1.288  398.000
# 1         5.718       1.916  580.000
# 2        13.746       4.609    1.466
# 3        17.155       5.959    1.940
# 4        20.112       7.712    3.035
# ..          ...         ...      ...
# 859      37.711      24.553   10.574
# 860      27.117      18.342    7.992
# 861      15.972      11.553    5.361
# 862       5.197       1.465  386.000
# 863      18.237       6.517    1.374
#
# [864 rows x 8 columns]

# %%
df_stations = pd.read_csv(f"{path_data}/TfL_london_transport_tube_stations.csv")
df_stations = df_stations.drop(["Zone_original", "OS X", "OS Y"], axis=1)
df_stations = df_stations.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
df_stations["Station"] = df_stations["Station"].str.replace(" and ", " & ")
df_stations
# Out:
#                Station   Latitude  Longitude  Zone  Postcode
# 0           Abbey Road  51.531952   0.003723     3   E15 3NB
# 1           Abbey Wood  51.490784   0.120272     4   SE2 9RH
# 2        Acton Central  51.508757  -0.263430     2    W3 6BH
# 3      Acton Main Line  51.516886  -0.267690     3    W3 9EH
# 4           Acton Town  51.503071  -0.280303     3    W3 8HN
# ..                 ...        ...        ...   ...       ...
# 648      Woodside Park  51.617868  -0.185426     4   N12 8SE
# 649           Woolwich  51.491578   0.071819     4  SE18 6EU
# 650   Woolwich Arsenal  51.489907   0.069194     4  SE18 6HX
# 651  Woolwich Dockyard  51.491108   0.054612     3  SE18 5JY
# 652     Worcester Park  51.381104  -0.245575     4   KT4 7ND
#
# [653 rows x 5 columns]

# %%
df_sightseeing = pd.read_csv(
    f"{path_data}/TfL_london_transport_tube_sightseeing.csv", sep=";", header=1
)
df_sightseeing = df_sightseeing.T.drop_duplicates().T.rename(columns={"Blurb": "Note"})
df_sightseeing = df_sightseeing.apply(
    lambda x: x.str.strip() if x.dtype == "object" else x
)
df_sightseeing
# Out:
#               Station                                               Note
# 0          Abbey Road  Explore the historic House Mill and the Three ...
# 1          Acton Town  Gunnersbury Park and Museum offer landscaped g...
# 2             Aldgate  See the historic Aldgate Pump and visit the ne...
# 3        Aldgate East  Head to Brick Lane for famous curry houses, vi...
# 4          All Saints  Chrisp Street Market and the Lansbury Estate s...
# ..                ...                                                ...
# 294    Wimbledon Park  Row on the lake at Wimbledon Park and watch te...
# 295        Wood Green  Take in the views from Alexandra Palace and sh...
# 296          Woodford  Explore Epping Forest and play golf at Woodfor...
# 297     Woodside Park  Walk the Dollis Valley Greenwalk and shop alon...
# 298  Woolwich Arsenal  Explore the Royal Arsenal Riverside and take t...
#
# [299 rows x 2 columns]

# %%
df_stations = pd.merge(df_stations, df_sightseeing, on="Station", how="left")
df_stations
# Out:
#                Station   Latitude  Longitude  Zone  Postcode  \
# 0           Abbey Road  51.531952   0.003723     3   E15 3NB
# 1           Abbey Wood  51.490784   0.120272     4   SE2 9RH
# 2        Acton Central  51.508757  -0.263430     2    W3 6BH
# 3      Acton Main Line  51.516886  -0.267690     3    W3 9EH
# 4           Acton Town  51.503071  -0.280303     3    W3 8HN
# ..                 ...        ...        ...   ...       ...
# 648      Woodside Park  51.617868  -0.185426     4   N12 8SE
# 649           Woolwich  51.491578   0.071819     4  SE18 6EU
# 650   Woolwich Arsenal  51.489907   0.069194     4  SE18 6HX
# 651  Woolwich Dockyard  51.491108   0.054612     3  SE18 5JY
# 652     Worcester Park  51.381104  -0.245575     4   KT4 7ND
#
#                                                   Note
# 0    Explore the historic House Mill and the Three ...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Gunnersbury Park and Museum offer landscaped g...
# ..                                                 ...
# 648  Walk the Dollis Valley Greenwalk and shop alon...
# 649                                                NaN
# 650  Explore the Royal Arsenal Riverside and take t...
# 651                                                NaN
# 652                                                NaN
#
# [653 rows x 6 columns]

# %%
df_link_stations
# Out:
#                 Line  Order       From_Station         To_Station   Total  \
# 0           Bakerloo      1  Elephant & Castle      Lambeth North  13.432
# 1           Bakerloo      2      Lambeth North           Waterloo  18.597
# 2           Bakerloo      3           Waterloo         Embankment  46.020
# 3           Bakerloo      4         Embankment      Charing Cross  55.475
# 4           Bakerloo      5      Charing Cross  Piccadilly Circus  63.929
# ..               ...    ...                ...                ...     ...
# 859         Victoria     13            Pimlico           Vauxhall  94.853
# 860         Victoria     14           Vauxhall          Stockwell  66.561
# 861         Victoria     15          Stockwell            Brixton  41.178
# 862  Waterloo & City      1           Waterloo  Bank and Monument   5.554
# 863  Waterloo & City      1  Bank and Monument           Waterloo   6.348
#
#      PM Peak     Evening        Late
# 0         4.118       1.288  398.000
# 1         5.718       1.916  580.000
# 2        13.746       4.609    1.466
# 3        17.155       5.959    1.940
# 4        20.112       7.712    3.035
# ..          ...         ...      ...
# 859      37.711      24.553   10.574
# 860      27.117      18.342    7.992
# 861      15.972      11.553    5.361
# 862       5.197       1.465  386.000
# 863      18.237       6.517    1.374
#
# [864 rows x 8 columns]

# %% [markdown]
# # Create graph from dataframe

# %%
G = create_graph_from_df(
    df_link_stations,
    source_node_col={"id": "From_Station", "type": "Station"},
    target_node_col={"id": "To_Station", "type": "Station"},
    node_attributes_df=df_stations,
    node_attributes_key_col="Station",
    edge_col="Line",
)

# %%
# Show 10 first nodes
for node in list(G.nodes(data=True))[:10]:
    print(node)
# Out:
# ('Elephant & Castle', {'displayName': 'Elephant & Castle', 'type': 'Station', 'Latitude': 51.4958492200292, 'Longitude': -0.100738714256282, 'Zone': 1, 'Postcode': 'SE1 6LW', 'Note': 'nan'})
# ('Lambeth North', {'displayName': 'Lambeth North', 'type': 'Station', 'Latitude': 51.4991297653886, 'Longitude': -0.111768260460206, 'Zone': 1, 'Postcode': 'SE1 7XG', 'Note': 'Visit the Imperial War Museum and browse the Saturday market on Lower Marsh.'})
# ('Waterloo', {'displayName': 'Waterloo', 'type': 'Station', 'Latitude': 51.5031464567835, 'Longitude': -0.113259251258196, 'Zone': 1, 'Postcode': 'SE1 7NY', 'Note': 'Ride the London Eye, stroll along the South Bank and see a play at the National Theatre.'})
# ('Embankment', {'displayName': 'Embankment', 'type': 'Station', 'Latitude': 51.5073122969468, 'Longitude': -0.12236733566212, 'Zone': 1, 'Postcode': 'WC2N 6NS', 'Note': 'Relax in Victoria Embankment Gardens and see Cleopatra’s Needle along the Thames.'})
# ('Charing Cross', {'displayName': 'Charing Cross', 'type': 'Station', 'Latitude': 51.5083584281862, 'Longitude': -0.124802937233044, 'Zone': 1, 'Postcode': 'WC2N 5HS', 'Note': 'Stand in Trafalgar Square beneath Nelson’s Column and explore the National Gallery.'})
# ('Piccadilly Circus', {'displayName': 'Piccadilly Circus', 'type': 'Station', 'Latitude': 51.5096965321706, 'Longitude': -0.133711596159076, 'Zone': 1, 'Postcode': 'W1J 9HS', 'Note': 'See the bright lights of Piccadilly Circus, meet Eros at the Shaftesbury Memorial Fountain and visit the Criterion Theatre.'})
# ('Oxford Circus', {'displayName': 'Oxford Circus', 'type': 'Station', 'Latitude': 51.5152231744017, 'Longitude': -0.140836170133341, 'Zone': 1, 'Postcode': 'W1C 2JS', 'Note': 'Shop on Oxford Street and Regent Street and visit Hamleys, the world’s oldest toy store.'})
# ("Regent's Park", {'displayName': "Regent's Park", 'type': 'Station'})
# ('Baker Street', {'displayName': 'Baker Street', 'type': 'Station', 'Latitude': 51.5231293660588, 'Longitude': -0.156904192986185, 'Zone': 1, 'Postcode': 'NW1 5LA', 'Note': 'Step into Sherlock Holmes’ world at 221B Baker Street or meet wax celebrities at Madame\xa0Tussauds.'})
# ('Marylebone', {'displayName': 'Marylebone', 'type': 'Station', 'Latitude': 51.5223964032654, 'Longitude': -0.163492562310913, 'Zone': 1, 'Postcode': 'NW1 6JJ', 'Note': 'Shop on Marylebone High Street and tour Madame Tussauds.'})

# %%
# Show 10 first edges
for edge in list(G.edges(data=True))[:10]:
    print(edge)
# Out:
# ('Elephant & Castle', 'Lambeth North', {'Line': 'Bakerloo'})
# ('Elephant & Castle', 'Borough', {'Line': 'Northern'})
# ('Elephant & Castle', 'Kennington', {'Line': 'Northern'})
# ('Lambeth North', 'Waterloo', {'Line': 'Bakerloo'})
# ('Lambeth North', 'Elephant & Castle', {'Line': 'Bakerloo'})
# ('Waterloo', 'Embankment', {'Line': 'Northern'})
# ('Waterloo', 'Lambeth North', {'Line': 'Bakerloo'})
# ('Waterloo', 'Westminster', {'Line': 'Jubilee'})
# ('Waterloo', 'Southwark', {'Line': 'Jubilee'})
# ('Waterloo', 'Kennington', {'Line': 'Northern'})

# %% [markdown]
# # Create graph using `turingdb` python package

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         See <a href="https://docs.turingdb.ai/quickstart">TuringDB Get started documentation</a> for the important steps to follow :
#     </h2>
#     <h4>
#         <ul>
#             <li>Create your TuringDB account</li>
#             <li>Create your instance in the <a href="https://console.turingdb.ai/auth">TuringDB Cloud UI</a></li>
#             <li>Copy your Instance ID from the Database Instances management page</li>
#             <li>Get API Key from the Settings in UI</li>
#         </ul>
#         Remember to have your instance active while working in this notebook !
#     </h4>
# </div>

# %%
from turingdb import TuringDB

# Create TuringDB client
client = TuringDB(
    host="http://localhost:6666"  # Remove this parameter and set the two parameters below
    # instance_id="...",  # Replace by your instance id
    # auth_token="...",  # Replace by your API token
)

# %%
# Get list of available graphs
list_graphs = client.query("LIST GRAPH").loc[:, 0].tolist()

# %%
# Set graph name
graph_name_prefix = example_name
graph_name_nb_suffix = str(
    max(
        [
            int(re.sub(graph_name_prefix, "", g))
            for g in list_graphs
            if g.startswith(graph_name_prefix)
            and re.sub(graph_name_prefix, "", g).isdigit()
        ]
        + [0]
    )
    + 1
)
graph_name = graph_name_prefix + graph_name_nb_suffix
graph_name = re.sub("-", "_", graph_name)
graph_name
# Out:
# 'london_transport_TfL1'

# %%
# %%time

# Create a new graph
client.query(f"CREATE GRAPH {graph_name}")
client.set_graph(graph_name)

# Create a new change on the graph
change = client.query("CHANGE NEW").loc[0, 0]

# Checkout into the change
client.checkout(change=change)
# Out:
# CPU times: user 6.2 ms, sys: 58 μs, total: 6.26 ms
# Wall time: 21.8 ms

# %%
# Build CREATE command from networkx object
create_command = build_create_command_from_networkx(G)
print(f"Cypher CREATE command :\n\n{100 * '*'}\n{create_command}\n{100 * '*'}")
# Out:
# Cypher CREATE command :
#
# ****************************************************************************************************
# CREATE (n0:Station {"id":"Elephant & Castle", "displayName":"Elephant & Castle", "type":"Station", "Latitude":"51.4958492200292", "Longitude":"-0.100738714256282", "Zone":"1", "Postcode":"SE1 6LW", "Note":"nan"}),
# (n1:Station {"id":"Lambeth North", "displayName":"Lambeth North", "type":"Station", "Latitude":"51.4991297653886", "Longitude":"-0.111768260460206", "Zone":"1", "Postcode":"SE1 7XG", "Note":"Visit the Imperial War Museum and browse the Saturday market on Lower Marsh."}),
# (n2:Station {"id":"Waterloo", "displayName":"Waterloo", "type":"Station", "Latitude":"51.5031464567835", "Longitude":"-0.113259251258196", "Zone":"1", "Postcode":"SE1 7NY", "Note":"Ride the London Eye, stroll along the South Bank and see a play at the National Theatre."}),
# (n3:Station {"id":"Embankment", "displayName":"Embankment", "type":"Station", "Latitude":"51.5073122969468", "Longitude":"-0.12236733566212", "Zone":"1", "Postcode":"WC2N 6NS", "Note":"Relax in Victoria Embankment Gardens and see Cleopatra s Needle along the Thames."}),
# (n4:Station {"id":"Charing Cross", "displayName":"Charing Cross", "type":"Station", "Latitude":"51.5083584281862", "Longitude":"-0.124802937233044", "Zone":"1", "Postcode":"WC2N 5HS", "Note":"Stand in Trafalgar Square beneath Nelson s Column and explore the National Gallery."}),
# (n5:Station {"id":"Piccadilly Circus", "displayName":"Piccadilly Circus", "type":"Station", "Latitude":"51.5096965321706", "Longitude":"-0.133711596159076", "Zone":"1", "Postcode":"W1J 9HS", "Note":"See the bright lights of Piccadilly Circus, meet Eros at the Shaftesbury Memorial Fountain and visit the Criterion Theatre."}),
# (n6:Station {"id":"Oxford Circus", "displayName":"Oxford Circus", "type":"Station", "Latitude":"51.5152231744017", "Longitude":"-0.140836170133341", "Zone":"1", "Postcode":"W1C 2JS", "Note":"Shop on Oxford Street and Regent Street and visit Hamleys, the world s oldest toy store."}),
# (n7:Station {"id":"Regent's Park", "displayName":"Regent s Park", "type":"Station"}),
# (n8:Station {"id":"Baker Street", "displayName":"Baker Street", "type":"Station", "Latitude":"51.5231293660588", "Longitude":"-0.156904192986185", "Zone":"1", "Postcode":"NW1 5LA", "Note":"Step into Sherlock Holmes world at 221B Baker Street or meet wax celebrities at Madame Tussauds."}),
# (n9:Station {"id":"Marylebone", "displayName":"Marylebone", "type":"Station", "Latitude":"51.5223964032654", "Longitude":"-0.163492562310913", "Zone":"1", "Postcode":"NW1 6JJ", "Note":"Shop on Marylebone High Street and tour Madame Tussauds."}),
# (n10:Station {"id":"Edgware Road (B)", "displayName":"Edgware Road (B)", "type":"Station"}),
# (n11:Station {"id":"Paddington", "displayName":"Paddington", "type":"Station", "Latitude":"51.5153935002265", "Longitude":"-0.175736750265772", "Zone":"1", "Postcode":"W2 1RH", "Note":"Stroll along the canals at Paddington Basin and say hello to the Paddington Bear statue."}),
# (n12:Station {"id":"Warwick Avenue", "displayName":"Warwick Avenue", "type":"Station", "Latitude":"51.5231041380791", "Longitude":"-0.182953291113456", "Zone":"2", "Postcode":"W9 2PT", "Note":"Take a canal boat from Little Venice or watch a puppet show on the Puppet Theatre Barge."}),
# (n13:Station {"id":"Maida Vale", "displayName":"Maida Vale", "type":"Station", "Latitude":"51.5299947556212", "Longitude":"-0.185432644935856", "Zone":"2", "Postcode":"W9 1JS", "Note":"Explore Little Venice s canals and visit the BBC Maida Vale Studios exterior."}),
# (n14:Station {"id":"Kilburn Park", "displayName":"Kilburn Park", "type":"Station", "Latitude":"51.5351352218434", "Longitude":"-0.193966054939706", "Zone":"2", "Postcode":"NW6 5AD", "Note":"Walk to Maida Vale s canals or relax in Paddington Recreation Ground."}),
# (n15:Station {"id":"Queen's Park", "displayName":"Queen s Park", "type":"Station"}),
# (n16:Station {"id":"Kensal Green", "displayName":"Kensal Green", "type":"Station", "Latitude":"51.5305238487188", "Longitude":"-0.224713381138044", "Zone":"2", "Postcode":"NW10 5JT", "Note":"Walk through the historic Kensal Green Cemetery or enjoy a drink at Paradise by way of Kensal Green pub."}),
# (n17:Station {"id":"Willesden Junction", "displayName":"Willesden Junction", "type":"Station", "Latitude":"51.532233566617", "Longitude":"-0.243909139837678", "Zone":"3", "Postcode":"NW10 4RA", "Note":"Walk the Grand Union Canal and explore the industrial heritage of Old Oak Common."}),
# (n18:Station {"id":"Harlesden", "displayName":"Harlesden", "type":"Station", "Latitude":"51.5362579086204", "Longitude":"-0.257495670377017", "Zone":"3", "Postcode":"NW10 8UT", "Note":"Drop into the legendary Ace Cafe or see the Jubilee Clock at Harlesden High Street."}),
# (n19:Station {"id":"Stonebridge Park", "displayName":"Stonebridge Park", "type":"Station", "Latitude":"51.5439861056564", "Longitude":"-0.275400437104679", "Zone":"3", "Postcode":"NW10 0RW", "Note":"Walk along the Grand Union Canal by the Brent Reservoir (Welsh Harp) and stop at the Ace Cafe."}),
# (n20:Station {"id":"Wembley Central", "displayName":"Wembley Central", "type":"Station", "Latitude":"51.5518642975386", "Longitude":"-0.296392321916041", "Zone":"4", "Postcode":"HA9 6AG", "Note":"Attend events at Wembley Arena or watch a match at Wembley Stadium and shop at London Designer Outlet."}),
# (n21:Station {"id":"North Wembley", "displayName":"North Wembley", "type":"Station", "Latitude":"51.5623957964433", "Longitude":"-0.303948213913291", "Zone":"4", "Postcode":"HA0 3NT", "Note":"Walk to Wembley Stadium and the London Designer Outlet for shopping."}),
# (n22:Station {"id":"South Kenton", "displayName":"South Kenton", "type":"Station", "Latitude":"51.571043947551296", "Longitude":"-0.308142971762093", "Zone":"4", "Postcode":"HA9 8QT", "Note":"Play sports at Northwick Park and enjoy a drink at The Windermere pub."}),
# (n23:Station {"id":"Kenton", "displayName":"Kenton", "type":"Station", "Latitude":"51.5814957703514", "Longitude":"-0.315216860826321", "Zone":"4", "Postcode":"HA3 0XS", "Note":"Stroll around Northwick Park or relax in Kenton Recreation Ground."}),
# (n24:Station {"id":"Harrow & Wealdstone", "displayName":"Harrow & Wealdstone", "type":"Station", "Latitude":"51.5925940880877", "Longitude":"-0.334252678574127", "Zone":"5", "Postcode":"HA3 7RF", "Note":"nan"}),
# (n25:Station {"id":"West Ruislip", "displayName":"West Ruislip", "type":"Station", "Latitude":"51.5695871570355", "Longitude":"-0.437860134374038", "Zone":"6", "Postcode":"HA4 7WD", "Note":"Ride the miniature railway at Ruislip Lido and watch planes at RAF Northolt."}),
# (n26:Station {"id":"Ruislip Gardens", "displayName":"Ruislip Gardens", "type":"Station", "Latitude":"51.5599595105222", "Longitude":"-0.409294101374034", "Zone":"5", "Postcode":"HA4 6LG", "Note":"Walk the Yeading Brook Nature Reserve and visit the nearby Polish War Memorial."}),
# (n27:Station {"id":"South Ruislip", "displayName":"South Ruislip", "type":"Station", "Latitude":"51.556889651478", "Longitude":"-0.399115901006822", "Zone":"5", "Postcode":"HA4 6TP", "Note":"Visit the Polish War Memorial and watch planes at RAF Northolt."}),
# (n28:Station {"id":"Northolt", "displayName":"Northolt", "type":"Station", "Latitude":"51.5482123001801", "Longitude":"-0.36844058759762", "Zone":"5", "Postcode":"UB5 4AA", "Note":"Explore Northala Fields with its four man made hills and lakes."}),
# (n29:Station {"id":"Greenford", "displayName":"Greenford", "type":"Station", "Latitude":"51.5419795070146", "Longitude":"-0.345878733131022", "Zone":"4", "Postcode":"UB6 8PR", "Note":"Visit the London Motorcycle Museum or enjoy open space at Ravenor Park."}),
# (n30:Station {"id":"Perivale", "displayName":"Perivale", "type":"Station", "Latitude":"51.5363412946729", "Longitude":"-0.323070415901167", "Zone":"4", "Postcode":"UB6 7NP", "Note":"Admire the Art Deco Hoover Building and enjoy green space in Perivale Park."}),
# (n31:Station {"id":"Hanger Lane", "displayName":"Hanger Lane", "type":"Station", "Latitude":"51.5300715563412", "Longitude":"-0.292996140557165", "Zone":"3", "Postcode":"W5 1DL", "Note":"Marvel at the Hanger Lane gyratory and visit the nearby Ace Cafe, a motorcycling icon."}),
# (n32:Station {"id":"North Acton", "displayName":"North Acton", "type":"Station", "Latitude":"51.5234320046099", "Longitude":"-0.259729523922228", "Zone":"2", "Postcode":"W3 6UP", "Note":"Relax in North Acton Playing Fields and explore the new mixed use development of Acton Gardens."}),
# (n33:Station {"id":"Ealing Broadway", "displayName":"Ealing Broadway", "type":"Station", "Latitude":"51.5148614827794", "Longitude":"-0.302010376133626", "Zone":"3", "Postcode":"W5 2NU", "Note":"Visit Ealing Broadway Shopping Centre or relax in the landscaped Walpole Park."}),
# (n34:Station {"id":"West Acton", "displayName":"West Acton", "type":"Station", "Latitude":"51.517769693141", "Longitude":"-0.280657170904487", "Zone":"3", "Postcode":"W3 6UP", "Note":"Relax in North Acton Playing Fields and explore the Gunnersbury Triangle Nature Reserve."}),
# (n35:Station {"id":"East Acton", "displayName":"East Acton", "type":"Station", "Latitude":"51.5162630104536", "Longitude":"-0.248112221281314", "Zone":"2", "Postcode":"W12 0BP", "Note":"Stroll through Acton Park or head to Wormwood Scrubs for wide open spaces."}),
# (n36:Station {"id":"White City", "displayName":"White City", "type":"Station", "Latitude":"51.5122320722798", "Longitude":"-0.224631928515273", "Zone":"2", "Postcode":"W12 7RH", "Note":"Shop at Westfield London and see the redeveloped BBC Television Centre."}),
# (n37:Station {"id":"Shepherd's Bush (C)", "displayName":"Shepherd s Bush (C)", "type":"Station"}),
# (n38:Station {"id":"Holland Park", "displayName":"Holland Park", "type":"Station", "Latitude":"51.5071461481404", "Longitude":"-0.206557775412328", "Zone":"2", "Postcode":"W11 3RB", "Note":"Stroll through Holland Park and its Kyoto Garden for a Japanese oasis."}),
# (n39:Station {"id":"Notting Hill Gate", "displayName":"Notting Hill Gate", "type":"Station", "Latitude":"51.5093750180118", "Longitude":"-0.195921616226391", "Zone":"1", "Postcode":"W11 3HT", "Note":"Browse antiques at Portobello Road Market and watch a film at the Electric Cinema."}),
# (n40:Station {"id":"Queensway", "displayName":"Queensway", "type":"Station", "Latitude":"51.5104489285477", "Longitude":"-0.187419901048369", "Zone":"1", "Postcode":"W2 4SS", "Note":"Go ice skating at Queens Ice and Bowl or explore the redeveloped Whiteleys building."}),
# (n41:Station {"id":"Lancaster Gate", "displayName":"Lancaster Gate", "type":"Station", "Latitude":"51.511890658328305", "Longitude":"-0.175429926789792", "Zone":"1", "Postcode":"W2 4QH", "Note":"Admire the Italian Gardens in Hyde Park and the Lancaster Gate Hotel façade."}),
# (n42:Station {"id":"Marble Arch", "displayName":"Marble Arch", "type":"Station", "Latitude":"51.5139652346594", "Longitude":"-0.158571214792758", "Zone":"1", "Postcode":"W1C 2JS", "Note":"View the Marble Arch monument and Speaker s Corner at Hyde Park."}),
# (n43:Station {"id":"Bond Street", "displayName":"Bond Street", "type":"Station", "Latitude":"51.5137972823274", "Longitude":"-0.149613608531646", "Zone":"1", "Postcode":"W1C 2HU", "Note":"Shop luxury boutiques on Bond Street or high street stores along Oxford Street."}),
# (n44:Station {"id":"Tottenham Court Road", "displayName":"Tottenham Court Road", "type":"Station", "Latitude":"51.5162106579362", "Longitude":"-0.131110437940232", "Zone":"1", "Postcode":"W1D 2DA", "Note":"Watch a musical at the Dominion Theatre and browse electronics shops along Tottenham Court Road."}),
# (n45:Station {"id":"Holborn", "displayName":"Holborn", "type":"Station", "Latitude":"51.5172355413957", "Longitude":"-0.119840506602937", "Zone":"1", "Postcode":"WC2B 6AA", "Note":"Visit the British Museum and the Sir John Soane s Museum near Lincoln s Inn Fields."}),
# (n46:Station {"id":"Chancery Lane", "displayName":"Chancery Lane", "type":"Station", "Latitude":"51.5184938358199", "Longitude":"-0.111962026762417", "Zone":"1", "Postcode":"WC1V 6DR", "Note":"Visit the Sir John Soane s Museum or walk through the historic Inns of Court."}),
# (n47:Station {"id":"St. Paul's", "displayName":"St. Paul s", "type":"Station"}),
# (n48:Station {"id":"Bank and Monument", "displayName":"Bank and Monument", "type":"Station"}),
# (n49:Station {"id":"Liverpool Street", "displayName":"Liverpool Street", "type":"Station", "Latitude":"51.517598132254", "Longitude":"-0.0822496218888544", "Zone":"1", "Postcode":"EC2M 7PR", "Note":"Browse Old Spitalfields Market for food and crafts and admire the City s skyscrapers."}),
# (n50:Station {"id":"Bethnal Green", "displayName":"Bethnal Green", "type":"Station", "Latitude":"51.527191653122095", "Longitude":"-0.055392111450162", "Zone":"2", "Postcode":"E2 0ET", "Note":"The V&A Museum of Childhood displays toys and childhood culture in a charming hall."}),
# (n51:Station {"id":"Mile End", "displayName":"Mile End", "type":"Station", "Latitude":"51.5253109195645", "Longitude":"-0.0326660842711517", "Zone":"2", "Postcode":"E3 4DH", "Note":"Cycle through Mile End Park and visit the campus of Queen Mary University of London."}),
# (n52:Station {"id":"Stratford", "displayName":"Stratford", "type":"Station", "Latitude":"51.541692575874", "Longitude":"-0.0037516410271907", "Zone":"3", "Postcode":"E15 1AZ", "Note":"Explore Queen Elizabeth Olympic Park and shop at Westfield Stratford City."}),
# (n53:Station {"id":"Leyton", "displayName":"Leyton", "type":"Station", "Latitude":"51.5581322623127", "Longitude":"-0.006465331580603", "Zone":"3", "Postcode":"E10 5PS", "Note":"Visit Leyton Orient s Brisbane Road stadium and enjoy green space at Coronation Gardens."}),
# (n54:Station {"id":"Leytonstone", "displayName":"Leytonstone", "type":"Station", "Latitude":"51.5685223067262", "Longitude":"0.0091404519570612", "Zone":"3", "Postcode":"E11 1HE", "Note":"Spot Hitchcock mosaics in the tube station and stroll through Epping Forest s southern edge."}),
# (n55:Station {"id":"Snaresbrook", "displayName":"Snaresbrook", "type":"Station", "Latitude":"51.5808913115707", "Longitude":"0.021463927810755", "Zone":"4", "Postcode":"E11 1QE", "Note":"Walk around Eagle Pond and the ornamental lake in Epping Forest near Snaresbrook."}),
# (n56:Station {"id":"South Woodford", "displayName":"South Woodford", "type":"Station", "Latitude":"51.5915526647549", "Longitude":"0.0279430783744094", "Zone":"4", "Postcode":"E18 1JJ", "Note":"Walk in Epping Forest and shop along George Lane."}),
# (n57:Station {"id":"Woodford", "displayName":"Woodford", "type":"Station", "Latitude":"51.6072019027903", "Longitude":"0.034056202416626", "Zone":"4", "Postcode":"IG8 7QE", "Note":"Explore Epping Forest and play golf at Woodford Golf Club."}),
# (n58:Station {"id":"Buckhurst Hill", "displayName":"Buckhurst Hill", "type":"Station", "Latitude":"51.6265767400473", "Longitude":"0.0467125414287692", "Zone":"5", "Postcode":"IG9 5ET", "Note":"Explore Roding Valley Park or wander through Linder s Field Nature Reserve."}),
# (n59:Station {"id":"Loughton", "displayName":"Loughton", "type":"Station", "Latitude":"51.641570570828", "Longitude":"0.0552790792874479", "Zone":"6", "Postcode":"IG10 4PD", "Note":"Visit Epping Forest and shop along Loughton High Road."}),
# (n60:Station {"id":"Debden", "displayName":"Debden", "type":"Station", "Latitude":"51.6454921415259", "Longitude":"0.0838014752563246", "Zone":"6", "Postcode":"IG10 3TG", "Note":"Camp at Debden House and hike through Epping Forest s woodland."}),
# (n61:Station {"id":"Theydon Bois", "displayName":"Theydon Bois", "type":"Station", "Latitude":"51.67255225418", "Longitude":"0.102890736881682", "Zone":"6", "Postcode":"CM16 7EU", "Note":"Walk through Epping Forest and enjoy village pubs like the Queen Victoria."}),
# (n62:Station {"id":"Epping", "displayName":"Epping", "type":"Station", "Latitude":"51.693686354978", "Longitude":"0.113825553514212", "Zone":"6", "Postcode":"CM16 4HW", "Note":"Wander the ancient woodland of Epping Forest at the very end of the line."}),
# (n63:Station {"id":"Wanstead", "displayName":"Wanstead", "type":"Station", "Latitude":"51.57490219957089", "Longitude":"0.028760472436225", "Zone":"4", "Postcode":"E11 2NT", "Note":"Walk through Wanstead Park and explore Christchurch Green in the village centre."}),
# (n64:Station {"id":"Redbridge", "displayName":"Redbridge", "type":"Station", "Latitude":"51.5763669943606", "Longitude":"0.0453940440870774", "Zone":"4", "Postcode":"IG4 5BG", "Note":"Cycle at Redbridge Cycling Centre or walk through Wanstead Park and the ornamental lakes."}),
# (n65:Station {"id":"Gants Hill", "displayName":"Gants Hill", "type":"Station", "Latitude":"51.5765530629417", "Longitude":"0.0660840980631794", "Zone":"4", "Postcode":"IG2 6UD", "Note":"Stroll through Valentines Park and admire the station s striking Art Deco design."}),
# (n66:Station {"id":"Newbury Park", "displayName":"Newbury Park", "type":"Station", "Latitude":"51.5756385064638", "Longitude":"0.0903031581978967", "Zone":"4", "Postcode":"IG2 7RN", "Note":"Admire the station s Grade II listed bus shelter and walk to Valentines Park."}),
# (n67:Station {"id":"Barkingside", "displayName":"Barkingside", "type":"Station", "Latitude":"51.5858507614628", "Longitude":"0.0884766401059263", "Zone":"4", "Postcode":"IG6 1NB", "Note":"Learn about Barnardo s history at the Barnardo s Garden Village and roam Fairlop Waters park."}),
# (n68:Station {"id":"Fairlop", "displayName":"Fairlop", "type":"Station", "Latitude":"51.5961096941749", "Longitude":"0.0905932799159299", "Zone":"4", "Postcode":"IG6 3HD", "Note":"Sail or cycle around Fairlop Waters Country Park and its lake."}),
# (n69:Station {"id":"Hainault", "displayName":"Hainault", "type":"Station", "Latitude":"51.602845483752304", "Longitude":"0.0941085508301525", "Zone":"4", "Postcode":"IG6 3BD", "Note":"Walk the trails of Hainault Forest Country Park and visit Fox Burrow Farm."}),
# (n70:Station {"id":"Grange Hill", "displayName":"Grange Hill", "type":"Station", "Latitude":"51.6134805793354", "Longitude":"0.0922725301686921", "Zone":"4", "Postcode":"IG7 5QB", "Note":"Explore Hainault Forest Country Park just east of the station."}),
# (n71:Station {"id":"Chigwell", "displayName":"Chigwell", "type":"Station", "Latitude":"51.6178579997418", "Longitude":"0.0761792153523028", "Zone":"4", "Postcode":"IG7 6NT", "Note":"Play a round at Chigwell Golf Club or walk in Epping Forest s southern reaches."}),
# (n72:Station {"id":"Roding Valley", "displayName":"Roding Valley", "type":"Station", "Latitude":"51.6169565208123", "Longitude":"0.0440262071266385", "Zone":"4", "Postcode":"IG9 6LN", "Note":"Discover Roding Valley Meadows nature reserve, a haven for wildlife."}),
# (n73:Station {"id":"Ealing Common", "displayName":"Ealing Common", "type":"Station", "Latitude":"51.5102481879337", "Longitude":"-0.287151413105322", "Zone":"3", "Postcode":"W5 3LD", "Note":"Enjoy a picnic on Ealing Common and attend events at the annual Ealing Jazz and Blues festivals."}),
# (n74:Station {"id":"Acton Town", "displayName":"Acton Town", "type":"Station", "Latitude":"51.5030709863634", "Longitude":"-0.280302696832724", "Zone":"3", "Postcode":"W3 8HN", "Note":"Gunnersbury Park and Museum offer landscaped gardens and local history a short walk from the station."}),
# (n75:Station {"id":"Chiswick Park", "displayName":"Chiswick Park", "type":"Station", "Latitude":"51.49437027794271", "Longitude":"-0.267736917992298", "Zone":"3", "Postcode":"W4 5NE", "Note":"Tour the elegant Chiswick House and its beautiful gardens."}),
# (n76:Station {"id":"Turnham Green", "displayName":"Turnham Green", "type":"Station", "Latitude":"51.4951815268556", "Longitude":"-0.254524564284254", "Zone":"2", "Postcode":"W4 1LR", "Note":"Visit Chiswick High Road s boutiques and Hogarth s House near the green."}),
# (n77:Station {"id":"Richmond", "displayName":"Richmond", "type":"Station", "Latitude":"51.4632323939592", "Longitude":"-0.301739128704929", "Zone":"4", "Postcode":"TW9 2AZ", "Note":"Walk through Richmond Park to see the deer or along the riverside to Richmond Green."}),
# (n78:Station {"id":"Kew Gardens", "displayName":"Kew Gardens", "type":"Station", "Latitude":"51.4767886712304", "Longitude":"-0.285381006676174", "Zone":"9", "Postcode":"TW9 3PZ", "Note":"Explore the Royal Botanic Gardens, Kew and the treetop walkway."}),
# (n79:Station {"id":"Gunnersbury", "displayName":"Gunnersbury", "type":"Station", "Latitude":"51.4918629632299", "Longitude":"-0.27516413141625", "Zone":"3", "Postcode":"W4 5RP", "Note":"Relax in Gunnersbury Park and visit the London Transport Museum Depot."}),
# (n80:Station {"id":"Stamford Brook", "displayName":"Stamford Brook", "type":"Station", "Latitude":"51.4944495685697", "Longitude":"-0.245246306027922", "Zone":"2", "Postcode":"W6 0SB", "Note":"Relax in Ravenscourt Park or explore Chiswick High Road s shops and cafes."}),
# (n81:Station {"id":"Ravenscourt Park", "displayName":"Ravenscourt Park", "type":"Station", "Latitude":"51.494067596546", "Longitude":"-0.235969229860143", "Zone":"2", "Postcode":"W6 0UG", "Note":"Stroll through Ravenscourt Park and its walled garden and glasshouses."}),
# (n82:Station {"id":"Hammersmith", "displayName":"Hammersmith", "type":"Station", "Latitude":"51.4918194135572", "Longitude":"-0.222860925885304", "Zone":"2", "Postcode":"W6 9YA", "Note":"See a show at the Eventim Apollo and shop at Kings Mall."}),
# (n83:Station {"id":"Barons Court", "displayName":"Barons Court", "type":"Station", "Latitude":"51.490228334902", "Longitude":"-0.213430142417892", "Zone":"2", "Postcode":"W14 9DP", "Note":"Catch a tennis match at the Queen s Club or admire the Victorian architecture of St Paul s School."}),
# (n84:Station {"id":"West Kensington", "displayName":"West Kensington", "type":"Station", "Latitude":"51.4901090272106", "Longitude":"-0.206203692218027", "Zone":"2", "Postcode":"W14 9NL", "Note":"Watch matches at the Queen s Club and explore the Olympia London Exhibition Centre."}),
# (n85:Station {"id":"Earl's Court", "displayName":"Earl s Court", "type":"Station"}),
# (n86:Station {"id":"Wimbledon", "displayName":"Wimbledon", "type":"Station", "Latitude":"51.4211075087935", "Longitude":"-0.206662833440053", "Zone":"3", "Postcode":"SW19 1PS", "Note":"Visit the Wimbledon Lawn Tennis Museum at the All England Club and stroll through Wimbledon Village."}),
# (n87:Station {"id":"Wimbledon Park", "displayName":"Wimbledon Park", "type":"Station", "Latitude":"51.4345806287444", "Longitude":"-0.199186272973062", "Zone":"3", "Postcode":"SW19 7DZ", "Note":"Row on the lake at Wimbledon Park and watch tennis at the Wimbledon Club."}),
# (n88:Station {"id":"Southfields", "displayName":"Southfields", "type":"Station", "Latitude":"51.44488297741", "Longitude":"-0.206609383090931", "Zone":"3", "Postcode":"SW18 5RJ", "Note":"Visit the All England Lawn Tennis Club and its Wimbledon Lawn Tennis Museum."}),
# (n89:Station {"id":"East Putney", "displayName":"East Putney", "type":"Station", "Latitude":"51.4588794403538", "Longitude":"-0.210998231595942", "Zone":"2", "Postcode":"SW15 6SN", "Note":"Follow the Thames Path through Wandsworth Park and enjoy river views."}),
# (n90:Station {"id":"Putney Bridge", "displayName":"Putney Bridge", "type":"Station", "Latitude":"51.4678649970564", "Longitude":"-0.209365414301954", "Zone":"2", "Postcode":"SW6 3UH", "Note":"Visit the historic Fulham Palace and stroll through Bishops Park along the Thames."}),
# (n91:Station {"id":"Parsons Green", "displayName":"Parsons Green", "type":"Station", "Latitude":"51.4749598256595", "Longitude":"-0.201124490012253", "Zone":"2", "Postcode":"SW6 4HU", "Note":"Relax on Parsons Green, dine at the White Horse pub and browse New King s Road boutiques."}),
# (n92:Station {"id":"Fulham Broadway", "displayName":"Fulham Broadway", "type":"Station", "Latitude":"51.4802605857463", "Longitude":"-0.195544161527897", "Zone":"2", "Postcode":"SW6 1BY", "Note":"Tour Chelsea FC s Stamford Bridge stadium and museum."}),
# (n93:Station {"id":"West Brompton", "displayName":"West Brompton", "type":"Station", "Latitude":"51.4873285969614", "Longitude":"-0.195538809670428", "Zone":"2", "Postcode":"SW5 9JX", "Note":"Walk through Brompton Cemetery and catch a match at Stamford Bridge stadium."}),
# (n94:Station {"id":"Kensington (Olympia)", "displayName":"Kensington (Olympia)", "type":"Station"}),
# (n95:Station {"id":"High Street Kensington", "displayName":"High Street Kensington", "type":"Station", "Latitude":"51.5007291341687", "Longitude":"-0.191566055496419", "Zone":"1", "Postcode":"W8 5SA", "Note":"Visit Kensington Palace and stroll through Kensington Gardens."}),
# (n96:Station {"id":"Bayswater", "displayName":"Bayswater", "type":"Station", "Latitude":"51.5121109831796", "Longitude":"-0.187901571878205", "Zone":"1", "Postcode":"W2 4QH", "Note":"nan"}),
# (n97:Station {"id":"Edgware Road (C)", "displayName":"Edgware Road (C)", "type":"Station"}),
# (n98:Station {"id":"Gloucester Road", "displayName":"Gloucester Road", "type":"Station", "Latitude":"51.4944992596252", "Longitude":"-0.183543557571591", "Zone":"1", "Postcode":"SW7 4SF", "Note":"Walk to the Natural History Museum or Victoria & Albert Museum in nearby South Kensington."}),
# (n99:Station {"id":"South Kensington", "displayName":"South Kensington", "type":"Station", "Latitude":"51.4940710832552", "Longitude":"-0.17392302133764", "Zone":"1", "Postcode":"SW7 2NB", "Note":"Visit the Natural History, Science and Victoria & Albert museums in the Exhibition Road area."}),
# (n100:Station {"id":"Sloane Square", "displayName":"Sloane Square", "type":"Station", "Latitude":"51.4923595104806", "Longitude":"-0.156488856057024", "Zone":"1", "Postcode":"SW1W 8BB", "Note":"Browse the Saatchi Gallery and shop along the fashionable King s Road."}),
# (n101:Station {"id":"Victoria", "displayName":"Victoria", "type":"Station", "Latitude":"51.4964237195677", "Longitude":"-0.143920705126304", "Zone":"1", "Postcode":"SW1E 5JX", "Note":"Tour Buckingham Palace and watch the Changing of the Guard on The Mall."}),
# (n102:Station {"id":"St. James's Park", "displayName":"St. James s Park", "type":"Station", "Latitude":"51.4996095777261", "Longitude":"-0.133878754341125", "Zone":"1", "Postcode":"SW1H 0BD", "Note":"Walk through St James s Park to Buckingham Palace and watch the Changing of the Guard."}),
# (n103:Station {"id":"Westminster", "displayName":"Westminster", "type":"Station", "Latitude":"51.5014013891933", "Longitude":"-0.12500207834678", "Zone":"1", "Postcode":"SW1A 2JR", "Note":"Marvel at the Houses of Parliament and Big Ben and visit Westminster Abbey."}),
# (n104:Station {"id":"Temple", "displayName":"Temple", "type":"Station", "Latitude":"51.5110404236047", "Longitude":"-0.113725749531254", "Zone":"1", "Postcode":"WC2R 2PH", "Note":"Discover the historic Temple Church and stroll through Victoria Embankment Gardens."}),
# (n105:Station {"id":"Blackfriars", "displayName":"Blackfriars", "type":"Station", "Latitude":"51.511586761695", "Longitude":"-0.102995384624505", "Zone":"1", "Postcode":"EC4V 4DD", "Note":"Cross the Blackfriars Bridge to the Tate Modern or explore the riverside walkways."}),
# (n106:Station {"id":"Mansion House", "displayName":"Mansion House", "type":"Station", "Latitude":"51.5120915984511", "Longitude":"-0.0941976572437842", "Zone":"1", "Postcode":"EC4N 6JD", "Note":"See the Lord Mayor s official residence at Mansion House and walk to St Paul s Cathedral."}),
# (n107:Station {"id":"Cannon Street", "displayName":"Cannon Street", "type":"Station", "Latitude":"51.5113619437019", "Longitude":"-0.0902505264150348", "Zone":"1", "Postcode":"EC4N 6AP", "Note":"See the medieval London Stone and explore the garden of St Stephen Walbrook church."}),
# (n108:Station {"id":"Tower Hill", "displayName":"Tower Hill", "type":"Station", "Latitude":"51.5103941502293", "Longitude":"-0.0767011981209769", "Zone":"1", "Postcode":"EC3N 4DJ", "Note":"See the Crown Jewels at the Tower of London and join a Yeoman Warder tour."}),
# (n109:Station {"id":"Aldgate East", "displayName":"Aldgate East", "type":"Station", "Latitude":"51.5150815056987", "Longitude":"-0.0730014624207396", "Zone":"1", "Postcode":"E1 7PT", "Note":"Head to Brick Lane for famous curry houses, vintage shops and colourful street art."}),
# (n110:Station {"id":"Whitechapel", "displayName":"Whitechapel", "type":"Station", "Latitude":"51.5195876908872", "Longitude":"-0.0594204849881092", "Zone":"2", "Postcode":"E1 1BY", "Note":"See exhibitions at Whitechapel Gallery and eat along Brick Lane s curry mile."}),
# (n111:Station {"id":"Stepney Green", "displayName":"Stepney Green", "type":"Station", "Latitude":"51.5219957586155", "Longitude":"-0.0473825231948551", "Zone":"2", "Postcode":"E1 4AQ", "Note":"Watch independent films at Genesis Cinema and meet animals at Stepney City Farm."}),
# (n112:Station {"id":"Bow Road", "displayName":"Bow Road", "type":"Station", "Latitude":"51.5270417695097", "Longitude":"-0.0243595906326814", "Zone":"2", "Postcode":"E3 4DH", "Note":"Pop into the Bow Bells pub and learn local history at the Tower Hamlets Local History Library."}),
# (n113:Station {"id":"Bromley-by-Bow", "displayName":"Bromley-by-Bow", "type":"Station", "Latitude":"51.524840183700896", "Longitude":"-0.0116823743530454", "Zone":"2", "Postcode":"E3 3BT", "Note":"See the 18th century House Mill and relax at Three Mills Green."}),
# (n114:Station {"id":"West Ham", "displayName":"West Ham", "type":"Station", "Latitude":"51.528525530727", "Longitude":"0.0053173938327879", "Zone":"3", "Postcode":"E15 3BN", "Note":"Cheer on West Ham United at the London Stadium and explore Queen Elizabeth Olympic Park."}),
# (n115:Station {"id":"Plaistow", "displayName":"Plaistow", "type":"Station", "Latitude":"51.5312883668178", "Longitude":"0.0177806419969852", "Zone":"3", "Postcode":"E13 0DY", "Note":"Swim at Newham Leisure Centre or relax in Plaistow Park."}),
# (n116:Station {"id":"Upton Park", "displayName":"Upton Park", "type":"Station", "Latitude":"51.53662825987809", "Longitude":"0.0345418397236073", "Zone":"3", "Postcode":"E13 9AP", "Note":"Browse Queen s Market on Green Street and remember the former Boleyn Ground."}),
# (n117:Station {"id":"East Ham", "displayName":"East Ham", "type":"Station", "Latitude":"51.5392462519437", "Longitude":"0.0515162934805762", "Zone":"3", "Postcode":"E6 2JA", "Note":"Visit the Grade II listed East Ham Town Hall and wander through Plashet Park."}),
# (n118:Station {"id":"Barking", "displayName":"Barking", "type":"Station", "Latitude":"51.5395212483974", "Longitude":"0.0808316104030654", "Zone":"4", "Postcode":"IG11 8TU", "Note":"Discover the medieval ruins of Barking Abbey and the Tudor Eastbury Manor House."}),
# (n119:Station {"id":"Upney", "displayName":"Upney", "type":"Station", "Latitude":"51.5384058166655", "Longitude":"0.101531744664137", "Zone":"4", "Postcode":"IG11 9LS", "Note":"Explore Eastbrookend Country Park and visit Barking Abbey remains nearby."}),
# (n120:Station {"id":"Becontree", "displayName":"Becontree", "type":"Station", "Latitude":"51.539585619744", "Longitude":"0.126880292693594", "Zone":"5", "Postcode":"RM9 4TP", "Note":"Check out the Valence House Museum and enjoy a stroll in Parsloes Park."}),
# (n121:Station {"id":"Dagenham Heathway", "displayName":"Dagenham Heathway", "type":"Station", "Latitude":"51.5412120355014", "Longitude":"0.147679721474003", "Zone":"5", "Postcode":"RM9 5AN", "Note":"Shop along Heathway or relax in Parsloes Park s open spaces."}),
# (n122:Station {"id":"Dagenham East", "displayName":"Dagenham East", "type":"Station", "Latitude":"51.5441876132896", "Longitude":"0.165833433309167", "Zone":"5", "Postcode":"RM10 8AA", "Note":"Spot wildlife in Beam Valley Country Park or stroll through The Chase Nature Reserve."}),
# (n123:Station {"id":"Elm Park", "displayName":"Elm Park", "type":"Station", "Latitude":"51.5491249099079", "Longitude":"0.197252684283427", "Zone":"6", "Postcode":"RM12 4RW", "Note":"Stroll around Harrow Lodge Park and the lake at this suburban stop."}),
# (n124:Station {"id":"Hornchurch", "displayName":"Hornchurch", "type":"Station", "Latitude":"51.55435547079", "Longitude":"0.218926999411176", "Zone":"6", "Postcode":"RM12 6LS", "Note":"Watch a play at the Queen s Theatre and walk around Hornchurch Country Park."}),
# (n125:Station {"id":"Upminster Bridge", "displayName":"Upminster Bridge", "type":"Station", "Latitude":"51.5577191878009", "Longitude":"0.234541891929042", "Zone":"6", "Postcode":"RM12 6PL", "Note":"Visit the restored Upminster Windmill and play at Upminster Golf Club."}),
# (n126:Station {"id":"Upminster", "displayName":"Upminster", "type":"Station", "Latitude":"51.5587637710015", "Longitude":"0.251400804800992", "Zone":"6", "Postcode":"RM14 2TD", "Note":"Tour the Upminster Windmill and the Tithe Barn Agricultural Museum."}),
# (n127:Station {"id":"Woolwich Arsenal", "displayName":"Woolwich Arsenal", "type":"Station", "Latitude":"51.4899072325859", "Longitude":"0.0691939066943666", "Zone":"4", "Postcode":"SE18 6HX", "Note":"Explore the Royal Arsenal Riverside and take the Woolwich Ferry across the Thames."}),
# (n128:Station {"id":"King George V", "displayName":"King George V", "type":"Station", "Latitude":"51.5020087119328", "Longitude":"0.0622062141092917", "Zone":"3", "Postcode":"E16 2JF", "Note":"Visit Royal Victoria Gardens and Thames Barrier Park near this DLR stop."}),
# (n129:Station {"id":"London City Airport", "displayName":"London City Airport", "type":"Station", "Latitude":"51.5036897452474", "Longitude":"0.0478727155835259", "Zone":"3", "Postcode":"E16 2DS", "Note":"This station serves London City Airport for quick flights and business travel."}),
# (n130:Station {"id":"Pontoon Dock", "displayName":"Pontoon Dock", "type":"Station", "Latitude":"51.5022162729144", "Longitude":"0.0333257075489251", "Zone":"3", "Postcode":"E16 2SB", "Note":"Walk through Thames Barrier Park and admire the modern landscaping."}),
# (n131:Station {"id":"West Silvertown", "displayName":"West Silvertown", "type":"Station", "Latitude":"51.5028844739075", "Longitude":"0.0222460466810224", "Zone":"3", "Postcode":"E16 2AT", "Note":"Explore Thames Barrier Park and spot the Tate & Lyle Sugar Refinery across the water."}),
# (n132:Station {"id":"Canning Town", "displayName":"Canning Town", "type":"Station", "Latitude":"51.5138703035051", "Longitude":"0.0083056327487644", "Zone":"3", "Postcode":"E16 1DQ", "Note":"Ride the Emirates Air Line cable car across the Thames or visit the Crystal sustainability exhibition."}),
# (n133:Station {"id":"Beckton", "displayName":"Beckton", "type":"Station", "Latitude":"51.5143767330068", "Longitude":"0.0615252971597842", "Zone":"3", "Postcode":"E6 5NT", "Note":"Visit Newham City Farm or relax in Beckton District Park near this DLR stop."}),
# (n134:Station {"id":"Gallions Reach", "displayName":"Gallions Reach", "type":"Station", "Latitude":"51.5090342602489", "Longitude":"0.0717753947300296", "Zone":"3", "Postcode":"E6 6FZ", "Note":"Shop at Gallions Reach Retail Park or relax in Thames Barrier Park."}),
# (n135:Station {"id":"Cyprus", "displayName":"Cyprus", "type":"Station", "Latitude":"51.508526688501", "Longitude":"0.0638407560748753", "Zone":"3", "Postcode":"E6 5PH", "Note":"Visit the University of East London campus and enjoy waterside views at Royal Albert Dock."}),
# (n136:Station {"id":"Beckton Park", "displayName":"Beckton Park", "type":"Station", "Latitude":"51.5089008861867", "Longitude":"0.0548219390453979", "Zone":"3", "Postcode":"E6 5NE", "Note":"Walk along the Royal Albert Dock or explore the University of East London campus."}),
# (n137:Station {"id":"Royal Albert", "displayName":"Royal Albert", "type":"Station", "Latitude":"51.5084939463101", "Longitude":"0.0451771451896414", "Zone":"3", "Postcode":"E16 2QD", "Note":"Watch rowing at the London Regatta Centre or stroll along Royal Albert Dock."}),
# (n138:Station {"id":"Prince Regent", "displayName":"Prince Regent", "type":"Station", "Latitude":"51.5094346072403", "Longitude":"0.0334885741146772", "Zone":"3", "Postcode":"E16 3HE", "Note":"Access ExCeL London for exhibitions and explore Royal Victoria Dock."}),
# (n139:Station {"id":"Custom House", "displayName":"Custom House", "type":"Station", "Latitude":"51.5096221016304", "Longitude":"0.0257725103052806", "Zone":"3", "Postcode":"E16 3BX", "Note":"nan"}),
# (n140:Station {"id":"Royal Victoria", "displayName":"Royal Victoria", "type":"Station", "Latitude":"51.5090552671545", "Longitude":"0.0179654125889859", "Zone":"3", "Postcode":"E16 1DE", "Note":"Ride the Emirates Air Line cable car and explore Royal Victoria Dock."}),
# (n141:Station {"id":"Star Lane", "displayName":"Star Lane", "type":"Station", "Latitude":"51.5206042606449", "Longitude":"0.0041910026282406", "Zone":"3", "Postcode":"E16 4SR", "Note":"Enjoy community green space at Star Lane Park and admire the area s street art."}),
# (n142:Station {"id":"Abbey Road", "displayName":"Abbey Road", "type":"Station", "Latitude":"51.5319519954729", "Longitude":"0.0037233710983363", "Zone":"3", "Postcode":"E15 3NB", "Note":"Explore the historic House Mill and the Three Mills film studios near this Docklands station, showcasing industrial heritage on the River Lea."}),
# (n143:Station {"id":"Stratford High Street", "displayName":"Stratford High Street", "type":"Station", "Latitude":"51.5381489524464", "Longitude":"-0.0010803560037945", "Zone":"3", "Postcode":"E15 3PA", "Note":"Visit the ArcelorMittal Orbit and explore the aquatic centre at the Olympic Park."}),
# (n144:Station {"id":"Stratford International", "displayName":"Stratford International", "type":"Station", "Latitude":"51.5448085230875", "Longitude":"-0.0087784340129179", "Zone":"3", "Postcode":"E15 2LZ", "Note":"Access the International station and enjoy East Village s cafés and the Lee Valley VeloPark."}),
# (n145:Station {"id":"East India", "displayName":"East India", "type":"Station", "Latitude":"51.5086840050616", "Longitude":"-0.0023703315489933", "Zone":"2", "Postcode":"E14 9PS", "Note":"Walk along the East India Dock Basin nature reserve and visit Trinity Buoy Wharf."}),
# (n146:Station {"id":"Blackwall", "displayName":"Blackwall", "type":"Station", "Latitude":"51.507831531335", "Longitude":"-0.0072351658776662", "Zone":"2", "Postcode":"E14 9QB", "Note":"Visit Trinity Buoy Wharf with its lighthouse and arts venues on the Thames."}),
# (n147:Station {"id":"Poplar", "displayName":"Poplar", "type":"Station", "Latitude":"51.5075880448376", "Longitude":"-0.0172754932925174", "Zone":"2", "Postcode":"E14 0DS", "Note":"Relax in Poplar Recreation Ground and shop at Chrisp Street Market."}),
# (n148:Station {"id":"Westferry", "displayName":"Westferry", "type":"Station", "Latitude":"51.5096381074397", "Longitude":"-0.0263231371017839", "Zone":"2", "Postcode":"E14 8AD", "Note":"Visit the Museum of London Docklands and relax in West India Quay s restaurants."}),
# (n149:Station {"id":"Lewisham", "displayName":"Lewisham", "type":"Station", "Latitude":"51.4648806955123", "Longitude":"-0.0124327008980092", "Zone":"2", "Postcode":"SE13 7RY", "Note":"Shop at Lewisham Shopping Centre or swim at the Glass Mill Leisure Centre."}),
# (n150:Station {"id":"Elverson Road", "displayName":"Elverson Road", "type":"Station", "Latitude":"51.468372165038495", "Longitude":"-0.016816376196184", "Zone":"2", "Postcode":"SE8 4LA", "Note":"Walk through Brookmill Park along the River Ravensbourne."}),
# (n151:Station {"id":"Deptford Bridge", "displayName":"Deptford Bridge", "type":"Station", "Latitude":"51.4744767383948", "Longitude":"-0.0220524287742926", "Zone":"2", "Postcode":"SE10 8BU", "Note":"Explore Deptford High Street s markets and the Laban Dance Centre."}),
# (n152:Station {"id":"Greenwich", "displayName":"Greenwich", "type":"Station", "Latitude":"51.4775476425343", "Longitude":"-0.0148630836027375", "Zone":"2", "Postcode":"SE10 8JQ", "Note":"Tour the Cutty Sark, explore the National Maritime Museum and stand on the Prime Meridian at the Royal Observatory."}),
# (n153:Station {"id":"Cutty Sark", "displayName":"Cutty Sark", "type":"Station"}),
# (n154:Station {"id":"Island Gardens", "displayName":"Island Gardens", "type":"Station", "Latitude":"51.4879500735802", "Longitude":"-0.0104933031301963", "Zone":"2", "Postcode":"E14 3FA", "Note":"Enjoy riverside views from Island Gardens looking towards the Royal Naval College."}),
# (n155:Station {"id":"Mudchute", "displayName":"Mudchute", "type":"Station", "Latitude":"51.4912361634791", "Longitude":"-0.0149599448810793", "Zone":"2", "Postcode":"E14 9UW", "Note":"Feed the animals at Mudchute Park and Farm on the Isle of Dogs."}),
# (n156:Station {"id":"Crossharbour", "displayName":"Crossharbour", "type":"Station"}),
# (n157:Station {"id":"South Quay", "displayName":"South Quay", "type":"Station", "Latitude":"51.5008635789065", "Longitude":"-0.0184606926650221", "Zone":"2", "Postcode":"E14 9SH", "Note":"Stroll along South Dock Marina and dine at the waterfront restaurants."}),
# (n158:Station {"id":"Heron Quays", "displayName":"Heron Quays", "type":"Station", "Latitude":"51.5033865355316", "Longitude":"-0.0219535320363096", "Zone":"2", "Postcode":"E14 4JH", "Note":"Walk across the South Quay footbridge into Canary Wharf s skyscraper district."}),
# (n159:Station {"id":"Canary Wharf", "displayName":"Canary Wharf", "type":"Station", "Latitude":"51.5035783751289", "Longitude":"-0.0194668401393244", "Zone":"2", "Postcode":"E14 4QS", "Note":"Marvel at One Canada Square and wander through the Crossrail Place Roof Garden."}),
# (n160:Station {"id":"West India Quay", "displayName":"West India Quay", "type":"Station", "Latitude":"51.506762626601", "Longitude":"-0.0205824471280817", "Zone":"2", "Postcode":"E14 4ED", "Note":"Explore the Museum of London Docklands and dine at restaurants in old warehouses."}),
# (n161:Station {"id":"Limehouse", "displayName":"Limehouse", "type":"Station", "Latitude":"51.5123121016766", "Longitude":"-0.0393800776624937", "Zone":"2", "Postcode":"E14 7JD", "Note":"Admire boats in Limehouse Basin and have a drink at The Grapes pub on the riverside."}),
# (n162:Station {"id":"Shadwell", "displayName":"Shadwell", "type":"Station", "Latitude":"51.5113000646694", "Longitude":"-0.0569192069418581", "Zone":"2", "Postcode":"E1 2QE", "Note":"Explore Wilton s Music Hall and stroll around Shadwell Basin s docks."}),
# (n163:Station {"id":"Tower Gateway", "displayName":"Tower Gateway", "type":"Station", "Latitude":"51.5103925230575", "Longitude":"-0.0744098769115335", "Zone":"1", "Postcode":"EC3N 1JL", "Note":"Walk to the Tower of London and cross iconic Tower Bridge."}),
# (n164:Station {"id":"All Saints", "displayName":"All Saints", "type":"Station", "Latitude":"51.5104769064124", "Longitude":"-0.01262488536035", "Zone":"2", "Postcode":"E14 0EH", "Note":"Chrisp Street Market and the Lansbury Estate sit just outside this Docklands station."}),
# (n165:Station {"id":"Langdon Park", "displayName":"Langdon Park", "type":"Station", "Latitude":"51.5188839160837", "Longitude":"-0.0152137989477048", "Zone":"2", "Postcode":"E14 6NW", "Note":"Relax in Langdon Park and visit nearby Chrisp Street Market."}),
# (n166:Station {"id":"Devons Road", "displayName":"Devons Road", "type":"Station", "Latitude":"51.522258440743", "Longitude":"-0.0180077541751607", "Zone":"2", "Postcode":"E3 3QX", "Note":"Discover the brutalist Robin Hood Gardens estate and wander the peaceful Tower Hamlets Cemetery Park."}),
# (n167:Station {"id":"Bow Church", "displayName":"Bow Church", "type":"Station", "Latitude":"51.5276151727271", "Longitude":"-0.0204998991771464", "Zone":"2", "Postcode":"E3 3AA", "Note":"Admire the historic Bow Church and visit the Bow Arts Trust galleries."}),
# (n168:Station {"id":"Pudding Mill Lane", "displayName":"Pudding Mill Lane", "type":"Station", "Latitude":"51.5343278360506", "Longitude":"-0.0127685119445471", "Zone":"2", "Postcode":"E15 2PH", "Note":"Visit Queen Elizabeth Olympic Park and ascend the ArcelorMittal Orbit."}),
# (n169:Station {"id":"Moorgate", "displayName":"Moorgate", "type":"Station", "Latitude":"51.5184369958311", "Longitude":"-0.0890176874196191", "Zone":"1", "Postcode":"EC2M 6TX", "Note":"Tour the Guildhall Art Gallery or walk to the Museum of London at Barbican."}),
# (n170:Station {"id":"Barbican", "displayName":"Barbican", "type":"Station", "Latitude":"51.5202151261078", "Longitude":"-0.0977215780905023", "Zone":"1", "Postcode":"EC1A 4JA", "Note":"Experience concerts, films and exhibitions at the Barbican Centre, Europe s largest arts venue."}),
# (n171:Station {"id":"Farringdon", "displayName":"Farringdon", "type":"Station", "Latitude":"51.5201955191978", "Longitude":"-0.104843061316764", "Zone":"1", "Postcode":"EC1M 6BY", "Note":"Eat at historic Smithfield Market and explore the medieval Charterhouse complex."}),
# (n172:Station {"id":"King's Cross St. Pancras", "displayName":"King s Cross St. Pancras", "type":"Station"}),
# (n173:Station {"id":"Euston Square", "displayName":"Euston Square", "type":"Station", "Latitude":"51.528664114832", "Longitude":"-0.133296470819151", "Zone":"1", "Postcode":"NW1 2BN", "Note":"Discover exhibits at University College London and the Grant Museum of Zoology."}),
# (n174:Station {"id":"Great Portland Street", "displayName":"Great Portland Street", "type":"Station", "Latitude":"51.5237885627179", "Longitude":"-0.14396142408109", "Zone":"1", "Postcode":"W1W 5PP", "Note":"Visit Regent s Park and the Royal Institute of British Architects on Portland Place."}),
# (n175:Station {"id":"Royal Oak", "displayName":"Royal Oak", "type":"Station", "Latitude":"51.5182940459234", "Longitude":"-0.188823671546854", "Zone":"2", "Postcode":"W2 6ET", "Note":"nan"}),
# (n176:Station {"id":"Westbourne Park", "displayName":"Westbourne Park", "type":"Station", "Latitude":"51.5209885149093", "Longitude":"-0.200882512814746", "Zone":"2", "Postcode":"W11 1AB", "Note":"nan"}),
# (n177:Station {"id":"Ladbroke Grove", "displayName":"Ladbroke Grove", "type":"Station", "Latitude":"51.5172103317528", "Longitude":"-0.210198169891793", "Zone":"2", "Postcode":"W10 6HJ", "Note":"nan"}),
# (n178:Station {"id":"Latimer Road", "displayName":"Latimer Road", "type":"Station", "Latitude":"51.5139577448775", "Longitude":"-0.217459663317242", "Zone":"2", "Postcode":"W10 6SZ", "Note":"nan"}),
# (n179:Station {"id":"Wood Lane", "displayName":"Wood Lane", "type":"Station", "Latitude":"51.5096578296917", "Longitude":"-0.224472605709939", "Zone":"2", "Postcode":"W12 7DS", "Note":"nan"}),
# (n180:Station {"id":"Shepherd's Bush Market", "displayName":"Shepherd s Bush Market", "type":"Station"}),
# (n181:Station {"id":"Goldhawk Road", "displayName":"Goldhawk Road", "type":"Station", "Latitude":"51.5020765966368", "Longitude":"-0.227404003248823", "Zone":"2", "Postcode":"W12 8EG", "Note":"nan"}),
# (n182:Station {"id":"Bank", "displayName":"Bank", "type":"Station", "Latitude":"51.5133469191418", "Longitude":"-0.0890001234943747", "Zone":"1", "Postcode":"EC3V 3LA", "Note":"Explore the Bank of England Museum on Threadneedle Street and the Royal Exchange."}),
# (n183:Station {"id":"Aldgate", "displayName":"Aldgate", "type":"Station", "Latitude":"51.5143422574978", "Longitude":"-0.0756269123224863", "Zone":"1", "Postcode":"EC3N 1AH", "Note":"See the historic Aldgate Pump and visit the nearby Whitechapel Gallery for contemporary art."}),
# (n184:Station {"id":"Edgware Road", "displayName":"Edgware Road", "type":"Station", "Latitude":"51.5206450845361", "Longitude":"-0.17053954989974", "Zone":"1", "Postcode":"W2 1DY", "Note":"nan"}),
# (n185:Station {"id":"North Greenwich", "displayName":"North Greenwich", "type":"Station", "Latitude":"51.5002551610895", "Longitude":"0.0035862591259508", "Zone":"2", "Postcode":"SE10 0PH", "Note":"Enjoy a concert at The O2 Arena or ride the Emirates Air Line cable car."}),
# ...
# (n181)-[:CONNECTED {"Line":"Hammersmith & City"}]-(n82),
# (n181)-[:CONNECTED {"Line":"Hammersmith & City"}]-(n180),
# (n182)-[:CONNECTED {"Line":"Circle"}]-(n108),
# (n182)-[:CONNECTED {"Line":"Circle"}]-(n107),
# (n183)-[:CONNECTED {"Line":"Metropolitan"}]-(n49),
# (n183)-[:CONNECTED {"Line":"Circle"}]-(n108),
# (n185)-[:CONNECTED {"Line":"Jubilee"}]-(n159),
# (n185)-[:CONNECTED {"Line":"Jubilee"}]-(n132),
# (n186)-[:CONNECTED {"Line":"Jubilee"}]-(n187),
# (n186)-[:CONNECTED {"Line":"Jubilee"}]-(n159),
# (n186)-[:CONNECTED {"Line":"East London"}]-(n223),
# (n186)-[:CONNECTED {"Line":"East London"}]-(n211),
# (n187)-[:CONNECTED {"Line":"Jubilee"}]-(n188),
# (n187)-[:CONNECTED {"Line":"Jubilee"}]-(n186),
# (n188)-[:CONNECTED {"Line":"Jubilee"}]-(n189),
# (n188)-[:CONNECTED {"Line":"Jubilee"}]-(n187),
# (n188)-[:CONNECTED {"Line":"Northern"}]-(n48),
# (n188)-[:CONNECTED {"Line":"Northern"}]-(n272),
# (n189)-[:CONNECTED {"Line":"Jubilee"}]-(n2),
# (n189)-[:CONNECTED {"Line":"Jubilee"}]-(n188),
# (n190)-[:CONNECTED {"Line":"Jubilee"}]-(n43),
# (n190)-[:CONNECTED {"Line":"Jubilee"}]-(n103),
# (n190)-[:CONNECTED {"Line":"Piccadilly"}]-(n5),
# (n190)-[:CONNECTED {"Line":"Piccadilly"}]-(n313),
# (n190)-[:CONNECTED {"Line":"Victoria"}]-(n6),
# (n190)-[:CONNECTED {"Line":"Victoria"}]-(n101),
# (n191)-[:CONNECTED {"Line":"Jubilee"}]-(n192),
# (n191)-[:CONNECTED {"Line":"Jubilee"}]-(n8),
# (n192)-[:CONNECTED {"Line":"Jubilee"}]-(n193),
# (n192)-[:CONNECTED {"Line":"Jubilee"}]-(n191),
# (n193)-[:CONNECTED {"Line":"Jubilee"}]-(n194),
# (n193)-[:CONNECTED {"Line":"Jubilee"}]-(n192),
# (n193)-[:CONNECTED {"Line":"Metropolitan"}]-(n199),
# (n193)-[:CONNECTED {"Line":"Metropolitan"}]-(n8),
# (n194)-[:CONNECTED {"Line":"Jubilee"}]-(n195),
# (n194)-[:CONNECTED {"Line":"Jubilee"}]-(n193),
# (n195)-[:CONNECTED {"Line":"Jubilee"}]-(n196),
# (n195)-[:CONNECTED {"Line":"Jubilee"}]-(n194),
# (n196)-[:CONNECTED {"Line":"Jubilee"}]-(n197),
# (n196)-[:CONNECTED {"Line":"Jubilee"}]-(n195),
# (n197)-[:CONNECTED {"Line":"Jubilee"}]-(n198),
# (n197)-[:CONNECTED {"Line":"Jubilee"}]-(n196),
# (n198)-[:CONNECTED {"Line":"Jubilee"}]-(n199),
# (n198)-[:CONNECTED {"Line":"Jubilee"}]-(n197),
# (n199)-[:CONNECTED {"Line":"Jubilee"}]-(n200),
# (n199)-[:CONNECTED {"Line":"Jubilee"}]-(n198),
# (n199)-[:CONNECTED {"Line":"Metropolitan"}]-(n231),
# (n199)-[:CONNECTED {"Line":"Metropolitan"}]-(n193),
# (n200)-[:CONNECTED {"Line":"Jubilee"}]-(n201),
# (n200)-[:CONNECTED {"Line":"Jubilee"}]-(n199),
# (n201)-[:CONNECTED {"Line":"Jubilee"}]-(n202),
# (n201)-[:CONNECTED {"Line":"Jubilee"}]-(n200),
# (n202)-[:CONNECTED {"Line":"Jubilee"}]-(n203),
# (n202)-[:CONNECTED {"Line":"Jubilee"}]-(n201),
# (n203)-[:CONNECTED {"Line":"Jubilee"}]-(n202),
# (n204)-[:CONNECTED {"Line":"East London"}]-(n205),
# (n205)-[:CONNECTED {"Line":"East London"}]-(n207),
# (n205)-[:CONNECTED {"Line":"East London"}]-(n206),
# (n205)-[:CONNECTED {"Line":"East London"}]-(n204),
# (n206)-[:CONNECTED {"Line":"East London"}]-(n205),
# (n207)-[:CONNECTED {"Line":"East London"}]-(n208),
# (n207)-[:CONNECTED {"Line":"East London"}]-(n205),
# (n208)-[:CONNECTED {"Line":"East London"}]-(n209),
# (n208)-[:CONNECTED {"Line":"East London"}]-(n207),
# (n209)-[:CONNECTED {"Line":"East London"}]-(n210),
# (n209)-[:CONNECTED {"Line":"East London"}]-(n208),
# (n210)-[:CONNECTED {"Line":"East London"}]-(n211),
# (n210)-[:CONNECTED {"Line":"East London"}]-(n209),
# (n211)-[:CONNECTED {"Line":"East London"}]-(n186),
# (n211)-[:CONNECTED {"Line":"East London"}]-(n222),
# (n211)-[:CONNECTED {"Line":"East London"}]-(n221),
# (n211)-[:CONNECTED {"Line":"East London"}]-(n210),
# (n212)-[:CONNECTED {"Line":"East London"}]-(n213),
# (n213)-[:CONNECTED {"Line":"East London"}]-(n218),
# (n213)-[:CONNECTED {"Line":"East London"}]-(n217),
# (n213)-[:CONNECTED {"Line":"East London"}]-(n212),
# (n214)-[:CONNECTED {"Line":"East London"}]-(n215),
# (n215)-[:CONNECTED {"Line":"East London"}]-(n216),
# (n215)-[:CONNECTED {"Line":"East London"}]-(n214),
# (n216)-[:CONNECTED {"Line":"East London"}]-(n217),
# (n216)-[:CONNECTED {"Line":"East London"}]-(n215),
# (n217)-[:CONNECTED {"Line":"East London"}]-(n213),
# (n217)-[:CONNECTED {"Line":"East London"}]-(n216),
# (n218)-[:CONNECTED {"Line":"East London"}]-(n219),
# (n218)-[:CONNECTED {"Line":"East London"}]-(n213),
# (n219)-[:CONNECTED {"Line":"East London"}]-(n220),
# (n219)-[:CONNECTED {"Line":"East London"}]-(n218),
# (n220)-[:CONNECTED {"Line":"East London"}]-(n221),
# (n220)-[:CONNECTED {"Line":"East London"}]-(n219),
# (n221)-[:CONNECTED {"Line":"East London"}]-(n211),
# (n221)-[:CONNECTED {"Line":"East London"}]-(n220),
# (n222)-[:CONNECTED {"Line":"East London"}]-(n211),
# (n223)-[:CONNECTED {"Line":"East London"}]-(n224),
# (n223)-[:CONNECTED {"Line":"East London"}]-(n186),
# (n224)-[:CONNECTED {"Line":"East London"}]-(n162),
# (n224)-[:CONNECTED {"Line":"East London"}]-(n223),
# (n225)-[:CONNECTED {"Line":"East London"}]-(n226),
# (n225)-[:CONNECTED {"Line":"East London"}]-(n110),
# (n226)-[:CONNECTED {"Line":"East London"}]-(n227),
# (n226)-[:CONNECTED {"Line":"East London"}]-(n225),
# (n227)-[:CONNECTED {"Line":"East London"}]-(n228),
# (n227)-[:CONNECTED {"Line":"East London"}]-(n226),
# (n228)-[:CONNECTED {"Line":"East London"}]-(n229),
# (n228)-[:CONNECTED {"Line":"East London"}]-(n227),
# (n229)-[:CONNECTED {"Line":"East London"}]-(n230),
# (n229)-[:CONNECTED {"Line":"East London"}]-(n228),
# (n230)-[:CONNECTED {"Line":"East London"}]-(n229),
# (n230)-[:CONNECTED {"Line":"Victoria"}]-(n319),
# (n230)-[:CONNECTED {"Line":"Victoria"}]-(n172),
# (n231)-[:CONNECTED {"Line":"Metropolitan"}]-(n232),
# (n231)-[:CONNECTED {"Line":"Metropolitan"}]-(n199),
# (n232)-[:CONNECTED {"Line":"Metropolitan"}]-(n233),
# (n232)-[:CONNECTED {"Line":"Metropolitan"}]-(n231),
# (n233)-[:CONNECTED {"Line":"Metropolitan"}]-(n234),
# (n233)-[:CONNECTED {"Line":"Metropolitan"}]-(n246),
# (n233)-[:CONNECTED {"Line":"Metropolitan"}]-(n232),
# (n234)-[:CONNECTED {"Line":"Metropolitan"}]-(n235),
# (n234)-[:CONNECTED {"Line":"Metropolitan"}]-(n233),
# (n235)-[:CONNECTED {"Line":"Metropolitan"}]-(n236),
# (n235)-[:CONNECTED {"Line":"Metropolitan"}]-(n234),
# (n236)-[:CONNECTED {"Line":"Metropolitan"}]-(n237),
# (n236)-[:CONNECTED {"Line":"Metropolitan"}]-(n235),
# (n237)-[:CONNECTED {"Line":"Metropolitan"}]-(n238),
# (n237)-[:CONNECTED {"Line":"Metropolitan"}]-(n236),
# (n238)-[:CONNECTED {"Line":"Metropolitan"}]-(n239),
# (n238)-[:CONNECTED {"Line":"Metropolitan"}]-(n241),
# (n238)-[:CONNECTED {"Line":"Metropolitan"}]-(n237),
# (n239)-[:CONNECTED {"Line":"Metropolitan"}]-(n240),
# (n239)-[:CONNECTED {"Line":"Metropolitan"}]-(n238),
# (n240)-[:CONNECTED {"Line":"Metropolitan"}]-(n239),
# (n241)-[:CONNECTED {"Line":"Metropolitan"}]-(n242),
# (n241)-[:CONNECTED {"Line":"Metropolitan"}]-(n238),
# (n242)-[:CONNECTED {"Line":"Metropolitan"}]-(n243),
# (n242)-[:CONNECTED {"Line":"Metropolitan"}]-(n241),
# (n243)-[:CONNECTED {"Line":"Metropolitan"}]-(n244),
# (n243)-[:CONNECTED {"Line":"Metropolitan"}]-(n245),
# (n243)-[:CONNECTED {"Line":"Metropolitan"}]-(n242),
# (n244)-[:CONNECTED {"Line":"Metropolitan"}]-(n243),
# (n245)-[:CONNECTED {"Line":"Metropolitan"}]-(n243),
# (n246)-[:CONNECTED {"Line":"Metropolitan"}]-(n247),
# (n246)-[:CONNECTED {"Line":"Metropolitan"}]-(n233),
# (n247)-[:CONNECTED {"Line":"Piccadilly"}]-(n248),
# (n247)-[:CONNECTED {"Line":"Metropolitan"}]-(n246),
# (n247)-[:CONNECTED {"Line":"Piccadilly"}]-(n295),
# (n248)-[:CONNECTED {"Line":"Piccadilly"}]-(n249),
# (n248)-[:CONNECTED {"Line":"Piccadilly"}]-(n247),
# (n249)-[:CONNECTED {"Line":"Piccadilly"}]-(n250),
# (n249)-[:CONNECTED {"Line":"Piccadilly"}]-(n248),
# (n250)-[:CONNECTED {"Line":"Piccadilly"}]-(n251),
# (n250)-[:CONNECTED {"Line":"Piccadilly"}]-(n249),
# (n251)-[:CONNECTED {"Line":"Piccadilly"}]-(n252),
# (n251)-[:CONNECTED {"Line":"Piccadilly"}]-(n250),
# (n252)-[:CONNECTED {"Line":"Piccadilly"}]-(n253),
# (n252)-[:CONNECTED {"Line":"Piccadilly"}]-(n251),
# (n253)-[:CONNECTED {"Line":"Piccadilly"}]-(n252),
# (n254)-[:CONNECTED {"Line":"Northern"}]-(n255),
# (n255)-[:CONNECTED {"Line":"Northern"}]-(n256),
# (n255)-[:CONNECTED {"Line":"Northern"}]-(n254),
# (n256)-[:CONNECTED {"Line":"Northern"}]-(n257),
# (n256)-[:CONNECTED {"Line":"Northern"}]-(n255),
# (n257)-[:CONNECTED {"Line":"Northern"}]-(n258),
# (n257)-[:CONNECTED {"Line":"Northern"}]-(n256),
# (n258)-[:CONNECTED {"Line":"Northern"}]-(n259),
# (n258)-[:CONNECTED {"Line":"Northern"}]-(n257),
# (n259)-[:CONNECTED {"Line":"Northern"}]-(n260),
# (n259)-[:CONNECTED {"Line":"Northern"}]-(n258),
# (n260)-[:CONNECTED {"Line":"Northern"}]-(n261),
# (n260)-[:CONNECTED {"Line":"Northern"}]-(n259),
# (n261)-[:CONNECTED {"Line":"Northern"}]-(n262),
# (n261)-[:CONNECTED {"Line":"Northern"}]-(n260),
# (n262)-[:CONNECTED {"Line":"Northern"}]-(n263),
# (n262)-[:CONNECTED {"Line":"Northern"}]-(n261),
# (n263)-[:CONNECTED {"Line":"Northern"}]-(n264),
# (n263)-[:CONNECTED {"Line":"Northern"}]-(n262),
# (n263)-[:CONNECTED {"Line":"Victoria"}]-(n329),
# (n263)-[:CONNECTED {"Line":"Victoria"}]-(n328),
# (n264)-[:CONNECTED {"Line":"Northern"}]-(n265),
# (n264)-[:CONNECTED {"Line":"Northern"}]-(n263),
# (n265)-[:CONNECTED {"Line":"Northern"}]-(n2),
# (n265)-[:CONNECTED {"Line":"Northern"}]-(n0),
# (n265)-[:CONNECTED {"Line":"Northern"}]-(n264),
# (n266)-[:CONNECTED {"Line":"Northern"}]-(n44),
# (n266)-[:CONNECTED {"Line":"Northern"}]-(n4),
# (n266)-[:CONNECTED {"Line":"Piccadilly"}]-(n314),
# (n266)-[:CONNECTED {"Line":"Piccadilly"}]-(n5),
# (n267)-[:CONNECTED {"Line":"Northern"}]-(n268),
# (n267)-[:CONNECTED {"Line":"Northern"}]-(n44),
# (n268)-[:CONNECTED {"Line":"Victoria"}]-(n269),
# (n268)-[:CONNECTED {"Line":"Northern"}]-(n267),
# (n268)-[:CONNECTED {"Line":"Victoria"}]-(n6),
# (n269)-[:CONNECTED {"Line":"Northern"}]-(n270),
# (n269)-[:CONNECTED {"Line":"Northern"}]-(n271),
# (n269)-[:CONNECTED {"Line":"Victoria"}]-(n268),
# (n269)-[:CONNECTED {"Line":"Victoria"}]-(n172),
# (n270)-[:CONNECTED {"Line":"Northern"}]-(n271),
# (n270)-[:CONNECTED {"Line":"Northern"}]-(n269),
# (n271)-[:CONNECTED {"Line":"Northern"}]-(n275),
# (n271)-[:CONNECTED {"Line":"Northern"}]-(n286),
# (n271)-[:CONNECTED {"Line":"Northern"}]-(n270),
# (n271)-[:CONNECTED {"Line":"Northern"}]-(n269),
# (n272)-[:CONNECTED {"Line":"Northern"}]-(n188),
# (n272)-[:CONNECTED {"Line":"Northern"}]-(n0),
# (n273)-[:CONNECTED {"Line":"Northern"}]-(n274),
# (n273)-[:CONNECTED {"Line":"Northern"}]-(n169),
# (n274)-[:CONNECTED {"Line":"Northern"}]-(n172),
# (n274)-[:CONNECTED {"Line":"Northern"}]-(n273),
# (n275)-[:CONNECTED {"Line":"Northern"}]-(n276),
# (n275)-[:CONNECTED {"Line":"Northern"}]-(n271),
# (n276)-[:CONNECTED {"Line":"Northern"}]-(n277),
# (n276)-[:CONNECTED {"Line":"Northern"}]-(n275),
# (n277)-[:CONNECTED {"Line":"Northern"}]-(n278),
# (n277)-[:CONNECTED {"Line":"Northern"}]-(n276),
# (n278)-[:CONNECTED {"Line":"Northern"}]-(n279),
# (n278)-[:CONNECTED {"Line":"Northern"}]-(n277),
# (n279)-[:CONNECTED {"Line":"Northern"}]-(n280),
# (n279)-[:CONNECTED {"Line":"Northern"}]-(n278),
# (n280)-[:CONNECTED {"Line":"Northern"}]-(n281),
# (n280)-[:CONNECTED {"Line":"Northern"}]-(n282),
# (n280)-[:CONNECTED {"Line":"Northern"}]-(n279),
# (n281)-[:CONNECTED {"Line":"Northern"}]-(n280),
# (n282)-[:CONNECTED {"Line":"Northern"}]-(n283),
# (n282)-[:CONNECTED {"Line":"Northern"}]-(n280),
# (n283)-[:CONNECTED {"Line":"Northern"}]-(n284),
# (n283)-[:CONNECTED {"Line":"Northern"}]-(n282),
# (n284)-[:CONNECTED {"Line":"Northern"}]-(n285),
# (n284)-[:CONNECTED {"Line":"Northern"}]-(n283),
# (n285)-[:CONNECTED {"Line":"Northern"}]-(n284),
# (n286)-[:CONNECTED {"Line":"Northern"}]-(n287),
# (n286)-[:CONNECTED {"Line":"Northern"}]-(n271),
# (n287)-[:CONNECTED {"Line":"Northern"}]-(n288),
# (n287)-[:CONNECTED {"Line":"Northern"}]-(n286),
# (n288)-[:CONNECTED {"Line":"Northern"}]-(n289),
# (n288)-[:CONNECTED {"Line":"Northern"}]-(n287),
# (n289)-[:CONNECTED {"Line":"Northern"}]-(n290),
# (n289)-[:CONNECTED {"Line":"Northern"}]-(n288),
# (n290)-[:CONNECTED {"Line":"Northern"}]-(n291),
# (n290)-[:CONNECTED {"Line":"Northern"}]-(n289),
# (n291)-[:CONNECTED {"Line":"Northern"}]-(n292),
# (n291)-[:CONNECTED {"Line":"Northern"}]-(n290),
# (n292)-[:CONNECTED {"Line":"Northern"}]-(n293),
# (n292)-[:CONNECTED {"Line":"Northern"}]-(n291),
# (n293)-[:CONNECTED {"Line":"Northern"}]-(n294),
# (n293)-[:CONNECTED {"Line":"Northern"}]-(n292),
# (n294)-[:CONNECTED {"Line":"Northern"}]-(n293),
# (n295)-[:CONNECTED {"Line":"Piccadilly"}]-(n296),
# (n295)-[:CONNECTED {"Line":"Piccadilly"}]-(n247),
# (n296)-[:CONNECTED {"Line":"Piccadilly"}]-(n297),
# (n296)-[:CONNECTED {"Line":"Piccadilly"}]-(n295),
# (n297)-[:CONNECTED {"Line":"Piccadilly"}]-(n298),
# (n297)-[:CONNECTED {"Line":"Piccadilly"}]-(n296),
# (n298)-[:CONNECTED {"Line":"Piccadilly"}]-(n299),
# (n298)-[:CONNECTED {"Line":"Piccadilly"}]-(n297),
# (n299)-[:CONNECTED {"Line":"Piccadilly"}]-(n300),
# (n299)-[:CONNECTED {"Line":"Piccadilly"}]-(n298),
# (n300)-[:CONNECTED {"Line":"Piccadilly"}]-(n73),
# (n300)-[:CONNECTED {"Line":"Piccadilly"}]-(n299),
# (n301)-[:CONNECTED {"Line":"Piccadilly"}]-(n302),
# (n302)-[:CONNECTED {"Line":"Piccadilly"}]-(n304),
# (n302)-[:CONNECTED {"Line":"Piccadilly"}]-(n301),
# (n303)-[:CONNECTED {"Line":"Piccadilly"}]-(n302),
# (n304)-[:CONNECTED {"Line":"Piccadilly"}]-(n305),
# (n304)-[:CONNECTED {"Line":"Piccadilly"}]-(n303),
# (n304)-[:CONNECTED {"Line":"Piccadilly"}]-(n302),
# (n305)-[:CONNECTED {"Line":"Piccadilly"}]-(n306),
# (n305)-[:CONNECTED {"Line":"Piccadilly"}]-(n304),
# (n306)-[:CONNECTED {"Line":"Piccadilly"}]-(n307),
# (n306)-[:CONNECTED {"Line":"Piccadilly"}]-(n305),
# (n307)-[:CONNECTED {"Line":"Piccadilly"}]-(n308),
# (n307)-[:CONNECTED {"Line":"Piccadilly"}]-(n306),
# (n308)-[:CONNECTED {"Line":"Piccadilly"}]-(n309),
# (n308)-[:CONNECTED {"Line":"Piccadilly"}]-(n307),
# (n309)-[:CONNECTED {"Line":"Piccadilly"}]-(n310),
# (n309)-[:CONNECTED {"Line":"Piccadilly"}]-(n308),
# (n310)-[:CONNECTED {"Line":"Piccadilly"}]-(n311),
# (n310)-[:CONNECTED {"Line":"Piccadilly"}]-(n309),
# (n311)-[:CONNECTED {"Line":"Piccadilly"}]-(n74),
# (n311)-[:CONNECTED {"Line":"Piccadilly"}]-(n310),
# (n312)-[:CONNECTED {"Line":"Piccadilly"}]-(n313),
# (n312)-[:CONNECTED {"Line":"Piccadilly"}]-(n99),
# (n313)-[:CONNECTED {"Line":"Piccadilly"}]-(n190),
# (n313)-[:CONNECTED {"Line":"Piccadilly"}]-(n312),
# (n314)-[:CONNECTED {"Line":"Piccadilly"}]-(n45),
# (n314)-[:CONNECTED {"Line":"Piccadilly"}]-(n266),
# (n315)-[:CONNECTED {"Line":"Piccadilly"}]-(n172),
# (n315)-[:CONNECTED {"Line":"Piccadilly"}]-(n45),
# (n316)-[:CONNECTED {"Line":"Piccadilly"}]-(n317),
# (n316)-[:CONNECTED {"Line":"Piccadilly"}]-(n172),
# (n317)-[:CONNECTED {"Line":"Piccadilly"}]-(n318),
# (n317)-[:CONNECTED {"Line":"Piccadilly"}]-(n316),
# (n318)-[:CONNECTED {"Line":"Piccadilly"}]-(n319),
# (n318)-[:CONNECTED {"Line":"Piccadilly"}]-(n317),
# (n319)-[:CONNECTED {"Line":"Piccadilly"}]-(n320),
# (n319)-[:CONNECTED {"Line":"Piccadilly"}]-(n318),
# (n319)-[:CONNECTED {"Line":"Victoria"}]-(n331),
# (n319)-[:CONNECTED {"Line":"Victoria"}]-(n230),
# (n320)-[:CONNECTED {"Line":"Piccadilly"}]-(n321),
# (n320)-[:CONNECTED {"Line":"Piccadilly"}]-(n319),
# (n321)-[:CONNECTED {"Line":"Piccadilly"}]-(n322),
# (n321)-[:CONNECTED {"Line":"Piccadilly"}]-(n320),
# (n322)-[:CONNECTED {"Line":"Piccadilly"}]-(n323),
# (n322)-[:CONNECTED {"Line":"Piccadilly"}]-(n321),
# (n323)-[:CONNECTED {"Line":"Piccadilly"}]-(n324),
# (n323)-[:CONNECTED {"Line":"Piccadilly"}]-(n322),
# (n324)-[:CONNECTED {"Line":"Piccadilly"}]-(n325),
# (n324)-[:CONNECTED {"Line":"Piccadilly"}]-(n323),
# (n325)-[:CONNECTED {"Line":"Piccadilly"}]-(n326),
# (n325)-[:CONNECTED {"Line":"Piccadilly"}]-(n324),
# (n326)-[:CONNECTED {"Line":"Piccadilly"}]-(n327),
# (n326)-[:CONNECTED {"Line":"Piccadilly"}]-(n325),
# (n327)-[:CONNECTED {"Line":"Piccadilly"}]-(n326),
# (n328)-[:CONNECTED {"Line":"Victoria"}]-(n263),
# (n329)-[:CONNECTED {"Line":"Victoria"}]-(n330),
# (n329)-[:CONNECTED {"Line":"Victoria"}]-(n263),
# (n330)-[:CONNECTED {"Line":"Victoria"}]-(n101),
# (n330)-[:CONNECTED {"Line":"Victoria"}]-(n329),
# (n331)-[:CONNECTED {"Line":"Victoria"}]-(n332),
# (n331)-[:CONNECTED {"Line":"Victoria"}]-(n319),
# (n332)-[:CONNECTED {"Line":"Victoria"}]-(n333),
# (n332)-[:CONNECTED {"Line":"Victoria"}]-(n331),
# (n333)-[:CONNECTED {"Line":"Victoria"}]-(n334),
# (n333)-[:CONNECTED {"Line":"Victoria"}]-(n332),
# (n334)-[:CONNECTED {"Line":"Victoria"}]-(n333)
# ****************************************************************************************************

# %%
# %%time

# Run CREATE command
client.query(create_command)

# Commit the change
client.query("COMMIT")
client.query("CHANGE SUBMIT")

# Checkout into main
client.checkout()
# Out:
# CPU times: user 6.62 ms, sys: 1.09 ms, total: 7.71 ms
# Wall time: 145 ms

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         Visualize your graph in TuringDB Graph Visualizer ! Now that your instance is running:
#     </h2>
#     <h3>
#         <ul>
#             <li>Go to <a href="https://console.turingdb.ai/databases">TuringDB Console - Database Instances</a></li>
#             <li>In your current instance panel, click on "Open Visualizer" button</li>
#             <li>Visualizer opens, now you can choose your graph in the dropdown menu at the top-right corner</li>
#         </ul>
#         You can then play with your graph and visualize the nodes you want !
#     </h3>
# </div>

# %% [markdown]
# # Query TuringDB

# %% [markdown]
# ## Use metaqueries to have insight on graph overall structure
#
# <h3>
#     To learn more about 📮 Metaqueries, please check TuringDB documentation on this <a href="https://turingdb.mintlify.app/query/cypher_subset#%F0%9F%93%AE-metaqueries">link</a>
# </h3>

# %%
# %%time

# CALL LABELS () - returns a column of all the different node labels
command = """
CALL LABELS()
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = ["Node_type_ID", "Node_type"]
    display(df)
# Out:
#    Node_type_ID Node_type
# 0             0   Station
# CPU times: user 8.65 ms, sys: 47 μs, total: 8.7 ms
# Wall time: 7.22 ms

# %%
# %%time

# CALL EDGETYPES() - returns a column of all the different edge types (edge equivalent of node labels)
command = """
CALL EDGETYPES()
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = ["Edge_type_ID", "Edge_type"]
    display(df)
# Out:
#    Edge_type_ID  Edge_type
# 0             0  CONNECTED
# CPU times: user 6.78 ms, sys: 1.04 ms, total: 7.82 ms
# Wall time: 6.6 ms

# %% [markdown]
# ## Simple queries

# %%
# %%time

# Match all edges and return them - all links between two stations
command = """
MATCH (n)-[e]-(m)
RETURN n.displayName, e.Line, m.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#         n.displayName       e.Line         m.displayName
# 0           Canonbury  East London      Dalston Junction
# 1           Canonbury  East London  Highbury & Islington
# 2    Dalston Junction  East London            Haggerston
# 3    Dalston Junction  East London             Canonbury
# 4          Haggerston  East London                Hoxton
# ..                ...          ...                   ...
# 766     Cannon Street       Circle                  Bank
# 767     Mansion House       Circle           Blackfriars
# 768     Mansion House       Circle         Cannon Street
# 769       Blackfriars       Circle                Temple
# 770       Blackfriars       Circle         Mansion House
#
# [771 rows x 3 columns]
# CPU times: user 11.5 ms, sys: 1.93 ms, total: 13.4 ms
# Wall time: 11.8 ms

# %%
# %%time

# Check if there exists a path between Hoxton Station and South Kensington in 1 hop
command = """
MATCH (start{displayName: "Hoxton Station"})--(end{displayName:"South Kensington"})
RETURN start,end
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
# No result found
# CPU times: user 2.68 ms, sys: 0 ns, total: 2.68 ms
# Wall time: 2.22 ms

# %%
# %%time

# Check if there exists a path between Blackfriars and Mansion House in 1 hop
command = """
MATCH (start{displayName: "Blackfriars"})--(end{displayName:"Mansion House"})
RETURN start, start.displayName, end, end.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#    start start.displayName  end end.displayName
# 0    334       Blackfriars  333   Mansion House
# CPU times: user 9.37 ms, sys: 70 μs, total: 9.44 ms
# Wall time: 8.06 ms

# %%
# %%time

# Check if there exists a path between Victoria and South Kensington in 2 hops
command = """
MATCH (start{displayName: "Victoria"})--(s1)--(end{displayName:"South Kensington"})
RETURN start, start.displayName, s1, s1.displayName, end, end.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#    start start.displayName   s1 s1.displayName  end   end.displayName
# 0    296          Victoria  297  Sloane Square  298  South Kensington
# CPU times: user 9.18 ms, sys: 1.01 ms, total: 10.2 ms
# Wall time: 8.91 ms

# %%
# %%time

# Check if there exists a path between Victoria and South Kensington in 1 hop specifically using District Line
command = """
MATCH (start{displayName: "Victoria"})-[:line{displayName:"District"}]-(end{displayName:"South Kensington"})
RETURN start, end
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
# No result found
# CPU times: user 3.56 ms, sys: 81 μs, total: 3.64 ms
# Wall time: 2.35 ms

# %%
# %%time

# Check if there exists a path between Notting Hill Gate and High Street Kensington in 1 hop specifically using Circle Line
command = """
MATCH (start{displayName: "Notting Hill Gate"})-[e:CONNECTED{Line:"Circle"}]-(end{displayName:"High Street Kensington"})
RETURN start, start.displayName, e, e.Line, end, end.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#    start  start.displayName    e  e.Line  end         end.displayName
# 0    232  Notting Hill Gate  538  Circle  302  High Street Kensington
# CPU times: user 7.1 ms, sys: 3.87 ms, total: 11 ms
# Wall time: 9.4 ms

# %% [markdown]
# # Python functions to construct Cypher queries

# %%
# Define build_query_hops_with_edge function
def build_query_hops_with_edge(
    start_station: str, end_station: str, hopCount: int
) -> tuple[str, list[str]]:
    """
    Build query string and corresponding column names.

    Returns:
        tuple: (query_string, column_names)
    """
    query = "MATCH "
    query += '(start:Station{displayName:"'
    query += start_station
    query += '"})'

    for k in range(1, hopCount):
        query += f"-[e{k}:CONNECTED]-(s{k}:Station)"

    query += (
        "-[e"
        + str(hopCount)
        + ':CONNECTED]-(end:Station{displayName="'
        + end_station
        + '"})'
    )

    query += " RETURN start, start.displayName, start.Note, "
    for k in range(1, hopCount):
        query += f"e{k}.Line, s{k}, s{k}.displayName, s{k}.Note, "
    query += f"e{hopCount}.Line, end, end.displayName, end.Note"

    return query

# %%
start_station = "Paddington"
end_station = "Blackfriars"

distmax = 20

# %%
# %%time

# Loop over distance (number of hops) until we find a path between requested start and end stations
for k in range(1, distmax + 1):
    print(100 * "*")
    print(f"*** k = {k}\n")

    # We get a query and column names
    query_str = build_query_hops_with_edge(start_station, end_station, k)
    print(f"query_str : {query_str}")
    df_path = client.query(query_str)

    if not df_path.empty:
        df_path.columns = get_return_statements(query_str)
        display(df_path)
        break

print(100 * "*")
# Out:
# ****************************************************************************************************
# *** k = 1
#
# query_str : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, end, end.displayName, end.Note
# ****************************************************************************************************
# *** k = 2
#
# query_str : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, end, end.displayName, end.Note
# ****************************************************************************************************
# *** k = 3
#
# query_str : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, end, end.displayName, end.Note
# ****************************************************************************************************
# *** k = 4
#
# query_str : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(s3:Station)-[e4:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, end, end.displayName, end.Note
# ****************************************************************************************************
# *** k = 5
#
# query_str : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(s3:Station)-[e4:CONNECTED]-(s4:Station)-[e5:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, end, end.displayName, end.Note
# ****************************************************************************************************
# *** k = 6
#
# query_str : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(s3:Station)-[e4:CONNECTED]-(s4:Station)-[e5:CONNECTED]-(s5:Station)-[e6:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, s5, s5.displayName, s5.Note, e6.Line, end, end.displayName, end.Note
# ****************************************************************************************************
# *** k = 7
#
# query_str : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(s3:Station)-[e4:CONNECTED]-(s4:Station)-[e5:CONNECTED]-(s5:Station)-[e6:CONNECTED]-(s6:Station)-[e7:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, s5, s5.displayName, s5.Note, e6.Line, s6, s6.displayName, s6.Note, e7.Line, end, end.displayName, end.Note
# ****************************************************************************************************
# *** k = 8
#
# query_str : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(s3:Station)-[e4:CONNECTED]-(s4:Station)-[e5:CONNECTED]-(s5:Station)-[e6:CONNECTED]-(s6:Station)-[e7:CONNECTED]-(s7:Station)-[e8:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, s5, s5.displayName, s5.Note, e6.Line, s6, s6.displayName, s6.Note, e7.Line, s7, s7.displayName, s7.Note, e8.Line, end, end.displayName, end.Note
#    start start.displayName                                         start.Note  \
# 0    218        Paddington  Stroll along the canals at Paddington Basin an...
#
#   e1.Line   s1    s1.displayName s1.Note e2.Line   s2 s2.displayName  ...  \
# 0  Circle  300  Edgware Road (C)    None  Circle  221   Baker Street  ...
#
#   s6.displayName                                            s6.Note  e7.Line  \
# 0     Embankment  Relax in Victoria Embankment Gardens and see C...   Circle
#
#     s7 s7.displayName                                            s7.Note  \
# 0  293         Temple  Discover the historic Temple Church and stroll...
#
#    e8.Line  end end.displayName  \
# 0   Circle  334     Blackfriars
#
#                                             end.Note
# 0  Cross the Blackfriars Bridge to the Tate Moder...
#
# [1 rows x 35 columns]
# ****************************************************************************************************
# CPU times: user 31.3 ms, sys: 3.97 ms, total: 35.3 ms
# Wall time: 35.2 ms

# %% [markdown]
# # Process returned dataframe

# %%
# Define create_journey_string function
def create_journey_string(row):
    """Create journey string from DataFrame row - safer version"""
    # Start with initial station
    result = f"({row['start.displayName']})"

    # Find all available segment numbers
    line_cols = [
        col for col in row.index if col.startswith("e") and col.endswith(".Line")
    ]
    segment_numbers = sorted([int(col.split(".")[0][1:]) for col in line_cols])

    # Process each available segment
    for i in segment_numbers:
        line_col = f"e{i}.Line"
        station_col = f"s{i}.displayName"

        # Only process if both columns exist and have values
        if (
            line_col in row.index
            and station_col in row.index
            and not pd.isna(row[line_col])
            and not pd.isna(row[station_col])
        ):
            line = row[line_col]
            station = row[station_col]
            result += f"--[{line}]-->({station})"

    # Add end station if it exists
    if "end.displayName" in row.index and not pd.isna(row["end.displayName"]):
        # Check if there's a final line segment to the end
        max_segment = max(segment_numbers) if segment_numbers else 0
        final_line_col = f"e{max_segment}.Line"
        if final_line_col in row.index and not pd.isna(row[final_line_col]):
            result += f"--[{row[final_line_col]}]-->({row['end.displayName']})"

    return result

# %%
# Show journey strings (multiple paths of the same length can exist between two stations)
for i in range(len(df_path)):
    journey_path = create_journey_string(
        df_path.filter(regex="displayName$|Line$", axis=1).iloc[0]
    )
    print(f"Path n°{i}: {journey_path}")
# Out:
# Path n°0: (Paddington)--[Circle]-->(Edgware Road (C))--[Circle]-->(Baker Street)--[Jubilee]-->(Bond Street)--[Jubilee]-->(Green Park)--[Jubilee]-->(Westminster)--[Circle]-->(Embankment)--[Circle]-->(Temple)--[Circle]-->(Blackfriars)

# %% [markdown]
# # Create subgraph to visualise

# %%
def get_subgraph(G, df):
    subset_nodes = df.filter(regex="displayName$", axis=1).iloc[0].values.tolist()
    subG = G.subgraph(subset_nodes).copy()

    return subG

# %%
# Get subgraph with stations from matched path
subG = get_subgraph(G, df_path)
print(subG)

# Build CREATE command from subgraph
create_command_subG = build_create_command_from_networkx(subG)
print(f"Cypher CREATE command :\n\n{100 * '*'}\n{create_command_subG}\n{100 * '*'}")
# Out:
# DiGraph with 9 nodes and 16 edges
# Cypher CREATE command :
#
# ****************************************************************************************************
# CREATE (n0:Station {"id":"Temple", "displayName":"Temple", "type":"Station", "Latitude":"51.5110404236047", "Longitude":"-0.113725749531254", "Zone":"1", "Postcode":"WC2R 2PH", "Note":"Discover the historic Temple Church and stroll through Victoria Embankment Gardens."}),
# (n1:Station {"id":"Paddington", "displayName":"Paddington", "type":"Station", "Latitude":"51.5153935002265", "Longitude":"-0.175736750265772", "Zone":"1", "Postcode":"W2 1RH", "Note":"Stroll along the canals at Paddington Basin and say hello to the Paddington Bear statue."}),
# (n2:Station {"id":"Westminster", "displayName":"Westminster", "type":"Station", "Latitude":"51.5014013891933", "Longitude":"-0.12500207834678", "Zone":"1", "Postcode":"SW1A 2JR", "Note":"Marvel at the Houses of Parliament and Big Ben and visit Westminster Abbey."}),
# (n3:Station {"id":"Baker Street", "displayName":"Baker Street", "type":"Station", "Latitude":"51.5231293660588", "Longitude":"-0.156904192986185", "Zone":"1", "Postcode":"NW1 5LA", "Note":"Step into Sherlock Holmes world at 221B Baker Street or meet wax celebrities at Madame Tussauds."}),
# (n4:Station {"id":"Bond Street", "displayName":"Bond Street", "type":"Station", "Latitude":"51.5137972823274", "Longitude":"-0.149613608531646", "Zone":"1", "Postcode":"W1C 2HU", "Note":"Shop luxury boutiques on Bond Street or high street stores along Oxford Street."}),
# (n5:Station {"id":"Green Park", "displayName":"Green Park", "type":"Station", "Latitude":"51.5067602537146", "Longitude":"-0.142477574422533", "Zone":"1", "Postcode":"W1J 7BX", "Note":"Stroll through Green Park to Buckingham Palace or head to nearby Piccadilly."}),
# (n6:Station {"id":"Embankment", "displayName":"Embankment", "type":"Station", "Latitude":"51.5073122969468", "Longitude":"-0.12236733566212", "Zone":"1", "Postcode":"WC2N 6NS", "Note":"Relax in Victoria Embankment Gardens and see Cleopatra s Needle along the Thames."}),
# (n7:Station {"id":"Edgware Road (C)", "displayName":"Edgware Road (C)", "type":"Station"}),
# (n8:Station {"id":"Blackfriars", "displayName":"Blackfriars", "type":"Station", "Latitude":"51.511586761695", "Longitude":"-0.102995384624505", "Zone":"1", "Postcode":"EC4V 4DD", "Note":"Cross the Blackfriars Bridge to the Tate Modern or explore the riverside walkways."}),
# (n0)-[:CONNECTED {"Line":"Circle"}]-(n8),
# (n0)-[:CONNECTED {"Line":"Circle"}]-(n6),
# (n1)-[:CONNECTED {"Line":"Circle"}]-(n7),
# (n2)-[:CONNECTED {"Line":"Circle"}]-(n6),
# (n2)-[:CONNECTED {"Line":"Jubilee"}]-(n5),
# (n3)-[:CONNECTED {"Line":"Circle"}]-(n7),
# (n3)-[:CONNECTED {"Line":"Jubilee"}]-(n4),
# (n4)-[:CONNECTED {"Line":"Jubilee"}]-(n3),
# (n4)-[:CONNECTED {"Line":"Jubilee"}]-(n5),
# (n5)-[:CONNECTED {"Line":"Jubilee"}]-(n4),
# (n5)-[:CONNECTED {"Line":"Jubilee"}]-(n2),
# (n6)-[:CONNECTED {"Line":"Circle"}]-(n0),
# (n6)-[:CONNECTED {"Line":"Circle"}]-(n2),
# (n7)-[:CONNECTED {"Line":"Circle"}]-(n1),
# (n7)-[:CONNECTED {"Line":"Circle"}]-(n3),
# (n8)-[:CONNECTED {"Line":"Circle"}]-(n0)
# ****************************************************************************************************

# %%
subgraph_name = f"{graph_name}_subgraph"
subgraph_name
# Out:
# 'london_transport_TfL1_subgraph'

# %%
# %%time

# Create new graph
client.query(f"CREATE GRAPH {subgraph_name}")
client.set_graph(subgraph_name)

# Create a new change on the graph
change = client.query("CHANGE NEW").loc[0, 0]

# Checkout into the change
client.checkout(change=change)

# Run CREATE command
client.query(create_command_subG)

# Commit the change
client.query("COMMIT")
client.query("CHANGE SUBMIT")

# Checkout into main
client.checkout()
# Out:
# CPU times: user 7.39 ms, sys: 4.09 ms, total: 11.5 ms
# Wall time: 112 ms

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         You can visualise the subgraph directly in the notebook below. For more details on nodes and edges, you can go to TuringDB visualizer (running on your instance)
#     </h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         Visualize your graph in TuringDB Graph Visualizer ! Now that your instance is running:
#     </h2>
#     <h3>
#         <ul>
#             <li>Go to <a href="https://console.turingdb.ai/databases">TuringDB Console - Database Instances</a></li>
#             <li>In your current instance panel, click on "Open Visualizer" button</li>
#             <li>Visualizer opens, now you can choose your graph in the dropdown menu at the top-right corner</li>
#         </ul>
#         You can then play with your graph and visualize the nodes you want !
#     </h3>
# </div>

# %%
from pyvis.network import Network

net = Network(
    height="750px",
    width="100%",
    notebook=True,
    bgcolor="#ffffff",
    font_color="#000000",
    directed=True,
)

# Line colors (official TfL colors)
line_colors = {
    "Circle": "#FFD329",
    "Jubilee": "#A1A5A7",
    "Central": "#DC241F",
    "District": "#00782A",
    "Metropolitan": "#9B0058",
}

for node, data in subG.nodes(data=True):
    net.add_node(
        node,
        label=data.get("displayName", str(node)),
        title=f"{data.get('displayName', '')}<br>{data.get('Note', '')}",
        color="#3498db",
        size=25,
    )

for source, target, data in subG.edges(data=True):
    line = data.get("Line", "")
    color = line_colors.get(line, "#95a5a6")
    net.add_edge(source, target, title=line, label=line, color=color, width=3)

net.toggle_physics(True)
net.show(f"{example_name}_subgraph.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# london_transport_TfL_subgraph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="london_transport_TfL_subgraph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Use LLM to generate Cypher query

# %% [markdown]
# Before running this section, create a `.env` file in the project root with your API keys:
#
# ```env
# ANTHROPIC_API_KEY=your_key_here
# OPENAI_API_KEY=your_key_here
# MISTRAL_API_KEY=your_key_here

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
api_keys = {
    "Anthropic": os.getenv("ANTHROPIC_API_KEY"),
    "Mistral": os.getenv("MISTRAL_API_KEY"),
    "OpenAI": os.getenv("OPENAI_API_KEY"),
}

# %%
# %%time

system_prompt = """
Only base your response on the data provided.
Do not add knowledge but describe it in a natural way as if you were a touristic guide, be friendly !
You can add forms but not content.
Format the output with nice Markdown format and emojis.
"""

prompt = f"""
Here is the path I got from stations {start_station} to {end_station} : {df_path.to_dict()}.
Describe the path between these two stations.
Give me an itinerary of things I could visit on the way.
"""

provider = "Anthropic"

result = query_llm(
    prompt=prompt,
    system_prompt=system_prompt,
    provider=provider,
    api_key=api_keys[provider],
    temperature=0.2,
)
# Out:
# CPU times: user 206 ms, sys: 29.2 ms, total: 236 ms
# Wall time: 7.76 s

# %%
display(Markdown(result))
# Out:
# # 🚇 Paddington to Blackfriars: A London Underground Adventure! 🇬🇧
#
# ## 🛤️ Your Journey Highlights:
#
# 1. **Start at Paddington** 🐻
#    - Kick off your trip by saying hello to the Paddington Bear statue
#    - Enjoy a lovely stroll along Paddington Basin
#
# 2. **Edgware Road (Circle Line)**
#    - Quick transit station
#
# 3. **Baker Street** 🕵️
#    - Sherlock Holmes fans, rejoice! Visit the famous 221B Baker Street
#    - Pop into Madame Tussauds wax museum
#
# 4. **Bond Street** 💎
#    - Luxury shopping paradise!
#    - Browse high-end boutiques
#    - Explore Oxford Street's fantastic stores
#
# 5. **Green Park** 🌳
#    - Beautiful royal park
#    - Perfect for a quick walk
#    - Close to Buckingham Palace
#
# 6. **Westminster** 🏛️
#    - Iconic London landmarks
#    - See the Houses of Parliament
#    - Admire Big Ben
#    - Visit Westminster Abbey
#
# 7. **Embankment** 🌊
#    - Relax in Victoria Embankment Gardens
#    - See Cleopatra's Needle
#    - Enjoy Thames River views
#
# 8. **Temple** ⚖️
#    - Explore historic Temple Church
#    - More garden walks
#
# 9. **Final Stop: Blackfriars** 🎨
#    - Cross Blackfriars Bridge
#    - Visit Tate Modern
#    - Explore riverside walkways
#
# ### 🚉 Lines Used:
# - Circle Line
# - Jubilee Line
#
# **Total Journey: A fantastic London exploration!** 🇬🇧✨

# %% [markdown]
# # Use LLM to generate Cypher query

# %%
"""Build system prompt with TuringDB schema and examples"""

turingdb_cypher_system_prompt = """
You are an expert at converting natural language questions into TuringDB queries.

Your task is to generate syntactically correct TuringDB queries based on natural language input.

VERY IMPORTANT - TuringDB Syntax Guidelines:
1. Return ONLY the TuringDB query, no explanations or markdown formatting
2. Use MATCH or CREATE operations only
3. Nodes: (n:Label{property="value"}) or (n:Label{property:value})
4. Edges: Use UNDIRECTED syntax with - (NOT ->)
5. Pattern matching: MATCH (n)-[e]-(m)
6. Property matching: Use = or : operators for exact matching
7. String approximation: Use ~= for approximate string matching
8. Node ID injection: Use @ operator or AT keyword: (n @ 1) or (n AT 1)
9. Multiple constraints: (n:Person,Engineer{name="John", age=30})
10. Return all matched entities: RETURN n, e, m or use RETURN * for all

VERY IMPORTANT - FORBIDDEN in TuringDB:
- Do NOT use directed edges (-> or <-)
- Do NOT use AS aliases
- Do NOT use LIMIT, SKIP clauses
- Do NOT use WHERE clauses
- Do NOT use WITH clauses
- Do NOT use CALL (except for metaqueries)
- Do NOT use toLower() or other functions

Supported TuringDB Operations:
- MATCH queries: MATCH (n:Label)-[e:Type]-(m) RETURN n, m
- CREATE queries: CREATE (n:Label{property="value"})-[e:Type]-(m:Label)
- Metaqueries: CALL PROPERTIES(), CALL LABELS(), CALL EDGETYPES(), CALL LABELSETS()
- Property types: String ("text" or `text`), Boolean (true/false), Integer (20), Unsigned (20u), Double (20.5)

Examples for few-shot learning:
- Find all persons: MATCH (n:Person) RETURN n
- Find connections: MATCH (n:Person)-[e]-(m:Person) RETURN n, e, m
- Create person: CREATE (n:Person{name="John", age=30})
- String approximation: MATCH (n{name~="John"}) RETURN n
- Node by ID: MATCH (n @ 1) RETURN n
- Multiple IDs: MATCH (n:Person @ 1, 2, 3) RETURN n
- Path with 1 hop between Station Paddington and Blackfriars:  MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, end, end.displayName, end.Note
- Path with 2 hops between Station Paddington and Blackfriars: MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, end, end.displayName, end.Note
- Path with 8 hops between Station Paddington and Blackfriars: MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(s3:Station)-[e4:CONNECTED]-(s4:Station)-[e5:CONNECTED]-(s5:Station)-[e6:CONNECTED]-(s6:Station)-[e7:CONNECTED]-(s7:Station)-[e8:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, s5, s5.displayName, s5.Note, e6.Line, s6, s6.displayName, s6.Note, e7.Line, s7, s7.displayName, s7.Note, e8.Line, end, end.displayName, end.Note
- Find all Chinese providers and what they supply: MATCH (n{provider_country:"CHN"}) RETURN n, n.provider_name, n.displayName, n.share_provided, n.type
- Find all deposition tools and their types: MATCH (specific)-[e:IS_TYPE_OF]-(general:Tool_Resource{displayName:"Deposition tools"}) RETURN specific, specific.displayName, specific.provider_name, e, general, general.displayName
"""

# %%
# %%time

# Define maximum number of hops between two
distmax = 20

# Get subset of CREATE command to avoid exceeding context window
create_command_subset = "\n".join(
    create_command.split("\n")[:5] + create_command.split("\n")[-5:]
)

for k in range(1, distmax + 1):
    print(100 * "*")
    print(f"*** k = {k}\n")

    #########################################################################################################
    question = f"""
    Give me the Cypher query to find the path using London Tube between stations {start_station} and {end_station}.
    The path between the two stations has to contain {k} hops.
    Very important :
    - Make sure you respect the number of hops and stations required between the two stations.
    - Pay attention to use the correct node and edge properties name in the MATCH section.
    - Pay attention to use the correct node and edge properties name in the RETURN section.
    - If no contrary information is asked by the user :
        - return all the matched nodes and edges and their properties in the RETURN section.
    """

    system_prompt = f"""
    TuringDB Cypher prompt :
    {turingdb_cypher_system_prompt}
    
    Here is a subset of the CREATE command used to create the graph, this way you know graph structure.
    Only a subset is passed because the whole command is to long :
    {create_command_subset}
    
    Here is also the output of "CALL LABELS ()" command, showing the different node types of the graph :
    {client.query("CALL LABELS ()")}
    
    Here is also the output of "CALL EDGETYPES ()" command, showing the different edge types of the graph :
    {client.query("CALL EDGETYPES ()")}
    
    Very important :
    - You MUST follow current TuringDB Syntax Guidelines
    - You MUST NOT USE what is FORBIDDEN in TuringDB
    - By default, RETURN ALL THE MATCHED NODES AND EDGES AND THEIR PROPERTIES in the RETURN section (except contrary demand from user)
    - Use the correct node and edge properties name in the MATCH section.
    - Use the correct node and edge properties name in the RETURN section.
    - Pay attention to which properties come from nodes or edges, to create a functioning query
    - Pay attention to lower and uppercases in properties
    - If some properties contain spaces, be careful to wrap them
    
    Give me the query FOLLOWING TURINGDB GUIDELINES AND NOT USING WHAT IS FORBIDDEN for this specific question :
    """

    cypher_query = natural_language_to_cypher(
        question=question,
        system_prompt=system_prompt,
        provider=provider,
        api_key=api_keys[provider],
    )
    print(f"cypher_query : {cypher_query}")

    #########################################################################################################

    ## Build column names to exactly match the RETURN clause
    # column_names = ['start', 'start.displayName', 'start.Note']
    #
    # for k_ in range(1, k):
    #    column_names.extend([
    #        f'e{k_}.Line',
    #        f's{k_}',
    #        f's{k_}.displayName',
    #        f's{k_}.Note'
    #    ])
    #
    # column_names.extend([
    #    f'e{k}.Line',
    #    'end',
    #    'end.displayName',
    #    'end.Note'
    # ])
    cypher_query

    #########################################################################################################

    df_path = client.query(cypher_query)
    if df_path.empty:
        print("--> No result found\n")
    else:
        df_path.columns = get_return_statements(query_str)
        display(df_path)
        break

print(100 * "*")
# Out:
# ****************************************************************************************************
# *** k = 1
#
# cypher_query : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(end:Station{displayName:"Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, end, end.displayName, end.Note
# --> No result found
#
# ****************************************************************************************************
# *** k = 2
#
# cypher_query : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(end:Station{displayName:"Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, end, end.displayName, end.Note
# --> No result found
#
# ****************************************************************************************************
# *** k = 3
#
# cypher_query : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(end:Station{displayName:"Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, end, end.displayName, end.Note
# --> No result found
#
# ****************************************************************************************************
# *** k = 4
#
# cypher_query : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(s3:Station)-[e4:CONNECTED]-(end:Station{displayName:"Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, end, end.displayName, end.Note
# --> No result found
#
# ****************************************************************************************************
# *** k = 5
#
# cypher_query : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(s3:Station)-[e4:CONNECTED]-(s4:Station)-[e5:CONNECTED]-(end:Station{displayName:"Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, end, end.displayName, end.Note
# --> No result found
#
# ****************************************************************************************************
# *** k = 6
#
# cypher_query : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(s3:Station)-[e4:CONNECTED]-(s4:Station)-[e5:CONNECTED]-(s5:Station)-[e6:CONNECTED]-(end:Station{displayName:"Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, s5, s5.displayName, s5.Note, e6.Line, end, end.displayName, end.Note
# --> No result found
#
# ****************************************************************************************************
# *** k = 7
#
# cypher_query : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(s3:Station)-[e4:CONNECTED]-(s4:Station)-[e5:CONNECTED]-(s5:Station)-[e6:CONNECTED]-(s6:Station)-[e7:CONNECTED]-(end:Station{displayName:"Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, s5, s5.displayName, s5.Note, e6.Line, s6, s6.displayName, s6.Note, e7.Line, end, end.displayName, end.Note
# --> No result found
#
# ****************************************************************************************************
# *** k = 8
#
# cypher_query : MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(s3:Station)-[e4:CONNECTED]-(s4:Station)-[e5:CONNECTED]-(s5:Station)-[e6:CONNECTED]-(s6:Station)-[e7:CONNECTED]-(s7:Station)-[e8:CONNECTED]-(end:Station{displayName:"Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, s5, s5.displayName, s5.Note, e6.Line, s6, s6.displayName, s6.Note, e7.Line, s7, s7.displayName, s7.Note, e8.Line, end, end.displayName, end.Note
#    start start.displayName                                         start.Note  \
# 0      1        Paddington  Stroll along the canals at Paddington Basin an...
#
#   e1.Line  s1    s1.displayName s1.Note e2.Line  s2 s2.displayName  ...  \
# 0  Circle   7  Edgware Road (C)    None  Circle   3   Baker Street  ...
#
#   s6.displayName                                            s6.Note  e7.Line  \
# 0     Embankment  Relax in Victoria Embankment Gardens and see C...   Circle
#
#   s7 s7.displayName                                            s7.Note  \
# 0  0         Temple  Discover the historic Temple Church and stroll...
#
#    e8.Line end end.displayName  \
# 0   Circle   8     Blackfriars
#
#                                             end.Note
# 0  Cross the Blackfriars Bridge to the Tate Moder...
#
# [1 rows x 35 columns]
# ****************************************************************************************************
# CPU times: user 437 ms, sys: 25.9 ms, total: 463 ms
# Wall time: 30.1 s

# %%
# Show journey strings (multiple paths of the same length can exist between two stations)
for i in range(len(df_path)):
    journey_path = create_journey_string(
        df_path.filter(regex="displayName$|Line$", axis=1).iloc[0]
    )
    print(f"Path n°{i}: {journey_path}")
# Out:
# Path n°0: (Paddington)--[Circle]-->(Edgware Road (C))--[Circle]-->(Baker Street)--[Jubilee]-->(Bond Street)--[Jubilee]-->(Green Park)--[Jubilee]-->(Westminster)--[Circle]-->(Embankment)--[Circle]-->(Temple)--[Circle]-->(Blackfriars)

# %%
print("Notebook finished !")
# Out:
# Notebook finished !
