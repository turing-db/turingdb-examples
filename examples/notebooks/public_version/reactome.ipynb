# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>
#         Example notebook - Reactome subgraph
#     </h1>
# </div>

# %% [markdown]
# # Import modules and functions

# %%
# %load_ext autoreload
# %autoreload 2

import os
import glob
import re
import networkx as nx
import pandas as pd

from turingdb_examples.graph import (
    build_create_command_from_networkx,
)
from turingdb_examples.utils import get_return_statements
from turingdb_examples.llm import natural_language_to_cypher, query_llm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Check data files are available

# %%
folder_name = "reactome"
path_data = f"{os.getcwd()}/data/{folder_name}"
if not os.path.exists(path_data):
    raise ValueError(f"{path_data} does not exists")

list_csv_files = sorted([os.path.basename(file) for file in glob.glob(os.path.join(path_data, '*'))])
if not list_csv_files == [
    "entities_pairwise.gml"
]:
    raise ValueError(
        f"At least one of the {len(list_csv_files)} csv files is not available in {path_data}"
    )

# %% [markdown]
# # Import `gml` file

# %%
G = nx.read_gml(f"{path_data}/entities_pairwise.gml")
print(G)
# Out:
# MultiGraph with 40 nodes and 57 edges

# %%
from pyvis.network import Network
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

net = Network(
    height="750px", width="100%", notebook=True, bgcolor="#ffffff", font_color="#000000", directed=True
)

# Choose your palette (can be changed easily)
palette_name = 'Pastel1'  # Options: 'tab10', 'Set3', 'Paired', 'viridis', 'plasma', etc.

# Get unique node types
unique_types = list(set(data.get('schemaClass') for _, data in G.nodes(data=True)))

# Get colors from matplotlib palette
cmap = plt.get_cmap(palette_name)
colors = [mcolors.rgb2hex(cmap(i / len(unique_types))) for i in range(len(unique_types))]

# Map types to colors
type_colors = {node_type: colors[i] for i, node_type in enumerate(unique_types)}

# Then use in your visualization
for node, data in G.nodes(data=True):
    node_type = data.get('schemaClass', 'Unknown')
    color = type_colors.get(node_type, '#95a5a6')

    net.add_node(
        node,
        label=data.get("displayName", str(node)),
        title=f"{data.get('displayName', '')}",
        color=color,
        size=25,
    )

for source, target, data in G.edges(data=True):
    net.add_edge(source, target, color="#95a5a6", width=3)

net.toggle_physics(status=True)
net.show(f"{folder_name}_graph.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# reactome_graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="reactome_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Create graph using `turingdb` python package

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         See <a href="https://docs.turingdb.ai/quickstart">TuringDB Get started documentation</a> for the important steps to follow :
#     </h2>
#     <h4>
#         <ul>
#             <li>Create your TuringDB account</li>
#             <li>Create your instance in the <a href="https://console.turingdb.ai/auth">TuringDB Cloud UI</a></li>
#             <li>Copy your Instance ID from the Database Instances management page</li>
#             <li>Get API Key from the Settings in UI</li>
#         </ul>
#         Remember to have your instance active while working in this notebook !
#     </h4>
# </div>

# %%
from turingdb import TuringDB

# Create TuringDB client
client = TuringDB(
    host="http://localhost:6666"  # Remove this parameter and set the two parameters below
    # instance_id="...",  # Replace by your instance id
    # auth_token="...",  # Replace by your API token
)

# %%
# Get list of available graphs
list_graphs = client.query("LIST GRAPH").loc[:, 0].tolist()

# %%
# Set graph name
graph_name_prefix = folder_name
graph_name_nb_suffix = str(
    max(
        [
            int(re.sub(graph_name_prefix, "", g))
            for g in list_graphs
            if g.startswith(graph_name_prefix)
            and re.sub(graph_name_prefix, "", g).isdigit()
        ]
        + [0]
    )
    + 1
)
graph_name = graph_name_prefix + graph_name_nb_suffix
graph_name
# Out:
# 'reactome4'

# %%
# %%time

# Create a new graph
client.query(f"CREATE GRAPH {graph_name}")
client.set_graph(graph_name)

# Create a new change on the graph
change = client.query("CHANGE NEW").loc[0, 0]

# Checkout into the change
client.checkout(change=change)
# Out:
# CPU times: user 2.6 ms, sys: 129 μs, total: 2.73 ms
# Wall time: 2.33 ms

# %%
# Build CREATE command from networkx object
create_command = build_create_command_from_networkx(G, node_type_key="schemaClass")
print(f"Cypher CREATE command :\n\n{100 * '*'}\n{create_command}\n{100 * '*'}")
# Out:
# Cypher CREATE command :
#
# ****************************************************************************************************
# CREATE (n0:Reaction {"id":"TP53 binds the PMAIP1 (NOXA) promoter", "schemaClass":"Reaction", "stId":"R-HSA-4331331", "oldStId":"REACT_169265", "releaseDate":"2016-03-23", "name":"[ TP53 binds the PMAIP1 (NOXA) promoter ]", "stIdVersion":"R-HSA-4331331.6", "speciesName":"Homo sapiens", "category":"binding", "displayName":"TP53 binds the PMAIP1 (NOXA) promoter"}),
# (n1:Complex {"id":"p-S15,S20-TP53 Tetramer [nucleoplasm]", "schemaClass":"Complex", "stId":"R-HSA-3222171", "name":"[ p-S15,S20-TP53 Tetramer ]", "stIdVersion":"R-HSA-3222171.1", "speciesName":"Homo sapiens", "displayName":"p-S15,S20-TP53 Tetramer [nucleoplasm]"}),
# (n2:Reaction {"id":"TP53 binds the APAF1 gene promoter", "schemaClass":"Reaction", "stId":"R-HSA-6791349", "releaseDate":"2016-03-23", "name":"[ TP53 binds the APAF1 gene promoter ]", "stIdVersion":"R-HSA-6791349.3", "speciesName":"Homo sapiens", "category":"binding", "displayName":"TP53 binds the APAF1 gene promoter"}),
# (n3:BlackBoxEvent {"id":"TP53 stimulates APAF1 gene expression", "schemaClass":"BlackBoxEvent", "stId":"R-HSA-6791348", "releaseDate":"2016-03-23", "name":"[ TP53 stimulates APAF1 gene expression ]", "stIdVersion":"R-HSA-6791348.4", "speciesName":"Homo sapiens", "category":"omitted", "displayName":"TP53 stimulates APAF1 gene expression"}),
# (n4:Reaction {"id":"CYCS binds to APAF1", "schemaClass":"Reaction", "stId":"R-HSA-114254", "oldStId":"REACT_1640", "releaseDate":"2004-10-27", "name":"[ CYCS binds to APAF1 ]", "stIdVersion":"R-HSA-114254.6", "speciesName":"Homo sapiens", "category":"binding", "displayName":"CYCS binds to APAF1"}),
# (n5:EntityWithAccessionedSequence {"id":"CYCS [cytosol]", "schemaClass":"EntityWithAccessionedSequence", "stId":"R-HSA-53259", "oldStId":"REACT_4972", "name":"[ CYCS , Cytochrome c ]", "stIdVersion":"R-HSA-53259.1", "speciesName":"Homo sapiens", "referenceType":"ReferenceGeneProduct", "searchSeed":"1", "displayName":"CYCS [cytosol]"}),
# (n6:EntityWithAccessionedSequence {"id":"PMAIP1 Gene [nucleoplasm]", "schemaClass":"EntityWithAccessionedSequence", "stId":"R-HSA-4331342", "oldStId":"REACT_170122", "name":"[ PMAIP1 Gene , NOXA Gene ]", "stIdVersion":"R-HSA-4331342.1", "speciesName":"Homo sapiens", "referenceType":"ReferenceDNASequence", "searchSeed":"1", "displayName":"PMAIP1 Gene [nucleoplasm]"}),
# (n7:Complex {"id":"p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]", "schemaClass":"Complex", "stId":"R-HSA-4331332", "oldStId":"REACT_170069", "name":"[ p-S15,S20-TP53 Tetramer:PMAIP1 Gene ]", "stIdVersion":"R-HSA-4331332.4", "speciesName":"Homo sapiens", "displayName":"p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]"}),
# (n8:BlackBoxEvent {"id":"TP53 stimulates PMAIP1 (NOXA) expression", "schemaClass":"BlackBoxEvent", "stId":"R-HSA-140214", "oldStId":"REACT_2201", "releaseDate":"2004-10-27", "name":"[ TP53 stimulates PMAIP1 (NOXA) expression ]", "stIdVersion":"R-HSA-140214.6", "speciesName":"Homo sapiens", "category":"omitted", "displayName":"TP53 stimulates PMAIP1 (NOXA) expression"}),
# (n9:PositiveGeneExpressionRegulation {"id":"Positive gene expression regulation by 'p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]'", "schemaClass":"PositiveGeneExpressionRegulation", "stId":"R-HSA-159038", "oldStId":"REACT_6033", "stIdVersion":"R-HSA-159038.4", "displayName":"Positive gene expression regulation by p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]"}),
# (n10:Reaction {"id":"Translocation of PMAIP1 (NOXA) to mitochondria", "schemaClass":"Reaction", "stId":"R-HSA-140216", "oldStId":"REACT_1585", "releaseDate":"2004-10-27", "name":"[ Translocation of PMAIP1 (NOXA) to mitochondria ]", "stIdVersion":"R-HSA-140216.4", "speciesName":"Homo sapiens", "category":"transition", "displayName":"Translocation of PMAIP1 (NOXA) to mitochondria"}),
# (n11:Reaction {"id":"BH3-only proteins associate with and inactivate anti-apoptotic BCL-2", "schemaClass":"Reaction", "stId":"R-HSA-508163", "oldStId":"REACT_21389", "releaseDate":"2008-06-30", "name":"[ BH3-only proteins associate with and inactivate anti-apoptotic BCL-2 ]", "stIdVersion":"R-HSA-508163.4", "speciesName":"Homo sapiens", "category":"binding", "displayName":"BH3-only proteins associate with and inactivate anti-apoptotic BCL-2"}),
# (n12:Reaction {"id":"Translocation of tBID to mitochondria", "schemaClass":"Reaction", "stId":"R-HSA-139920", "oldStId":"REACT_1370", "releaseDate":"2004-10-27", "name":"[ Translocation of tBID to mitochondria ]", "stIdVersion":"R-HSA-139920.3", "speciesName":"Homo sapiens", "category":"transition", "displayName":"Translocation of tBID to mitochondria"}),
# (n13:Reaction {"id":"Release of Cytochrome c from mitochondria", "schemaClass":"Reaction", "stId":"R-HSA-114284", "oldStId":"REACT_535", "releaseDate":"2004-07-06", "name":"[ Release of Cytochrome c from mitochondria ]", "stIdVersion":"R-HSA-114284.7", "speciesName":"Homo sapiens", "category":"transition", "displayName":"Release of Cytochrome c from mitochondria"}),
# (n14:BlackBoxEvent {"id":"Transactivation of PMAIP1 (NOXA) by E2F1", "schemaClass":"BlackBoxEvent", "stId":"R-HSA-140217", "oldStId":"REACT_1872", "releaseDate":"2004-10-27", "name":"[ Transactivation of PMAIP1 (NOXA) by E2F1 ]", "stIdVersion":"R-HSA-140217.4", "speciesName":"Homo sapiens", "category":"omitted", "displayName":"Transactivation of PMAIP1 (NOXA) by E2F1"}),
# (n15:PositiveGeneExpressionRegulation {"id":"Positive gene expression regulation by 'E2F1:TFDP1:PMAIP1 Gene [nucleoplasm]'", "schemaClass":"PositiveGeneExpressionRegulation", "stId":"R-HSA-159039", "oldStId":"REACT_6130", "stIdVersion":"R-HSA-159039.1", "displayName":"Positive gene expression regulation by E2F1:TFDP1:PMAIP1 Gene [nucleoplasm]"}),
# (n16:Complex {"id":"E2F1:TFDP1,TFDP2 [nucleoplasm]", "schemaClass":"Complex", "stId":"R-HSA-68653", "oldStId":"REACT_5400", "name":"[ E2F1:TFDP1,TFDP2 , DP1/2:E2F1 ]", "stIdVersion":"R-HSA-68653.2", "speciesName":"Homo sapiens", "displayName":"E2F1:TFDP1,TFDP2 [nucleoplasm]"}),
# (n17:EntityWithAccessionedSequence {"id":"E2F1 [nucleoplasm]", "schemaClass":"EntityWithAccessionedSequence", "stId":"R-HSA-68639", "oldStId":"REACT_2601", "name":"[ E2F1 , Transcription factor E2F1 , E2F-1 , Retinoblastoma binding protein 3 , RBBP-3 , PRB-binding protein E2F-1 , PBR3 , Retinoblastoma-associated protein 1 , RBAP-1 ]", "stIdVersion":"R-HSA-68639.2", "speciesName":"Homo sapiens", "referenceType":"ReferenceGeneProduct", "displayName":"E2F1 [nucleoplasm]"}),
# (n18:Complex {"id":"E2F1:(TFDP1,TFDP2) [nucleoplasm]", "schemaClass":"Complex", "stId":"R-HSA-9007512", "name":"[ E2F1:(TFDP1,TFDP2) ]", "stIdVersion":"R-HSA-9007512.1", "speciesName":"Homo sapiens", "displayName":"E2F1:(TFDP1,TFDP2) [nucleoplasm]"}),
# (n19:Reaction {"id":"E2F1 binds APAF1 gene promoter", "schemaClass":"Reaction", "stId":"R-HSA-9007514", "releaseDate":"2017-09-12", "name":"[ E2F1 binds APAF1 gene promoter ]", "stIdVersion":"R-HSA-9007514.2", "speciesName":"Homo sapiens", "category":"binding", "displayName":"E2F1 binds APAF1 gene promoter"}),
# (n20:BlackBoxEvent {"id":"APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6", "schemaClass":"BlackBoxEvent", "stId":"R-HSA-9007496", "releaseDate":"2017-09-12", "name":"[ APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6 ]", "stIdVersion":"R-HSA-9007496.4", "speciesName":"Homo sapiens", "category":"omitted", "displayName":"APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6"}),
# (n21:EntityWithAccessionedSequence {"id":"APAF1 [cytosol]", "schemaClass":"EntityWithAccessionedSequence", "stId":"R-HSA-50099", "oldStId":"REACT_3886", "name":"[ APAF1 , Apaf-1 , Apoptotic protease activating factor 1 ]", "stIdVersion":"R-HSA-50099.1", "speciesName":"Homo sapiens", "referenceType":"ReferenceGeneProduct", "displayName":"APAF1 [cytosol]"}),
# (n22:Complex {"id":"APAF1:CYCS [cytosol]", "schemaClass":"Complex", "stId":"R-HSA-114253", "oldStId":"REACT_4880", "name":"[ APAF1:CYCS , APAF1:Cytochrome C ]", "stIdVersion":"R-HSA-114253.2", "speciesName":"Homo sapiens", "displayName":"APAF1:CYCS [cytosol]"}),
# (n23:Reaction {"id":"E2F1 binds PMAIP1 (NOXA) promoter", "schemaClass":"Reaction", "stId":"R-HSA-4331327", "oldStId":"REACT_169402", "releaseDate":"2013-09-18", "name":"[ E2F1 binds PMAIP1 (NOXA) promoter ]", "stIdVersion":"R-HSA-4331327.3", "speciesName":"Homo sapiens", "category":"binding", "displayName":"E2F1 binds PMAIP1 (NOXA) promoter"}),
# (n24:EntityWithAccessionedSequence {"id":"PMAIP1 [cytosol]", "schemaClass":"EntityWithAccessionedSequence", "stId":"R-HSA-140215", "oldStId":"REACT_4210", "name":"[ PMAIP1 , NOXA protein ]", "stIdVersion":"R-HSA-140215.1", "speciesName":"Homo sapiens", "referenceType":"ReferenceGeneProduct", "searchSeed":"1", "displayName":"PMAIP1 [cytosol]"}),
# (n25:EntityWithAccessionedSequence {"id":"CYCS [mitochondrial intermembrane space]", "schemaClass":"EntityWithAccessionedSequence", "stId":"R-HSA-114244", "oldStId":"REACT_3942", "name":"[ CYCS , Cytochrome c ]", "stIdVersion":"R-HSA-114244.1", "speciesName":"Homo sapiens", "referenceType":"ReferenceGeneProduct", "displayName":"CYCS [mitochondrial intermembrane space]"}),
# (n26:Complex {"id":"CYCS gene:NRF1:PPARGC1B [nucleoplasm]", "schemaClass":"Complex", "stId":"R-HSA-2466382", "oldStId":"REACT_265699", "name":"[ CYCS gene:NRF1:PPARGC1B , NRF1:PGC-1beta:CYCS ]", "stIdVersion":"R-HSA-2466382.1", "speciesName":"Homo sapiens", "displayName":"CYCS gene:NRF1:PPARGC1B [nucleoplasm]"}),
# (n27:EntityWithAccessionedSequence {"id":"NRF1 [nucleoplasm]", "schemaClass":"EntityWithAccessionedSequence", "stId":"R-HSA-1592205", "oldStId":"REACT_117514", "name":"[ NRF1 , Nuclear respiratory factor 1 , NRF1_HUMAN ]", "stIdVersion":"R-HSA-1592205.1", "speciesName":"Homo sapiens", "referenceType":"ReferenceGeneProduct", "displayName":"NRF1 [nucleoplasm]"}),
# (n28:Reaction {"id":"NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter", "schemaClass":"Reaction", "stId":"R-HSA-2466392", "oldStId":"REACT_264641", "releaseDate":"2014-03-12", "name":"[ NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter ]", "stIdVersion":"R-HSA-2466392.2", "speciesName":"Homo sapiens", "category":"binding", "displayName":"NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter"}),
# (n29:Reaction {"id":"p38 MAPK phosphorylates PPARGC1A", "schemaClass":"Reaction", "stId":"R-HSA-1592233", "oldStId":"REACT_263998", "releaseDate":"2014-03-12", "name":"[ p38 MAPK phosphorylates PPARGC1A ]", "stIdVersion":"R-HSA-1592233.2", "speciesName":"Homo sapiens", "category":"transition", "displayName":"p38 MAPK phosphorylates PPARGC1A"}),
# (n30:EntityWithAccessionedSequence {"id":"PPARGC1A [nucleoplasm]", "schemaClass":"EntityWithAccessionedSequence", "stId":"R-HSA-442481", "oldStId":"REACT_27383", "name":"[ PPARGC1A , Peroxisome proliferator-activated receptor gamma coactivator 1-alpha , PRGC1_HUMAN , PGC1A , PGC-1alpha ]", "stIdVersion":"R-HSA-442481.2", "speciesName":"Homo sapiens", "referenceType":"ReferenceGeneProduct", "displayName":"PPARGC1A [nucleoplasm]"}),
# (n31:Complex {"id":"RORA:Coactivator [nucleoplasm]", "schemaClass":"Complex", "stId":"R-HSA-1368124", "oldStId":"REACT_111748", "name":"[ RORA:Coactivator ]", "stIdVersion":"R-HSA-1368124.1", "speciesName":"Homo sapiens", "displayName":"RORA:Coactivator [nucleoplasm]"}),
# (n32:EntityWithAccessionedSequence {"id":"EP300 [nucleoplasm]", "schemaClass":"EntityWithAccessionedSequence", "stId":"R-HSA-381325", "oldStId":"REACT_26137", "name":"[ EP300 , p300 , Histone acetyltransferase p300 , EP300_HUMAN , KAT3B ]", "stIdVersion":"R-HSA-381325.1", "speciesName":"Homo sapiens", "referenceType":"ReferenceGeneProduct", "displayName":"EP300 [nucleoplasm]"}),
# (n33:Complex {"id":"p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene [nucleoplasm]", "schemaClass":"Complex", "stId":"R-HSA-3215149", "name":"[ p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ]", "stIdVersion":"R-HSA-3215149.1", "speciesName":"Homo sapiens", "displayName":"p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene [nucleoplasm]"}),
# (n34:Reaction {"id":"NRF1:PPARGC1B binds the CYCS promoter", "schemaClass":"Reaction", "stId":"R-HSA-2466370", "oldStId":"REACT_264393", "releaseDate":"2014-03-12", "name":"[ NRF1:PPARGC1B binds the CYCS promoter ]", "stIdVersion":"R-HSA-2466370.2", "speciesName":"Homo sapiens", "category":"binding", "displayName":"NRF1:PPARGC1B binds the CYCS promoter"}),
# (n35:BlackBoxEvent {"id":"Expression of NRF1", "schemaClass":"BlackBoxEvent", "stId":"R-HSA-1592242", "oldStId":"REACT_264032", "releaseDate":"2014-03-12", "name":"[ Expression of NRF1 ]", "stIdVersion":"R-HSA-1592242.4", "speciesName":"Homo sapiens", "category":"omitted", "displayName":"Expression of NRF1"}),
# (n36:BlackBoxEvent {"id":"Expression of CYCS", "schemaClass":"BlackBoxEvent", "stId":"R-HSA-1592231", "oldStId":"REACT_263920", "releaseDate":"2014-03-12", "name":"[ Expression of CYCS , Expression of Cytochrome c ]", "stIdVersion":"R-HSA-1592231.7", "speciesName":"Homo sapiens", "category":"omitted", "displayName":"Expression of CYCS"}),
# (n37:PositiveRegulation {"id":"Positive regulation by 'ESRRA [nucleoplasm]'", "stId":"R-HSA-1605565", "oldStId":"REACT_267555", "schemaClass":"PositiveRegulation", "stIdVersion":"R-HSA-1605565.1", "displayName":"Positive regulation by ESRRA [nucleoplasm]"}),
# (n38:EntityWithAccessionedSequence {"id":"ESRRA [nucleoplasm]", "schemaClass":"EntityWithAccessionedSequence", "stId":"R-HSA-446159", "oldStId":"REACT_21133", "name":"[ ESRRA , Steroid hormone receptor ERR1 , ERR1_HUMAN ]", "stIdVersion":"R-HSA-446159.1", "speciesName":"Homo sapiens", "referenceType":"ReferenceGeneProduct", "displayName":"ESRRA [nucleoplasm]"}),
# (n39:Complex {"id":"ESRRA:PPARGC1A [nucleoplasm]", "schemaClass":"Complex", "stId":"R-HSA-8939924", "name":"[ ESRRA:PPARGC1A ]", "stIdVersion":"R-HSA-8939924.1", "speciesName":"Homo sapiens", "displayName":"ESRRA:PPARGC1A [nucleoplasm]"}),
# (n0)-[:CONNECTED]-(n1),
# (n0)-[:CONNECTED]-(n6),
# (n0)-[:CONNECTED]-(n7),
# (n0)-[:CONNECTED]-(n8),
# (n1)-[:CONNECTED]-(n2),
# (n1)-[:CONNECTED]-(n7),
# (n1)-[:CONNECTED]-(n9),
# (n1)-[:CONNECTED]-(n33),
# (n2)-[:CONNECTED]-(n3),
# (n3)-[:CONNECTED]-(n21),
# (n3)-[:CONNECTED]-(n4),
# (n4)-[:CONNECTED]-(n5),
# (n4)-[:CONNECTED]-(n13),
# (n5)-[:CONNECTED]-(n13),
# (n5)-[:CONNECTED]-(n22),
# (n5)-[:CONNECTED]-(n36),
# (n6)-[:CONNECTED]-(n7),
# (n6)-[:CONNECTED]-(n8),
# (n6)-[:CONNECTED]-(n14),
# (n6)-[:CONNECTED]-(n23),
# (n7)-[:CONNECTED]-(n9),
# (n8)-[:CONNECTED]-(n9),
# (n8)-[:CONNECTED]-(n10),
# (n10)-[:CONNECTED]-(n14),
# (n10)-[:CONNECTED]-(n11),
# (n10)-[:CONNECTED]-(n24),
# (n11)-[:CONNECTED]-(n12),
# (n12)-[:CONNECTED]-(n13),
# (n13)-[:CONNECTED]-(n25),
# (n14)-[:CONNECTED]-(n15),
# (n14)-[:CONNECTED]-(n23),
# (n15)-[:CONNECTED]-(n16),
# (n16)-[:CONNECTED]-(n17),
# (n16)-[:CONNECTED]-(n23),
# (n17)-[:CONNECTED]-(n18),
# (n18)-[:CONNECTED]-(n19),
# (n19)-[:CONNECTED]-(n20),
# (n20)-[:CONNECTED]-(n21),
# (n21)-[:CONNECTED]-(n22),
# (n26)-[:CONNECTED]-(n27),
# (n26)-[:CONNECTED]-(n34),
# (n27)-[:CONNECTED]-(n28),
# (n27)-[:CONNECTED]-(n34),
# (n27)-[:CONNECTED]-(n35),
# (n28)-[:CONNECTED]-(n29),
# (n28)-[:CONNECTED]-(n35),
# (n29)-[:CONNECTED]-(n30),
# (n29)-[:CONNECTED]-(n35),
# (n30)-[:CONNECTED]-(n31),
# (n30)-[:CONNECTED]-(n39),
# (n31)-[:CONNECTED]-(n32),
# (n32)-[:CONNECTED]-(n33),
# (n34)-[:CONNECTED]-(n35),
# (n34)-[:CONNECTED]-(n36),
# (n36)-[:CONNECTED]-(n37),
# (n37)-[:CONNECTED]-(n38),
# (n38)-[:CONNECTED]-(n39)
# ****************************************************************************************************

# %%
# %%time

# Run CREATE command
client.query(create_command)

# Commit the change
client.query("COMMIT")
client.query("CHANGE SUBMIT")

# Checkout into main
client.checkout()
# Out:
# CPU times: user 3.49 ms, sys: 104 μs, total: 3.59 ms
# Wall time: 7.16 ms

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         Visualize your graph in TuringDB Graph Visualizer ! Now that your instance is running:
#     </h2>
#     <h3>
#         <ul>
#             <li>Go to <a href="https://console.turingdb.ai/databases">TuringDB Console - Database Instances</a></li>
#             <li>In your current instance panel, click on "Open Visualizer" button</li>
#             <li>Visualizer opens, now you can choose your graph in the dropdown menu at the top-right corner</li>
#         </ul>
#         You can then play with your graph and visualize the nodes you want !
#     </h3>
# </div>

# %% [markdown]
# # Query TuringDB

# %% [markdown]
# ## Use metaqueries to have insight on graph overall structure
#
# <h3>
#     To learn more about 📮 Metaqueries, please check TuringDB documentation on this <a href="https://turingdb.mintlify.app/query/cypher_subset#%F0%9F%93%AE-metaqueries">link</a>
# </h3>

# %%
# %%time

# CALL LABELS () - returns a column of all the different node labels
command = """
CALL LABELS()
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = ["Node_type_ID", "Node_type"]
    display(df)
# Out:
#    Node_type_ID                         Node_type
# 0             0                          Reaction
# 1             1                           Complex
# 2             2                     BlackBoxEvent
# 3             3     EntityWithAccessionedSequence
# 4             4  PositiveGeneExpressionRegulation
# 5             5                PositiveRegulation
# CPU times: user 4.57 ms, sys: 121 μs, total: 4.69 ms
# Wall time: 4.23 ms

# %%
# %%time

# CALL EDGETYPES() - returns a column of all the different edge types (edge equivalent of node labels)
command = """
CALL EDGETYPES()
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = ["Edge_type_ID", "Edge_type"]
    display(df)
# Out:
#    Edge_type_ID  Edge_type
# 0             0  CONNECTED
# CPU times: user 4.18 ms, sys: 35 μs, total: 4.21 ms
# Wall time: 3.96 ms

# %% [markdown]
# ## Simple queries

# %%
# %%time

# Match all edges and return them
command = """
MATCH (n)-[e]-(m) RETURN n.displayName, e, m.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#                                         n.displayName   e  \
# 0               TP53 binds the PMAIP1 (NOXA) promoter   0
# 1               TP53 binds the PMAIP1 (NOXA) promoter   1
# 2               TP53 binds the PMAIP1 (NOXA) promoter   2
# 3               TP53 binds the PMAIP1 (NOXA) promoter   3
# 4                  TP53 binds the APAF1 gene promoter   4
# 5               NRF1:PPARGC1B binds the CYCS promoter   5
# 6               NRF1:PPARGC1B binds the CYCS promoter   6
# 7                                 CYCS binds to APAF1   7
# 8                                 CYCS binds to APAF1   8
# 9                      E2F1 binds APAF1 gene promoter   9
# 10                   p38 MAPK phosphorylates PPARGC1A  10
# 11                   p38 MAPK phosphorylates PPARGC1A  11
# 12      NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter  12
# 13      NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter  13
# 14     Translocation of PMAIP1 (NOXA) to mitochondria  14
# 15     Translocation of PMAIP1 (NOXA) to mitochondria  15
# 16     Translocation of PMAIP1 (NOXA) to mitochondria  16
# 17  BH3-only proteins associate with and inactivat...  17
# 18              Translocation of tBID to mitochondria  18
# 19          Release of Cytochrome c from mitochondria  19
# 20                   E2F1:(TFDP1,TFDP2) [nucleoplasm]  20
# 21              CYCS gene:NRF1:PPARGC1B [nucleoplasm]  21
# 22              CYCS gene:NRF1:PPARGC1B [nucleoplasm]  22
# 23                     RORA:Coactivator [nucleoplasm]  23
# 24              p-S15,S20-TP53 Tetramer [nucleoplasm]  24
# 25              p-S15,S20-TP53 Tetramer [nucleoplasm]  25
# 26              p-S15,S20-TP53 Tetramer [nucleoplasm]  26
# 27              p-S15,S20-TP53 Tetramer [nucleoplasm]  27
# 28  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]  28
# 29                     E2F1:TFDP1,TFDP2 [nucleoplasm]  29
# 30                     E2F1:TFDP1,TFDP2 [nucleoplasm]  30
# 31  APAF1 gene expression is stimulated by E2F1 an...  31
# 32           Transactivation of PMAIP1 (NOXA) by E2F1  32
# 33           Transactivation of PMAIP1 (NOXA) by E2F1  33
# 34                                 Expression of CYCS  34
# 35              TP53 stimulates APAF1 gene expression  35
# 36              TP53 stimulates APAF1 gene expression  36
# 37           TP53 stimulates PMAIP1 (NOXA) expression  37
# 38           TP53 stimulates PMAIP1 (NOXA) expression  38
# 39                                 E2F1 [nucleoplasm]  39
# 40                                ESRRA [nucleoplasm]  40
# 41                                     CYCS [cytosol]  41
# 42                                     CYCS [cytosol]  42
# 43                                     CYCS [cytosol]  43
# 44                                EP300 [nucleoplasm]  44
# 45                          PMAIP1 Gene [nucleoplasm]  45
# 46                          PMAIP1 Gene [nucleoplasm]  46
# 47                          PMAIP1 Gene [nucleoplasm]  47
# 48                          PMAIP1 Gene [nucleoplasm]  48
# 49                             PPARGC1A [nucleoplasm]  49
# 50                             PPARGC1A [nucleoplasm]  50
# 51                                 NRF1 [nucleoplasm]  51
# 52                                 NRF1 [nucleoplasm]  52
# 53                                 NRF1 [nucleoplasm]  53
# 54                                    APAF1 [cytosol]  54
# 55  Positive gene expression regulation by E2F1:TF...  55
# 56         Positive regulation by ESRRA [nucleoplasm]  56
#
#                                         m.displayName
# 0               p-S15,S20-TP53 Tetramer [nucleoplasm]
# 1                           PMAIP1 Gene [nucleoplasm]
# 2   p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 3            TP53 stimulates PMAIP1 (NOXA) expression
# 4               TP53 stimulates APAF1 gene expression
# 5                                  Expression of CYCS
# 6                                  Expression of NRF1
# 7           Release of Cytochrome c from mitochondria
# 8                                      CYCS [cytosol]
# 9   APAF1 gene expression is stimulated by E2F1 an...
# 10                                 Expression of NRF1
# 11                             PPARGC1A [nucleoplasm]
# 12                   p38 MAPK phosphorylates PPARGC1A
# 13                                 Expression of NRF1
# 14                                   PMAIP1 [cytosol]
# 15  BH3-only proteins associate with and inactivat...
# 16           Transactivation of PMAIP1 (NOXA) by E2F1
# 17              Translocation of tBID to mitochondria
# 18          Release of Cytochrome c from mitochondria
# 19           CYCS [mitochondrial intermembrane space]
# 20                     E2F1 binds APAF1 gene promoter
# 21              NRF1:PPARGC1B binds the CYCS promoter
# 22                                 NRF1 [nucleoplasm]
# 23                                EP300 [nucleoplasm]
# 24  p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ...
# 25  Positive gene expression regulation by p-S15,S...
# 26                 TP53 binds the APAF1 gene promoter
# 27  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 28  Positive gene expression regulation by p-S15,S...
# 29                                 E2F1 [nucleoplasm]
# 30                  E2F1 binds PMAIP1 (NOXA) promoter
# 31                                    APAF1 [cytosol]
# 32  Positive gene expression regulation by E2F1:TF...
# 33                  E2F1 binds PMAIP1 (NOXA) promoter
# 34         Positive regulation by ESRRA [nucleoplasm]
# 35                                    APAF1 [cytosol]
# 36                                CYCS binds to APAF1
# 37     Translocation of PMAIP1 (NOXA) to mitochondria
# 38  Positive gene expression regulation by p-S15,S...
# 39                   E2F1:(TFDP1,TFDP2) [nucleoplasm]
# 40                       ESRRA:PPARGC1A [nucleoplasm]
# 41          Release of Cytochrome c from mitochondria
# 42                               APAF1:CYCS [cytosol]
# 43                                 Expression of CYCS
# 44  p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ...
# 45  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 46           TP53 stimulates PMAIP1 (NOXA) expression
# 47           Transactivation of PMAIP1 (NOXA) by E2F1
# 48                  E2F1 binds PMAIP1 (NOXA) promoter
# 49                     RORA:Coactivator [nucleoplasm]
# 50                       ESRRA:PPARGC1A [nucleoplasm]
# 51      NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter
# 52              NRF1:PPARGC1B binds the CYCS promoter
# 53                                 Expression of NRF1
# 54                               APAF1:CYCS [cytosol]
# 55                     E2F1:TFDP1,TFDP2 [nucleoplasm]
# 56                                ESRRA [nucleoplasm]
# CPU times: user 7.11 ms, sys: 55 μs, total: 7.17 ms
# Wall time: 6.68 ms

# %%
# %%time

# Find all nodes of type "EntityWithAccessionedSequence" (which is also schemaClass) and referenceType "ReferenceGeneProduct"
command = """
MATCH (n:EntityWithAccessionedSequence {"referenceType"="ReferenceGeneProduct"})
RETURN n.displayName, n.schemaClass, n.referenceType
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#                               n.displayName                  n.schemaClass  \
# 0                        E2F1 [nucleoplasm]  EntityWithAccessionedSequence
# 1                       ESRRA [nucleoplasm]  EntityWithAccessionedSequence
# 2                            CYCS [cytosol]  EntityWithAccessionedSequence
# 3                       EP300 [nucleoplasm]  EntityWithAccessionedSequence
# 4                    PPARGC1A [nucleoplasm]  EntityWithAccessionedSequence
# 5                        NRF1 [nucleoplasm]  EntityWithAccessionedSequence
# 6  CYCS [mitochondrial intermembrane space]  EntityWithAccessionedSequence
# 7                          PMAIP1 [cytosol]  EntityWithAccessionedSequence
# 8                           APAF1 [cytosol]  EntityWithAccessionedSequence
#
#         n.referenceType
# 0  ReferenceGeneProduct
# 1  ReferenceGeneProduct
# 2  ReferenceGeneProduct
# 3  ReferenceGeneProduct
# 4  ReferenceGeneProduct
# 5  ReferenceGeneProduct
# 6  ReferenceGeneProduct
# 7  ReferenceGeneProduct
# 8  ReferenceGeneProduct
# CPU times: user 9.55 ms, sys: 123 μs, total: 9.68 ms
# Wall time: 9.13 ms

# %%
# %%time

# Find all nodes of schemaClass "EntityWithAccessionedSequence" and referenceType "ReferenceGeneProduct"
command = """
MATCH (n)
RETURN n.schemaClass
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(pd.DataFrame(df.value_counts()))
# Out:
#                                   count
# n.schemaClass
# Reaction                             12
# EntityWithAccessionedSequence        10
# Complex                               9
# BlackBoxEvent                         6
# PositiveGeneExpressionRegulation      2
# PositiveRegulation                    1
# CPU times: user 10.3 ms, sys: 1.86 ms, total: 12.1 ms
# Wall time: 10.7 ms

# %%
# %%time

# Find all nodes of type "PositiveGeneExpressionRegulation" (which is also schemaClass)
command = """
MATCH (n:PositiveGeneExpressionRegulation)
RETURN n, n.displayName, n.schemaClass
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#     n                                      n.displayName  \
# 0  37  Positive gene expression regulation by p-S15,S...
# 1  38  Positive gene expression regulation by E2F1:TF...
#
#                       n.schemaClass
# 0  PositiveGeneExpressionRegulation
# 1  PositiveGeneExpressionRegulation
# CPU times: user 9.05 ms, sys: 1.01 ms, total: 10.1 ms
# Wall time: 8.69 ms

# %%
# %%time

# Find all edges involving a node of type Complex
command = """
MATCH (n:Complex)-[e]-(m)
RETURN n.displayName, n.schemaClass, e, m.displayName, m.schemaClass, m.category
"""
df1 = client.query(command)
if df1.empty:
    print("No result found")
else:
    df1.columns = get_return_statements(command)

command = """
MATCH (n)-[e]-(m:Complex)
RETURN n.displayName, n.schemaClass, e, m.displayName, m.schemaClass, m.category
"""
df2 = client.query(command)
if df2.empty:
    print("No result found")
else:
    df2.columns = get_return_statements(command)

df = pd.concat([df1, df2], axis=0).sort_values("e")
df.index = range(len(df))
df
# Out:
# CPU times: user 5 ms, sys: 1 ms, total: 6.01 ms
# Wall time: 5.24 ms
#                                         n.displayName  \
# 0               TP53 binds the PMAIP1 (NOXA) promoter
# 1               TP53 binds the PMAIP1 (NOXA) promoter
# 2                    E2F1:(TFDP1,TFDP2) [nucleoplasm]
# 3               CYCS gene:NRF1:PPARGC1B [nucleoplasm]
# 4               CYCS gene:NRF1:PPARGC1B [nucleoplasm]
# 5                      RORA:Coactivator [nucleoplasm]
# 6               p-S15,S20-TP53 Tetramer [nucleoplasm]
# 7               p-S15,S20-TP53 Tetramer [nucleoplasm]
# 8               p-S15,S20-TP53 Tetramer [nucleoplasm]
# 9               p-S15,S20-TP53 Tetramer [nucleoplasm]
# 10              p-S15,S20-TP53 Tetramer [nucleoplasm]
# 11              p-S15,S20-TP53 Tetramer [nucleoplasm]
# 12  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 13                     E2F1:TFDP1,TFDP2 [nucleoplasm]
# 14                     E2F1:TFDP1,TFDP2 [nucleoplasm]
# 15                                 E2F1 [nucleoplasm]
# 16                                ESRRA [nucleoplasm]
# 17                                     CYCS [cytosol]
# 18                                EP300 [nucleoplasm]
# 19                          PMAIP1 Gene [nucleoplasm]
# 20                             PPARGC1A [nucleoplasm]
# 21                             PPARGC1A [nucleoplasm]
# 22                                    APAF1 [cytosol]
# 23  Positive gene expression regulation by E2F1:TF...
#
#                        n.schemaClass   e  \
# 0                           Reaction   0
# 1                           Reaction   2
# 2                            Complex  20
# 3                            Complex  21
# 4                            Complex  22
# 5                            Complex  23
# 6                            Complex  24
# 7                            Complex  24
# 8                            Complex  25
# 9                            Complex  26
# 10                           Complex  27
# 11                           Complex  27
# 12                           Complex  28
# 13                           Complex  29
# 14                           Complex  30
# 15     EntityWithAccessionedSequence  39
# 16     EntityWithAccessionedSequence  40
# 17     EntityWithAccessionedSequence  42
# 18     EntityWithAccessionedSequence  44
# 19     EntityWithAccessionedSequence  45
# 20     EntityWithAccessionedSequence  49
# 21     EntityWithAccessionedSequence  50
# 22     EntityWithAccessionedSequence  54
# 23  PositiveGeneExpressionRegulation  55
#
#                                         m.displayName  \
# 0               p-S15,S20-TP53 Tetramer [nucleoplasm]
# 1   p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 2                      E2F1 binds APAF1 gene promoter
# 3               NRF1:PPARGC1B binds the CYCS promoter
# 4                                  NRF1 [nucleoplasm]
# 5                                 EP300 [nucleoplasm]
# 6   p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ...
# 7   p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ...
# 8   Positive gene expression regulation by p-S15,S...
# 9                  TP53 binds the APAF1 gene promoter
# 10  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 11  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 12  Positive gene expression regulation by p-S15,S...
# 13                                 E2F1 [nucleoplasm]
# 14                  E2F1 binds PMAIP1 (NOXA) promoter
# 15                   E2F1:(TFDP1,TFDP2) [nucleoplasm]
# 16                       ESRRA:PPARGC1A [nucleoplasm]
# 17                               APAF1:CYCS [cytosol]
# 18  p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ...
# 19  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 20                     RORA:Coactivator [nucleoplasm]
# 21                       ESRRA:PPARGC1A [nucleoplasm]
# 22                               APAF1:CYCS [cytosol]
# 23                     E2F1:TFDP1,TFDP2 [nucleoplasm]
#
#                        m.schemaClass m.category
# 0                            Complex       None
# 1                            Complex       None
# 2                           Reaction    binding
# 3                           Reaction    binding
# 4      EntityWithAccessionedSequence       None
# 5      EntityWithAccessionedSequence       None
# 6                            Complex       None
# 7                            Complex       None
# 8   PositiveGeneExpressionRegulation       None
# 9                           Reaction    binding
# 10                           Complex       None
# 11                           Complex       None
# 12  PositiveGeneExpressionRegulation       None
# 13     EntityWithAccessionedSequence       None
# 14                          Reaction    binding
# 15                           Complex       None
# 16                           Complex       None
# 17                           Complex       None
# 18                           Complex       None
# 19                           Complex       None
# 20                           Complex       None
# 21                           Complex       None
# 22                           Complex       None
# 23                           Complex       None

# %%
# %%time

# Find all edges involving one node related to mitochondria using string approximation
command = """
MATCH (n {"displayName"~="mitochond"})-[e]-(m)
RETURN n.displayName, n.schemaClass, e, m.displayName, m.schemaClass
"""
df1 = client.query(command)
if df1.empty:
    print("No result found")
else:
    df1.columns = get_return_statements(command)

command = """
MATCH (n)-[e]-(m {"displayName"~="mitochond"})
RETURN n.displayName, n.schemaClass, e, m.displayName, m.schemaClass
"""
df2 = client.query(command)
if df2.empty:
    print("No result found")
else:
    df2.columns = get_return_statements(command)

df = pd.concat([df1, df2], axis=0).sort_values("e")
df.index = range(len(df))
df
# Out:
# CPU times: user 8.35 ms, sys: 216 μs, total: 8.56 ms
# Wall time: 7.28 ms
#                                         n.displayName  \
# 0                                 CYCS binds to APAF1
# 1      Translocation of PMAIP1 (NOXA) to mitochondria
# 2      Translocation of PMAIP1 (NOXA) to mitochondria
# 3      Translocation of PMAIP1 (NOXA) to mitochondria
# 4   BH3-only proteins associate with and inactivat...
# 5               Translocation of tBID to mitochondria
# 6               Translocation of tBID to mitochondria
# 7           Release of Cytochrome c from mitochondria
# 8           Release of Cytochrome c from mitochondria
# 9            TP53 stimulates PMAIP1 (NOXA) expression
# 10                                     CYCS [cytosol]
#
#                     n.schemaClass   e  \
# 0                        Reaction   7
# 1                        Reaction  14
# 2                        Reaction  15
# 3                        Reaction  16
# 4                        Reaction  17
# 5                        Reaction  18
# 6                        Reaction  18
# 7                        Reaction  19
# 8                        Reaction  19
# 9                   BlackBoxEvent  37
# 10  EntityWithAccessionedSequence  41
#
#                                         m.displayName  \
# 0           Release of Cytochrome c from mitochondria
# 1                                    PMAIP1 [cytosol]
# 2   BH3-only proteins associate with and inactivat...
# 3            Transactivation of PMAIP1 (NOXA) by E2F1
# 4               Translocation of tBID to mitochondria
# 5           Release of Cytochrome c from mitochondria
# 6           Release of Cytochrome c from mitochondria
# 7            CYCS [mitochondrial intermembrane space]
# 8            CYCS [mitochondrial intermembrane space]
# 9      Translocation of PMAIP1 (NOXA) to mitochondria
# 10          Release of Cytochrome c from mitochondria
#
#                     m.schemaClass
# 0                        Reaction
# 1   EntityWithAccessionedSequence
# 2                        Reaction
# 3                   BlackBoxEvent
# 4                        Reaction
# 5                        Reaction
# 6                        Reaction
# 7   EntityWithAccessionedSequence
# 8   EntityWithAccessionedSequence
# 9                        Reaction
# 10                       Reaction

# %%
# %%time

# Find all edges with a node of category "binding" going to an other node
command = """
MATCH (n {"category"="binding"})-[e]-(m)
RETURN n.displayName, n.schemaClass, n.category, e, m.displayName, m.schemaClass, m.category
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#                                         n.displayName n.schemaClass  \
# 0               TP53 binds the PMAIP1 (NOXA) promoter      Reaction
# 1               TP53 binds the PMAIP1 (NOXA) promoter      Reaction
# 2               TP53 binds the PMAIP1 (NOXA) promoter      Reaction
# 3               TP53 binds the PMAIP1 (NOXA) promoter      Reaction
# 4                  TP53 binds the APAF1 gene promoter      Reaction
# 5               NRF1:PPARGC1B binds the CYCS promoter      Reaction
# 6               NRF1:PPARGC1B binds the CYCS promoter      Reaction
# 7                                 CYCS binds to APAF1      Reaction
# 8                                 CYCS binds to APAF1      Reaction
# 9                      E2F1 binds APAF1 gene promoter      Reaction
# 10      NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter      Reaction
# 11      NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter      Reaction
# 12  BH3-only proteins associate with and inactivat...      Reaction
#
#    n.category   e                                      m.displayName  \
# 0     binding   0              p-S15,S20-TP53 Tetramer [nucleoplasm]
# 1     binding   1                          PMAIP1 Gene [nucleoplasm]
# 2     binding   2  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 3     binding   3           TP53 stimulates PMAIP1 (NOXA) expression
# 4     binding   4              TP53 stimulates APAF1 gene expression
# 5     binding   5                                 Expression of CYCS
# 6     binding   6                                 Expression of NRF1
# 7     binding   7          Release of Cytochrome c from mitochondria
# 8     binding   8                                     CYCS [cytosol]
# 9     binding   9  APAF1 gene expression is stimulated by E2F1 an...
# 10    binding  12                   p38 MAPK phosphorylates PPARGC1A
# 11    binding  13                                 Expression of NRF1
# 12    binding  17              Translocation of tBID to mitochondria
#
#                     m.schemaClass  m.category
# 0                         Complex        None
# 1   EntityWithAccessionedSequence        None
# 2                         Complex        None
# 3                   BlackBoxEvent     omitted
# 4                   BlackBoxEvent     omitted
# 5                   BlackBoxEvent     omitted
# 6                   BlackBoxEvent     omitted
# 7                        Reaction  transition
# 8   EntityWithAccessionedSequence        None
# 9                   BlackBoxEvent     omitted
# 10                       Reaction  transition
# 11                  BlackBoxEvent     omitted
# 12                       Reaction  transition
# CPU times: user 11.8 ms, sys: 1.7 ms, total: 13.5 ms
# Wall time: 12.4 ms

# %% [markdown]
# ## Complex queries

# %%
def build_query_chain(
    hop_count: int,
    start_node_label: str = None,
    start_node_property: str = None,
    start_node_value: str = None,
    end_node_label: str = None,
    end_node_property: str = None,
    end_node_value: str = None,
    edge_type: str = None,
    intermediate_node_label: str = None,
    return_properties: list = None
) -> tuple[str, list[str]]:
    """
    Build a general query to find chains between nodes.
    
    Parameters:
    -----------
    hop_count : int
        Number of hops/edges in the path (REQUIRED)
    start_node_label : str, optional
        Label of the starting node (e.g., 'Process', 'Station')
    start_node_property : str, optional
        Property name to match on start node (e.g., 'displayName', 'id')
    start_node_value : str, optional
        Value to match for start node
    end_node_label : str, optional
        Label of the ending node (None for any node)
    end_node_property : str, optional
        Property name to match on end node
    end_node_value : str, optional
        Value to match for end node
    edge_type : str, optional
        Type of edges to traverse (None for any edge type)
    intermediate_node_label : str, optional
        Label constraint for intermediate nodes (None for any label)
    return_properties : list, optional
        List of property names to return for nodes (default: ['displayName'])
    
    Returns:
    --------
    tuple : (query_string, column_names)
    """
    
    if return_properties is None:
        return_properties = ['displayName']
    
    # Build MATCH clause
    query = "MATCH "
    
    # Start node - build based on what's provided
    start_parts = []
    if start_node_label:
        start_parts.append(f":{start_node_label}")
    if start_node_property and start_node_value:
        start_parts.append(f'{{{start_node_property}:"{start_node_value}"}}')
    
    if start_parts:
        query += f'(start{"".join(start_parts)})'
    else:
        query += "(start)"
    
    # Intermediate nodes and edges
    for k in range(1, hop_count + 1):
        # Edge
        if edge_type:
            query += f"-[e{k}:{edge_type}]-"
        else:
            query += f"-[e{k}]-"
        
        # Last hop - end node
        if k == hop_count:
            end_parts = []
            if end_node_label:
                end_parts.append(f":{end_node_label}")
            if end_node_property and end_node_value:
                end_parts.append(f'{{{end_node_property}:"{end_node_value}"}}')
            
            if end_parts:
                query += f'(end{"".join(end_parts)})'
            else:
                query += "(end)"
        # Intermediate nodes
        else:
            if intermediate_node_label:
                query += f"(s{k}:{intermediate_node_label})"
            else:
                query += f"(s{k})"
    
    # Build RETURN clause
    query += " RETURN start"
    column_names = ['start']
    
    # Add start node properties
    for prop in return_properties:
        query += f", start.{prop}"
        column_names.append(f'start.{prop}')
    
    # Add intermediate nodes/edges
    for k in range(1, hop_count + 1):
        query += f", e{k}"
        column_names.append(f'e{k}')
        
        if k == hop_count:
            query += ", end"
            column_names.append('end')
            for prop in return_properties:
                query += f", end.{prop}"
                column_names.append(f'end.{prop}')
        else:
            query += f", s{k}"
            column_names.append(f's{k}')
            for prop in return_properties:
                query += f", s{k}.{prop}"
                column_names.append(f's{k}.{prop}')
    
    return query, column_names

# %%
# %%time

# Find all paths (with maximum length of 15 hops) between a node of type "EntityWithAccessionedSequence" and a node of type "BlackBoxEvent"
max_hops = 15
longest_df = None

for hop in range(1, max_hops):
    print(100 * "*")
    print(f"{hop} hop(s) :\n")
    
    query, cols = build_query_chain(
        hop_count=hop,
        start_node_label="EntityWithAccessionedSequence",
        end_node_label="BlackBoxEvent",
        return_properties=['id', 'displayName', 'schemaClass', 'category']
    )
    
    # Use with client
    df = client.query(query)
    if df.empty:
        print("No result found")
    else:
        df.columns = cols
        display(df)
        longest_df = df

print(100 * "*")
# Out:
# ****************************************************************************************************
# 1 hop(s) :
#    start                   start.id          start.displayName  \
# 0     29             CYCS [cytosol]             CYCS [cytosol]
# 1     31  PMAIP1 Gene [nucleoplasm]  PMAIP1 Gene [nucleoplasm]
# 2     31  PMAIP1 Gene [nucleoplasm]  PMAIP1 Gene [nucleoplasm]
# 3     33         NRF1 [nucleoplasm]         NRF1 [nucleoplasm]
#
#                start.schemaClass start.category  e1  end  \
# 0  EntityWithAccessionedSequence           None  43   23
# 1  EntityWithAccessionedSequence           None  46   26
# 2  EntityWithAccessionedSequence           None  47   22
# 3  EntityWithAccessionedSequence           None  53   24
#
#                                      end.id  \
# 0                        Expression of CYCS
# 1  TP53 stimulates PMAIP1 (NOXA) expression
# 2  Transactivation of PMAIP1 (NOXA) by E2F1
# 3                        Expression of NRF1
#
#                             end.displayName end.schemaClass end.category
# 0                        Expression of CYCS   BlackBoxEvent      omitted
# 1  TP53 stimulates PMAIP1 (NOXA) expression   BlackBoxEvent      omitted
# 2  Transactivation of PMAIP1 (NOXA) by E2F1   BlackBoxEvent      omitted
# 3                        Expression of NRF1   BlackBoxEvent      omitted
# ****************************************************************************************************
# 2 hop(s) :
#    start            start.id   start.displayName  \
# 0     33  NRF1 [nucleoplasm]  NRF1 [nucleoplasm]
# 1     33  NRF1 [nucleoplasm]  NRF1 [nucleoplasm]
# 2     33  NRF1 [nucleoplasm]  NRF1 [nucleoplasm]
#
#                start.schemaClass start.category  e1  s1  \
# 0  EntityWithAccessionedSequence           None  51   6
# 1  EntityWithAccessionedSequence           None  52   2
# 2  EntityWithAccessionedSequence           None  52   2
#
#                                            s1.id  \
# 0  NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter
# 1          NRF1:PPARGC1B binds the CYCS promoter
# 2          NRF1:PPARGC1B binds the CYCS promoter
#
#                                   s1.displayName s1.schemaClass s1.category  \
# 0  NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter       Reaction     binding
# 1          NRF1:PPARGC1B binds the CYCS promoter       Reaction     binding
# 2          NRF1:PPARGC1B binds the CYCS promoter       Reaction     binding
#
#    e2  end              end.id     end.displayName end.schemaClass  \
# 0  13   24  Expression of NRF1  Expression of NRF1   BlackBoxEvent
# 1   5   23  Expression of CYCS  Expression of CYCS   BlackBoxEvent
# 2   6   24  Expression of NRF1  Expression of NRF1   BlackBoxEvent
#
#   end.category
# 0      omitted
# 1      omitted
# 2      omitted
# ****************************************************************************************************
# 3 hop(s) :
#    start                   start.id          start.displayName  \
# 0     27         E2F1 [nucleoplasm]         E2F1 [nucleoplasm]
# 1     31  PMAIP1 Gene [nucleoplasm]  PMAIP1 Gene [nucleoplasm]
# 2     33         NRF1 [nucleoplasm]         NRF1 [nucleoplasm]
#
#                start.schemaClass start.category  e1  s1  \
# 0  EntityWithAccessionedSequence           None  39  12
# 1  EntityWithAccessionedSequence           None  46  26
# 2  EntityWithAccessionedSequence           None  51   6
#
#                                            s1.id  \
# 0               E2F1:(TFDP1,TFDP2) [nucleoplasm]
# 1       TP53 stimulates PMAIP1 (NOXA) expression
# 2  NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter
#
#                                   s1.displayName s1.schemaClass  ...  \
# 0               E2F1:(TFDP1,TFDP2) [nucleoplasm]        Complex  ...
# 1       TP53 stimulates PMAIP1 (NOXA) expression  BlackBoxEvent  ...
# 2  NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter       Reaction  ...
#
#                                             s2.id  \
# 0                  E2F1 binds APAF1 gene promoter
# 1  Translocation of PMAIP1 (NOXA) to mitochondria
# 2                p38 MAPK phosphorylates PPARGC1A
#
#                                    s2.displayName  s2.schemaClass s2.category  \
# 0                  E2F1 binds APAF1 gene promoter        Reaction     binding
# 1  Translocation of PMAIP1 (NOXA) to mitochondria        Reaction  transition
# 2                p38 MAPK phosphorylates PPARGC1A        Reaction  transition
#
#    e3 end                                             end.id  \
# 0   9  21  APAF1 gene expression is stimulated by E2F1 an...
# 1  16  22           Transactivation of PMAIP1 (NOXA) by E2F1
# 2  10  24                                 Expression of NRF1
#
#                                      end.displayName  end.schemaClass  \
# 0  APAF1 gene expression is stimulated by E2F1 an...    BlackBoxEvent
# 1           Transactivation of PMAIP1 (NOXA) by E2F1    BlackBoxEvent
# 2                                 Expression of NRF1    BlackBoxEvent
#
#   end.category
# 0      omitted
# 1      omitted
# 2      omitted
#
# [3 rows x 23 columns]
# ****************************************************************************************************
# 4 hop(s) :
#
# No result found
# ****************************************************************************************************
# 5 hop(s) :
#
# No result found
# ****************************************************************************************************
# 6 hop(s) :
#
# No result found
# ****************************************************************************************************
# 7 hop(s) :
#    start                   start.id          start.displayName  \
# 0     31  PMAIP1 Gene [nucleoplasm]  PMAIP1 Gene [nucleoplasm]
#
#                start.schemaClass start.category  e1  s1  \
# 0  EntityWithAccessionedSequence           None  47  22
#
#                                       s1.id  \
# 0  Transactivation of PMAIP1 (NOXA) by E2F1
#
#                              s1.displayName s1.schemaClass  ...  \
# 0  Transactivation of PMAIP1 (NOXA) by E2F1  BlackBoxEvent  ...
#
#                             s6.id                  s6.displayName  \
# 0  E2F1 binds APAF1 gene promoter  E2F1 binds APAF1 gene promoter
#
#    s6.schemaClass s6.category e7 end  \
# 0        Reaction     binding  9  21
#
#                                               end.id  \
# 0  APAF1 gene expression is stimulated by E2F1 an...
#
#                                      end.displayName  end.schemaClass  \
# 0  APAF1 gene expression is stimulated by E2F1 an...    BlackBoxEvent
#
#   end.category
# 0      omitted
#
# [1 rows x 47 columns]
# ****************************************************************************************************
# 8 hop(s) :
#
# No result found
# ****************************************************************************************************
# 9 hop(s) :
#    start                   start.id          start.displayName  \
# 0     31  PMAIP1 Gene [nucleoplasm]  PMAIP1 Gene [nucleoplasm]
#
#                start.schemaClass start.category  e1  s1  \
# 0  EntityWithAccessionedSequence           None  46  26
#
#                                       s1.id  \
# 0  TP53 stimulates PMAIP1 (NOXA) expression
#
#                              s1.displayName s1.schemaClass  ...  \
# 0  TP53 stimulates PMAIP1 (NOXA) expression  BlackBoxEvent  ...
#
#                             s8.id                  s8.displayName  \
# 0  E2F1 binds APAF1 gene promoter  E2F1 binds APAF1 gene promoter
#
#    s8.schemaClass s8.category e9 end  \
# 0        Reaction     binding  9  21
#
#                                               end.id  \
# 0  APAF1 gene expression is stimulated by E2F1 an...
#
#                                      end.displayName  end.schemaClass  \
# 0  APAF1 gene expression is stimulated by E2F1 an...    BlackBoxEvent
#
#   end.category
# 0      omitted
#
# [1 rows x 59 columns]
# ****************************************************************************************************
# 10 hop(s) :
#
# No result found
# ****************************************************************************************************
# 11 hop(s) :
#
# No result found
# ****************************************************************************************************
# 12 hop(s) :
#
# No result found
# ****************************************************************************************************
# 13 hop(s) :
#
# No result found
# ****************************************************************************************************
# 14 hop(s) :
#
# No result found
# ****************************************************************************************************
# CPU times: user 46.2 ms, sys: 2.34 ms, total: 48.5 ms
# Wall time: 45.3 ms

# %% [markdown]
# # Create subgraph to visualise

# %%
# Get subgraph
subset_nodes = longest_df.filter(regex="id$", axis=1).iloc[0].values.tolist()
subG = G.subgraph(subset_nodes).copy()
print(subG)

# Build CREATE command from subgraph
create_command_subG = build_create_command_from_networkx(subG)
print(f"Cypher CREATE command :\n\n{100 * '*'}\n{create_command_subG}\n{100 * '*'}")
# Out:
# MultiGraph with 10 nodes and 10 edges
# Cypher CREATE command :
#
# ****************************************************************************************************
# CREATE (n0:Node {"id":"Translocation of PMAIP1 (NOXA) to mitochondria", "schemaClass":"Reaction", "stId":"R-HSA-140216", "oldStId":"REACT_1585", "releaseDate":"2004-10-27", "name":"[ Translocation of PMAIP1 (NOXA) to mitochondria ]", "stIdVersion":"R-HSA-140216.4", "speciesName":"Homo sapiens", "category":"transition", "displayName":"Translocation of PMAIP1 (NOXA) to mitochondria"}),
# (n1:Node {"id":"TP53 stimulates PMAIP1 (NOXA) expression", "schemaClass":"BlackBoxEvent", "stId":"R-HSA-140214", "oldStId":"REACT_2201", "releaseDate":"2004-10-27", "name":"[ TP53 stimulates PMAIP1 (NOXA) expression ]", "stIdVersion":"R-HSA-140214.6", "speciesName":"Homo sapiens", "category":"omitted", "displayName":"TP53 stimulates PMAIP1 (NOXA) expression"}),
# (n2:Node {"id":"E2F1 [nucleoplasm]", "schemaClass":"EntityWithAccessionedSequence", "stId":"R-HSA-68639", "oldStId":"REACT_2601", "name":"[ E2F1 , Transcription factor E2F1 , E2F-1 , Retinoblastoma binding protein 3 , RBBP-3 , PRB-binding protein E2F-1 , PBR3 , Retinoblastoma-associated protein 1 , RBAP-1 ]", "stIdVersion":"R-HSA-68639.2", "speciesName":"Homo sapiens", "referenceType":"ReferenceGeneProduct", "displayName":"E2F1 [nucleoplasm]"}),
# (n3:Node {"id":"E2F1:TFDP1,TFDP2 [nucleoplasm]", "schemaClass":"Complex", "stId":"R-HSA-68653", "oldStId":"REACT_5400", "name":"[ E2F1:TFDP1,TFDP2 , DP1/2:E2F1 ]", "stIdVersion":"R-HSA-68653.2", "speciesName":"Homo sapiens", "displayName":"E2F1:TFDP1,TFDP2 [nucleoplasm]"}),
# (n4:Node {"id":"APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6", "schemaClass":"BlackBoxEvent", "stId":"R-HSA-9007496", "releaseDate":"2017-09-12", "name":"[ APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6 ]", "stIdVersion":"R-HSA-9007496.4", "speciesName":"Homo sapiens", "category":"omitted", "displayName":"APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6"}),
# (n5:Node {"id":"E2F1 binds APAF1 gene promoter", "schemaClass":"Reaction", "stId":"R-HSA-9007514", "releaseDate":"2017-09-12", "name":"[ E2F1 binds APAF1 gene promoter ]", "stIdVersion":"R-HSA-9007514.2", "speciesName":"Homo sapiens", "category":"binding", "displayName":"E2F1 binds APAF1 gene promoter"}),
# (n6:Node {"id":"E2F1:(TFDP1,TFDP2) [nucleoplasm]", "schemaClass":"Complex", "stId":"R-HSA-9007512", "name":"[ E2F1:(TFDP1,TFDP2) ]", "stIdVersion":"R-HSA-9007512.1", "speciesName":"Homo sapiens", "displayName":"E2F1:(TFDP1,TFDP2) [nucleoplasm]"}),
# (n7:Node {"id":"Transactivation of PMAIP1 (NOXA) by E2F1", "schemaClass":"BlackBoxEvent", "stId":"R-HSA-140217", "oldStId":"REACT_1872", "releaseDate":"2004-10-27", "name":"[ Transactivation of PMAIP1 (NOXA) by E2F1 ]", "stIdVersion":"R-HSA-140217.4", "speciesName":"Homo sapiens", "category":"omitted", "displayName":"Transactivation of PMAIP1 (NOXA) by E2F1"}),
# (n8:Node {"id":"Positive gene expression regulation by 'E2F1:TFDP1:PMAIP1 Gene [nucleoplasm]'", "schemaClass":"PositiveGeneExpressionRegulation", "stId":"R-HSA-159039", "oldStId":"REACT_6130", "stIdVersion":"R-HSA-159039.1", "displayName":"Positive gene expression regulation by E2F1:TFDP1:PMAIP1 Gene [nucleoplasm]"}),
# (n9:Node {"id":"PMAIP1 Gene [nucleoplasm]", "schemaClass":"EntityWithAccessionedSequence", "stId":"R-HSA-4331342", "oldStId":"REACT_170122", "name":"[ PMAIP1 Gene , NOXA Gene ]", "stIdVersion":"R-HSA-4331342.1", "speciesName":"Homo sapiens", "referenceType":"ReferenceDNASequence", "searchSeed":"1", "displayName":"PMAIP1 Gene [nucleoplasm]"}),
# (n0)-[:CONNECTED]-(n1),
# (n0)-[:CONNECTED]-(n7),
# (n1)-[:CONNECTED]-(n9),
# (n2)-[:CONNECTED]-(n3),
# (n2)-[:CONNECTED]-(n6),
# (n3)-[:CONNECTED]-(n8),
# (n4)-[:CONNECTED]-(n5),
# (n5)-[:CONNECTED]-(n6),
# (n7)-[:CONNECTED]-(n9),
# (n7)-[:CONNECTED]-(n8)
# ****************************************************************************************************

# %%
subgraph_name = f"{graph_name}_subgraph"
subgraph_name
# Out:
# 'reactome4_subgraph'

# %%
# %%time

# Create new graph
client.query(f"CREATE GRAPH {subgraph_name}")
client.set_graph(subgraph_name)

# Create a new change on the graph
change = client.query("CHANGE NEW").loc[0, 0]

# Checkout into the change
client.checkout(change=change)

# Run CREATE command
client.query(create_command_subG)

# Commit the change
client.query("COMMIT")
client.query("CHANGE SUBMIT")

# Checkout into main
client.checkout()
# Out:
# CPU times: user 5.22 ms, sys: 1.72 ms, total: 6.94 ms
# Wall time: 10.4 ms

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         You can visualise the subgraph directly in the notebook below. For more details on nodes and edges, you can go to TuringDB visualizer (running on your instance)
#     </h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         Visualize your graph in TuringDB Graph Visualizer ! Now that your instance is running:
#     </h2>
#     <h3>
#         <ul>
#             <li>Go to <a href="https://console.turingdb.ai/databases">TuringDB Console - Database Instances</a></li>
#             <li>In your current instance panel, click on "Open Visualizer" button</li>
#             <li>Visualizer opens, now you can choose your graph in the dropdown menu at the top-right corner</li>
#         </ul>
#         You can then play with your graph and visualize the nodes you want !
#     </h3>
# </div>

# %%
from pyvis.network import Network
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

net = Network(
    height="750px", width="100%", notebook=True, bgcolor="#ffffff", font_color="#000000", directed=True
)

# Choose your palette (can be changed easily)
palette_name = 'Pastel1'  # Options: 'tab10', 'Set3', 'Paired', 'viridis', 'plasma', etc.

# Get unique node types
unique_types = list(set(data.get('schemaClass') for _, data in G.nodes(data=True)))

# Get colors from matplotlib palette
cmap = plt.get_cmap(palette_name)
colors = [mcolors.rgb2hex(cmap(i / len(unique_types))) for i in range(len(unique_types))]

# Map types to colors
type_colors = {node_type: colors[i] for i, node_type in enumerate(unique_types)}

# Then use in your visualization
for node, data in subG.nodes(data=True):
    node_type = data.get('schemaClass', 'Unknown')
    color = type_colors.get(node_type, '#95a5a6')

    net.add_node(
        node,
        label=data.get("displayName", str(node)),
        title=f"{data.get('displayName', '')}",
        color=color,
        size=25,
    )

for source, target, data in subG.edges(data=True):
    net.add_edge(source, target, color="#95a5a6", width=3)

net.toggle_physics(status=True)
net.show(f"{folder_name}_graph.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# reactome_graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="reactome_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Use LLM to generate Cypher query

# %% [markdown]
# Before running this section, create a `.env` file in the project root with your API keys:
#
# ```env
# ANTHROPIC_API_KEY=your_key_here
# OPENAI_API_KEY=your_key_here
# MISTRAL_API_KEY=your_key_here

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv(override=True)
# Out:
# True

# %%
api_keys = {
    "Anthropic": os.getenv("ANTHROPIC_API_KEY"),
    "Mistral": os.getenv("MISTRAL_API_KEY"),
    "OpenAI": os.getenv("OPENAI_API_KEY"),
}

# %%
"""Build system prompt with TuringDB schema and examples"""

turingdb_cypher_system_prompt = """
You are an expert at converting natural language questions into TuringDB queries.

Your task is to generate syntactically correct TuringDB queries based on natural language input.

VERY IMPORTANT - TuringDB Syntax Guidelines:
1. Return ONLY the TuringDB query, no explanations or markdown formatting
2. Use MATCH or CREATE operations only
3. Nodes: (n:Label{property="value"}) or (n:Label{property:value})
4. Edges: Use UNDIRECTED syntax with - (NOT ->)
5. Pattern matching: MATCH (n)-[e]-(m)
6. Property matching: Use = or : operators for exact matching
7. String approximation: Use ~= for approximate string matching
8. Node ID injection: Use @ operator or AT keyword: (n @ 1) or (n AT 1)
9. Multiple constraints: (n:Person,Engineer{name="John", age=30})
10. Return all matched entities: RETURN n, e, m or use RETURN * for all

VERY IMPORTANT - FORBIDDEN in TuringDB:
- Do NOT use directed edges (-> or <-)
- Do NOT use AS aliases
- Do NOT use LIMIT, SKIP clauses
- Do NOT use WHERE clauses
- Do NOT use WITH clauses
- Do NOT use CALL (except for metaqueries)
- Do NOT use toLower() or other functions

Supported TuringDB Operations:
- MATCH queries: MATCH (n:Label)-[e:Type]-(m) RETURN n, m
- CREATE queries: CREATE (n:Label{property="value"})-[e:Type]-(m:Label)
- Metaqueries: CALL PROPERTIES(), CALL LABELS(), CALL EDGETYPES(), CALL LABELSETS()
- Property types: String ("text" or `text`), Boolean (true/false), Integer (20), Unsigned (20u), Double (20.5)

Examples for few-shot learning:
- Find all persons: MATCH (n:Person) RETURN n
- Find connections: MATCH (n:Person)-[e]-(m:Person) RETURN n, e, m
- Create person: CREATE (n:Person{name="John", age=30})
- String approximation: MATCH (n{name~="John"}) RETURN n
- Node by ID: MATCH (n @ 1) RETURN n
- Multiple IDs: MATCH (n:Person @ 1, 2, 3) RETURN n
- Path with 1 hop between Station Paddington and Blackfriars:  MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, end, end.displayName, end.Note
- Path with 2 hops between Station Paddington and Blackfriars: MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, end, end.displayName, end.Note
- Path with 8 hops between Station Paddington and Blackfriars: MATCH (start:Station{displayName:"Paddington"})-[e1:CONNECTED]-(s1:Station)-[e2:CONNECTED]-(s2:Station)-[e3:CONNECTED]-(s3:Station)-[e4:CONNECTED]-(s4:Station)-[e5:CONNECTED]-(s5:Station)-[e6:CONNECTED]-(s6:Station)-[e7:CONNECTED]-(s7:Station)-[e8:CONNECTED]-(end:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, s5, s5.displayName, s5.Note, e6.Line, s6, s6.displayName, s6.Note, e7.Line, s7, s7.displayName, s7.Note, e8.Line, end, end.displayName, end.Note
- Find all Chinese providers and what they supply: MATCH (n{provider_country:"CHN"}) RETURN n, n.provider_name, n.displayName, n.share_provided, n.type
- Find all deposition tools and their types: MATCH (specific)-[e:IS_TYPE_OF]-(general:Tool_Resource{displayName:"Deposition tools"}) RETURN specific, specific.displayName, specific.provider_name, e, general, general.displayName
"""

# %%
# Get subset of CREATE command to avoid exceeding context window
create_command_subset = create_command.split("\n")[:5] + create_command.split("\n")[-5:]

# Create system_prompt
system_prompt = f"""
TuringDB Cypher prompt :
{turingdb_cypher_system_prompt}

Here is a subset of the CREATE command used to create the graph, this way you know graph structure.
Only a subset is passed because the whole command is to long :
{create_command_subset}

Here is also the output of "CALL LABELS ()" command, showing the different node types of the graph :
{client.query("CALL LABELS ()")}

Here is also the output of "CALL EDGETYPES ()" command, showing the different edge types of the graph :
{client.query("CALL EDGETYPES ()")}

Very important :
- You MUST follow current TuringDB Syntax Guidelines
- You MUST NOT USE what is FORBIDDEN in TuringDB
- By default, RETURN ALL THE MATCHED NODES AND EDGES AND THEIR PROPERTIES in the RETURN section (except contrary demand from user)
- Use the correct node and edge properties name in the MATCH section.
- Use the correct node and edge properties name in the RETURN section.
- Pay attention to which properties come from nodes or edges, to create a functioning query
- Pay attention to lower and uppercases in properties
- If some properties contain spaces, be careful to wrap them

Give me the query FOLLOWING TURINGDB GUIDELINES AND NOT USING WHAT IS FORBIDDEN for this specific question :
"""

# %%
question = """
Is there a path of any size linking gene PMAIP1 and gene E2F1 ?
"""

# %%
# %%time

provider = "Anthropic"

cypher_query = natural_language_to_cypher(
    question=question,
    system_prompt=system_prompt,
    provider=provider,
    api_key=api_keys[provider],
    temperature=0.0,
    #model="claude-3-haiku-20240307",
)
print(f"cypher_query : {cypher_query}")
# Out:
# cypher_query : MATCH (start{displayName:"PMAIP1"})-[e1]-(n1)-[e2]-(n2)-[e3]-(n3)-[e4]-(n4)-[e5]-(n5)-[e6]-(n6)-[e7]-(end{displayName:"E2F1"}) RETURN start, end, e1, e2, e3, e4, e5, e6, e7, n1, n2, n3, n4, n5, n6
# CPU times: user 27.8 ms, sys: 1.21 ms, total: 29.1 ms
# Wall time: 2.45 s

# %%
# %%time

# Set original graph
client.set_graph(graph_name)

df_path = client.query(cypher_query)
df_path.columns = get_return_statements(cypher_query)
if df_path.empty:
    print("--> No result found\n")
else:
    display(df_path)
# Out:
# --> No result found
#
# CPU times: user 2.42 ms, sys: 89 μs, total: 2.51 ms
# Wall time: 1.91 ms

# %% [markdown]
# # Use LLM to get subgraph summary

# %%
# %%time

prompt = f"""
Give me a summary of this graph. It represents biological entities, tell me more about the entities involved and the interactions.
Here is the graph :
{G.nodes(data=True)} {G.edges(data=True)}
"""

system_prompt = """
You are a specialist in analysing graphs and their structure.
You will use your knowledge to add more information about the entities and relationships in the graph.
Add information only when you are sure it is relevant.
"""

provider = "OpenAI"

response = query_llm(
    prompt=prompt,
    system_prompt=system_prompt,
    provider=provider,
    api_key=api_keys[provider],
    temperature=0.0
)
# Out:
# CPU times: user 24.9 ms, sys: 0 ns, total: 24.9 ms
# Wall time: 11.8 s

# %%
from IPython.display import display, Markdown, HTML

# %%
display(Markdown(response))
# Out:
# The graph represents a complex network of interactions involving various biological entities primarily related to gene regulation, apoptosis, and cellular signaling in *Homo sapiens*. Here’s a summary of the key entities and their interactions:
#
# ### Key Entities:
# 1. **TP53 (Tumor Protein p53)**: A crucial tumor suppressor gene that regulates the cell cycle and functions in preventing cancer. It binds to the promoters of various genes, including PMAIP1 and APAF1, to stimulate their expression.
#    - **p-S15,S20-TP53 Tetramer**: The phosphorylated form of TP53 that is active in gene regulation.
#
# 2. **PMAIP1 (NOXA)**: A pro-apoptotic gene that is regulated by TP53. It plays a role in apoptosis and is translocated to mitochondria to promote cell death.
#
# 3. **APAF1 (Apoptotic Protease Activating Factor 1)**: A key component in the apoptosome that activates caspases, leading to apoptosis. Its expression is stimulated by TP53 and E2F1.
#
# 4. **CYCS (Cytochrome c)**: A protein involved in the electron transport chain and apoptosis. It binds to APAF1 and is released from mitochondria during apoptosis.
#
# 5. **E2F1**: A transcription factor that regulates the expression of genes involved in cell cycle progression and apoptosis. It binds to the promoters of PMAIP1 and APAF1.
#
# 6. **NRF1 (Nuclear Respiratory Factor 1)**: A transcription factor that regulates the expression of genes involved in mitochondrial biogenesis and function, including CYCS.
#
# 7. **PPARGC1A (Peroxisome Proliferator-Activated Receptor Gamma Coactivator 1-alpha)**: A coactivator that regulates genes involved in energy metabolism and mitochondrial function.
#
# 8. **ESRRA (Estrogen-Related Receptor Alpha)**: A transcription factor that positively regulates the expression of various genes, including those involved in mitochondrial function.
#
# ### Key Interactions:
# - **TP53 Binding**: TP53 binds to the promoters of PMAIP1 and APAF1, stimulating their expression, which is crucial for apoptosis.
# - **E2F1 Regulation**: E2F1 also binds to the promoters of PMAIP1 and APAF1, indicating a collaborative role in regulating apoptosis and cell cycle.
# - **CYCS and APAF1 Interaction**: CYCS binds to APAF1, leading to the formation of the apoptosome and subsequent activation of caspases, which are essential for the apoptotic process.
# - **Translocation Events**: PMAIP1 is translocated to mitochondria, where it can exert its pro-apoptotic effects, and CYCS is released from mitochondria, further promoting apoptosis.
# - **Positive Regulation**: The interactions between TP53, E2F1, and other transcription factors like NRF1 and ESRRA indicate a complex regulatory network that ensures proper gene expression in response to cellular stress and damage.
#
# ### Conclusion:
# This graph illustrates a network of interactions that highlight the roles of TP53, E2F1, and other transcription factors in regulating apoptosis and gene expression in response to cellular signals. The interplay between these entities is crucial for maintaining cellular homeostasis and preventing tumorigenesis.

# %%
print("Notebook finished !")
# Out:
# Notebook finished !
