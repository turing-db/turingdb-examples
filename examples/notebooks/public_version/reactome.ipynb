# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>
#         Example notebook - Reactome subgraph
#     </h1>
# </div>

# %% [markdown]
# # Import modules and functions

# %%
import os
import glob
import re
import networkx as nx
import pandas as pd
import time
from tqdm.auto import tqdm

from IPython.display import display, Markdown

from turingdb_examples.graph import (
    build_create_command_from_networkx,
)
from turingdb_examples.graph import split_cypher_commands
from turingdb_examples.llm import natural_language_to_cypher, query_llm

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Check data files are available

# %%
example_name = "reactome"
path_data = f"{os.getcwd()}/data/{example_name}"
if not os.path.exists(path_data):
    raise ValueError(f"{path_data} does not exists")

list_csv_files = sorted(
    [os.path.basename(file) for file in glob.glob(os.path.join(path_data, "*"))]
)
if not "entities_pairwise.gml" in list_csv_files:
    raise ValueError(
        f"At least one of the {len(list_csv_files)} csv files is not available in {path_data}"
    )

# %% [markdown]
# # Import `gml` file

# %%
G = nx.read_gml(f"{path_data}/entities_pairwise.gml")
print(G)
# Out:
# MultiGraph with 40 nodes and 57 edges

# %% [markdown]
# # Graph Creation in TuringDB

# %% [markdown]
# ## Build Cypher CREATE Commands

# %%
# Build CREATE command from networkx object
graph_CREATE_command = build_create_command_from_networkx(G, node_type_key="schemaClass")

print(f"""
Cypher CREATE command :
* size: {len(graph_CREATE_command.encode('utf-8'))/1024/1000:.4f} MB\n
{100 * '*'}
{graph_CREATE_command if len(graph_CREATE_command.split("\n")) < 10000 else "\n".join(graph_CREATE_command.split('\n')[:5]) + "\n...\n" + "\n".join(graph_CREATE_command.split('\n')[-5:])}
{100 * '*'}
""")
# Out:
# Cypher query will create graph with 40 nodes and 57 edges
#
# Cypher CREATE command :
# * size: 0.0215 MB
#
# ****************************************************************************************************
# CREATE (:Reaction {id: "TP53 binds the PMAIP1 (NOXA) promoter", schemaClass: "Reaction", stId: "R-HSA-4331331", oldStId: "REACT_169265", releaseDate: "2016-03-23", name: "[ TP53 binds the PMAIP1 (NOXA) promoter ]", stIdVersion: "R-HSA-4331331.6", speciesName: "Homo sapiens", category: "binding", displayName: "TP53 binds the PMAIP1 (NOXA) promoter"}),
# (:Complex {id: "p-S15,S20-TP53 Tetramer [nucleoplasm]", schemaClass: "Complex", stId: "R-HSA-3222171", name: "[ p-S15,S20-TP53 Tetramer ]", stIdVersion: "R-HSA-3222171.1", speciesName: "Homo sapiens", displayName: "p-S15,S20-TP53 Tetramer [nucleoplasm]"}),
# (:Reaction {id: "TP53 binds the APAF1 gene promoter", schemaClass: "Reaction", stId: "R-HSA-6791349", releaseDate: "2016-03-23", name: "[ TP53 binds the APAF1 gene promoter ]", stIdVersion: "R-HSA-6791349.3", speciesName: "Homo sapiens", category: "binding", displayName: "TP53 binds the APAF1 gene promoter"}),
# (:BlackBoxEvent {id: "TP53 stimulates APAF1 gene expression", schemaClass: "BlackBoxEvent", stId: "R-HSA-6791348", releaseDate: "2016-03-23", name: "[ TP53 stimulates APAF1 gene expression ]", stIdVersion: "R-HSA-6791348.4", speciesName: "Homo sapiens", category: "omitted", displayName: "TP53 stimulates APAF1 gene expression"}),
# (:Reaction {id: "CYCS binds to APAF1", schemaClass: "Reaction", stId: "R-HSA-114254", oldStId: "REACT_1640", releaseDate: "2004-10-27", name: "[ CYCS binds to APAF1 ]", stIdVersion: "R-HSA-114254.6", speciesName: "Homo sapiens", category: "binding", displayName: "CYCS binds to APAF1"}),
# (:EntityWithAccessionedSequence {id: "CYCS [cytosol]", schemaClass: "EntityWithAccessionedSequence", stId: "R-HSA-53259", oldStId: "REACT_4972", name: "[ CYCS , Cytochrome c ]", stIdVersion: "R-HSA-53259.1", speciesName: "Homo sapiens", referenceType: "ReferenceGeneProduct", searchSeed: "1", displayName: "CYCS [cytosol]"}),
# (:EntityWithAccessionedSequence {id: "PMAIP1 Gene [nucleoplasm]", schemaClass: "EntityWithAccessionedSequence", stId: "R-HSA-4331342", oldStId: "REACT_170122", name: "[ PMAIP1 Gene , NOXA Gene ]", stIdVersion: "R-HSA-4331342.1", speciesName: "Homo sapiens", referenceType: "ReferenceDNASequence", searchSeed: "1", displayName: "PMAIP1 Gene [nucleoplasm]"}),
# (:Complex {id: "p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]", schemaClass: "Complex", stId: "R-HSA-4331332", oldStId: "REACT_170069", name: "[ p-S15,S20-TP53 Tetramer:PMAIP1 Gene ]", stIdVersion: "R-HSA-4331332.4", speciesName: "Homo sapiens", displayName: "p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]"}),
# (:BlackBoxEvent {id: "TP53 stimulates PMAIP1 (NOXA) expression", schemaClass: "BlackBoxEvent", stId: "R-HSA-140214", oldStId: "REACT_2201", releaseDate: "2004-10-27", name: "[ TP53 stimulates PMAIP1 (NOXA) expression ]", stIdVersion: "R-HSA-140214.6", speciesName: "Homo sapiens", category: "omitted", displayName: "TP53 stimulates PMAIP1 (NOXA) expression"}),
# (:PositiveGeneExpressionRegulation {id: "Positive gene expression regulation by 'p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]'", schemaClass: "PositiveGeneExpressionRegulation", stId: "R-HSA-159038", oldStId: "REACT_6033", stIdVersion: "R-HSA-159038.4", displayName: "Positive gene expression regulation by p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]"}),
# (:Reaction {id: "Translocation of PMAIP1 (NOXA) to mitochondria", schemaClass: "Reaction", stId: "R-HSA-140216", oldStId: "REACT_1585", releaseDate: "2004-10-27", name: "[ Translocation of PMAIP1 (NOXA) to mitochondria ]", stIdVersion: "R-HSA-140216.4", speciesName: "Homo sapiens", category: "transition", displayName: "Translocation of PMAIP1 (NOXA) to mitochondria"}),
# (:Reaction {id: "BH3-only proteins associate with and inactivate anti-apoptotic BCL-2", schemaClass: "Reaction", stId: "R-HSA-508163", oldStId: "REACT_21389", releaseDate: "2008-06-30", name: "[ BH3-only proteins associate with and inactivate anti-apoptotic BCL-2 ]", stIdVersion: "R-HSA-508163.4", speciesName: "Homo sapiens", category: "binding", displayName: "BH3-only proteins associate with and inactivate anti-apoptotic BCL-2"}),
# (:Reaction {id: "Translocation of tBID to mitochondria", schemaClass: "Reaction", stId: "R-HSA-139920", oldStId: "REACT_1370", releaseDate: "2004-10-27", name: "[ Translocation of tBID to mitochondria ]", stIdVersion: "R-HSA-139920.3", speciesName: "Homo sapiens", category: "transition", displayName: "Translocation of tBID to mitochondria"}),
# (:Reaction {id: "Release of Cytochrome c from mitochondria", schemaClass: "Reaction", stId: "R-HSA-114284", oldStId: "REACT_535", releaseDate: "2004-07-06", name: "[ Release of Cytochrome c from mitochondria ]", stIdVersion: "R-HSA-114284.7", speciesName: "Homo sapiens", category: "transition", displayName: "Release of Cytochrome c from mitochondria"}),
# (:BlackBoxEvent {id: "Transactivation of PMAIP1 (NOXA) by E2F1", schemaClass: "BlackBoxEvent", stId: "R-HSA-140217", oldStId: "REACT_1872", releaseDate: "2004-10-27", name: "[ Transactivation of PMAIP1 (NOXA) by E2F1 ]", stIdVersion: "R-HSA-140217.4", speciesName: "Homo sapiens", category: "omitted", displayName: "Transactivation of PMAIP1 (NOXA) by E2F1"}),
# (:PositiveGeneExpressionRegulation {id: "Positive gene expression regulation by 'E2F1:TFDP1:PMAIP1 Gene [nucleoplasm]'", schemaClass: "PositiveGeneExpressionRegulation", stId: "R-HSA-159039", oldStId: "REACT_6130", stIdVersion: "R-HSA-159039.1", displayName: "Positive gene expression regulation by E2F1:TFDP1:PMAIP1 Gene [nucleoplasm]"}),
# (:Complex {id: "E2F1:TFDP1,TFDP2 [nucleoplasm]", schemaClass: "Complex", stId: "R-HSA-68653", oldStId: "REACT_5400", name: "[ E2F1:TFDP1,TFDP2 , DP1/2:E2F1 ]", stIdVersion: "R-HSA-68653.2", speciesName: "Homo sapiens", displayName: "E2F1:TFDP1,TFDP2 [nucleoplasm]"}),
# (:EntityWithAccessionedSequence {id: "E2F1 [nucleoplasm]", schemaClass: "EntityWithAccessionedSequence", stId: "R-HSA-68639", oldStId: "REACT_2601", name: "[ E2F1 , Transcription factor E2F1 , E2F-1 , Retinoblastoma binding protein 3 , RBBP-3 , PRB-binding protein E2F-1 , PBR3 , Retinoblastoma-associated protein 1 , RBAP-1 ]", stIdVersion: "R-HSA-68639.2", speciesName: "Homo sapiens", referenceType: "ReferenceGeneProduct", displayName: "E2F1 [nucleoplasm]"}),
# (:Complex {id: "E2F1:(TFDP1,TFDP2) [nucleoplasm]", schemaClass: "Complex", stId: "R-HSA-9007512", name: "[ E2F1:(TFDP1,TFDP2) ]", stIdVersion: "R-HSA-9007512.1", speciesName: "Homo sapiens", displayName: "E2F1:(TFDP1,TFDP2) [nucleoplasm]"}),
# (:Reaction {id: "E2F1 binds APAF1 gene promoter", schemaClass: "Reaction", stId: "R-HSA-9007514", releaseDate: "2017-09-12", name: "[ E2F1 binds APAF1 gene promoter ]", stIdVersion: "R-HSA-9007514.2", speciesName: "Homo sapiens", category: "binding", displayName: "E2F1 binds APAF1 gene promoter"}),
# (:BlackBoxEvent {id: "APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6", schemaClass: "BlackBoxEvent", stId: "R-HSA-9007496", releaseDate: "2017-09-12", name: "[ APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6 ]", stIdVersion: "R-HSA-9007496.4", speciesName: "Homo sapiens", category: "omitted", displayName: "APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6"}),
# (:EntityWithAccessionedSequence {id: "APAF1 [cytosol]", schemaClass: "EntityWithAccessionedSequence", stId: "R-HSA-50099", oldStId: "REACT_3886", name: "[ APAF1 , Apaf-1 , Apoptotic protease activating factor 1 ]", stIdVersion: "R-HSA-50099.1", speciesName: "Homo sapiens", referenceType: "ReferenceGeneProduct", displayName: "APAF1 [cytosol]"}),
# (:Complex {id: "APAF1:CYCS [cytosol]", schemaClass: "Complex", stId: "R-HSA-114253", oldStId: "REACT_4880", name: "[ APAF1:CYCS , APAF1:Cytochrome C ]", stIdVersion: "R-HSA-114253.2", speciesName: "Homo sapiens", displayName: "APAF1:CYCS [cytosol]"}),
# (:Reaction {id: "E2F1 binds PMAIP1 (NOXA) promoter", schemaClass: "Reaction", stId: "R-HSA-4331327", oldStId: "REACT_169402", releaseDate: "2013-09-18", name: "[ E2F1 binds PMAIP1 (NOXA) promoter ]", stIdVersion: "R-HSA-4331327.3", speciesName: "Homo sapiens", category: "binding", displayName: "E2F1 binds PMAIP1 (NOXA) promoter"}),
# (:EntityWithAccessionedSequence {id: "PMAIP1 [cytosol]", schemaClass: "EntityWithAccessionedSequence", stId: "R-HSA-140215", oldStId: "REACT_4210", name: "[ PMAIP1 , NOXA protein ]", stIdVersion: "R-HSA-140215.1", speciesName: "Homo sapiens", referenceType: "ReferenceGeneProduct", searchSeed: "1", displayName: "PMAIP1 [cytosol]"}),
# (:EntityWithAccessionedSequence {id: "CYCS [mitochondrial intermembrane space]", schemaClass: "EntityWithAccessionedSequence", stId: "R-HSA-114244", oldStId: "REACT_3942", name: "[ CYCS , Cytochrome c ]", stIdVersion: "R-HSA-114244.1", speciesName: "Homo sapiens", referenceType: "ReferenceGeneProduct", displayName: "CYCS [mitochondrial intermembrane space]"}),
# (:Complex {id: "CYCS gene:NRF1:PPARGC1B [nucleoplasm]", schemaClass: "Complex", stId: "R-HSA-2466382", oldStId: "REACT_265699", name: "[ CYCS gene:NRF1:PPARGC1B , NRF1:PGC-1beta:CYCS ]", stIdVersion: "R-HSA-2466382.1", speciesName: "Homo sapiens", displayName: "CYCS gene:NRF1:PPARGC1B [nucleoplasm]"}),
# (:EntityWithAccessionedSequence {id: "NRF1 [nucleoplasm]", schemaClass: "EntityWithAccessionedSequence", stId: "R-HSA-1592205", oldStId: "REACT_117514", name: "[ NRF1 , Nuclear respiratory factor 1 , NRF1_HUMAN ]", stIdVersion: "R-HSA-1592205.1", speciesName: "Homo sapiens", referenceType: "ReferenceGeneProduct", displayName: "NRF1 [nucleoplasm]"}),
# (:Reaction {id: "NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter", schemaClass: "Reaction", stId: "R-HSA-2466392", oldStId: "REACT_264641", releaseDate: "2014-03-12", name: "[ NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter ]", stIdVersion: "R-HSA-2466392.2", speciesName: "Homo sapiens", category: "binding", displayName: "NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter"}),
# (:Reaction {id: "p38 MAPK phosphorylates PPARGC1A", schemaClass: "Reaction", stId: "R-HSA-1592233", oldStId: "REACT_263998", releaseDate: "2014-03-12", name: "[ p38 MAPK phosphorylates PPARGC1A ]", stIdVersion: "R-HSA-1592233.2", speciesName: "Homo sapiens", category: "transition", displayName: "p38 MAPK phosphorylates PPARGC1A"}),
# (:EntityWithAccessionedSequence {id: "PPARGC1A [nucleoplasm]", schemaClass: "EntityWithAccessionedSequence", stId: "R-HSA-442481", oldStId: "REACT_27383", name: "[ PPARGC1A , Peroxisome proliferator-activated receptor gamma coactivator 1-alpha , PRGC1_HUMAN , PGC1A , PGC-1alpha ]", stIdVersion: "R-HSA-442481.2", speciesName: "Homo sapiens", referenceType: "ReferenceGeneProduct", displayName: "PPARGC1A [nucleoplasm]"}),
# (:Complex {id: "RORA:Coactivator [nucleoplasm]", schemaClass: "Complex", stId: "R-HSA-1368124", oldStId: "REACT_111748", name: "[ RORA:Coactivator ]", stIdVersion: "R-HSA-1368124.1", speciesName: "Homo sapiens", displayName: "RORA:Coactivator [nucleoplasm]"}),
# (:EntityWithAccessionedSequence {id: "EP300 [nucleoplasm]", schemaClass: "EntityWithAccessionedSequence", stId: "R-HSA-381325", oldStId: "REACT_26137", name: "[ EP300 , p300 , Histone acetyltransferase p300 , EP300_HUMAN , KAT3B ]", stIdVersion: "R-HSA-381325.1", speciesName: "Homo sapiens", referenceType: "ReferenceGeneProduct", displayName: "EP300 [nucleoplasm]"}),
# (:Complex {id: "p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene [nucleoplasm]", schemaClass: "Complex", stId: "R-HSA-3215149", name: "[ p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ]", stIdVersion: "R-HSA-3215149.1", speciesName: "Homo sapiens", displayName: "p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene [nucleoplasm]"}),
# (:Reaction {id: "NRF1:PPARGC1B binds the CYCS promoter", schemaClass: "Reaction", stId: "R-HSA-2466370", oldStId: "REACT_264393", releaseDate: "2014-03-12", name: "[ NRF1:PPARGC1B binds the CYCS promoter ]", stIdVersion: "R-HSA-2466370.2", speciesName: "Homo sapiens", category: "binding", displayName: "NRF1:PPARGC1B binds the CYCS promoter"}),
# (:BlackBoxEvent {id: "Expression of NRF1", schemaClass: "BlackBoxEvent", stId: "R-HSA-1592242", oldStId: "REACT_264032", releaseDate: "2014-03-12", name: "[ Expression of NRF1 ]", stIdVersion: "R-HSA-1592242.4", speciesName: "Homo sapiens", category: "omitted", displayName: "Expression of NRF1"}),
# (:BlackBoxEvent {id: "Expression of CYCS", schemaClass: "BlackBoxEvent", stId: "R-HSA-1592231", oldStId: "REACT_263920", releaseDate: "2014-03-12", name: "[ Expression of CYCS , Expression of Cytochrome c ]", stIdVersion: "R-HSA-1592231.7", speciesName: "Homo sapiens", category: "omitted", displayName: "Expression of CYCS"}),
# (:PositiveRegulation {id: "Positive regulation by 'ESRRA [nucleoplasm]'", stId: "R-HSA-1605565", oldStId: "REACT_267555", schemaClass: "PositiveRegulation", stIdVersion: "R-HSA-1605565.1", displayName: "Positive regulation by ESRRA [nucleoplasm]"}),
# (:EntityWithAccessionedSequence {id: "ESRRA [nucleoplasm]", schemaClass: "EntityWithAccessionedSequence", stId: "R-HSA-446159", oldStId: "REACT_21133", name: "[ ESRRA , Steroid hormone receptor ERR1 , ERR1_HUMAN ]", stIdVersion: "R-HSA-446159.1", speciesName: "Homo sapiens", referenceType: "ReferenceGeneProduct", displayName: "ESRRA [nucleoplasm]"}),
# (:Complex {id: "ESRRA:PPARGC1A [nucleoplasm]", schemaClass: "Complex", stId: "R-HSA-8939924", name: "[ ESRRA:PPARGC1A ]", stIdVersion: "R-HSA-8939924.1", speciesName: "Homo sapiens", displayName: "ESRRA:PPARGC1A [nucleoplasm]"})
# MATCH (source {id: "TP53 binds the PMAIP1 (NOXA) promoter"}), (target {id: "p-S15,S20-TP53 Tetramer [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "TP53 binds the PMAIP1 (NOXA) promoter"}), (target {id: "PMAIP1 Gene [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "TP53 binds the PMAIP1 (NOXA) promoter"}), (target {id: "p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "TP53 binds the PMAIP1 (NOXA) promoter"}), (target {id: "TP53 stimulates PMAIP1 (NOXA) expression"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "p-S15,S20-TP53 Tetramer [nucleoplasm]"}), (target {id: "TP53 binds the APAF1 gene promoter"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "p-S15,S20-TP53 Tetramer [nucleoplasm]"}), (target {id: "p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "p-S15,S20-TP53 Tetramer [nucleoplasm]"}), (target {id: "Positive gene expression regulation by 'p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]'"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "p-S15,S20-TP53 Tetramer [nucleoplasm]"}), (target {id: "p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "TP53 binds the APAF1 gene promoter"}), (target {id: "TP53 stimulates APAF1 gene expression"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "TP53 stimulates APAF1 gene expression"}), (target {id: "APAF1 [cytosol]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "TP53 stimulates APAF1 gene expression"}), (target {id: "CYCS binds to APAF1"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "CYCS binds to APAF1"}), (target {id: "CYCS [cytosol]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "CYCS binds to APAF1"}), (target {id: "Release of Cytochrome c from mitochondria"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "CYCS [cytosol]"}), (target {id: "Release of Cytochrome c from mitochondria"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "CYCS [cytosol]"}), (target {id: "APAF1:CYCS [cytosol]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "CYCS [cytosol]"}), (target {id: "Expression of CYCS"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "PMAIP1 Gene [nucleoplasm]"}), (target {id: "p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "PMAIP1 Gene [nucleoplasm]"}), (target {id: "TP53 stimulates PMAIP1 (NOXA) expression"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "PMAIP1 Gene [nucleoplasm]"}), (target {id: "Transactivation of PMAIP1 (NOXA) by E2F1"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "PMAIP1 Gene [nucleoplasm]"}), (target {id: "E2F1 binds PMAIP1 (NOXA) promoter"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]"}), (target {id: "Positive gene expression regulation by 'p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]'"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "TP53 stimulates PMAIP1 (NOXA) expression"}), (target {id: "Positive gene expression regulation by 'p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]'"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "TP53 stimulates PMAIP1 (NOXA) expression"}), (target {id: "Translocation of PMAIP1 (NOXA) to mitochondria"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Translocation of PMAIP1 (NOXA) to mitochondria"}), (target {id: "Transactivation of PMAIP1 (NOXA) by E2F1"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Translocation of PMAIP1 (NOXA) to mitochondria"}), (target {id: "BH3-only proteins associate with and inactivate anti-apoptotic BCL-2"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Translocation of PMAIP1 (NOXA) to mitochondria"}), (target {id: "PMAIP1 [cytosol]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "BH3-only proteins associate with and inactivate anti-apoptotic BCL-2"}), (target {id: "Translocation of tBID to mitochondria"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Translocation of tBID to mitochondria"}), (target {id: "Release of Cytochrome c from mitochondria"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Release of Cytochrome c from mitochondria"}), (target {id: "CYCS [mitochondrial intermembrane space]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Transactivation of PMAIP1 (NOXA) by E2F1"}), (target {id: "Positive gene expression regulation by 'E2F1:TFDP1:PMAIP1 Gene [nucleoplasm]'"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Transactivation of PMAIP1 (NOXA) by E2F1"}), (target {id: "E2F1 binds PMAIP1 (NOXA) promoter"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Positive gene expression regulation by 'E2F1:TFDP1:PMAIP1 Gene [nucleoplasm]'"}), (target {id: "E2F1:TFDP1,TFDP2 [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "E2F1:TFDP1,TFDP2 [nucleoplasm]"}), (target {id: "E2F1 [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "E2F1:TFDP1,TFDP2 [nucleoplasm]"}), (target {id: "E2F1 binds PMAIP1 (NOXA) promoter"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "E2F1 [nucleoplasm]"}), (target {id: "E2F1:(TFDP1,TFDP2) [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "E2F1:(TFDP1,TFDP2) [nucleoplasm]"}), (target {id: "E2F1 binds APAF1 gene promoter"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "E2F1 binds APAF1 gene promoter"}), (target {id: "APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6"}), (target {id: "APAF1 [cytosol]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "APAF1 [cytosol]"}), (target {id: "APAF1:CYCS [cytosol]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "CYCS gene:NRF1:PPARGC1B [nucleoplasm]"}), (target {id: "NRF1 [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "CYCS gene:NRF1:PPARGC1B [nucleoplasm]"}), (target {id: "NRF1:PPARGC1B binds the CYCS promoter"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "NRF1 [nucleoplasm]"}), (target {id: "NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "NRF1 [nucleoplasm]"}), (target {id: "NRF1:PPARGC1B binds the CYCS promoter"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "NRF1 [nucleoplasm]"}), (target {id: "Expression of NRF1"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter"}), (target {id: "p38 MAPK phosphorylates PPARGC1A"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter"}), (target {id: "Expression of NRF1"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "p38 MAPK phosphorylates PPARGC1A"}), (target {id: "PPARGC1A [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "p38 MAPK phosphorylates PPARGC1A"}), (target {id: "Expression of NRF1"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "PPARGC1A [nucleoplasm]"}), (target {id: "RORA:Coactivator [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "PPARGC1A [nucleoplasm]"}), (target {id: "ESRRA:PPARGC1A [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "RORA:Coactivator [nucleoplasm]"}), (target {id: "EP300 [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "EP300 [nucleoplasm]"}), (target {id: "p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "NRF1:PPARGC1B binds the CYCS promoter"}), (target {id: "Expression of NRF1"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "NRF1:PPARGC1B binds the CYCS promoter"}), (target {id: "Expression of CYCS"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Expression of CYCS"}), (target {id: "Positive regulation by 'ESRRA [nucleoplasm]'"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Positive regulation by 'ESRRA [nucleoplasm]'"}), (target {id: "ESRRA [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "ESRRA [nucleoplasm]"}), (target {id: "ESRRA:PPARGC1A [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# ****************************************************************************************************

# %% [markdown]
# ## Split command into chunks

# %%
# %%time

chunks = split_cypher_commands(graph_CREATE_command, max_size_mb=1)

print(f"✓ Split into {len(chunks['node_chunks'])} node chunk(s) and {len(chunks['edge_chunks'])} edge chunk(s)")

print("\nNode chunks:")
for i, chunk in enumerate(chunks['node_chunks']):
    print(f"  Node chunk {i+1}: {len(chunk.encode('utf-8'))/1024:.1f} KB")
    if i == 10:
        print("  ...")
        break

print("\nEdge chunks:")
for i, chunk in enumerate(chunks['edge_chunks']):
    print(f"  Edge chunk {i+1}: {len(chunk.encode('utf-8'))/1024:.1f} KB")
    if i == 10:
        print("  ...")
        break
# Out:
# ✓ Split into 1 node chunk(s) and 57 edge chunk(s)
#
# Node chunks:
#   Node chunk 1: 13.0 KB
#
# Edge chunks:
#   Edge chunk 1: 0.2 KB
#   Edge chunk 2: 0.1 KB
#   Edge chunk 3: 0.2 KB
#   Edge chunk 4: 0.2 KB
#   Edge chunk 5: 0.1 KB
#   Edge chunk 6: 0.2 KB
#   Edge chunk 7: 0.2 KB
#   Edge chunk 8: 0.2 KB
#   Edge chunk 9: 0.1 KB
#   Edge chunk 10: 0.1 KB
#   Edge chunk 11: 0.1 KB
#   ...
# CPU times: user 1.15 ms, sys: 0 ns, total: 1.15 ms
# Wall time: 1.03 ms

# %% [markdown]
# # Create graph using `turingdb` python package

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         See <a href="https://docs.turingdb.ai/quickstart">TuringDB Get started documentation</a> for the important steps to follow :
#     </h2>
#     <h4>
#         <ul>
#             <li>Create your TuringDB account</li>
#             <li>Create your instance in the <a href="https://console.turingdb.ai/auth">TuringDB Cloud UI</a></li>
#             <li>Copy your Instance ID from the Database Instances management page</li>
#             <li>Get API Key from the Settings in UI</li>
#         </ul>
#         Remember to have your instance active while working in this notebook !
#     </h4>
# </div>

# %%
from turingdb import TuringDB

# Create TuringDB client
# set host parameter to the URL (as string) on which TuringDB is running,
# default "http://localhost:6666"
client = TuringDB(host="http://localhost:6666")
try:
    client.warmup()
except Exception as e:
    print(f"TuringDB not started, please run `uv run turingdb` in your terminal")

# %%
# Get list of available graphs
list_graphs = client.list_available_graphs()

# %%
client.list_loaded_graphs()
# Out:
# ['wine_ontology1',
#  'healthcare_dataset1',
#  'crypto_orbitaal_fraud_detection1',
#  'citeab_antibody1',
#  'default']

# %%
# Set graph name
graph_name_prefix = example_name
graph_name_nb_suffix = str(
    max(
        [
            int(re.sub(graph_name_prefix, "", g))
            for g in list_graphs
            if g.startswith(graph_name_prefix)
            and re.sub(graph_name_prefix, "", g).isdigit()
        ]
        + [0]
    )
    + 1
)
graph_name = graph_name_prefix + graph_name_nb_suffix
graph_name = re.sub("-", "_", graph_name)
graph_name
# Out:
# 'reactome1'

# %%
from turingdb.exceptions import TuringDBException

# %%
# %%time

# Set graph
try:
    client.create_graph(graph_name)
except TuringDBException as e:
    print(e)

# Set working graph
client.set_graph(graph_name)
# Out:
# CPU times: user 1.82 ms, sys: 60 μs, total: 1.88 ms
# Wall time: 8.12 ms

# %%
# %%time

# Create a new change on the graph
client.checkout()
change = client.new_change()
print(f"Current change {change}")

# Checkout into the change
client.checkout(change=change)
# Out:
# Current change 0
# CPU times: user 1.69 ms, sys: 0 ns, total: 1.69 ms
# Wall time: 1.4 ms

# %%
# %%time

# Run CREATE command
print("\nExecuting query on TuringDB...")
start_time = time.time()

print(f"✓ Split into {len(chunks['node_chunks'])} node chunk(s) and {len(chunks['edge_chunks'])} edge chunk(s)")

# CREATE nodes
print("\nNode chunks:")
for i, chunk in enumerate(tqdm(chunks['node_chunks'])):
    result = client.query(chunk)
# Commit the change
client.query("COMMIT")
print(f"✓ {len(chunks['node_chunks'])} node chunks done")

# CREATE edges
print("\nEdge chunks:")
for i, chunk in enumerate(tqdm(chunks['edge_chunks'])):
    result = client.query(chunk)
# Commit the change
client.query("COMMIT")
print(f"✓ {len(chunks['edge_chunks'])} edge chunks done")

execution_time = time.time() - start_time
print(f"\n✓ Graph created successfully in {execution_time:.2f} seconds")

# Submit changes
start_time = time.time()
client.query("CHANGE SUBMIT")
execution_time = time.time() - start_time
print(f"\n✓ Changes successfully submitted in {execution_time:.2f} seconds")

# Checkout into main
client.checkout()
# Out:
# Executing query on TuringDB...
# ✓ Split into 1 node chunk(s) and 57 edge chunk(s)
#
# Node chunks:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✓ 1 node chunks done
#
# Edge chunks:
#   0%|          | 0/57 [00:00<?, ?it/s]
# ✓ 57 edge chunks done
#
# ✓ Graph created successfully in 0.06 seconds
#
# ✓ Changes successfully submitted in 0.06 seconds
# CPU times: user 54.7 ms, sys: 7.04 ms, total: 61.7 ms
# Wall time: 122 ms

# %%
# Returns the commit history
client.query("CALL db.history()")
# Out:
#              commit  nodeCount  edgeCount  partCount
# 0  c8d5bb6bf5109a99          0          0          0
# 1  d3f5359c8c55ea40         40          0          1
# 2  374526511fd88385          0         57          1
# 3   557b2cda9fc2e87          0          0          0

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         Visualize your graph in TuringDB Graph Visualizer ! Now that your instance is running:
#     </h2>
#     <h3>
#         <ul>
#             <li>Go to <a href="https://console.turingdb.ai/databases">TuringDB Console - Database Instances</a></li>
#             <li>In your current instance panel, click on "Open Visualizer" button</li>
#             <li>Visualizer opens, now you can choose your graph in the dropdown menu at the top-right corner</li>
#         </ul>
#         You can then play with your graph and visualize the nodes you want !
#     </h3>
# </div>

# %% [markdown]
# # Query TuringDB

# %% [markdown]
# ## Use metaqueries to have insight on graph overall structure
#
# <h3>
#     To learn more about 📮 Metaqueries, please check TuringDB documentation on this <a href="https://turingdb.mintlify.app/query/cypher_subset#%F0%9F%93%AE-metaqueries">link</a>
# </h3>

# %%
# %%time

# CALL propertyTypes() - returns a column of all the different node and edge properties and their types in the database
command = """
CALL db.propertyTypes()
"""
df_propertyTypes = client.query(command)
if df_propertyTypes.empty:
    print("No result found")
else:
    display(df_propertyTypes)
# Out:
#     id   propertyType valueType
# 0    0    displayName    String
# 1    1    stIdVersion    String
# 2    2           name    String
# 3    3    releaseDate    String
# 4    4        oldStId    String
# 5    5       category    String
# 6    6           stId    String
# 7    7    schemaClass    String
# 8    8    speciesName    String
# 9    9             id    String
# 10  10     searchSeed    String
# 11  11  referenceType    String
# CPU times: user 4.25 ms, sys: 22 μs, total: 4.27 ms
# Wall time: 3.93 ms

# %%
# Get node properties
nodes_properties = df_propertyTypes["propertyType"].values.tolist()
print(f"Node properties: {nodes_properties}")
# Out:
# Node properties: ['displayName', 'stIdVersion', 'name', 'releaseDate', 'oldStId', 'category', 'stId', 'schemaClass', 'speciesName', 'id', 'searchSeed', 'referenceType']

# %%
# %%time

# CALL labels () - returns a column of all the different node labels
command = """
CALL db.labels()
"""
df_labels = client.query(command)
if df_labels.empty:
    print("No result found")
else:
    display(df_labels)
# Out:
#    id                             label
# 0   0                          Reaction
# 1   1                           Complex
# 2   2                     BlackBoxEvent
# 3   3     EntityWithAccessionedSequence
# 4   4  PositiveGeneExpressionRegulation
# 5   5                PositiveRegulation
# CPU times: user 3.54 ms, sys: 47 μs, total: 3.59 ms
# Wall time: 3.26 ms

# %%
# %%time

# CALL edgeTypes() - returns a column of all the different edge types (edge equivalent of node labels)
command = """
CALL db.edgeTypes()
"""
df_edgeTypes = client.query(command)
if df_edgeTypes.empty:
    print("No result found")
else:
    display(df_edgeTypes)
# Out:
#    id   edgeType
# 0   0  CONNECTED
# CPU times: user 3.56 ms, sys: 0 ns, total: 3.56 ms
# Wall time: 3.16 ms

# %% [markdown]
# ## Counts

# %%
# %%time

# Find number of nodes and number of edges in the graph
n_nodes = len(client.query("MATCH (n) RETURN n"))
n_edges = len(client.query("MATCH (n)-->(m) RETURN n, m"))
print(f"Graph: {n_nodes:,} nodes and {n_edges:,} edges\n")
# Out:
# Graph: 40 nodes and 57 edges
#
# CPU times: user 2.49 ms, sys: 45 μs, total: 2.54 ms
# Wall time: 2.24 ms

# %%
# %%time

# Count all nodes
command = """
MATCH (n)
RETURN COUNT(n)
"""
df_count_nodes = client.query(command)
display(df_count_nodes)

# Count all edges
command = """
MATCH (n)-->()
RETURN COUNT(n)
"""
df_count_edges = client.query(command)
display(df_count_edges)

# Find number of nodes and number of edges in the graph
n_nodes = int(df_count_nodes.loc[0, "COUNT(n)"])
n_edges = int(df_count_edges.loc[0, "COUNT(n)"])
print(f"Graph: {n_nodes:,} nodes and {n_edges:,} edges\n")
# Out:
#    COUNT(n)
# 0        40
#    COUNT(n)
# 0        57
# Graph: 40 nodes and 57 edges
#
# CPU times: user 5.63 ms, sys: 1.06 ms, total: 6.69 ms
# Wall time: 6.07 ms

# %%
# Count number of nodes for each label
for label in df_labels["label"]:
    print(100 * '-')
    print(f"label: {label}")
    df_curr_label = client.query(f"""
    MATCH (n:{label})
    RETURN n.name
    """)
    df_curr_label_count = client.query(f"""
    MATCH (n:{label})
    RETURN count(n)
    """)
    display(df_curr_label)
    display(df_curr_label_count)
    
    print()
print(100 * '-')
# Out:
# ----------------------------------------------------------------------------------------------------
# label: Reaction
#                                                n.name
# 0           [ TP53 binds the PMAIP1 (NOXA) promoter ]
# 1              [ TP53 binds the APAF1 gene promoter ]
# 2           [ NRF1:PPARGC1B binds the CYCS promoter ]
# 3                             [ CYCS binds to APAF1 ]
# 4                  [ E2F1 binds APAF1 gene promoter ]
# 5                [ p38 MAPK phosphorylates PPARGC1A ]
# 6   [ NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter ]
# 7               [ E2F1 binds PMAIP1 (NOXA) promoter ]
# 8   [ Translocation of PMAIP1 (NOXA) to mitochondr...
# 9   [ BH3-only proteins associate with and inactiv...
# 10          [ Translocation of tBID to mitochondria ]
# 11      [ Release of Cytochrome c from mitochondria ]
#    count(n)
# 0        12
# ----------------------------------------------------------------------------------------------------
# label: Complex
#                                               n.name
# 0                             [ E2F1:(TFDP1,TFDP2) ]
# 1                [ APAF1:CYCS , APAF1:Cytochrome C ]
# 2  [ CYCS gene:NRF1:PPARGC1B , NRF1:PGC-1beta:CYCS ]
# 3                               [ RORA:Coactivator ]
# 4  [ p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ]
# 5                                 [ ESRRA:PPARGC1A ]
# 6                        [ p-S15,S20-TP53 Tetramer ]
# 7            [ p-S15,S20-TP53 Tetramer:PMAIP1 Gene ]
# 8                  [ E2F1:TFDP1,TFDP2 , DP1/2:E2F1 ]
#    count(n)
# 0         9
# ----------------------------------------------------------------------------------------------------
# label: BlackBoxEvent
#                                               n.name
# 0  [ APAF1 gene expression is stimulated by E2F1 ...
# 1       [ Transactivation of PMAIP1 (NOXA) by E2F1 ]
# 2  [ Expression of CYCS , Expression of Cytochrom...
# 3                             [ Expression of NRF1 ]
# 4          [ TP53 stimulates APAF1 gene expression ]
# 5       [ TP53 stimulates PMAIP1 (NOXA) expression ]
#    count(n)
# 0         6
# ----------------------------------------------------------------------------------------------------
# label: EntityWithAccessionedSequence
#                                               n.name
# 0  [ E2F1 , Transcription factor E2F1 , E2F-1 , R...
# 1  [ ESRRA , Steroid hormone receptor ERR1 , ERR1...
# 2                            [ CYCS , Cytochrome c ]
# 3  [ EP300 , p300 , Histone acetyltransferase p30...
# 4                        [ PMAIP1 Gene , NOXA Gene ]
# 5  [ PPARGC1A , Peroxisome proliferator-activated...
# 6  [ NRF1 , Nuclear respiratory factor 1 , NRF1_H...
# 7                            [ CYCS , Cytochrome c ]
# 8                          [ PMAIP1 , NOXA protein ]
# 9  [ APAF1 , Apaf-1 , Apoptotic protease activati...
#    count(n)
# 0        10
# ----------------------------------------------------------------------------------------------------
# label: PositiveGeneExpressionRegulation
#   n.name
# 0   <NA>
# 1   <NA>
#    count(n)
# 0         2
# ----------------------------------------------------------------------------------------------------
# label: PositiveRegulation
#   n.name
# 0   <NA>
#    count(n)
# 0         1
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Queries

# %%
# %%time

# Match all edges and return them
command = """
MATCH (n)-[e]->(m)
RETURN n.displayName, e, m.displayName
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#                                         n.displayName   e  \
# 0               TP53 binds the PMAIP1 (NOXA) promoter   0
# 1               TP53 binds the PMAIP1 (NOXA) promoter   1
# 2               TP53 binds the PMAIP1 (NOXA) promoter   2
# 3               TP53 binds the PMAIP1 (NOXA) promoter   3
# 4                  TP53 binds the APAF1 gene promoter   4
# 5               NRF1:PPARGC1B binds the CYCS promoter   5
# 6               NRF1:PPARGC1B binds the CYCS promoter   6
# 7                                 CYCS binds to APAF1   7
# 8                                 CYCS binds to APAF1   8
# 9                      E2F1 binds APAF1 gene promoter   9
# 10                   p38 MAPK phosphorylates PPARGC1A  10
# 11                   p38 MAPK phosphorylates PPARGC1A  11
# 12      NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter  12
# 13      NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter  13
# 14     Translocation of PMAIP1 (NOXA) to mitochondria  14
# 15     Translocation of PMAIP1 (NOXA) to mitochondria  15
# 16     Translocation of PMAIP1 (NOXA) to mitochondria  16
# 17  BH3-only proteins associate with and inactivat...  17
# 18              Translocation of tBID to mitochondria  18
# 19          Release of Cytochrome c from mitochondria  19
# 20                   E2F1:(TFDP1,TFDP2) [nucleoplasm]  20
# 21              CYCS gene:NRF1:PPARGC1B [nucleoplasm]  21
# 22              CYCS gene:NRF1:PPARGC1B [nucleoplasm]  22
# 23                     RORA:Coactivator [nucleoplasm]  23
# 24              p-S15,S20-TP53 Tetramer [nucleoplasm]  24
# 25              p-S15,S20-TP53 Tetramer [nucleoplasm]  25
# 26              p-S15,S20-TP53 Tetramer [nucleoplasm]  26
# 27              p-S15,S20-TP53 Tetramer [nucleoplasm]  27
# 28  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]  28
# 29                     E2F1:TFDP1,TFDP2 [nucleoplasm]  29
# 30                     E2F1:TFDP1,TFDP2 [nucleoplasm]  30
# 31  APAF1 gene expression is stimulated by E2F1 an...  31
# 32           Transactivation of PMAIP1 (NOXA) by E2F1  32
# 33           Transactivation of PMAIP1 (NOXA) by E2F1  33
# 34                                 Expression of CYCS  34
# 35              TP53 stimulates APAF1 gene expression  35
# 36              TP53 stimulates APAF1 gene expression  36
# 37           TP53 stimulates PMAIP1 (NOXA) expression  37
# 38           TP53 stimulates PMAIP1 (NOXA) expression  38
# 39                                 E2F1 [nucleoplasm]  39
# 40                                ESRRA [nucleoplasm]  40
# 41                                     CYCS [cytosol]  41
# 42                                     CYCS [cytosol]  42
# 43                                     CYCS [cytosol]  43
# 44                                EP300 [nucleoplasm]  44
# 45                          PMAIP1 Gene [nucleoplasm]  45
# 46                          PMAIP1 Gene [nucleoplasm]  46
# 47                          PMAIP1 Gene [nucleoplasm]  47
# 48                          PMAIP1 Gene [nucleoplasm]  48
# 49                             PPARGC1A [nucleoplasm]  49
# 50                             PPARGC1A [nucleoplasm]  50
# 51                                 NRF1 [nucleoplasm]  51
# 52                                 NRF1 [nucleoplasm]  52
# 53                                 NRF1 [nucleoplasm]  53
# 54                                    APAF1 [cytosol]  54
# 55  Positive gene expression regulation by E2F1:TF...  55
# 56         Positive regulation by ESRRA [nucleoplasm]  56
#
#                                         m.displayName
# 0               p-S15,S20-TP53 Tetramer [nucleoplasm]
# 1                           PMAIP1 Gene [nucleoplasm]
# 2   p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 3            TP53 stimulates PMAIP1 (NOXA) expression
# 4               TP53 stimulates APAF1 gene expression
# 5                                  Expression of CYCS
# 6                                  Expression of NRF1
# 7           Release of Cytochrome c from mitochondria
# 8                                      CYCS [cytosol]
# 9   APAF1 gene expression is stimulated by E2F1 an...
# 10                                 Expression of NRF1
# 11                             PPARGC1A [nucleoplasm]
# 12                   p38 MAPK phosphorylates PPARGC1A
# 13                                 Expression of NRF1
# 14                                   PMAIP1 [cytosol]
# 15  BH3-only proteins associate with and inactivat...
# 16           Transactivation of PMAIP1 (NOXA) by E2F1
# 17              Translocation of tBID to mitochondria
# 18          Release of Cytochrome c from mitochondria
# 19           CYCS [mitochondrial intermembrane space]
# 20                     E2F1 binds APAF1 gene promoter
# 21              NRF1:PPARGC1B binds the CYCS promoter
# 22                                 NRF1 [nucleoplasm]
# 23                                EP300 [nucleoplasm]
# 24  p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ...
# 25  Positive gene expression regulation by p-S15,S...
# 26                 TP53 binds the APAF1 gene promoter
# 27  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 28  Positive gene expression regulation by p-S15,S...
# 29                                 E2F1 [nucleoplasm]
# 30                  E2F1 binds PMAIP1 (NOXA) promoter
# 31                                    APAF1 [cytosol]
# 32  Positive gene expression regulation by E2F1:TF...
# 33                  E2F1 binds PMAIP1 (NOXA) promoter
# 34         Positive regulation by ESRRA [nucleoplasm]
# 35                                    APAF1 [cytosol]
# 36                                CYCS binds to APAF1
# 37     Translocation of PMAIP1 (NOXA) to mitochondria
# 38  Positive gene expression regulation by p-S15,S...
# 39                   E2F1:(TFDP1,TFDP2) [nucleoplasm]
# 40                       ESRRA:PPARGC1A [nucleoplasm]
# 41          Release of Cytochrome c from mitochondria
# 42                               APAF1:CYCS [cytosol]
# 43                                 Expression of CYCS
# 44  p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ...
# 45  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 46           TP53 stimulates PMAIP1 (NOXA) expression
# 47           Transactivation of PMAIP1 (NOXA) by E2F1
# 48                  E2F1 binds PMAIP1 (NOXA) promoter
# 49                     RORA:Coactivator [nucleoplasm]
# 50                       ESRRA:PPARGC1A [nucleoplasm]
# 51      NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter
# 52              NRF1:PPARGC1B binds the CYCS promoter
# 53                                 Expression of NRF1
# 54                               APAF1:CYCS [cytosol]
# 55                     E2F1:TFDP1,TFDP2 [nucleoplasm]
# 56                                ESRRA [nucleoplasm]
# CPU times: user 4.73 ms, sys: 974 μs, total: 5.71 ms
# Wall time: 5.3 ms

# %%
# %%time

# Find all nodes of type "EntityWithAccessionedSequence" and referenceType "ReferenceGeneProduct"
command = """
MATCH (n:EntityWithAccessionedSequence)
WHERE n.referenceType = "ReferenceGeneProduct"
RETURN n.displayName, n.schemaClass, n.referenceType
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#                               n.displayName                  n.schemaClass  \
# 0                        E2F1 [nucleoplasm]  EntityWithAccessionedSequence
# 1                       ESRRA [nucleoplasm]  EntityWithAccessionedSequence
# 2                            CYCS [cytosol]  EntityWithAccessionedSequence
# 3                       EP300 [nucleoplasm]  EntityWithAccessionedSequence
# 4                    PPARGC1A [nucleoplasm]  EntityWithAccessionedSequence
# 5                        NRF1 [nucleoplasm]  EntityWithAccessionedSequence
# 6  CYCS [mitochondrial intermembrane space]  EntityWithAccessionedSequence
# 7                          PMAIP1 [cytosol]  EntityWithAccessionedSequence
# 8                           APAF1 [cytosol]  EntityWithAccessionedSequence
#
#         n.referenceType
# 0  ReferenceGeneProduct
# 1  ReferenceGeneProduct
# 2  ReferenceGeneProduct
# 3  ReferenceGeneProduct
# 4  ReferenceGeneProduct
# 5  ReferenceGeneProduct
# 6  ReferenceGeneProduct
# 7  ReferenceGeneProduct
# 8  ReferenceGeneProduct
# CPU times: user 3.65 ms, sys: 965 μs, total: 4.62 ms
# Wall time: 4.21 ms

# %%
# %%time

# Count nodes of each schemaClass
command = """
MATCH (n)
RETURN n.schemaClass
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(pd.DataFrame(df.value_counts()))
# Out:
#                                   count
# n.schemaClass
# Reaction                             12
# EntityWithAccessionedSequence        10
# Complex                               9
# BlackBoxEvent                         6
# PositiveGeneExpressionRegulation      2
# PositiveRegulation                    1
# CPU times: user 4.52 ms, sys: 52 μs, total: 4.57 ms
# Wall time: 4.17 ms

# %%
# %%time

# Find all nodes of type "PositiveGeneExpressionRegulation" (which is also schemaClass)
command = """
MATCH (n:PositiveGeneExpressionRegulation)
RETURN n, n.displayName, n.schemaClass
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#     n                                      n.displayName  \
# 0  37  Positive gene expression regulation by p-S15,S...
# 1  38  Positive gene expression regulation by E2F1:TF...
#
#                       n.schemaClass
# 0  PositiveGeneExpressionRegulation
# 1  PositiveGeneExpressionRegulation
# CPU times: user 3.91 ms, sys: 92 μs, total: 4 ms
# Wall time: 3.61 ms

# %%
# %%time

# Find all edges involving a node of type Complex (undirected edge get both directions of directed edges)
command = """
MATCH (n:Complex)-[e]-(m)
RETURN n.displayName, n.schemaClass, e, m.displayName, m.schemaClass, m.category
"""
df = client.query(command)

df
# Out:
# CPU times: user 1.83 ms, sys: 0 ns, total: 1.83 ms
# Wall time: 1.55 ms
#                                         n.displayName n.schemaClass   e  \
# 0                    E2F1:(TFDP1,TFDP2) [nucleoplasm]       Complex  20
# 1                    E2F1:(TFDP1,TFDP2) [nucleoplasm]       Complex  39
# 2                                APAF1:CYCS [cytosol]       Complex  42
# 3                                APAF1:CYCS [cytosol]       Complex  54
# 4               CYCS gene:NRF1:PPARGC1B [nucleoplasm]       Complex  21
# 5               CYCS gene:NRF1:PPARGC1B [nucleoplasm]       Complex  22
# 6                      RORA:Coactivator [nucleoplasm]       Complex  23
# 7                      RORA:Coactivator [nucleoplasm]       Complex  49
# 8   p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ...       Complex  44
# 9   p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ...       Complex  24
# 10                       ESRRA:PPARGC1A [nucleoplasm]       Complex  40
# 11                       ESRRA:PPARGC1A [nucleoplasm]       Complex  50
# 12              p-S15,S20-TP53 Tetramer [nucleoplasm]       Complex  24
# 13              p-S15,S20-TP53 Tetramer [nucleoplasm]       Complex  25
# 14              p-S15,S20-TP53 Tetramer [nucleoplasm]       Complex  26
# 15              p-S15,S20-TP53 Tetramer [nucleoplasm]       Complex  27
# 16              p-S15,S20-TP53 Tetramer [nucleoplasm]       Complex   0
# 17  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]       Complex  28
# 18  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]       Complex   2
# 19  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]       Complex  27
# 20  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]       Complex  45
# 21                     E2F1:TFDP1,TFDP2 [nucleoplasm]       Complex  29
# 22                     E2F1:TFDP1,TFDP2 [nucleoplasm]       Complex  30
# 23                     E2F1:TFDP1,TFDP2 [nucleoplasm]       Complex  55
#
#                                         m.displayName  \
# 0                      E2F1 binds APAF1 gene promoter
# 1                                  E2F1 [nucleoplasm]
# 2                                      CYCS [cytosol]
# 3                                     APAF1 [cytosol]
# 4               NRF1:PPARGC1B binds the CYCS promoter
# 5                                  NRF1 [nucleoplasm]
# 6                                 EP300 [nucleoplasm]
# 7                              PPARGC1A [nucleoplasm]
# 8                                 EP300 [nucleoplasm]
# 9               p-S15,S20-TP53 Tetramer [nucleoplasm]
# 10                                ESRRA [nucleoplasm]
# 11                             PPARGC1A [nucleoplasm]
# 12  p-S15,S20-TP53:EP300:PRMT1:CARM1:GADD45A Gene ...
# 13  Positive gene expression regulation by p-S15,S...
# 14                 TP53 binds the APAF1 gene promoter
# 15  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 16              TP53 binds the PMAIP1 (NOXA) promoter
# 17  Positive gene expression regulation by p-S15,S...
# 18              TP53 binds the PMAIP1 (NOXA) promoter
# 19              p-S15,S20-TP53 Tetramer [nucleoplasm]
# 20                          PMAIP1 Gene [nucleoplasm]
# 21                                 E2F1 [nucleoplasm]
# 22                  E2F1 binds PMAIP1 (NOXA) promoter
# 23  Positive gene expression regulation by E2F1:TF...
#
#                        m.schemaClass m.category
# 0                           Reaction    binding
# 1      EntityWithAccessionedSequence       <NA>
# 2      EntityWithAccessionedSequence       <NA>
# 3      EntityWithAccessionedSequence       <NA>
# 4                           Reaction    binding
# 5      EntityWithAccessionedSequence       <NA>
# 6      EntityWithAccessionedSequence       <NA>
# 7      EntityWithAccessionedSequence       <NA>
# 8      EntityWithAccessionedSequence       <NA>
# 9                            Complex       <NA>
# 10     EntityWithAccessionedSequence       <NA>
# 11     EntityWithAccessionedSequence       <NA>
# 12                           Complex       <NA>
# 13  PositiveGeneExpressionRegulation       <NA>
# 14                          Reaction    binding
# 15                           Complex       <NA>
# 16                          Reaction    binding
# 17  PositiveGeneExpressionRegulation       <NA>
# 18                          Reaction    binding
# 19                           Complex       <NA>
# 20     EntityWithAccessionedSequence       <NA>
# 21     EntityWithAccessionedSequence       <NA>
# 22                          Reaction    binding
# 23  PositiveGeneExpressionRegulation       <NA>

# %%
# %%time

# Find all edges with a node of category "binding" going to an other node
command = """
MATCH (n)-[e]->(m)
WHERE n.category = "binding"
RETURN n.displayName, n.schemaClass, n.category, e, m.displayName, m.schemaClass, m.category
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    display(df)
# Out:
#                                         n.displayName n.schemaClass  \
# 0               TP53 binds the PMAIP1 (NOXA) promoter      Reaction
# 1               TP53 binds the PMAIP1 (NOXA) promoter      Reaction
# 2               TP53 binds the PMAIP1 (NOXA) promoter      Reaction
# 3               TP53 binds the PMAIP1 (NOXA) promoter      Reaction
# 4                  TP53 binds the APAF1 gene promoter      Reaction
# 5               NRF1:PPARGC1B binds the CYCS promoter      Reaction
# 6               NRF1:PPARGC1B binds the CYCS promoter      Reaction
# 7                                 CYCS binds to APAF1      Reaction
# 8                                 CYCS binds to APAF1      Reaction
# 9                      E2F1 binds APAF1 gene promoter      Reaction
# 10      NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter      Reaction
# 11      NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter      Reaction
# 12  BH3-only proteins associate with and inactivat...      Reaction
#
#    n.category   e                                      m.displayName  \
# 0     binding   0              p-S15,S20-TP53 Tetramer [nucleoplasm]
# 1     binding   1                          PMAIP1 Gene [nucleoplasm]
# 2     binding   2  p-S15,S20-TP53 Tetramer:PMAIP1 Gene [nucleoplasm]
# 3     binding   3           TP53 stimulates PMAIP1 (NOXA) expression
# 4     binding   4              TP53 stimulates APAF1 gene expression
# 5     binding   5                                 Expression of CYCS
# 6     binding   6                                 Expression of NRF1
# 7     binding   7          Release of Cytochrome c from mitochondria
# 8     binding   8                                     CYCS [cytosol]
# 9     binding   9  APAF1 gene expression is stimulated by E2F1 an...
# 10    binding  12                   p38 MAPK phosphorylates PPARGC1A
# 11    binding  13                                 Expression of NRF1
# 12    binding  17              Translocation of tBID to mitochondria
#
#                     m.schemaClass  m.category
# 0                         Complex        <NA>
# 1   EntityWithAccessionedSequence        <NA>
# 2                         Complex        <NA>
# 3                   BlackBoxEvent     omitted
# 4                   BlackBoxEvent     omitted
# 5                   BlackBoxEvent     omitted
# 6                   BlackBoxEvent     omitted
# 7                        Reaction  transition
# 8   EntityWithAccessionedSequence        <NA>
# 9                   BlackBoxEvent     omitted
# 10                       Reaction  transition
# 11                  BlackBoxEvent     omitted
# 12                       Reaction  transition
# CPU times: user 6.19 ms, sys: 20 μs, total: 6.21 ms
# Wall time: 5.76 ms

# %% [markdown]
# ## Complex queries

# %%
def build_query_chain(
    hop_count: int,
    start_node_label: str = None,
    start_node_property: str = None,
    start_node_value: str = None,
    end_node_label: str = None,
    end_node_property: str = None,
    end_node_value: str = None,
    edge_type: str = None,
    intermediate_node_label: str = None,
    return_properties: list = None,
) -> tuple[str, list[str]]:
    """
    Build a general query to find chains between nodes.

    Parameters:
    -----------
    hop_count : int
        Number of hops/edges in the path (REQUIRED)
    start_node_label : str, optional
        Label of the starting node (e.g., 'Process', 'Station')
    start_node_property : str, optional
        Property name to match on start node (e.g., 'displayName', 'id')
    start_node_value : str, optional
        Value to match for start node
    end_node_label : str, optional
        Label of the ending node (None for any node)
    end_node_property : str, optional
        Property name to match on end node
    end_node_value : str, optional
        Value to match for end node
    edge_type : str, optional
        Type of edges to traverse (None for any edge type)
    intermediate_node_label : str, optional
        Label constraint for intermediate nodes (None for any label)
    return_properties : list, optional
        List of property names to return for nodes (default: ['displayName'])

    Returns:
    --------
    tuple : (query_string, column_names)
    """

    if return_properties is None:
        return_properties = ["displayName"]

    # Build MATCH clause
    query = "MATCH "

    # Start node - build based on what's provided
    start_parts = []
    if start_node_label:
        start_parts.append(f":{start_node_label}")
    if start_node_property and start_node_value:
        start_parts.append(f'{{{start_node_property}:"{start_node_value}"}}')

    if start_parts:
        query += f"(first{''.join(start_parts)})"
    else:
        query += "(first)"

    # Intermediate nodes and edges
    for k in range(1, hop_count + 1):
        # Edge
        if edge_type:
            query += f"-[e{k}:{edge_type}]->"
        else:
            query += f"-[e{k}]->"

        # Last hop - end node
        if k == hop_count:
            end_parts = []
            if end_node_label:
                end_parts.append(f":{end_node_label}")
            if end_node_property and end_node_value:
                end_parts.append(f'{{{end_node_property}:"{end_node_value}"}}')

            if end_parts:
                query += f"(last{''.join(end_parts)})"
            else:
                query += "(last)"
        # Intermediate nodes
        else:
            if intermediate_node_label:
                query += f"(n{k}:{intermediate_node_label})"
            else:
                query += f"(n{k})"

    # Build RETURN clause
    query += " RETURN first"
    column_names = ["first"]

    # Add start node properties
    for prop in return_properties:
        query += f", first.{prop}"
        column_names.append(f"first.{prop}")

    # Add intermediate nodes/edges
    for k in range(1, hop_count + 1):
        query += f", e{k}"
        column_names.append(f"e{k}")

        if k == hop_count:
            query += ", last"
            column_names.append("last")
            for prop in return_properties:
                query += f", last.{prop}"
                column_names.append(f"last.{prop}")
        else:
            query += f", n{k}"
            column_names.append(f"n{k}")
            for prop in return_properties:
                query += f", n{k}.{prop}"
                column_names.append(f"n{k}.{prop}")

    return query, column_names

# %%
# %%time

# Find all paths (with maximum length of 15 hops) between a node of type "EntityWithAccessionedSequence" and a node of type "BlackBoxEvent"
max_hops = 15
longest_df = None

for hop in range(1, max_hops):
    print(100 * "*")
    print(f"{hop} hop(s) :\n")

    query, cols = build_query_chain(
        hop_count=hop,
        start_node_label="EntityWithAccessionedSequence",
        end_node_label="BlackBoxEvent",
        return_properties=["id", "displayName", "schemaClass", "category"],
    )
    #print(query)
    
    # Use with client
    df = client.query(query)
    if df.empty:
        print("No result found")
    else:
        df.columns = cols
        display(df)
        longest_df = df

print(100 * "*")
# Out:
# ****************************************************************************************************
# 1 hop(s) :
#    first                   first.id          first.displayName  \
# 0     29             CYCS [cytosol]             CYCS [cytosol]
# 1     31  PMAIP1 Gene [nucleoplasm]  PMAIP1 Gene [nucleoplasm]
# 2     31  PMAIP1 Gene [nucleoplasm]  PMAIP1 Gene [nucleoplasm]
# 3     33         NRF1 [nucleoplasm]         NRF1 [nucleoplasm]
#
#                first.schemaClass first.category  e1  last  \
# 0  EntityWithAccessionedSequence           <NA>  43    23
# 1  EntityWithAccessionedSequence           <NA>  46    26
# 2  EntityWithAccessionedSequence           <NA>  47    22
# 3  EntityWithAccessionedSequence           <NA>  53    24
#
#                                     last.id  \
# 0                        Expression of CYCS
# 1  TP53 stimulates PMAIP1 (NOXA) expression
# 2  Transactivation of PMAIP1 (NOXA) by E2F1
# 3                        Expression of NRF1
#
#                            last.displayName last.schemaClass last.category
# 0                        Expression of CYCS    BlackBoxEvent       omitted
# 1  TP53 stimulates PMAIP1 (NOXA) expression    BlackBoxEvent       omitted
# 2  Transactivation of PMAIP1 (NOXA) by E2F1    BlackBoxEvent       omitted
# 3                        Expression of NRF1    BlackBoxEvent       omitted
# ****************************************************************************************************
# 2 hop(s) :
#    first            first.id   first.displayName  \
# 0     33  NRF1 [nucleoplasm]  NRF1 [nucleoplasm]
# 1     33  NRF1 [nucleoplasm]  NRF1 [nucleoplasm]
# 2     33  NRF1 [nucleoplasm]  NRF1 [nucleoplasm]
#
#                first.schemaClass first.category  e1  n1  \
# 0  EntityWithAccessionedSequence           <NA>  51   6
# 1  EntityWithAccessionedSequence           <NA>  52   2
# 2  EntityWithAccessionedSequence           <NA>  52   2
#
#                                            n1.id  \
# 0  NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter
# 1          NRF1:PPARGC1B binds the CYCS promoter
# 2          NRF1:PPARGC1B binds the CYCS promoter
#
#                                   n1.displayName n1.schemaClass n1.category  \
# 0  NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter       Reaction     binding
# 1          NRF1:PPARGC1B binds the CYCS promoter       Reaction     binding
# 2          NRF1:PPARGC1B binds the CYCS promoter       Reaction     binding
#
#    e2  last             last.id    last.displayName last.schemaClass  \
# 0  13    24  Expression of NRF1  Expression of NRF1    BlackBoxEvent
# 1   5    23  Expression of CYCS  Expression of CYCS    BlackBoxEvent
# 2   6    24  Expression of NRF1  Expression of NRF1    BlackBoxEvent
#
#   last.category
# 0       omitted
# 1       omitted
# 2       omitted
# ****************************************************************************************************
# 3 hop(s) :
#    first                   first.id          first.displayName  \
# 0     27         E2F1 [nucleoplasm]         E2F1 [nucleoplasm]
# 1     31  PMAIP1 Gene [nucleoplasm]  PMAIP1 Gene [nucleoplasm]
# 2     33         NRF1 [nucleoplasm]         NRF1 [nucleoplasm]
#
#                first.schemaClass first.category  e1  n1  \
# 0  EntityWithAccessionedSequence           <NA>  39  12
# 1  EntityWithAccessionedSequence           <NA>  46  26
# 2  EntityWithAccessionedSequence           <NA>  51   6
#
#                                            n1.id  \
# 0               E2F1:(TFDP1,TFDP2) [nucleoplasm]
# 1       TP53 stimulates PMAIP1 (NOXA) expression
# 2  NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter
#
#                                   n1.displayName n1.schemaClass  ...  \
# 0               E2F1:(TFDP1,TFDP2) [nucleoplasm]        Complex  ...
# 1       TP53 stimulates PMAIP1 (NOXA) expression  BlackBoxEvent  ...
# 2  NRF1:p-PPARGC1A, NRF2 bind the TFB2M promoter       Reaction  ...
#
#                                             n2.id  \
# 0                  E2F1 binds APAF1 gene promoter
# 1  Translocation of PMAIP1 (NOXA) to mitochondria
# 2                p38 MAPK phosphorylates PPARGC1A
#
#                                    n2.displayName  n2.schemaClass n2.category  \
# 0                  E2F1 binds APAF1 gene promoter        Reaction     binding
# 1  Translocation of PMAIP1 (NOXA) to mitochondria        Reaction  transition
# 2                p38 MAPK phosphorylates PPARGC1A        Reaction  transition
#
#    e3 last                                            last.id  \
# 0   9   21  APAF1 gene expression is stimulated by E2F1 an...
# 1  16   22           Transactivation of PMAIP1 (NOXA) by E2F1
# 2  10   24                                 Expression of NRF1
#
#                                     last.displayName  last.schemaClass  \
# 0  APAF1 gene expression is stimulated by E2F1 an...     BlackBoxEvent
# 1           Transactivation of PMAIP1 (NOXA) by E2F1     BlackBoxEvent
# 2                                 Expression of NRF1     BlackBoxEvent
#
#   last.category
# 0       omitted
# 1       omitted
# 2       omitted
#
# [3 rows x 23 columns]
# ****************************************************************************************************
# 4 hop(s) :
#
# No result found
# ****************************************************************************************************
# 5 hop(s) :
#
# No result found
# ****************************************************************************************************
# 6 hop(s) :
#
# No result found
# ****************************************************************************************************
# 7 hop(s) :
#    first                   first.id          first.displayName  \
# 0     31  PMAIP1 Gene [nucleoplasm]  PMAIP1 Gene [nucleoplasm]
#
#                first.schemaClass first.category  e1  n1  \
# 0  EntityWithAccessionedSequence           <NA>  47  22
#
#                                       n1.id  \
# 0  Transactivation of PMAIP1 (NOXA) by E2F1
#
#                              n1.displayName n1.schemaClass  ...  \
# 0  Transactivation of PMAIP1 (NOXA) by E2F1  BlackBoxEvent  ...
#
#                             n6.id                  n6.displayName  \
# 0  E2F1 binds APAF1 gene promoter  E2F1 binds APAF1 gene promoter
#
#    n6.schemaClass n6.category e7 last  \
# 0        Reaction     binding  9   21
#
#                                              last.id  \
# 0  APAF1 gene expression is stimulated by E2F1 an...
#
#                                     last.displayName  last.schemaClass  \
# 0  APAF1 gene expression is stimulated by E2F1 an...     BlackBoxEvent
#
#   last.category
# 0       omitted
#
# [1 rows x 47 columns]
# ****************************************************************************************************
# 8 hop(s) :
#
# No result found
# ****************************************************************************************************
# 9 hop(s) :
#    first                   first.id          first.displayName  \
# 0     31  PMAIP1 Gene [nucleoplasm]  PMAIP1 Gene [nucleoplasm]
#
#                first.schemaClass first.category  e1  n1  \
# 0  EntityWithAccessionedSequence           <NA>  46  26
#
#                                       n1.id  \
# 0  TP53 stimulates PMAIP1 (NOXA) expression
#
#                              n1.displayName n1.schemaClass  ...  \
# 0  TP53 stimulates PMAIP1 (NOXA) expression  BlackBoxEvent  ...
#
#                             n8.id                  n8.displayName  \
# 0  E2F1 binds APAF1 gene promoter  E2F1 binds APAF1 gene promoter
#
#    n8.schemaClass n8.category e9 last  \
# 0        Reaction     binding  9   21
#
#                                              last.id  \
# 0  APAF1 gene expression is stimulated by E2F1 an...
#
#                                     last.displayName  last.schemaClass  \
# 0  APAF1 gene expression is stimulated by E2F1 an...     BlackBoxEvent
#
#   last.category
# 0       omitted
#
# [1 rows x 59 columns]
# ****************************************************************************************************
# 10 hop(s) :
#
# No result found
# ****************************************************************************************************
# 11 hop(s) :
#
# No result found
# ****************************************************************************************************
# 12 hop(s) :
#
# No result found
# ****************************************************************************************************
# 13 hop(s) :
#
# No result found
# ****************************************************************************************************
# 14 hop(s) :
#
# No result found
# ****************************************************************************************************
# CPU times: user 109 ms, sys: 2.34 ms, total: 112 ms
# Wall time: 112 ms

# %% [markdown]
# # Create subgraph to visualise

# %%
# Get subgraph
subset_nodes = longest_df.filter(regex="id$", axis=1).iloc[0].values.tolist()
subG = G.subgraph(subset_nodes).copy()
print(subG)

# Build CREATE command from subgraph
create_command_subG = build_create_command_from_networkx(subG)
print(f"""
Cypher CREATE command :
* size: {len(create_command_subG.encode('utf-8'))/1024/1000:.4f} MB\n
{100 * '*'}
{create_command_subG \
if len(create_command_subG.split("\n")) < 10000 \
else "\n".join(create_command_subG.split('\n')[:5]) + "\n...\n" + "\n".join(create_command_subG.split('\n')[-5:])}
{100 * '*'}
""")
# Out:
# MultiGraph with 10 nodes and 10 edges
# Cypher query will create graph with 10 nodes and 10 edges
#
# Cypher CREATE command :
# * size: 0.0049 MB
#
# ****************************************************************************************************
# CREATE (:Node {id: "Translocation of PMAIP1 (NOXA) to mitochondria", schemaClass: "Reaction", stId: "R-HSA-140216", oldStId: "REACT_1585", releaseDate: "2004-10-27", name: "[ Translocation of PMAIP1 (NOXA) to mitochondria ]", stIdVersion: "R-HSA-140216.4", speciesName: "Homo sapiens", category: "transition", displayName: "Translocation of PMAIP1 (NOXA) to mitochondria"}),
# (:Node {id: "E2F1:(TFDP1,TFDP2) [nucleoplasm]", schemaClass: "Complex", stId: "R-HSA-9007512", name: "[ E2F1:(TFDP1,TFDP2) ]", stIdVersion: "R-HSA-9007512.1", speciesName: "Homo sapiens", displayName: "E2F1:(TFDP1,TFDP2) [nucleoplasm]"}),
# (:Node {id: "E2F1 binds APAF1 gene promoter", schemaClass: "Reaction", stId: "R-HSA-9007514", releaseDate: "2017-09-12", name: "[ E2F1 binds APAF1 gene promoter ]", stIdVersion: "R-HSA-9007514.2", speciesName: "Homo sapiens", category: "binding", displayName: "E2F1 binds APAF1 gene promoter"}),
# (:Node {id: "TP53 stimulates PMAIP1 (NOXA) expression", schemaClass: "BlackBoxEvent", stId: "R-HSA-140214", oldStId: "REACT_2201", releaseDate: "2004-10-27", name: "[ TP53 stimulates PMAIP1 (NOXA) expression ]", stIdVersion: "R-HSA-140214.6", speciesName: "Homo sapiens", category: "omitted", displayName: "TP53 stimulates PMAIP1 (NOXA) expression"}),
# (:Node {id: "E2F1 [nucleoplasm]", schemaClass: "EntityWithAccessionedSequence", stId: "R-HSA-68639", oldStId: "REACT_2601", name: "[ E2F1 , Transcription factor E2F1 , E2F-1 , Retinoblastoma binding protein 3 , RBBP-3 , PRB-binding protein E2F-1 , PBR3 , Retinoblastoma-associated protein 1 , RBAP-1 ]", stIdVersion: "R-HSA-68639.2", speciesName: "Homo sapiens", referenceType: "ReferenceGeneProduct", displayName: "E2F1 [nucleoplasm]"}),
# (:Node {id: "Transactivation of PMAIP1 (NOXA) by E2F1", schemaClass: "BlackBoxEvent", stId: "R-HSA-140217", oldStId: "REACT_1872", releaseDate: "2004-10-27", name: "[ Transactivation of PMAIP1 (NOXA) by E2F1 ]", stIdVersion: "R-HSA-140217.4", speciesName: "Homo sapiens", category: "omitted", displayName: "Transactivation of PMAIP1 (NOXA) by E2F1"}),
# (:Node {id: "E2F1:TFDP1,TFDP2 [nucleoplasm]", schemaClass: "Complex", stId: "R-HSA-68653", oldStId: "REACT_5400", name: "[ E2F1:TFDP1,TFDP2 , DP1/2:E2F1 ]", stIdVersion: "R-HSA-68653.2", speciesName: "Homo sapiens", displayName: "E2F1:TFDP1,TFDP2 [nucleoplasm]"}),
# (:Node {id: "Positive gene expression regulation by 'E2F1:TFDP1:PMAIP1 Gene [nucleoplasm]'", schemaClass: "PositiveGeneExpressionRegulation", stId: "R-HSA-159039", oldStId: "REACT_6130", stIdVersion: "R-HSA-159039.1", displayName: "Positive gene expression regulation by E2F1:TFDP1:PMAIP1 Gene [nucleoplasm]"}),
# (:Node {id: "PMAIP1 Gene [nucleoplasm]", schemaClass: "EntityWithAccessionedSequence", stId: "R-HSA-4331342", oldStId: "REACT_170122", name: "[ PMAIP1 Gene , NOXA Gene ]", stIdVersion: "R-HSA-4331342.1", speciesName: "Homo sapiens", referenceType: "ReferenceDNASequence", searchSeed: "1", displayName: "PMAIP1 Gene [nucleoplasm]"}),
# (:Node {id: "APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6", schemaClass: "BlackBoxEvent", stId: "R-HSA-9007496", releaseDate: "2017-09-12", name: "[ APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6 ]", stIdVersion: "R-HSA-9007496.4", speciesName: "Homo sapiens", category: "omitted", displayName: "APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6"})
# MATCH (source {id: "Translocation of PMAIP1 (NOXA) to mitochondria"}), (target {id: "TP53 stimulates PMAIP1 (NOXA) expression"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Translocation of PMAIP1 (NOXA) to mitochondria"}), (target {id: "Transactivation of PMAIP1 (NOXA) by E2F1"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "E2F1:(TFDP1,TFDP2) [nucleoplasm]"}), (target {id: "E2F1 [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "E2F1:(TFDP1,TFDP2) [nucleoplasm]"}), (target {id: "E2F1 binds APAF1 gene promoter"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "E2F1 binds APAF1 gene promoter"}), (target {id: "APAF1 gene expression is stimulated by E2F1 and inhibited by E2F6"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "TP53 stimulates PMAIP1 (NOXA) expression"}), (target {id: "PMAIP1 Gene [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "E2F1 [nucleoplasm]"}), (target {id: "E2F1:TFDP1,TFDP2 [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Transactivation of PMAIP1 (NOXA) by E2F1"}), (target {id: "PMAIP1 Gene [nucleoplasm]"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "Transactivation of PMAIP1 (NOXA) by E2F1"}), (target {id: "Positive gene expression regulation by 'E2F1:TFDP1:PMAIP1 Gene [nucleoplasm]'"}) CREATE (source)-[:CONNECTED]->(target)
# MATCH (source {id: "E2F1:TFDP1,TFDP2 [nucleoplasm]"}), (target {id: "Positive gene expression regulation by 'E2F1:TFDP1:PMAIP1 Gene [nucleoplasm]'"}) CREATE (source)-[:CONNECTED]->(target)
# ****************************************************************************************************

# %%
subgraph_name = f"{graph_name}_subgraph"
subgraph_name
# Out:
# 'reactome1_subgraph'

# %%
# %%time

# Set graph
try:
    client.create_graph(subgraph_name)
except TuringDBException as e:
    print(e)

# Set working graph
client.set_graph(subgraph_name)

# Create a new change on the graph
client.checkout()
change = client.new_change()
print(f"Current change {change}")

# Checkout into the change
client.checkout(change=change)
# Out:
# Current change 0
# CPU times: user 2.82 ms, sys: 0 ns, total: 2.82 ms
# Wall time: 9.19 ms

# %%
# %%time

chunks = split_cypher_commands(create_command_subG, max_size_mb=1)

print(f"✓ Split into {len(chunks['node_chunks'])} node chunk(s) and {len(chunks['edge_chunks'])} edge chunk(s)")

print("\nNode chunks:")
for i, chunk in enumerate(chunks['node_chunks']):
    print(f"  Node chunk {i+1}: {len(chunk.encode('utf-8'))/1024:.1f} KB")
    if i == 10:
        print("  ...")
        break

print("\nEdge chunks:")
for i, chunk in enumerate(chunks['edge_chunks']):
    print(f"  Edge chunk {i+1}: {len(chunk.encode('utf-8'))/1024:.1f} KB")
    if i == 10:
        print("  ...")
        break
# Out:
# ✓ Split into 1 node chunk(s) and 10 edge chunk(s)
#
# Node chunks:
#   Node chunk 1: 3.3 KB
#
# Edge chunks:
#   Edge chunk 1: 0.2 KB
#   Edge chunk 2: 0.2 KB
#   Edge chunk 3: 0.1 KB
#   Edge chunk 4: 0.1 KB
#   Edge chunk 5: 0.2 KB
#   Edge chunk 6: 0.1 KB
#   Edge chunk 7: 0.1 KB
#   Edge chunk 8: 0.1 KB
#   Edge chunk 9: 0.2 KB
#   Edge chunk 10: 0.2 KB
# CPU times: user 496 μs, sys: 0 ns, total: 496 μs
# Wall time: 449 μs

# %%
# %%time

# Run CREATE command
print("\nExecuting query on TuringDB...")
start_time = time.time()

print(f"✓ Split into {len(chunks['node_chunks'])} node chunk(s) and {len(chunks['edge_chunks'])} edge chunk(s)")

# CREATE nodes
print("\nNode chunks:")
for i, chunk in enumerate(tqdm(chunks['node_chunks'])):
    result = client.query(chunk)
# Commit the change
client.query("COMMIT")
print(f"✓ {len(chunks['node_chunks'])} node chunks done")

# CREATE edges
print("\nEdge chunks:")
for i, chunk in enumerate(tqdm(chunks['edge_chunks'])):
    result = client.query(chunk)
# Commit the change
client.query("COMMIT")
print(f"✓ {len(chunks['edge_chunks'])} edge chunks done")

execution_time = time.time() - start_time
print(f"\n✓ Graph created successfully in {execution_time:.2f} seconds")

# Submit changes
start_time = time.time()
client.query("CHANGE SUBMIT")
execution_time = time.time() - start_time
print(f"\n✓ Changes successfully submitted in {execution_time:.2f} seconds")

# Checkout into main
client.checkout()
# Out:
# Executing query on TuringDB...
# ✓ Split into 1 node chunk(s) and 10 edge chunk(s)
#
# Node chunks:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✓ 1 node chunks done
#
# Edge chunks:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ✓ 10 edge chunks done
#
# ✓ Graph created successfully in 0.02 seconds
#
# ✓ Changes successfully submitted in 0.06 seconds
# CPU times: user 25.7 ms, sys: 5.2 ms, total: 30.9 ms
# Wall time: 89.6 ms

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         You can visualise the subgraph directly in the notebook below. For more details on nodes and edges, you can go to TuringDB visualizer (running on your instance)
#     </h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         Visualize your graph in TuringDB Graph Visualizer ! Now that your instance is running:
#     </h2>
#     <h3>
#         <ul>
#             <li>Go to <a href="https://console.turingdb.ai/databases">TuringDB Console - Database Instances</a></li>
#             <li>In your current instance panel, click on "Open Visualizer" button</li>
#             <li>Visualizer opens, now you can choose your graph in the dropdown menu at the top-right corner</li>
#         </ul>
#         You can then play with your graph and visualize the nodes you want !
#     </h3>
# </div>

# %%
from pyvis.network import Network
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

net = Network(
    height="750px",
    width="100%",
    notebook=True,
    bgcolor="#ffffff",
    font_color="#000000",
    directed=True,
)

# Choose your palette (can be changed easily)
palette_name = (
    "Pastel1"  # Options: 'tab10', 'Set3', 'Paired', 'viridis', 'plasma', etc.
)

# Get unique node types
unique_types = list(set(data.get("schemaClass") for _, data in G.nodes(data=True)))

# Get colors from matplotlib palette
cmap = plt.get_cmap(palette_name)
colors = [
    mcolors.rgb2hex(cmap(i / len(unique_types))) for i in range(len(unique_types))
]

# Map types to colors
type_colors = {node_type: colors[i] for i, node_type in enumerate(unique_types)}

# Then use in your visualization
for node, data in subG.nodes(data=True):
    node_type = data.get("schemaClass", "Unknown")
    color = type_colors.get(node_type, "#95a5a6")

    net.add_node(
        node,
        label=data.get("displayName", str(node)),
        title=f"{data.get('displayName', '')}",
        color=color,
        size=25,
    )

for source, target, data in subG.edges(data=True):
    net.add_edge(source, target, color="#95a5a6", width=3)

net.toggle_physics(status=True)
net.show(f"{example_name}_subgraph.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# reactome_subgraph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="reactome_subgraph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Use LLM to generate Cypher query

# %% [markdown]
# Before running this section, create a `.env` file in the project root with your API keys:
#
# ```env
# ANTHROPIC_API_KEY=your_key_here
# OPENAI_API_KEY=your_key_here
# MISTRAL_API_KEY=your_key_here

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv(override=True)
# Out:
# True

# %%
api_keys = {
    "Anthropic": os.getenv("ANTHROPIC_API_KEY"),
    "Mistral": os.getenv("MISTRAL_API_KEY"),
    "OpenAI": os.getenv("OPENAI_API_KEY"),
}

# %%
"""Build system prompt with TuringDB schema and examples"""

turingdb_cypher_system_prompt = """
You are an expert at converting natural language questions into TuringDB queries.

Your task is to generate syntactically correct TuringDB queries based on natural language input.

VERY IMPORTANT - YOU MUST FOLLOW THESE REQUESTS - TuringDB Syntax Guidelines:
1. Return ONLY the TuringDB query, no explanations or markdown formatting
2. Use MATCH, CREATE and WHERE operations only
3. Nodes: (n:Label {property = "value"}) or (n:Label {property: value})
4. Edges: Use DIRECTED syntax with ->
5. Pattern matching: MATCH (n)-[e]->(m)
6. Property matching: Use = operator for exact matching
7. Multiple constraints: (n:Person:Engineer {name = "John", age = 30})
8. Return all matched entities: RETURN n, e, m or use RETURN * for all
9. Filter using WHERE clause: MATCH (n:Person) WHERE n.name = 'John' RETURN n.firstname, n.lastname

VERY IMPORTANT - YOU ARE NOT ALLOWED TO USE THE FOLLOWING - FORBIDDEN in TuringDB:
- Do NOT use AS aliases
- Do NOT use LIMIT, SKIP clauses
- Do NOT use WITH clauses
- Do NOT use CALL (except for metaqueries)
- Do NOT use toLower() or other functions
- Do NOT use wildcard character (*)
- Do NOT use multi-hops pattern for edges: e.g. `-[e:CONNECTED*1..10]->`
- Do NOT use "end" or "s3" variable name

Supported TuringDB Operations:
- MATCH queries: MATCH (n:Label)-[e:Type]->(m) RETURN n, m
- CREATE queries: CREATE (n:Label{property="value"})-[e:Type]->(m:Label)
- Metaqueries: CALL db.propertyTypes(), CALL db.labels(), CALL db.edgeTypes()
- Property types: String ("text" or `text`), Boolean (true/false), Integer (20), Double (20.5)

Examples for few-shot learning:
- Find all persons: MATCH (n:Person) RETURN n
- Find connections: MATCH (n:Person)-[e]->(m:Person) RETURN n, e, m
- Create person: CREATE (n:Person{name="John", age=30})
- Match person with specific name: MATCH (p:Person) WHERE p.name = "John" RETURN p
- Path with 1 hop between Station Paddington and Blackfriars:  MATCH (first:Station{displayName:"Paddington"})-[e1:CONNECTED]->(last:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, last, last.displayName, last.Note
- Path with 2 hops between Station Paddington and Blackfriars: MATCH (first:Station{displayName:"Paddington"})-[e1:CONNECTED]->(s1:Station)-[e2:CONNECTED]->(last:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, last, last.displayName, last.Note
- Path with 8 hops between Station Paddington and Blackfriars: MATCH (first:Station{displayName:"Paddington"})-[e1:CONNECTED]->(s1:Station)-[e2:CONNECTED]->(s2:Station)-[e3:CONNECTED]->(s3:Station)-[e4:CONNECTED]->(s4:Station)-[e5:CONNECTED]->(s5:Station)-[e6:CONNECTED]->(s6:Station)-[e7:CONNECTED]->(s7:Station)-[e8:CONNECTED]->(last:Station{displayName="Blackfriars"}) RETURN start, start.displayName, start.Note, e1.Line, s1, s1.displayName, s1.Note, e2.Line, s2, s2.displayName, s2.Note, e3.Line, s3, s3.displayName, s3.Note, e4.Line, s4, s4.displayName, s4.Note, e5.Line, s5, s5.displayName, s5.Note, e6.Line, s6, s6.displayName, s6.Note, e7.Line, s7, s7.displayName, s7.Note, e8.Line, last, last.displayName, last.Note
- Find all Chinese providers and what they supply: MATCH (n{provider_country:"CHN"}) RETURN n, n.provider_name, n.displayName, n.share_provided, n.type
- Find all deposition tools and their types: MATCH (specific)-[e:IS_TYPE_OF]->(general:Tool_Resource{displayName:"Deposition tools"}) RETURN specific, specific.displayName, specific.provider_name, e, general, general.displayName
"""

# %%
# Get subset of CREATE command to avoid exceeding context window
create_command_subset = create_command_subG.split("\n")[:5] + create_command_subG.split("\n")[-5:]

# Create system_prompt
system_prompt = f"""
TuringDB Cypher prompt :
{turingdb_cypher_system_prompt}

Here is a subset of the CREATE command used to create the graph, this way you know graph structure.
Only a subset is passed because the whole command is to long :
{create_command_subset}

Here is also the output of "CALL LABELS ()" command, showing the different node types of the graph :
{client.query("CALL db.labels()")}

Here is also the output of "CALL EDGETYPES ()" command, showing the different edge types of the graph :
{client.query("CALL db.edgeTypes()")}

Very important :
- You MUST follow current TuringDB Syntax Guidelines
- You MUST NOT USE what is FORBIDDEN in TuringDB
- By default, RETURN ALL THE MATCHED NODES AND EDGES AND THEIR PROPERTIES in the RETURN section (except contrary demand from user)
- Use the correct node and edge properties name in the MATCH section.
- Use the correct node and edge properties name in the RETURN section.
- Pay attention to which properties come from nodes or edges, to create a functioning query
- Pay attention to lower and uppercases in properties
- If some properties contain spaces, be careful to wrap them

Give me the query FOLLOWING TURINGDB GUIDELINES AND NOT USING WHAT IS FORBIDDEN for this specific question :
"""

# %%
question = """
Is there a path of any size linking gene PMAIP1 and gene E2F1 ?
"""

# %%
# %%time

provider = "OpenAI"

cypher_query = natural_language_to_cypher(
    question=question,
    system_prompt=system_prompt,
    provider=provider,
    api_key=api_keys[provider],
    temperature=0.0,
)
print(f"cypher_query : {cypher_query}")
# Out:
# cypher_query : MATCH (n:Node {id: "PMAIP1 Gene [nucleoplasm]"})-[e:CONNECTED]->(m:Node {id: "E2F1 [nucleoplasm]"}) RETURN n, e, m
# CPU times: user 363 ms, sys: 52.9 ms, total: 416 ms
# Wall time: 2.68 s

# %%
# %%time

# Set original graph
client.set_graph(graph_name)

try:
    df_path = client.query(cypher_query)

    if df_path.empty:
        print("--> No result found\n")
    else:
        display(df_path)

except TuringDBException:
    print(f"Query generated by LLM not supported.")
# Out:
# Query generated by LLM not supported.
# CPU times: user 106 μs, sys: 2.87 ms, total: 2.97 ms
# Wall time: 2.1 ms

# %% [markdown]
# # Use LLM to get subgraph summary

# %%
# %%time

prompt = f"""
Give me a summary of this graph. It represents biological entities, tell me more about the entities involved and the interactions.
Here is the graph :
{G.nodes(data=True)} {G.edges(data=True)}
"""

system_prompt = """
You are a specialist in analysing graphs and their structure.
You will use your knowledge to add more information about the entities and relationships in the graph.
Add information only when you are sure it is relevant.
"""

provider = "OpenAI"

response = query_llm(
    prompt=prompt,
    system_prompt=system_prompt,
    provider=provider,
    api_key=api_keys[provider],
    temperature=0.0,
)
# Out:
# CPU times: user 105 ms, sys: 15.1 ms, total: 120 ms
# Wall time: 17 s

# %%
display(Markdown(response))
# Out:
# The graph represents a complex network of interactions involving various biological entities primarily related to gene regulation, apoptosis, and cellular signaling in *Homo sapiens*. Here’s a summary of the key entities and their interactions:
#
# ### Key Entities:
# 1. **TP53 (Tumor Protein p53)**: A crucial tumor suppressor protein that regulates the cell cycle and functions in preventing cancer. It binds to the promoters of various genes, including PMAIP1 and APAF1, to stimulate their expression.
#    - **p-S15,S20-TP53 Tetramer**: A phosphorylated form of TP53 that is active in gene regulation.
#
# 2. **PMAIP1 (NOXA)**: A pro-apoptotic gene that is regulated by TP53. It plays a role in apoptosis and is translocated to mitochondria to promote cell death.
#
# 3. **APAF1 (Apoptotic Protease Activating Factor 1)**: A key component in the apoptosome that activates caspases, leading to apoptosis. Its expression is stimulated by TP53 and E2F1.
#
# 4. **CYCS (Cytochrome c)**: A protein involved in the electron transport chain and apoptosis. It binds to APAF1 and is released from mitochondria during apoptosis.
#
# 5. **E2F1**: A transcription factor that regulates the expression of genes involved in cell cycle progression and apoptosis. It binds to the promoters of PMAIP1 and APAF1.
#
# 6. **NRF1 (Nuclear Respiratory Factor 1)**: A transcription factor that regulates the expression of genes involved in mitochondrial biogenesis and function, including CYCS.
#
# 7. **PPARGC1A (Peroxisome Proliferator-Activated Receptor Gamma Coactivator 1-alpha)**: A coactivator that regulates genes involved in energy metabolism and mitochondrial function.
#
# 8. **ESRRA (Estrogen-Related Receptor Alpha)**: A transcription factor that positively regulates the expression of various genes, including those involved in mitochondrial function.
#
# ### Key Interactions:
# - **TP53 Binding**: TP53 binds to the promoters of PMAIP1 and APAF1, stimulating their expression, which is crucial for apoptosis.
# - **E2F1 Regulation**: E2F1 also binds to the promoters of PMAIP1 and APAF1, indicating a collaborative role in regulating apoptosis and cell cycle.
# - **CYCS and APAF1 Interaction**: CYCS binds to APAF1, leading to the formation of the apoptosome and subsequent activation of caspases.
# - **Translocation Events**: PMAIP1 is translocated to mitochondria, where it can exert its pro-apoptotic effects, and CYCS is released from mitochondria during apoptosis.
# - **Positive Regulation**: The interactions between TP53, E2F1, and other transcription factors like NRF1 and ESRRA indicate a complex regulatory network that ensures proper gene expression in response to cellular stress or damage.
#
# ### Conclusion:
# This graph illustrates a network of interactions that highlight the roles of TP53, E2F1, and other transcription factors in regulating apoptosis and gene expression in response to cellular signals. The interplay between these entities is crucial for maintaining cellular homeostasis and preventing tumorigenesis.

# %%
print("Notebook finished !")
# Out:
# Notebook finished !
