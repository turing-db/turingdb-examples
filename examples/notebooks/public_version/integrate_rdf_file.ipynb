# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>
#         Example notebook - Integrate RDF file
#     </h1>
#     <p>
#         Link to dataset : <a href="TR/owl-guide/wine.rdf">Link to Wine RDF file download</a>
#     </p>
# </div>

# %% [markdown]
# # Import modules and functions

# %%
from rdflib import Graph as RDFGraph
import re
import time

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %% [markdown]
# # Check data files are available

# %%
example_name = "wine_ontology"
path_data = f"{os.getcwd()}/data/{example_name}"
if not os.path.exists(path_data):
    print(f"{path_data} does not exist")
    os.makedirs(path_data)
    print(f"{path_data} folder created ✔")

list_files = sorted(os.listdir(path_data))
rdf_filename = "wine_ontology.rdf"
if not rdf_filename in list_files:
    print(f"Wine ontology RDF file is not available in {path_data}. \n")
    url_rdf = "https://www.w3.org/TR/owl-guide/wine.rdf"
    print(
        f"Downloading from: {url_rdf}"
        "\n...\n"
    )
    os.system(f"wget {url_rdf} -O {path_data}/{rdf_filename}")

# %% [markdown]
# # Load dataset

# %%
# RDF graph loading
path_rdf = f"{path_data}/{rdf_filename}"

rg = RDFGraph()
rg.parse(path_rdf)
print(f"RDF file successfully loaded with {len(rg)} triples")
# Out:
# RDF file successfully loaded with 1839 triples

# %%
for obj in list(rg.objects())[:10]:
    print(f"Object: {obj}")
    print(f"Type:   {type(obj)}")
    print()
# Out:
# Object: http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaine
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: http://www.w3.org/2002/07/owl#Restriction
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Strong
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: http://www.w3.org/2002/07/owl#Restriction
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: N6195445ed69f491abe1fff4e84477818
# Type:   <class 'rdflib.term.BNode'>
#
# Object: http://www.w3.org/2002/07/owl#Restriction
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Burgundy
# Type:   <class 'rdflib.term.URIRef'>

# %% [markdown]
# # Graph Creation in TuringDB

# %% [markdown]
# ## Build Cypher CREATE Commands

# %% [markdown]
# ### Sanitize Cypher query

# %%
def sanitize_cypher_query(query):
    query = query.replace("#", "_")
    query = query.replace("-", "_")

    return query

# %% [markdown]
# ### TuringDB v2 (not implemented yet)

# %%
def rdf_to_cypher_v2(rdf_file, batch_size=1000):
    from rdflib import Graph
    
    g = Graph()
    g.parse(rdf_file)
    
    nodes = {str(s) for s, _, _ in g} | {str(o) for _, _, o in g if not isinstance(o, str) or o.startswith('http')}
    
    for i in range(0, len(nodes), batch_size):
        batch = list(nodes)[i:i+batch_size]
        yield "CREATE " + ",\n".join(
            f"(:{node.split('/')[-1]} {{uri: '{node}'}})" 
            for node in batch
        )
    
    for s, p, o in g:
        if not isinstance(o, str) or o.startswith('http'):
            yield f"MATCH (a {{uri: '{s}'}}), (b {{uri: '{o}'}}) CREATE (a)-[:{str(p).split('/')[-1]}]->(b)"

# %%
# %%time

# Create Cypher CREATE command for TuringDB v2
graph_CREATE_command_v2 = '\n'.join(rdf_to_cypher_v2(path_rdf))
graph_CREATE_command_v2 = sanitize_cypher_query(graph_CREATE_command_v2)
print(graph_CREATE_command_v2)
# Out:
# CREATE (:wine_ChateauLafiteRothschild {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauLafiteRothschild'}),
# (:N126ee764c7b64d1dbdcecf26a566a90e {uri: 'N126ee764c7b64d1dbdcecf26a566a90e'}),
# (:wine_locatedIn {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_locatedIn'}),
# (:Nfbb714dcf0f746c39cba4e59ad2d6f2f {uri: 'Nfbb714dcf0f746c39cba4e59ad2d6f2f'}),
# (:wine_TexasWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_TexasWine'}),
# (:wine_KalinCellars {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_KalinCellars'}),
# (:owl_ObjectProperty {uri: 'http://www.w3.org/2002/07/owl_ObjectProperty'}),
# (:wine_hasFlavor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasFlavor'}),
# (:wine_ItalianRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ItalianRegion'}),
# (:Nfdc0ca7deac64163a6dff6da230e5c5b {uri: 'Nfdc0ca7deac64163a6dff6da230e5c5b'}),
# (:wine_SaucelitoCanyonZinfandel1998 {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SaucelitoCanyonZinfandel1998'}),
# (:Na3fdedd1228a4c8da8100e85b5c97546 {uri: 'Na3fdedd1228a4c8da8100e85b5c97546'}),
# (:Na1819128a2f34ad8a8eccb8489049ba7 {uri: 'Na1819128a2f34ad8a8eccb8489049ba7'}),
# (:N61efbe50519749398b94c56ee15077b4 {uri: 'N61efbe50519749398b94c56ee15077b4'}),
# (:wine_RedTableWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RedTableWine'}),
# (:N9915f19b6bfa44f0a414f265b357c2ea {uri: 'N9915f19b6bfa44f0a414f265b357c2ea'}),
# (:Neb58033f60914e459c28958860bd1a75 {uri: 'Neb58033f60914e459c28958860bd1a75'}),
# (:N5932d3912160499780b63285fca5baf2 {uri: 'N5932d3912160499780b63285fca5baf2'}),
# (:N88c7c9174eb74342a00b0d928f6de510 {uri: 'N88c7c9174eb74342a00b0d928f6de510'}),
# (:wine_MerlotGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MerlotGrape'}),
# (:N01d64b6850cb4ce28c8f0ecc782d8be1 {uri: 'N01d64b6850cb4ce28c8f0ecc782d8be1'}),
# (:N06455d74181f41dca49afd22f1490bff {uri: 'N06455d74181f41dca49afd22f1490bff'}),
# (:wine_USRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_USRegion'}),
# (:N08c61b0e16e8428182c70599f69817de {uri: 'N08c61b0e16e8428182c70599f69817de'}),
# (:N276c70b8ac0d4280876099b636af683e {uri: 'N276c70b8ac0d4280876099b636af683e'}),
# (:wine_Medium {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}),
# (:wine_FormanChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FormanChardonnay'}),
# (:N85c934b1139d4879b9d1aeb9287da0dc {uri: 'N85c934b1139d4879b9d1aeb9287da0dc'}),
# (:N897065dfcf26492bb807d4c39532bbec {uri: 'N897065dfcf26492bb807d4c39532bbec'}),
# (:wine_MendocinoRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MendocinoRegion'}),
# (:N040075ecf5114e758618827128c57fe3 {uri: 'N040075ecf5114e758618827128c57fe3'}),
# (:wine_CongressSpringsSemillon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CongressSpringsSemillon'}),
# (:N24d671aaf8314dda955ac799050d703f {uri: 'N24d671aaf8314dda955ac799050d703f'}),
# (:N6de0e9f57cb049a9a4b1254d38cd7834 {uri: 'N6de0e9f57cb049a9a4b1254d38cd7834'}),
# (:N91c87c2f5c4749f3bc0bfaef52255c7c {uri: 'N91c87c2f5c4749f3bc0bfaef52255c7c'}),
# (:N4a032629ab6c4a06b7e2ac443e12cfc2 {uri: 'N4a032629ab6c4a06b7e2ac443e12cfc2'}),
# (:wine {uri: 'http://www.w3.org/TR/2003/CR_owl_guide_20030818/wine'}),
# (:N8cdb2ac4531c4b9db2bacdd352d18e9a {uri: 'N8cdb2ac4531c4b9db2bacdd352d18e9a'}),
# (:Ncde6466538544d6285e2cdea5955554c {uri: 'Ncde6466538544d6285e2cdea5955554c'}),
# (:owl_Class {uri: 'http://www.w3.org/2002/07/owl_Class'}),
# (:Nacca3830c3fa45ffbfdc228df2adc04c {uri: 'Nacca3830c3fa45ffbfdc228df2adc04c'}),
# (:wine_MountEdenVineyard {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountEdenVineyard'}),
# (:wine_ChateauChevalBlancStEmilion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauChevalBlancStEmilion'}),
# (:N22f55dde86f942a1b39298b29c37d8b5 {uri: 'N22f55dde86f942a1b39298b29c37d8b5'}),
# (:Nb307157db095493595d1d8c83ff521fe {uri: 'Nb307157db095493595d1d8c83ff521fe'}),
# (:wine_BancroftChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BancroftChardonnay'}),
# (:Ncf6f865133ec4cbe877f7ccab051b4ed {uri: 'Ncf6f865133ec4cbe877f7ccab051b4ed'}),
# (:N3c8606d1dcd84a59821faf674cc3ba05 {uri: 'N3c8606d1dcd84a59821faf674cc3ba05'}),
# (:N1af6412db2e444589cfa9b781d6a7904 {uri: 'N1af6412db2e444589cfa9b781d6a7904'}),
# (:Nc922c674d4e64d5fa3c23a62fc6409c0 {uri: 'Nc922c674d4e64d5fa3c23a62fc6409c0'}),
# (:Nada2029298964625949501b94a1da580 {uri: 'Nada2029298964625949501b94a1da580'}),
# (:N8790f1931a6345d1b6db8a182021c5a0 {uri: 'N8790f1931a6345d1b6db8a182021c5a0'}),
# (:N756ba6fa73154736847a0c4ee31d808d {uri: 'N756ba6fa73154736847a0c4ee31d808d'}),
# (:N254a8c12820a480195b13be1af169858 {uri: 'N254a8c12820a480195b13be1af169858'}),
# (:N39286447946c489e805e825ebed73a18 {uri: 'N39286447946c489e805e825ebed73a18'}),
# (:wine_CaliforniaWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CaliforniaWine'}),
# (:wine_PulignyMontrachetWhiteBurgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PulignyMontrachetWhiteBurgundy'}),
# (:wine_CaliforniaRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CaliforniaRegion'}),
# (:wine_GaryFarrell {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GaryFarrell'}),
# (:wine_SelaksSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SelaksSauvignonBlanc'}),
# (:Nd9592f05f7354123bae62a332969f0e0 {uri: 'Nd9592f05f7354123bae62a332969f0e0'}),
# (:N8d3d66b9d45a4d0b93c7d9f357a8c624 {uri: 'N8d3d66b9d45a4d0b93c7d9f357a8c624'}),
# (:Ne89558d1e10b408490c65de27b105609 {uri: 'Ne89558d1e10b408490c65de27b105609'}),
# (:Nf31108be011e4ab4b6ee1796e2c994f0 {uri: 'Nf31108be011e4ab4b6ee1796e2c994f0'}),
# (:N6e3c99ed6b56461bb773dfabd5aadff9 {uri: 'N6e3c99ed6b56461bb773dfabd5aadff9'}),
# (:N472deec411c541e19a2c28e1a97e5bec {uri: 'N472deec411c541e19a2c28e1a97e5bec'}),
# (:Naf5b65bf3c594fa88820c5d6f24a3e09 {uri: 'Naf5b65bf3c594fa88820c5d6f24a3e09'}),
# (:wine_MeursaultRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MeursaultRegion'}),
# (:wine_ClosDeVougeot {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeVougeot'}),
# (:wine_ChateauLafiteRothschildPauillac {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauLafiteRothschildPauillac'}),
# (:wine_LoireRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LoireRegion'}),
# (:Nd9b4bfbebba84b57949549be2a951d9b {uri: 'Nd9b4bfbebba84b57949549be2a951d9b'}),
# (:N65ccbd186757488ab43239c83952a6a0 {uri: 'N65ccbd186757488ab43239c83952a6a0'}),
# (:N109778e0717146d48bc9864db300a02e {uri: 'N109778e0717146d48bc9864db300a02e'}),
# (:wine_madeFromGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}),
# (:wine_Sauternes {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sauternes'}),
# (:wine_WineTaste {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineTaste'}),
# (:wine_CorbansPrivateBinSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansPrivateBinSauvignonBlanc'}),
# (:Ncf064cace4b448c0a3e8445777b0c81b {uri: 'Ncf064cace4b448c0a3e8445777b0c81b'}),
# (:N9829351424e8460ab3212794ca7cccf3 {uri: 'N9829351424e8460ab3212794ca7cccf3'}),
# (:Nb22a349291734421aad193b3f7a6561d {uri: 'Nb22a349291734421aad193b3f7a6561d'}),
# (:Nd36910f347044d2b918b9feadc517b6c {uri: 'Nd36910f347044d2b918b9feadc517b6c'}),
# (:N713e528911344a258cc206a204d77df4 {uri: 'N713e528911344a258cc206a204d77df4'}),
# (:Nb32a148952054755996cd22f85a77d07 {uri: 'Nb32a148952054755996cd22f85a77d07'}),
# (:N82ca3a44755242adb8a9417408927a3c {uri: 'N82ca3a44755242adb8a9417408927a3c'}),
# (:N00320210a4b64fe7a94bf795181cd397 {uri: 'N00320210a4b64fe7a94bf795181cd397'}),
# (:wine_Semillon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Semillon'}),
# (:N2b3f52e414114463807dd95dd0c20eed {uri: 'N2b3f52e414114463807dd95dd0c20eed'}),
# (:Nf030a97c1a624979bb85de075bc07d7a {uri: 'Nf030a97c1a624979bb85de075bc07d7a'}),
# (:wine_SeanThackrey {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SeanThackrey'}),
# (:wine_CabernetFrancGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetFrancGrape'}),
# (:N1dadea248f6c4175be4bd8f52697e278 {uri: 'N1dadea248f6c4175be4bd8f52697e278'}),
# (:N85673cd646744604a423e7f26016cb78 {uri: 'N85673cd646744604a423e7f26016cb78'}),
# (:Nd68402d9a2d84073905d8dbfc5ba0f40 {uri: 'Nd68402d9a2d84073905d8dbfc5ba0f40'}),
# (:Na0865e49933841a181b04e970afd6d6a {uri: 'Na0865e49933841a181b04e970afd6d6a'}),
# (:N4a6f9d5b8a6240cb95cd795532d33384 {uri: 'N4a6f9d5b8a6240cb95cd795532d33384'}),
# (:N1026b0c5532d44dcb351fbb68b942759 {uri: 'N1026b0c5532d44dcb351fbb68b942759'}),
# (:N0577577c858144368f92d35c0fa18d0c {uri: 'N0577577c858144368f92d35c0fa18d0c'}),
# (:Nb088e7354fa745c69e34d226ea06a7b8 {uri: 'Nb088e7354fa745c69e34d226ea06a7b8'}),
# (:wine_CongressSprings {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CongressSprings'}),
# (:N3a04c3000d8b4ccc8fda6e8e69774b9e {uri: 'N3a04c3000d8b4ccc8fda6e8e69774b9e'}),
# (:Ne0afedffc00b4f39a6d122aec93b11f8 {uri: 'Ne0afedffc00b4f39a6d122aec93b11f8'}),
# (:wine_ToursRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ToursRegion'}),
# (:wine_MuscadetRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MuscadetRegion'}),
# (:N37753f2d411b48488c5016f81e4e394a {uri: 'N37753f2d411b48488c5016f81e4e394a'}),
# (:wine_Red {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Red'}),
# (:Ne45078786f8b4852800d34063687a3db {uri: 'Ne45078786f8b4852800d34063687a3db'}),
# (:Nd4e8b4066b1745a190fa453795f5fddf {uri: 'Nd4e8b4066b1745a190fa453795f5fddf'}),
# (:wine_StGenevieveTexasWhite {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StGenevieveTexasWhite'}),
# (:Nfad66f0e81e34e2eacc8d7b2d21ca609 {uri: 'Nfad66f0e81e34e2eacc8d7b2d21ca609'}),
# (:N4eba41cbf16a484fbee5d752a0abd204 {uri: 'N4eba41cbf16a484fbee5d752a0abd204'}),
# (:wine_AnjouRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AnjouRegion'}),
# (:Ncb3376f3baf946bd89a2e6ec5d504c71 {uri: 'Ncb3376f3baf946bd89a2e6ec5d504c71'}),
# (:wine_Bordeaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Bordeaux'}),
# (:wine_SantaCruzMountainsRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SantaCruzMountainsRegion'}),
# (:N81cc833c96de4e629a69519c8483d55d {uri: 'N81cc833c96de4e629a69519c8483d55d'}),
# (:Ndf86b06ab55249f29bfe7d10a9b532cb {uri: 'Ndf86b06ab55249f29bfe7d10a9b532cb'}),
# (:wine_hasColor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasColor'}),
# (:owl_Restriction {uri: 'http://www.w3.org/2002/07/owl_Restriction'}),
# (:Nf47d020476d54cbbb63c0c739ed38ba2 {uri: 'Nf47d020476d54cbbb63c0c739ed38ba2'}),
# (:N5c28c3489b9044318c8e66b39d8307ce {uri: 'N5c28c3489b9044318c8e66b39d8307ce'}),
# (:wine_Chardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Chardonnay'}),
# (:Nf3f7c15b4f71478e89e0dea4baf3d142 {uri: 'Nf3f7c15b4f71478e89e0dea4baf3d142'}),
# (:N8f34b1265e7343a2bf89ef79ca27ac45 {uri: 'N8f34b1265e7343a2bf89ef79ca27ac45'}),
# (:wine_Anjou {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Anjou'}),
# (:wine_ChiantiRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChiantiRegion'}),
# (:wine_WhitehallLane {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhitehallLane'}),
# (:N71a2ea7b1c584ad5be76983b8739441e {uri: 'N71a2ea7b1c584ad5be76983b8739441e'}),
# (:N4d6fdf62774841a1a536a414f10d6047 {uri: 'N4d6fdf62774841a1a536a414f10d6047'}),
# (:wine_StEmilionRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StEmilionRegion'}),
# (:wine_Burgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Burgundy'}),
# (:Nc85244746a4346d4a0339e9d0401a49b {uri: 'Nc85244746a4346d4a0339e9d0401a49b'}),
# (:wine_PetiteVerdotGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PetiteVerdotGrape'}),
# (:wine_CentralTexasRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CentralTexasRegion'}),
# (:N18382a83855c4c1daaa3fd0493ccb995 {uri: 'N18382a83855c4c1daaa3fd0493ccb995'}),
# (:wine_MariettaPetiteSyrah {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaPetiteSyrah'}),
# (:N3b851299885e4a1d8c3919b8df978865 {uri: 'N3b851299885e4a1d8c3919b8df978865'}),
# (:wine_MountadamChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamChardonnay'}),
# (:N72f58a284ec14ac8a7aeca1d606ced28 {uri: 'N72f58a284ec14ac8a7aeca1d606ced28'}),
# (:Nc85d6bd577f141788ea8fb0f227d6847 {uri: 'Nc85d6bd577f141788ea8fb0f227d6847'}),
# (:N88889563f186421cb3a7930d554ae52e {uri: 'N88889563f186421cb3a7930d554ae52e'}),
# (:N5ebd614ede2a46a2897ae6cede2c4a03 {uri: 'N5ebd614ede2a46a2897ae6cede2c4a03'}),
# (:Nd34fc615117343fcb2a58d6e170efdc2 {uri: 'Nd34fc615117343fcb2a58d6e170efdc2'}),
# (:N93d47fdafc6b4d4689274a8183e07e78 {uri: 'N93d47fdafc6b4d4689274a8183e07e78'}),
# (:Nfd7f44c7c2bf47b98e891a2053d04a7d {uri: 'Nfd7f44c7c2bf47b98e891a2053d04a7d'}),
# (:wine_CotesDOrRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CotesDOrRegion'}),
# (:N2f5340e8d249482e9c1f2d30dcd4ee49 {uri: 'N2f5340e8d249482e9c1f2d30dcd4ee49'}),
# (:N0284df4d2a5840ac917c95e9359d8c16 {uri: 'N0284df4d2a5840ac917c95e9359d8c16'}),
# (:wine_SemillonGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SemillonGrape'}),
# (:wine_hasSugar {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasSugar'}),
# (:wine_ChateauDeMeursault {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauDeMeursault'}),
# (:wine_WineSugar {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineSugar'}),
# (:N0cc1784752b940779b484e5332225533 {uri: 'N0cc1784752b940779b484e5332225533'}),
# (:N82ecbbe515ac49b8a76be2e91781b3ce {uri: 'N82ecbbe515ac49b8a76be2e91781b3ce'}),
# (:N6e4c67994d7a4599bad30fc07c66d303 {uri: 'N6e4c67994d7a4599bad30fc07c66d303'}),
# (:wine_MariettaZinfandel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaZinfandel'}),
# (:Ne1112cae0fb045fda263e6767121ce09 {uri: 'Ne1112cae0fb045fda263e6767121ce09'}),
# (:N935fbe5ded9f43d19981e6436be8dcb2 {uri: 'N935fbe5ded9f43d19981e6436be8dcb2'}),
# (:wine_SchlossVolrad {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossVolrad'}),
# (:wine_Winery {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Winery'}),
# (:Nbbccf9a915144e5c89e54d6ce6249ce1 {uri: 'Nbbccf9a915144e5c89e54d6ce6249ce1'}),
# (:Nae6fd44497334c2ba873156cc8f2df99 {uri: 'Nae6fd44497334c2ba873156cc8f2df99'}),
# (:wine_VentanaCheninBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_VentanaCheninBlanc'}),
# (:N5379deebeec748aca81dfbeb2cbfa7ac {uri: 'N5379deebeec748aca81dfbeb2cbfa7ac'}),
# (:Naa04b895831e425e8d5179dc57b64993 {uri: 'Naa04b895831e425e8d5179dc57b64993'}),
# (:wine_WhiteWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteWine'}),
# (:N23c7b876ee8b4bbcbf10a50c291ea370 {uri: 'N23c7b876ee8b4bbcbf10a50c291ea370'}),
# (:Nde9160ff7f7548cf9d84bfbd93c27e78 {uri: 'Nde9160ff7f7548cf9d84bfbd93c27e78'}),
# (:Nfbdf90a4ca864ac0b3459a2f9a7b85b9 {uri: 'Nfbdf90a4ca864ac0b3459a2f9a7b85b9'}),
# (:N062ba288a193464fafa38ec0f21ceac1 {uri: 'N062ba288a193464fafa38ec0f21ceac1'}),
# (:wine_VintageYear {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_VintageYear'}),
# (:Ne3fd3247b6f041e997fb670e2c76e834 {uri: 'Ne3fd3247b6f041e997fb670e2c76e834'}),
# (:N1606f4867b5d4f3680739ddd53d224f6 {uri: 'N1606f4867b5d4f3680739ddd53d224f6'}),
# (:wine_Forman {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Forman'}),
# (:N2d28c546e5ef4f6f9b6f6d2743596f3b {uri: 'N2d28c546e5ef4f6f9b6f6d2743596f3b'}),
# (:wine_SantaBarbaraRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SantaBarbaraRegion'}),
# (:wine_SweetWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SweetWine'}),
# (:wine_ItalianWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ItalianWine'}),
# (:wine_SeanThackreySiriusPetiteSyrah {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SeanThackreySiriusPetiteSyrah'}),
# (:N1558feead16c490098c14933327e1d9c {uri: 'N1558feead16c490098c14933327e1d9c'}),
# (:wine_MargauxRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MargauxRegion'}),
# (:N8f24f648ad1e4dfca6deb872169bbc07 {uri: 'N8f24f648ad1e4dfca6deb872169bbc07'}),
# (:N330f33f4c69f47798b97d045f8c700a1 {uri: 'N330f33f4c69f47798b97d045f8c700a1'}),
# (:wine_DryWhiteWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryWhiteWine'}),
# (:N9822a2f5d549436f9814c418c69caec4 {uri: 'N9822a2f5d549436f9814c418c69caec4'}),
# (:wine_Year1998 {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Year1998'}),
# (:N306a3f015d6949269a8e56bc48e168bc {uri: 'N306a3f015d6949269a8e56bc48e168bc'}),
# (:wine_CabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetSauvignon'}),
# (:Nbdb3c8973be445e09bb25f0e3bca0f08 {uri: 'Nbdb3c8973be445e09bb25f0e3bca0f08'}),
# (:N2dc7a73f16264a3f9b9166730ea2e6cb {uri: 'N2dc7a73f16264a3f9b9166730ea2e6cb'}),
# (:wine_Stonleigh {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Stonleigh'}),
# (:N69d94fa7efc741729bc74d0b6b28bd66 {uri: 'N69d94fa7efc741729bc74d0b6b28bd66'}),
# (:wine_GaryFarrellMerlot {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GaryFarrellMerlot'}),
# (:wine_WineColor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineColor'}),
# (:N05b7579cddc546c7bfee576e539e8db0 {uri: 'N05b7579cddc546c7bfee576e539e8db0'}),
# (:N76d9094a33724e02a563b7c67ca3634c {uri: 'N76d9094a33724e02a563b7c67ca3634c'}),
# (:N7a810898a2784275bc2f9dac769e1c8b {uri: 'N7a810898a2784275bc2f9dac769e1c8b'}),
# (:Nf8a1bffa68f9435bbd8246141b673368 {uri: 'Nf8a1bffa68f9435bbd8246141b673368'}),
# (:N6780a45b34e244bf97750ac30b08cd1b {uri: 'N6780a45b34e244bf97750ac30b08cd1b'}),
# (:N076efbcfbab94ac8b5bfff4a577dba3d {uri: 'N076efbcfbab94ac8b5bfff4a577dba3d'}),
# (:wine_White {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_White'}),
# (:wine_AlsatianWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AlsatianWine'}),
# (:Nc52bc5ab2f00440a9f460dc39175038a {uri: 'Nc52bc5ab2f00440a9f460dc39175038a'}),
# (:wine_BordeauxRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BordeauxRegion'}),
# (:N0383182451b34606bf5555ed0d8ab4d5 {uri: 'N0383182451b34606bf5555ed0d8ab4d5'}),
# (:N1653d77627b2408291cd5487123459b4 {uri: 'N1653d77627b2408291cd5487123459b4'}),
# (:owl_AllDifferent {uri: 'http://www.w3.org/2002/07/owl_AllDifferent'}),
# (:Nb59fd0fd2e8c4b0ea6b788abfce13ae4 {uri: 'Nb59fd0fd2e8c4b0ea6b788abfce13ae4'}),
# (:wine_TableWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_TableWine'}),
# (:N0178760d72c9434c9ce0a680a049b6d8 {uri: 'N0178760d72c9434c9ce0a680a049b6d8'}),
# (:wine_CortonMontrachet {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CortonMontrachet'}),
# (:wine_FrenchWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FrenchWine'}),
# (:wine_ChiantiClassico {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChiantiClassico'}),
# (:wine_SweetRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SweetRiesling'}),
# (:N0be6db841fd4485d91c77f488ae939d8 {uri: 'N0be6db841fd4485d91c77f488ae939d8'}),
# (:Nc34641291fb74176be1f463a317bf5ef {uri: 'Nc34641291fb74176be1f463a317bf5ef'}),
# (:wine_PageMillWineryCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PageMillWineryCabernetSauvignon'}),
# (:Nbd203f1c10cc47869a313deae4ccbcf8 {uri: 'Nbd203f1c10cc47869a313deae4ccbcf8'}),
# (:N6be5cb3ebfa54199a0752a11795209ba {uri: 'N6be5cb3ebfa54199a0752a11795209ba'}),
# (:N52dbfa5e15ef45d0984706e41fa5776d {uri: 'N52dbfa5e15ef45d0984706e41fa5776d'}),
# (:N7d5123e049164e6ca911840cb255c39a {uri: 'N7d5123e049164e6ca911840cb255c39a'}),
# (:wine_Full {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Full'}),
# (:wine_SchlossVolradTrochenbierenausleseRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossVolradTrochenbierenausleseRiesling'}),
# (:Nc5a79c8052d74825ad6db0d2eecbf54c {uri: 'Nc5a79c8052d74825ad6db0d2eecbf54c'}),
# (:Ndc1c792046f74c7b9849259dc2bb2f93 {uri: 'Ndc1c792046f74c7b9849259dc2bb2f93'}),
# (:Nd83631b4a5d04d06aa576b62045a8242 {uri: 'Nd83631b4a5d04d06aa576b62045a8242'}),
# (:N36481a6c7f904eb6aec4acdc3c952ec9 {uri: 'N36481a6c7f904eb6aec4acdc3c952ec9'}),
# (:Na99877f1817941b1a6fd43c28d38643c {uri: 'Na99877f1817941b1a6fd43c28d38643c'}),
# (:N6975679deb5d4546ae40a4c374d44f17 {uri: 'N6975679deb5d4546ae40a4c374d44f17'}),
# (:wine_TaylorPort {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_TaylorPort'}),
# (:N28411a7124f04e378a2a22b7bc816c85 {uri: 'N28411a7124f04e378a2a22b7bc816c85'}),
# (:N5ef7b793faa04b1892119bd42955e5ff {uri: 'N5ef7b793faa04b1892119bd42955e5ff'}),
# (:N25142698f9344706be8a586b77ce99e1 {uri: 'N25142698f9344706be8a586b77ce99e1'}),
# (:Nedb8897fa85849fdab413405c709fcd1 {uri: 'Nedb8897fa85849fdab413405c709fcd1'}),
# (:N3992cb33f4b149d38a32f208fd58a2ab {uri: 'N3992cb33f4b149d38a32f208fd58a2ab'}),
# (:N86bbde0ed2594a5b8e077b35ee5d2175 {uri: 'N86bbde0ed2594a5b8e077b35ee5d2175'}),
# (:N33125266be1b4ecab8abd370ce26e420 {uri: 'N33125266be1b4ecab8abd370ce26e420'}),
# (:wine_ElyseZinfandel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ElyseZinfandel'}),
# (:N6c9e6035371244c58ce5439569af9061 {uri: 'N6c9e6035371244c58ce5439569af9061'}),
# (:N9134058b6a5c41168939461b27e59886 {uri: 'N9134058b6a5c41168939461b27e59886'}),
# (:Nd3464a0ee6a44b3bbb6ab8e0ed2ae26d {uri: 'Nd3464a0ee6a44b3bbb6ab8e0ed2ae26d'}),
# (:Nd11f38c3fada429181d4b45af85c36ab {uri: 'Nd11f38c3fada429181d4b45af85c36ab'}),
# (:wine_ClosDeVougeotCotesDOr {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeVougeotCotesDOr'}),
# (:N0b2671e19f5240a49bb6f92417db0bb5 {uri: 'N0b2671e19f5240a49bb6f92417db0bb5'}),
# (:wine_RedBurgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RedBurgundy'}),
# (:Nf2c31d8515a740c99429661b26116daf {uri: 'Nf2c31d8515a740c99429661b26116daf'}),
# (:wine_SchlossRothermelTrochenbierenausleseRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossRothermelTrochenbierenausleseRiesling'}),
# (:Nc4f82f2845b048789f5b7fc386f0e7e7 {uri: 'Nc4f82f2845b048789f5b7fc386f0e7e7'}),
# (:wine_Moderate {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Moderate'}),
# (:wine_Beringer {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Beringer'}),
# (:Ne949d8d8116a446291a0bc0ec3f30409 {uri: 'Ne949d8d8116a446291a0bc0ec3f30409'}),
# (:wine_PinotBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotBlanc'}),
# (:N45a8dea4bdb749e5847186fca642451e {uri: 'N45a8dea4bdb749e5847186fca642451e'}),
# (:N0a4e71ffd45a46de8288cbeca7b93ef8 {uri: 'N0a4e71ffd45a46de8288cbeca7b93ef8'}),
# (:N5bbadee8d1f54f8cb5e29331afe95651 {uri: 'N5bbadee8d1f54f8cb5e29331afe95651'}),
# (:N836fc4f50a3a4246b8346b687f550f30 {uri: 'N836fc4f50a3a4246b8346b687f550f30'}),
# (:N85f27619ea2e48b19ca5b908076913ff {uri: 'N85f27619ea2e48b19ca5b908076913ff'}),
# (:wine_Handley {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Handley'}),
# (:wine_StonleighSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StonleighSauvignonBlanc'}),
# (:Ne5cacfade2b1472c94b547785f04eab3 {uri: 'Ne5cacfade2b1472c94b547785f04eab3'}),
# (:wine_ArroyoGrandeRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ArroyoGrandeRegion'}),
# (:N4862a3da4927464ca1b1e69677df128b {uri: 'N4862a3da4927464ca1b1e69677df128b'}),
# (:wine_Pauillac {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Pauillac'}),
# (:N8e2e3c0283854dceace9d8cc00c18534 {uri: 'N8e2e3c0283854dceace9d8cc00c18534'}),
# (:N2a1ca17d84ca4d1c98691c0878702b75 {uri: 'N2a1ca17d84ca4d1c98691c0878702b75'}),
# (:Nb4b61e16a71c45c3b07c406bc32aefd9 {uri: 'Nb4b61e16a71c45c3b07c406bc32aefd9'}),
# (:N2b909c0a73f744a19285280187cac867 {uri: 'N2b909c0a73f744a19285280187cac867'}),
# (:wine_MedocRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MedocRegion'}),
# (:N34c483d1dea54677886a5110c81dca16 {uri: 'N34c483d1dea54677886a5110c81dca16'}),
# (:Nd39db2293ad64451bda1418bb3f0135a {uri: 'Nd39db2293ad64451bda1418bb3f0135a'}),
# (:Nd68d9ca9bd0849889a8d7205f02403f3 {uri: 'Nd68d9ca9bd0849889a8d7205f02403f3'}),
# (:wine_WhiteBurgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteBurgundy'}),
# (:N9a721c5bd8e141f081a5a2c48b811357 {uri: 'N9a721c5bd8e141f081a5a2c48b811357'}),
# (:wine_KalinCellarsSemillon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_KalinCellarsSemillon'}),
# (:wine_CorbansDryWhiteRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansDryWhiteRiesling'}),
# (:Na0f0d8917bd146bc8d8d4632a7eb307f {uri: 'Na0f0d8917bd146bc8d8d4632a7eb307f'}),
# (:wine_SchlossRothermel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossRothermel'}),
# (:food_madeFromFruit {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/food_madeFromFruit'}),
# (:wine_Region {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Region'}),
# (:wine_LaneTannerPinotNoir {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LaneTannerPinotNoir'}),
# (:N9303f7b9228f41538b652f810a6375b7 {uri: 'N9303f7b9228f41538b652f810a6375b7'}),
# (:N779b05e1066f410bbca36d61548ce2d0 {uri: 'N779b05e1066f410bbca36d61548ce2d0'}),
# (:N00f7f47e0c894bf89cba34deea09c801 {uri: 'N00f7f47e0c894bf89cba34deea09c801'}),
# (:wine_WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineDescriptor'}),
# (:wine_Elyse {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Elyse'}),
# (:N8a5f1f622ece4fb1bf70d6de5ef17de1 {uri: 'N8a5f1f622ece4fb1bf70d6de5ef17de1'}),
# (:wine_WhiteNonSweetWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteNonSweetWine'}),
# (:N97e3683dae16472f85732a4ab22c48cc {uri: 'N97e3683dae16472f85732a4ab22c48cc'}),
# (:owl_FunctionalProperty {uri: 'http://www.w3.org/2002/07/owl_FunctionalProperty'}),
# (:Nb88bd35a9e0a4862be5886c1d86e9719 {uri: 'Nb88bd35a9e0a4862be5886c1d86e9719'}),
# (:N9867beafeec3444abb7e7c98ecc4fbe4 {uri: 'N9867beafeec3444abb7e7c98ecc4fbe4'}),
# (:wine_producesWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_producesWine'}),
# (:wine_IceWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_IceWine'}),
# (:wine_SantaCruzMountainVineyard {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SantaCruzMountainVineyard'}),
# (:N4810295dcb794995a4b54d90fcfa8a2a {uri: 'N4810295dcb794995a4b54d90fcfa8a2a'}),
# (:N9ed2e903fcf9423b9c8f28db943eef5e {uri: 'N9ed2e903fcf9423b9c8f28db943eef5e'}),
# (:wine_ChateauMargaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMargaux'}),
# (:wine_CabernetFranc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetFranc'}),
# (:wine_GermanyRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GermanyRegion'}),
# (:wine_PinotNoirGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotNoirGrape'}),
# (:wine_ZinfandelGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ZinfandelGrape'}),
# (:22_rdf_syntax_ns_nil {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}),
# (:N819006877a834cafa488ac175bf91724 {uri: 'N819006877a834cafa488ac175bf91724'}),
# (:N9429728441634299a898d67573672255 {uri: 'N9429728441634299a898d67573672255'}),
# (:N1a6aa72ab9dd4ca885c996b43f2a48d5 {uri: 'N1a6aa72ab9dd4ca885c996b43f2a48d5'}),
# (:N5fa3ebcaca464ae0ac2103e359024a45 {uri: 'N5fa3ebcaca464ae0ac2103e359024a45'}),
# (:N8a0c5776a25a40d99d301c932d63976a {uri: 'N8a0c5776a25a40d99d301c932d63976a'}),
# (:wine_Tours {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Tours'}),
# (:wine_PauillacRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PauillacRegion'}),
# (:wine_MariettaCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaCabernetSauvignon'}),
# (:wine_FormanCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FormanCabernetSauvignon'}),
# (:N1d7224a10ddb4797bc24003af8fead9f {uri: 'N1d7224a10ddb4797bc24003af8fead9f'}),
# (:Na913c6ae33f14a18996a9c877b91ba9c {uri: 'Na913c6ae33f14a18996a9c877b91ba9c'}),
# (:N6bb95b8e14e846148f1659a54c95fff1 {uri: 'N6bb95b8e14e846148f1659a54c95fff1'}),
# (:wine_Wine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Wine'}),
# (:wine_GermanWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GermanWine'}),
# (:wine_WhiteBordeaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteBordeaux'}),
# (:Nb5d70d20ab1f4345a875c6c07f01ae27 {uri: 'Nb5d70d20ab1f4345a875c6c07f01ae27'}),
# (:Ned776377f32c4b43a2ecdd7f2043e840 {uri: 'Ned776377f32c4b43a2ecdd7f2043e840'}),
# (:N82b9220c18b3432f89f932011749cbc2 {uri: 'N82b9220c18b3432f89f932011749cbc2'}),
# (:wine_RoseWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RoseWine'}),
# (:wine_AlsaceRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AlsaceRegion'}),
# (:owl_DatatypeProperty {uri: 'http://www.w3.org/2002/07/owl_DatatypeProperty'}),
# (:N39e6f54435684c5ea9442672b9b05ebd {uri: 'N39e6f54435684c5ea9442672b9b05ebd'}),
# (:Nbc79ab11aeb8472293fb1eee6fc5ca1c {uri: 'Nbc79ab11aeb8472293fb1eee6fc5ca1c'}),
# (:N2c175cc0dc3146d79255e57f1bd55de1 {uri: 'N2c175cc0dc3146d79255e57f1bd55de1'}),
# (:Nfa71f2a0438c49269c85413d2a0e607f {uri: 'Nfa71f2a0438c49269c85413d2a0e607f'}),
# (:N2f7179acb06d460da664e9470fca5e84 {uri: 'N2f7179acb06d460da664e9470fca5e84'}),
# (:N5b543953299c43f2b905caa2edbf044b {uri: 'N5b543953299c43f2b905caa2edbf044b'}),
# (:N6cd82ce9b39040d68015d8ad46d1e462 {uri: 'N6cd82ce9b39040d68015d8ad46d1e462'}),
# (:N1146c544dcde47d5acf50a4408cb1c99 {uri: 'N1146c544dcde47d5acf50a4408cb1c99'}),
# (:Ncc9058a17f9f4fd48d85b5f88e3ce24e {uri: 'Ncc9058a17f9f4fd48d85b5f88e3ce24e'}),
# (:Nb1f07216a5d74fbfbbef27876a6172f3 {uri: 'Nb1f07216a5d74fbfbbef27876a6172f3'}),
# (:N3b6a3878330743fc9688fc850e6a1d3b {uri: 'N3b6a3878330743fc9688fc850e6a1d3b'}),
# (:N389c60e0d87d4ab5a288f628b2a3c522 {uri: 'N389c60e0d87d4ab5a288f628b2a3c522'}),
# (:N014a42d02f934ef6bfd0f0eacd149182 {uri: 'N014a42d02f934ef6bfd0f0eacd149182'}),
# (:N8fdb76f18ceb45b09db8af0d0960165c {uri: 'N8fdb76f18ceb45b09db8af0d0960165c'}),
# (:wine_ChateauDYchemSauterne {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauDYchemSauterne'}),
# (:N7a2f41e523914a97992e2fbd309cdc12 {uri: 'N7a2f41e523914a97992e2fbd309cdc12'}),
# (:Naaa2f982de1541fd9d5b0fcfec6048f8 {uri: 'Naaa2f982de1541fd9d5b0fcfec6048f8'}),
# (:N765941ea49984b73b804764eb7f9d7ed {uri: 'N765941ea49984b73b804764eb7f9d7ed'}),
# (:N5eb458a016e748a69f8e831960b35b83 {uri: 'N5eb458a016e748a69f8e831960b35b83'}),
# (:Ndca43912bb94426c80e4d3182225445e {uri: 'Ndca43912bb94426c80e4d3182225445e'}),
# (:Nef0c03cca79940e7ac6c4bcc7503ab65 {uri: 'Nef0c03cca79940e7ac6c4bcc7503ab65'}),
# (:Ne858ce1499b0482eb1d8cd4216c4b0a9 {uri: 'Ne858ce1499b0482eb1d8cd4216c4b0a9'}),
# (:wine_PortugalRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PortugalRegion'}),
# (:wine_LongridgeMerlot {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LongridgeMerlot'}),
# (:Nfdaded8e219e45d3b577b46416d07d8a {uri: 'Nfdaded8e219e45d3b577b46416d07d8a'}),
# (:Nc7233cad969443c69174f5ed4e79d4e4 {uri: 'Nc7233cad969443c69174f5ed4e79d4e4'}),
# (:wine_ChateauMorgonBeaujolais {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMorgonBeaujolais'}),
# (:N1a87c91f2c134efe8365fc43e4b7b90a {uri: 'N1a87c91f2c134efe8365fc43e4b7b90a'}),
# (:Nf96fe5fa206347cab4f331efdd02730a {uri: 'Nf96fe5fa206347cab4f331efdd02730a'}),
# (:wine_CortonMontrachetWhiteBurgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CortonMontrachetWhiteBurgundy'}),
# (:XMLSchema_positiveInteger {uri: 'http://www.w3.org/2001/XMLSchema_positiveInteger'}),
# (:N8d3249aadc49415481fe6a03c3ef515d {uri: 'N8d3249aadc49415481fe6a03c3ef515d'}),
# (:Ndfb56b82820a4893a2c879232ba188f4 {uri: 'Ndfb56b82820a4893a2c879232ba188f4'}),
# (:N00755aa3bfcb4898939e281adcbef16c {uri: 'N00755aa3bfcb4898939e281adcbef16c'}),
# (:Nf66c2cbbc57e424aa4f45a1936d885c9 {uri: 'Nf66c2cbbc57e424aa4f45a1936d885c9'}),
# (:N51bc141e9dde414daf5a262e028762f4 {uri: 'N51bc141e9dde414daf5a262e028762f4'}),
# (:N7f8be366b7724f4cbfc2ca319325653c {uri: 'N7f8be366b7724f4cbfc2ca319325653c'}),
# (:N53dc9428d6d848289eaec8b631b54d63 {uri: 'N53dc9428d6d848289eaec8b631b54d63'}),
# (:wine_SancerreRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SancerreRegion'}),
# (:N37b5b449a6b7495696551021e18fd868 {uri: 'N37b5b449a6b7495696551021e18fd868'}),
# (:Nbca6ad70bf2645509f2998d333ff0187 {uri: 'Nbca6ad70bf2645509f2998d333ff0187'}),
# (:food_Grape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/food_Grape'}),
# (:N02cbeb4d53b94b5488062396d26502d2 {uri: 'N02cbeb4d53b94b5488062396d26502d2'}),
# (:wine_Muscadet {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Muscadet'}),
# (:N580f163d6caa423080931ebd966eb64e {uri: 'N580f163d6caa423080931ebd966eb64e'}),
# (:Ndd3fd7b1748b4cb7bbc918a579503340 {uri: 'Ndd3fd7b1748b4cb7bbc918a579503340'}),
# (:N35cd0b7a2ff04ce894465b6e3141f4bb {uri: 'N35cd0b7a2ff04ce894465b6e3141f4bb'}),
# (:Ndad5d4c6c462447681f71ff2f8e373e4 {uri: 'Ndad5d4c6c462447681f71ff2f8e373e4'}),
# (:wine_Beaujolais {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Beaujolais'}),
# (:Nf83985b8670c45f99a4b4d8994f8c7bd {uri: 'Nf83985b8670c45f99a4b4d8994f8c7bd'}),
# (:Ne63170efcc9b4ef191e8fbdaa4f2eef2 {uri: 'Ne63170efcc9b4ef191e8fbdaa4f2eef2'}),
# (:N80af51cfc8ab4005b2bc0f1385a1a000 {uri: 'N80af51cfc8ab4005b2bc0f1385a1a000'}),
# (:wine_EdnaValleyRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_EdnaValleyRegion'}),
# (:N9609ce5d3559488fbffb8c88e17326e3 {uri: 'N9609ce5d3559488fbffb8c88e17326e3'}),
# (:Nc63ba36cd9b34a64aa6c5e7e398401d4 {uri: 'Nc63ba36cd9b34a64aa6c5e7e398401d4'}),
# (:wine_hasWineDescriptor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasWineDescriptor'}),
# (:Nb7b2a88073a94b4699c3dbad33e8f528 {uri: 'Nb7b2a88073a94b4699c3dbad33e8f528'}),
# (:N2ba73f1254be4e8f90f0f8d53b34bde8 {uri: 'N2ba73f1254be4e8f90f0f8d53b34bde8'}),
# (:N4282cbeff68b498caa2811194bae9603 {uri: 'N4282cbeff68b498caa2811194bae9603'}),
# (:N3b424cbeb6994edba70feae911436e2f {uri: 'N3b424cbeb6994edba70feae911436e2f'}),
# (:wine_TexasRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_TexasRegion'}),
# (:wine_PetiteSyrahGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PetiteSyrahGrape'}),
# (:N9cbb277c665d443c88e17e0933ea2067 {uri: 'N9cbb277c665d443c88e17e0933ea2067'}),
# (:Nd11d32b5bf6241b18e7d077590f97f18 {uri: 'Nd11d32b5bf6241b18e7d077590f97f18'}),
# (:N6ad13fe724634107943b7ec525b7a32c {uri: 'N6ad13fe724634107943b7ec525b7a32c'}),
# (:wine_AmericanWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AmericanWine'}),
# (:N8c88f4c30fe848baac9fb870dff5cfc0 {uri: 'N8c88f4c30fe848baac9fb870dff5cfc0'}),
# (:N3375c46a41e14946b89ea1f1a7f0e96f {uri: 'N3375c46a41e14946b89ea1f1a7f0e96f'}),
# (:N5dc0565e416a45208a0dc721a3fe9082 {uri: 'N5dc0565e416a45208a0dc721a3fe9082'}),
# (:Nc1f3df815e6a48b5838cf41d4cfdd6ae {uri: 'Nc1f3df815e6a48b5838cf41d4cfdd6ae'}),
# (:N4072fdf9004f4806939e7d907d883747 {uri: 'N4072fdf9004f4806939e7d907d883747'}),
# (:wine_SevreEtMaineMuscadet {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SevreEtMaineMuscadet'}),
# (:wine_Strong {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Strong'}),
# (:N871a4e31fff940618a1b10263d445ee4 {uri: 'N871a4e31fff940618a1b10263d445ee4'}),
# (:wine_NewZealandRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_NewZealandRegion'}),
# (:Ndd2c1c24e51b48619e5f639de9eb92f2 {uri: 'Ndd2c1c24e51b48619e5f639de9eb92f2'}),
# (:wine_CentralCoastRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CentralCoastRegion'}),
# (:N148e6e663c1a4989b9c8d0daba2a8415 {uri: 'N148e6e663c1a4989b9c8d0daba2a8415'}),
# (:wine_Selaks {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Selaks'}),
# (:N8c6bf04e528a4d45ace4298fdcaf01ff {uri: 'N8c6bf04e528a4d45ace4298fdcaf01ff'}),
# (:wine_PinotBlancGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotBlancGrape'}),
# (:N94ccfa7a4d5c4a689f57cc10418548d8 {uri: 'N94ccfa7a4d5c4a689f57cc10418548d8'}),
# (:Naff135d444244d249d809ffefc0ae00d {uri: 'Naff135d444244d249d809ffefc0ae00d'}),
# (:wine_PageMillWinery {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PageMillWinery'}),
# (:wine_FrenchRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FrenchRegion'}),
# (:wine_SauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SauvignonBlanc'}),
# (:Nd42fff33d99c426c96efc0a34eedce4b {uri: 'Nd42fff33d99c426c96efc0a34eedce4b'}),
# (:N8a8dbe9399154ca6acd6e0a8f9a307d7 {uri: 'N8a8dbe9399154ca6acd6e0a8f9a307d7'}),
# (:N495a57e555624d79a0a12270f27e4bc8 {uri: 'N495a57e555624d79a0a12270f27e4bc8'}),
# (:wine_Light {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Light'}),
# (:N4cd88ee697f04342904e29d21a77329f {uri: 'N4cd88ee697f04342904e29d21a77329f'}),
# (:Neaa78d65980c40129f547519db80c851 {uri: 'Neaa78d65980c40129f547519db80c851'}),
# (:Ne86520f4621c4bc1bc45e0391756cf41 {uri: 'Ne86520f4621c4bc1bc45e0391756cf41'}),
# (:Nef977437071140029cde34a882f29656 {uri: 'Nef977437071140029cde34a882f29656'}),
# (:Nee796117cfe34348b650b7185432e791 {uri: 'Nee796117cfe34348b650b7185432e791'}),
# (:N1ce08d3f175f4c6893197af1740fc589 {uri: 'N1ce08d3f175f4c6893197af1740fc589'}),
# (:N488fd43760c84559acea029a91e96e2d {uri: 'N488fd43760c84559acea029a91e96e2d'}),
# (:wine_GamayGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GamayGrape'}),
# (:N0ddd2646072a466e83b0fc78601f6342 {uri: 'N0ddd2646072a466e83b0fc78601f6342'}),
# (:wine_ClosDeLaPoussie {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeLaPoussie'}),
# (:Na602c2d97c4944eb8c26c1be4aa27f12 {uri: 'Na602c2d97c4944eb8c26c1be4aa27f12'}),
# (:Na5770c0a3cca45adbc4326e92351d549 {uri: 'Na5770c0a3cca45adbc4326e92351d549'}),
# (:wine_ChateauChevalBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauChevalBlanc'}),
# (:wine_SemillonOrSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SemillonOrSauvignonBlanc'}),
# (:Ne287a406db3b42ea90fe384aa28d67ad {uri: 'Ne287a406db3b42ea90fe384aa28d67ad'}),
# (:Na26431e2320f4a3c92b6fbdfec3e5450 {uri: 'Na26431e2320f4a3c92b6fbdfec3e5450'}),
# (:N98baafe4121e4a19ab4919bdb90aa047 {uri: 'N98baafe4121e4a19ab4919bdb90aa047'}),
# (:N3dc8399595c04f368c8d8fb3a8c2250b {uri: 'N3dc8399595c04f368c8d8fb3a8c2250b'}),
# (:N65127f72099f47ecbe6aa4046735d87c {uri: 'N65127f72099f47ecbe6aa4046735d87c'}),
# (:wine_LaneTanner {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LaneTanner'}),
# (:wine_CotesDOr {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CotesDOr'}),
# (:N2061ca1224f5437c8501d512768fa1b3 {uri: 'N2061ca1224f5437c8501d512768fa1b3'}),
# (:Nbc0c0da3de084eae86673f440adf0502 {uri: 'Nbc0c0da3de084eae86673f440adf0502'}),
# (:Ndd02e45a5f1141eda257a243f0aa1fea {uri: 'Ndd02e45a5f1141eda257a243f0aa1fea'}),
# (:wine_WineFlavor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineFlavor'}),
# (:N7e555c1d2db245c6ae92483317c09ccb {uri: 'N7e555c1d2db245c6ae92483317c09ccb'}),
# (:wine_hasBody {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasBody'}),
# (:wine_ChateauMorgon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMorgon'}),
# (:N4fa8b15988ee4eb8aa532e53a0edbf82 {uri: 'N4fa8b15988ee4eb8aa532e53a0edbf82'}),
# (:Nd467950ac4e04469b0ffccaf0ec2738e {uri: 'Nd467950ac4e04469b0ffccaf0ec2738e'}),
# (:wine_MountadamRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamRiesling'}),
# (:N1703365535ee4437879ec7fab7b102a4 {uri: 'N1703365535ee4437879ec7fab7b102a4'}),
# (:Nd887ace838b843ceb4d1aec3ed201da3 {uri: 'Nd887ace838b843ceb4d1aec3ed201da3'}),
# (:N02320a2d9062446789b6c429008b5173 {uri: 'N02320a2d9062446789b6c429008b5173'}),
# (:wine_PetiteSyrah {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PetiteSyrah'}),
# (:N56f21b5d1523402d92dc7cde9076c65b {uri: 'N56f21b5d1523402d92dc7cde9076c65b'}),
# (:wine_EarlyHarvest {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_EarlyHarvest'}),
# (:Na2acda67d602476c9a9f25ce52df9dab {uri: 'Na2acda67d602476c9a9f25ce52df9dab'}),
# (:N357f0f97e5a74e4d809dbe400d32493a {uri: 'N357f0f97e5a74e4d809dbe400d32493a'}),
# (:Nd00d3c1afaad46a1ac18bcb22b5448eb {uri: 'Nd00d3c1afaad46a1ac18bcb22b5448eb'}),
# (:Nd424e59809cc4246b1a854340f7c0dd1 {uri: 'Nd424e59809cc4246b1a854340f7c0dd1'}),
# (:wine_FullBodiedWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FullBodiedWine'}),
# (:wine_PulignyMontrachet {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PulignyMontrachet'}),
# (:N7f716fa1787342b8bfcbd9db90680a49 {uri: 'N7f716fa1787342b8bfcbd9db90680a49'}),
# (:N42e2ad7d55274145a45d94ee5d0c6cec {uri: 'N42e2ad7d55274145a45d94ee5d0c6cec'}),
# (:wine_SangioveseGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SangioveseGrape'}),
# (:Ndbd6eb8bf28b4716af5227481dfa34db {uri: 'Ndbd6eb8bf28b4716af5227481dfa34db'}),
# (:N7dd19a7f740742a1bc43f424776a9b19 {uri: 'N7dd19a7f740742a1bc43f424776a9b19'}),
# (:N6705d10772f34f418b17bb4412b6dead {uri: 'N6705d10772f34f418b17bb4412b6dead'}),
# (:Nfc5f50576f094c439ffb851b3580a39f {uri: 'Nfc5f50576f094c439ffb851b3580a39f'}),
# (:N918a8dd5acab44f3a0941cc2784dad9a {uri: 'N918a8dd5acab44f3a0941cc2784dad9a'}),
# (:wine_SaucelitoCanyon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SaucelitoCanyon'}),
# (:Ncbd0557b893d43d8a6883bb272c5482c {uri: 'Ncbd0557b893d43d8a6883bb272c5482c'}),
# (:wine_Mountadam {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Mountadam'}),
# (:Na09b3ddae3b54021bd3645db5a0e4947 {uri: 'Na09b3ddae3b54021bd3645db5a0e4947'}),
# (:wine_ChateauDYchem {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauDYchem'}),
# (:wine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine'}),
# (:N918cc68cf20044089615639d21d95fe8 {uri: 'N918cc68cf20044089615639d21d95fe8'}),
# (:wine_Bancroft {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Bancroft'}),
# (:wine_PinotNoir {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotNoir'}),
# (:Nbe453afb5a544914b1ffa6017440aa30 {uri: 'Nbe453afb5a544914b1ffa6017440aa30'}),
# (:Nb21ebd3a37d84ce79352d706819ad049 {uri: 'Nb21ebd3a37d84ce79352d706819ad049'}),
# (:wine_LateHarvest {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LateHarvest'}),
# (:N00b8eac89a5f4520b9b33ef890e0f7ed {uri: 'N00b8eac89a5f4520b9b33ef890e0f7ed'}),
# (:wine_StGenevieve {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StGenevieve'}),
# (:wine_Gamay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Gamay'}),
# (:Nb42a9bc9817c4ca5938c5d8324cff7ce {uri: 'Nb42a9bc9817c4ca5938c5d8324cff7ce'}),
# (:wine_Medoc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medoc'}),
# (:N2a035fa3a93443309c27d3533c8cc504 {uri: 'N2a035fa3a93443309c27d3533c8cc504'}),
# (:N6049c9418a7244f1a43d7ae6220e61e8 {uri: 'N6049c9418a7244f1a43d7ae6220e61e8'}),
# (:N9621c7a5f9374ae4ba4af2392f32bea5 {uri: 'N9621c7a5f9374ae4ba4af2392f32bea5'}),
# (:N2b07aebaafa34dcd9dc331655055d0e7 {uri: 'N2b07aebaafa34dcd9dc331655055d0e7'}),
# (:N9fead8d237844550ad15a5492327a302 {uri: 'N9fead8d237844550ad15a5492327a302'}),
# (:N02cf0e5d35b949bbbea5bb1281e33396 {uri: 'N02cf0e5d35b949bbbea5bb1281e33396'}),
# (:food {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/food'}),
# (:N1977eac05ee243848d50aa18543c31d6 {uri: 'N1977eac05ee243848d50aa18543c31d6'}),
# (:wine_DessertWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DessertWine'}),
# (:Nf1d24a88de9340038ca9585a20e1a3f4 {uri: 'Nf1d24a88de9340038ca9585a20e1a3f4'}),
# (:wine_StEmilion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StEmilion'}),
# (:wine_PeterMccoy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PeterMccoy'}),
# (:N06379e22e5a94c6fb2fc1fd73a492681 {uri: 'N06379e22e5a94c6fb2fc1fd73a492681'}),
# (:wine_Sancerre {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sancerre'}),
# (:N4212dc4161d241de8f4f5059bac6e9c7 {uri: 'N4212dc4161d241de8f4f5059bac6e9c7'}),
# (:Nb858a9224d364f3ba3925618d17ca625 {uri: 'Nb858a9224d364f3ba3925618d17ca625'}),
# (:N64b8347294664e92b1566f741c374a7f {uri: 'N64b8347294664e92b1566f741c374a7f'}),
# (:Nc3258092afc44daa8b52293d80c84bf9 {uri: 'Nc3258092afc44daa8b52293d80c84bf9'}),
# (:wine_ChardonnayGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChardonnayGrape'}),
# (:wine_SevreEtMaine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SevreEtMaine'}),
# (:N71d1daa99b204d7f94af08107f77e4ce {uri: 'N71d1daa99b204d7f94af08107f77e4ce'}),
# (:N4b9d998255ea49e9b758dc3ce6483334 {uri: 'N4b9d998255ea49e9b758dc3ce6483334'}),
# (:wine_RedBordeaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RedBordeaux'}),
# (:wine_ChateauMargauxWinery {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMargauxWinery'}),
# (:wine_hasMaker {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasMaker'}),
# (:N8084fcf11ba246d5851fe361f9798d57 {uri: 'N8084fcf11ba246d5851fe361f9798d57'}),
# (:N52c1fa6860044a9ab5acd36076cd42c8 {uri: 'N52c1fa6860044a9ab5acd36076cd42c8'}),
# (:N843bf081e2ed4f4f92c7044ebab7bf23 {uri: 'N843bf081e2ed4f4f92c7044ebab7bf23'}),
# (:N294608af584049b49d4d9a433e3aa837 {uri: 'N294608af584049b49d4d9a433e3aa837'}),
# (:wine_Margaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Margaux'}),
# (:wine_OffDry {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_OffDry'}),
# (:Naec3ec0048274f7099a80f6d04b239de {uri: 'Naec3ec0048274f7099a80f6d04b239de'}),
# (:Nffe15d25feab4a9da9d40b058db9250e {uri: 'Nffe15d25feab4a9da9d40b058db9250e'}),
# (:owl_TransitiveProperty {uri: 'http://www.w3.org/2002/07/owl_TransitiveProperty'}),
# (:N09367e0f5834462ab458a698c5e24ce2 {uri: 'N09367e0f5834462ab458a698c5e24ce2'}),
# (:wine_DryRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryRiesling'}),
# (:Nadaa5b3c452145f180005ab0865a044a {uri: 'Nadaa5b3c452145f180005ab0865a044a'}),
# (:Nd3d9ea33041947edb5abc6930c849a58 {uri: 'Nd3d9ea33041947edb5abc6930c849a58'}),
# (:wine_WhiteTableWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteTableWine'}),
# (:N9a507ada3fdb47dd875429aad0fc7349 {uri: 'N9a507ada3fdb47dd875429aad0fc7349'}),
# (:Nc706c76b12894058a8904ff3f4ecfb86 {uri: 'Nc706c76b12894058a8904ff3f4ecfb86'}),
# (:N01c14502720f4493a23377b4ba7db1f6 {uri: 'N01c14502720f4493a23377b4ba7db1f6'}),
# (:Nd51ca066472b4b02a915535a7ad88d5e {uri: 'Nd51ca066472b4b02a915535a7ad88d5e'}),
# (:wine_madeIntoWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeIntoWine'}),
# (:wine_RedWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RedWine'}),
# (:wine_CabernetSauvignonGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetSauvignonGrape'}),
# (:wine_WhiteLoire {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteLoire'}),
# (:Nbf580f1e145f44eab34fafa697e59b6c {uri: 'Nbf580f1e145f44eab34fafa697e59b6c'}),
# (:wine_DryRedWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryRedWine'}),
# (:wine_BeaujolaisRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BeaujolaisRegion'}),
# (:N16070f19956142488960a47a7ee7e8ba {uri: 'N16070f19956142488960a47a7ee7e8ba'}),
# (:N51f1769a4bd146d8be27617925f641cd {uri: 'N51f1769a4bd146d8be27617925f641cd'}),
# (:wine_SouthAustraliaRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SouthAustraliaRegion'}),
# (:N498891101c11490cb95250489a41ab94 {uri: 'N498891101c11490cb95250489a41ab94'}),
# (:N9d3d975657a54fad8767e3cbeb6c9e7c {uri: 'N9d3d975657a54fad8767e3cbeb6c9e7c'}),
# (:N64c30b655d9e4851a1d68aa9fd2dc201 {uri: 'N64c30b655d9e4851a1d68aa9fd2dc201'}),
# (:wine_BourgogneRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BourgogneRegion'}),
# (:N22cfb7a00ab9463791ebde393d920663 {uri: 'N22cfb7a00ab9463791ebde393d920663'}),
# (:N2530de78791b48989331b21293f16e03 {uri: 'N2530de78791b48989331b21293f16e03'}),
# (:N74dbd64edf5f4a6b8bb0446993418803 {uri: 'N74dbd64edf5f4a6b8bb0446993418803'}),
# (:N63020e97f3cc4f3c806c7b8cf197c1cf {uri: 'N63020e97f3cc4f3c806c7b8cf197c1cf'}),
# (:wine_Loire {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Loire'}),
# (:wine_SaucelitoCanyonZinfandel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SaucelitoCanyonZinfandel'}),
# (:N237dfd988187437fb0ac76b847d747ea {uri: 'N237dfd988187437fb0ac76b847d747ea'}),
# ...
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansPrivateBinSauvignonBlanc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Dry'}) CREATE (a)_[:wine_hasSugar]_>(b)
# MATCH (a {uri: 'N4810295dcb794995a4b54d90fcfa8a2a'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N5c28c3489b9044318c8e66b39d8307ce'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasFlavor'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'N4a6f9d5b8a6240cb95cd795532d33384'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N9621c7a5f9374ae4ba4af2392f32bea5'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N6e001948bf3a4071a8c38f9d539d2efa'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_locatedIn'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'N98baafe4121e4a19ab4919bdb90aa047'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N330f33f4c69f47798b97d045f8c700a1'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Nef977437071140029cde34a882f29656'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasFlavor'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChiantiClassico'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}) CREATE (a)_[:wine_hasBody]_>(b)
# MATCH (a {uri: 'N07b8c9e5d1c74bd583fd17e41295f059'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Nf96fe5fa206347cab4f331efdd02730a'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'N2a1ca17d84ca4d1c98691c0878702b75'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasFlavor'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeLaPoussieSancerre'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sancerre'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Nf47d020476d54cbbb63c0c739ed38ba2'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SelaksSauvignonBlanc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Dry'}) CREATE (a)_[:wine_hasSugar]_>(b)
# MATCH (a {uri: 'N8fdb76f18ceb45b09db8af0d0960165c'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteWine'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LongridgeMerlot'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Light'}) CREATE (a)_[:wine_hasBody]_>(b)
# MATCH (a {uri: 'Nc87c104abf8446658d4b2a5fce763a7e'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_White'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'Nd68402d9a2d84073905d8dbfc5ba0f40'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_White'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'Na3fdedd1228a4c8da8100e85b5c97546'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Light'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'Nfbb714dcf0f746c39cba4e59ad2d6f2f'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CotesDOrRegion'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BourgogneRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'N0a4e71ffd45a46de8288cbeca7b93ef8'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GamayGrape'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineGrape'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamPinotNoir'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Mountadam'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasBody'}), (b {uri: 'http://www.w3.org/2002/07/owl_FunctionalProperty'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N86c938666f34409983a0dc98d933e731'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaZinfandel'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SonomaRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'N51f1769a4bd146d8be27617925f641cd'}), (b {uri: 'http://www.w3.org/2002/07/owl_AllDifferent'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Delicate'}), (b {uri: 'http://www.w3.org/2002/07/owl_Thing'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N076efbcfbab94ac8b5bfff4a577dba3d'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N2b909c0a73f744a19285280187cac867'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'N3992cb33f4b149d38a32f208fd58a2ab'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Red'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CotturiZinfandel'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Dry'}) CREATE (a)_[:wine_hasSugar]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/CR_owl_guide_20030818/wine'}), (b {uri: 'http://www.w3.org/2002/07/owl_Ontology'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N23c7b876ee8b4bbcbf10a50c291ea370'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Nd83631b4a5d04d06aa576b62045a8242'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossVolradTrochenbierenausleseRiesling'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossVolrad'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'N3b6a3878330743fc9688fc850e6a1d3b'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineGrape'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/food_Grape'}) CREATE (a)_[:rdf_schema_subClassOf]_>(b)
# MATCH (a {uri: 'N9ed2e903fcf9423b9c8f28db943eef5e'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Cotturi'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'N6692f3852de84a4d90a7cf1b1a712502'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N765941ea49984b73b804764eb7f9d7ed'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sweet'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Elyse'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Winery'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_adjacentRegion'}), (b {uri: 'http://www.w3.org/2002/07/owl_ObjectProperty'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansPrivateBinSauvignonBlanc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_NewZealandRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'N85c934b1139d4879b9d1aeb9287da0dc'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Nf3f7c15b4f71478e89e0dea4baf3d142'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'Nf08945c86fa34e9d8c8da8dd92afd5bf'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Nd34fc615117343fcb2a58d6e170efdc2'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SauvignonBlancGrape'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SelaksIceWine'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Selaks'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamRiesling'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryRiesling'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sweet'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineSugar'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_White'}), (b {uri: 'http://www.w3.org/2002/07/owl_Thing'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SantaCruzMountainsRegion'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CaliforniaRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'N5379deebeec748aca81dfbeb2cbfa7ac'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CheninBlancGrape'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'Nf66c2cbbc57e424aa4f45a1936d885c9'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasColor'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamRiesling'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Delicate'}) CREATE (a)_[:wine_hasFlavor]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PulignyMontrachetWhiteBurgundy'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Moderate'}) CREATE (a)_[:wine_hasFlavor]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountEdenVineyardEstatePinotNoir'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Full'}) CREATE (a)_[:wine_hasBody]_>(b)
# MATCH (a {uri: 'N9829351424e8460ab3212794ca7cccf3'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Full'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotNoir'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DessertWine'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N836fc4f50a3a4246b8346b687f550f30'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_locatedIn'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'N014175bce8324c99baf6e86a96611a98'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N330f33f4c69f47798b97d045f8c700a1'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GermanWine'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CaliforniaRegion'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Region'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N062ba288a193464fafa38ec0f21ceac1'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Loire'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'N389c60e0d87d4ab5a288f628b2a3c522'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Delicate'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'Nc922c674d4e64d5fa3c23a62fc6409c0'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'Ne949d8d8116a446291a0bc0ec3f30409'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SancerreRegion'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'N4d6fdf62774841a1a536a414f10d6047'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'Nb1f0e8293d3c438790ec004bc0c3febf'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_VentanaCheninBlanc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CentralCoastRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FormanChardonnay'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Chardonnay'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Nd5b3f9d8f7b54d86ab466aeeb3143387'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Red'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'Nd3d9ea33041947edb5abc6930c849a58'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FrenchRegion'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'N7a810898a2784275bc2f9dac769e1c8b'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'N8c6bf04e528a4d45ace4298fdcaf01ff'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Elyse'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'Na41c137f1bf54a26aafda641dbd2ae70'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteWine'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'Nee9fb63870e94cfb942188188c9c954f'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CongressSprings'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Winery'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Nfa71f2a0438c49269c85413d2a0e607f'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Wine'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SonomaRegion'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Region'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SemillonGrape'}), (b {uri: 'http://www.w3.org/2002/07/owl_Thing'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N6c9e6035371244c58ce5439569af9061'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BancroftChardonnay'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_NapaRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SelaksSauvignonBlanc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Moderate'}) CREATE (a)_[:wine_hasFlavor]_>(b)
# MATCH (a {uri: 'N262db418f9f24d8eb4cbc354ee9e4a01'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# CPU times: user 101 ms, sys: 7.89 ms, total: 109 ms
# Wall time: 107 ms

# %% [markdown]
# ### TuringDB v1

# %%
def rdf_to_cypher_v1(rdf_file):
    from rdflib import Graph
    
    g = Graph()
    g.parse(rdf_file)
    
    # Collect nodes
    nodes = {str(s) for s, _, _ in g} | {str(o) for _, _, o in g if not isinstance(o, str) or o.startswith('http')}
    node_to_var = {node: f"n{i}" for i, node in enumerate(nodes)}
    
    parts = []
    
    # Add all nodes
    for node in nodes:
        var = node_to_var[node]
        label = node.split('/')[-1]
        # Prefix label with underscore if it starts with a digit
        if label and label[0].isdigit():
            label = 'ID_' + label
        parts.append(f"({var}:{label} {{uri: '{node}'}})")
    
    # Add all edges
    for s, p, o in g:
        if not isinstance(o, str) or o.startswith('http'):
            s_var = node_to_var[str(s)]
            o_var = node_to_var[str(o)]
            pred = str(p).split('/')[-1]
            # Prefix predicate with underscore if it starts with a digit
            if pred and pred[0].isdigit():
                pred = 'ID_' + pred
            parts.append(f"({s_var})-[:{pred}]->({o_var})")
    
    return "CREATE " + ",\n".join(parts)

# %%
def sanitize_identifier(s):
    """Sanitize identifiers (labels, relationship types, property names)"""
    if not s:
        return "ID_empty"
    
    # Replace invalid characters with underscores
    s = s.replace('#', '_').replace('-', '_').replace('/', '_').replace('.', '_')
    
    # Prefix with ID_ if starts with digit or underscore
    if s[0].isdigit() or s[0] == '_':
        s = 'ID_' + s
    
    # Remove any other non-alphanumeric characters except underscores
    s = ''.join(c if c.isalnum() or c == '_' else '_' for c in s)
    
    return s

def sanitize_value(s):
    """Sanitize property values (escape quotes)"""
    return s.replace("'", "\\'").replace('"', '\\"')

def rdf_to_cypher_v1(rdf_file):
    from rdflib import Graph
    
    g = Graph()
    g.parse(rdf_file)
    
    # Collect nodes
    nodes = {str(s) for s, _, _ in g} | {str(o) for _, _, o in g if not isinstance(o, str) or o.startswith('http')}
    node_to_var = {node: f"n{i}" for i, node in enumerate(nodes)}
    
    parts = []
    
    # Add all nodes
    for node in nodes:
        var = node_to_var[node]
        label = sanitize_identifier(node.split('/')[-1])
        uri_value = sanitize_value(node)
        parts.append(f"({var}:{label} {{uri: '{uri_value}'}})")
    
    # Add all edges
    for s, p, o in g:
        if not isinstance(o, str) or o.startswith('http'):
            s_var = node_to_var[str(s)]
            o_var = node_to_var[str(o)]
            pred = sanitize_identifier(str(p).split('/')[-1])
            parts.append(f"({s_var})-[:{pred}]-({o_var})")
    
    return "CREATE " + ",\n".join(parts)

# %%
#%%time

# Create Cypher CREATE command for TuringDB v1
graph_CREATE_command_v1 = rdf_to_cypher_v1(path_rdf)
#graph_CREATE_command_v1 = sanitize_cypher_query(graph_CREATE_command_v1)
print(graph_CREATE_command_v1)
# Out:
# CREATE (n0:Na2c6b9b7544149578526587c85ae3287 {uri: 'Na2c6b9b7544149578526587c85ae3287'}),
# (n1:wine_ChateauLafiteRothschild {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauLafiteRothschild'}),
# (n2:wine_locatedIn {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#locatedIn'}),
# (n3:wine_TexasWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TexasWine'}),
# (n4:wine_KalinCellars {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KalinCellars'}),
# (n5:owl_ObjectProperty {uri: 'http://www.w3.org/2002/07/owl#ObjectProperty'}),
# (n6:wine_hasFlavor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasFlavor'}),
# (n7:wine_ItalianRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ItalianRegion'}),
# (n8:wine_SaucelitoCanyonZinfandel1998 {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SaucelitoCanyonZinfandel1998'}),
# (n9:N4c976574bc0743aebfdbee340150e47a {uri: 'N4c976574bc0743aebfdbee340150e47a'}),
# (n10:Nc828e5e57aae46199425e64aa5add4ea {uri: 'Nc828e5e57aae46199425e64aa5add4ea'}),
# (n11:wine_RedTableWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedTableWine'}),
# (n12:N4ed3a8bfeeaf4538b544107c25c8008f {uri: 'N4ed3a8bfeeaf4538b544107c25c8008f'}),
# (n13:Nd46879d69c8c424790bd12951a3e10b2 {uri: 'Nd46879d69c8c424790bd12951a3e10b2'}),
# (n14:wine_MerlotGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MerlotGrape'}),
# (n15:Nb19222e740e747b7bdb9f1b1b86e84cf {uri: 'Nb19222e740e747b7bdb9f1b1b86e84cf'}),
# (n16:Nd8dd3be8544a485896d155e4a12e212d {uri: 'Nd8dd3be8544a485896d155e4a12e212d'}),
# (n17:wine_USRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#USRegion'}),
# (n18:Nff65ad0200164d8889d98aa64786e483 {uri: 'Nff65ad0200164d8889d98aa64786e483'}),
# (n19:wine_Medium {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'}),
# (n20:wine_FormanChardonnay {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FormanChardonnay'}),
# (n21:wine_MendocinoRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MendocinoRegion'}),
# (n22:wine_CongressSpringsSemillon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CongressSpringsSemillon'}),
# (n23:Nd978c0e1c7024c6e82761478064cfe05 {uri: 'Nd978c0e1c7024c6e82761478064cfe05'}),
# (n24:N05ae6c06fb5146798d95f7521fc12d47 {uri: 'N05ae6c06fb5146798d95f7521fc12d47'}),
# (n25:N59b34e13e6cf4f2dbb242f4fdff55895 {uri: 'N59b34e13e6cf4f2dbb242f4fdff55895'}),
# (n26:N737074aa2d44491baae87f5388817b1d {uri: 'N737074aa2d44491baae87f5388817b1d'}),
# (n27:wine {uri: 'http://www.w3.org/TR/2003/CR-owl-guide-20030818/wine'}),
# (n28:owl_Class {uri: 'http://www.w3.org/2002/07/owl#Class'}),
# (n29:N3d9d1e4485b24867884db8329a5ca366 {uri: 'N3d9d1e4485b24867884db8329a5ca366'}),
# (n30:wine_MountEdenVineyard {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountEdenVineyard'}),
# (n31:wine_ChateauChevalBlancStEmilion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauChevalBlancStEmilion'}),
# (n32:N04068907249c4036aceff127d1f6a3df {uri: 'N04068907249c4036aceff127d1f6a3df'}),
# (n33:N0aef2153795742e78b0c061664c6897f {uri: 'N0aef2153795742e78b0c061664c6897f'}),
# (n34:wine_BancroftChardonnay {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BancroftChardonnay'}),
# (n35:Nd0180331e7064bc5bba7812011ee28a8 {uri: 'Nd0180331e7064bc5bba7812011ee28a8'}),
# (n36:N0192c0a918c7429d97e2495d20ac99bb {uri: 'N0192c0a918c7429d97e2495d20ac99bb'}),
# (n37:Nc3e95a39fdf84415b57b174b70810cd4 {uri: 'Nc3e95a39fdf84415b57b174b70810cd4'}),
# (n38:N318eafc5c3b544139b20ac921a2789a0 {uri: 'N318eafc5c3b544139b20ac921a2789a0'}),
# (n39:N6ae3cafe0c68416ab94089826bc140eb {uri: 'N6ae3cafe0c68416ab94089826bc140eb'}),
# (n40:Neb4f44a618a64d61be0b8666a0500b4a {uri: 'Neb4f44a618a64d61be0b8666a0500b4a'}),
# (n41:N24ba38c8900d4f5bb4d0112b686af4e7 {uri: 'N24ba38c8900d4f5bb4d0112b686af4e7'}),
# (n42:Nd1fdafa937b64ec3b11cf1f488be9468 {uri: 'Nd1fdafa937b64ec3b11cf1f488be9468'}),
# (n43:N293cf1261275464f9bfa8b8502b7b947 {uri: 'N293cf1261275464f9bfa8b8502b7b947'}),
# (n44:N3cd78052460d455693e107d0df5000ae {uri: 'N3cd78052460d455693e107d0df5000ae'}),
# (n45:N8631dbba9271463696fe24a6f580feaf {uri: 'N8631dbba9271463696fe24a6f580feaf'}),
# (n46:Nd04be570848745f98f415e59b9bda5f4 {uri: 'Nd04be570848745f98f415e59b9bda5f4'}),
# (n47:wine_PulignyMontrachetWhiteBurgundy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PulignyMontrachetWhiteBurgundy'}),
# (n48:wine_CaliforniaWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaWine'}),
# (n49:Na6e59ea0ad3d468a9371442c66807356 {uri: 'Na6e59ea0ad3d468a9371442c66807356'}),
# (n50:wine_CaliforniaRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaRegion'}),
# (n51:Nce1a8822827a4578831b28ba90c19f4a {uri: 'Nce1a8822827a4578831b28ba90c19f4a'}),
# (n52:wine_GaryFarrell {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrell'}),
# (n53:N14f2e2affcd544de8ef3b0532095b359 {uri: 'N14f2e2affcd544de8ef3b0532095b359'}),
# (n54:wine_SelaksSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SelaksSauvignonBlanc'}),
# (n55:N1238f47d9dc7407cbc58d018836e9458 {uri: 'N1238f47d9dc7407cbc58d018836e9458'}),
# (n56:Nc222bd4e1a1049b4b1cd19daf50ee804 {uri: 'Nc222bd4e1a1049b4b1cd19daf50ee804'}),
# (n57:N857ab98fe6ac41e3939d0483365bf5f6 {uri: 'N857ab98fe6ac41e3939d0483365bf5f6'}),
# (n58:wine_MeursaultRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MeursaultRegion'}),
# (n59:Ne6ac9d9757674eaea99633686380a086 {uri: 'Ne6ac9d9757674eaea99633686380a086'}),
# (n60:Nc6d5e6f837ed4b6482a6af4a1d77faf5 {uri: 'Nc6d5e6f837ed4b6482a6af4a1d77faf5'}),
# (n61:Ne91f4b2bfc104572a265de42064765ad {uri: 'Ne91f4b2bfc104572a265de42064765ad'}),
# (n62:Na79ad92479ad428fa0a9bdbc4704f5f6 {uri: 'Na79ad92479ad428fa0a9bdbc4704f5f6'}),
# (n63:wine_ClosDeVougeot {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeVougeot'}),
# (n64:wine_ChateauLafiteRothschildPauillac {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauLafiteRothschildPauillac'}),
# (n65:N733b8d2d05104ccbb989bd40ee4d33ed {uri: 'N733b8d2d05104ccbb989bd40ee4d33ed'}),
# (n66:Nd5ade1841871427fbd5fcc822561c7e2 {uri: 'Nd5ade1841871427fbd5fcc822561c7e2'}),
# (n67:Ncc22338cd4fa40ecba7263a7099361ae {uri: 'Ncc22338cd4fa40ecba7263a7099361ae'}),
# (n68:wine_LoireRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LoireRegion'}),
# (n69:Nf425cce3b06942b49b922d2c44a43f70 {uri: 'Nf425cce3b06942b49b922d2c44a43f70'}),
# (n70:N8f1390d94d4047d088a6cefe63a6d41f {uri: 'N8f1390d94d4047d088a6cefe63a6d41f'}),
# (n71:Nbafb421fc91c44169d2d0db30c3e5fbc {uri: 'Nbafb421fc91c44169d2d0db30c3e5fbc'}),
# (n72:wine_madeFromGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'}),
# (n73:wine_Sauternes {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sauternes'}),
# (n74:Nc35701aee9e64d63b8e6d09b3ca9f12c {uri: 'Nc35701aee9e64d63b8e6d09b3ca9f12c'}),
# (n75:wine_CorbansPrivateBinSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansPrivateBinSauvignonBlanc'}),
# (n76:wine_WineTaste {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineTaste'}),
# (n77:wine_Semillon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Semillon'}),
# (n78:N5aff179217934a8095fe547e9a84ba9e {uri: 'N5aff179217934a8095fe547e9a84ba9e'}),
# (n79:N4f365bcba275453fbb2a7403d18c6c3f {uri: 'N4f365bcba275453fbb2a7403d18c6c3f'}),
# (n80:wine_SeanThackrey {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SeanThackrey'}),
# (n81:N1e8fd75412af463093e000df256e5211 {uri: 'N1e8fd75412af463093e000df256e5211'}),
# (n82:N87899b106fa94ab28c009baf3a4f473b {uri: 'N87899b106fa94ab28c009baf3a4f473b'}),
# (n83:wine_CabernetFrancGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFrancGrape'}),
# (n84:N1156708573a440cdb6e0edb49a71cccb {uri: 'N1156708573a440cdb6e0edb49a71cccb'}),
# (n85:Nbb36ce25c8f349298d8b04d80db9acd5 {uri: 'Nbb36ce25c8f349298d8b04d80db9acd5'}),
# (n86:Na6432d7b351e4367ba3312a59efabf0d {uri: 'Na6432d7b351e4367ba3312a59efabf0d'}),
# (n87:Nfcb9e3a8287c41509c581da820df8b88 {uri: 'Nfcb9e3a8287c41509c581da820df8b88'}),
# (n88:N56d4fbecf1154b52ac88db2454bd96c0 {uri: 'N56d4fbecf1154b52ac88db2454bd96c0'}),
# (n89:Nd076c1c4fb4f4155b422eaa9e0c5b01e {uri: 'Nd076c1c4fb4f4155b422eaa9e0c5b01e'}),
# (n90:Na26349fb5b704a30b34e12e8db4b4afa {uri: 'Na26349fb5b704a30b34e12e8db4b4afa'}),
# (n91:N64292471fa594ea684e7eea1dd3504ad {uri: 'N64292471fa594ea684e7eea1dd3504ad'}),
# (n92:Nf3fa875d5a43427cb3c6473117f761d8 {uri: 'Nf3fa875d5a43427cb3c6473117f761d8'}),
# (n93:N46e60d6e6e2742549893c8287810cf45 {uri: 'N46e60d6e6e2742549893c8287810cf45'}),
# (n94:Ne4cf3b36bdac4e44990ae8b82c0a72f0 {uri: 'Ne4cf3b36bdac4e44990ae8b82c0a72f0'}),
# (n95:N3c336a191f2a4243bf6f9e11fe1b5c08 {uri: 'N3c336a191f2a4243bf6f9e11fe1b5c08'}),
# (n96:wine_CongressSprings {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CongressSprings'}),
# (n97:N82bcf0c1bd3f4114a929d028dceac950 {uri: 'N82bcf0c1bd3f4114a929d028dceac950'}),
# (n98:N9402a283a2014c96be11e86d5c8d4c42 {uri: 'N9402a283a2014c96be11e86d5c8d4c42'}),
# (n99:Nf471e838a56048e1aaffbeb1fa97d48e {uri: 'Nf471e838a56048e1aaffbeb1fa97d48e'}),
# (n100:wine_ToursRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ToursRegion'}),
# (n101:wine_MuscadetRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MuscadetRegion'}),
# (n102:N02b2e9731450452d9fa512a9fbb138bf {uri: 'N02b2e9731450452d9fa512a9fbb138bf'}),
# (n103:wine_Red {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Red'}),
# (n104:N76db6d08275441529d43808ee82feec2 {uri: 'N76db6d08275441529d43808ee82feec2'}),
# (n105:N41d8bd16e92d44319b75b586612ad1a3 {uri: 'N41d8bd16e92d44319b75b586612ad1a3'}),
# (n106:wine_StGenevieveTexasWhite {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StGenevieveTexasWhite'}),
# (n107:wine_AnjouRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AnjouRegion'}),
# (n108:Nbb70e228def74fc6b7109c14a6a366d1 {uri: 'Nbb70e228def74fc6b7109c14a6a366d1'}),
# (n109:wine_Bordeaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Bordeaux'}),
# (n110:wine_SantaCruzMountainsRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaCruzMountainsRegion'}),
# (n111:N57736e21cf2f4fcb85b8fafa3dcfc846 {uri: 'N57736e21cf2f4fcb85b8fafa3dcfc846'}),
# (n112:N519892e8d2da4f12b5f0af62bd7d25cc {uri: 'N519892e8d2da4f12b5f0af62bd7d25cc'}),
# (n113:wine_hasColor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasColor'}),
# (n114:owl_Restriction {uri: 'http://www.w3.org/2002/07/owl#Restriction'}),
# (n115:Ncbe082cb493d4a7fbc87f708d49ca497 {uri: 'Ncbe082cb493d4a7fbc87f708d49ca497'}),
# (n116:wine_Chardonnay {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chardonnay'}),
# (n117:wine_Anjou {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Anjou'}),
# (n118:wine_ChiantiRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChiantiRegion'}),
# (n119:wine_WhitehallLane {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhitehallLane'}),
# (n120:Nba03bfbad7984f42a491d7f5c34c564a {uri: 'Nba03bfbad7984f42a491d7f5c34c564a'}),
# (n121:N8730b0ba91054d21ab519bc8b2fbac73 {uri: 'N8730b0ba91054d21ab519bc8b2fbac73'}),
# (n122:wine_StEmilionRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StEmilionRegion'}),
# (n123:Ne66efa433696465faa0909663c3d7cf0 {uri: 'Ne66efa433696465faa0909663c3d7cf0'}),
# (n124:wine_Burgundy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Burgundy'}),
# (n125:N143156d795764cdf8725969ae5e3e00f {uri: 'N143156d795764cdf8725969ae5e3e00f'}),
# (n126:N027b5a6b42c044d084f135d8f564ba76 {uri: 'N027b5a6b42c044d084f135d8f564ba76'}),
# (n127:Nb3f02af8475d4fe5a7d2e5de7e54abcb {uri: 'Nb3f02af8475d4fe5a7d2e5de7e54abcb'}),
# (n128:wine_PetiteVerdotGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteVerdotGrape'}),
# (n129:N00f82966672444f1a46302d1ccc3d50c {uri: 'N00f82966672444f1a46302d1ccc3d50c'}),
# (n130:wine_CentralTexasRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CentralTexasRegion'}),
# (n131:N59ae95142d7f44d4a7275a268c4e1db4 {uri: 'N59ae95142d7f44d4a7275a268c4e1db4'}),
# (n132:N75d6e2500c46431ea873120c99a31d99 {uri: 'N75d6e2500c46431ea873120c99a31d99'}),
# (n133:wine_MariettaPetiteSyrah {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaPetiteSyrah'}),
# (n134:N419874b84b404b52948645272026b9f0 {uri: 'N419874b84b404b52948645272026b9f0'}),
# (n135:wine_MountadamChardonnay {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamChardonnay'}),
# (n136:N58a4f7887e8e41f396b90f8021c28f07 {uri: 'N58a4f7887e8e41f396b90f8021c28f07'}),
# (n137:N6a5a2916bd0c4ffeb9521dcc65e8ec3d {uri: 'N6a5a2916bd0c4ffeb9521dcc65e8ec3d'}),
# (n138:N0ace578b8b0a43eabc4d41a06f910201 {uri: 'N0ace578b8b0a43eabc4d41a06f910201'}),
# (n139:N117fc4505c914d278e2cb6c6db28a60c {uri: 'N117fc4505c914d278e2cb6c6db28a60c'}),
# (n140:Ned75cb9cad334159ab9daf7e1c317215 {uri: 'Ned75cb9cad334159ab9daf7e1c317215'}),
# (n141:Nf8e01382e56247cdb68d778011361f66 {uri: 'Nf8e01382e56247cdb68d778011361f66'}),
# (n142:wine_CotesDOrRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotesDOrRegion'}),
# (n143:Ne37b55ccf5294bb695e96de19af59440 {uri: 'Ne37b55ccf5294bb695e96de19af59440'}),
# (n144:N6dda2ea0286e499d8f5c199f51061ab8 {uri: 'N6dda2ea0286e499d8f5c199f51061ab8'}),
# (n145:wine_SemillonGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SemillonGrape'}),
# (n146:N9f29f53ce337476d89690ff68a592b8a {uri: 'N9f29f53ce337476d89690ff68a592b8a'}),
# (n147:N1bda61677c654e90bae94cfa356f2728 {uri: 'N1bda61677c654e90bae94cfa356f2728'}),
# (n148:wine_hasSugar {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'}),
# (n149:wine_ChateauDeMeursault {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDeMeursault'}),
# (n150:wine_WineSugar {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineSugar'}),
# (n151:N75e253bafa9742e69e24a78df1b3c34a {uri: 'N75e253bafa9742e69e24a78df1b3c34a'}),
# (n152:N6caf8d32dc324102bc068d30a176064f {uri: 'N6caf8d32dc324102bc068d30a176064f'}),
# (n153:N7c541921115d47f093e0e9dcb54f7a9c {uri: 'N7c541921115d47f093e0e9dcb54f7a9c'}),
# (n154:Nea9e53690e2d4153b23d2df0ed03aa73 {uri: 'Nea9e53690e2d4153b23d2df0ed03aa73'}),
# (n155:wine_MariettaZinfandel {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaZinfandel'}),
# (n156:Nb025846b5903407394385249034ed280 {uri: 'Nb025846b5903407394385249034ed280'}),
# (n157:wine_SchlossVolrad {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossVolrad'}),
# (n158:N9574e39f5c944437b9768e766550d748 {uri: 'N9574e39f5c944437b9768e766550d748'}),
# (n159:Nc9840319a45348b6a2a56a2d1491b8d2 {uri: 'Nc9840319a45348b6a2a56a2d1491b8d2'}),
# (n160:wine_Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n161:N259611e1ee2a4810974808d5d473ddb2 {uri: 'N259611e1ee2a4810974808d5d473ddb2'}),
# (n162:wine_VentanaCheninBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#VentanaCheninBlanc'}),
# (n163:Nb14ab087363e464ea1b639d5df856678 {uri: 'Nb14ab087363e464ea1b639d5df856678'}),
# (n164:wine_WhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteWine'}),
# (n165:N5b29f1457f274ec2a0ac3d6a56d544e2 {uri: 'N5b29f1457f274ec2a0ac3d6a56d544e2'}),
# (n166:N8780264f0e454af69b4b01601addafb2 {uri: 'N8780264f0e454af69b4b01601addafb2'}),
# (n167:Nc998b77493904d72ab771218afa18158 {uri: 'Nc998b77493904d72ab771218afa18158'}),
# (n168:wine_VintageYear {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#VintageYear'}),
# (n169:Nf46d785a3d3d40038bd2061d7b289b61 {uri: 'Nf46d785a3d3d40038bd2061d7b289b61'}),
# (n170:N7c04554636a84f328340073dfa1a5ad9 {uri: 'N7c04554636a84f328340073dfa1a5ad9'}),
# (n171:wine_Forman {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Forman'}),
# (n172:wine_SantaBarbaraRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaBarbaraRegion'}),
# (n173:N6f8bd37d19b34e93937dc71d5dd9ddf4 {uri: 'N6f8bd37d19b34e93937dc71d5dd9ddf4'}),
# (n174:wine_SweetWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SweetWine'}),
# (n175:N0c022a6e259949e2ab3d306fafb86ebf {uri: 'N0c022a6e259949e2ab3d306fafb86ebf'}),
# (n176:wine_SeanThackreySiriusPetiteSyrah {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SeanThackreySiriusPetiteSyrah'}),
# (n177:wine_ItalianWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ItalianWine'}),
# (n178:N600691cd2f67415e90c2b3340ae61b56 {uri: 'N600691cd2f67415e90c2b3340ae61b56'}),
# (n179:N470a3daae385474b939fc04def351f75 {uri: 'N470a3daae385474b939fc04def351f75'}),
# (n180:wine_MargauxRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MargauxRegion'}),
# (n181:N95a59bd6c3664a419d5dc569060bb714 {uri: 'N95a59bd6c3664a419d5dc569060bb714'}),
# (n182:N2d3c5963a12244d6978eea5cd0354208 {uri: 'N2d3c5963a12244d6978eea5cd0354208'}),
# (n183:N3cd54ccad6174874894189f387cf866f {uri: 'N3cd54ccad6174874894189f387cf866f'}),
# (n184:wine_Year1998 {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Year1998'}),
# (n185:wine_DryWhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryWhiteWine'}),
# (n186:wine_CabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'}),
# (n187:N1707fa8bc0d842d2a527b9a207234f26 {uri: 'N1707fa8bc0d842d2a527b9a207234f26'}),
# (n188:N566843d41a424e4a8a196365fd0e8bc0 {uri: 'N566843d41a424e4a8a196365fd0e8bc0'}),
# (n189:Ndc51c71db8a9466ebe4e23cdb0f9f5f2 {uri: 'Ndc51c71db8a9466ebe4e23cdb0f9f5f2'}),
# (n190:N93cd01d50301475aaf4f9c1c4929d782 {uri: 'N93cd01d50301475aaf4f9c1c4929d782'}),
# (n191:Nd0a77bb1b5524dda82771f8d69da4ff9 {uri: 'Nd0a77bb1b5524dda82771f8d69da4ff9'}),
# (n192:wine_GaryFarrellMerlot {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrellMerlot'}),
# (n193:N4841fe90c27b4a2381204beda175dba7 {uri: 'N4841fe90c27b4a2381204beda175dba7'}),
# (n194:wine_WineColor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineColor'}),
# (n195:wine_AlsatianWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AlsatianWine'}),
# (n196:N5dc36c43146b4553a24d61c7bc57fc92 {uri: 'N5dc36c43146b4553a24d61c7bc57fc92'}),
# (n197:wine_White {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#White'}),
# (n198:Naafb7ae8c665413faf330f82d13a8691 {uri: 'Naafb7ae8c665413faf330f82d13a8691'}),
# (n199:N7e17b2f23ad84c478ab20ff544a02671 {uri: 'N7e17b2f23ad84c478ab20ff544a02671'}),
# (n200:wine_Stonleigh {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Stonleigh'}),
# (n201:wine_BordeauxRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BordeauxRegion'}),
# (n202:owl_AllDifferent {uri: 'http://www.w3.org/2002/07/owl#AllDifferent'}),
# (n203:N48eaadeb6c784ee49cfa177dab79fe3d {uri: 'N48eaadeb6c784ee49cfa177dab79fe3d'}),
# (n204:N58e8691966a646a3a50e311a76a6b27f {uri: 'N58e8691966a646a3a50e311a76a6b27f'}),
# (n205:Nc48523ab8c7b443b87b185723585b560 {uri: 'Nc48523ab8c7b443b87b185723585b560'}),
# (n206:Nb2db700b557941938aeea419fdc0203e {uri: 'Nb2db700b557941938aeea419fdc0203e'}),
# (n207:N9fc86536330e44f8b136cfc0ec302bcc {uri: 'N9fc86536330e44f8b136cfc0ec302bcc'}),
# (n208:wine_TableWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TableWine'}),
# (n209:N77e839f9c5244bbfb25a4e32b2a9a21f {uri: 'N77e839f9c5244bbfb25a4e32b2a9a21f'}),
# (n210:Na5ebcd666e204cfaa1561766a1c06b8b {uri: 'Na5ebcd666e204cfaa1561766a1c06b8b'}),
# (n211:wine_CortonMontrachet {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CortonMontrachet'}),
# (n212:Nb9662bedeacd48b0a3919a860c538cf8 {uri: 'Nb9662bedeacd48b0a3919a860c538cf8'}),
# (n213:Ne246b51a703e495bb8b125579734218a {uri: 'Ne246b51a703e495bb8b125579734218a'}),
# (n214:N69e9f50a4198471f9995535297368dd8 {uri: 'N69e9f50a4198471f9995535297368dd8'}),
# (n215:Nc05bbfe40d5041f8a759f9514abecda6 {uri: 'Nc05bbfe40d5041f8a759f9514abecda6'}),
# (n216:wine_ChiantiClassico {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChiantiClassico'}),
# (n217:Nada208a9d6fe4fa29d3b83e114b45593 {uri: 'Nada208a9d6fe4fa29d3b83e114b45593'}),
# (n218:N7b936e63fbde49348aa0139f4a277036 {uri: 'N7b936e63fbde49348aa0139f4a277036'}),
# (n219:Ndfb170ca4d4a462fa4f05eb19f6146d3 {uri: 'Ndfb170ca4d4a462fa4f05eb19f6146d3'}),
# (n220:wine_FrenchWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FrenchWine'}),
# (n221:N2dfcb863fef841ee8a5d556f7a6b1e22 {uri: 'N2dfcb863fef841ee8a5d556f7a6b1e22'}),
# (n222:wine_SweetRiesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SweetRiesling'}),
# (n223:Nbbf75c3789c34a7fba9a210314344f6c {uri: 'Nbbf75c3789c34a7fba9a210314344f6c'}),
# (n224:Nd7d4d517d5d34816a3dccea4eb9ce198 {uri: 'Nd7d4d517d5d34816a3dccea4eb9ce198'}),
# (n225:Naed96260c14545e09bb793c4764d0b1f {uri: 'Naed96260c14545e09bb793c4764d0b1f'}),
# (n226:N60569a9a0b324886a299c824d585dc9d {uri: 'N60569a9a0b324886a299c824d585dc9d'}),
# (n227:N66dafb3e18044446b1fa94e5e28852d8 {uri: 'N66dafb3e18044446b1fa94e5e28852d8'}),
# (n228:wine_PageMillWineryCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PageMillWineryCabernetSauvignon'}),
# (n229:N2c6f5701a9d24c8b908e03932279308c {uri: 'N2c6f5701a9d24c8b908e03932279308c'}),
# (n230:Ne2bc1569bfdf498db469315aa4526513 {uri: 'Ne2bc1569bfdf498db469315aa4526513'}),
# (n231:Nf6dbc74a449b4ef58f5b48aa4e4a8a3a {uri: 'Nf6dbc74a449b4ef58f5b48aa4e4a8a3a'}),
# (n232:wine_Full {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Full'}),
# (n233:N05d68db3e9094e02976fbae1b531affb {uri: 'N05d68db3e9094e02976fbae1b531affb'}),
# (n234:Nc888a3bef42948019e99681f99df44df {uri: 'Nc888a3bef42948019e99681f99df44df'}),
# (n235:N3fca9747fef34e54b93a74f8e79a8d5d {uri: 'N3fca9747fef34e54b93a74f8e79a8d5d'}),
# (n236:wine_SchlossVolradTrochenbierenausleseRiesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossVolradTrochenbierenausleseRiesling'}),
# (n237:N1f71befa79fb4933a6c064d1f9bb36ab {uri: 'N1f71befa79fb4933a6c064d1f9bb36ab'}),
# (n238:N8c46ff07e4564e90af7e0d73ff004bfa {uri: 'N8c46ff07e4564e90af7e0d73ff004bfa'}),
# (n239:N96f5efea1c454c09b9bf8ffd9785f721 {uri: 'N96f5efea1c454c09b9bf8ffd9785f721'}),
# (n240:N587cfe0687e3414b9c5747ae975d6c57 {uri: 'N587cfe0687e3414b9c5747ae975d6c57'}),
# (n241:Ne8aaaf5b08cc4db592a7da72bb1ce056 {uri: 'Ne8aaaf5b08cc4db592a7da72bb1ce056'}),
# (n242:Nf04f013a621e4345be2ad390366be0cb {uri: 'Nf04f013a621e4345be2ad390366be0cb'}),
# (n243:N629f21d3b010486daac997503a4dd4d3 {uri: 'N629f21d3b010486daac997503a4dd4d3'}),
# (n244:Nf7189824278c4144931148cdf8923bb5 {uri: 'Nf7189824278c4144931148cdf8923bb5'}),
# (n245:wine_TaylorPort {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TaylorPort'}),
# (n246:N10531d1e67da45b3ab03b58d0da8d5d5 {uri: 'N10531d1e67da45b3ab03b58d0da8d5d5'}),
# (n247:N996c4e3b23d3475abed87eb22f3b9b57 {uri: 'N996c4e3b23d3475abed87eb22f3b9b57'}),
# (n248:Na43d3e3e6b94468380cbf5993ef1c4f9 {uri: 'Na43d3e3e6b94468380cbf5993ef1c4f9'}),
# (n249:N0795935e76324ff0bf842de4ffc87dc3 {uri: 'N0795935e76324ff0bf842de4ffc87dc3'}),
# (n250:wine_ElyseZinfandel {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ElyseZinfandel'}),
# (n251:N822bd9a64699428aa90bd2aa9a37edd3 {uri: 'N822bd9a64699428aa90bd2aa9a37edd3'}),
# (n252:N62ad4c4a519b4868bf5eb0fa3202e823 {uri: 'N62ad4c4a519b4868bf5eb0fa3202e823'}),
# (n253:Ne2a06f00e48e4e68b2eca405b7617b82 {uri: 'Ne2a06f00e48e4e68b2eca405b7617b82'}),
# (n254:wine_ClosDeVougeotCotesDOr {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeVougeotCotesDOr'}),
# (n255:N54c79732c20144439b0e80a39a8651b0 {uri: 'N54c79732c20144439b0e80a39a8651b0'}),
# (n256:wine_RedBurgundy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedBurgundy'}),
# (n257:N9b46af60d20147fd83b15e23b6763743 {uri: 'N9b46af60d20147fd83b15e23b6763743'}),
# (n258:Ncae64e5f3ebc4449a5865931ab0aaee8 {uri: 'Ncae64e5f3ebc4449a5865931ab0aaee8'}),
# (n259:wine_SchlossRothermelTrochenbierenausleseRiesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossRothermelTrochenbierenausleseRiesling'}),
# (n260:wine_Moderate {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'}),
# (n261:wine_Beringer {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Beringer'}),
# (n262:wine_PinotBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotBlanc'}),
# (n263:N70e4583dfe3e46b189027561c3489ce8 {uri: 'N70e4583dfe3e46b189027561c3489ce8'}),
# (n264:wine_Handley {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Handley'}),
# (n265:N49ea4aeaf33b408186be222de56d010f {uri: 'N49ea4aeaf33b408186be222de56d010f'}),
# (n266:wine_StonleighSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StonleighSauvignonBlanc'}),
# (n267:wine_ArroyoGrandeRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ArroyoGrandeRegion'}),
# (n268:Nf8a8fabdd4a4401da100f3116aa8e421 {uri: 'Nf8a8fabdd4a4401da100f3116aa8e421'}),
# (n269:N4f08a3c05d644af897befeb08a181079 {uri: 'N4f08a3c05d644af897befeb08a181079'}),
# (n270:N68ed2bff7f804423880598599a74540e {uri: 'N68ed2bff7f804423880598599a74540e'}),
# (n271:N87d2cec3f0664cd582995c80376ee646 {uri: 'N87d2cec3f0664cd582995c80376ee646'}),
# (n272:wine_Pauillac {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Pauillac'}),
# (n273:Ne5941e9ee43f47b589e352f7753d84a2 {uri: 'Ne5941e9ee43f47b589e352f7753d84a2'}),
# (n274:Nf4ddf1eae7b84b0f845c010eea547ecf {uri: 'Nf4ddf1eae7b84b0f845c010eea547ecf'}),
# (n275:wine_MedocRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MedocRegion'}),
# (n276:N437b68c619574bb6aee2b21d8d13697a {uri: 'N437b68c619574bb6aee2b21d8d13697a'}),
# (n277:N23099ebecae74d0b80fdadf75fe34f58 {uri: 'N23099ebecae74d0b80fdadf75fe34f58'}),
# (n278:N634653c844404decb87c84df1812e318 {uri: 'N634653c844404decb87c84df1812e318'}),
# (n279:N1bef92502798476282c4e23175fb50bc {uri: 'N1bef92502798476282c4e23175fb50bc'}),
# (n280:N07b57f45c72142f19129b2c6744e40cf {uri: 'N07b57f45c72142f19129b2c6744e40cf'}),
# (n281:Nd6fb45549e894e128e292bdf4bbdc5e1 {uri: 'Nd6fb45549e894e128e292bdf4bbdc5e1'}),
# (n282:N339fca785e894678b62806424a1c5b1a {uri: 'N339fca785e894678b62806424a1c5b1a'}),
# (n283:wine_KalinCellarsSemillon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KalinCellarsSemillon'}),
# (n284:wine_CorbansDryWhiteRiesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansDryWhiteRiesling'}),
# (n285:wine_WhiteBurgundy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteBurgundy'}),
# (n286:N8c4f6baf72c74e548070180db82e9528 {uri: 'N8c4f6baf72c74e548070180db82e9528'}),
# (n287:wine_SchlossRothermel {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossRothermel'}),
# (n288:wine_Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n289:food_madeFromFruit {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#madeFromFruit'}),
# (n290:wine_LaneTannerPinotNoir {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTannerPinotNoir'}),
# (n291:N919cd059f63148fb91338043e3848e5b {uri: 'N919cd059f63148fb91338043e3848e5b'}),
# (n292:wine_WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineDescriptor'}),
# (n293:wine_Elyse {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Elyse'}),
# (n294:Nbb80139ad58c4da493a3cf8955ac43d2 {uri: 'Nbb80139ad58c4da493a3cf8955ac43d2'}),
# (n295:Nf8da1a96b25b43509748c3d2cec94093 {uri: 'Nf8da1a96b25b43509748c3d2cec94093'}),
# (n296:N7679418a09df418dac492f022fbb5f41 {uri: 'N7679418a09df418dac492f022fbb5f41'}),
# (n297:wine_WhiteNonSweetWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteNonSweetWine'}),
# (n298:owl_FunctionalProperty {uri: 'http://www.w3.org/2002/07/owl#FunctionalProperty'}),
# (n299:N9d12478af2bf43d9a8fc3c950115be90 {uri: 'N9d12478af2bf43d9a8fc3c950115be90'}),
# (n300:N25f1f377a5ed40779909fd6f86b45368 {uri: 'N25f1f377a5ed40779909fd6f86b45368'}),
# (n301:wine_IceWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#IceWine'}),
# (n302:wine_producesWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#producesWine'}),
# (n303:wine_SantaCruzMountainVineyard {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaCruzMountainVineyard'}),
# (n304:N239de626c91c44d193293c5afcc03552 {uri: 'N239de626c91c44d193293c5afcc03552'}),
# (n305:Nd331d20c8b2e40279c76ab93c8f2767d {uri: 'Nd331d20c8b2e40279c76ab93c8f2767d'}),
# (n306:wine_ChateauMargaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMargaux'}),
# (n307:N2b675af5984b4744a92a5d61cc455e3f {uri: 'N2b675af5984b4744a92a5d61cc455e3f'}),
# (n308:wine_CabernetFranc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFranc'}),
# (n309:N03afed472a9c4073a191406a3fb6387b {uri: 'N03afed472a9c4073a191406a3fb6387b'}),
# (n310:wine_GermanyRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GermanyRegion'}),
# (n311:N20a20776d53d47b68535d82a55c87d15 {uri: 'N20a20776d53d47b68535d82a55c87d15'}),
# (n312:wine_PinotNoirGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoirGrape'}),
# (n313:Nab829760af2e4b518389772b18164229 {uri: 'Nab829760af2e4b518389772b18164229'}),
# (n314:Nd1bd1273ed7242eaa6a3012b8825e4ff {uri: 'Nd1bd1273ed7242eaa6a3012b8825e4ff'}),
# (n315:wine_ZinfandelGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ZinfandelGrape'}),
# (n316:ID_22_rdf_syntax_ns_nil {uri: 'http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'}),
# (n317:Nc8ca37ed7b96465ba5b5281337afc870 {uri: 'Nc8ca37ed7b96465ba5b5281337afc870'}),
# (n318:wine_Tours {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Tours'}),
# (n319:N1b56a235160c4828bbe164ac6eacdd40 {uri: 'N1b56a235160c4828bbe164ac6eacdd40'}),
# (n320:N5829997c8755485c98e46c7775ddd068 {uri: 'N5829997c8755485c98e46c7775ddd068'}),
# (n321:wine_MariettaCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaCabernetSauvignon'}),
# (n322:wine_PauillacRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PauillacRegion'}),
# (n323:wine_FormanCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FormanCabernetSauvignon'}),
# (n324:Nf7d66dfc80a24cdd83a8e9fa53dd1290 {uri: 'Nf7d66dfc80a24cdd83a8e9fa53dd1290'}),
# (n325:Ne0d5e4c47c44492caecc11e26563ff2e {uri: 'Ne0d5e4c47c44492caecc11e26563ff2e'}),
# (n326:Na2f4cfb4b1ad4e4184d5abe7e32a6bba {uri: 'Na2f4cfb4b1ad4e4184d5abe7e32a6bba'}),
# (n327:N7c04809be9784288b69e2a9360f1e31f {uri: 'N7c04809be9784288b69e2a9360f1e31f'}),
# (n328:N0b5afe1b0ab544ebb0215da21a51974e {uri: 'N0b5afe1b0ab544ebb0215da21a51974e'}),
# (n329:N45b08ab891b545bfb8ff18ddcfb4489b {uri: 'N45b08ab891b545bfb8ff18ddcfb4489b'}),
# (n330:wine_Wine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'}),
# (n331:N6170b76c3b4640f6a33fe442dc986ed3 {uri: 'N6170b76c3b4640f6a33fe442dc986ed3'}),
# (n332:wine_GermanWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GermanWine'}),
# (n333:wine_WhiteBordeaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteBordeaux'}),
# (n334:N056645c2296b410a9a12b4e7f8ceda1f {uri: 'N056645c2296b410a9a12b4e7f8ceda1f'}),
# (n335:N5a2e98be913d45e5aa22fc515e93b3b9 {uri: 'N5a2e98be913d45e5aa22fc515e93b3b9'}),
# (n336:wine_RoseWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RoseWine'}),
# (n337:wine_AlsaceRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AlsaceRegion'}),
# (n338:N8f475a4992ee4248b9a85f558368d998 {uri: 'N8f475a4992ee4248b9a85f558368d998'}),
# (n339:Ne90887dc1b7c4665888bb04648f2b2ef {uri: 'Ne90887dc1b7c4665888bb04648f2b2ef'}),
# (n340:owl_DatatypeProperty {uri: 'http://www.w3.org/2002/07/owl#DatatypeProperty'}),
# (n341:Ne5babc40c0a14c39be08126a997b7613 {uri: 'Ne5babc40c0a14c39be08126a997b7613'}),
# (n342:N340a341ca2de4a60a2e94959969b52d7 {uri: 'N340a341ca2de4a60a2e94959969b52d7'}),
# (n343:N3dc390642efa4ca3aa8c175cc728a066 {uri: 'N3dc390642efa4ca3aa8c175cc728a066'}),
# (n344:Nfd39ab6982954693be6df3cb404f2147 {uri: 'Nfd39ab6982954693be6df3cb404f2147'}),
# (n345:N72440b4dee07453e9fcd4e121d5f12fa {uri: 'N72440b4dee07453e9fcd4e121d5f12fa'}),
# (n346:Nee0dd986fd104f19b0815e8546578960 {uri: 'Nee0dd986fd104f19b0815e8546578960'}),
# (n347:N021f5c5372244557ae78f658591f68d3 {uri: 'N021f5c5372244557ae78f658591f68d3'}),
# (n348:N385c46d337d042d2b14b736c47726643 {uri: 'N385c46d337d042d2b14b736c47726643'}),
# (n349:wine_ChateauDYchemSauterne {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDYchemSauterne'}),
# (n350:N3499143efe544ae28fa0e252e334ba5a {uri: 'N3499143efe544ae28fa0e252e334ba5a'}),
# (n351:N534f69bf8c0d4ebab3f9e187d5f39ea0 {uri: 'N534f69bf8c0d4ebab3f9e187d5f39ea0'}),
# (n352:N99bb71c83564419db4e5183ea738a6d2 {uri: 'N99bb71c83564419db4e5183ea738a6d2'}),
# (n353:N5050177be9284ece99f42ef14c7d9166 {uri: 'N5050177be9284ece99f42ef14c7d9166'}),
# (n354:Nc9259fd546d14faf934def4b24613827 {uri: 'Nc9259fd546d14faf934def4b24613827'}),
# (n355:Nf87dcc6a09204c8fbec62742ee373054 {uri: 'Nf87dcc6a09204c8fbec62742ee373054'}),
# (n356:Nb44c9520a3e243508fb9c24a2e556864 {uri: 'Nb44c9520a3e243508fb9c24a2e556864'}),
# (n357:wine_PortugalRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PortugalRegion'}),
# (n358:N6a219e6537c34246aac88c45a22b7cf6 {uri: 'N6a219e6537c34246aac88c45a22b7cf6'}),
# (n359:wine_LongridgeMerlot {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LongridgeMerlot'}),
# (n360:wine_ChateauMorgonBeaujolais {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMorgonBeaujolais'}),
# (n361:Ndb393b887eb842b48c7e3254fdf2985a {uri: 'Ndb393b887eb842b48c7e3254fdf2985a'}),
# (n362:N075bc96ec45a409aac2d881eb2c5ed39 {uri: 'N075bc96ec45a409aac2d881eb2c5ed39'}),
# (n363:wine_CortonMontrachetWhiteBurgundy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CortonMontrachetWhiteBurgundy'}),
# (n364:N883ddd6f647c47f18989605504e6a938 {uri: 'N883ddd6f647c47f18989605504e6a938'}),
# (n365:N5b7b5d16599c4f788f4207e12abdf41e {uri: 'N5b7b5d16599c4f788f4207e12abdf41e'}),
# (n366:N039c3758fa0b41dd997f1bf1186459db {uri: 'N039c3758fa0b41dd997f1bf1186459db'}),
# (n367:XMLSchema_positiveInteger {uri: 'http://www.w3.org/2001/XMLSchema#positiveInteger'}),
# (n368:N444410a969b64966a518b51b439200c4 {uri: 'N444410a969b64966a518b51b439200c4'}),
# (n369:Nf97a1e67e78045a7879d1a725f626893 {uri: 'Nf97a1e67e78045a7879d1a725f626893'}),
# (n370:wine_SancerreRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SancerreRegion'}),
# (n371:food_Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#Grape'}),
# (n372:Ndbe0cb2315ef40259a53aad2d22e869c {uri: 'Ndbe0cb2315ef40259a53aad2d22e869c'}),
# (n373:wine_Muscadet {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Muscadet'}),
# (n374:Ne6e0f7a93b7b43ceae100cf10b864947 {uri: 'Ne6e0f7a93b7b43ceae100cf10b864947'}),
# (n375:Nf9fee9136cdf4433b955ac6863b6653b {uri: 'Nf9fee9136cdf4433b955ac6863b6653b'}),
# (n376:Na1182eaec7a6467c8a2b82df4d8b2a0c {uri: 'Na1182eaec7a6467c8a2b82df4d8b2a0c'}),
# (n377:N6788cd20eef44d1cbfb35762a7e1fde9 {uri: 'N6788cd20eef44d1cbfb35762a7e1fde9'}),
# (n378:N19a6da2566f04e74b6a4c9565855ef1b {uri: 'N19a6da2566f04e74b6a4c9565855ef1b'}),
# (n379:N779e420e23c0481bbd642461ef6f6bfe {uri: 'N779e420e23c0481bbd642461ef6f6bfe'}),
# (n380:wine_Beaujolais {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Beaujolais'}),
# (n381:wine_EdnaValleyRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EdnaValleyRegion'}),
# (n382:wine_hasWineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasWineDescriptor'}),
# (n383:Nf0887a330dab464fbc0c597bafe84023 {uri: 'Nf0887a330dab464fbc0c597bafe84023'}),
# (n384:wine_TexasRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TexasRegion'}),
# (n385:N863a16ad56e244148527b616c03104b3 {uri: 'N863a16ad56e244148527b616c03104b3'}),
# (n386:wine_PetiteSyrahGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteSyrahGrape'}),
# (n387:N47d0c3b4592e46a1a47b4d15e4861084 {uri: 'N47d0c3b4592e46a1a47b4d15e4861084'}),
# (n388:Nc1d7e4ac923443139832d324bd0fd1b0 {uri: 'Nc1d7e4ac923443139832d324bd0fd1b0'}),
# (n389:N887409ee44094a459f78927ba99e2795 {uri: 'N887409ee44094a459f78927ba99e2795'}),
# (n390:Nc75886cef40047cea80a6627630bf718 {uri: 'Nc75886cef40047cea80a6627630bf718'}),
# (n391:Ncff3d5c0b99842eaa5d5bde39bf77512 {uri: 'Ncff3d5c0b99842eaa5d5bde39bf77512'}),
# (n392:N70f52aa6c1004b14952fd81f5d58363d {uri: 'N70f52aa6c1004b14952fd81f5d58363d'}),
# (n393:wine_AmericanWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AmericanWine'}),
# (n394:Nd5b72de0cab441ef8621e39c41549973 {uri: 'Nd5b72de0cab441ef8621e39c41549973'}),
# (n395:Nac6dfb9ac7014407a05e8c786e4508aa {uri: 'Nac6dfb9ac7014407a05e8c786e4508aa'}),
# (n396:wine_SevreEtMaineMuscadet {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaineMuscadet'}),
# (n397:Neeb0d9f070e74a2295fc25ae506d2af4 {uri: 'Neeb0d9f070e74a2295fc25ae506d2af4'}),
# (n398:Nb516e14ff8854eef8ca8e0cd908ba2cd {uri: 'Nb516e14ff8854eef8ca8e0cd908ba2cd'}),
# (n399:Ndad4f24a07724aeb9b0c1b13952a815f {uri: 'Ndad4f24a07724aeb9b0c1b13952a815f'}),
# (n400:wine_Strong {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Strong'}),
# (n401:Nf708f847e786491798b29ecd7cf634ca {uri: 'Nf708f847e786491798b29ecd7cf634ca'}),
# (n402:wine_NewZealandRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#NewZealandRegion'}),
# (n403:Nce12e96c1451472eb33bb0e4d54af030 {uri: 'Nce12e96c1451472eb33bb0e4d54af030'}),
# (n404:N9e619723c4f84b26a87aa96a04b24093 {uri: 'N9e619723c4f84b26a87aa96a04b24093'}),
# (n405:wine_CentralCoastRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CentralCoastRegion'}),
# (n406:N3b72c828a5a24a1fba831c69346261af {uri: 'N3b72c828a5a24a1fba831c69346261af'}),
# (n407:wine_Selaks {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Selaks'}),
# (n408:Nb68272625719462781b2dc17ba1ae318 {uri: 'Nb68272625719462781b2dc17ba1ae318'}),
# (n409:wine_PinotBlancGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotBlancGrape'}),
# (n410:wine_PageMillWinery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PageMillWinery'}),
# (n411:wine_FrenchRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FrenchRegion'}),
# (n412:wine_SauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlanc'}),
# (n413:N2ef26396061b477e82984924676f0ec4 {uri: 'N2ef26396061b477e82984924676f0ec4'}),
# (n414:wine_Light {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Light'}),
# (n415:N7e61961f29304ccda1bd8d197eb9d3d4 {uri: 'N7e61961f29304ccda1bd8d197eb9d3d4'}),
# (n416:N48570d0c41274b0caecfc87a8b3251d6 {uri: 'N48570d0c41274b0caecfc87a8b3251d6'}),
# (n417:N76809e6903384e9a96aa4ba455c4ae0d {uri: 'N76809e6903384e9a96aa4ba455c4ae0d'}),
# (n418:Nb658901bfb8b41968eb0cd359f1e58e2 {uri: 'Nb658901bfb8b41968eb0cd359f1e58e2'}),
# (n419:wine_GamayGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GamayGrape'}),
# (n420:wine_ClosDeLaPoussie {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeLaPoussie'}),
# (n421:N59ca6eb879fa46a6a5c265fbecc0c196 {uri: 'N59ca6eb879fa46a6a5c265fbecc0c196'}),
# (n422:N89e6b4d91b3244e7a16e752457dc8297 {uri: 'N89e6b4d91b3244e7a16e752457dc8297'}),
# (n423:N0ebbeb4f874240e9ab4587dbd5c85832 {uri: 'N0ebbeb4f874240e9ab4587dbd5c85832'}),
# (n424:Nbb2c02f55ccc4f63b7a89bd1066ac972 {uri: 'Nbb2c02f55ccc4f63b7a89bd1066ac972'}),
# (n425:wine_ChateauChevalBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauChevalBlanc'}),
# (n426:wine_SemillonOrSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SemillonOrSauvignonBlanc'}),
# (n427:Nc6728f7ddcf6405bb3cefcca25990fa5 {uri: 'Nc6728f7ddcf6405bb3cefcca25990fa5'}),
# (n428:N346804c9be9c49c7976155c77f0400d0 {uri: 'N346804c9be9c49c7976155c77f0400d0'}),
# (n429:N92a2805c3e9143f38a1a5418583c2c47 {uri: 'N92a2805c3e9143f38a1a5418583c2c47'}),
# (n430:N299dc02d6ad34d999e3bd6eed1c87a9c {uri: 'N299dc02d6ad34d999e3bd6eed1c87a9c'}),
# (n431:Nc0d5d05156594bccb1c53d5f09d9881c {uri: 'Nc0d5d05156594bccb1c53d5f09d9881c'}),
# (n432:N6f76f3a4306d4ad78ba3ae9bc28f7011 {uri: 'N6f76f3a4306d4ad78ba3ae9bc28f7011'}),
# (n433:N9b37c9b70de14f1b8be8defe7db0a6e2 {uri: 'N9b37c9b70de14f1b8be8defe7db0a6e2'}),
# (n434:Nafd059932f77447eaccb2e035e19b41d {uri: 'Nafd059932f77447eaccb2e035e19b41d'}),
# (n435:wine_LaneTanner {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTanner'}),
# (n436:Nd0e29c0aa7824c8695154a2896a851f7 {uri: 'Nd0e29c0aa7824c8695154a2896a851f7'}),
# (n437:Na5e2ef878e7343b186a756e638d87e2b {uri: 'Na5e2ef878e7343b186a756e638d87e2b'}),
# (n438:wine_CotesDOr {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotesDOr'}),
# (n439:N1e9ff8c992964d009df8e7edee0afeba {uri: 'N1e9ff8c992964d009df8e7edee0afeba'}),
# (n440:wine_WineFlavor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineFlavor'}),
# (n441:N46951e771d0e4409b5eadc34327b40fe {uri: 'N46951e771d0e4409b5eadc34327b40fe'}),
# (n442:N2cd6f69fc4a8492e95c44a29f50dbe75 {uri: 'N2cd6f69fc4a8492e95c44a29f50dbe75'}),
# (n443:wine_hasBody {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasBody'}),
# (n444:wine_ChateauMorgon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMorgon'}),
# (n445:N81e884800297423d93e6b498d4a67785 {uri: 'N81e884800297423d93e6b498d4a67785'}),
# (n446:wine_MountadamRiesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamRiesling'}),
# (n447:wine_PetiteSyrah {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteSyrah'}),
# (n448:N1d5de70ef93d491b94708cf5b8653c7d {uri: 'N1d5de70ef93d491b94708cf5b8653c7d'}),
# (n449:wine_EarlyHarvest {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EarlyHarvest'}),
# (n450:Nf5a88a1ddde9450d888d5ae9e261e9b9 {uri: 'Nf5a88a1ddde9450d888d5ae9e261e9b9'}),
# (n451:wine_FullBodiedWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FullBodiedWine'}),
# (n452:wine_PulignyMontrachet {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PulignyMontrachet'}),
# (n453:wine_SangioveseGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SangioveseGrape'}),
# (n454:wine_SaucelitoCanyon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SaucelitoCanyon'}),
# (n455:N01e97750db0a43a0995d5c2757c8e503 {uri: 'N01e97750db0a43a0995d5c2757c8e503'}),
# (n456:N599080fad982417cb3ca9b83a7316f5b {uri: 'N599080fad982417cb3ca9b83a7316f5b'}),
# (n457:wine_Mountadam {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Mountadam'}),
# (n458:wine_ChateauDYchem {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDYchem'}),
# (n459:N70ab145aca4341e8b57819883c7f9413 {uri: 'N70ab145aca4341e8b57819883c7f9413'}),
# (n460:wine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine'}),
# (n461:N7e2b5b368b1a4d45828ef15d7610dd72 {uri: 'N7e2b5b368b1a4d45828ef15d7610dd72'}),
# (n462:Ne2265c00f7b7428a865cb3e307364135 {uri: 'Ne2265c00f7b7428a865cb3e307364135'}),
# (n463:N5dd0e04bd3914b52a7b25f7dcb46649f {uri: 'N5dd0e04bd3914b52a7b25f7dcb46649f'}),
# (n464:N53a78b6e153c4a7fb733c877ff47bfc8 {uri: 'N53a78b6e153c4a7fb733c877ff47bfc8'}),
# (n465:Nf0aaa021d0324af0b3cb085ed2b366e6 {uri: 'Nf0aaa021d0324af0b3cb085ed2b366e6'}),
# (n466:N65fa405d06844bb6862d29fb37993a3c {uri: 'N65fa405d06844bb6862d29fb37993a3c'}),
# (n467:wine_Bancroft {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Bancroft'}),
# (n468:Ndc369754f1ba4161adf1fe6910f7e717 {uri: 'Ndc369754f1ba4161adf1fe6910f7e717'}),
# (n469:N13fa272719a341d883303b6a8dc27af9 {uri: 'N13fa272719a341d883303b6a8dc27af9'}),
# (n470:wine_PinotNoir {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoir'}),
# (n471:Nde849b2223054bfa884ca99b22cb0d80 {uri: 'Nde849b2223054bfa884ca99b22cb0d80'}),
# (n472:Nefbedd076f2548cf81ae7a5f83970890 {uri: 'Nefbedd076f2548cf81ae7a5f83970890'}),
# (n473:Nbbaa0bab8ce24e78afb195560b19d4f8 {uri: 'Nbbaa0bab8ce24e78afb195560b19d4f8'}),
# (n474:wine_LateHarvest {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LateHarvest'}),
# (n475:N9de21f35f4544424952397f6c2a1bcf9 {uri: 'N9de21f35f4544424952397f6c2a1bcf9'}),
# (n476:wine_Gamay {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Gamay'}),
# (n477:N55ceb9eaef214d8fbc7b8f65c08cc229 {uri: 'N55ceb9eaef214d8fbc7b8f65c08cc229'}),
# (n478:wine_StGenevieve {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StGenevieve'}),
# (n479:Ncf1a518f48ed48a08536ed3e502fdc62 {uri: 'Ncf1a518f48ed48a08536ed3e502fdc62'}),
# (n480:wine_Medoc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medoc'}),
# (n481:Nd3988b15efd5446ba19d01c0a683b4e4 {uri: 'Nd3988b15efd5446ba19d01c0a683b4e4'}),
# (n482:Na5b807977c5a4a7da0cb829a73a5c9db {uri: 'Na5b807977c5a4a7da0cb829a73a5c9db'}),
# (n483:food {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/food'}),
# (n484:wine_DessertWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DessertWine'}),
# (n485:wine_StEmilion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StEmilion'}),
# (n486:wine_PeterMccoy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PeterMccoy'}),
# (n487:N679eeb45d5004c65b0a0e708171df780 {uri: 'N679eeb45d5004c65b0a0e708171df780'}),
# (n488:wine_Sancerre {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sancerre'}),
# (n489:N56ff8782636c4d6ba015cee2962afb62 {uri: 'N56ff8782636c4d6ba015cee2962afb62'}),
# (n490:N94232b02e5ac4ce08ed46a975ed50af7 {uri: 'N94232b02e5ac4ce08ed46a975ed50af7'}),
# (n491:N861f25b87c964362afe638185b323bca {uri: 'N861f25b87c964362afe638185b323bca'}),
# (n492:Neaf49886121546b1871cf41fc65bc2e7 {uri: 'Neaf49886121546b1871cf41fc65bc2e7'}),
# (n493:wine_ChardonnayGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChardonnayGrape'}),
# (n494:Ne8bb39338a6e4a75a78764eeef086bec {uri: 'Ne8bb39338a6e4a75a78764eeef086bec'}),
# (n495:wine_SevreEtMaine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaine'}),
# (n496:Nf7406d37a61d4fc6b602db7116d0c68d {uri: 'Nf7406d37a61d4fc6b602db7116d0c68d'}),
# (n497:wine_RedBordeaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedBordeaux'}),
# (n498:N1e8675db2f2d4ca2ac4de23518fc2c89 {uri: 'N1e8675db2f2d4ca2ac4de23518fc2c89'}),
# (n499:N2016e77744b04a3aaa316f775132a39c {uri: 'N2016e77744b04a3aaa316f775132a39c'}),
# (n500:N572a80bdce1341c990bf0de1bec0c15d {uri: 'N572a80bdce1341c990bf0de1bec0c15d'}),
# (n501:N5918022204ec463b9fd135cb1db91c9f {uri: 'N5918022204ec463b9fd135cb1db91c9f'}),
# (n502:wine_ChateauMargauxWinery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMargauxWinery'}),
# (n503:wine_hasMaker {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasMaker'}),
# (n504:Ne348c230da314ca48064cacbb09c77af {uri: 'Ne348c230da314ca48064cacbb09c77af'}),
# (n505:N1bd7e3d7cafd446e9fe93bd9c92fb3f5 {uri: 'N1bd7e3d7cafd446e9fe93bd9c92fb3f5'}),
# (n506:N7bda7219478a413b8794796e65577e91 {uri: 'N7bda7219478a413b8794796e65577e91'}),
# (n507:N32f8a4b55fb8472b98c65b03baecd75d {uri: 'N32f8a4b55fb8472b98c65b03baecd75d'}),
# (n508:N50896746d1ad44a3815bfb9ec8352378 {uri: 'N50896746d1ad44a3815bfb9ec8352378'}),
# (n509:Neb5d48605beb4a6a85c8237dd664cd10 {uri: 'Neb5d48605beb4a6a85c8237dd664cd10'}),
# (n510:wine_Margaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Margaux'}),
# (n511:Nb929891a0d6e44cba1f4e6781bc24800 {uri: 'Nb929891a0d6e44cba1f4e6781bc24800'}),
# (n512:wine_OffDry {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#OffDry'}),
# (n513:Nb7d95fdfbde649ff83ab11abfb950090 {uri: 'Nb7d95fdfbde649ff83ab11abfb950090'}),
# (n514:owl_TransitiveProperty {uri: 'http://www.w3.org/2002/07/owl#TransitiveProperty'}),
# (n515:Nedfb25f1df814e3c9c5858d30dd1b91a {uri: 'Nedfb25f1df814e3c9c5858d30dd1b91a'}),
# (n516:N3fa50ae917954fc7a893820866d32252 {uri: 'N3fa50ae917954fc7a893820866d32252'}),
# (n517:wine_DryRiesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryRiesling'}),
# (n518:N2e842f211c5240bf94443de2b024ccd1 {uri: 'N2e842f211c5240bf94443de2b024ccd1'}),
# (n519:N43d162ef50ae40e1a387e0af97f51dc8 {uri: 'N43d162ef50ae40e1a387e0af97f51dc8'}),
# (n520:Nf18afd938f9f410899a4d6d6625313d5 {uri: 'Nf18afd938f9f410899a4d6d6625313d5'}),
# (n521:wine_WhiteTableWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteTableWine'}),
# (n522:Nd3b0bb715d094938accfd0081ca9dc97 {uri: 'Nd3b0bb715d094938accfd0081ca9dc97'}),
# ...
# (n259)-[:wine_locatedIn]-(n310),
# (n176)-[:wine_hasSugar]-(n721),
# (n228)-[:wine_locatedIn]-(n624),
# (n490)-[:owl_onProperty]-(n148),
# (n95)-[:ID_22_rdf_syntax_ns_first]-(n512),
# (n56)-[:owl_onProperty]-(n72),
# (n630)-[:wine_locatedIn]-(n536),
# (n360)-[:wine_hasMaker]-(n444),
# (n562)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n684)-[:wine_hasBody]-(n19),
# (n236)-[:wine_hasBody]-(n232),
# (n276)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n103)-[:ID_22_rdf_syntax_ns_type]-(n588),
# (n506)-[:owl_hasValue]-(n19),
# (n403)-[:ID_22_rdf_syntax_ns_first]-(n478),
# (n269)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n65)-[:owl_onProperty]-(n503),
# (n102)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n12)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n12)-[:owl_hasValue]-(n103),
# (n608)-[:wine_hasMaker]-(n30),
# (n492)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n504)-[:ID_22_rdf_syntax_ns_first]-(n145),
# (n585)-[:ID_22_rdf_syntax_ns_first]-(n232),
# (n315)-[:ID_22_rdf_syntax_ns_type]-(n710),
# (n130)-[:wine_locatedIn]-(n384),
# (n499)-[:ID_22_rdf_syntax_ns_first]-(n171),
# (n227)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n399)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n359)-[:wine_hasSugar]-(n721),
# (n183)-[:ID_22_rdf_syntax_ns_first]-(n19),
# (n512)-[:ID_22_rdf_syntax_ns_type]-(n150),
# (n22)-[:wine_hasFlavor]-(n260),
# (n75)-[:wine_hasFlavor]-(n400),
# (n65)-[:owl_allValuesFrom]-(n160),
# (n87)-[:owl_hasValue]-(n103),
# (n349)-[:ID_22_rdf_syntax_ns_type]-(n73),
# (n617)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n719)-[:wine_hasMaker]-(n303),
# (n334)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n23)-[:owl_onProperty]-(n148),
# (n83)-[:ID_22_rdf_syntax_ns_type]-(n710),
# (n144)-[:owl_hasValue]-(n512),
# (n671)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n525)-[:owl_inverseOf]-(n72),
# (n312)-[:ID_22_rdf_syntax_ns_type]-(n710),
# (n375)-[:ID_22_rdf_syntax_ns_first]-(n400),
# (n296)-[:owl_onProperty]-(n443),
# (n158)-[:owl_hasValue]-(n17),
# (n47)-[:ID_22_rdf_syntax_ns_type]-(n285),
# (n248)-[:owl_onProperty]-(n2),
# (n301)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n656)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n275)-[:ID_22_rdf_syntax_ns_type]-(n288),
# (n466)-[:ID_22_rdf_syntax_ns_first]-(n260),
# (n710)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n279)-[:owl_onProperty]-(n72),
# (n97)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n129)-[:owl_onProperty]-(n148),
# (n274)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n322)-[:ID_22_rdf_syntax_ns_type]-(n288),
# (n640)-[:owl_hasValue]-(n721),
# (n525)-[:ID_22_rdf_syntax_ns_type]-(n5),
# (n578)-[:owl_hasValue]-(n312),
# (n613)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n43)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n213)-[:owl_onProperty]-(n148),
# (n674)-[:ID_22_rdf_syntax_ns_type]-(n710),
# (n88)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n90)-[:owl_onProperty]-(n6),
# (n556)-[:owl_onProperty]-(n2),
# (n474)-[:rdf_schema_subClassOf]-(n330),
# (n20)-[:wine_hasSugar]-(n721),
# (n44)-[:owl_onProperty]-(n113),
# (n6)-[:ID_22_rdf_syntax_ns_type]-(n298),
# (n290)-[:ID_22_rdf_syntax_ns_type]-(n470),
# (n428)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n240)-[:ID_22_rdf_syntax_ns_first]-(n164),
# (n68)-[:wine_locatedIn]-(n411),
# (n283)-[:wine_hasSugar]-(n721),
# (n388)-[:owl_hasValue]-(n103),
# (n180)-[:wine_locatedIn]-(n275),
# (n359)-[:wine_hasFlavor]-(n260),
# (n191)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n21)-[:ID_22_rdf_syntax_ns_type]-(n288),
# (n3)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n349)-[:wine_hasMaker]-(n458),
# (n143)-[:ID_22_rdf_syntax_ns_first]-(n330),
# (n152)-[:ID_22_rdf_syntax_ns_first]-(n330),
# (n337)-[:wine_locatedIn]-(n411),
# (n617)-[:owl_onProperty]-(n113),
# (n554)-[:rdf_schema_range]-(n168),
# (n442)-[:ID_22_rdf_syntax_ns_first]-(n119),
# (n722)-[:wine_locatedIn]-(n714),
# (n488)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n158)-[:owl_onProperty]-(n2),
# (n416)-[:owl_onProperty]-(n72),
# (n567)-[:ID_22_rdf_syntax_ns_first]-(n232),
# (n503)-[:ID_22_rdf_syntax_ns_type]-(n298),
# (n323)-[:wine_locatedIn]-(n624),
# (n677)-[:owl_onProperty]-(n72),
# (n434)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n232)-[:ID_22_rdf_syntax_ns_type]-(n588),
# (n356)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n369)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n250)-[:wine_locatedIn]-(n624),
# (n236)-[:ID_22_rdf_syntax_ns_type]-(n222),
# (n105)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n361)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n453)-[:ID_22_rdf_syntax_ns_type]-(n710),
# (n368)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n459)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n688)-[:ID_22_rdf_syntax_ns_type]-(n308),
# (n349)-[:wine_hasFlavor]-(n400),
# (n292)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n378)-[:ID_22_rdf_syntax_ns_first]-(n330),
# (n135)-[:wine_hasBody]-(n232),
# (n623)-[:owl_onProperty]-(n72),
# (n512)-[:owl_differentFrom]-(n634),
# (n53)-[:ID_22_rdf_syntax_ns_first]-(n330),
# (n49)-[:ID_22_rdf_syntax_ns_first]-(n634),
# (n545)-[:ID_22_rdf_syntax_ns_first]-(n208),
# (n577)-[:rdf_schema_subClassOf]-(n76),
# (n196)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n598)-[:owl_hasValue]-(n197),
# (n36)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n34)-[:ID_22_rdf_syntax_ns_type]-(n116),
# (n643)-[:ID_22_rdf_syntax_ns_first]-(n19),
# (n672)-[:wine_hasFlavor]-(n400),
# (n382)-[:rdf_schema_domain]-(n330),
# (n228)-[:wine_hasFlavor]-(n260),
# (n113)-[:rdf_schema_subPropertyOf]-(n382),
# (n370)-[:ID_22_rdf_syntax_ns_type]-(n288),
# (n8)-[:wine_hasSugar]-(n721),
# (n200)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n313)-[:owl_onProperty]-(n148),
# (n88)-[:owl_onProperty]-(n148),
# (n265)-[:ID_22_rdf_syntax_ns_first]-(n260),
# (n659)-[:ID_22_rdf_syntax_ns_first]-(n400),
# (n441)-[:ID_22_rdf_syntax_ns_first]-(n260),
# (n411)-[:ID_22_rdf_syntax_ns_type]-(n288),
# (n414)-[:ID_22_rdf_syntax_ns_type]-(n588),
# (n613)-[:owl_onProperty]-(n72),
# (n406)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n326)-[:owl_onProperty]-(n6),
# (n194)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n109)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n155)-[:wine_hasMaker]-(n635),
# (n722)-[:wine_hasSugar]-(n721),
# (n524)-[:ID_22_rdf_syntax_ns_first]-(n128),
# (n465)-[:ID_22_rdf_syntax_ns_first]-(n197),
# (n456)-[:ID_22_rdf_syntax_ns_first]-(n63),
# (n428)-[:owl_onProperty]-(n72),
# (n701)-[:ID_22_rdf_syntax_ns_first]-(n80),
# (n450)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n233)-[:ID_22_rdf_syntax_ns_first]-(n512),
# (n687)-[:ID_22_rdf_syntax_ns_type]-(n621),
# (n533)-[:owl_hasValue]-(n197),
# (n383)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n290)-[:wine_hasMaker]-(n435),
# (n220)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n30)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n719)-[:wine_hasBody]-(n232),
# (n385)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n323)-[:wine_hasSugar]-(n721),
# (n282)-[:owl_hasValue]-(n103),
# (n82)-[:owl_onProperty]-(n72),
# (n101)-[:ID_22_rdf_syntax_ns_type]-(n288),
# (n350)-[:owl_onProperty]-(n72),
# (n495)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n123)-[:ID_22_rdf_syntax_ns_type]-(n202),
# (n648)-[:ID_22_rdf_syntax_ns_first]-(n330),
# (n688)-[:wine_hasBody]-(n19),
# (n338)-[:ID_22_rdf_syntax_ns_first]-(n526),
# (n304)-[:ID_22_rdf_syntax_ns_first]-(n330),
# (n557)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n24)-[:owl_onProperty]-(n554),
# (n8)-[:wine_hasFlavor]-(n260),
# (n259)-[:wine_hasFlavor]-(n400),
# (n721)-[:ID_22_rdf_syntax_ns_type]-(n588),
# (n19)-[:ID_22_rdf_syntax_ns_type]-(n577),
# (n382)-[:rdf_schema_range]-(n292),
# (n695)-[:owl_onProperty]-(n6),
# (n699)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n642)-[:ID_22_rdf_syntax_ns_first]-(n19),
# (n603)-[:wine_locatedIn]-(n201),
# (n277)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n426)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n361)-[:owl_onProperty]-(n72),
# (n75)-[:wine_hasMaker]-(n671),
# (n184)-[:ID_22_rdf_syntax_ns_type]-(n168),
# (n722)-[:wine_hasFlavor]-(n260),
# (n203)-[:ID_22_rdf_syntax_ns_first]-(n678),
# (n92)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n518)-[:owl_hasValue]-(n260),
# (n443)-[:rdf_schema_subPropertyOf]-(n382),
# (n694)-[:ID_22_rdf_syntax_ns_first]-(n420),
# (n115)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n363)-[:wine_hasFlavor]-(n400),
# (n592)-[:owl_onProperty]-(n443),
# (n446)-[:wine_hasMaker]-(n457),
# (n8)-[:ID_22_rdf_syntax_ns_type]-(n552),
# (n58)-[:ID_22_rdf_syntax_ns_type]-(n288),
# (n446)-[:wine_hasSugar]-(n721),
# (n684)-[:wine_hasColor]-(n197),
# (n366)-[:ID_22_rdf_syntax_ns_first]-(n609),
# (n47)-[:wine_hasBody]-(n19),
# (n443)-[:rdf_schema_range]-(n577),
# (n118)-[:wine_locatedIn]-(n7),
# (n716)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n500)-[:owl_onProperty]-(n443),
# (n475)-[:ID_22_rdf_syntax_ns_first]-(n586),
# (n71)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n629)-[:ID_22_rdf_syntax_ns_type]-(n202),
# (n42)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n560)-[:ID_22_rdf_syntax_ns_first]-(n542),
# (n719)-[:wine_locatedIn]-(n110),
# (n139)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n684)-[:wine_hasFlavor]-(n260),
# (n700)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n506)-[:owl_onProperty]-(n443),
# (n688)-[:wine_hasMaker]-(n119),
# (n549)-[:ID_22_rdf_syntax_ns_first]-(n232),
# (n688)-[:wine_locatedIn]-(n624),
# (n670)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n247)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n94)-[:ID_22_rdf_syntax_ns_first]-(n414),
# (n714)-[:wine_locatedIn]-(n50),
# (n190)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n580)-[:ID_22_rdf_syntax_ns_first]-(n426),
# (n458)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n423)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n54)-[:wine_hasBody]-(n19),
# (n385)-[:owl_onProperty]-(n72),
# (n474)-[:owl_disjointWith]-(n449),
# (n517)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n22)-[:ID_22_rdf_syntax_ns_type]-(n77),
# (n480)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n704)-[:owl_onProperty]-(n443),
# (n575)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n8)-[:wine_hasMaker]-(n454),
# (n478)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n196)-[:owl_hasValue]-(n384),
# (n111)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n106)-[:wine_hasSugar]-(n721),
# (n463)-[:ID_22_rdf_syntax_ns_first]-(n527),
# (n164)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n685)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n156)-[:owl_hasValue]-(n260),
# (n238)-[:ID_22_rdf_syntax_ns_first]-(n109),
# (n223)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n584)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n662)-[:owl_onProperty]-(n113),
# (n381)-[:ID_22_rdf_syntax_ns_type]-(n288),
# (n636)-[:ID_22_rdf_syntax_ns_type]-(n588),
# (n133)-[:ID_22_rdf_syntax_ns_type]-(n447),
# (n602)-[:wine_hasSugar]-(n634),
# (n4)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n41)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n589)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n543)-[:wine_hasBody]-(n19),
# (n661)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n702)-[:owl_hasValue]-(n14),
# (n343)-[:owl_hasValue]-(n409),
# (n237)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n267)-[:ID_22_rdf_syntax_ns_type]-(n288),
# (n468)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n36)-[:owl_onProperty]-(n443),
# (n718)-[:owl_onProperty]-(n6),
# (n632)-[:owl_onProperty]-(n113),
# (n440)-[:rdf_schema_subClassOf]-(n76),
# (n445)-[:owl_hasValue]-(n337),
# (n306)-[:ID_22_rdf_syntax_ns_type]-(n510),
# (n241)-[:ID_22_rdf_syntax_ns_first]-(n260),
# (n700)-[:owl_onProperty]-(n148),
# (n522)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n602)-[:wine_hasBody]-(n414),
# (n377)-[:ID_22_rdf_syntax_ns_first]-(n260),
# (n473)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n688)-[:wine_hasSugar]-(n721),
# (n307)-[:ID_22_rdf_syntax_ns_first]-(n76),
# (n247)-[:owl_onProperty]-(n148),
# (n719)-[:wine_hasSugar]-(n721),
# (n106)-[:wine_hasFlavor]-(n260),
# (n280)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n422)-[:owl_hasValue]-(n634),
# (n115)-[:ID_22_rdf_syntax_ns_first]-(n19),
# (n518)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n338)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n471)-[:ID_22_rdf_syntax_ns_first]-(n571),
# (n252)-[:ID_22_rdf_syntax_ns_first]-(n197),
# (n339)-[:ID_22_rdf_syntax_ns_first]-(n256),
# (n322)-[:wine_locatedIn]-(n275),
# (n597)-[:ID_22_rdf_syntax_ns_first]-(n124),
# (n592)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n460)-[:owl_priorVersion]-(n27),
# (n24)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n704)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n230)-[:ID_22_rdf_syntax_ns_first]-(n330),
# (n8)-[:wine_hasVintageYear]-(n184),
# (n542)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n630)-[:ID_22_rdf_syntax_ns_type]-(n470),
# (n42)-[:ID_22_rdf_syntax_ns_first]-(n19),
# (n150)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n73)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n687)-[:rdf_schema_domain]-(n288),
# (n553)-[:ID_22_rdf_syntax_ns_first]-(n330),
# (n107)-[:ID_22_rdf_syntax_ns_type]-(n288),
# (n106)-[:wine_hasMaker]-(n478),
# (n228)-[:wine_hasMaker]-(n410),
# (n536)-[:wine_locatedIn]-(n569),
# (n279)-[:owl_hasValue]-(n145),
# (n558)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n47)-[:wine_hasSugar]-(n721),
# (n264)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n669)-[:owl_hasValue]-(n315),
# (n290)-[:wine_hasFlavor]-(n647),
# (n223)-[:owl_onProperty]-(n72),
# (n506)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n457)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n688)-[:wine_hasFlavor]-(n260),
# (n538)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n507)-[:ID_22_rdf_syntax_ns_first]-(n586),
# (n420)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n75)-[:wine_hasSugar]-(n721),
# (n12)-[:owl_onProperty]-(n113),
# (n328)-[:owl_onProperty]-(n72),
# (n365)-[:ID_22_rdf_syntax_ns_first]-(n647),
# (n408)-[:owl_hasValue]-(n103),
# (n216)-[:wine_hasBody]-(n19),
# (n353)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n581)-[:owl_onProperty]-(n113),
# (n491)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n159)-[:owl_hasValue]-(n118),
# (n468)-[:owl_onProperty]-(n72),
# (n604)-[:ID_22_rdf_syntax_ns_type]-(n488),
# (n397)-[:ID_22_rdf_syntax_ns_first]-(n414),
# (n320)-[:owl_onProperty]-(n443),
# (n556)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n54)-[:wine_hasSugar]-(n721),
# (n418)-[:owl_onProperty]-(n6),
# (n359)-[:wine_hasBody]-(n414),
# (n156)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n142)-[:wine_locatedIn]-(n541),
# (n419)-[:ID_22_rdf_syntax_ns_type]-(n710),
# (n630)-[:wine_hasMaker]-(n457),
# (n443)-[:ID_22_rdf_syntax_ns_type]-(n298),
# (n273)-[:owl_onProperty]-(n6),
# (n155)-[:wine_locatedIn]-(n714),
# (n647)-[:ID_22_rdf_syntax_ns_type]-(n588),
# (n415)-[:ID_22_rdf_syntax_ns_first]-(n19),
# (n191)-[:owl_hasValue]-(n197),
# (n18)-[:ID_22_rdf_syntax_ns_first]-(n636),
# (n584)-[:owl_onProperty]-(n72),
# (n633)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n286)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n0)-[:owl_hasValue]-(n634),
# (n600)-[:wine_hasSugar]-(n721),
# (n299)-[:owl_hasValue]-(n493),
# (n27)-[:ID_22_rdf_syntax_ns_type]-(n697),
# (n236)-[:wine_hasMaker]-(n157),
# (n710)-[:rdf_schema_subClassOf]-(n371),
# (n247)-[:owl_hasValue]-(n721),
# (n311)-[:owl_hasValue]-(n386),
# (n158)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n365)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n293)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n687)-[:ID_22_rdf_syntax_ns_type]-(n5),
# (n136)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n434)-[:owl_hasValue]-(n197),
# (n75)-[:wine_locatedIn]-(n402),
# (n625)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n388)-[:owl_onProperty]-(n113),
# (n684)-[:wine_hasMaker]-(n407),
# (n191)-[:owl_onProperty]-(n113),
# (n446)-[:ID_22_rdf_syntax_ns_type]-(n517),
# (n634)-[:ID_22_rdf_syntax_ns_type]-(n150),
# (n491)-[:ID_22_rdf_syntax_ns_first]-(n721),
# (n455)-[:ID_22_rdf_syntax_ns_first]-(n330),
# (n197)-[:ID_22_rdf_syntax_ns_type]-(n588),
# (n110)-[:wine_locatedIn]-(n50),
# (n718)-[:owl_hasValue]-(n647),
# (n619)-[:ID_22_rdf_syntax_ns_first]-(n444),
# (n43)-[:owl_onProperty]-(n72),
# (n720)-[:owl_onProperty]-(n6),
# (n446)-[:wine_hasFlavor]-(n647),
# (n47)-[:wine_hasFlavor]-(n260),
# (n608)-[:wine_hasBody]-(n232),
# (n547)-[:ID_22_rdf_syntax_ns_first]-(n407),
# (n329)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n470)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n484)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n683)-[:owl_onProperty]-(n6),
# (n535)-[:ID_22_rdf_syntax_ns_first]-(n330),
# (n404)-[:owl_onProperty]-(n443),
# (n189)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n439)-[:ID_22_rdf_syntax_ns_first]-(n285),
# (n255)-[:ID_22_rdf_syntax_ns_first]-(n287),
# (n585)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n332)-[:ID_22_rdf_syntax_ns_type]-(n28),
# (n429)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n50)-[:ID_22_rdf_syntax_ns_type]-(n288),
# (n353)-[:owl_onProperty]-(n72),
# (n278)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n23)-[:owl_hasValue]-(n634),
# (n62)-[:ID_22_rdf_syntax_ns_type]-(n114),
# (n162)-[:wine_locatedIn]-(n405),
# (n537)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n20)-[:ID_22_rdf_syntax_ns_type]-(n116),
# (n335)-[:ID_22_rdf_syntax_ns_rest]-(n316),
# (n96)-[:ID_22_rdf_syntax_ns_type]-(n160),
# (n481)-[:ID_22_rdf_syntax_ns_type]-(n202),
# (n592)-[:owl_hasValue]-(n414),
# (n714)-[:ID_22_rdf_syntax_ns_type]-(n288),
# (n432)-[:owl_onProperty]-(n2),
# (n145)-[:ID_22_rdf_syntax_ns_type]-(n588),
# (n34)-[:wine_locatedIn]-(n624),
# (n54)-[:wine_hasFlavor]-(n260),
# (n295)-[:owl_hasValue]-(n260)

# %%
# %%time

# Save Cypher query to file
with open(f"{path_data}/{example_name}.cypher", "w") as f:
    f.write(graph_CREATE_command_v1)
# Out:
# CPU times: user 1.17 ms, sys: 18 μs, total: 1.19 ms
# Wall time: 677 μs

# %% [markdown]
# # Create graph using `turingdb` python package

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         See <a href="https://docs.turingdb.ai/quickstart">TuringDB Get started documentation</a> for the important steps to follow :
#     </h2>
#     <h3>
#         <ul>
#             <li>Create your TuringDB account</li>
#             <li>Create your instance in the <a href="https://console.turingdb.ai/auth">TuringDB Cloud UI</a></li>
#             <li>Copy your Instance ID from the Database Instances management page</li>
#             <li>Get API Key from the Settings in UI</li>
#         </ul>
#         Remember to have your instance active while working in this notebook !
#     </h3>
# </div>

# %%
from turingdb import TuringDB

# Create TuringDB client
client = TuringDB(
    host="http://localhost:6666"  # Remove this parameter and set the two parameters below
    # instance_id=os.getenv("INSTANCE_ID"),
    # auth_token=os.getenv("AUTH_TOKEN"),
)

# %%
# %%time

client.s3_connect(
    bucket_name="turing-internal",
    region="eu-west-2",
    access_key=os.getenv("AWS_ACCESS_KEY"),
    secret_key=os.getenv("AWS_SECRET_KEY"),
)
# Out:
# CPU times: user 78.8 ms, sys: 47 ms, total: 126 ms
# Wall time: 173 ms

# %%
# Get list of loaded graphs
list_graphs = client.list_loaded_graphs()
list_graphs
# Out:
# ['default']

# %%
# Set graph name
graph_name_prefix = example_name
graph_name_nb_suffix = str(
    max(
        [
            int(re.sub(graph_name_prefix, "", g))
            for g in list_graphs
            if g.startswith(graph_name_prefix)
            and re.sub(graph_name_prefix, "", g).isdigit()
        ]
        + [0]
    )
    + 1
)
graph_name = graph_name_prefix + graph_name_nb_suffix
graph_name = re.sub("-", "_", graph_name)
print(f"graph_name: {graph_name}")
# Out:
# graph_name: wine_ontology1

# %%
from turingdb.exceptions import TuringDBException

# %%
# %%time

# Set graph
try:
    client.create_graph(graph_name)
except TuringDBException as e:
    print(e)

# Set working graph
client.set_graph(graph_name)
# Out:
# CPU times: user 3.85 ms, sys: 0 ns, total: 3.85 ms
# Wall time: 18 ms

# %%
# %%time

# Create a new change on the graph
client.checkout()
change = client.new_change()
print(f"Current change {change}")

# Checkout into the change
client.checkout(change=change)
# Out:
# Current change 0
# CPU times: user 2.89 ms, sys: 0 ns, total: 2.89 ms
# Wall time: 2.5 ms

# %%
# %%time

# Run CREATE command
print("\nExecuting query on TuringDB...")
start_time = time.time()
result = client.query(graph_CREATE_command_v1)
execution_time = time.time() - start_time
print(f"✓ Graph created successfully in {execution_time:.2f} seconds")

# Commit the change
client.query("COMMIT")
client.query("CHANGE SUBMIT")

# Checkout into main
client.checkout()
# Out:
# Executing query on TuringDB...
# CPU times: user 3.16 ms, sys: 1.02 ms, total: 4.18 ms
# Wall time: 3.1 ms
# ---------------------------------------------------------------------------
# TuringDBException                         Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '\n# Run CREATE command\nprint("\\nExecuting query on TuringDB...")\nstart_time = time.time()\nresult = client.query(graph_CREATE_command_v1)\nexecution_time = time.time() - start_time\nprint(f"✓ Graph created successfully in {execution_time:.2f} seconds")\n\n# Commit the change\nclient.query("COMMIT")\nclient.query("CHANGE SUBMIT")\n\n# Checkout into main\nclient.checkout()\n')
#
# File ~/.cache/uv/archive-v0/4b3v0Vq7OGrxiQadajE5L/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.cache/uv/archive-v0/4b3v0Vq7OGrxiQadajE5L/lib/python3.13/site-packages/IPython/core/magics/execution.py:1470, in ExecutionMagics.time(self, line, cell, local_ns)
#    1468 if interrupt_occured:
#    1469     if exit_on_interrupt and captured_exception:
# -> 1470         raise captured_exception
#    1471     return
#    1472 return out
#
# File ~/.cache/uv/archive-v0/4b3v0Vq7OGrxiQadajE5L/lib/python3.13/site-packages/IPython/core/magics/execution.py:1434, in ExecutionMagics.time(self, line, cell, local_ns)
#    1432 st = clock2()
#    1433 try:
# -> 1434     exec(code, glob, local_ns)
#    1435     out = None
#    1436     # multi-line %%time case
#
# File <timed exec>:4
#
# File ~/turingdb-examples/.venv/lib/python3.13/site-packages/turingdb/turingdb.py:82, in TuringDB.query(self, query)
#      81 def query(self, query: str):
# ---> 82     json = self._send_request("query", data=query, params=self._params)
#      84     if not isinstance(json, dict):
#      85         raise TuringDBException("Invalid response from the server")
#
# File ~/turingdb-examples/.venv/lib/python3.13/site-packages/turingdb/turingdb.py:184, in TuringDB._send_request(self, path, data, params)
#     182         if details is not None:
#     183             err = f"{err}: {details}"
# --> 184         raise TuringDBException(err)
#     186 self._t1 = time.time()
#     187 self._total_exec_time = (self._t1 - self._t0) * 1000
#
# TuringDBException: GRAPH_NOT_FOUND: No error message available.

# %% [markdown]
# # Query TuringDB

# %% [markdown]
# ## Use metaqueries to have insight on graph overall structure
#
# <h3>
#     To learn more about 📮 Metaqueries, please check TuringDB documentation on this <a href="https://turingdb.mintlify.app/query/cypher_subset#%F0%9F%93%AE-metaqueries">link</a>
# </h3>

# %%
# %%time

# CALL PROPERTIES() - returns a column of all the different node and edge properties and their types in the database
command = """
CALL PROPERTIES()
"""
df_PROPERTIES = client.query(command)
if df_PROPERTIES.empty:
    print("No result found")
else:
    df_PROPERTIES.columns = ["Property_ID", "Property_name", "Property_type"]
    display(df_PROPERTIES)
# Out:
# No result found
# CPU times: user 3.26 ms, sys: 1.94 ms, total: 5.2 ms
# Wall time: 3.55 ms

# %%
# Get node properties
nodes_properties = df_PROPERTIES["Property_name"].values.tolist()
print(f"Node properties: {nodes_properties}")
# Out:
# Node properties: ['id', 'type', 'amount', 'step', 'is_fraud', 'is_flagged', 'oldbalance', 'newbalance']

# %%
# %%time

# CALL LABELS () - returns a column of all the different node labels
command = """
CALL LABELS()
"""
df_LABELS = client.query(command)
if df_LABELS.empty:
    print("No result found")
else:
    df_LABELS.columns = ["Node_type_ID", "Node_label"]
    display(df_LABELS)
# Out:
#    Node_type_ID   Node_label
# 0             0      Account
# 1             1  Transaction
# CPU times: user 6.76 ms, sys: 1.98 ms, total: 8.74 ms
# Wall time: 7.3 ms

# %%
# %%time

# CALL EDGETYPES() - returns a column of all the different edge types (edge equivalent of node labels)
command = """
CALL EDGETYPES()
"""
df_EDGETYPES = client.query(command)
if df_EDGETYPES.empty:
    print("No result found")
else:
    df_EDGETYPES.columns = ["Edge_type_ID", "Edge_label"]
    display(df_EDGETYPES)
# Out:
#    Edge_type_ID Edge_label
# 0             0       SENT
# 1             1   RECEIVED
# CPU times: user 4.69 ms, sys: 3.96 ms, total: 8.65 ms
# Wall time: 7.18 ms

# %%
# %%time

# CALL LABELSETS() - returns a two columns describing combinations of node labels
command = """
CALL LABELSETS()
"""
df_LABELSETS = client.query(command)
if df_LABELSETS.empty:
    print("No result found")
else:
    df_LABELSETS.columns = ["Node_type_ID", "Node_label"]
    display(df_LABELSETS)
# Out:
#    Node_type_ID   Node_label
# 0             0      Account
# 1             1  Transaction
# CPU times: user 7.24 ms, sys: 1.02 ms, total: 8.26 ms
# Wall time: 7.05 ms

# %%
# %%time

# Find number of nodes and number of edges in the graph
n_nodes = len(client.query("MATCH (n) RETURN n"))
n_edges = len(client.query("MATCH (n)--(m) RETURN n, m"))
print(f"Graph: {n_nodes:,} nodes and {n_edges:,} edges")
# Out:
# Graph: 1,572 nodes and 1,472 edges
# CPU times: user 3.66 ms, sys: 2.99 ms, total: 6.65 ms
# Wall time: 5.03 ms

# %% [markdown]
# ## Simple queries

# %%
from turingdb_examples.utils import get_return_statements

# %%
# %%time

# Match all edges and return them
command = """
MATCH (n)-[e]-(m)
RETURN n.id, n.type, e, m.id, m.type
"""
df_all_edges = client.query(command)
if df_all_edges.empty:
    print("No result found")
else:
    df_all_edges.columns = get_return_statements(command)
    display(df_all_edges)
# Out:
#              n.id    n.type     e         m.id    m.type
# 0     C1958260831  customer     0        TX307  CASH_OUT
# 1      C693207385  customer     1        TX592  CASH_OUT
# 2     C1108687791  customer     2        TX308  CASH_OUT
# 3     C2048633894  customer     3        TX309  TRANSFER
# 4      C436378709  customer     4        TX312  CASH_OUT
# ...           ...       ...   ...          ...       ...
# 1467        TX340  TRANSFER  1467    C19673653  customer
# 1468        TX341  CASH_OUT  1468  C1241266786  customer
# 1469        TX342  CASH_OUT  1469  C1241266786  customer
# 1470        TX343   CASH_IN  1470  C1241266786  customer
# 1471        TX344  CASH_OUT  1471  C1241266786  customer
#
# [1472 rows x 5 columns]
# CPU times: user 18.8 ms, sys: 1.03 ms, total: 19.8 ms
# Wall time: 18.5 ms
