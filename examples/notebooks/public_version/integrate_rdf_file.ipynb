# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>
#         Example notebook - Integrate RDF file
#     </h1>
#     <p>
#         Link to dataset : <a href="TR/owl-guide/wine.rdf">Link to Wine RDF file download</a>
#     </p>
# </div>

# %% [markdown]
# # Import modules and functions

# %%
from rdflib import Graph as RDFGraph
import re
import time

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %% [markdown]
# # Check data files are available

# %%
example_name = "wine_ontology"
path_data = f"{os.getcwd()}/data/{example_name}"
if not os.path.exists(path_data):
    print(f"{path_data} does not exist")
    os.makedirs(path_data)
    print(f"{path_data} folder created ✔")

list_files = sorted(os.listdir(path_data))
rdf_filename = "wine_ontology.rdf"
if not rdf_filename in list_files:
    print(f"Wine ontology RDF file is not available in {path_data}. \n")
    url_rdf = "https://www.w3.org/TR/owl-guide/wine.rdf"
    print(
        f"Downloading from: {url_rdf}"
        "\n...\n"
    )
    os.system(f"wget {url_rdf} -O {path_data}/{rdf_filename}")

# %% [markdown]
# # Load dataset

# %%
# RDF graph loading
path_rdf = f"{path_data}/{rdf_filename}"

rg = RDFGraph()
rg.parse(path_rdf)
print(f"RDF file successfully loaded with {len(rg)} triples")
# Out:
# RDF file successfully loaded with 1839 triples

# %%
for obj in list(rg.objects())[:10]:
    print(f"Object: {obj}")
    print(f"Type:   {type(obj)}")
    print()
# Out:
# Object: http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: N4049a69e82b14a21b8080f190f324b9b
# Type:   <class 'rdflib.term.BNode'>
#
# Object: http://www.w3.org/2002/07/owl#Class
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoir
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: N6b0a9c9ea8434e15bbf37ebe217a6704
# Type:   <class 'rdflib.term.BNode'>
#
# Object: http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: N215cc0b118f04f1c94a95296d4e3d572
# Type:   <class 'rdflib.term.BNode'>
#
# Object: http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Delicate
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: http://www.w3.org/2002/07/owl#Restriction
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: http://www.w3.org/2002/07/owl#Class
# Type:   <class 'rdflib.term.URIRef'>

# %%
print(obj)
# Out:
# http://www.w3.org/2002/07/owl#Class

# %% [markdown]
# # Graph Creation in TuringDB

# %% [markdown]
# ## Build Cypher CREATE Commands

# %% [markdown]
# ### Sanitize Cypher query

# %%
def sanitize_cypher_query(query):
    query = query.replace("#", "_")
    query = query.replace("-", "_")

    return query

# %% [markdown]
# ### TuringDB v2 (not implemented yet)

# %%
def rdf_to_cypher_v2(rdf_file, batch_size=1000):
    from rdflib import Graph
    
    g = Graph()
    g.parse(rdf_file)

    #for s, p, o in g:
    #    print(f"""s: {s}\np: {p}\no: {o}""")
    #    print()
    #
    #return
    
    nodes = {str(s) for s, _, _ in g} | {str(o) for _, _, o in g if not isinstance(o, str) or o.startswith('http')}
    
    for i in range(0, len(nodes), batch_size):
        batch = list(nodes)[i:i+batch_size]
        yield "CREATE " + ",\n".join(
            f"(:{node.split('/')[-1]} {{uri: '{node}'}})" 
            for node in batch
        )
    
    for s, p, o in g:
        if not isinstance(o, str) or o.startswith('http'):
            yield f"MATCH (a {{uri: '{s}'}}), (b {{uri: '{o}'}}) CREATE (a)-[:{str(p).split('/')[-1]}]->(b)"

# %%
# %%time

# Create Cypher CREATE command for TuringDB v2
graph_CREATE_command_v2 = '\n'.join(rdf_to_cypher_v2(path_rdf))
graph_CREATE_command_v2 = sanitize_cypher_query(graph_CREATE_command_v2)
print(graph_CREATE_command_v2)
# Out:
# CREATE (:wine_GaryFarrellMerlot {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GaryFarrellMerlot'}),
# (:N6f3a10c292c446e98e694645c3d288e7 {uri: 'N6f3a10c292c446e98e694645c3d288e7'}),
# (:N0f34ecc800844be2bd19996591433ffe {uri: 'N0f34ecc800844be2bd19996591433ffe'}),
# (:N643c237a054c4c0785d74d87f9a28147 {uri: 'N643c237a054c4c0785d74d87f9a28147'}),
# (:wine_GamayGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GamayGrape'}),
# (:N2835ab8aabfb4315ae199f38fb1e3c78 {uri: 'N2835ab8aabfb4315ae199f38fb1e3c78'}),
# (:N51497b936600455c9f1d1a175e35c566 {uri: 'N51497b936600455c9f1d1a175e35c566'}),
# (:wine_FrenchWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FrenchWine'}),
# (:Nfde46439f9ec4842b33eaeb88a0965d1 {uri: 'Nfde46439f9ec4842b33eaeb88a0965d1'}),
# (:wine_Rose {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Rose'}),
# (:Nc615edae9a4d45db995660f963b0852d {uri: 'Nc615edae9a4d45db995660f963b0852d'}),
# (:wine_Margaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Margaux'}),
# (:N98c42362343c427d83bde0974c90effe {uri: 'N98c42362343c427d83bde0974c90effe'}),
# (:N9087ae47172e43edb019dc05d4a85925 {uri: 'N9087ae47172e43edb019dc05d4a85925'}),
# (:wine_PinotBlancGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotBlancGrape'}),
# (:N285b030474e9493eb9b3824486489faa {uri: 'N285b030474e9493eb9b3824486489faa'}),
# (:Nd14f3bcdf2e64a47a5b62b439da0de4f {uri: 'Nd14f3bcdf2e64a47a5b62b439da0de4f'}),
# (:Nafee3eb2a78d4aed80e69da81c7cd151 {uri: 'Nafee3eb2a78d4aed80e69da81c7cd151'}),
# (:N333fe0fb5d5d40948bc1606251fd9a19 {uri: 'N333fe0fb5d5d40948bc1606251fd9a19'}),
# (:N114003cf97fa421587459bc354a3a01d {uri: 'N114003cf97fa421587459bc354a3a01d'}),
# (:wine_Light {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Light'}),
# (:N9d86ad7677d94688956ef5aabd9ab619 {uri: 'N9d86ad7677d94688956ef5aabd9ab619'}),
# (:Nd26c17e84df04d0e9c71e8643e179d58 {uri: 'Nd26c17e84df04d0e9c71e8643e179d58'}),
# (:N1e2570f9e1c04d39b52d176500dae8b4 {uri: 'N1e2570f9e1c04d39b52d176500dae8b4'}),
# (:N0a3baef2e25d435fb6493d0d117e00f7 {uri: 'N0a3baef2e25d435fb6493d0d117e00f7'}),
# (:N00a29cf49e11497e89f7cedfd0d66195 {uri: 'N00a29cf49e11497e89f7cedfd0d66195'}),
# (:wine_WineColor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineColor'}),
# (:wine_ClosDeLaPoussieSancerre {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeLaPoussieSancerre'}),
# (:Nfbb7e8af3bb548dea4a85e1cb508f955 {uri: 'Nfbb7e8af3bb548dea4a85e1cb508f955'}),
# (:N6f68779f27514be0b312c93926770430 {uri: 'N6f68779f27514be0b312c93926770430'}),
# (:N1a77831faeca45da998d54285f34806c {uri: 'N1a77831faeca45da998d54285f34806c'}),
# (:Nb94be601f7b44e2fa443998b08beb388 {uri: 'Nb94be601f7b44e2fa443998b08beb388'}),
# (:wine_MalbecGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MalbecGrape'}),
# (:N1737b83da84a4d50aa3736d7f44c43a3 {uri: 'N1737b83da84a4d50aa3736d7f44c43a3'}),
# (:N0cb8cf5521a4442d96d4c4913ce7385a {uri: 'N0cb8cf5521a4442d96d4c4913ce7385a'}),
# (:N15a183a085f242418675e8a4cc555555 {uri: 'N15a183a085f242418675e8a4cc555555'}),
# (:Ncff506a0f09b472895fa9dc0e05099d4 {uri: 'Ncff506a0f09b472895fa9dc0e05099d4'}),
# (:N01ec1aa6e3f54cacb5bbfc2552bb6342 {uri: 'N01ec1aa6e3f54cacb5bbfc2552bb6342'}),
# (:wine_ChiantiClassico {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChiantiClassico'}),
# (:N6412aa49a4f2453098438fa9b88b4c5e {uri: 'N6412aa49a4f2453098438fa9b88b4c5e'}),
# (:Ne7fa853364bb4425bbe4beef70274517 {uri: 'Ne7fa853364bb4425bbe4beef70274517'}),
# (:Nc90cdd4a70234f46ac6fa42449b1f130 {uri: 'Nc90cdd4a70234f46ac6fa42449b1f130'}),
# (:Nddc7d637d6064951813ea5c387b7f84c {uri: 'Nddc7d637d6064951813ea5c387b7f84c'}),
# (:22_rdf_syntax_ns_nil {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}),
# (:N9df3b8cda5d741fcaea936fd2e257707 {uri: 'N9df3b8cda5d741fcaea936fd2e257707'}),
# (:wine_SchlossVolrad {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossVolrad'}),
# (:wine_Strong {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Strong'}),
# (:wine_Chianti {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Chianti'}),
# (:N39f3aeadd6094b9db742f023a276d854 {uri: 'N39f3aeadd6094b9db742f023a276d854'}),
# (:N9f837b9263464d388e552d2dfa64d7aa {uri: 'N9f837b9263464d388e552d2dfa64d7aa'}),
# (:wine_WineBody {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineBody'}),
# (:Nb0177a2b90164baaa794708c45e75600 {uri: 'Nb0177a2b90164baaa794708c45e75600'}),
# (:N293e21e2bbf3486197a5b27d4399c34f {uri: 'N293e21e2bbf3486197a5b27d4399c34f'}),
# (:Ne205cfd5f344475b99ccdc599ad56bfb {uri: 'Ne205cfd5f344475b99ccdc599ad56bfb'}),
# (:N0cb3e1843cf248d3a3e8e5038947ffd3 {uri: 'N0cb3e1843cf248d3a3e8e5038947ffd3'}),
# (:wine_RieslingGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RieslingGrape'}),
# (:N0ce7a18fde194998be8e01c28926e987 {uri: 'N0ce7a18fde194998be8e01c28926e987'}),
# (:wine_FullBodiedWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FullBodiedWine'}),
# (:wine_KalinCellarsSemillon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_KalinCellarsSemillon'}),
# (:Nf6961d0902964ced845d48685566577a {uri: 'Nf6961d0902964ced845d48685566577a'}),
# (:Na78adea29f58444f922ddb9726322a21 {uri: 'Na78adea29f58444f922ddb9726322a21'}),
# (:wine_Stonleigh {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Stonleigh'}),
# (:wine_MedocRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MedocRegion'}),
# (:N46e4591b3f524ba9a6668cdac51345a0 {uri: 'N46e4591b3f524ba9a6668cdac51345a0'}),
# (:N1f9e22e0533440b9b06a8f5f37d53861 {uri: 'N1f9e22e0533440b9b06a8f5f37d53861'}),
# (:Na73d551d36664d0c8f3557f7382f2670 {uri: 'Na73d551d36664d0c8f3557f7382f2670'}),
# (:Nf167fcbd4bf54a79add4fd55e5d283c3 {uri: 'Nf167fcbd4bf54a79add4fd55e5d283c3'}),
# (:wine_DryRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryRiesling'}),
# (:N74069c8144094c78b9aeb3e7a144814c {uri: 'N74069c8144094c78b9aeb3e7a144814c'}),
# (:wine_Merlot {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Merlot'}),
# (:wine_CotesDOr {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CotesDOr'}),
# (:N0f56216549064af8a61b881c7c3a0d07 {uri: 'N0f56216549064af8a61b881c7c3a0d07'}),
# (:Nab656afde2f04ac7921a3597e50d4009 {uri: 'Nab656afde2f04ac7921a3597e50d4009'}),
# (:N7b3e94b387b842bc866baab753b347fd {uri: 'N7b3e94b387b842bc866baab753b347fd'}),
# (:wine_BancroftChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BancroftChardonnay'}),
# (:wine_Elyse {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Elyse'}),
# (:N69d183e1f34442979ec9b776d347e3aa {uri: 'N69d183e1f34442979ec9b776d347e3aa'}),
# (:N98c7a9bb3a88454eb654d93db102f9cd {uri: 'N98c7a9bb3a88454eb654d93db102f9cd'}),
# (:wine_Region {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Region'}),
# (:wine_PulignyMontrachetWhiteBurgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PulignyMontrachetWhiteBurgundy'}),
# (:wine_PulignyMontrachet {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PulignyMontrachet'}),
# (:N68abb6414e7c413eafca6ec1821b15cf {uri: 'N68abb6414e7c413eafca6ec1821b15cf'}),
# (:wine_yearValue {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_yearValue'}),
# (:wine_Delicate {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Delicate'}),
# (:Nbc3bfc6c1ef84557a5b0723f3d28422d {uri: 'Nbc3bfc6c1ef84557a5b0723f3d28422d'}),
# (:N33e3e326f0254568b6a08ea21ca9c035 {uri: 'N33e3e326f0254568b6a08ea21ca9c035'}),
# (:N1ab67314f832403baa82a616d3f0c251 {uri: 'N1ab67314f832403baa82a616d3f0c251'}),
# (:N1f5c6df7eb2940dcacd9e2bb352db481 {uri: 'N1f5c6df7eb2940dcacd9e2bb352db481'}),
# (:wine_MargauxRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MargauxRegion'}),
# (:N5f3a3bff94a44e3695359dd103b191fe {uri: 'N5f3a3bff94a44e3695359dd103b191fe'}),
# (:Nec36eb22f1c140f992f1745229ea0bf6 {uri: 'Nec36eb22f1c140f992f1745229ea0bf6'}),
# (:N4743a2a5d8174001bb7beecca186a3f7 {uri: 'N4743a2a5d8174001bb7beecca186a3f7'}),
# (:wine_AmericanWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AmericanWine'}),
# (:Ncd47b4071b0240d28ec04eb4c57fb358 {uri: 'Ncd47b4071b0240d28ec04eb4c57fb358'}),
# (:wine_SantaCruzMountainVineyardCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SantaCruzMountainVineyardCabernetSauvignon'}),
# (:N0a76b8645527478d9586df35ed696888 {uri: 'N0a76b8645527478d9586df35ed696888'}),
# (:wine_AnjouRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AnjouRegion'}),
# (:N58d09ebea6f04ac5bf1b76efa359fcfa {uri: 'N58d09ebea6f04ac5bf1b76efa359fcfa'}),
# (:N8d37921115a44a63b3d60ff06e5bd5b6 {uri: 'N8d37921115a44a63b3d60ff06e5bd5b6'}),
# (:wine_WhitehallLanePrimavera {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhitehallLanePrimavera'}),
# (:N6310ba3446d946a1aa7b182d0cb6cb1c {uri: 'N6310ba3446d946a1aa7b182d0cb6cb1c'}),
# (:Nef3abc40b8bf488d99ceff175fba0ba5 {uri: 'Nef3abc40b8bf488d99ceff175fba0ba5'}),
# (:N521528e1923d4741a121424c9c133114 {uri: 'N521528e1923d4741a121424c9c133114'}),
# (:wine_EarlyHarvest {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_EarlyHarvest'}),
# (:wine_MuscadetRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MuscadetRegion'}),
# (:N5eccf71354ad4b5da0c09380cef7c5e4 {uri: 'N5eccf71354ad4b5da0c09380cef7c5e4'}),
# (:wine_Bancroft {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Bancroft'}),
# (:N5fbe2e8e65294e378531f518623b2afb {uri: 'N5fbe2e8e65294e378531f518623b2afb'}),
# (:wine_PeterMccoy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PeterMccoy'}),
# (:Ne9ceb42bce104da4b90eb59d347c3a30 {uri: 'Ne9ceb42bce104da4b90eb59d347c3a30'}),
# (:food_Grape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/food_Grape'}),
# (:wine_SaucelitoCanyonZinfandel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SaucelitoCanyonZinfandel'}),
# (:N0c75244e398a43439130709e0931015e {uri: 'N0c75244e398a43439130709e0931015e'}),
# (:wine_hasVintageYear {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasVintageYear'}),
# (:wine_hasSugar {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasSugar'}),
# (:N59b83829c61d4449845526681f12533a {uri: 'N59b83829c61d4449845526681f12533a'}),
# (:wine_WhitehallLane {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhitehallLane'}),
# (:N5cfba0fc7906492c8683cac2e963a8ab {uri: 'N5cfba0fc7906492c8683cac2e963a8ab'}),
# (:Ncf410d7d521244b294e2472c42a18234 {uri: 'Ncf410d7d521244b294e2472c42a18234'}),
# (:wine_WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineDescriptor'}),
# (:N0e24c0ce11ee441cba9e3200b9395b96 {uri: 'N0e24c0ce11ee441cba9e3200b9395b96'}),
# (:Neb81037d01864d7d8d4d5c01250aa990 {uri: 'Neb81037d01864d7d8d4d5c01250aa990'}),
# (:N182add8a47ea418e8ca49271307e265f {uri: 'N182add8a47ea418e8ca49271307e265f'}),
# (:Nc0f857fb5d8742718988b73b14f00078 {uri: 'Nc0f857fb5d8742718988b73b14f00078'}),
# (:wine_CongressSpringsSemillon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CongressSpringsSemillon'}),
# (:Nde06736cf198418f9ea70bf43ef6d5ff {uri: 'Nde06736cf198418f9ea70bf43ef6d5ff'}),
# (:wine_RedBordeaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RedBordeaux'}),
# (:Nc3bb688a984d413b9ce3f20b57922faa {uri: 'Nc3bb688a984d413b9ce3f20b57922faa'}),
# (:wine_ClosDeVougeot {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeVougeot'}),
# (:wine_MariettaPetiteSyrah {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaPetiteSyrah'}),
# (:food_PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/food_PotableLiquid'}),
# (:wine_locatedIn {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_locatedIn'}),
# (:Nf289ce9ec9df4321a96ad79917157847 {uri: 'Nf289ce9ec9df4321a96ad79917157847'}),
# (:Ncfd2e8d86f98476ca2bac3151fd40c96 {uri: 'Ncfd2e8d86f98476ca2bac3151fd40c96'}),
# (:N6e258a28fb904c219ee5fe58f7ab317a {uri: 'N6e258a28fb904c219ee5fe58f7ab317a'}),
# (:N90c4b8a00df44a0aa6303ae3298bdb17 {uri: 'N90c4b8a00df44a0aa6303ae3298bdb17'}),
# (:N37233f80c4254d8cb0b72be8ca79dc60 {uri: 'N37233f80c4254d8cb0b72be8ca79dc60'}),
# (:wine_Sweet {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sweet'}),
# (:wine_LoireRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LoireRegion'}),
# (:N5558c5b12d9e4e1daa3096f9e3013ba9 {uri: 'N5558c5b12d9e4e1daa3096f9e3013ba9'}),
# (:N8e182ffd462640e79f0d3f168d7e325e {uri: 'N8e182ffd462640e79f0d3f168d7e325e'}),
# (:Nb0b9070912f84bdf9e068491bb987e03 {uri: 'Nb0b9070912f84bdf9e068491bb987e03'}),
# (:N5b63e1b79b9e4291917878172f7f39c3 {uri: 'N5b63e1b79b9e4291917878172f7f39c3'}),
# (:wine_StEmilionRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StEmilionRegion'}),
# (:N6a91c9e8e5e34636a240c889eee8c86f {uri: 'N6a91c9e8e5e34636a240c889eee8c86f'}),
# (:N84faba972fbe465191b1f483d2882a3b {uri: 'N84faba972fbe465191b1f483d2882a3b'}),
# (:wine_PinotNoir {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotNoir'}),
# (:N8afcff4a2b8a419b9ee018a40e55906c {uri: 'N8afcff4a2b8a419b9ee018a40e55906c'}),
# (:N97679a6e3b764995a3653224e96ea127 {uri: 'N97679a6e3b764995a3653224e96ea127'}),
# (:wine_Burgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Burgundy'}),
# (:N3e2c0a5796ea4e26948b88340f133111 {uri: 'N3e2c0a5796ea4e26948b88340f133111'}),
# (:wine_SchlossVolradTrochenbierenausleseRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossVolradTrochenbierenausleseRiesling'}),
# (:N54bad85d2cc54beda9303530b8e3487b {uri: 'N54bad85d2cc54beda9303530b8e3487b'}),
# (:N4e5032f8fb064f449ff5856fdc39bdbe {uri: 'N4e5032f8fb064f449ff5856fdc39bdbe'}),
# (:N8eaf53b8d03c46f79b1645824532a227 {uri: 'N8eaf53b8d03c46f79b1645824532a227'}),
# (:N572e43b9f9a04423907d8a02d8ba8b38 {uri: 'N572e43b9f9a04423907d8a02d8ba8b38'}),
# (:N1e495c53a7e84128af659f48ed0362e1 {uri: 'N1e495c53a7e84128af659f48ed0362e1'}),
# (:N4572cc07eb3345668a5b2f473f25f5bf {uri: 'N4572cc07eb3345668a5b2f473f25f5bf'}),
# (:Na0eb6a7964b64cf1bcd4f44f53c952cd {uri: 'Na0eb6a7964b64cf1bcd4f44f53c952cd'}),
# (:wine_IceWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_IceWine'}),
# (:N8c56b3c34b56468ea1cebb3a99ae8f65 {uri: 'N8c56b3c34b56468ea1cebb3a99ae8f65'}),
# (:N348b504a46be4a4cbbc512f76171124b {uri: 'N348b504a46be4a4cbbc512f76171124b'}),
# (:wine_MountadamRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamRiesling'}),
# (:N0d5f002159da4561a71f7a84f4485bfb {uri: 'N0d5f002159da4561a71f7a84f4485bfb'}),
# (:wine_CongressSprings {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CongressSprings'}),
# (:wine_PortugalRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PortugalRegion'}),
# (:N00c63e1ac310466da63409528cd21f09 {uri: 'N00c63e1ac310466da63409528cd21f09'}),
# (:N15ad9a806dec4952b2f86826c989a9d8 {uri: 'N15ad9a806dec4952b2f86826c989a9d8'}),
# (:N914b1ced5d5245a29ebb8a694eff8187 {uri: 'N914b1ced5d5245a29ebb8a694eff8187'}),
# (:wine_ChateauMargauxWinery {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMargauxWinery'}),
# (:wine_CorbansSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansSauvignonBlanc'}),
# (:wine_SweetRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SweetRiesling'}),
# (:wine {uri: 'http://www.w3.org/TR/2003/CR_owl_guide_20030818/wine'}),
# (:Nf753ddac215d42bcb421fb211f118c4e {uri: 'Nf753ddac215d42bcb421fb211f118c4e'}),
# (:wine_FrenchRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FrenchRegion'}),
# (:wine_CotturiZinfandel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CotturiZinfandel'}),
# (:N4ff8f67092fd4f818274b71ba03dac12 {uri: 'N4ff8f67092fd4f818274b71ba03dac12'}),
# (:N3e69c59ec87840e5bbd5cc662d68998c {uri: 'N3e69c59ec87840e5bbd5cc662d68998c'}),
# (:N6947b956efe84427a95a4fd21a2b37e6 {uri: 'N6947b956efe84427a95a4fd21a2b37e6'}),
# (:Nf708aa5f43fa45b1a08ad95dca55d80c {uri: 'Nf708aa5f43fa45b1a08ad95dca55d80c'}),
# (:N39dbb8d045e24b9bbcad29467dfbbcea {uri: 'N39dbb8d045e24b9bbcad29467dfbbcea'}),
# (:Nd25530548ffd4893a74c2e1041ea82b5 {uri: 'Nd25530548ffd4893a74c2e1041ea82b5'}),
# (:Naf79dc6a2ded449691a281fa3f4b6c65 {uri: 'Naf79dc6a2ded449691a281fa3f4b6c65'}),
# (:Nfa6894b0e9cf426ead5410b28dfd6730 {uri: 'Nfa6894b0e9cf426ead5410b28dfd6730'}),
# (:wine_McGuinnesso {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_McGuinnesso'}),
# (:wine_GaryFarrell {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GaryFarrell'}),
# (:Ne8aeb649536348f894518169a61ff7ef {uri: 'Ne8aeb649536348f894518169a61ff7ef'}),
# (:wine_MariettaZinfandel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaZinfandel'}),
# (:wine_CaliforniaRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CaliforniaRegion'}),
# (:wine_MeursaultRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MeursaultRegion'}),
# (:wine_MountadamChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamChardonnay'}),
# (:wine_ChateauChevalBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauChevalBlanc'}),
# (:N29fd70b75c2b4b6cba721b89c6dccf04 {uri: 'N29fd70b75c2b4b6cba721b89c6dccf04'}),
# (:wine_Pauillac {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Pauillac'}),
# (:Nd66332d10e794fef9a97fe27739b2a92 {uri: 'Nd66332d10e794fef9a97fe27739b2a92'}),
# (:N76ab2c305b4e48ad9986472a329bdaaf {uri: 'N76ab2c305b4e48ad9986472a329bdaaf'}),
# (:Ndbb1de2eeb154459ae783e62cffac45c {uri: 'Ndbb1de2eeb154459ae783e62cffac45c'}),
# (:N73dca359370048ef96c56a314dbf058e {uri: 'N73dca359370048ef96c56a314dbf058e'}),
# (:Nce678f1e3e02443589d76f02bdaedfd9 {uri: 'Nce678f1e3e02443589d76f02bdaedfd9'}),
# (:wine_SantaBarbaraRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SantaBarbaraRegion'}),
# (:wine_KalinCellars {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_KalinCellars'}),
# (:N6405265409c147f490e65b5d15238a1b {uri: 'N6405265409c147f490e65b5d15238a1b'}),
# (:N2b0e1b8005204558939ae43ab66ddf04 {uri: 'N2b0e1b8005204558939ae43ab66ddf04'}),
# (:Ne3ad3679d949419095234d58d7c6a401 {uri: 'Ne3ad3679d949419095234d58d7c6a401'}),
# (:Nd63c02558acd4ff98bc728c6f937d39b {uri: 'Nd63c02558acd4ff98bc728c6f937d39b'}),
# (:wine_BeaujolaisRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BeaujolaisRegion'}),
# (:wine_SelaksIceWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SelaksIceWine'}),
# (:Nf8e54421b5b347bcac3baa30b48def2b {uri: 'Nf8e54421b5b347bcac3baa30b48def2b'}),
# (:Nf4ece160f81944e08a3600701bb98d3a {uri: 'Nf4ece160f81944e08a3600701bb98d3a'}),
# (:wine_WhiteNonSweetWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteNonSweetWine'}),
# (:wine_NewZealandRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_NewZealandRegion'}),
# (:wine_Year1998 {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Year1998'}),
# (:wine_Sauternes {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sauternes'}),
# (:N1c919ac99be64b30a381076a28273ef6 {uri: 'N1c919ac99be64b30a381076a28273ef6'}),
# (:N5a9cb21adc4c40ecb004cc61e71bf293 {uri: 'N5a9cb21adc4c40ecb004cc61e71bf293'}),
# (:wine_Loire {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Loire'}),
# (:wine_SouthAustraliaRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SouthAustraliaRegion'}),
# (:N191d8e3222714db9bdaba1e6b73beaa2 {uri: 'N191d8e3222714db9bdaba1e6b73beaa2'}),
# (:Nd298cfa7168e47648de84a14fe44b617 {uri: 'Nd298cfa7168e47648de84a14fe44b617'}),
# (:wine_hasColor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasColor'}),
# (:wine_WineTaste {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineTaste'}),
# (:Nbf1e4859327b482791f9a7a0d817c6fc {uri: 'Nbf1e4859327b482791f9a7a0d817c6fc'}),
# (:N122712bd8d25439daa0bab118eaf8f6c {uri: 'N122712bd8d25439daa0bab118eaf8f6c'}),
# (:wine_SantaCruzMountainVineyard {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SantaCruzMountainVineyard'}),
# (:Nc3d4359d91654271975cbe63bb7318bd {uri: 'Nc3d4359d91654271975cbe63bb7318bd'}),
# (:N1520e3263b4d4523a7b64b8861337a32 {uri: 'N1520e3263b4d4523a7b64b8861337a32'}),
# (:N81d10df9029e4dfe99dee65a3b824d0d {uri: 'N81d10df9029e4dfe99dee65a3b824d0d'}),
# (:N52eae3edcbe944e4b051d82304328954 {uri: 'N52eae3edcbe944e4b051d82304328954'}),
# (:N1836becc36a047bab16a5b25c7e1292b {uri: 'N1836becc36a047bab16a5b25c7e1292b'}),
# (:N5182f605e8d14ca4840a62ae85f25000 {uri: 'N5182f605e8d14ca4840a62ae85f25000'}),
# (:N4342125403b445f0948f975264d34ef1 {uri: 'N4342125403b445f0948f975264d34ef1'}),
# (:N645e8ea444914bdeb3d5e2e0bf1b1a9a {uri: 'N645e8ea444914bdeb3d5e2e0bf1b1a9a'}),
# (:wine_ToursRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ToursRegion'}),
# (:N31e84e597f9341f79e46ac60fb848227 {uri: 'N31e84e597f9341f79e46ac60fb848227'}),
# (:wine_USRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_USRegion'}),
# (:N86b07af83393451aab8c3f6fc46a7aa8 {uri: 'N86b07af83393451aab8c3f6fc46a7aa8'}),
# (:Nd9a787226ac74eef8f02bd29ed972b3a {uri: 'Nd9a787226ac74eef8f02bd29ed972b3a'}),
# (:N86ef30adf0574a83891c9b594a25d6f8 {uri: 'N86ef30adf0574a83891c9b594a25d6f8'}),
# (:Nf13a8615404e48d2a9a567cf7a5b5615 {uri: 'Nf13a8615404e48d2a9a567cf7a5b5615'}),
# (:N13770f9fb97647628c503ee2bfd8c697 {uri: 'N13770f9fb97647628c503ee2bfd8c697'}),
# (:wine_Medium {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}),
# (:wine_MountEdenVineyardEdnaValleyChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountEdenVineyardEdnaValleyChardonnay'}),
# (:N171c32d87f4549ba95ac94834b91982f {uri: 'N171c32d87f4549ba95ac94834b91982f'}),
# (:Nf14bb9a9b2464d2ca466980af5be96c3 {uri: 'Nf14bb9a9b2464d2ca466980af5be96c3'}),
# (:N4bf5b55a32654afab0d585615e1fc6c9 {uri: 'N4bf5b55a32654afab0d585615e1fc6c9'}),
# (:Nb0384b66497c407397b5fe00abb02c80 {uri: 'Nb0384b66497c407397b5fe00abb02c80'}),
# (:wine_Forman {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Forman'}),
# (:wine_SeanThackrey {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SeanThackrey'}),
# (:N67e675bae2144dc385ae38fcfa059f00 {uri: 'N67e675bae2144dc385ae38fcfa059f00'}),
# (:wine_FormanChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FormanChardonnay'}),
# (:wine_DryRedWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryRedWine'}),
# (:N247675d9b4fb4658892ae4f07e76a374 {uri: 'N247675d9b4fb4658892ae4f07e76a374'}),
# (:Nb55ac367617a49ef91ea9ce3b2957e7c {uri: 'Nb55ac367617a49ef91ea9ce3b2957e7c'}),
# (:N73d5f06979274a2a99458a1fc960ba01 {uri: 'N73d5f06979274a2a99458a1fc960ba01'}),
# (:N3835dd12ae2b4ff2abb6398a3644fb3a {uri: 'N3835dd12ae2b4ff2abb6398a3644fb3a'}),
# (:wine_SancerreRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SancerreRegion'}),
# (:N750ac6e334bc4d5eb362d1126c4e16f9 {uri: 'N750ac6e334bc4d5eb362d1126c4e16f9'}),
# (:N6e30ff4c2f87411ab937104e38aab102 {uri: 'N6e30ff4c2f87411ab937104e38aab102'}),
# (:N92b9cf1e7fb846eca251f04edd02d6e1 {uri: 'N92b9cf1e7fb846eca251f04edd02d6e1'}),
# (:N94501c00d56e4d61aa45a1d8fe1d3795 {uri: 'N94501c00d56e4d61aa45a1d8fe1d3795'}),
# (:N8057b11808064d63b596a173ed2c4d3f {uri: 'N8057b11808064d63b596a173ed2c4d3f'}),
# (:wine_SaucelitoCanyonZinfandel1998 {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SaucelitoCanyonZinfandel1998'}),
# (:N4ae7ed79799c47c0bf1e056c7a5d7b41 {uri: 'N4ae7ed79799c47c0bf1e056c7a5d7b41'}),
# (:N74cda1de119b47e7b475a65e50dc9ea3 {uri: 'N74cda1de119b47e7b475a65e50dc9ea3'}),
# (:wine_hasMaker {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasMaker'}),
# (:wine_StonleighSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StonleighSauvignonBlanc'}),
# (:wine_MerlotGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MerlotGrape'}),
# (:wine_ChateauMorgon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMorgon'}),
# (:wine_Meritage {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Meritage'}),
# (:N5e21a5197728445da7ff0a58087bfdba {uri: 'N5e21a5197728445da7ff0a58087bfdba'}),
# (:N299f236f77994f4a8d9ea24fa41edd74 {uri: 'N299f236f77994f4a8d9ea24fa41edd74'}),
# (:N0ba9a1ac43b34f79a68f2d590e648939 {uri: 'N0ba9a1ac43b34f79a68f2d590e648939'}),
# (:wine_ChateauChevalBlancStEmilion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauChevalBlancStEmilion'}),
# (:wine_PinotBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotBlanc'}),
# (:N235d53fbc2564c48bc46134b79bb4451 {uri: 'N235d53fbc2564c48bc46134b79bb4451'}),
# (:N4da29559a44f4a34a5de07b734b2e933 {uri: 'N4da29559a44f4a34a5de07b734b2e933'}),
# (:Nd4fd5da6c43845fb89317e89f10fedab {uri: 'Nd4fd5da6c43845fb89317e89f10fedab'}),
# (:N6ca00b6ee0b040c883f3443fe9ba2e91 {uri: 'N6ca00b6ee0b040c883f3443fe9ba2e91'}),
# (:wine_PetiteSyrahGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PetiteSyrahGrape'}),
# (:N1d8d00b3e7e94101bcb8527cf177b3a9 {uri: 'N1d8d00b3e7e94101bcb8527cf177b3a9'}),
# (:N18d57ae069a04c35a5408c93e46b0444 {uri: 'N18d57ae069a04c35a5408c93e46b0444'}),
# (:Nac25a1acf42142a5894e09cd2024daf8 {uri: 'Nac25a1acf42142a5894e09cd2024daf8'}),
# (:wine_Ventana {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Ventana'}),
# (:wine_ClosDeLaPoussie {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeLaPoussie'}),
# (:N5cf723e75e2941c597831e1f99146738 {uri: 'N5cf723e75e2941c597831e1f99146738'}),
# (:N479734bef7de4daab27ff652880076cd {uri: 'N479734bef7de4daab27ff652880076cd'}),
# (:N5931fb404a99489791a81f778c7a2fc0 {uri: 'N5931fb404a99489791a81f778c7a2fc0'}),
# (:N5447415a1c084a65ae9ef6691200a515 {uri: 'N5447415a1c084a65ae9ef6691200a515'}),
# (:wine_Zinfandel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Zinfandel'}),
# (:N2810a9b7f7df43e790e55a99ff0e9456 {uri: 'N2810a9b7f7df43e790e55a99ff0e9456'}),
# (:N28d1ccf63a5a43838cac37daaad67a23 {uri: 'N28d1ccf63a5a43838cac37daaad67a23'}),
# (:Nf65b4d7026474e319318a5a47d1ec7c9 {uri: 'Nf65b4d7026474e319318a5a47d1ec7c9'}),
# (:wine_OffDry {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_OffDry'}),
# (:N68e59a6f36f9480c8e5005c743a2733a {uri: 'N68e59a6f36f9480c8e5005c743a2733a'}),
# (:N98691bd9709b490fa0225df869578f19 {uri: 'N98691bd9709b490fa0225df869578f19'}),
# (:wine_RedBurgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RedBurgundy'}),
# (:N4de5218a8d144b559dde207fb5d42529 {uri: 'N4de5218a8d144b559dde207fb5d42529'}),
# (:Nfd06f1fe679f4d9b80698daf5a2f655d {uri: 'Nfd06f1fe679f4d9b80698daf5a2f655d'}),
# (:N023620f9760c442fb1707b80b462dcb1 {uri: 'N023620f9760c442fb1707b80b462dcb1'}),
# (:N68e8681041744ddfbd539adab999fbc0 {uri: 'N68e8681041744ddfbd539adab999fbc0'}),
# (:wine_WhitehallLaneCabernetFranc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhitehallLaneCabernetFranc'}),
# (:wine_Dry {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Dry'}),
# (:Ne3266e9ad7eb47fe8ddd702bf37e6a35 {uri: 'Ne3266e9ad7eb47fe8ddd702bf37e6a35'}),
# (:N1b0b35dd96e14f63a03d6bb3461830e2 {uri: 'N1b0b35dd96e14f63a03d6bb3461830e2'}),
# (:N60c6b8e4145a41a5952cfdafc8acd9ba {uri: 'N60c6b8e4145a41a5952cfdafc8acd9ba'}),
# (:Ncd4e3b76f70648fd848ad12d44da91dc {uri: 'Ncd4e3b76f70648fd848ad12d44da91dc'}),
# (:N01da9531b69743d6983bc9e13cb8f43c {uri: 'N01da9531b69743d6983bc9e13cb8f43c'}),
# (:wine_Bordeaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Bordeaux'}),
# (:wine_RoseWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RoseWine'}),
# (:wine_CabernetFranc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetFranc'}),
# (:Nea12b28ffeb24c0384eca580cec3b4fe {uri: 'Nea12b28ffeb24c0384eca580cec3b4fe'}),
# (:Nd4a3dde4e58e42b5b58a73b34ed7624e {uri: 'Nd4a3dde4e58e42b5b58a73b34ed7624e'}),
# (:Ncf51f9208f604815a8741a891f4aa558 {uri: 'Ncf51f9208f604815a8741a891f4aa558'}),
# (:N0f42f674c63f46529a1c897d02db95e0 {uri: 'N0f42f674c63f46529a1c897d02db95e0'}),
# (:Nbb5eb188aad148b2a31ce09d3b3b8cb4 {uri: 'Nbb5eb188aad148b2a31ce09d3b3b8cb4'}),
# (:wine_Tours {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Tours'}),
# (:Nc5aae934552c46cfbe8ecab27fe13ab1 {uri: 'Nc5aae934552c46cfbe8ecab27fe13ab1'}),
# (:N4ca5fd7230d94e8d901fb2f68d012d23 {uri: 'N4ca5fd7230d94e8d901fb2f68d012d23'}),
# (:Nc09c1e29db2d4dccba0696429a9f8498 {uri: 'Nc09c1e29db2d4dccba0696429a9f8498'}),
# (:owl_Restriction {uri: 'http://www.w3.org/2002/07/owl_Restriction'}),
# (:N4b8037bc2a704278b57ac12c720c4466 {uri: 'N4b8037bc2a704278b57ac12c720c4466'}),
# (:wine_ChateauDeMeursault {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauDeMeursault'}),
# (:wine_MountadamPinotNoir {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamPinotNoir'}),
# (:N90304f13302a4f1d9e061b57bcf3e7b1 {uri: 'N90304f13302a4f1d9e061b57bcf3e7b1'}),
# (:N10e81563f6614f0e92cb0ccb66607b97 {uri: 'N10e81563f6614f0e92cb0ccb66607b97'}),
# (:Nc441d12e14284810bc9033b89918f276 {uri: 'Nc441d12e14284810bc9033b89918f276'}),
# (:N98505c4818c44c49931258a6b21fe514 {uri: 'N98505c4818c44c49931258a6b21fe514'}),
# (:wine_ChateauDYchemSauterne {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauDYchemSauterne'}),
# (:N898eb0f9037a4658acb11d8a22c424d2 {uri: 'N898eb0f9037a4658acb11d8a22c424d2'}),
# (:N856c597aef1448998fba98ea0ed842b0 {uri: 'N856c597aef1448998fba98ea0ed842b0'}),
# (:N8676d1630ce7482f9f958213b4a21471 {uri: 'N8676d1630ce7482f9f958213b4a21471'}),
# (:wine_hasFlavor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasFlavor'}),
# (:wine_Vintage {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Vintage'}),
# (:N64e6f74b589445f99f01e29d3b695778 {uri: 'N64e6f74b589445f99f01e29d3b695778'}),
# (:wine_CortonMontrachetWhiteBurgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CortonMontrachetWhiteBurgundy'}),
# (:Nfbccfd500c2d4991942579cef9f3f58b {uri: 'Nfbccfd500c2d4991942579cef9f3f58b'}),
# (:N70ae99149fcc4004acdec653a99ff299 {uri: 'N70ae99149fcc4004acdec653a99ff299'}),
# (:food {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/food'}),
# (:N509f8ba9bb584d7bb5da1e965c947510 {uri: 'N509f8ba9bb584d7bb5da1e965c947510'}),
# (:wine_PageMillWineryCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PageMillWineryCabernetSauvignon'}),
# (:wine_CentralTexasRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CentralTexasRegion'}),
# (:wine_TexasWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_TexasWine'}),
# (:N255b8b3f952c45c083ba80d4bc25eaa8 {uri: 'N255b8b3f952c45c083ba80d4bc25eaa8'}),
# (:N7e4a28a5594a4a95bedd7a3bb33cbe91 {uri: 'N7e4a28a5594a4a95bedd7a3bb33cbe91'}),
# (:N7423abbaeec2461d9def54810c846c61 {uri: 'N7423abbaeec2461d9def54810c846c61'}),
# (:N64a9834355274139b33ffa069160c4f8 {uri: 'N64a9834355274139b33ffa069160c4f8'}),
# (:wine_BourgogneRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BourgogneRegion'}),
# (:N72d835828bd2493f8434313be4bdebba {uri: 'N72d835828bd2493f8434313be4bdebba'}),
# (:N21be29614c004e50b88635a2b252955c {uri: 'N21be29614c004e50b88635a2b252955c'}),
# (:N567da5ce7ccc48319bd24e75140adc4e {uri: 'N567da5ce7ccc48319bd24e75140adc4e'}),
# (:N1b437d10ebb54122a328162b3bcf0590 {uri: 'N1b437d10ebb54122a328162b3bcf0590'}),
# (:wine_CorbansPrivateBinSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansPrivateBinSauvignonBlanc'}),
# (:N684b444ed61446ab8e378348c373451a {uri: 'N684b444ed61446ab8e378348c373451a'}),
# (:wine_WineFlavor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineFlavor'}),
# (:N0329030d60aa491282111a3361da35c1 {uri: 'N0329030d60aa491282111a3361da35c1'}),
# (:N94cac4c9bf33473fb3f1ae62da46af63 {uri: 'N94cac4c9bf33473fb3f1ae62da46af63'}),
# (:Nd817f77798f64d5ba8a7b200a949a2b1 {uri: 'Nd817f77798f64d5ba8a7b200a949a2b1'}),
# (:wine_AlsaceRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AlsaceRegion'}),
# (:N855bb9d782db41e2b085ad40430e065c {uri: 'N855bb9d782db41e2b085ad40430e065c'}),
# (:N8b97d29b03144ddb917cefd0c087c433 {uri: 'N8b97d29b03144ddb917cefd0c087c433'}),
# (:Nb45ef2bf2fcf48b2b2b7129b06a9e994 {uri: 'Nb45ef2bf2fcf48b2b2b7129b06a9e994'}),
# (:N9645492462af4fd6867b0b4d4b9520fc {uri: 'N9645492462af4fd6867b0b4d4b9520fc'}),
# (:N6fbdbd1481704d4aa54f875efa536a7e {uri: 'N6fbdbd1481704d4aa54f875efa536a7e'}),
# (:wine_DessertWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DessertWine'}),
# (:N8668d0f01aa5427ea0e93ecfd6cfbc3a {uri: 'N8668d0f01aa5427ea0e93ecfd6cfbc3a'}),
# (:N2bc51f57271c41f685147ad1e8bbe62f {uri: 'N2bc51f57271c41f685147ad1e8bbe62f'}),
# (:N3b45986eeaf14a6ebeab5c1c15075c20 {uri: 'N3b45986eeaf14a6ebeab5c1c15075c20'}),
# (:Naafa5dd3c4584b13be26855851bebe14 {uri: 'Naafa5dd3c4584b13be26855851bebe14'}),
# (:N651dcac8fb0b4cc5adee02eda283f2f1 {uri: 'N651dcac8fb0b4cc5adee02eda283f2f1'}),
# (:N68f5cef14c7c4671be2d46e8ab1b8794 {uri: 'N68f5cef14c7c4671be2d46e8ab1b8794'}),
# (:N8f9cac681a7f47f99365aee460d69224 {uri: 'N8f9cac681a7f47f99365aee460d69224'}),
# (:Nf411ad2766dd49be9dbfa603426fd5f8 {uri: 'Nf411ad2766dd49be9dbfa603426fd5f8'}),
# (:wine_madeFromGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}),
# (:N9483e111abc647d08c67863aa3dd58f0 {uri: 'N9483e111abc647d08c67863aa3dd58f0'}),
# (:Nb03711465958472fa322ed49d1a8a87c {uri: 'Nb03711465958472fa322ed49d1a8a87c'}),
# (:Na3962684d2fe49a0a5d103818639b3fa {uri: 'Na3962684d2fe49a0a5d103818639b3fa'}),
# (:N4a9d53d592c9410b8729243b7d0a3bda {uri: 'N4a9d53d592c9410b8729243b7d0a3bda'}),
# (:N40f84bb654904cc4a93ea88ea65c33f3 {uri: 'N40f84bb654904cc4a93ea88ea65c33f3'}),
# (:wine_SangioveseGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SangioveseGrape'}),
# (:wine_MariettaOldVinesRed {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaOldVinesRed'}),
# (:Na672961e4c48467ebda5841df267fac2 {uri: 'Na672961e4c48467ebda5841df267fac2'}),
# (:wine_WineSugar {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineSugar'}),
# (:Nac66da557db24e5eb24a9157c221f4a4 {uri: 'Nac66da557db24e5eb24a9157c221f4a4'}),
# (:Nd76fd8c9b47748ebadcc8ad89dec6b6c {uri: 'Nd76fd8c9b47748ebadcc8ad89dec6b6c'}),
# (:N7082509d3e7a4351a4ab330b40a2de8f {uri: 'N7082509d3e7a4351a4ab330b40a2de8f'}),
# (:N0bad335f3a55419c9312dd1801713de9 {uri: 'N0bad335f3a55419c9312dd1801713de9'}),
# (:wine_SauterneRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SauterneRegion'}),
# (:N4de3da6ed8154d5cad4454a45119e046 {uri: 'N4de3da6ed8154d5cad4454a45119e046'}),
# (:N03f86de1a5654517b144432965905fcf {uri: 'N03f86de1a5654517b144432965905fcf'}),
# (:N734f53b733df46c6859f39a7da885f6a {uri: 'N734f53b733df46c6859f39a7da885f6a'}),
# (:Nf8051c99b54a4d079f28cf0971af4bae {uri: 'Nf8051c99b54a4d079f28cf0971af4bae'}),
# (:wine_LateHarvest {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LateHarvest'}),
# (:N258ef10ebf8440139db1cb1d5e52110f {uri: 'N258ef10ebf8440139db1cb1d5e52110f'}),
# (:N4a74431663c74212bfe14a8cc70ce000 {uri: 'N4a74431663c74212bfe14a8cc70ce000'}),
# (:N206ecf5c7b984ac991595890cc54afb9 {uri: 'N206ecf5c7b984ac991595890cc54afb9'}),
# (:Ne661a7a6224e4128813b737da1422172 {uri: 'Ne661a7a6224e4128813b737da1422172'}),
# (:wine_LaneTannerPinotNoir {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LaneTannerPinotNoir'}),
# (:Nd2cc550529eb42cebcb1c3860a953574 {uri: 'Nd2cc550529eb42cebcb1c3860a953574'}),
# (:N9e56c5a7506449d496113e9e9db14209 {uri: 'N9e56c5a7506449d496113e9e9db14209'}),
# (:wine_Anjou {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Anjou'}),
# (:N4aa89a90c09c4dd89e14474b5d332095 {uri: 'N4aa89a90c09c4dd89e14474b5d332095'}),
# (:Ndaa75dabcd6d469f9650ff0c443bcd59 {uri: 'Ndaa75dabcd6d469f9650ff0c443bcd59'}),
# (:Nb49f483e84064db58f833093ec1c2468 {uri: 'Nb49f483e84064db58f833093ec1c2468'}),
# (:wine_Beaujolais {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Beaujolais'}),
# (:wine_CotesDOrRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CotesDOrRegion'}),
# (:Ncd58b4ebfae1491b8204abb1be2f030a {uri: 'Ncd58b4ebfae1491b8204abb1be2f030a'}),
# (:wine_DryWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryWine'}),
# (:Ne4bb1c3955ee4436985da7c0da547ab8 {uri: 'Ne4bb1c3955ee4436985da7c0da547ab8'}),
# (:N52df6d06976448bfb92315109f44645d {uri: 'N52df6d06976448bfb92315109f44645d'}),
# (:N0af3631f354448859692fe37d8701dbf {uri: 'N0af3631f354448859692fe37d8701dbf'}),
# (:wine_Taylor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Taylor'}),
# (:wine_LongridgeMerlot {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LongridgeMerlot'}),
# (:N8fb7a22ae3fd485990c17cbc03fab565 {uri: 'N8fb7a22ae3fd485990c17cbc03fab565'}),
# (:N56e7caf99ea34489b853dfa4f1b16b51 {uri: 'N56e7caf99ea34489b853dfa4f1b16b51'}),
# (:Nfbc9a4200082420ab85e832999e3bb6e {uri: 'Nfbc9a4200082420ab85e832999e3bb6e'}),
# (:N098838fdc82643ae95a56a75d440b701 {uri: 'N098838fdc82643ae95a56a75d440b701'}),
# (:N9e663ba7d6ff4625b590583ffa3ddeca {uri: 'N9e663ba7d6ff4625b590583ffa3ddeca'}),
# (:Nf7cd766991a443bbb028a774954fb69f {uri: 'Nf7cd766991a443bbb028a774954fb69f'}),
# (:Nee05a53161454c99ba8dbc591cf06251 {uri: 'Nee05a53161454c99ba8dbc591cf06251'}),
# (:wine_Marietta {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Marietta'}),
# (:Na5fc278341844b3b94766c6b3ccd1b48 {uri: 'Na5fc278341844b3b94766c6b3ccd1b48'}),
# (:wine_RedTableWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RedTableWine'}),
# (:wine_Moderate {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Moderate'}),
# (:Nb2d7cfa5b42a43319ec080cc19ea125e {uri: 'Nb2d7cfa5b42a43319ec080cc19ea125e'}),
# (:wine_WineGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineGrape'}),
# (:N6226338a126d409a9d163e03805cd0d3 {uri: 'N6226338a126d409a9d163e03805cd0d3'}),
# (:N47d5be69558b4ed6bdc9f9cf33d5e077 {uri: 'N47d5be69558b4ed6bdc9f9cf33d5e077'}),
# (:Nd391bdf0ab974f84be1a646ef9f3a296 {uri: 'Nd391bdf0ab974f84be1a646ef9f3a296'}),
# (:N8a0f184ad2134b48a7b6a4d89e4c0749 {uri: 'N8a0f184ad2134b48a7b6a4d89e4c0749'}),
# (:Neba2d7325d7242d7b6b04a77f8034223 {uri: 'Neba2d7325d7242d7b6b04a77f8034223'}),
# (:wine_Meursault {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Meursault'}),
# (:Nfb6b394821534b44895abb91a1cf48c2 {uri: 'Nfb6b394821534b44895abb91a1cf48c2'}),
# (:N8075afd8088d46aeb32d6477a95261b6 {uri: 'N8075afd8088d46aeb32d6477a95261b6'}),
# (:wine_CabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetSauvignon'}),
# (:N602bbdf384cf4e1e94c66e4084e8135c {uri: 'N602bbdf384cf4e1e94c66e4084e8135c'}),
# (:Na4f9e39d466f4f62bd7120ee8e0fb14a {uri: 'Na4f9e39d466f4f62bd7120ee8e0fb14a'}),
# (:N9fe6d95379fd46d48a4b30174bcbdbe0 {uri: 'N9fe6d95379fd46d48a4b30174bcbdbe0'}),
# (:Nf6f48cacfed84d599d417e124ab66e98 {uri: 'Nf6f48cacfed84d599d417e124ab66e98'}),
# (:N68e41b203a9b45c98c16c58f3a49f8ad {uri: 'N68e41b203a9b45c98c16c58f3a49f8ad'}),
# (:Ne1bf6497f7a949eab96ccd3399066256 {uri: 'Ne1bf6497f7a949eab96ccd3399066256'}),
# (:N6857067f53fc4b3ab16b334f0676ad7e {uri: 'N6857067f53fc4b3ab16b334f0676ad7e'}),
# (:wine_WhiteBordeaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteBordeaux'}),
# (:N5094ff85f06f49e6ace09f52dd41e88b {uri: 'N5094ff85f06f49e6ace09f52dd41e88b'}),
# (:XMLSchema_positiveInteger {uri: 'http://www.w3.org/2001/XMLSchema_positiveInteger'}),
# (:wine_BordeauxRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BordeauxRegion'}),
# (:N47cdb82db50f4f3384edb2c3f76498f1 {uri: 'N47cdb82db50f4f3384edb2c3f76498f1'}),
# (:wine_CabernetFrancGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetFrancGrape'}),
# (:wine_FoxenCheninBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FoxenCheninBlanc'}),
# (:N4d3dab50b2254e02bd793f259ac191f8 {uri: 'N4d3dab50b2254e02bd793f259ac191f8'}),
# (:Nc7ed567265184d01876ef3d9b89fdf17 {uri: 'Nc7ed567265184d01876ef3d9b89fdf17'}),
# (:wine_SauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SauvignonBlanc'}),
# (:wine_MariettaCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaCabernetSauvignon'}),
# (:wine_adjacentRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_adjacentRegion'}),
# (:wine_SchlossRothermel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossRothermel'}),
# (:wine_VintageYear {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_VintageYear'}),
# (:N86e569093a8940ceaba49fcf4670e49c {uri: 'N86e569093a8940ceaba49fcf4670e49c'}),
# (:wine_SevreEtMaine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SevreEtMaine'}),
# (:wine_White {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_White'}),
# (:Na15c555d1c2244a3a411143ade6d63d9 {uri: 'Na15c555d1c2244a3a411143ade6d63d9'}),
# (:N2e79391f014c4f07a9e70601c5303acc {uri: 'N2e79391f014c4f07a9e70601c5303acc'}),
# (:Nf31817d8ebf44fa89649ac68c51c122d {uri: 'Nf31817d8ebf44fa89649ac68c51c122d'}),
# (:N5610a9341653447c979782fb3da5ada1 {uri: 'N5610a9341653447c979782fb3da5ada1'}),
# (:N866a1c12dca447e69565f9d9067d574e {uri: 'N866a1c12dca447e69565f9d9067d574e'}),
# (:Necf2587cb3ef45feaf39bbac168cf5d7 {uri: 'Necf2587cb3ef45feaf39bbac168cf5d7'}),
# (:Nbe143803ad68483783a94fcc2d0a22d2 {uri: 'Nbe143803ad68483783a94fcc2d0a22d2'}),
# (:Ne1e3da9779fb4f3c807d5c8200378871 {uri: 'Ne1e3da9779fb4f3c807d5c8200378871'}),
# (:Nb9666828b18647e692d3a1ca9a4231e8 {uri: 'Nb9666828b18647e692d3a1ca9a4231e8'}),
# (:Ne30b3b6c1d444fcb9374e9b3df0a58fb {uri: 'Ne30b3b6c1d444fcb9374e9b3df0a58fb'}),
# (:N6ace755563894236bc7bb0c505ae580d {uri: 'N6ace755563894236bc7bb0c505ae580d'}),
# (:N3b073a427c7648c593091d5266601c84 {uri: 'N3b073a427c7648c593091d5266601c84'}),
# (:wine_TexasRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_TexasRegion'}),
# (:wine_CheninBlancGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CheninBlancGrape'}),
# (:Ndc8a4d1139184e96ab834f4f8cf62159 {uri: 'Ndc8a4d1139184e96ab834f4f8cf62159'}),
# (:N5fcb39ba0e5a4cf2a03da16be7d1af48 {uri: 'N5fcb39ba0e5a4cf2a03da16be7d1af48'}),
# (:N724c5668cf7e4b22b1f69ec1748374b3 {uri: 'N724c5668cf7e4b22b1f69ec1748374b3'}),
# (:wine_ItalianRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ItalianRegion'}),
# (:N0793038b30c2409895ab073b849f7af0 {uri: 'N0793038b30c2409895ab073b849f7af0'}),
# (:N1692871381fd4143a936013161caa7f2 {uri: 'N1692871381fd4143a936013161caa7f2'}),
# (:Nf8f7c1ecf6ab44b4839b12b94e8c901e {uri: 'Nf8f7c1ecf6ab44b4839b12b94e8c901e'}),
# (:Ne52b3f7a5c1a4757bebd397306c932f3 {uri: 'Ne52b3f7a5c1a4757bebd397306c932f3'}),
# (:wine_Beringer {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Beringer'}),
# (:wine_Full {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Full'}),
# (:Nca5d8e6e9f7244a1aacf221249073a86 {uri: 'Nca5d8e6e9f7244a1aacf221249073a86'}),
# (:Nd80fcbd0e340462f87b17ddbb160dd64 {uri: 'Nd80fcbd0e340462f87b17ddbb160dd64'}),
# (:N5e68fad32a704780bf168e06731531cb {uri: 'N5e68fad32a704780bf168e06731531cb'}),
# (:N79a9ad3dc0f34e3e8ed3682a4cb40aa8 {uri: 'N79a9ad3dc0f34e3e8ed3682a4cb40aa8'}),
# (:wine_Foxen {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Foxen'}),
# (:wine_CorbansDryWhiteRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansDryWhiteRiesling'}),
# (:Nc6fc4773fb9f4c4aad3941fac7df8e43 {uri: 'Nc6fc4773fb9f4c4aad3941fac7df8e43'}),
# (:N89050ce901d5444a8a29dee0ba1180fe {uri: 'N89050ce901d5444a8a29dee0ba1180fe'}),
# (:Ncbc6556c9f8749bcb12cb4a2addeddd1 {uri: 'Ncbc6556c9f8749bcb12cb4a2addeddd1'}),
# (:N9a8f2fa669934a59a69e180a04f20640 {uri: 'N9a8f2fa669934a59a69e180a04f20640'}),
# (:N6e2796240130432695f2bdbcd5080d1f {uri: 'N6e2796240130432695f2bdbcd5080d1f'}),
# (:Nb51a59ce880a4972b0644f6f047df3dd {uri: 'Nb51a59ce880a4972b0644f6f047df3dd'}),
# (:Nfe896c62babe4feeaacef54d6d02f080 {uri: 'Nfe896c62babe4feeaacef54d6d02f080'}),
# (:N166a8ebb8d2f42abb9e7b8baf0d5c726 {uri: 'N166a8ebb8d2f42abb9e7b8baf0d5c726'}),
# (:N88a79cfccccc402095981fbe6738e41c {uri: 'N88a79cfccccc402095981fbe6738e41c'}),
# (:wine_Sancerre {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sancerre'}),
# (:N73629312b28c482f9dfd98da4a5c6b13 {uri: 'N73629312b28c482f9dfd98da4a5c6b13'}),
# (:N5ac775180f084f0a8cf03764c30cf99f {uri: 'N5ac775180f084f0a8cf03764c30cf99f'}),
# (:wine_Wine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Wine'}),
# (:N11a631a24ba141a38f965f953c71ba6c {uri: 'N11a631a24ba141a38f965f953c71ba6c'}),
# (:N447e88091de74d5e9ef0909fb5912a9e {uri: 'N447e88091de74d5e9ef0909fb5912a9e'}),
# (:N59290cc6555a4fa09ce019834b5d5fc5 {uri: 'N59290cc6555a4fa09ce019834b5d5fc5'}),
# (:N255ee2412a5b4438b5b1fce66f960042 {uri: 'N255ee2412a5b4438b5b1fce66f960042'}),
# (:wine_SantaCruzMountainsRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SantaCruzMountainsRegion'}),
# (:N79b656cca9d24e1c970dc40caf0407a4 {uri: 'N79b656cca9d24e1c970dc40caf0407a4'}),
# (:wine_CabernetSauvignonGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetSauvignonGrape'}),
# (:Nddd289f5d4d3422a8aae9a1c9836c077 {uri: 'Nddd289f5d4d3422a8aae9a1c9836c077'}),
# (:wine_SelaksSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SelaksSauvignonBlanc'}),
# (:wine_CentralCoastRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CentralCoastRegion'}),
# (:Nc191254f12ff42c3a7d7387f4eace642 {uri: 'Nc191254f12ff42c3a7d7387f4eace642'}),
# (:Nfc64ad9c18044587b5711287c7f97c43 {uri: 'Nfc64ad9c18044587b5711287c7f97c43'}),
# (:N6d970c78c2e9493b895e1ba20fb13370 {uri: 'N6d970c78c2e9493b895e1ba20fb13370'}),
# (:owl_FunctionalProperty {uri: 'http://www.w3.org/2002/07/owl_FunctionalProperty'}),
# (:wine_hasBody {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasBody'}),
# (:Nd5f268e67e9247479081bdec843208a1 {uri: 'Nd5f268e67e9247479081bdec843208a1'}),
# (:Nec0bf3b0322741e1bd2c18c40d8a5a0c {uri: 'Nec0bf3b0322741e1bd2c18c40d8a5a0c'}),
# (:Nd4ac25fa737e4a67ab3b873e8e7eb010 {uri: 'Nd4ac25fa737e4a67ab3b873e8e7eb010'}),
# (:N63a1eb09f54a47f392a6732bc6782c84 {uri: 'N63a1eb09f54a47f392a6732bc6782c84'}),
# (:wine_StEmilion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StEmilion'}),
# (:wine_EdnaValleyRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_EdnaValleyRegion'}),
# (:owl_TransitiveProperty {uri: 'http://www.w3.org/2002/07/owl_TransitiveProperty'}),
# (:N119d876024f547198f60d69ce4281117 {uri: 'N119d876024f547198f60d69ce4281117'}),
# (:N6ae9a49fe2c14eed9be6857307df314d {uri: 'N6ae9a49fe2c14eed9be6857307df314d'}),
# (:Nf173d41f20d94a8f861a494d9a40288b {uri: 'Nf173d41f20d94a8f861a494d9a40288b'}),
# (:Nabaa1f0f5abf407ebbc0eb2829013a02 {uri: 'Nabaa1f0f5abf407ebbc0eb2829013a02'}),
# (:Nf03b4fdf5ec94a36ac323dceb4240dc8 {uri: 'Nf03b4fdf5ec94a36ac323dceb4240dc8'}),
# (:Nab79022b421948d3803dc7ff4a2b9c21 {uri: 'Nab79022b421948d3803dc7ff4a2b9c21'}),
# (:Nf5e7fa7d42074a70b6064933b0dc844b {uri: 'Nf5e7fa7d42074a70b6064933b0dc844b'}),
# (:N69bcc0f8d44e4260b2fc60604c67817b {uri: 'N69bcc0f8d44e4260b2fc60604c67817b'}),
# (:Na49da34fc89441099127cf2414d10fe9 {uri: 'Na49da34fc89441099127cf2414d10fe9'}),
# (:wine_MendocinoRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MendocinoRegion'}),
# (:wine_VentanaCheninBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_VentanaCheninBlanc'}),
# (:N86976c7f8950449db4adaab516444d31 {uri: 'N86976c7f8950449db4adaab516444d31'}),
# (:wine_hasWineDescriptor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasWineDescriptor'}),
# (:Nc927c135c6c6427191e071c2ea2bbee8 {uri: 'Nc927c135c6c6427191e071c2ea2bbee8'}),
# (:wine_ChateauMargaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMargaux'}),
# (:wine_ElyseZinfandel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ElyseZinfandel'}),
# (:wine_SauvignonBlancGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SauvignonBlancGrape'}),
# (:wine_SchlossRothermelTrochenbierenausleseRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossRothermelTrochenbierenausleseRiesling'}),
# (:wine_madeIntoWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeIntoWine'}),
# (:wine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine'}),
# (:wine_SweetWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SweetWine'}),
# (:wine_PetiteVerdotGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PetiteVerdotGrape'}),
# (:N77f357a8728e4ccf82b3d99a0284b027 {uri: 'N77f357a8728e4ccf82b3d99a0284b027'}),
# (:wine_PeterMccoyChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PeterMccoyChardonnay'}),
# ...
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountEdenVineyardEdnaValleyChardonnay'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}) CREATE (a)_[:wine_hasBody]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Ventana'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Winery'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N73629312b28c482f9dfd98da4a5c6b13'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'Nbc3bfc6c1ef84557a5b0723f3d28422d'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'N7e4a28a5594a4a95bedd7a3bb33cbe91'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LongridgeMerlot'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Dry'}) CREATE (a)_[:wine_hasSugar]_>(b)
# MATCH (a {uri: 'Nfc2e0cc462644f02b8acf73c44ceb144'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasColor'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'Nc90cdd4a70234f46ac6fa42449b1f130'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Bancroft'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'Nf31817d8ebf44fa89649ac68c51c122d'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PetiteSyrah'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GaryFarrellMerlot'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}) CREATE (a)_[:wine_hasBody]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BancroftChardonnay'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_NapaRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauDeMeursaultMeursault'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Moderate'}) CREATE (a)_[:wine_hasFlavor]_>(b)
# MATCH (a {uri: 'Nee05a53161454c99ba8dbc591cf06251'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GamayGrape'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'N77277ceb6c714ec89970492b4721c277'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N2b0e1b8005204558939ae43ab66ddf04'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_White'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineColor'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Nf8051c99b54a4d079f28cf0971af4bae'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Full'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'Nf8ac4219e8b44e8eb4c194365159fd9b'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Full'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MendocinoRegion'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CaliforniaRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossVolradTrochenbierenausleseRiesling'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossVolrad'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'N63a1eb09f54a47f392a6732bc6782c84'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetSauvignonGrape'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'Na73d551d36664d0c8f3557f7382f2670'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhitehallLanePrimavera'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_NapaRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'N98505c4818c44c49931258a6b21fe514'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SelaksSauvignonBlanc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_NewZealandRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'Necf2587cb3ef45feaf39bbac168cf5d7'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N70ae99149fcc4004acdec653a99ff299'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Marietta'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'N0d5f002159da4561a71f7a84f4485bfb'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Wine'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamPinotNoir'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Mountadam'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'Nddc7d637d6064951813ea5c387b7f84c'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhitehallLanePrimavera'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DessertWine'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CaliforniaRegion'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_USRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'N0ce7a18fde194998be8e01c28926e987'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_locatedIn'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'Nf753ddac215d42bcb421fb211f118c4e'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Moderate'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FullBodiedWine'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N9e56c5a7506449d496113e9e9db14209'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SangioveseGrape'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'Nc5aae934552c46cfbe8ecab27fe13ab1'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeVougeot'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'N0b71027280f741daadbcd2987b01100d'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RieslingGrape'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineGrape'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N2264bac77a00472b9c3d487372a3a0f4'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SauvignonBlanc'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasSugar'}), (b {uri: 'http://www.w3.org/2002/07/owl_ObjectProperty'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Naf79dc6a2ded449691a281fa3f4b6c65'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChardonnayGrape'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'N1836becc36a047bab16a5b25c7e1292b'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMargauxWinery'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'Na5fc278341844b3b94766c6b3ccd1b48'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N84faba972fbe465191b1f483d2882a3b'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MeursaultRegion'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sweet'}), (b {uri: 'http://www.w3.org/2002/07/owl_Thing'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N84faba972fbe465191b1f483d2882a3b'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryRiesling'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N73dca359370048ef96c56a314dbf058e'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasColor'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ElyseZinfandel'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Elyse'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountEdenVineyardEdnaValleyChardonnay'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Dry'}) CREATE (a)_[:wine_hasSugar]_>(b)
# MATCH (a {uri: 'N9f837b9263464d388e552d2dfa64d7aa'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Full'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'N4bf5b55a32654afab0d585615e1fc6c9'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_White'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'Nc3bb688a984d413b9ce3f20b57922faa'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasColor'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'N285b030474e9493eb9b3824486489faa'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AnjouRegion'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PageMillWineryCabernetSauvignon'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}) CREATE (a)_[:wine_hasBody]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountEdenVineyardEstatePinotNoir'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotNoir'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CentralTexasRegion'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Region'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LateHarvest'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_EarlyHarvest'}) CREATE (a)_[:owl_disjointWith]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_NapaRegion'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CaliforniaRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'N98c7a9bb3a88454eb654d93db102f9cd'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasBody'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaOldVinesRed'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Marietta'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'Ncd4e3b76f70648fd848ad12d44da91dc'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'N855bb9d782db41e2b085ad40430e065c'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ZinfandelGrape'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'N77f357a8728e4ccf82b3d99a0284b027'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Riesling'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineDescriptor'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Ncc0fc18787694b44ab1d7897500ad3db'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Loire'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Nf276d16cd59b43cab4e1634ed4295900'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_KalinCellarsSemillon'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_KalinCellars'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SelaksSauvignonBlanc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SauvignonBlanc'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Ndc8a4d1139184e96ab834f4f8cf62159'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasColor'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasBody'}), (b {uri: 'http://www.w3.org/2002/07/owl_ObjectProperty'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeLaPoussie'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Winery'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_VentanaCheninBlanc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Moderate'}) CREATE (a)_[:wine_hasFlavor]_>(b)
# MATCH (a {uri: 'Nc927c135c6c6427191e071c2ea2bbee8'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BancroftChardonnay'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Moderate'}) CREATE (a)_[:wine_hasFlavor]_>(b)
# MATCH (a {uri: 'N734f53b733df46c6859f39a7da885f6a'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansPrivateBinSauvignonBlanc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SauvignonBlanc'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N86e569093a8940ceaba49fcf4670e49c'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N54bad85d2cc54beda9303530b8e3487b'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasBody'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'N0c75244e398a43439130709e0931015e'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_locatedIn'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'Nbb5eb188aad148b2a31ce09d3b3b8cb4'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N39f3aeadd6094b9db742f023a276d854'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaZinfandel'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Moderate'}) CREATE (a)_[:wine_hasFlavor]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhitehallLaneCabernetFranc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Dry'}) CREATE (a)_[:wine_hasSugar]_>(b)
# CPU times: user 91.1 ms, sys: 9.62 ms, total: 101 ms
# Wall time: 93 ms

# %% [markdown]
# ### TuringDB v1

# %%
def rdf_to_cypher_v1(rdf_file):
    from rdflib import Graph
    
    g = Graph()
    g.parse(rdf_file)
    
    # Collect nodes
    nodes = {str(s) for s, _, _ in g} | {str(o) for _, _, o in g if not isinstance(o, str) or o.startswith('http')}
    node_to_var = {node: f"n{i}" for i, node in enumerate(nodes)}
    
    parts = []
    
    # Add all nodes
    for node in nodes:
        var = node_to_var[node]
        label = node.split('/')[-1]
        # Prefix label with underscore if it starts with a digit
        if label and label[0].isdigit():
            label = 'ID_' + label
        parts.append(f"({var}:{label} {{uri: '{node}'}})")
    
    # Add all edges
    for s, p, o in g:
        if not isinstance(o, str) or o.startswith('http'):
            s_var = node_to_var[str(s)]
            o_var = node_to_var[str(o)]
            pred = str(p).split('/')[-1]
            # Prefix predicate with underscore if it starts with a digit
            if pred and pred[0].isdigit():
                pred = 'ID_' + pred
            parts.append(f"({s_var})-[:{pred}]->({o_var})")
    
    return "CREATE " + ",\n".join(parts)

# %%
def sanitize_identifier(s):
    """Sanitize identifiers (labels, relationship types, property names)"""
    if not s:
        return "ID_empty"
    
    # Replace invalid characters with underscores
    s = s.replace('#', '_').replace('-', '_').replace('/', '_').replace('.', '_')
    
    # Prefix with ID_ if starts with digit or underscore
    if s[0].isdigit() or s[0] == '_':
        s = 'ID_' + s
    
    # Remove any other non-alphanumeric characters except underscores
    s = ''.join(c if c.isalnum() or c == '_' else '_' for c in s)
    
    return s

def sanitize_value(s):
    """Sanitize property values (escape quotes)"""
    return s.replace("'", "\\'").replace('"', '\\"')

def rdf_to_cypher_v1(rdf_file):
    from rdflib import Graph
    
    g = Graph()
    g.parse(rdf_file)
    
    # Collect nodes
    nodes = {str(s) for s, _, _ in g} | {str(o) for _, _, o in g if not isinstance(o, str) or o.startswith('http')}
    node_to_var = {node: f"n{i}" for i, node in enumerate(nodes)}
    
    parts = []
    
    # Add all nodes
    for node in nodes:
        var = node_to_var[node]
        label = sanitize_identifier(node.split('/')[-1])
        uri_value = sanitize_value(node)
        parts.append(f"({var}:{label} {{uri: '{uri_value}'}})")
    
    # Add all edges
    for s, p, o in g:
        if not isinstance(o, str) or o.startswith('http'):
            s_var = node_to_var[str(s)]
            o_var = node_to_var[str(o)]
            pred = sanitize_identifier(str(p).split('/')[-1])
            parts.append(f"({s_var})-[:{pred}]-({o_var})")
    
    return "CREATE " + ",\n".join(parts)

# %%
def rdf_to_cypher_v1(rdf_file, include_blank_nodes=False):
    from rdflib import Graph, RDF, RDFS, OWL, Literal
    
    g = Graph()
    g.parse(rdf_file)
    
    # Helper function to detect blank nodes
    def is_blank_node(uri):
        # Blank nodes in RDF are just the hash without http://
        return not uri.startswith('http://') and not uri.startswith('https://')
    
    # Collect all nodes (exclude literal values)
    nodes = {str(s) for s, _, _ in g} | {str(o) for _, _, o in g if not isinstance(o, Literal)}
    
    # Filter out blank nodes if requested
    if not include_blank_nodes:
        nodes = {n for n in nodes if not is_blank_node(n)}
    
    node_to_var = {node: f"n{i}" for i, node in enumerate(nodes)}
    
    # Map nodes to their types (classes)
    node_types = {}
    for s, p, o in g:
        if p == RDF.type and not isinstance(o, Literal):
            node_types[str(s)] = str(o)
    
    parts = []
    
    # Add all nodes
    for node in nodes:
        var = node_to_var[node]
        
        # Use the node's own name as label
        label = sanitize_identifier(node.split('/')[-1].split('#')[-1])
        
        # Extract meaningful name (without sanitization for readability)
        name = node.split('/')[-1].split('#')[-1]
        
        # Use generic label for blank nodes
        if is_blank_node(node):
            label = "BlankNode"
            name = "BlankNode"
        
        uri_value = sanitize_value(node)
        name_value = sanitize_value(name)
        
        # Add type as a property if available
        if node in node_types:
            type_value = sanitize_value(node_types[node])
            parts.append(f"({var}:{label} {{uri: '{uri_value}', name: '{name_value}', type: '{type_value}'}})")
        else:
            parts.append(f"({var}:{label} {{uri: '{uri_value}', name: '{name_value}'}})")
    
    # Add all edges (exclude literals and blank nodes if requested)
    for s, p, o in g:
        if not isinstance(o, Literal):
            # Skip edges involving blank nodes if not included
            if str(s) not in node_to_var or str(o) not in node_to_var:
                continue
            
            s_var = node_to_var[str(s)]
            o_var = node_to_var[str(o)]
            pred = sanitize_identifier(str(p).split('/')[-1].split('#')[-1])
            parts.append(f"({s_var})-[:{pred}]->({o_var})")

    return "CREATE " + ",\n".join(parts)

# %%
# %%time

# Create Cypher CREATE command for TuringDB v1
graph_CREATE_command_v1 = rdf_to_cypher_v1(path_rdf, include_blank_nodes=False)
#print(graph_CREATE_command_v1)

# Save Cypher query to file
with open(f"{path_data}/{example_name}.cypher", "w") as f:
    f.write(graph_CREATE_command_v1)
# Out:
# CPU times: user 89 ms, sys: 6.89 ms, total: 95.9 ms
# Wall time: 94.4 ms

# %%
# %%time

# Create Cypher CREATE command for TuringDB v1
graph_CREATE_command_v1_whole_ontology = rdf_to_cypher_v1(path_rdf, include_blank_nodes=True)
#print(graph_CREATE_command_v1_whole_ontology)

# Save Cypher query to file
with open(f"{path_data}/{example_name}_whole_ontology.cypher", "w") as f:
    f.write(graph_CREATE_command_v1_whole_ontology)
# Out:
# CPU times: user 95 ms, sys: 13.7 ms, total: 109 ms
# Wall time: 98.3 ms

# %% [markdown]
# ## tree - New version

# %%
def rdf_to_cypher(rdf_file, include_blank_nodes=False):
    from rdflib import Graph, RDF, RDFS, OWL, Literal
    
    g = Graph()
    g.parse(rdf_file)
    
    # Helper function to detect blank nodes
    def is_blank_node(uri):
        return not uri.startswith('http://') and not uri.startswith('https://')
    
    # Build class hierarchy map
    def build_class_hierarchy():
        """Build a map of class -> parent class(es) from subClassOf and intersectionOf"""
        hierarchy = {}
        
        # Handle rdfs:subClassOf
        for s, p, o in g:
            if p == RDFS.subClassOf and not isinstance(o, Literal):
                if not is_blank_node(str(o)):
                    child = str(s)
                    parent = str(o)
                    if child not in hierarchy:
                        hierarchy[child] = []
                    hierarchy[child].append(parent)
        
        # Handle owl:intersectionOf - find Wine in the intersection
        for s, p, o in g:
            if p == OWL.intersectionOf and not isinstance(o, Literal):
                child = str(s)
                # Follow the RDF list to find classes in the intersection
                current = o
                while current and str(current) != 'http://www.w3.org/1999/02/22-rdf-syntax-ns#nil':
                    # Get rdf:first (the class in the list)
                    for _, first_p, first_o in g.triples((current, RDF.first, None)):
                        if not isinstance(first_o, Literal) and not is_blank_node(str(first_o)):
                            if child not in hierarchy:
                                hierarchy[child] = []
                            hierarchy[child].append(str(first_o))
                    
                    # Get rdf:rest (next item in list)
                    next_item = None
                    for _, rest_p, rest_o in g.triples((current, RDF.rest, None)):
                        next_item = rest_o
                        break
                    current = next_item
        
        return hierarchy
    
    def get_root_class(class_uri, hierarchy, max_depth=20):
        """Get the most generic (root) class by following parent chain"""
        visited = set()
        current = class_uri
        
        for _ in range(max_depth):
            if current in visited:
                break
            visited.add(current)
            
            # Check if this class has parents
            if current in hierarchy:
                # Pick the first non-OWL/RDF parent
                parents = [p for p in hierarchy[current] 
                          if not p.startswith('http://www.w3.org/2002/07/owl#')
                          and not p.startswith('http://www.w3.org/2000/01/rdf-schema#')
                          and not p.startswith('http://www.w3.org/1999/02/')]
                if parents:
                    current = parents[0]  # Follow first parent
                else:
                    break
            else:
                break
        
        return current
    
    hierarchy = build_class_hierarchy()
    
    # Collect all nodes
    all_nodes = {str(s) for s, _, _ in g} | {str(o) for _, _, o in g if not isinstance(o, Literal)}
    
    if not include_blank_nodes:
        nodes = {n for n in all_nodes if not is_blank_node(n)}
    else:
        nodes = all_nodes
    
    node_to_var = {node: f"n{i}" for i, node in enumerate(nodes)}
    
    parts = []
    
    # Add all nodes
    for node in nodes:
        var = node_to_var[node]
        instance_name = node.split('/')[-1].split('#')[-1]
        
        if is_blank_node(node):
            label = "BlankNode"
            name = "BlankNode"
            uri_value = sanitize_value(node)
            name_value = sanitize_value(name)
            parts.append(f"({var}:{label} {{uri: '{uri_value}', name: '{name_value}'}})")
        else:
            # Check if this node is an instance (has rdf:type)
            instance_type = None
            for s, p, o in g:
                if str(s) == node and p == RDF.type and not isinstance(o, Literal):
                    o_str = str(o)
                    if o_str != 'http://www.w3.org/2002/07/owl#Class' and not is_blank_node(o_str):
                        instance_type = o_str
                        break
            
            if instance_type:
                # This is an instance - find its root class
                root_class = get_root_class(instance_type, hierarchy)
                label = sanitize_identifier(root_class.split('/')[-1].split('#')[-1])
                name = instance_name
                
                uri_value = sanitize_value(node)
                name_value = sanitize_value(name)
                type_value = sanitize_value(instance_type)
                parts.append(f"({var}:{label} {{uri: '{uri_value}', name: '{name_value}', type: '{type_value}'}})")
            else:
                # This is a class definition - find its root
                if node in hierarchy or any(node in parents for parents in hierarchy.values()):
                    root_class = get_root_class(node, hierarchy)
                    label = sanitize_identifier(root_class.split('/')[-1].split('#')[-1])
                else:
                    label = sanitize_identifier(instance_name)
                
                name = instance_name
                uri_value = sanitize_value(node)
                name_value = sanitize_value(name)
                parts.append(f"({var}:{label} {{uri: '{uri_value}', name: '{name_value}'}})")
    
    # Add all edges
    for s, p, o in g:
        if not isinstance(o, Literal):
            if str(s) not in node_to_var or str(o) not in node_to_var:
                continue
            
            s_var = node_to_var[str(s)]
            o_var = node_to_var[str(o)]
            pred = sanitize_identifier(str(p).split('/')[-1].split('#')[-1])
            parts.append(f"({s_var})-[:{pred}]->({o_var})")
    
    return "CREATE " + ",\n".join(parts)

# %%
# %%time

# Create Cypher CREATE command for TuringDB v1
graph_CREATE_command = rdf_to_cypher(path_rdf, include_blank_nodes=False)
print(graph_CREATE_command)

# Save Cypher query to file
with open(f"{path_data}/{example_name}_tree.cypher", "w") as f:
    f.write(graph_CREATE_command)
# Out:
# CREATE (n0:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#McGuinnesso', name: 'McGuinnesso', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n1:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrellMerlot', name: 'GaryFarrellMerlot', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Merlot'}),
# (n2:Thing {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlancGrape', name: 'SauvignonBlancGrape', type: 'http://www.w3.org/2002/07/owl#Thing'}),
# (n3:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrell', name: 'GaryFarrell', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n4:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossRothermelTrochenbierenausleseRiesling', name: 'SchlossRothermelTrochenbierenausleseRiesling', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SweetRiesling'}),
# (n5:ObjectProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeIntoWine', name: 'madeIntoWine', type: 'http://www.w3.org/2002/07/owl#ObjectProperty'}),
# (n6:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaZinfandel', name: 'MariettaZinfandel', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Zinfandel'}),
# (n7:Ontology {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine', name: 'wine', type: 'http://www.w3.org/2002/07/owl#Ontology'}),
# (n8:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaRegion', name: 'CaliforniaRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n9:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GamayGrape', name: 'GamayGrape', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'}),
# (n10:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MeursaultRegion', name: 'MeursaultRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n11:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FrenchWine', name: 'FrenchWine'}),
# (n12:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamChardonnay', name: 'MountadamChardonnay', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chardonnay'}),
# (n13:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauChevalBlanc', name: 'ChateauChevalBlanc', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n14:ObjectProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape', name: 'madeFromGrape', type: 'http://www.w3.org/2002/07/owl#ObjectProperty'}),
# (n15:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SweetWine', name: 'SweetWine'}),
# (n16:Thing {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteVerdotGrape', name: 'PetiteVerdotGrape', type: 'http://www.w3.org/2002/07/owl#Thing'}),
# (n17:Thing {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Rose', name: 'Rose', type: 'http://www.w3.org/2002/07/owl#Thing'}),
# (n18:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PeterMccoyChardonnay', name: 'PeterMccoyChardonnay', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chardonnay'}),
# (n19:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Pauillac', name: 'Pauillac'}),
# (n20:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Gamay', name: 'Gamay'}),
# (n21:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Margaux', name: 'Margaux'}),
# (n22:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotBlancGrape', name: 'PinotBlancGrape', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'}),
# (n23:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SemillonGrape', name: 'SemillonGrape', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'}),
# (n24:DatatypeProperty {uri: 'http://www.w3.org/2002/07/owl#DatatypeProperty', name: 'DatatypeProperty'}),
# (n25:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Muscadet', name: 'Muscadet'}),
# (n26:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaBarbaraRegion', name: 'SantaBarbaraRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n27:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KalinCellars', name: 'KalinCellars', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n28:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SangioveseGrape', name: 'SangioveseGrape', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'}),
# (n29:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaOldVinesRed', name: 'MariettaOldVinesRed', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedTableWine'}),
# (n30:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PauillacRegion', name: 'PauillacRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n31:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineSugar', name: 'WineSugar'}),
# (n32:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chardonnay', name: 'Chardonnay'}),
# (n33:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BeaujolaisRegion', name: 'BeaujolaisRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n34:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Light', name: 'Light', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineBody'}),
# (n35:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SelaksIceWine', name: 'SelaksIceWine', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#IceWine'}),
# (n36:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KathrynKennedy', name: 'KathrynKennedy', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n37:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauterneRegion', name: 'SauterneRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n38:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedWine', name: 'RedWine'}),
# (n39:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteNonSweetWine', name: 'WhiteNonSweetWine'}),
# (n40:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineColor', name: 'WineColor'}),
# (n41:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LateHarvest', name: 'LateHarvest'}),
# (n42:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeLaPoussieSancerre', name: 'ClosDeLaPoussieSancerre', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sancerre'}),
# (n43:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#NewZealandRegion', name: 'NewZealandRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n44:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ArroyoGrandeRegion', name: 'ArroyoGrandeRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n45:VintageYear {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Year1998', name: 'Year1998', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#VintageYear'}),
# (n46:Thing {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MalbecGrape', name: 'MalbecGrape', type: 'http://www.w3.org/2002/07/owl#Thing'}),
# (n47:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Longridge', name: 'Longridge', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n48:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sauternes', name: 'Sauternes'}),
# (n49:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTannerPinotNoir', name: 'LaneTannerPinotNoir', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoir'}),
# (n50:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Loire', name: 'Loire'}),
# (n51:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SouthAustraliaRegion', name: 'SouthAustraliaRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n52:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Anjou', name: 'Anjou'}),
# (n53:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaineMuscadet', name: 'SevreEtMaineMuscadet', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Muscadet'}),
# (n54:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Port', name: 'Port'}),
# (n55:ObjectProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasColor', name: 'hasColor', type: 'http://www.w3.org/2002/07/owl#ObjectProperty'}),
# (n56:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Beaujolais', name: 'Beaujolais'}),
# (n57:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CortonMontrachet', name: 'CortonMontrachet', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n58:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChiantiClassico', name: 'ChiantiClassico', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chianti'}),
# (n59:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AustralianRegion', name: 'AustralianRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n60:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineTaste', name: 'WineTaste'}),
# (n61:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Corbans', name: 'Corbans', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n62:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotesDOrRegion', name: 'CotesDOrRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n63:nil {uri: 'http://www.w3.org/1999/02/22-rdf-syntax-ns#nil', name: 'nil'}),
# (n64:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaCruzMountainVineyard', name: 'SantaCruzMountainVineyard', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n65:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Semillon', name: 'Semillon'}),
# (n66:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryWine', name: 'DryWine'}),
# (n67:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossVolrad', name: 'SchlossVolrad', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n68:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StGenevieveTexasWhite', name: 'StGenevieveTexasWhite', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteWine'}),
# (n69:Thing {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Strong', name: 'Strong', type: 'http://www.w3.org/2002/07/owl#Thing'}),
# (n70:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chianti', name: 'Chianti'}),
# (n71:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Taylor', name: 'Taylor', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n72:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LongridgeMerlot', name: 'LongridgeMerlot', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Merlot'}),
# (n73:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineBody', name: 'WineBody'}),
# (n74:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ToursRegion', name: 'ToursRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n75:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RieslingGrape', name: 'RieslingGrape', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'}),
# (n76:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FullBodiedWine', name: 'FullBodiedWine'}),
# (n77:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KalinCellarsSemillon', name: 'KalinCellarsSemillon', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Semillon'}),
# (n78:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Mountadam', name: 'Mountadam', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n79:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountEdenVineyard', name: 'MountEdenVineyard', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n80:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#USRegion', name: 'USRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n81:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Stonleigh', name: 'Stonleigh', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n82:SymmetricProperty {uri: 'http://www.w3.org/2002/07/owl#SymmetricProperty', name: 'SymmetricProperty'}),
# (n83:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MedocRegion', name: 'MedocRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n84:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeVougeotCotesDOr', name: 'ClosDeVougeotCotesDOr', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotesDOr'}),
# (n85:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauLafiteRothschildPauillac', name: 'ChateauLafiteRothschildPauillac', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Pauillac'}),
# (n86:madeFromFruit {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#madeFromFruit', name: 'madeFromFruit'}),
# (n87:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryRiesling', name: 'DryRiesling'}),
# (n88:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Marietta', name: 'Marietta', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n89:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium', name: 'Medium', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineBody'}),
# (n90:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountEdenVineyardEdnaValleyChardonnay', name: 'MountEdenVineyardEdnaValleyChardonnay', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chardonnay'}),
# (n91:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Merlot', name: 'Merlot'}),
# (n92:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotesDOr', name: 'CotesDOr'}),
# (n93:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedTableWine', name: 'RedTableWine'}),
# (n94:Thing {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Red', name: 'Red', type: 'http://www.w3.org/2002/07/owl#Thing'}),
# (n95:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Forman', name: 'Forman', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n96:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SeanThackrey', name: 'SeanThackrey', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n97:Thing {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate', name: 'Moderate', type: 'http://www.w3.org/2002/07/owl#Thing'}),
# (n98:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FormanChardonnay', name: 'FormanChardonnay', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chardonnay'}),
# (n99:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#NapaRegion', name: 'NapaRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n100:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryRedWine', name: 'DryRedWine'}),
# (n101:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape', name: 'WineGrape'}),
# (n102:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMorgonBeaujolais', name: 'ChateauMorgonBeaujolais', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Beaujolais'}),
# (n103:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BancroftChardonnay', name: 'BancroftChardonnay', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chardonnay'}),
# (n104:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SancerreRegion', name: 'SancerreRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n105:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StGenevieve', name: 'StGenevieve', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n106:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Meursault', name: 'Meursault'}),
# (n107:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Elyse', name: 'Elyse', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n108:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SaucelitoCanyonZinfandel1998', name: 'SaucelitoCanyonZinfandel1998', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Zinfandel'}),
# (n109:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region', name: 'Region'}),
# (n110:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PulignyMontrachetWhiteBurgundy', name: 'PulignyMontrachetWhiteBurgundy', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteBurgundy'}),
# (n111:DatatypeProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#yearValue', name: 'yearValue', type: 'http://www.w3.org/2002/07/owl#DatatypeProperty'}),
# (n112:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PulignyMontrachet', name: 'PulignyMontrachet', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n113:Thing {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Delicate', name: 'Delicate', type: 'http://www.w3.org/2002/07/owl#Thing'}),
# (n114:ObjectProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasMaker', name: 'hasMaker', type: 'http://www.w3.org/2002/07/owl#ObjectProperty'}),
# (n115:Thing {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MerlotGrape', name: 'MerlotGrape', type: 'http://www.w3.org/2002/07/owl#Thing'}),
# (n116:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StonleighSauvignonBlanc', name: 'StonleighSauvignonBlanc', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlanc'}),
# (n117:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMorgon', name: 'ChateauMorgon', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n118:Ontology {uri: 'http://www.w3.org/2002/07/owl#Ontology', name: 'Ontology'}),
# (n119:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon', name: 'CabernetSauvignon'}),
# (n120:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteTableWine', name: 'WhiteTableWine'}),
# (n121:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Meritage', name: 'Meritage'}),
# (n122:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MargauxRegion', name: 'MargauxRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n123:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GermanyRegion', name: 'GermanyRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n124:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AmericanWine', name: 'AmericanWine'}),
# (n125:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChardonnayGrape', name: 'ChardonnayGrape', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'}),
# (n126:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TableWine', name: 'TableWine'}),
# (n127:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauChevalBlancStEmilion', name: 'ChateauChevalBlancStEmilion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StEmilion'}),
# (n128:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteBordeaux', name: 'WhiteBordeaux'}),
# (n129:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaCruzMountainVineyardCabernetSauvignon', name: 'SantaCruzMountainVineyardCabernetSauvignon', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'}),
# (n130:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotBlanc', name: 'PinotBlanc'}),
# (n131:positiveInteger {uri: 'http://www.w3.org/2001/XMLSchema#positiveInteger', name: 'positiveInteger'}),
# (n132:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AnjouRegion', name: 'AnjouRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n133:AllDifferent {uri: 'http://www.w3.org/2002/07/owl#AllDifferent', name: 'AllDifferent'}),
# (n134:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteSyrahGrape', name: 'PetiteSyrahGrape', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'}),
# (n135:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhitehallLanePrimavera', name: 'WhitehallLanePrimavera', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DessertWine'}),
# (n136:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeLaPoussie', name: 'ClosDeLaPoussie', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n137:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BordeauxRegion', name: 'BordeauxRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n138:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Ventana', name: 'Ventana', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n139:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFrancGrape', name: 'CabernetFrancGrape', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'}),
# (n140:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ZinfandelGrape', name: 'ZinfandelGrape', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'}),
# (n141:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EarlyHarvest', name: 'EarlyHarvest'}),
# (n142:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FoxenCheninBlanc', name: 'FoxenCheninBlanc', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlanc'}),
# (n143:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MuscadetRegion', name: 'MuscadetRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n144:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlanc', name: 'SauvignonBlanc'}),
# (n145:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaCabernetSauvignon', name: 'MariettaCabernetSauvignon', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'}),
# (n146:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Zinfandel', name: 'Zinfandel'}),
# (n147:SymmetricProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#adjacentRegion', name: 'adjacentRegion', type: 'http://www.w3.org/2002/07/owl#SymmetricProperty'}),
# (n148:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossRothermel', name: 'SchlossRothermel', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n149:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#OffDry', name: 'OffDry', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineSugar'}),
# (n150:VintageYear {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#VintageYear', name: 'VintageYear'}),
# (n151:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Bancroft', name: 'Bancroft', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n152:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ItalianWine', name: 'ItalianWine'}),
# (n153:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaine', name: 'SevreEtMaine', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n154:Thing {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#White', name: 'White', type: 'http://www.w3.org/2002/07/owl#Thing'}),
# (n155:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PeterMccoy', name: 'PeterMccoy', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n156:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Riesling', name: 'Riesling'}),
# (n157:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#Grape', name: 'Grape'}),
# (n158:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medoc', name: 'Medoc'}),
# (n159:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedBurgundy', name: 'RedBurgundy'}),
# (n160:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoirGrape', name: 'PinotNoirGrape', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'}),
# (n161:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SaucelitoCanyonZinfandel', name: 'SaucelitoCanyonZinfandel', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Zinfandel'}),
# (n162:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Selaks', name: 'Selaks', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n163:ObjectProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasVintageYear', name: 'hasVintageYear', type: 'http://www.w3.org/2002/07/owl#ObjectProperty'}),
# (n164:FunctionalProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar', name: 'hasSugar', type: 'http://www.w3.org/2002/07/owl#FunctionalProperty'}),
# (n165:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhitehallLane', name: 'WhitehallLane', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n166:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhitehallLaneCabernetFranc', name: 'WhitehallLaneCabernetFranc', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFranc'}),
# (n167:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SaucelitoCanyon', name: 'SaucelitoCanyon', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n168:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineDescriptor', name: 'WineDescriptor'}),
# (n169:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry', name: 'Dry', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineSugar'}),
# (n170:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FormanCabernetSauvignon', name: 'FormanCabernetSauvignon', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'}),
# (n171:ObjectProperty {uri: 'http://www.w3.org/2002/07/owl#ObjectProperty', name: 'ObjectProperty'}),
# (n172:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Cotturi', name: 'Cotturi', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n173:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDYchem', name: 'ChateauDYchem', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n174:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountEdenVineyardEstatePinotNoir', name: 'MountEdenVineyardEstatePinotNoir', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoir'}),
# (n175:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CongressSpringsSemillon', name: 'CongressSpringsSemillon', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Semillon'}),
# (n176:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedBordeaux', name: 'RedBordeaux'}),
# (n177:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Bordeaux', name: 'Bordeaux'}),
# (n178:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeVougeot', name: 'ClosDeVougeot', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n179:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteBurgundy', name: 'WhiteBurgundy'}),
# (n180:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KathrynKennedyLateral', name: 'KathrynKennedyLateral', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Meritage'}),
# (n181:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TexasRegion', name: 'TexasRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n182:Thing {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlancGrape', name: 'CheninBlancGrape', type: 'http://www.w3.org/2002/07/owl#Thing'}),
# (n183:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaPetiteSyrah', name: 'MariettaPetiteSyrah', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteSyrah'}),
# (n184:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#PotableLiquid', name: 'PotableLiquid'}),
# (n185:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RoseWine', name: 'RoseWine'}),
# (n186:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFranc', name: 'CabernetFranc'}),
# (n187:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SeanThackreySiriusPetiteSyrah', name: 'SeanThackreySiriusPetiteSyrah', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteSyrah'}),
# (n188:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ItalianRegion', name: 'ItalianRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n189:ObjectProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#locatedIn', name: 'locatedIn', type: 'http://www.w3.org/2002/07/owl#ObjectProperty'}),
# (n190:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Tours', name: 'Tours'}),
# (n191:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChiantiRegion', name: 'ChiantiRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n192:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlanc', name: 'CheninBlanc'}),
# (n193:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sweet', name: 'Sweet', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineSugar'}),
# (n194:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Beringer', name: 'Beringer', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n195:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Full', name: 'Full', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineBody'}),
# (n196:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LoireRegion', name: 'LoireRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n197:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteSyrah', name: 'PetiteSyrah'}),
# (n198:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Foxen', name: 'Foxen', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n199:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansDryWhiteRiesling', name: 'CorbansDryWhiteRiesling', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Riesling'}),
# (n200:Restriction {uri: 'http://www.w3.org/2002/07/owl#Restriction', name: 'Restriction'}),
# (n201:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDeMeursault', name: 'ChateauDeMeursault', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n202:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StEmilionRegion', name: 'StEmilionRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n203:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery', name: 'Winery'}),
# (n204:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoir', name: 'PinotNoir'}),
# (n205:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamPinotNoir', name: 'MountadamPinotNoir', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoir'}),
# (n206:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sancerre', name: 'Sancerre'}),
# (n207:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Burgundy', name: 'Burgundy'}),
# (n208:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Handley', name: 'Handley', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n209:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossVolradTrochenbierenausleseRiesling', name: 'SchlossVolradTrochenbierenausleseRiesling', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SweetRiesling'}),
# (n210:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDYchemSauterne', name: 'ChateauDYchemSauterne', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sauternes'}),
# (n211:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteLoire', name: 'WhiteLoire'}),
# (n212:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SonomaRegion', name: 'SonomaRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n213:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaWine', name: 'CaliforniaWine'}),
# (n214:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PageMillWinery', name: 'PageMillWinery', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n215:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GermanWine', name: 'GermanWine'}),
# (n216:ObjectProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasFlavor', name: 'hasFlavor', type: 'http://www.w3.org/2002/07/owl#ObjectProperty'}),
# (n217:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine', name: 'Wine'}),
# (n218:Vintage {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Vintage', name: 'Vintage'}),
# (n219:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DAnjou', name: 'DAnjou', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n220:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TaylorPort', name: 'TaylorPort', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Port'}),
# (n221:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CortonMontrachetWhiteBurgundy', name: 'CortonMontrachetWhiteBurgundy', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteBurgundy'}),
# (n222:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaCruzMountainsRegion', name: 'SantaCruzMountainsRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n223:Thing {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignonGrape', name: 'CabernetSauvignonGrape', type: 'http://www.w3.org/2002/07/owl#Thing'}),
# (n224:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SelaksSauvignonBlanc', name: 'SelaksSauvignonBlanc', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlanc'}),
# (n225:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SemillonOrSauvignonBlanc', name: 'SemillonOrSauvignonBlanc'}),
# (n226:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryWhiteWine', name: 'DryWhiteWine'}),
# (n227:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#IceWine', name: 'IceWine'}),
# (n228:food {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/food', name: 'food'}),
# (n229:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CentralCoastRegion', name: 'CentralCoastRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n230:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PageMillWineryCabernetSauvignon', name: 'PageMillWineryCabernetSauvignon', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'}),
# (n231:FunctionalProperty {uri: 'http://www.w3.org/2002/07/owl#FunctionalProperty', name: 'FunctionalProperty'}),
# (n232:FunctionalProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasBody', name: 'hasBody', type: 'http://www.w3.org/2002/07/owl#FunctionalProperty'}),
# (n233:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamRiesling', name: 'MountadamRiesling', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryRiesling'}),
# (n234:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CentralTexasRegion', name: 'CentralTexasRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n235:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TexasWine', name: 'TexasWine'}),
# (n236:ObjectProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#producesWine', name: 'producesWine', type: 'http://www.w3.org/2002/07/owl#ObjectProperty'}),
# (n237:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CongressSprings', name: 'CongressSprings', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n238:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PortugalRegion', name: 'PortugalRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n239:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StEmilion', name: 'StEmilion'}),
# (n240:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EdnaValleyRegion', name: 'EdnaValleyRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n241:TransitiveProperty {uri: 'http://www.w3.org/2002/07/owl#TransitiveProperty', name: 'TransitiveProperty'}),
# (n242:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BourgogneRegion', name: 'BourgogneRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n243:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauLafiteRothschild', name: 'ChateauLafiteRothschild', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n244:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMargauxWinery', name: 'ChateauMargauxWinery', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n245:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansSauvignonBlanc', name: 'CorbansSauvignonBlanc', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlanc'}),
# (n246:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SweetRiesling', name: 'SweetRiesling'}),
# (n247:Ontology {uri: 'http://www.w3.org/TR/2003/CR-owl-guide-20030818/wine', name: 'wine', type: 'http://www.w3.org/2002/07/owl#Ontology'}),
# (n248:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansPrivateBinSauvignonBlanc', name: 'CorbansPrivateBinSauvignonBlanc', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlanc'}),
# (n249:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FrenchRegion', name: 'FrenchRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n250:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotturiZinfandel', name: 'CotturiZinfandel', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Zinfandel'}),
# (n251:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineFlavor', name: 'WineFlavor'}),
# (n252:Class {uri: 'http://www.w3.org/2002/07/owl#Class', name: 'Class'}),
# (n253:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTanner', name: 'LaneTanner', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n254:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AlsaceRegion', name: 'AlsaceRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n255:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AlsatianWine', name: 'AlsatianWine'}),
# (n256:Thing {uri: 'http://www.w3.org/2002/07/owl#Thing', name: 'Thing'}),
# (n257:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MendocinoRegion', name: 'MendocinoRegion', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'}),
# (n258:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#VentanaCheninBlanc', name: 'VentanaCheninBlanc', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlanc'}),
# (n259:ObjectProperty {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasWineDescriptor', name: 'hasWineDescriptor', type: 'http://www.w3.org/2002/07/owl#ObjectProperty'}),
# (n260:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RoseDAnjou', name: 'RoseDAnjou', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Anjou'}),
# (n261:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDeMeursaultMeursault', name: 'ChateauDeMeursaultMeursault', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Meursault'}),
# (n262:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DessertWine', name: 'DessertWine'}),
# (n263:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMargaux', name: 'ChateauMargaux', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Margaux'}),
# (n264:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteWine', name: 'WhiteWine'}),
# (n265:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ElyseZinfandel', name: 'ElyseZinfandel', type: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Zinfandel'}),
# (n6)-[:hasSugar]->(n169),
# (n186)-[:type]->(n252),
# (n205)-[:type]->(n204),
# (n1)-[:hasSugar]->(n169),
# (n235)-[:type]->(n252),
# (n106)-[:type]->(n252),
# (n189)-[:type]->(n171),
# (n119)-[:type]->(n252),
# (n126)-[:type]->(n252),
# (n192)-[:type]->(n252),
# (n199)-[:type]->(n156),
# (n163)-[:domain]->(n218),
# (n53)-[:hasMaker]->(n153),
# (n180)-[:hasFlavor]->(n113),
# (n102)-[:hasMaker]->(n117),
# (n164)-[:type]->(n231),
# (n245)-[:hasMaker]->(n61),
# (n183)-[:hasFlavor]->(n97),
# (n222)-[:locatedIn]->(n8),
# (n178)-[:type]->(n203),
# (n40)-[:type]->(n252),
# (n26)-[:locatedIn]->(n8),
# (n183)-[:hasSugar]->(n169),
# (n49)-[:type]->(n204),
# (n15)-[:type]->(n252),
# (n100)-[:type]->(n252),
# (n49)-[:locatedIn]->(n26),
# (n258)-[:type]->(n192),
# (n41)-[:type]->(n252),
# (n153)-[:type]->(n203),
# (n176)-[:type]->(n252),
# (n10)-[:type]->(n109),
# (n101)-[:subClassOf]->(n157),
# (n7)-[:imports]->(n228),
# (n250)-[:locatedIn]->(n212),
# (n116)-[:hasBody]->(n89),
# (n202)-[:locatedIn]->(n137),
# (n122)-[:type]->(n109),
# (n224)-[:hasFlavor]->(n97),
# (n217)-[:type]->(n252),
# (n216)-[:type]->(n171),
# (n251)-[:type]->(n252),
# (n224)-[:hasSugar]->(n169),
# (n229)-[:type]->(n109),
# (n140)-[:type]->(n101),
# (n54)-[:subClassOf]->(n38),
# (n21)-[:type]->(n252),
# (n236)-[:inverseOf]->(n114),
# (n4)-[:type]->(n246),
# (n158)-[:type]->(n252),
# (n23)-[:type]->(n101),
# (n208)-[:type]->(n203),
# (n264)-[:type]->(n252),
# (n225)-[:type]->(n252),
# (n98)-[:locatedIn]->(n99),
# (n129)-[:locatedIn]->(n222),
# (n196)-[:locatedIn]->(n249),
# (n242)-[:locatedIn]->(n249),
# (n183)-[:type]->(n197),
# (n2)-[:type]->(n256),
# (n6)-[:hasMaker]->(n88),
# (n68)-[:hasMaker]->(n105),
# (n110)-[:hasMaker]->(n112),
# (n161)-[:hasBody]->(n89),
# (n62)-[:type]->(n109),
# (n210)-[:hasMaker]->(n173),
# (n196)-[:type]->(n109),
# (n88)-[:type]->(n203),
# (n112)-[:type]->(n203),
# (n107)-[:type]->(n203),
# (n217)-[:subClassOf]->(n184),
# (n6)-[:type]->(n146),
# (n209)-[:type]->(n246),
# (n224)-[:hasMaker]->(n162),
# (n129)-[:hasFlavor]->(n69),
# (n135)-[:hasFlavor]->(n113),
# (n216)-[:type]->(n231),
# (n79)-[:type]->(n203),
# (n183)-[:hasMaker]->(n88),
# (n199)-[:locatedIn]->(n43),
# (n43)-[:type]->(n109),
# (n98)-[:hasFlavor]->(n97),
# (n199)-[:hasSugar]->(n149),
# (n72)-[:hasMaker]->(n47),
# (n129)-[:hasSugar]->(n169),
# (n89)-[:type]->(n73),
# (n60)-[:subClassOf]->(n168),
# (n212)-[:type]->(n109),
# (n248)-[:locatedIn]->(n43),
# (n30)-[:locatedIn]->(n83),
# (n129)-[:type]->(n119),
# (n35)-[:hasBody]->(n89),
# (n20)-[:type]->(n252),
# (n51)-[:type]->(n109),
# (n207)-[:type]->(n252),
# (n103)-[:type]->(n32),
# (n103)-[:hasMaker]->(n151),
# (n260)-[:type]->(n52),
# (n84)-[:type]->(n92),
# (n73)-[:type]->(n252),
# (n84)-[:hasMaker]->(n178),
# (n77)-[:type]->(n65),
# (n14)-[:subPropertyOf]->(n86),
# (n130)-[:type]->(n252),
# (n205)-[:hasBody]->(n89),
# (n202)-[:type]->(n109),
# (n14)-[:range]->(n101),
# (n165)-[:type]->(n203),
# (n170)-[:type]->(n119),
# (n233)-[:hasBody]->(n89),
# (n2)-[:type]->(n101),
# (n265)-[:hasSugar]->(n169),
# (n163)-[:type]->(n171),
# (n175)-[:type]->(n65),
# (n246)-[:subClassOf]->(n262),
# (n38)-[:type]->(n252),
# (n122)-[:locatedIn]->(n83),
# (n145)-[:type]->(n119),
# (n29)-[:locatedIn]->(n212),
# (n233)-[:locatedIn]->(n51),
# (n210)-[:hasFlavor]->(n69),
# (n163)-[:range]->(n150),
# (n81)-[:type]->(n203),
# (n147)-[:type]->(n82),
# (n174)-[:hasBody]->(n195),
# (n10)-[:locatedIn]->(n242),
# (n237)-[:type]->(n203),
# (n12)-[:type]->(n32),
# (n96)-[:type]->(n203),
# (n205)-[:locatedIn]->(n51),
# (n91)-[:type]->(n252),
# (n59)-[:type]->(n109),
# (n261)-[:hasMaker]->(n201),
# (n258)-[:hasMaker]->(n138),
# (n219)-[:type]->(n203),
# (n201)-[:type]->(n203),
# (n150)-[:type]->(n252),
# (n58)-[:type]->(n70),
# (n205)-[:hasSugar]->(n169),
# (n204)-[:type]->(n252),
# (n187)-[:type]->(n197),
# (n45)-[:type]->(n150),
# (n90)-[:type]->(n32),
# (n47)-[:type]->(n203),
# (n163)-[:type]->(n231),
# (n154)-[:type]->(n256),
# (n16)-[:type]->(n256),
# (n189)-[:type]->(n241),
# (n12)-[:locatedIn]->(n51),
# (n248)-[:hasBody]->(n195),
# (n258)-[:locatedIn]->(n229),
# (n35)-[:type]->(n227),
# (n166)-[:type]->(n186),
# (n72)-[:hasBody]->(n34),
# (n128)-[:type]->(n252),
# (n258)-[:hasBody]->(n89),
# (n248)-[:hasFlavor]->(n69),
# (n98)-[:type]->(n32),
# (n193)-[:differentFrom]->(n169),
# (n181)-[:locatedIn]->(n80),
# (n60)-[:type]->(n252),
# (n137)-[:locatedIn]->(n249),
# (n255)-[:type]->(n252),
# (n127)-[:hasMaker]->(n13),
# (n169)-[:type]->(n31),
# (n248)-[:hasSugar]->(n169),
# (n145)-[:hasMaker]->(n88),
# (n187)-[:locatedIn]->(n99),
# (n159)-[:type]->(n252),
# (n97)-[:type]->(n256),
# (n230)-[:hasMaker]->(n214),
# (n265)-[:type]->(n146),
# (n99)-[:type]->(n109),
# (n146)-[:type]->(n252),
# (n85)-[:type]->(n19),
# (n129)-[:hasBody]->(n195),
# (n245)-[:hasBody]->(n89),
# (n221)-[:hasFlavor]->(n69),
# (n54)-[:type]->(n252),
# (n33)-[:type]->(n109),
# (n49)-[:hasMaker]->(n253),
# (n253)-[:type]->(n203),
# (n5)-[:inverseOf]->(n14),
# (n149)-[:type]->(n31),
# (n28)-[:type]->(n101),
# (n104)-[:locatedIn]->(n196),
# (n142)-[:locatedIn]->(n26),
# (n68)-[:locatedIn]->(n234),
# (n239)-[:type]->(n252),
# (n1)-[:locatedIn]->(n212),
# (n227)-[:type]->(n252),
# (n23)-[:type]->(n256),
# (n250)-[:hasMaker]->(n172),
# (n116)-[:hasMaker]->(n81),
# (n139)-[:type]->(n101),
# (n55)-[:domain]->(n217),
# (n191)-[:type]->(n109),
# (n161)-[:hasMaker]->(n167),
# (n259)-[:domain]->(n217),
# (n250)-[:hasFlavor]->(n69),
# (n209)-[:hasFlavor]->(n97),
# (n117)-[:type]->(n203),
# (n234)-[:locatedIn]->(n181),
# (n143)-[:type]->(n109),
# (n30)-[:type]->(n109),
# (n16)-[:type]->(n101),
# (n222)-[:type]->(n109),
# (n245)-[:locatedIn]->(n43),
# (n26)-[:type]->(n109),
# (n265)-[:hasBody]->(n195),
# (n236)-[:type]->(n171),
# (n108)-[:locatedIn]->(n44),
# (n7)-[:priorVersion]->(n247),
# (n205)-[:hasFlavor]->(n97),
# (n257)-[:adjacentRegion]->(n212),
# (n166)-[:hasMaker]->(n165),
# (n103)-[:hasSugar]->(n169),
# (n143)-[:locatedIn]->(n196),
# (n216)-[:range]->(n251),
# (n135)-[:hasBody]->(n34),
# (n170)-[:hasSugar]->(n169),
# (n223)-[:type]->(n256),
# (n262)-[:subClassOf]->(n217),
# (n161)-[:type]->(n146),
# (n180)-[:type]->(n121),
# (n4)-[:hasSugar]->(n193),
# (n108)-[:hasMaker]->(n167),
# (n170)-[:hasMaker]->(n95),
# (n110)-[:hasSugar]->(n169),
# (n92)-[:type]->(n252),
# (n83)-[:locatedIn]->(n137),
# (n142)-[:type]->(n192),
# (n49)-[:hasSugar]->(n169),
# (n232)-[:range]->(n73),
# (n31)-[:subClassOf]->(n60),
# (n148)-[:type]->(n203),
# (n12)-[:hasBody]->(n195),
# (n12)-[:hasFlavor]->(n69),
# (n57)-[:type]->(n203),
# (n51)-[:locatedIn]->(n59),
# (n209)-[:hasSugar]->(n193),
# (n18)-[:hasBody]->(n89),
# (n147)-[:domain]->(n109),
# (n233)-[:type]->(n87),
# (n18)-[:hasMaker]->(n155),
# (n198)-[:type]->(n203),
# (n8)-[:type]->(n109),
# (n172)-[:type]->(n203),
# (n64)-[:type]->(n203),
# (n12)-[:hasSugar]->(n169),
# (n259)-[:range]->(n168),
# (n61)-[:type]->(n203),
# (n93)-[:type]->(n252),
# (n221)-[:hasMaker]->(n57),
# (n78)-[:type]->(n203),
# (n124)-[:type]->(n252),
# (n34)-[:type]->(n73),
# (n13)-[:type]->(n203),
# (n250)-[:type]->(n146),
# (n209)-[:locatedIn]->(n123),
# (n72)-[:locatedIn]->(n43),
# (n55)-[:subPropertyOf]->(n259),
# (n125)-[:type]->(n101),
# (n223)-[:type]->(n101),
# (n70)-[:subClassOf]->(n152),
# (n62)-[:locatedIn]->(n242),
# (n132)-[:type]->(n109),
# (n58)-[:hasBody]->(n89),
# (n166)-[:hasBody]->(n89),
# (n74)-[:locatedIn]->(n196),
# (n6)-[:hasBody]->(n89),
# (n34)-[:type]->(n256),
# (n212)-[:locatedIn]->(n8),
# (n116)-[:type]->(n144),
# (n114)-[:type]->(n171),
# (n18)-[:hasSugar]->(n169),
# (n7)-[:type]->(n118),
# (n73)-[:subClassOf]->(n60),
# (n111)-[:type]->(n24),
# (n246)-[:type]->(n252),
# (n147)-[:range]->(n109),
# (n19)-[:type]->(n252),
# (n137)-[:type]->(n109),
# (n152)-[:type]->(n252),
# (n193)-[:type]->(n31),
# (n1)-[:type]->(n91),
# (n68)-[:hasFlavor]->(n97),
# (n182)-[:type]->(n256),
# (n183)-[:hasBody]->(n89),
# (n69)-[:type]->(n256),
# (n121)-[:type]->(n252),
# (n29)-[:hasFlavor]->(n97),
# (n167)-[:type]->(n203),
# (n230)-[:type]->(n119),
# (n258)-[:hasSugar]->(n149),
# (n89)-[:type]->(n256),
# (n145)-[:locatedIn]->(n212),
# (n108)-[:hasFlavor]->(n97),
# (n240)-[:locatedIn]->(n8),
# (n108)-[:hasSugar]->(n169),
# (n105)-[:type]->(n203),
# (n70)-[:type]->(n252),
# (n110)-[:type]->(n179),
# (n94)-[:type]->(n256),
# (n175)-[:hasFlavor]->(n97),
# (n220)-[:type]->(n54),
# (n135)-[:hasSugar]->(n193),
# (n114)-[:type]->(n231),
# (n190)-[:type]->(n252),
# (n31)-[:type]->(n252),
# (n40)-[:subClassOf]->(n168),
# (n3)-[:type]->(n203),
# (n48)-[:subClassOf]->(n41),
# (n94)-[:type]->(n40),
# (n210)-[:type]->(n48),
# (n72)-[:hasFlavor]->(n97),
# (n37)-[:type]->(n109),
# (n262)-[:type]->(n252),
# (n141)-[:subClassOf]->(n217),
# (n22)-[:type]->(n101),
# (n48)-[:type]->(n252),
# (n18)-[:hasFlavor]->(n97),
# (n166)-[:locatedIn]->(n99),
# (n35)-[:hasColor]->(n154),
# (n123)-[:type]->(n109),
# (n69)-[:type]->(n251),
# (n139)-[:type]->(n256),
# (n58)-[:hasMaker]->(n0),
# (n182)-[:type]->(n101),
# (n108)-[:hasVintageYear]->(n45),
# (n120)-[:type]->(n252),
# (n4)-[:locatedIn]->(n123),
# (n187)-[:hasMaker]->(n96),
# (n29)-[:type]->(n93),
# (n199)-[:hasFlavor]->(n97),
# (n230)-[:locatedIn]->(n99),
# (n108)-[:type]->(n146),
# (n71)-[:type]->(n203),
# (n101)-[:type]->(n252),
# (n233)-[:hasMaker]->(n78),
# (n18)-[:locatedIn]->(n212),
# (n55)-[:range]->(n40),
# (n90)-[:hasFlavor]->(n97),
# (n134)-[:type]->(n101),
# (n95)-[:type]->(n203),
# (n211)-[:type]->(n252),
# (n66)-[:type]->(n252),
# (n166)-[:hasFlavor]->(n97),
# (n1)-[:hasFlavor]->(n97),
# (n238)-[:type]->(n109),
# (n48)-[:subClassOf]->(n177),
# (n142)-[:hasMaker]->(n198),
# (n149)-[:differentFrom]->(n169),
# (n116)-[:locatedIn]->(n43),
# (n210)-[:madeFromGrape]->(n2),
# (n1)-[:hasMaker]->(n3),
# (n33)-[:locatedIn]->(n249),
# (n242)-[:type]->(n109),
# (n213)-[:type]->(n252),
# (n98)-[:hasBody]->(n195),
# (n170)-[:hasBody]->(n89),
# (n104)-[:type]->(n109),
# (n80)-[:type]->(n109),
# (n214)-[:type]->(n203),
# (n142)-[:hasBody]->(n195),
# (n53)-[:type]->(n25),
# (n151)-[:type]->(n203),
# (n230)-[:hasFlavor]->(n97),
# (n174)-[:hasMaker]->(n79),
# (n161)-[:locatedIn]->(n44),
# (n25)-[:type]->(n252),
# (n145)-[:hasBody]->(n89),
# (n221)-[:type]->(n179),
# (n12)-[:hasMaker]->(n78),
# (n98)-[:hasSugar]->(n169),
# (n83)-[:type]->(n109),
# (n14)-[:type]->(n171),
# (n142)-[:hasFlavor]->(n97),
# (n132)-[:locatedIn]->(n196),
# (n218)-[:type]->(n252),
# (n254)-[:locatedIn]->(n249),
# (n56)-[:type]->(n252),
# (n142)-[:hasSugar]->(n169),
# (n260)-[:hasMaker]->(n219),
# (n188)-[:type]->(n109),
# (n98)-[:hasMaker]->(n95),
# (n174)-[:hasFlavor]->(n69),
# (n110)-[:hasBody]->(n89),
# (n187)-[:hasBody]->(n195),
# (n230)-[:hasSugar]->(n169),
# (n162)-[:type]->(n203),
# (n147)-[:type]->(n171),
# (n220)-[:hasMaker]->(n71),
# (n164)-[:subPropertyOf]->(n259),
# (n6)-[:locatedIn]->(n212),
# (n183)-[:locatedIn]->(n212),
# (n187)-[:hasFlavor]->(n69),
# (n174)-[:hasSugar]->(n169),
# (n90)-[:locatedIn]->(n240),
# (n232)-[:type]->(n231),
# (n55)-[:type]->(n171),
# (n164)-[:range]->(n31),
# (n233)-[:hasSugar]->(n169),
# (n97)-[:type]->(n251),
# (n187)-[:hasSugar]->(n169),
# (n259)-[:type]->(n171),
# (n5)-[:type]->(n171),
# (n44)-[:type]->(n109),
# (n49)-[:hasBody]->(n34),
# (n145)-[:hasSugar]->(n169),
# (n245)-[:type]->(n144),
# (n35)-[:locatedIn]->(n43),
# (n17)-[:type]->(n256),
# (n155)-[:type]->(n203),
# (n257)-[:type]->(n109),
# (n160)-[:type]->(n101),
# (n4)-[:hasMaker]->(n148),
# (n215)-[:type]->(n252),
# (n65)-[:type]->(n252),
# (n180)-[:hasBody]->(n89),
# (n18)-[:type]->(n32),
# (n195)-[:type]->(n73),
# (n115)-[:type]->(n256),
# (n170)-[:locatedIn]->(n99),
# (n32)-[:type]->(n252),
# (n39)-[:type]->(n252),
# (n181)-[:type]->(n109),
# (n141)-[:type]->(n252),
# (n169)-[:type]->(n256),
# (n17)-[:type]->(n40),
# (n102)-[:type]->(n56),
# (n174)-[:locatedIn]->(n240),
# (n247)-[:type]->(n118),
# (n229)-[:locatedIn]->(n8),
# (n111)-[:range]->(n131),
# (n11)-[:type]->(n252),
# (n72)-[:type]->(n91),
# (n27)-[:type]->(n203),
# (n173)-[:type]->(n203),
# (n261)-[:type]->(n106),
# (n195)-[:type]->(n256),
# (n55)-[:type]->(n231),
# (n116)-[:hasSugar]->(n169),
# (n179)-[:type]->(n252),
# (n170)-[:hasFlavor]->(n69),
# (n149)-[:type]->(n256),
# (n194)-[:type]->(n203),
# (n42)-[:type]->(n206),
# (n265)-[:locatedIn]->(n99),
# (n85)-[:hasMaker]->(n243),
# (n216)-[:subPropertyOf]->(n259),
# (n113)-[:type]->(n256),
# (n199)-[:hasMaker]->(n61),
# (n189)-[:range]->(n109),
# (n108)-[:hasBody]->(n89),
# (n149)-[:differentFrom]->(n193),
# (n210)-[:madeFromGrape]->(n23),
# (n233)-[:hasFlavor]->(n113),
# (n129)-[:hasMaker]->(n64),
# (n175)-[:hasBody]->(n89),
# (n29)-[:hasBody]->(n89),
# (n245)-[:hasFlavor]->(n69),
# (n189)-[:domain]->(n256),
# (n185)-[:type]->(n252),
# (n145)-[:hasFlavor]->(n97),
# (n248)-[:hasMaker]->(n61),
# (n22)-[:type]->(n256),
# (n161)-[:hasFlavor]->(n97),
# (n4)-[:hasFlavor]->(n69),
# (n263)-[:type]->(n21),
# (n161)-[:hasSugar]->(n169),
# (n46)-[:type]->(n256),
# (n180)-[:hasMaker]->(n36),
# (n14)-[:domain]->(n217),
# (n103)-[:hasBody]->(n89),
# (n115)-[:type]->(n101),
# (n245)-[:hasSugar]->(n169),
# (n67)-[:type]->(n203),
# (n4)-[:hasBody]->(n195),
# (n249)-[:type]->(n109),
# (n35)-[:hasFlavor]->(n97),
# (n110)-[:hasFlavor]->(n97),
# (n265)-[:hasFlavor]->(n97),
# (n68)-[:hasSugar]->(n169),
# (n240)-[:type]->(n109),
# (n226)-[:type]->(n252),
# (n52)-[:type]->(n252),
# (n77)-[:hasBody]->(n195),
# (n49)-[:hasFlavor]->(n113),
# (n0)-[:type]->(n203),
# (n203)-[:type]->(n252),
# (n36)-[:type]->(n203),
# (n221)-[:hasBody]->(n195),
# (n77)-[:hasFlavor]->(n69),
# (n191)-[:locatedIn]->(n188),
# (n250)-[:hasBody]->(n195),
# (n206)-[:type]->(n252),
# (n116)-[:hasFlavor]->(n113),
# (n41)-[:subClassOf]->(n217),
# (n263)-[:hasMaker]->(n244),
# (n175)-[:hasSugar]->(n169),
# (n29)-[:hasSugar]->(n169),
# (n209)-[:hasBody]->(n195),
# (n113)-[:type]->(n251),
# (n177)-[:type]->(n252),
# (n77)-[:hasSugar]->(n169),
# (n175)-[:hasMaker]->(n237),
# (n243)-[:type]->(n203),
# (n127)-[:type]->(n239),
# (n254)-[:type]->(n109),
# (n221)-[:hasSugar]->(n169),
# (n199)-[:hasBody]->(n89),
# (n250)-[:hasSugar]->(n169),
# (n180)-[:hasSugar]->(n169),
# (n109)-[:type]->(n252),
# (n37)-[:locatedIn]->(n137),
# (n224)-[:hasBody]->(n89),
# (n9)-[:type]->(n101),
# (n244)-[:type]->(n203),
# (n232)-[:subPropertyOf]->(n259),
# (n68)-[:type]->(n264),
# (n251)-[:subClassOf]->(n60),
# (n111)-[:domain]->(n150),
# (n46)-[:type]->(n101),
# (n90)-[:hasMaker]->(n79),
# (n74)-[:type]->(n109),
# (n35)-[:hasMaker]->(n162),
# (n44)-[:locatedIn]->(n8),
# (n90)-[:hasBody]->(n89),
# (n138)-[:type]->(n203),
# (n42)-[:hasMaker]->(n136),
# (n72)-[:hasSugar]->(n169),
# (n197)-[:type]->(n252),
# (n1)-[:hasBody]->(n89),
# (n103)-[:locatedIn]->(n99),
# (n261)-[:hasFlavor]->(n97),
# (n154)-[:type]->(n40),
# (n257)-[:locatedIn]->(n8),
# (n209)-[:hasMaker]->(n67),
# (n135)-[:locatedIn]->(n99),
# (n224)-[:locatedIn]->(n43),
# (n205)-[:hasMaker]->(n78),
# (n135)-[:type]->(n262),
# (n8)-[:locatedIn]->(n80),
# (n76)-[:type]->(n252),
# (n75)-[:type]->(n101),
# (n144)-[:type]->(n252),
# (n164)-[:type]->(n171),
# (n193)-[:type]->(n256),
# (n87)-[:type]->(n252),
# (n90)-[:hasSugar]->(n169),
# (n265)-[:hasMaker]->(n107),
# (n230)-[:hasBody]->(n89),
# (n174)-[:type]->(n204),
# (n234)-[:type]->(n109),
# (n41)-[:disjointWith]->(n141),
# (n99)-[:locatedIn]->(n8),
# (n29)-[:hasMaker]->(n88),
# (n156)-[:type]->(n252),
# (n168)-[:type]->(n252),
# (n50)-[:type]->(n252),
# (n77)-[:hasMaker]->(n27),
# (n224)-[:type]->(n144),
# (n232)-[:type]->(n171),
# (n136)-[:type]->(n203),
# (n258)-[:hasFlavor]->(n97),
# (n103)-[:hasFlavor]->(n97),
# (n248)-[:type]->(n144),
# (n6)-[:hasFlavor]->(n97),
# (n166)-[:hasSugar]->(n169)
# CPU times: user 346 ms, sys: 2.8 ms, total: 349 ms
# Wall time: 347 ms

# %% [markdown]
# ## Using networkx

# %%
def rdf_to_cypher_nx(rdf_file, include_blank_nodes=False):
    from rdflib import Graph #, RDF, RDFS, OWL, Literal
    from rdflib.extras.external_graph_libs import rdflib_to_networkx_multidigraph
    
    g = Graph()
    result = g.parse(rdf_file)

    G = rdflib_to_networkx_multidigraph(result)

    return G

# %%
G = rdf_to_cypher_nx(path_rdf)
print(G)
# Out:
# MultiDiGraph with 733 nodes and 1839 edges

# %%
for nodes in G.nodes(data=True):
    print(nodes)
# Out:
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaZinfandel'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamPinotNoir'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoir'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFranc'), {})
# (rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.BNode('Na69323a4dbbb48bb9ca8268064fa894e'), {})
# (rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N7820cafd23d146c196faf920bbd885fb'), {})
# (rdflib.term.BNode('N422ad33260b245189cba1ce599e2dbfe'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrellMerlot'), {})
# (rdflib.term.BNode('Nc4dda7f5f7054bffa3e4cff73d2dfa74'), {})
# (rdflib.term.BNode('N0c07547f2e614dffae10b17422308216'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'), {})
# (rdflib.term.BNode('N39537a10149b49cb95687685024347d2'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TexasWine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Meursault'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#locatedIn'), {})
# (rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'), {})
# (rdflib.term.BNode('N291a1b9749a341d68d31108112bf3fae'), {})
# (rdflib.term.BNode('N981d5d6a59bd4968a9666a08050c8b29'), {})
# (rdflib.term.BNode('Na922c8a024744eddada32aa79d2624e1'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), {})
# (rdflib.term.BNode('Nc157fe7a4b844ab892982b6ab4a21186'), {})
# (rdflib.term.BNode('Nc0168a8cc3ef4137b60e209222b411ad'), {})
# (rdflib.term.BNode('N0db4f652c8474e248ae67604d0cb48c0'), {})
# (rdflib.term.BNode('Nd4cf0f26c9ea4e9c9d52531a10d29dfb'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Delicate'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'), {})
# (rdflib.term.BNode('Ne9b41dd984c34e2b843738d40aee7b06'), {})
# (rdflib.term.BNode('N815a5c1dcc70431682b8fa754d462a1c'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFrancGrape'), {})
# (rdflib.term.BNode('N5c81ef50cb96451fb1aad40fcc89d43f'), {})
# (rdflib.term.BNode('N3ada577683d2447398e63db36880f8c5'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TableWine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlanc'), {})
# (rdflib.term.BNode('N6125f2fadab346ffad1bcc6bc54ee125'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#White'), {})
# (rdflib.term.BNode('Nb58642dfa2f94f51a48d649f5cea3471'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), {})
# (rdflib.term.BNode('N9807701a3d9f4c068fc57005305d6527'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LateHarvest'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansDryWhiteRiesling'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Riesling'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasVintageYear'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Vintage'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaineMuscadet'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), {})
# (rdflib.term.BNode('N5446d0b8e9eb4bd28ff40be1ff93e97b'), {})
# (rdflib.term.BNode('N84d3b6b009324056a1d77d4f60e4affc'), {})
# (rdflib.term.BNode('N4e170e1709da4018a251b2be47b7dda7'), {})
# (rdflib.term.BNode('N1d26bc5360854a8396ef782094a9d401'), {})
# (rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KathrynKennedyLateral'), {})
# (rdflib.term.BNode('N30d493953df74a31b0d5d3f10777c74b'), {})
# (rdflib.term.BNode('N2058bc45bcbc45d281de9613b0453699'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SeanThackrey'), {})
# (rdflib.term.BNode('N9501c80ba31b47a3819a0f2557510cf0'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMorgonBeaujolais'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMorgon'), {})
# (rdflib.term.BNode('N4bd42f07319f494ca73188690c9719da'), {})
# (rdflib.term.BNode('Nc1e173865e3d42258d147b56b98d991c'), {})
# (rdflib.term.BNode('Nab9bc303439d4858ad529cd268289504'), {})
# (rdflib.term.BNode('Ne41735398fc348a08da1dbb53ac17116'), {})
# (rdflib.term.URIRef('http://www.w3.org/2002/07/owl#FunctionalProperty'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansSauvignonBlanc'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Corbans'), {})
# (rdflib.term.BNode('N57fcbbc9325447d0a3e59354ba7d36f7'), {})
# (rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#nonNegativeInteger')), {})
# (rdflib.term.BNode('Neb6cb30b3d144531a6df9551da377dd5'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaCruzMountainsRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaRegion'), {})
# (rdflib.term.BNode('N222a465d50294237adf3c829b61527f3'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#OffDry'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaPetiteSyrah'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeVougeot'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'), {})
# (rdflib.term.BNode('N578fa396a4e842cdb8ab92fa3983196c'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineColor'), {})
# (rdflib.term.BNode('N9fcd0111e4cd49fd9bc08b5d8674da58'), {})
# (rdflib.term.BNode('N0b525a5cbd544e1ea78c8611403ffc8c'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SancerreRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DessertWine'), {})
# (rdflib.term.BNode('N3c12eb98856545ab89ce23dcb5597104'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaBarbaraRegion'), {})
# (rdflib.term.BNode('N8de4801613284679b5ba460bb9430c7f'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTannerPinotNoir'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FrenchWine'), {})
# (rdflib.term.BNode('N6be0a9ab11224750a26e7fac3d36bdc2'), {})
# (rdflib.term.BNode('N9a36e9a9f3494919b03c01c6df8b8cea'), {})
# (rdflib.term.BNode('N832640c5f1884dd9a3c881afb40d5634'), {})
# (rdflib.term.BNode('Nac264714e07246cfa409f558437433e8'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotesDOrRegion'), {})
# (rdflib.term.BNode('Na5466a105bd848b286dd6416d292c0d0'), {})
# (rdflib.term.BNode('Nbd08ff2164f84d19a8b86aeb931b4d74'), {})
# (rdflib.term.BNode('Nfbe90077e40b4f0ebb52d7e288346917'), {})
# (rdflib.term.BNode('N2f85e1fd611e49ddabe2f0a1b3018545'), {})
# (rdflib.term.BNode('N9d85a5b5f0634b13aad1da1d554854a8'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SemillonOrSauvignonBlanc'), {})
# (rdflib.term.BNode('Nc6975e0ce1fc4e0da35f6e1ebd7efd90'), {})
# (rdflib.term.BNode('N34ff8ae592cb4f1393aacf436c190431'), {})
# (rdflib.term.BNode('N6f9a520aa4b24736b1f07d7a1a710590'), {})
# (rdflib.term.BNode('N1ed1bd773f3040ec9fe4c268fe8d3493'), {})
# (rdflib.term.BNode('N2863a26290a5431aba2892895656b5fe'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SweetWine'), {})
# (rdflib.term.BNode('N9cddbad0b0b44f8a81229fee03c3c585'), {})
# (rdflib.term.BNode('N567c9c5654bf48be99d115ff1b83667c'), {})
# (rdflib.term.BNode('Ne83da762137d41c5bb347be9a8017c2d'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Full'), {})
# (rdflib.term.BNode('N356883f170154540a4428274a5a66e8e'), {})
# (rdflib.term.BNode('N83f6377f713049e6a65e1dbe1fded976'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasFlavor'), {})
# (rdflib.term.BNode('N5933cfccef174cc39b738c4c9077e729'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryRedWine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#VentanaCheninBlanc'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteSyrah'), {})
# (rdflib.term.BNode('N8f717ac28c374c0b85a4282ec6c543b5'), {})
# (rdflib.term.BNode('N641b19d91fc149a0b8a67773959e4d71'), {})
# (rdflib.term.BNode('N0ac549ef4273494e8834f7cd017bbdea'), {})
# (rdflib.term.BNode('N2a7d488913c04160b41b7a92817c00c9'), {})
# (rdflib.term.BNode('N8066f1f3cb1e49a7aad7d8d9bab6d80f'), {})
# (rdflib.term.BNode('N2c47595fa2814cb0bf34fe2036ff8db4'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryWhiteWine'), {})
# (rdflib.term.BNode('N1e41e50041ec4edb8cd4fe810df6ce9a'), {})
# (rdflib.term.BNode('N731822eaedb14a378ed420e2d9712c02'), {})
# (rdflib.term.BNode('N0ac2ed2d854f4fd6a406003d4726a2b2'), {})
# (rdflib.term.BNode('N17c7d65dd2564142a90cece74a780dd6'), {})
# (rdflib.term.BNode('N284c6e215b02497cad75086f83f44ed9'), {})
# (rdflib.term.BNode('Nab80b92b3ac5481fa59c5053b3bcf57f'), {})
# (rdflib.term.BNode('N0df86bd6a3f6485992f97cfb90ec51fd'), {})
# (rdflib.term.BNode('N2a5e02f411934eb3a8c0755a00b66dd0'), {})
# (rdflib.term.BNode('N50e40f1a8f114c8195a4be3ccfc8815c'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Anjou'), {})
# (rdflib.term.BNode('Nb26250782e2a419f8748659dc6eb2868'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedBordeaux'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MeursaultRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#Grape'), {})
# (rdflib.term.BNode('N5bb7ed163bf04cd5ae37551a52426d1d'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/food'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SweetRiesling'), {})
# (rdflib.term.BNode('Nf494d088f28049ef82ecb36a73e230f8'), {})
# (rdflib.term.BNode('N9c013490cfbb4b97ada2c8912d2fe32e'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Strong'), {})
# (rdflib.term.BNode('N0fc91f5d067a4691adba20a33ffd4f33'), {})
# (rdflib.term.BNode('N6a013ba2348f4bc5ac61c80551f5daf2'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotturiZinfandel'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SonomaRegion'), {})
# (rdflib.term.BNode('Ne073f09070ef40b4afca8e89f369e9a2'), {})
# (rdflib.term.BNode('Nf56e74849bbe4bb882a1d6a17f76ab47'), {})
# (rdflib.term.BNode('N3ebf26c073ea47ca8b8d497d3b92a09b'), {})
# (rdflib.term.BNode('N7c29ef4170404e98a3e070bbc70c3f68'), {})
# (rdflib.term.BNode('N92b2235070f14f43a83618e06f4cedc1'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StonleighSauvignonBlanc'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StEmilionRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BordeauxRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MargauxRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SelaksSauvignonBlanc'), {})
# (rdflib.term.BNode('N6dcf5d87071543f89b9470d5325fc285'), {})
# (rdflib.term.BNode('N11b9add61cd946f08e64f60e75d1de44'), {})
# (rdflib.term.BNode('Nc83a1aa0ee67400c84520b236c9c4533'), {})
# (rdflib.term.BNode('N86ff473ec60d45b29a092d2ec40619dd'), {})
# (rdflib.term.BNode('N91509ce8eac5409a9db7e53cbd545c57'), {})
# (rdflib.term.BNode('Nde55dee0359f49238c4c79c98617afd4'), {})
# (rdflib.term.BNode('N71474de88d7647619184cddc0ae6e623'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TexasRegion'), {})
# (rdflib.term.BNode('N0ba35c27a6374e22823d222515244cc7'), {})
# (rdflib.term.BNode('N749e8f536cbf4b25bd1ba14f55d7872a'), {})
# (rdflib.term.BNode('N4b8a56c34bfb4395a8c83703fd79cfce'), {})
# (rdflib.term.BNode('N745dc64a1d1542a68acf2b55fe8b8764'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineFlavor'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Merlot'), {})
# (rdflib.term.BNode('N3348a84f7eb645db9ba6913d52547798'), {})
# (rdflib.term.BNode('N02cdda25dadd418aa44fa0c3d230a101'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MerlotGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CentralCoastRegion'), {})
# (rdflib.term.BNode('N2badfc80347d41c2a4edc93f146213ad'), {})
# (rdflib.term.BNode('Nf3938e7a257049bd816e5d13bfaa9788'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasBody'), {})
# (rdflib.term.BNode('N974cceaab34c497b85a457f112eb5b5c'), {})
# (rdflib.term.BNode('N4a4862c34ad24e0b9016602f0331c319'), {})
# (rdflib.term.BNode('N5362f3a7ccf44ab3b69075fac1f84ff5'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SemillonGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ZinfandelGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Margaux'), {})
# (rdflib.term.BNode('Na5aadf766e1b4133b57f2132e83d456e'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sweet'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Port'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedWine'), {})
# (rdflib.term.BNode('Nbb92ff60417d48e087585bc3caf668a7'), {})
# (rdflib.term.BNode('Nf21c77fcf71e43dab89ac8290d0992bf'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#producesWine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasMaker'), {})
# (rdflib.term.BNode('N164229f0216a47eab6a5993e967b08cd'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GermanyRegion'), {})
# (rdflib.term.BNode('N23dee70963564074be138c95b2bf1c1f'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Muscadet'), {})
# (rdflib.term.BNode('Na5da585849f14f55b240a94da8f905b6'), {})
# (rdflib.term.BNode('N8630d08656f141b0a55a12585d1da5be'), {})
# (rdflib.term.BNode('Nec81acbf833143d2a3f04419ae10c156'), {})
# (rdflib.term.BNode('N2b817ad3c4734ac4b3303eef586ebd68'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossRothermelTrochenbierenausleseRiesling'), {})
# (rdflib.term.BNode('N7de1cce0235f43bea6fe05bd30b0b154'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medoc'), {})
# (rdflib.term.BNode('Nc0e509c35fc54dbe9d7fcd187588fdec'), {})
# (rdflib.term.BNode('Nf73a67febadf424fba4ef57055e55dad'), {})
# (rdflib.term.BNode('N1b9aa07e383442ffb7efdbdfa9a09f92'), {})
# (rdflib.term.BNode('N3f29a7cf1f494857b2f641c704b68adf'), {})
# (rdflib.term.BNode('Nc37878e78f8a45289e49a62285457ad2'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Handley'), {})
# (rdflib.term.BNode('Nbeb9674fbe9b48d7ba9d1791590ef584'), {})
# (rdflib.term.BNode('N1cc7604c7aa347c4aed9f9441457a5c8'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteWine'), {})
# (rdflib.term.BNode('N469ca9ffdfb94019a99af4da61b7797a'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FormanChardonnay'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#NapaRegion'), {})
# (rdflib.term.BNode('Nbb50f57c27f4402e9a9b5e557ee8fe49'), {})
# (rdflib.term.BNode('N64f04aa28d5441b68379655123dc6590'), {})
# (rdflib.term.BNode('N9da4b67be0ee4451a7dbc341b7a7248e'), {})
# (rdflib.term.BNode('N81005f1fb5fa42d991146d35afc7fe81'), {})
# (rdflib.term.BNode('Nab8f60010c4741b0bc5401a527ada7b0'), {})
# (rdflib.term.BNode('N81077d599ddf45378a1f39ead578cb30'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoirGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaCruzMountainVineyardCabernetSauvignon'), {})
# (rdflib.term.BNode('N42170f7b87d54685ac37435c328c48c2'), {})
# (rdflib.term.BNode('N74858034599147dcbec4fb011886e25d'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrell'), {})
# (rdflib.term.BNode('N570e51463a0545b5a07a5308cc326eca'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasColor'), {})
# (rdflib.term.BNode('N516bae7023ca43d69daf77f29654d1db'), {})
# (rdflib.term.BNode('N79303a3f99f24412a24ecb6c598eedef'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LoireRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FrenchRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BourgogneRegion'), {})
# (rdflib.term.BNode('N7a262b768f3f4153b324b91e1c818c66'), {})
# (rdflib.term.BNode('Ne3fc4c355c3e4641827ed8295d335f37'), {})
# (rdflib.term.BNode('N7a10775d01e9483a87ab7a5f8e09f48d'), {})
# (rdflib.term.BNode('Na61962e1a92048e9938dc8ea74275138'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlancGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Thing'), {})
# (rdflib.term.BNode('N3560d1567d2b4893ae40aeb07a32190d'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedBurgundy'), {})
# (rdflib.term.BNode('N8d1ecd7552a94868981cba7671710eca'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Marietta'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StGenevieveTexasWhite'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StGenevieve'), {})
# (rdflib.term.BNode('N1d90756802cf448f9cf4e6a8b88445f5'), {})
# (rdflib.term.BNode('N9baeb74e0b914390abf859f121b3701f'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryWine'), {})
# (rdflib.term.BNode('N22627093483e4d5a9c6a6f86e3451a65'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PulignyMontrachetWhiteBurgundy'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PulignyMontrachet'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MalbecGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SaucelitoCanyonZinfandel'), {})
# (rdflib.term.BNode('Ncb0d05ca3fde42599ebab8fd6f2baf95'), {})
# (rdflib.term.BNode('N0a880379e17d4b7f80180366ed7de231'), {})
# (rdflib.term.BNode('Nba6d231654784a1dadff4fb68cd8f81e'), {})
# (rdflib.term.BNode('N8c38fc590dd6402eb7888a538115c4e1'), {})
# (rdflib.term.BNode('N7b73320cde3c408fbd8d02c3f11202d7'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDYchem'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDYchemSauterne'), {})
# (rdflib.term.BNode('Nfcee5bf312a04effa3272144ea65cb2b'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Burgundy'), {})
# (rdflib.term.BNode('N7896c7b9eec34bd1a48c7e7abe39c84d'), {})
# (rdflib.term.BNode('N59d1ba758df64d8cbb9bbe8a7790aeb7'), {})
# (rdflib.term.BNode('Ne1259c391579409b92428ec63b1b9dc4'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Red'), {})
# (rdflib.term.BNode('Nf78c388ce581466bbe9f22322741ec9a'), {})
# (rdflib.term.BNode('N0c1629c584554197ad5c6f1c0d47537d'), {})
# (rdflib.term.BNode('Na32e0302360e4b4cacdc3f97844d5566'), {})
# (rdflib.term.BNode('N80128f11817f40499f610c35e9360c75'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaCruzMountainVineyard'), {})
# (rdflib.term.BNode('Nfaa6919cf390404189720ee0c94d4381'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Zinfandel'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#PotableLiquid'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Elyse'), {})
# (rdflib.term.BNode('N52851e3b325b4c868f2d46ee9fca942b'), {})
# (rdflib.term.BNode('N18c0b506f90f4b41ab9bc361bac73786'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossVolradTrochenbierenausleseRiesling'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlanc'), {})
# (rdflib.term.BNode('N1f1f5935270042aa8ac7e4e789dff0b4'), {})
# (rdflib.term.BNode('Nf311cd6e34554c87921f1cae96ad11de'), {})
# (rdflib.term.BNode('Ndae68a10121747c5bc5c38a4cc34ac84'), {})
# (rdflib.term.BNode('N158af7f42bfc44b9afc6fbbc66eee7eb'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Selaks'), {})
# (rdflib.term.BNode('N4e45cf54888e476b8f05d4e441bd1de5'), {})
# (rdflib.term.BNode('N5f9f7ef03fe241eab6efb39aac382be1'), {})
# (rdflib.term.BNode('Nd6414932ea5d433ba0acacfdbbc639a7'), {})
# (rdflib.term.BNode('Nb15ce3de9d8b4b22ae0bd3d3c6357b89'), {})
# (rdflib.term.BNode('Nf3b6c387af3e416b81b05033a35783f8'), {})
# (rdflib.term.BNode('N6d1464ab9e904c868b0801a0b5600ee0'), {})
# (rdflib.term.BNode('N98320a68665044139e4200ec1753b69a'), {})
# (rdflib.term.BNode('Nd39702bb0e0a43419d5f33638123d0b9'), {})
# (rdflib.term.BNode('N5be995870ba64bb8a3b0c501103fe396'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhitehallLanePrimavera'), {})
# (rdflib.term.BNode('Nfa184cbed98a4027a8fbabfd7d5d5b04'), {})
# (rdflib.term.BNode('Nf784213d0fac47feba3d5c305cbdafad'), {})
# (rdflib.term.BNode('N22c6e9110a5942818a53d260e1983d45'), {})
# (rdflib.term.BNode('N3ec6c6b64dfa472b8489c0c755ae11d9'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StEmilion'), {})
# (rdflib.term.BNode('N5206f13d36d346aaadfece5a9c2d8943'), {})
# (rdflib.term.BNode('Nffa3bfda62c34388b7b0978ee1ae24a3'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountEdenVineyard'), {})
# (rdflib.term.BNode('N07fd55dd2a8d44ceab16db52bfb903ac'), {})
# (rdflib.term.BNode('N024a90dc3053466eac54ae572e957b8d'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#NewZealandRegion'), {})
# (rdflib.term.BNode('N1b62cb1665554f72a8ba46fae63d3364'), {})
# (rdflib.term.BNode('N5b9a3be7b5b84dfc87304bb080a8aaac'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Meritage'), {})
# (rdflib.term.BNode('Nd94f72a98c7d461aabcae12e2a8f4ad1'), {})
# (rdflib.term.BNode('Nab5eb7c317e94844b01f107fd4b86ba2'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AlsatianWine'), {})
# (rdflib.term.BNode('N951bedaf201347d49e7a240bf0e9a437'), {})
# (rdflib.term.BNode('Ne395fc5b501047fbb329f5ef14ef63fc'), {})
# (rdflib.term.BNode('N9e081f6236d14fee813094d5988b3de7'), {})
# (rdflib.term.BNode('N69c8edaf3f074c8c8585e236a8ea4b9b'), {})
# (rdflib.term.BNode('N236d1724d8e14342b63be0e05930bfd4'), {})
# (rdflib.term.BNode('N1560a9b22a174c1684fa34021443bce7'), {})
# (rdflib.term.BNode('N9a0febc7922743288326316ea4d22b58'), {})
# (rdflib.term.BNode('N4d6e943b82724f01bafbde778a960215'), {})
# (rdflib.term.BNode('Na6e52db29d15464bbde429ea990d6cb9'), {})
# (rdflib.term.BNode('N253bb25ae0284ce19b7bf5a350e08baa'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LongridgeMerlot'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Longridge'), {})
# (rdflib.term.BNode('Nc11d13d3b0974bd2a6c2c9c3ce0857ea'), {})
# (rdflib.term.BNode('N7152202a52c748f6ae5c41b4af5cfa7f'), {})
# (rdflib.term.BNode('N4808cec8def6491cb81958dc65a95ed2'), {})
# (rdflib.term.BNode('Nb51172289e694595b1633ded64e9bf3a'), {})
# (rdflib.term.BNode('Nf39f2706dc5040f3ad1de031e1ee2914'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Taylor'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineBody'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Beaujolais'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineTaste'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineDescriptor'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sancerre'), {})
# (rdflib.term.BNode('Nbeee0c5347554fc0942f2fe8cd221a60'), {})
# (rdflib.term.BNode('N0fe24beb711243debd28185b47f87954'), {})
# (rdflib.term.BNode('Nc9925325e5134b4bbe4e6a1805001dda'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansPrivateBinSauvignonBlanc'), {})
# (rdflib.term.BNode('N655cadf6c5704804a9426a43daf9bd3c'), {})
# (rdflib.term.BNode('N748df5a42caa462880df7037802a9a5b'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PauillacRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MedocRegion'), {})
# (rdflib.term.BNode('Nac6148bda0df4a94a51d0c9bad6fb5c5'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SelaksIceWine'), {})
# (rdflib.term.BNode('N59e3c712469f4d7e9601b92ecfc7589c'), {})
# (rdflib.term.BNode('N52866f2b8a714658a8e886f767ed33aa'), {})
# (rdflib.term.BNode('Nbb197fc13a0b480cb58986c24df70337'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Gamay'), {})
# (rdflib.term.BNode('Nf46cc707b7bf4940a3cace1e9146b5f3'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SouthAustraliaRegion'), {})
# (rdflib.term.BNode('N7e2c54d151bc45cbaf0a5042bc0643ca'), {})
# (rdflib.term.BNode('N756cc19b14404cccbfc38b8a60a17731'), {})
# (rdflib.term.BNode('N67ad952c106f4718af235b358805410e'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BancroftChardonnay'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chardonnay'), {})
# (rdflib.term.BNode('Nc788947d56a24df5b97c75f51c8c4181'), {})
# (rdflib.term.BNode('Nc59b690e078d438781251a4d464e4d84'), {})
# (rdflib.term.BNode('N873eee64bd1945f8a1eb06805d3e285d'), {})
# (rdflib.term.BNode('N7b984a34de8a4194958c28577263d59f'), {})
# (rdflib.term.BNode('Nc1daeb8d08104e92b612f9f632d062dd'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Bancroft'), {})
# (rdflib.term.BNode('Nae9156af66f944579fa1871005542f4f'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignonGrape'), {})
# (rdflib.term.BNode('N166e6059f2c14ae1a83f25a3f91324cd'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RoseDAnjou'), {})
# (rdflib.term.BNode('N68bbcc2576a744d3bbeea12d14217f88'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FullBodiedWine'), {})
# (rdflib.term.BNode('N4b1514ed18e740cab5841e28075d49d3'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryRiesling'), {})
# (rdflib.term.BNode('N184650c6d6f04b4d8c134b384ce86e9b'), {})
# (rdflib.term.BNode('N45553b4252d2428c974388d7775d71e8'), {})
# (rdflib.term.BNode('N746c091f48a6466dac35da27f9f0f101'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeVougeotCotesDOr'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotesDOr'), {})
# (rdflib.term.BNode('Ncd9f6f41f8cc4ede94c90cb022dea7d8'), {})
# (rdflib.term.BNode('Nb23622abbc9a4a089d275b1cb17ddd6a'), {})
# (rdflib.term.BNode('N58363f03b35a40589e658149b3912fcd'), {})
# (rdflib.term.BNode('N2c2b17ad407b4fa4b88f71f6c72aab20'), {})
# (rdflib.term.BNode('Nb4dfe2addba34dbba2909f2f10bf54f4'), {})
# (rdflib.term.BNode('N8c938fe21524490fbbb9297ae46a1ae1'), {})
# (rdflib.term.BNode('Nad1462b28ac041c3807b9a5880214cdf'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KalinCellarsSemillon'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Semillon'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#madeFromFruit'), {})
# (rdflib.term.BNode('N8926957e07f740858c6a489347eadeb2'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotBlanc'), {})
# (rdflib.term.BNode('N650796419cd74910a405f6d86276af24'), {})
# (rdflib.term.BNode('N3e87d478b60843c19077054dd9530a2e'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMargauxWinery'), {})
# (rdflib.term.BNode('Naa00719b967041e39713b37ceda0ec88'), {})
# (rdflib.term.BNode('N98e643896ce7467596da28c5ee219e60'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhitehallLane'), {})
# (rdflib.term.BNode('N19b0de19fea84e008fc65ccf8a6bf9f5'), {})
# (rdflib.term.BNode('Nb5bd27f340984659bcd3976206c97c47'), {})
# (rdflib.term.BNode('N490cd85f13d94eaeaafb6da5488eb910'), {})
# (rdflib.term.BNode('N1d57d23d48804a3ba417855c29ae67ec'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GamayGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FormanCabernetSauvignon'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamRiesling'), {})
# (rdflib.term.BNode('N309fa7170bb9443491d5855cef4ea63d'), {})
# (rdflib.term.BNode('Na74ff6eff1ba4f82bddb4e8b20005cab'), {})
# (rdflib.term.BNode('N3bacd5da8e124dfc90128d5501fe89d8'), {})
# (rdflib.term.BNode('N1db4f6f0d4db4d0e96255f471864f489'), {})
# (rdflib.term.BNode('Nef2e3bae05ba4236aeeb5c7298d0655a'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ElyseZinfandel'), {})
# (rdflib.term.BNode('N3e78f74f7dfb4d73a9e00227f94e8349'), {})
# (rdflib.term.BNode('N93060598bad945e2815e5b1d9c536270'), {})
# (rdflib.term.BNode('Nf6aa432d9366479e904f933b7b10d456'), {})
# (rdflib.term.BNode('Nd09c6b489a104b05b9fe5882c1f6467d'), {})
# (rdflib.term.BNode('Ne37f4750fb4746209486dcea1ca4dc71'), {})
# (rdflib.term.BNode('N22e2123edfe24cd790a5a0b6dac59d6e'), {})
# (rdflib.term.BNode('N6567404e45f54ce0aae0f6151e2b9c2f'), {})
# (rdflib.term.BNode('N6d9dd79c10934734ad913ce79a0f0789'), {})
# (rdflib.term.BNode('Nf28a3fefd3694c07882701bea3bc6f46'), {})
# (rdflib.term.BNode('Ndeb080c2e645462b98de74e32b9d5576'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CongressSpringsSemillon'), {})
# (rdflib.term.BNode('N5e235537672344a4841f5ec76b8d81f5'), {})
# (rdflib.term.BNode('Nd9e2140dd6054723a69d6d1c4cd818fc'), {})
# (rdflib.term.BNode('N55100034a3304f3c9584dd69d765bbe7'), {})
# (rdflib.term.BNode('Nf490ccd2210b408495cd6a640f7a9381'), {})
# (rdflib.term.BNode('N1f17c3e9803446c5a013a9466c2633ef'), {})
# (rdflib.term.BNode('Nfa4daa22194f40fc8522f81cd4f322dd'), {})
# (rdflib.term.BNode('N0023e79448e44734b2fe814683e8aac1'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaCabernetSauvignon'), {})
# (rdflib.term.BNode('N16dcf462ad3e48c79f3ff0d15d07a55d'), {})
# (rdflib.term.BNode('N27db8515397145dc86eedf3b7b7c1874'), {})
# (rdflib.term.BNode('N836ad25a61e54a29a29ec7a8cfdd36c1'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaOldVinesRed'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#VintageYear'), {})
# (rdflib.term.BNode('N8d75e5a0f5524b1c9b67d5c472e51d26'), {})
# (rdflib.term.BNode('N177950a0ac654e578264fb2a6e42bf4e'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Stonleigh'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteTableWine'), {})
# (rdflib.term.BNode('Nd4b72d9c44a34170a848f8457d266ea8'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#adjacentRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/2002/07/owl#SymmetricProperty'), {})
# (rdflib.term.BNode('N04b714777e844901aadc7837e47fa22f'), {})
# (rdflib.term.BNode('Nbb705e8c5a0e4f37b0b7aa4a88a88ea8'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountEdenVineyardEstatePinotNoir'), {})
# (rdflib.term.BNode('N84654800a3e24b5facc12fe08b370800'), {})
# (rdflib.term.BNode('N45ea8016991843e39cc45d5ae1cae3ae'), {})
# (rdflib.term.BNode('N0f8bfedd767d4c50b0887ccce32b1adc'), {})
# (rdflib.term.BNode('Ne7da292058b74812b8e8941719192597'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CongressSprings'), {})
# (rdflib.term.BNode('N56378e1bb6414aa59bb9d2f2e356fd7f'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamChardonnay'), {})
# (rdflib.term.BNode('N5e65c5f40834414581e161869ff4217b'), {})
# (rdflib.term.BNode('Na0efd582cd4b400db8a18533e551d5ca'), {})
# (rdflib.term.BNode('N46f0f4113cfb46bea2e3dbf99297f132'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AustralianRegion'), {})
# (rdflib.term.BNode('N81d4b8513d6f46409b2826f1b1a9b3a3'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDeMeursaultMeursault'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDeMeursault'), {})
# (rdflib.term.BNode('Na170857fa826416aba1ce57070ee2972'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteVerdotGrape'), {})
# (rdflib.term.BNode('N4abb8a0f8d434ac1bdef1e818654afec'), {})
# (rdflib.term.BNode('N19f5cd55ef234874bd8813234cd25184'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AnjouRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Ventana'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteNonSweetWine'), {})
# (rdflib.term.BNode('Nc6a248248c0741ac8b5e323dfe2ddff9'), {})
# (rdflib.term.BNode('N04d34740a23e42f5a122dd171418eb66'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DAnjou'), {})
# (rdflib.term.BNode('N36675c279b604a3e9b5fe16305deddf8'), {})
# (rdflib.term.BNode('Nce210f44ba134da182646345225143a4'), {})
# (rdflib.term.BNode('N5cf82a780413426cb7e3a84fee3bdeac'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PageMillWinery'), {})
# (rdflib.term.BNode('Ncac39726d4e348e9bffe006cca713d07'), {})
# (rdflib.term.BNode('Nf089fc2292f848179ecd86daddab7ed9'), {})
# (rdflib.term.BNode('N321c417d742a4ffcb85f4e8413ed35b0'), {})
# (rdflib.term.BNode('Ne1abe35157554b41a9b3a8dc3bfe0919'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChiantiClassico'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chianti'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Tours'), {})
# (rdflib.term.BNode('N60ca4f66bb524b61a0e5aaf6f3ece9ed'), {})
# (rdflib.term.BNode('Nfe667eefc4004a78acaca17123bb25cf'), {})
# (rdflib.term.BNode('Naed8c3f4430b4063b9b8f8c252daa0cb'), {})
# (rdflib.term.BNode('Ne7a88eab4df24fa1a860b9d4be408378'), {})
# (rdflib.term.BNode('N319c3533e0c540b885c7930a41d0be88'), {})
# (rdflib.term.BNode('N44cc6bd7212943f69c15efb072217c2f'), {})
# (rdflib.term.BNode('N13472dd8289648e9967e421384dc8b25'), {})
# (rdflib.term.BNode('Nacaad31698d14a3aa542af5f387829e4'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SeanThackreySiriusPetiteSyrah'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Year1998'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountEdenVineyardEdnaValleyChardonnay'), {})
# (rdflib.term.BNode('N260a9a9ca9d3446f84e533d7f0ad3ec4'), {})
# (rdflib.term.BNode('N33535c1efa5d425b8e70fd75146bda02'), {})
# (rdflib.term.BNode('N69d3b15bf1964c49a59cf09ae60df67e'), {})
# (rdflib.term.BNode('N64df53b72069489ebc233b0d053a5ffa'), {})
# (rdflib.term.BNode('N42553b30ee6f49f6a9b621addf7dd5a6'), {})
# (rdflib.term.BNode('N48b03aa3126c43378946350035dbdc4f'), {})
# (rdflib.term.BNode('N65ddf4fc594c463696ef538c2d920043'), {})
# (rdflib.term.URIRef('http://www.w3.org/2002/07/owl#TransitiveProperty'), {})
# (rdflib.term.BNode('Na7cc09ccc56f41b5bc9030a4e544a897'), {})
# (rdflib.term.BNode('Nd51b29604c654f0a9a3ac3519c0c79a9'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossRothermel'), {})
# (rdflib.term.BNode('Nec7418b94cc24ff1b3141f6ce8a292c0'), {})
# (rdflib.term.BNode('Nbfa3336be9b040c0a2943a0b4f07a7cd'), {})
# (rdflib.term.BNode('Nd6e88653808448a19f33813bc6666200'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhitehallLaneCabernetFranc'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#IceWine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Light'), {})
# (rdflib.term.BNode('Nf5b80633875b42518e16e07dec1ea920'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteBordeaux'), {})
# (rdflib.term.BNode('Ned0f6563e9c84158bd2d23990aad8cba'), {})
# (rdflib.term.BNode('N9ab61f390fd240c6993e4813d1fc7c90'), {})
# (rdflib.term.BNode('N4c595b9ab31d45919f652cae07ebe2e0'), {})
# (rdflib.term.BNode('N13b22bc8e86c488583109eecdab9ff2a'), {})
# (rdflib.term.BNode('N2e6686c777334f1ebe66fc6b27721fb9'), {})
# (rdflib.term.BNode('Nf8bb24bac31e4238bf4548470e3e0c67'), {})
# (rdflib.term.BNode('N172c094c68824785ac488cb4d194fa64'), {})
# (rdflib.term.BNode('Nf0bf461ada154aee9f39b4171192be16'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#USRegion'), {})
# (rdflib.term.BNode('Ncf53ee32f7a34ae198c9aefb90cdfbba'), {})
# (rdflib.term.BNode('N9c89ecfce85342bbb60b6af65dd26246'), {})
# (rdflib.term.BNode('N6a82fcb0807a4ce5a12022c19744a9ca'), {})
# (rdflib.term.BNode('Nad2c9b4fe2b74fe2b0cb92f2a4ed53e3'), {})
# (rdflib.term.BNode('N691492c7affa4e82a2db1073c856a18c'), {})
# (rdflib.term.BNode('N5173fd599f8c4c3aa4b17b070b32ee85'), {})
# (rdflib.term.BNode('N741036a7bb174ec28d0f8a9007969c87'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauChevalBlancStEmilion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauChevalBlanc'), {})
# (rdflib.term.BNode('Ncc2785d0b52540b0a6864c66006d12e3'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Pauillac'), {})
# (rdflib.term.BNode('N3996f5bb554f40329411283d16d9fcfc'), {})
# (rdflib.term.BNode('N8f124718225144cab098dd169d0ae11a'), {})
# (rdflib.term.BNode('N7cd8d279d13e4238868d5143e9a75319'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineSugar'), {})
# (rdflib.term.BNode('N6481fb748e6140a089989d4a66754957'), {})
# (rdflib.term.BNode('N6e9aca695dd14a0882df0db46d94c258'), {})
# (rdflib.term.BNode('Nddfe066c138f4872abb708862a8b5d6e'), {})
# (rdflib.term.BNode('Naf328cdc96a14d5ca56f769a8b67b072'), {})
# (rdflib.term.BNode('N28b9707ee267470585cb7d61476f418c'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotBlancGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PageMillWineryCabernetSauvignon'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ItalianRegion'), {})
# (rdflib.term.BNode('N88880ad955624c139b3bb157f40dcb20'), {})
# (rdflib.term.BNode('Na424326f9ff3426bacd6449f8edfe9f5'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauLafiteRothschildPauillac'), {})
# (rdflib.term.BNode('N4f83e67332fc49ac86ea2e5dbfcc8133'), {})
# (rdflib.term.BNode('Nb338ebaf2e824c269d8c86ac14411e04'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CortonMontrachetWhiteBurgundy'), {})
# (rdflib.term.BNode('Nf09ab282c30e47bf983b048b6ea9f494'), {})
# (rdflib.term.BNode('N11e11f1c515e4321a60c87fd0c6e2634'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Loire'), {})
# (rdflib.term.BNode('N84bd9fb9357d4ec1b97e6487c906767f'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BeaujolaisRegion'), {})
# (rdflib.term.BNode('N2314db9725e143f7aef13c9dc5ea4463'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTanner'), {})
# (rdflib.term.BNode('Nf2d52710b0954a8aaa56b73cf9bcf971'), {})
# (rdflib.term.BNode('Ne707c9df32ed463abc58b7b206c835aa'), {})
# (rdflib.term.BNode('N5a480256e40f4f7db1cfd863ae1cdd99'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeIntoWine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteLoire'), {})
# (rdflib.term.BNode('N3211bc489e554048902466cb349938ad'), {})
# (rdflib.term.BNode('Na4629eca65a947bc9a21f823aee51ad4'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SangioveseGrape'), {})
# (rdflib.term.BNode('Nb503db9d701e44eb91cf0d0a4668697a'), {})
# (rdflib.term.BNode('Nc41b7e8d628a478b9388e936266a271e'), {})
# (rdflib.term.BNode('Nf14f4d0ad7e341acb7b861d8b5079a43'), {})
# (rdflib.term.BNode('N01a8eeebb545420fbba63c9243e2725e'), {})
# (rdflib.term.BNode('Nc646ddbd6b734bbda607dba1de0a578a'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CentralTexasRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FoxenCheninBlanc'), {})
# (rdflib.term.BNode('N25b6646875d942d296d83d189481d4f0'), {})
# (rdflib.term.BNode('Nf217ef3615ea48148ead58045f7b1fb6'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Cotturi'), {})
# (rdflib.term.BNode('N610267b51b564f81be4118925564566b'), {})
# (rdflib.term.BNode('N19918900f73d4bc7aff795262f167d2c'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlancGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChiantiRegion'), {})
# (rdflib.term.BNode('N34e84ab489854a6f9749083db6a31501'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SaucelitoCanyon'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasWineDescriptor'), {})
# (rdflib.term.BNode('N9749ce30b9f145ee9718b9816f28784d'), {})
# (rdflib.term.BNode('Nee5578524c4e41109ba474cd53e1e300'), {})
# (rdflib.term.BNode('Nb629d609878247d5b06663ef9fd650f7'), {})
# (rdflib.term.BNode('N4c7ea8ea0d0a43a08d44e3f435dc9a0c'), {})
# (rdflib.term.Literal('An example OWL ontology'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MuscadetRegion'), {})
# (rdflib.term.BNode('N46ff801a5acf44159bacb2b83268c543'), {})
# (rdflib.term.BNode('N04f0491524e5446a8a626b7b6bdaeb60'), {})
# (rdflib.term.BNode('N55d0af3079fd45a5964e3dd20613804c'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteBurgundy'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/CR-owl-guide-20030818/wine'), {})
# (rdflib.term.BNode('Nf243a55712d44e11a8f767dd1ee8fbfd'), {})
# (rdflib.term.BNode('N6cc3ebfa7a1448f0ab66e17dcb42a041'), {})
# (rdflib.term.BNode('Naf74fb09bc3c471a81cb146d708cc380'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SaucelitoCanyonZinfandel1998'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ArroyoGrandeRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Rose'), {})
# (rdflib.term.BNode('N3dc6ff8e1eed48e49789c4f676fdf8cd'), {})
# (rdflib.term.BNode('N0cb063ba5e57476aa49bc97049aec174'), {})
# (rdflib.term.BNode('Nbfd31759f5494e8ea826630d85be92ce'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#McGuinnesso'), {})
# (rdflib.term.BNode('Nefe9261d51c042efbf614dcb63dbcab6'), {})
# (rdflib.term.BNode('N9cff521bbe404bb7a28eabba0accf225'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Forman'), {})
# (rdflib.term.BNode('N69ad0e0fe4d0408b9fd1e2192c66ab22'), {})
# (rdflib.term.BNode('N39222b13df864a57aaed3861e45f3538'), {})
# (rdflib.term.BNode('N9c48604a6012465a818e513436683a2a'), {})
# (rdflib.term.BNode('Nd609471460984220bc8bcdb71351e50d'), {})
# (rdflib.term.BNode('N856a07ce57894a23b1aafe2f140b635f'), {})
# (rdflib.term.BNode('Nbf40f6fbd5d94132b8dffc93aa81d5c5'), {})
# (rdflib.term.BNode('N08daeebe60f04f9483e44d101d174fd2'), {})
# (rdflib.term.BNode('Nf06f14693e414683890f6e396abd5d4c'), {})
# (rdflib.term.BNode('Na177f6918c33415692e726386b794342'), {})
# (rdflib.term.BNode('Nfb06df8a55de443480b12b6e0513bc53'), {})
# (rdflib.term.BNode('N997880520ed744e8899b9dddb8cae676'), {})
# (rdflib.term.BNode('Na842b234af124021b7912e62bf72a39c'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CortonMontrachet'), {})
# (rdflib.term.BNode('N99e32a6515284ccbb6ff5a1bb7756fa7'), {})
# (rdflib.term.BNode('Neb55882f1de94ea7a66c074b9c631c5b'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PeterMccoyChardonnay'), {})
# (rdflib.term.BNode('N167ae9a9108945329463a57a45151dd6'), {})
# (rdflib.term.BNode('N783234dcbec94fbf941d171f14e40323'), {})
# (rdflib.term.BNode('N370cb9673dcc437980a6f8ca2c7a7deb'), {})
# (rdflib.term.BNode('Nfa0d0a2923ec42f192292c2667ba9f4c'), {})
# (rdflib.term.BNode('Nc1980c00355d44a48b57f8a3bc833404'), {})
# (rdflib.term.BNode('Nfbc3a69efd2c4d26bb24f7cbaf7f3d31'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Foxen'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PeterMccoy'), {})
# (rdflib.term.BNode('N8e0bd5eac65a43adae82b4cd5defaa60'), {})
# (rdflib.term.BNode('Nfd88d3f96aa848bcbb14b8b9bd1c199e'), {})
# (rdflib.term.BNode('N16832468cc81441db0eb2040f09b2a6f'), {})
# (rdflib.term.URIRef('http://www.w3.org/2002/07/owl#AllDifferent'), {})
# (rdflib.term.BNode('N4985b15075a84d64b6a699a00a45f029'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedTableWine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChardonnayGrape'), {})
# (rdflib.term.BNode('Ndcbedc356e854a928b74e7a59a663a94'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AmericanWine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Mountadam'), {})
# (rdflib.term.BNode('Nddc1f30deb344461820f5748886d9963'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KalinCellars'), {})
# (rdflib.term.BNode('Ned90393f94b24aa9b5fbffc8a9684363'), {})
# (rdflib.term.BNode('Nc7787ffe8fe2452db74b20d7ca5e6954'), {})
# (rdflib.term.BNode('N8a1b6fee8695422ab1eb5bf9aff1a90e'), {})
# (rdflib.term.BNode('Nf8dcc4e6d4484edc84da6892f06f4dba'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaWine'), {})
# (rdflib.term.Literal('1998', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#positiveInteger')), {})
# (rdflib.term.BNode('N25e6103383074eb098843aa466cbece1'), {})
# (rdflib.term.BNode('Nce16a281b4e94c27964c5b5209c8b5f7'), {})
# (rdflib.term.BNode('Nb62cdb1ddee04b21b6b729a3820a6a6a'), {})
# (rdflib.term.BNode('N84b72845cc7c4374b4a44d3fc87234d8'), {})
# (rdflib.term.BNode('N29434050314e47919bcae8350ddb36f8'), {})
# (rdflib.term.BNode('Nb14aba50c080489790cdb3e8b39cdf26'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ItalianWine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteSyrahGrape'), {})
# (rdflib.term.BNode('N701c145898814560ac0def9dae1e47f7'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ToursRegion'), {})
# (rdflib.term.BNode('Nc8e007c227f74518aa4a570364a757ee'), {})
# (rdflib.term.BNode('Ne0e79da571934ffe8084e57350fc5809'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KathrynKennedy'), {})
# (rdflib.term.BNode('Nf8cd168fb63b48bf810763fe23610f1b'), {})
# (rdflib.term.BNode('Nab8a0f92a17a4e99856f409b60fc1289'), {})
# (rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Ontology'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#yearValue'), {})
# (rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GermanWine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PortugalRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sauternes'), {})
# (rdflib.term.BNode('Nd51c061b882642f7b1a235af609c0219'), {})
# (rdflib.term.BNode('Nf6ab739c27524674a87c88d5e6f2bea4'), {})
# (rdflib.term.BNode('N2e80871658284cb4a5bce2c8723f3291'), {})
# (rdflib.term.BNode('N3747c893e9f8414cb690fd978119c7ec'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EdnaValleyRegion'), {})
# (rdflib.term.BNode('Nb158f541018e45449d4a0355cf38e347'), {})
# (rdflib.term.BNode('N2da7ac5c2ce64302a13e91307bbe0d41'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Bordeaux'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossVolrad'), {})
# (rdflib.term.BNode('N9d970c0875764fc8a1fdf801b0c1b89c'), {})
# (rdflib.term.BNode('N850e7e9ba65740cd98300e3ab63a2856'), {})
# (rdflib.term.BNode('N968ba3c89b3b46d884d548efcf08d1cd'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TaylorPort'), {})
# (rdflib.term.BNode('N5252571591424f9e8e2a8749ac24c316'), {})
# (rdflib.term.BNode('N17095d5ab8594f3a88708ebe429f3bf2'), {})
# (rdflib.term.BNode('N133207d1c5ee4d92ab2288f370ceb0dc'), {})
# (rdflib.term.BNode('Neea2dae15ba9436da5444a5f729af184'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauterneRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EarlyHarvest'), {})
# (rdflib.term.BNode('N5a02573cc100495f8f635061d443e2a6'), {})
# (rdflib.term.BNode('Nb40de0a3e5a3478dbda8926f36c50578'), {})
# (rdflib.term.BNode('N613f41181b004dc2ac86e289c8c268ff'), {})
# (rdflib.term.BNode('Na8369224a43b4e109040d5b336878fce'), {})
# (rdflib.term.BNode('N76bb092440554388921402379cec21c8'), {})
# (rdflib.term.BNode('N3fa8c9f2febf45f190d2ab4723d9fd98'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MendocinoRegion'), {})
# (rdflib.term.BNode('Neb1c4e280372450daecb16de5ecbca08'), {})
# (rdflib.term.BNode('Ndf761f0633bf4e18aa41aa3134f0c70d'), {})
# (rdflib.term.BNode('Nd5cd0dfd55c7449ab1487784396888a1'), {})
# (rdflib.term.BNode('N722fc121b9224068941c2df34f661656'), {})
# (rdflib.term.BNode('N18483cbea66a4268b71e17ccc3cb0ae6'), {})
# (rdflib.term.BNode('N763968c78f02473fa1bdc4de619ae421'), {})
# (rdflib.term.BNode('N3a42b51c854a4e42af03ca2182e3fc4f'), {})
# (rdflib.term.BNode('Nd6307926dc2449f7a78650c5ef45504a'), {})
# (rdflib.term.BNode('Ne4964f3567d3489e931f99804bfa785d'), {})
# (rdflib.term.BNode('Nf4c522c2437840ba8d14379df512c517'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RieslingGrape'), {})
# (rdflib.term.BNode('Ne670b2b8ed734ec4839d36e64404c9f6'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AlsaceRegion'), {})
# (rdflib.term.BNode('Nf42ebbdfd96b4771a3f72aac60dda9bd'), {})
# (rdflib.term.BNode('N3a1eb74f5dbf4429a35591f785acd830'), {})
# (rdflib.term.BNode('Ne2367b61fbb34b9eb9a975c1304d38a2'), {})
# (rdflib.term.BNode('Nbd4bbd176c9541a98d04b7365c62a89e'), {})
# (rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#nonNegativeInteger')), {})
# (rdflib.term.BNode('N630c38b1cd954f8b83bd293d9e6ef485'), {})
# (rdflib.term.BNode('N6c5b850d118a4b1394e347351fea87ff'), {})
# (rdflib.term.BNode('Nee746bb0e67c4cf8abf84cb6d9ba7863'), {})
# (rdflib.term.BNode('Nbd821fd7100340bc8e96ec48c01fa807'), {})
# (rdflib.term.Literal('Derived from the DAML Wine ontology at\n      http://ontolingua.stanford.edu/doc/chimaera/ontologies/wines.daml\n      Substantially changed, in particular the Region based relations.\n    '), {})
# (rdflib.term.BNode('N68fbb21eb183434b8829ae6a3e46a62e'), {})
# (rdflib.term.Literal('vin', lang='fr'), {})
# (rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#positiveInteger'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauLafiteRothschild'), {})
# (rdflib.term.BNode('N7f9d02fcef204966a8ef69bbd3ec3bac'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Beringer'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeLaPoussieSancerre'), {})
# (rdflib.term.BNode('N2b5d8f14438240bd822fbcd62b30782f'), {})
# (rdflib.term.BNode('N048d2f78c8df4feca5c53c466392d4e5'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RoseWine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeLaPoussie'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMargaux'), {})
# (rdflib.term.BNode('Nf3d0e086259a4bf297bec72ba445a57b'), {})
# (rdflib.term.BNode('Ncd4d8c5ca3ea49119d08843f3896c291'), {})
# (rdflib.term.BNode('N34bfc57a3be74af6a89c6370a73ee967'), {})
# (rdflib.term.Literal('wine', lang='en'), {})
# (rdflib.term.Literal('Wine Ontology'), {})
# (rdflib.term.Literal('Made WineDescriptor unionType of tastes and color'), {})

# %%
for edges in G.edges(data=True):
    print(edges)
# Out:
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaZinfandel'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaZinfandel'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Marietta'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaZinfandel'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Zinfandel'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaZinfandel'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaZinfandel'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SonomaRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaZinfandel'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineSugar'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Thing'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamPinotNoir'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoir'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamPinotNoir'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamPinotNoir'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SouthAustraliaRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamPinotNoir'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamPinotNoir'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamPinotNoir'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Mountadam'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoir'), rdflib.term.BNode('N39537a10149b49cb95687685024347d2'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoir'), rdflib.term.BNode('Ne37f4750fb4746209486dcea1ca4dc71'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoir'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFranc'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFranc'), rdflib.term.BNode('Neb6cb30b3d144531a6df9551da377dd5'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFranc'), rdflib.term.BNode('Ne83da762137d41c5bb347be9a8017c2d'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFranc'), rdflib.term.BNode('N45ea8016991843e39cc45d5ae1cae3ae'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFranc'), rdflib.term.BNode('Naf328cdc96a14d5ca56f769a8b67b072'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFranc'), rdflib.term.BNode('N42170f7b87d54685ac37435c328c48c2'), {})
# (rdflib.term.BNode('Na69323a4dbbb48bb9ca8268064fa894e'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Na69323a4dbbb48bb9ca8268064fa894e'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Strong'), {})
# (rdflib.term.BNode('N7820cafd23d146c196faf920bbd885fb'), rdflib.term.BNode('N422ad33260b245189cba1ce599e2dbfe'), {})
# (rdflib.term.BNode('N7820cafd23d146c196faf920bbd885fb'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PageMillWinery'), {})
# (rdflib.term.BNode('N422ad33260b245189cba1ce599e2dbfe'), rdflib.term.BNode('N7b984a34de8a4194958c28577263d59f'), {})
# (rdflib.term.BNode('N422ad33260b245189cba1ce599e2dbfe'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PeterMccoy'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrellMerlot'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrellMerlot'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SonomaRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrellMerlot'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Merlot'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrellMerlot'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrellMerlot'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrell'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrellMerlot'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.BNode('Nc4dda7f5f7054bffa3e4cff73d2dfa74'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Nc4dda7f5f7054bffa3e4cff73d2dfa74'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Strong'), {})
# (rdflib.term.BNode('N0c07547f2e614dffae10b17422308216'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'), {})
# (rdflib.term.BNode('N0c07547f2e614dffae10b17422308216'), rdflib.term.BNode('Nd09c6b489a104b05b9fe5882c1f6467d'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Thing'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineFlavor'), {})
# (rdflib.term.BNode('N39537a10149b49cb95687685024347d2'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N39537a10149b49cb95687685024347d2'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Red'), {})
# (rdflib.term.BNode('N39537a10149b49cb95687685024347d2'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasColor'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TexasWine'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TexasWine'), rdflib.term.BNode('Nbd4bbd176c9541a98d04b7365c62a89e'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Meursault'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Meursault'), rdflib.term.BNode('Nd39702bb0e0a43419d5f33638123d0b9'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Meursault'), rdflib.term.BNode('Naed8c3f4430b4063b9b8f8c252daa0cb'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#locatedIn'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#locatedIn'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#TransitiveProperty'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#locatedIn'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#locatedIn'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Thing'), {})
# (rdflib.term.BNode('N291a1b9749a341d68d31108112bf3fae'), rdflib.term.BNode('N981d5d6a59bd4968a9666a08050c8b29'), {})
# (rdflib.term.BNode('N291a1b9749a341d68d31108112bf3fae'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.BNode('N981d5d6a59bd4968a9666a08050c8b29'), rdflib.term.BNode('Nc1980c00355d44a48b57f8a3bc833404'), {})
# (rdflib.term.BNode('N981d5d6a59bd4968a9666a08050c8b29'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'), {})
# (rdflib.term.BNode('Na922c8a024744eddada32aa79d2624e1'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), {})
# (rdflib.term.BNode('Na922c8a024744eddada32aa79d2624e1'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('Na922c8a024744eddada32aa79d2624e1'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#FunctionalProperty'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasWineDescriptor'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineSugar'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'), {})
# (rdflib.term.BNode('Nc157fe7a4b844ab892982b6ab4a21186'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Nc157fe7a4b844ab892982b6ab4a21186'), rdflib.term.BNode('Nfa4daa22194f40fc8522f81cd4f322dd'), {})
# (rdflib.term.BNode('Nc0168a8cc3ef4137b60e209222b411ad'), rdflib.term.BNode('N0db4f652c8474e248ae67604d0cb48c0'), {})
# (rdflib.term.BNode('Nc0168a8cc3ef4137b60e209222b411ad'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.BNode('N0db4f652c8474e248ae67604d0cb48c0'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Full'), {})
# (rdflib.term.BNode('N0db4f652c8474e248ae67604d0cb48c0'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Nd4cf0f26c9ea4e9c9d52531a10d29dfb'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Delicate'), {})
# (rdflib.term.BNode('Nd4cf0f26c9ea4e9c9d52531a10d29dfb'), rdflib.term.BNode('N84d3b6b009324056a1d77d4f60e4affc'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Delicate'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Thing'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Delicate'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineFlavor'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'), rdflib.term.BNode('N8de4801613284679b5ba460bb9430c7f'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'), rdflib.term.BNode('Nbb92ff60417d48e087585bc3caf668a7'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'), rdflib.term.BNode('N6cc3ebfa7a1448f0ab66e17dcb42a041'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'), rdflib.term.BNode('N9d970c0875764fc8a1fdf801b0c1b89c'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'), rdflib.term.BNode('Nd6307926dc2449f7a78650c5ef45504a'), {})
# (rdflib.term.BNode('Ne9b41dd984c34e2b843738d40aee7b06'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Ne9b41dd984c34e2b843738d40aee7b06'), rdflib.term.BNode('N2b817ad3c4734ac4b3303eef586ebd68'), {})
# (rdflib.term.BNode('N815a5c1dcc70431682b8fa754d462a1c'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFrancGrape'), {})
# (rdflib.term.BNode('N815a5c1dcc70431682b8fa754d462a1c'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N815a5c1dcc70431682b8fa754d462a1c'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFrancGrape'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFrancGrape'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Thing'), {})
# (rdflib.term.BNode('N5c81ef50cb96451fb1aad40fcc89d43f'), rdflib.term.BNode('N3ada577683d2447398e63db36880f8c5'), {})
# (rdflib.term.BNode('N5c81ef50cb96451fb1aad40fcc89d43f'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Full'), {})
# (rdflib.term.BNode('N3ada577683d2447398e63db36880f8c5'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.BNode('N3ada577683d2447398e63db36880f8c5'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TableWine'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TableWine'), rdflib.term.BNode('N490cd85f13d94eaeaafb6da5488eb910'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlanc'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlanc'), rdflib.term.BNode('N81005f1fb5fa42d991146d35afc7fe81'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlanc'), rdflib.term.BNode('N2a5e02f411934eb3a8c0755a00b66dd0'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlanc'), rdflib.term.BNode('N0ac549ef4273494e8834f7cd017bbdea'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlanc'), rdflib.term.BNode('Nc646ddbd6b734bbda607dba1de0a578a'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlanc'), rdflib.term.BNode('Na61962e1a92048e9938dc8ea74275138'), {})
# (rdflib.term.BNode('N6125f2fadab346ffad1bcc6bc54ee125'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#White'), {})
# (rdflib.term.BNode('N6125f2fadab346ffad1bcc6bc54ee125'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N6125f2fadab346ffad1bcc6bc54ee125'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasColor'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#White'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Thing'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#White'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineColor'), {})
# (rdflib.term.BNode('Nb58642dfa2f94f51a48d649f5cea3471'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), {})
# (rdflib.term.BNode('Nb58642dfa2f94f51a48d649f5cea3471'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignonGrape'), {})
# (rdflib.term.BNode('Nb58642dfa2f94f51a48d649f5cea3471'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#madeFromFruit'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), {})
# (rdflib.term.BNode('N9807701a3d9f4c068fc57005305d6527'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LateHarvest'), {})
# (rdflib.term.BNode('N9807701a3d9f4c068fc57005305d6527'), rdflib.term.BNode('N69d3b15bf1964c49a59cf09ae60df67e'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LateHarvest'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LateHarvest'), rdflib.term.BNode('N17c7d65dd2564142a90cece74a780dd6'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LateHarvest'), rdflib.term.BNode('N974cceaab34c497b85a457f112eb5b5c'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LateHarvest'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LateHarvest'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EarlyHarvest'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansDryWhiteRiesling'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Riesling'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansDryWhiteRiesling'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#NewZealandRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansDryWhiteRiesling'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#OffDry'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansDryWhiteRiesling'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansDryWhiteRiesling'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Corbans'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansDryWhiteRiesling'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Riesling'), rdflib.term.BNode('Ndf761f0633bf4e18aa41aa3134f0c70d'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Riesling'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Riesling'), rdflib.term.BNode('Nde55dee0359f49238c4c79c98617afd4'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasVintageYear'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Vintage'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasVintageYear'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasVintageYear'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#VintageYear'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasVintageYear'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#FunctionalProperty'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Vintage'), rdflib.term.BNode('N59e3c712469f4d7e9601b92ecfc7589c'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Vintage'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaineMuscadet'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaineMuscadet'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Muscadet'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaine'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), rdflib.term.BNode('N5446d0b8e9eb4bd28ff40be1ff93e97b'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), rdflib.term.BNode('N7de1cce0235f43bea6fe05bd30b0b154'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), rdflib.term.BNode('Nfaa6919cf390404189720ee0c94d4381'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#PotableLiquid'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), rdflib.term.BNode('N253bb25ae0284ce19b7bf5a350e08baa'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), rdflib.term.BNode('Na5466a105bd848b286dd6416d292c0d0'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), rdflib.term.BNode('N11e11f1c515e4321a60c87fd0c6e2634'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), rdflib.term.Literal('vin', lang='fr'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), rdflib.term.Literal('wine', lang='en'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), rdflib.term.BNode('Nf2d52710b0954a8aaa56b73cf9bcf971'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), rdflib.term.BNode('N9a0febc7922743288326316ea4d22b58'), {})
# (rdflib.term.BNode('N5446d0b8e9eb4bd28ff40be1ff93e97b'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'), {})
# (rdflib.term.BNode('N5446d0b8e9eb4bd28ff40be1ff93e97b'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N5446d0b8e9eb4bd28ff40be1ff93e97b'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasMaker'), {})
# (rdflib.term.BNode('N84d3b6b009324056a1d77d4f60e4affc'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'), {})
# (rdflib.term.BNode('N84d3b6b009324056a1d77d4f60e4affc'), rdflib.term.BNode('N167ae9a9108945329463a57a45151dd6'), {})
# (rdflib.term.BNode('N4e170e1709da4018a251b2be47b7dda7'), rdflib.term.BNode('N0c07547f2e614dffae10b17422308216'), {})
# (rdflib.term.BNode('N4e170e1709da4018a251b2be47b7dda7'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.BNode('N1d26bc5360854a8396ef782094a9d401'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N1d26bc5360854a8396ef782094a9d401'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignonGrape'), {})
# (rdflib.term.BNode('N1d26bc5360854a8396ef782094a9d401'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KathrynKennedyLateral'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Delicate'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KathrynKennedyLateral'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Meritage'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KathrynKennedyLateral'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KathrynKennedyLateral'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KathrynKennedy'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KathrynKennedyLateral'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), {})
# (rdflib.term.BNode('N30d493953df74a31b0d5d3f10777c74b'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N30d493953df74a31b0d5d3f10777c74b'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), {})
# (rdflib.term.BNode('N30d493953df74a31b0d5d3f10777c74b'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#nonNegativeInteger')), {})
# (rdflib.term.BNode('N2058bc45bcbc45d281de9613b0453699'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SeanThackrey'), {})
# (rdflib.term.BNode('N2058bc45bcbc45d281de9613b0453699'), rdflib.term.BNode('Naa00719b967041e39713b37ceda0ec88'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SeanThackrey'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'), {})
# (rdflib.term.BNode('N9501c80ba31b47a3819a0f2557510cf0'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N9501c80ba31b47a3819a0f2557510cf0'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasColor'), {})
# (rdflib.term.BNode('N9501c80ba31b47a3819a0f2557510cf0'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#White'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMorgonBeaujolais'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMorgon'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMorgonBeaujolais'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Beaujolais'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMorgon'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'), {})
# (rdflib.term.BNode('N4bd42f07319f494ca73188690c9719da'), rdflib.term.BNode('Nc1e173865e3d42258d147b56b98d991c'), {})
# (rdflib.term.BNode('N4bd42f07319f494ca73188690c9719da'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Nc1e173865e3d42258d147b56b98d991c'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), {})
# (rdflib.term.BNode('Nc1e173865e3d42258d147b56b98d991c'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sweet'), {})
# (rdflib.term.BNode('Nc1e173865e3d42258d147b56b98d991c'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('Nab9bc303439d4858ad529cd268289504'), rdflib.term.BNode('Ne41735398fc348a08da1dbb53ac17116'), {})
# (rdflib.term.BNode('Nab9bc303439d4858ad529cd268289504'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFrancGrape'), {})
# (rdflib.term.BNode('Ne41735398fc348a08da1dbb53ac17116'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MalbecGrape'), {})
# (rdflib.term.BNode('Ne41735398fc348a08da1dbb53ac17116'), rdflib.term.BNode('Na170857fa826416aba1ce57070ee2972'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansSauvignonBlanc'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Corbans'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansSauvignonBlanc'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansSauvignonBlanc'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#NewZealandRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansSauvignonBlanc'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlanc'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansSauvignonBlanc'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Strong'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansSauvignonBlanc'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Corbans'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'), {})
# (rdflib.term.BNode('N57fcbbc9325447d0a3e59354ba7d36f7'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#nonNegativeInteger')), {})
# (rdflib.term.BNode('N57fcbbc9325447d0a3e59354ba7d36f7'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N57fcbbc9325447d0a3e59354ba7d36f7'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), {})
# (rdflib.term.BNode('Neb6cb30b3d144531a6df9551da377dd5'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'), {})
# (rdflib.term.BNode('Neb6cb30b3d144531a6df9551da377dd5'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('Neb6cb30b3d144531a6df9551da377dd5'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasFlavor'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaCruzMountainsRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaCruzMountainsRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#USRegion'), {})
# (rdflib.term.BNode('N222a465d50294237adf3c829b61527f3'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#OffDry'), {})
# (rdflib.term.BNode('N222a465d50294237adf3c829b61527f3'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#OffDry'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineSugar'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#OffDry'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#OffDry'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Thing'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#OffDry'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sweet'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaPetiteSyrah'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Moderate'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaPetiteSyrah'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaPetiteSyrah'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteSyrah'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaPetiteSyrah'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Marietta'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaPetiteSyrah'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaPetiteSyrah'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SonomaRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeVougeot'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.BNode('N578fa396a4e842cdb8ab92fa3983196c'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), {})
# (rdflib.term.BNode('N578fa396a4e842cdb8ab92fa3983196c'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), {})
# (rdflib.term.BNode('N578fa396a4e842cdb8ab92fa3983196c'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineColor'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineColor'), rdflib.term.BNode('Nba6d231654784a1dadff4fb68cd8f81e'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineColor'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineDescriptor'), {})
# (rdflib.term.BNode('N9fcd0111e4cd49fd9bc08b5d8674da58'), rdflib.term.BNode('N4bd42f07319f494ca73188690c9719da'), {})
# (rdflib.term.BNode('N9fcd0111e4cd49fd9bc08b5d8674da58'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), {})
# (rdflib.term.BNode('N0b525a5cbd544e1ea78c8611403ffc8c'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SancerreRegion'), {})
# (rdflib.term.BNode('N0b525a5cbd544e1ea78c8611403ffc8c'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#locatedIn'), {})
# (rdflib.term.BNode('N0b525a5cbd544e1ea78c8611403ffc8c'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SancerreRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LoireRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SancerreRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DessertWine'), rdflib.term.BNode('N3c12eb98856545ab89ce23dcb5597104'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DessertWine'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DessertWine'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.BNode('N3c12eb98856545ab89ce23dcb5597104'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), {})
# (rdflib.term.BNode('N3c12eb98856545ab89ce23dcb5597104'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N3c12eb98856545ab89ce23dcb5597104'), rdflib.term.BNode('Ndae68a10121747c5bc5c38a4cc34ac84'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaBarbaraRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaBarbaraRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'), {})
# (rdflib.term.BNode('N8de4801613284679b5ba460bb9430c7f'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Red'), {})
# (rdflib.term.BNode('N8de4801613284679b5ba460bb9430c7f'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasColor'), {})
# (rdflib.term.BNode('N8de4801613284679b5ba460bb9430c7f'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTannerPinotNoir'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoir'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTannerPinotNoir'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaBarbaraRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTannerPinotNoir'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTanner'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTannerPinotNoir'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTannerPinotNoir'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Light'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTannerPinotNoir'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Delicate'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FrenchWine'), rdflib.term.BNode('N6be0a9ab11224750a26e7fac3d36bdc2'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FrenchWine'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.BNode('N6be0a9ab11224750a26e7fac3d36bdc2'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), {})
# (rdflib.term.BNode('N6be0a9ab11224750a26e7fac3d36bdc2'), rdflib.term.BNode('N701c145898814560ac0def9dae1e47f7'), {})
# (rdflib.term.BNode('N9a36e9a9f3494919b03c01c6df8b8cea'), rdflib.term.BNode('N832640c5f1884dd9a3c881afb40d5634'), {})
# (rdflib.term.BNode('N9a36e9a9f3494919b03c01c6df8b8cea'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.BNode('N832640c5f1884dd9a3c881afb40d5634'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N832640c5f1884dd9a3c881afb40d5634'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Full'), {})
# (rdflib.term.BNode('Nac264714e07246cfa409f558437433e8'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotesDOrRegion'), {})
# (rdflib.term.BNode('Nac264714e07246cfa409f558437433e8'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('Nac264714e07246cfa409f558437433e8'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#locatedIn'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotesDOrRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotesDOrRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BourgogneRegion'), {})
# (rdflib.term.BNode('Na5466a105bd848b286dd6416d292c0d0'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), {})
# (rdflib.term.BNode('Na5466a105bd848b286dd6416d292c0d0'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#nonNegativeInteger')), {})
# (rdflib.term.BNode('Na5466a105bd848b286dd6416d292c0d0'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('Nbd08ff2164f84d19a8b86aeb931b4d74'), rdflib.term.BNode('Nfbe90077e40b4f0ebb52d7e288346917'), {})
# (rdflib.term.BNode('Nbd08ff2164f84d19a8b86aeb931b4d74'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Loire'), {})
# (rdflib.term.BNode('Nfbe90077e40b4f0ebb52d7e288346917'), rdflib.term.BNode('N1d90756802cf448f9cf4e6a8b88445f5'), {})
# (rdflib.term.BNode('Nfbe90077e40b4f0ebb52d7e288346917'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N2f85e1fd611e49ddabe2f0a1b3018545'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N2f85e1fd611e49ddabe2f0a1b3018545'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), {})
# (rdflib.term.BNode('N2f85e1fd611e49ddabe2f0a1b3018545'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChardonnayGrape'), {})
# (rdflib.term.BNode('N9d85a5b5f0634b13aad1da1d554854a8'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SemillonOrSauvignonBlanc'), {})
# (rdflib.term.BNode('N9d85a5b5f0634b13aad1da1d554854a8'), rdflib.term.BNode('N46ff801a5acf44159bacb2b83268c543'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SemillonOrSauvignonBlanc'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SemillonOrSauvignonBlanc'), rdflib.term.BNode('N44cc6bd7212943f69c15efb072217c2f'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SemillonOrSauvignonBlanc'), rdflib.term.BNode('N4985b15075a84d64b6a699a00a45f029'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SemillonOrSauvignonBlanc'), rdflib.term.BNode('Nfbc3a69efd2c4d26bb24f7cbaf7f3d31'), {})
# (rdflib.term.BNode('Nc6975e0ce1fc4e0da35f6e1ebd7efd90'), rdflib.term.BNode('N34ff8ae592cb4f1393aacf436c190431'), {})
# (rdflib.term.BNode('Nc6975e0ce1fc4e0da35f6e1ebd7efd90'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), {})
# (rdflib.term.BNode('N34ff8ae592cb4f1393aacf436c190431'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N34ff8ae592cb4f1393aacf436c190431'), rdflib.term.BNode('N570e51463a0545b5a07a5308cc326eca'), {})
# (rdflib.term.BNode('N6f9a520aa4b24736b1f07d7a1a710590'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), {})
# (rdflib.term.BNode('N6f9a520aa4b24736b1f07d7a1a710590'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N6f9a520aa4b24736b1f07d7a1a710590'), rdflib.term.BNode('Nbf40f6fbd5d94132b8dffc93aa81d5c5'), {})
# (rdflib.term.BNode('N1ed1bd773f3040ec9fe4c268fe8d3493'), rdflib.term.BNode('N2863a26290a5431aba2892895656b5fe'), {})
# (rdflib.term.BNode('N1ed1bd773f3040ec9fe4c268fe8d3493'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N1ed1bd773f3040ec9fe4c268fe8d3493'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), {})
# (rdflib.term.BNode('N2863a26290a5431aba2892895656b5fe'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.BNode('N2863a26290a5431aba2892895656b5fe'), rdflib.term.BNode('Nbb705e8c5a0e4f37b0b7aa4a88a88ea8'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SweetWine'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SweetWine'), rdflib.term.BNode('N9fcd0111e4cd49fd9bc08b5d8674da58'), {})
# (rdflib.term.BNode('N9cddbad0b0b44f8a81229fee03c3c585'), rdflib.term.BNode('N567c9c5654bf48be99d115ff1b83667c'), {})
# (rdflib.term.BNode('N9cddbad0b0b44f8a81229fee03c3c585'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N567c9c5654bf48be99d115ff1b83667c'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sweet'), {})
# (rdflib.term.BNode('N567c9c5654bf48be99d115ff1b83667c'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N567c9c5654bf48be99d115ff1b83667c'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), {})
# (rdflib.term.BNode('Ne83da762137d41c5bb347be9a8017c2d'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'), {})
# (rdflib.term.BNode('Ne83da762137d41c5bb347be9a8017c2d'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('Ne83da762137d41c5bb347be9a8017c2d'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasSugar'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Full'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineBody'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Full'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Thing'), {})
# (rdflib.term.BNode('N356883f170154540a4428274a5a66e8e'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N356883f170154540a4428274a5a66e8e'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), {})
# (rdflib.term.BNode('N356883f170154540a4428274a5a66e8e'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlancGrape'), {})
# (rdflib.term.BNode('N83f6377f713049e6a65e1dbe1fded976'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasFlavor'), {})
# (rdflib.term.BNode('N83f6377f713049e6a65e1dbe1fded976'), rdflib.term.BNode('N34e84ab489854a6f9749083db6a31501'), {})
# (rdflib.term.BNode('N83f6377f713049e6a65e1dbe1fded976'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasFlavor'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasFlavor'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#FunctionalProperty'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasFlavor'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineFlavor'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasFlavor'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasWineDescriptor'), {})
# (rdflib.term.BNode('N5933cfccef174cc39b738c4c9077e729'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), {})
# (rdflib.term.BNode('N5933cfccef174cc39b738c4c9077e729'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#nonNegativeInteger')), {})
# (rdflib.term.BNode('N5933cfccef174cc39b738c4c9077e729'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryRedWine'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryRedWine'), rdflib.term.BNode('N9baeb74e0b914390abf859f121b3701f'), {})
# ...
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EdnaValleyRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'), {})
# (rdflib.term.BNode('Nb158f541018e45449d4a0355cf38e347'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('Nb158f541018e45449d4a0355cf38e347'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BordeauxRegion'), {})
# (rdflib.term.BNode('Nb158f541018e45449d4a0355cf38e347'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#locatedIn'), {})
# (rdflib.term.BNode('N2da7ac5c2ce64302a13e91307bbe0d41'), rdflib.term.BNode('Na177f6918c33415692e726386b794342'), {})
# (rdflib.term.BNode('N2da7ac5c2ce64302a13e91307bbe0d41'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TableWine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Bordeaux'), rdflib.term.BNode('N9c89ecfce85342bbb60b6af65dd26246'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Bordeaux'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossVolrad'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'), {})
# (rdflib.term.BNode('N9d970c0875764fc8a1fdf801b0c1b89c'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasFlavor'), {})
# (rdflib.term.BNode('N9d970c0875764fc8a1fdf801b0c1b89c'), rdflib.term.BNode('N6567404e45f54ce0aae0f6151e2b9c2f'), {})
# (rdflib.term.BNode('N9d970c0875764fc8a1fdf801b0c1b89c'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N850e7e9ba65740cd98300e3ab63a2856'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N850e7e9ba65740cd98300e3ab63a2856'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlancGrape'), {})
# (rdflib.term.BNode('N968ba3c89b3b46d884d548efcf08d1cd'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Bordeaux'), {})
# (rdflib.term.BNode('N968ba3c89b3b46d884d548efcf08d1cd'), rdflib.term.BNode('N7f9d02fcef204966a8ef69bbd3ec3bac'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TaylorPort'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Port'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TaylorPort'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Taylor'), {})
# (rdflib.term.BNode('N5252571591424f9e8e2a8749ac24c316'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), {})
# (rdflib.term.BNode('N5252571591424f9e8e2a8749ac24c316'), rdflib.term.BNode('Ne707c9df32ed463abc58b7b206c835aa'), {})
# (rdflib.term.BNode('N17095d5ab8594f3a88708ebe429f3bf2'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N17095d5ab8594f3a88708ebe429f3bf2'), rdflib.term.BNode('N9ab61f390fd240c6993e4813d1fc7c90'), {})
# (rdflib.term.BNode('N133207d1c5ee4d92ab2288f370ceb0dc'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Light'), {})
# (rdflib.term.BNode('N133207d1c5ee4d92ab2288f370ceb0dc'), rdflib.term.BNode('N630c38b1cd954f8b83bd293d9e6ef485'), {})
# (rdflib.term.BNode('Neea2dae15ba9436da5444a5f729af184'), rdflib.term.BNode('N8066f1f3cb1e49a7aad7d8d9bab6d80f'), {})
# (rdflib.term.BNode('Neea2dae15ba9436da5444a5f729af184'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Elyse'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauterneRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauterneRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BordeauxRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EarlyHarvest'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EarlyHarvest'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EarlyHarvest'), rdflib.term.BNode('N6f9a520aa4b24736b1f07d7a1a710590'), {})
# (rdflib.term.BNode('N5a02573cc100495f8f635061d443e2a6'), rdflib.term.BNode('Nb40de0a3e5a3478dbda8926f36c50578'), {})
# (rdflib.term.BNode('N5a02573cc100495f8f635061d443e2a6'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedBurgundy'), {})
# (rdflib.term.BNode('Nb40de0a3e5a3478dbda8926f36c50578'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Nb40de0a3e5a3478dbda8926f36c50578'), rdflib.term.BNode('Nac264714e07246cfa409f558437433e8'), {})
# (rdflib.term.BNode('N613f41181b004dc2ac86e289c8c268ff'), rdflib.term.BNode('N164229f0216a47eab6a5993e967b08cd'), {})
# (rdflib.term.BNode('N613f41181b004dc2ac86e289c8c268ff'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Na8369224a43b4e109040d5b336878fce'), rdflib.term.BNode('Nef2e3bae05ba4236aeeb5c7298d0655a'), {})
# (rdflib.term.BNode('Na8369224a43b4e109040d5b336878fce'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotBlancGrape'), {})
# (rdflib.term.BNode('N76bb092440554388921402379cec21c8'), rdflib.term.BNode('N158af7f42bfc44b9afc6fbbc66eee7eb'), {})
# (rdflib.term.BNode('N76bb092440554388921402379cec21c8'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N3fa8c9f2febf45f190d2ab4723d9fd98'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#AllDifferent'), {})
# (rdflib.term.BNode('N3fa8c9f2febf45f190d2ab4723d9fd98'), rdflib.term.BNode('Nf490ccd2210b408495cd6a640f7a9381'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MendocinoRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SonomaRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MendocinoRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MendocinoRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaRegion'), {})
# (rdflib.term.BNode('Neb1c4e280372450daecb16de5ecbca08'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#AllDifferent'), {})
# (rdflib.term.BNode('Neb1c4e280372450daecb16de5ecbca08'), rdflib.term.BNode('N8630d08656f141b0a55a12585d1da5be'), {})
# (rdflib.term.BNode('Ndf761f0633bf4e18aa41aa3134f0c70d'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), {})
# (rdflib.term.BNode('Ndf761f0633bf4e18aa41aa3134f0c70d'), rdflib.term.BNode('Nc7787ffe8fe2452db74b20d7ca5e6954'), {})
# (rdflib.term.BNode('Nd5cd0dfd55c7449ab1487784396888a1'), rdflib.term.BNode('N722fc121b9224068941c2df34f661656'), {})
# (rdflib.term.BNode('Nd5cd0dfd55c7449ab1487784396888a1'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N722fc121b9224068941c2df34f661656'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#nonNegativeInteger')), {})
# (rdflib.term.BNode('N722fc121b9224068941c2df34f661656'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('N722fc121b9224068941c2df34f661656'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), {})
# (rdflib.term.BNode('N18483cbea66a4268b71e17ccc3cb0ae6'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MerlotGrape'), {})
# (rdflib.term.BNode('N18483cbea66a4268b71e17ccc3cb0ae6'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N763968c78f02473fa1bdc4de619ae421'), rdflib.term.BNode('N370cb9673dcc437980a6f8ca2c7a7deb'), {})
# (rdflib.term.BNode('N763968c78f02473fa1bdc4de619ae421'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Burgundy'), {})
# (rdflib.term.BNode('N3a42b51c854a4e42af03ca2182e3fc4f'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteWine'), {})
# (rdflib.term.BNode('N3a42b51c854a4e42af03ca2182e3fc4f'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Nd6307926dc2449f7a78650c5ef45504a'), rdflib.term.BNode('Ne4964f3567d3489e931f99804bfa785d'), {})
# (rdflib.term.BNode('Nd6307926dc2449f7a78650c5ef45504a'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasBody'), {})
# (rdflib.term.BNode('Nd6307926dc2449f7a78650c5ef45504a'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.BNode('Ne4964f3567d3489e931f99804bfa785d'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.BNode('Ne4964f3567d3489e931f99804bfa785d'), rdflib.term.BNode('Na4629eca65a947bc9a21f823aee51ad4'), {})
# (rdflib.term.BNode('Nf4c522c2437840ba8d14379df512c517'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#madeFromGrape'), {})
# (rdflib.term.BNode('Nf4c522c2437840ba8d14379df512c517'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GamayGrape'), {})
# (rdflib.term.BNode('Nf4c522c2437840ba8d14379df512c517'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Restriction'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RieslingGrape'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'), {})
# (rdflib.term.BNode('Ne670b2b8ed734ec4839d36e64404c9f6'), rdflib.term.BNode('N8a1b6fee8695422ab1eb5bf9aff1a90e'), {})
# (rdflib.term.BNode('Ne670b2b8ed734ec4839d36e64404c9f6'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AlsaceRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FrenchRegion'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AlsaceRegion'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Region'), {})
# (rdflib.term.BNode('Nf42ebbdfd96b4771a3f72aac60dda9bd'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Nf42ebbdfd96b4771a3f72aac60dda9bd'), rdflib.term.BNode('Nc788947d56a24df5b97c75f51c8c4181'), {})
# (rdflib.term.BNode('N3a1eb74f5dbf4429a35591f785acd830'), rdflib.term.BNode('Nab8f60010c4741b0bc5401a527ada7b0'), {})
# (rdflib.term.BNode('N3a1eb74f5dbf4429a35591f785acd830'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Ne2367b61fbb34b9eb9a975c1304d38a2'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.BNode('Ne2367b61fbb34b9eb9a975c1304d38a2'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Nbd4bbd176c9541a98d04b7365c62a89e'), rdflib.term.BNode('N6c5b850d118a4b1394e347351fea87ff'), {})
# (rdflib.term.BNode('Nbd4bbd176c9541a98d04b7365c62a89e'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'), {})
# (rdflib.term.BNode('N630c38b1cd954f8b83bd293d9e6ef485'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.BNode('N630c38b1cd954f8b83bd293d9e6ef485'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N6c5b850d118a4b1394e347351fea87ff'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N6c5b850d118a4b1394e347351fea87ff'), rdflib.term.BNode('N71474de88d7647619184cddc0ae6e623'), {})
# (rdflib.term.BNode('Nee746bb0e67c4cf8abf84cb6d9ba7863'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('Nee746bb0e67c4cf8abf84cb6d9ba7863'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteWine'), {})
# (rdflib.term.BNode('Nbd821fd7100340bc8e96ec48c01fa807'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Loire'), {})
# (rdflib.term.BNode('Nbd821fd7100340bc8e96ec48c01fa807'), rdflib.term.BNode('N76bb092440554388921402379cec21c8'), {})
# (rdflib.term.BNode('N68fbb21eb183434b8829ae6a3e46a62e'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Bordeaux'), {})
# (rdflib.term.BNode('N68fbb21eb183434b8829ae6a3e46a62e'), rdflib.term.BNode('Nc8e007c227f74518aa4a570364a757ee'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauLafiteRothschild'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'), {})
# (rdflib.term.BNode('N7f9d02fcef204966a8ef69bbd3ec3bac'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteWine'), {})
# (rdflib.term.BNode('N7f9d02fcef204966a8ef69bbd3ec3bac'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Beringer'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeLaPoussieSancerre'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sancerre'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeLaPoussieSancerre'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeLaPoussie'), {})
# (rdflib.term.BNode('N2b5d8f14438240bd822fbcd62b30782f'), rdflib.term.BNode('N4c7ea8ea0d0a43a08d44e3f435dc9a0c'), {})
# (rdflib.term.BNode('N2b5d8f14438240bd822fbcd62b30782f'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Loire'), {})
# (rdflib.term.BNode('N048d2f78c8df4feca5c53c466392d4e5'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'), {})
# (rdflib.term.BNode('N048d2f78c8df4feca5c53c466392d4e5'), rdflib.term.BNode('Nf5b80633875b42518e16e07dec1ea920'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RoseWine'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RoseWine'), rdflib.term.BNode('Nc6975e0ce1fc4e0da35f6e1ebd7efd90'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeLaPoussie'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMargaux'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Margaux'), {})
# (rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMargaux'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMargauxWinery'), {})
# (rdflib.term.BNode('Nf3d0e086259a4bf297bec72ba445a57b'), rdflib.term.BNode('N22c6e9110a5942818a53d260e1983d45'), {})
# (rdflib.term.BNode('Nf3d0e086259a4bf297bec72ba445a57b'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), {})
# (rdflib.term.BNode('Ncd4d8c5ca3ea49119d08843f3896c291'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium'), {})
# (rdflib.term.BNode('Ncd4d8c5ca3ea49119d08843f3896c291'), rdflib.term.BNode('N9749ce30b9f145ee9718b9816f28784d'), {})
# (rdflib.term.BNode('N34bfc57a3be74af6a89c6370a73ee967'), rdflib.term.URIRef('http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#OffDry'), {})
# (rdflib.term.BNode('N34bfc57a3be74af6a89c6370a73ee967'), rdflib.term.BNode('Nd6e88653808448a19f33813bc6666200'), {})

# %% [markdown]
# ## Test Owlready2 package

# %%
#pip install owlready2

from owlready2 import *

onto = get_ontology(path_rdf).load()

# Get all individuals (instances)
print("\n=== INDIVIDUALS ===")
for ind in onto.individuals():
    print(f"Individual: {ind.name}")
    print(f"Classes: {[c.name for c in ind.is_a]}")
    print(f"Properties: {[(p.name, getattr(ind, p.name, None)) for p in ind.get_properties()]}")
    print("---")

# Get all classes with their hierarchy
print("\n=== CLASS HIERARCHY ===")
for cls in onto.classes():
    # Get direct parent (not all ancestors)
    parents = [c.name for c in cls.is_a if isinstance(c, ThingClass)]
    print(f"Class: {cls.name}, Direct Parents: {parents}")
# Out:
# === INDIVIDUALS ===
#
# === CLASS HIERARCHY ===
# Class: Wine, Direct Parents: ['PotableLiquid']
# Class: Winery, Direct Parents: ['Thing']
# Class: Vintage, Direct Parents: ['Thing']
# Class: WineGrape, Direct Parents: ['Grape']
# Class: WhiteWine, Direct Parents: ['Thing']
# Class: WhiteTableWine, Direct Parents: ['Thing']
# Class: TableWine, Direct Parents: ['Thing']
# Class: WhiteNonSweetWine, Direct Parents: ['Thing']
# Class: WhiteLoire, Direct Parents: ['Thing']
# Class: Loire, Direct Parents: ['Thing']
# Class: WhiteBurgundy, Direct Parents: ['Thing']
# Class: Burgundy, Direct Parents: ['Thing']
# Class: WhiteBordeaux, Direct Parents: ['Thing']
# Class: Bordeaux, Direct Parents: ['Thing']
# Class: Region, Direct Parents: ['Thing']
# Class: VintageYear, Direct Parents: ['Thing']
# Class: WineDescriptor, Direct Parents: ['Thing']
# Class: WineSugar, Direct Parents: ['WineTaste']
# Class: WineBody, Direct Parents: ['WineTaste']
# Class: WineFlavor, Direct Parents: ['WineTaste']
# Class: WineColor, Direct Parents: ['WineDescriptor']
# Class: Zinfandel, Direct Parents: ['Thing']
# Class: WineTaste, Direct Parents: ['WineDescriptor']
# Class: Tours, Direct Parents: ['Thing']
# Class: SweetWine, Direct Parents: ['Thing']
# Class: SweetRiesling, Direct Parents: ['DessertWine']
# Class: DessertWine, Direct Parents: ['Wine']
# Class: Riesling, Direct Parents: ['Thing']
# Class: StEmilion, Direct Parents: ['Thing']
# Class: SemillonOrSauvignonBlanc, Direct Parents: ['Thing']
# Class: Semillon, Direct Parents: ['Thing']
# Class: SauvignonBlanc, Direct Parents: ['Thing']
# Class: Sauternes, Direct Parents: ['LateHarvest', 'Bordeaux']
# Class: LateHarvest, Direct Parents: ['Wine']
# Class: Sancerre, Direct Parents: ['Thing']
# Class: RoseWine, Direct Parents: ['Thing']
# Class: RedWine, Direct Parents: ['Thing']
# Class: RedTableWine, Direct Parents: ['Thing']
# Class: RedBurgundy, Direct Parents: ['Thing']
# Class: RedBordeaux, Direct Parents: ['Thing']
# Class: Port, Direct Parents: ['RedWine']
# Class: PinotNoir, Direct Parents: ['Thing']
# Class: PinotBlanc, Direct Parents: ['Thing']
# Class: PetiteSyrah, Direct Parents: ['Thing']
# Class: Pauillac, Direct Parents: ['Thing']
# Class: Medoc, Direct Parents: ['Thing']
# Class: Muscadet, Direct Parents: ['Thing']
# Class: Meursault, Direct Parents: ['Thing']
# Class: Merlot, Direct Parents: ['Thing']
# Class: Meritage, Direct Parents: ['Thing']
# Class: Margaux, Direct Parents: ['Thing']
# Class: EarlyHarvest, Direct Parents: ['Wine']
# Class: ItalianWine, Direct Parents: ['Thing']
# Class: IceWine, Direct Parents: ['Thing']
# Class: GermanWine, Direct Parents: ['Thing']
# Class: Gamay, Direct Parents: ['Thing']
# Class: FullBodiedWine, Direct Parents: ['Thing']
# Class: FrenchWine, Direct Parents: ['Thing']
# Class: DryWine, Direct Parents: ['Thing']
# Class: DryWhiteWine, Direct Parents: ['Thing']
# Class: DryRiesling, Direct Parents: ['Thing']
# Class: DryRedWine, Direct Parents: ['Thing']
# Class: CotesDOr, Direct Parents: ['Thing']
# Class: Chianti, Direct Parents: ['ItalianWine']
# Class: CheninBlanc, Direct Parents: ['Thing']
# Class: Chardonnay, Direct Parents: ['Thing']
# Class: CaliforniaWine, Direct Parents: ['Thing']
# Class: TexasWine, Direct Parents: ['Thing']
# Class: CabernetSauvignon, Direct Parents: ['Thing']
# Class: CabernetFranc, Direct Parents: ['Thing']
# Class: Beaujolais, Direct Parents: ['Thing']
# Class: Anjou, Direct Parents: ['Thing']
# Class: AmericanWine, Direct Parents: ['Thing']
# Class: AlsatianWine, Direct Parents: ['Thing']

# %%
def owlready_to_cypher(rdf_file, include_blank_nodes=False):
    from owlready2 import get_ontology, ThingClass, Thing, ObjectProperty, DataProperty, sync_reasoner_pellet
    
    onto = get_ontology(f"file://{rdf_file}").load()
    
    # Run reasoner
    try:
        with onto:
            sync_reasoner_pellet(infer_property_values=True, infer_data_property_values=True)
        print("Reasoner completed successfully")
    except Exception as e:
        print(f"Reasoner failed: {e}, continuing without reasoning")
    
    node_parts = []
    edge_parts = []
    node_counter = 0
    node_to_var = {}
    
    def get_var(uri):
        nonlocal node_counter
        if uri not in node_to_var:
            node_to_var[uri] = f"n{node_counter}"
            node_counter += 1
        return node_to_var[uri]
    
    def get_most_generic_parent(cls):
        """Get the most generic non-Thing parent"""
        ancestors = [a for a in cls.ancestors() 
                    if isinstance(a, ThingClass) 
                    and a.name != 'Thing'
                    and a != cls]
        return ancestors[-1] if ancestors else cls
    
    # First pass: collect all nodes that will be created
    valid_nodes = set()
    
    # Add all classes
    for cls in onto.classes():
        if cls.name != 'Thing':
            valid_nodes.add(cls.iri)
    
    # Add all properties
    for prop in onto.properties():
        valid_nodes.add(prop.iri)
    
    # Add all individuals
    for ind in onto.individuals():
        valid_nodes.add(ind.iri)
    
    # Create nodes for all classes
    for cls in onto.classes():
        if cls.name == 'Thing':
            continue
        
        var = get_var(cls.iri)
        root = get_most_generic_parent(cls)
        label = sanitize_identifier(root.name)
        name = cls.name
        
        # Build properties
        props = [
            f"uri: '{sanitize_value(cls.iri)}'",
            f"name: '{sanitize_value(name)}'",
            f"type: 'Class'"
        ]
        
        # Add direct parent names (only those in valid_nodes)
        direct_parents = [p.name for p in cls.is_a 
                         if isinstance(p, ThingClass) 
                         and p.name != 'Thing'
                         and p.iri in valid_nodes]
        if direct_parents:
            props.append(f"parents: '{sanitize_value(", ".join(direct_parents))}'")
        
        # Add comment if exists
        if hasattr(cls, 'comment') and cls.comment:
            comment = cls.comment[0] if isinstance(cls.comment, list) else cls.comment
            props.append(f"comment: '{sanitize_value(str(comment))}'")
        
        # Add label if exists
        if hasattr(cls, 'label') and cls.label:
            lbl = cls.label[0] if isinstance(cls.label, list) else cls.label
            props.append(f"rdfs_label: '{sanitize_value(str(lbl))}'")
        
        node_parts.append(f"({var}:{label} {{{', '.join(props)}}})")
    
    # Track added edges to avoid duplicates
    added_edges = set()
    
    # Create subClassOf relationships (only for valid nodes)
    for cls in onto.classes():
        if cls.name == 'Thing':
            continue
        
        s_var = get_var(cls.iri)
        
        for parent in cls.is_a:
            if isinstance(parent, ThingClass) and parent.name != 'Thing' and parent.iri in valid_nodes:
                o_var = get_var(parent.iri)
                edge = f"({s_var})-[:subClassOf]->({o_var})"
                if edge not in added_edges:
                    edge_parts.append(edge)
                    added_edges.add(edge)
    
    # Create nodes for properties
    for prop in onto.properties():
        prop_var = get_var(prop.iri)
        prop_type = "ObjectProperty" if isinstance(prop, ObjectProperty) else "DataProperty"
        
        props_list = [
            f"uri: '{sanitize_value(prop.iri)}'",
            f"name: '{sanitize_value(prop.name)}'",
            f"type: 'Property'",
            f"property_type: '{prop_type}'"
        ]
        
        node_parts.append(f"({prop_var}:Property {{{', '.join(props_list)}}})")
        
        # Add domain relationships (only for valid nodes)
        if hasattr(prop, 'domain') and prop.domain:
            domains = prop.domain if isinstance(prop.domain, list) else [prop.domain]
            for domain in domains:
                if isinstance(domain, ThingClass) and domain.name != 'Thing' and domain.iri in valid_nodes:
                    domain_var = get_var(domain.iri)
                    edge = f"({domain_var})-[:hasDomain]->({prop_var})"
                    if edge not in added_edges:
                        edge_parts.append(edge)
                        added_edges.add(edge)
        
        # Add range relationships (only for valid nodes)
        if hasattr(prop, 'range') and prop.range:
            ranges = prop.range if isinstance(prop.range, list) else [prop.range]
            for rng in ranges:
                if isinstance(rng, ThingClass) and rng.name != 'Thing' and rng.iri in valid_nodes:
                    range_var = get_var(rng.iri)
                    edge = f"({prop_var})-[:hasRange]->({range_var})"
                    if edge not in added_edges:
                        edge_parts.append(edge)
                        added_edges.add(edge)
    
    # Handle individuals (only for valid nodes)
    for ind in onto.individuals():
        s_var = get_var(ind.iri)
        
        for prop in ind.get_properties():
            values = getattr(ind, prop.name, [])
            if not isinstance(values, list):
                values = [values]
            
            for value in values:
                if isinstance(value, Thing) and value.iri in valid_nodes:
                    o_var = get_var(value.iri)
                    pred = sanitize_identifier(prop.name)
                    edge = f"({s_var})-[:{pred}]->({o_var})"
                    if edge not in added_edges:
                        edge_parts.append(edge)
                        added_edges.add(edge)
    
    # Combine nodes first, then edges
    return "CREATE " + ",\n".join(node_parts + edge_parts)

# %%
# %%time

graph_CREATE_command_owlready = owlready_to_cypher(path_rdf, include_blank_nodes=True)
print(graph_CREATE_command_owlready)

# Save Cypher query to file
with open(f"{path_data}/{example_name}_owlready.cypher", "w") as f:
    f.write(graph_CREATE_command_owlready)
# Out:
# * Owlready2 * Running Pellet...
#     java -Xmx2000M -cp /home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/antlr-3.2.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/jena-core-2.10.0.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/owlapi-distribution-3.4.3-bin.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/xercesImpl-2.10.0.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/xml-apis-1.4.01.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/jena-arq-2.10.0.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/slf4j-log4j12-1.6.4.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/jgrapht-jdk1.5.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/log4j-core-2.19.0.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/aterm-java-1.6.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/log4j-1.2-api-2.19.0.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/httpcore-4.2.2.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/jena-tdb-0.10.0.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/log4j-api-2.19.0.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/slf4j-api-1.6.4.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/httpclient-4.2.3.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/jena-iri-0.9.5.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/jcl-over-slf4j-1.6.4.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/antlr-runtime-3.2.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/pellet-2.3.1.jar:/home/dev/turingdb-examples/.venv/lib/python3.13/site-packages/owlready2/pellet/commons-codec-1.6.jar pellet.Pellet realize --loader Jena --input-format N-Triples --infer-prop-values --infer-data-prop-values --ignore-imports /tmp/tmp32yj4y5n
# Reasoner completed successfully
# CREATE (n0:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Wine', name: 'Wine', type: 'Class', rdfs_label: 'wine'}),
# (n1:Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Winery', name: 'Winery', type: 'Class'}),
# (n2:Vintage {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Vintage', name: 'Vintage', type: 'Class'}),
# (n3:Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WineGrape', name: 'WineGrape', type: 'Class'}),
# (n4:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WhiteWine', name: 'WhiteWine', type: 'Class', parents: 'Wine'}),
# (n5:WhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WhiteTableWine', name: 'WhiteTableWine', type: 'Class', parents: 'TableWine, WhiteNonSweetWine, DryWine'}),
# (n6:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##TableWine', name: 'TableWine', type: 'Class', parents: 'Wine'}),
# (n7:WhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WhiteNonSweetWine', name: 'WhiteNonSweetWine', type: 'Class', parents: 'WhiteWine'}),
# (n8:Loire {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WhiteLoire', name: 'WhiteLoire', type: 'Class', parents: 'WhiteWine, Loire'}),
# (n9:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Loire', name: 'Loire', type: 'Class', parents: 'Wine'}),
# (n10:DryWhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WhiteBurgundy', name: 'WhiteBurgundy', type: 'Class', parents: 'Chardonnay, DryWhiteWine, Burgundy, WhiteTableWine'}),
# (n11:DryWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Burgundy', name: 'Burgundy', type: 'Class', parents: 'TableWine, DryWine'}),
# (n12:SemillonOrSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WhiteBordeaux', name: 'WhiteBordeaux', type: 'Class', parents: 'SemillonOrSauvignonBlanc, Bordeaux'}),
# (n13:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Bordeaux', name: 'Bordeaux', type: 'Class', parents: 'Wine'}),
# (n14:Region {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Region', name: 'Region', type: 'Class'}),
# (n15:VintageYear {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##VintageYear', name: 'VintageYear', type: 'Class'}),
# (n16:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WineDescriptor', name: 'WineDescriptor', type: 'Class', comment: 'Made WineDescriptor unionType of tastes and color'}),
# (n17:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WineSugar', name: 'WineSugar', type: 'Class', parents: 'WineTaste'}),
# (n18:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WineBody', name: 'WineBody', type: 'Class', parents: 'WineTaste'}),
# (n19:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WineFlavor', name: 'WineFlavor', type: 'Class', parents: 'WineTaste'}),
# (n20:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WineColor', name: 'WineColor', type: 'Class', parents: 'WineDescriptor'}),
# (n21:DryWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Zinfandel', name: 'Zinfandel', type: 'Class', parents: 'DryRedWine, RedTableWine'}),
# (n22:WineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##WineTaste', name: 'WineTaste', type: 'Class', parents: 'WineDescriptor'}),
# (n23:WhiteNonSweetWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Tours', name: 'Tours', type: 'Class', parents: 'CheninBlanc, WhiteLoire'}),
# (n24:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##SweetWine', name: 'SweetWine', type: 'Class', parents: 'Wine'}),
# (n25:DessertWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##SweetRiesling', name: 'SweetRiesling', type: 'Class', parents: 'DessertWine, Riesling, SweetWine, FullBodiedWine'}),
# (n26:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##DessertWine', name: 'DessertWine', type: 'Class', parents: 'Wine'}),
# (n27:WhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Riesling', name: 'Riesling', type: 'Class', parents: 'WhiteWine'}),
# (n28:RedBordeaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##StEmilion', name: 'StEmilion', type: 'Class', parents: 'RedBordeaux, CabernetSauvignon'}),
# (n29:WhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##SemillonOrSauvignonBlanc', name: 'SemillonOrSauvignonBlanc', type: 'Class', parents: 'WhiteWine'}),
# (n30:SemillonOrSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Semillon', name: 'Semillon', type: 'Class', parents: 'SemillonOrSauvignonBlanc'}),
# (n31:SemillonOrSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##SauvignonBlanc', name: 'SauvignonBlanc', type: 'Class', parents: 'SemillonOrSauvignonBlanc'}),
# (n32:LateHarvest {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Sauternes', name: 'Sauternes', type: 'Class', parents: 'LateHarvest, WhiteBordeaux'}),
# (n33:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##LateHarvest', name: 'LateHarvest', type: 'Class', parents: 'SweetWine'}),
# (n34:Loire {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Sancerre', name: 'Sancerre', type: 'Class', parents: 'SauvignonBlanc, WhiteLoire, WhiteNonSweetWine'}),
# (n35:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##RoseWine', name: 'RoseWine', type: 'Class', parents: 'Wine'}),
# (n36:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##RedWine', name: 'RedWine', type: 'Class', parents: 'Wine'}),
# (n37:DryWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##RedTableWine', name: 'RedTableWine', type: 'Class', parents: 'TableWine, RedWine, DryWine'}),
# (n38:DryWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##RedBurgundy', name: 'RedBurgundy', type: 'Class', parents: 'PinotNoir, DryRedWine, RedTableWine, Burgundy'}),
# (n39:RedWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##RedBordeaux', name: 'RedBordeaux', type: 'Class', parents: 'Bordeaux, RedWine'}),
# (n40:RedWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Port', name: 'Port', type: 'Class', parents: 'RedWine, FullBodiedWine, SweetWine'}),
# (n41:RedWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##PinotNoir', name: 'PinotNoir', type: 'Class', parents: 'RedWine'}),
# (n42:WhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##PinotBlanc', name: 'PinotBlanc', type: 'Class', parents: 'WhiteWine'}),
# (n43:DryWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##PetiteSyrah', name: 'PetiteSyrah', type: 'Class', parents: 'DryRedWine, RedTableWine'}),
# (n44:RedBordeaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Pauillac', name: 'Pauillac', type: 'Class', parents: 'Medoc, FullBodiedWine, CabernetSauvignon'}),
# (n45:RedBordeaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Medoc', name: 'Medoc', type: 'Class', parents: 'DryRedWine, RedBordeaux, RedTableWine'}),
# (n46:Loire {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Muscadet', name: 'Muscadet', type: 'Class', parents: 'DryWhiteWine, WhiteLoire, PinotBlanc, WhiteTableWine'}),
# (n47:DryWhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Meursault', name: 'Meursault', type: 'Class', parents: 'WhiteBurgundy, FullBodiedWine'}),
# (n48:DryWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Merlot', name: 'Merlot', type: 'Class', parents: 'DryRedWine, RedTableWine'}),
# (n49:RedWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Meritage', name: 'Meritage', type: 'Class', parents: 'RedWine'}),
# (n50:RedBordeaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Margaux', name: 'Margaux', type: 'Class', parents: 'Medoc, Merlot'}),
# (n51:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##EarlyHarvest', name: 'EarlyHarvest', type: 'Class', parents: 'Wine'}),
# (n52:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##ItalianWine', name: 'ItalianWine', type: 'Class', parents: 'Wine'}),
# (n53:LateHarvest {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##IceWine', name: 'IceWine', type: 'Class', parents: 'WhiteWine, DessertWine, LateHarvest'}),
# (n54:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##GermanWine', name: 'GermanWine', type: 'Class', parents: 'Wine'}),
# (n55:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Gamay', name: 'Gamay', type: 'Class', parents: 'Wine'}),
# (n56:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##FullBodiedWine', name: 'FullBodiedWine', type: 'Class', parents: 'Wine'}),
# (n57:Wine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##FrenchWine', name: 'FrenchWine', type: 'Class', parents: 'Wine'}),
# (n58:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##DryWine', name: 'DryWine', type: 'Class', parents: 'Wine'}),
# (n59:WhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##DryWhiteWine', name: 'DryWhiteWine', type: 'Class', parents: 'TableWine, WhiteNonSweetWine, DryWine'}),
# (n60:DryWhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##DryRiesling', name: 'DryRiesling', type: 'Class', parents: 'Riesling, DryWhiteWine, WhiteTableWine'}),
# (n61:DryWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##DryRedWine', name: 'DryRedWine', type: 'Class', parents: 'TableWine, RedWine, DryWine'}),
# (n62:RedBurgundy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##CotesDOr', name: 'CotesDOr', type: 'Class', parents: 'RedBurgundy'}),
# (n63:DryWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Chianti', name: 'Chianti', type: 'Class', parents: 'ItalianWine, DryRedWine, RedTableWine'}),
# (n64:WhiteNonSweetWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##CheninBlanc', name: 'CheninBlanc', type: 'Class', parents: 'WhiteNonSweetWine'}),
# (n65:WhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Chardonnay', name: 'Chardonnay', type: 'Class', parents: 'WhiteWine'}),
# (n66:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##CaliforniaWine', name: 'CaliforniaWine', type: 'Class', parents: 'Wine'}),
# (n67:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##TexasWine', name: 'TexasWine', type: 'Class', parents: 'Wine'}),
# (n68:DryWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##CabernetSauvignon', name: 'CabernetSauvignon', type: 'Class', parents: 'DryRedWine, RedTableWine'}),
# (n69:DryWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##CabernetFranc', name: 'CabernetFranc', type: 'Class', parents: 'DryRedWine, RedTableWine'}),
# (n70:DryWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Beaujolais', name: 'Beaujolais', type: 'Class', parents: 'DryRedWine, Gamay, RedTableWine'}),
# (n71:RoseWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##Anjou', name: 'Anjou', type: 'Class', parents: 'Loire, RoseWine'}),
# (n72:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##AmericanWine', name: 'AmericanWine', type: 'Class', parents: 'Wine'}),
# (n73:PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##AlsatianWine', name: 'AlsatianWine', type: 'Class', parents: 'Wine'}),
# (n74:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##yearValue', name: 'yearValue', type: 'Property', property_type: 'DataProperty'}),
# (n75:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##hasMaker', name: 'hasMaker', type: 'Property', property_type: 'DataProperty'}),
# (n76:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##madeFromGrape', name: 'madeFromGrape', type: 'Property', property_type: 'DataProperty'}),
# (n77:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##hasSugar', name: 'hasSugar', type: 'Property', property_type: 'DataProperty'}),
# (n78:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##hasFlavor', name: 'hasFlavor', type: 'Property', property_type: 'DataProperty'}),
# (n79:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##hasBody', name: 'hasBody', type: 'Property', property_type: 'DataProperty'}),
# (n80:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##hasColor', name: 'hasColor', type: 'Property', property_type: 'DataProperty'}),
# (n81:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##locatedIn', name: 'locatedIn', type: 'Property', property_type: 'DataProperty'}),
# (n82:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##hasVintageYear', name: 'hasVintageYear', type: 'Property', property_type: 'DataProperty'}),
# (n83:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##adjacentRegion', name: 'adjacentRegion', type: 'Property', property_type: 'DataProperty'}),
# (n84:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##madeIntoWine', name: 'madeIntoWine', type: 'Property', property_type: 'DataProperty'}),
# (n85:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##hasWineDescriptor', name: 'hasWineDescriptor', type: 'Property', property_type: 'DataProperty'}),
# (n86:Property {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine##producesWine', name: 'producesWine', type: 'Property', property_type: 'DataProperty'}),
# (n4)-[:subClassOf]->(n0),
# (n5)-[:subClassOf]->(n6),
# (n5)-[:subClassOf]->(n7),
# (n5)-[:subClassOf]->(n58),
# (n6)-[:subClassOf]->(n0),
# (n7)-[:subClassOf]->(n4),
# (n8)-[:subClassOf]->(n4),
# (n8)-[:subClassOf]->(n9),
# (n9)-[:subClassOf]->(n0),
# (n10)-[:subClassOf]->(n65),
# (n10)-[:subClassOf]->(n59),
# (n10)-[:subClassOf]->(n11),
# (n10)-[:subClassOf]->(n5),
# (n11)-[:subClassOf]->(n6),
# (n11)-[:subClassOf]->(n58),
# (n12)-[:subClassOf]->(n29),
# (n12)-[:subClassOf]->(n13),
# (n13)-[:subClassOf]->(n0),
# (n17)-[:subClassOf]->(n22),
# (n18)-[:subClassOf]->(n22),
# (n19)-[:subClassOf]->(n22),
# (n20)-[:subClassOf]->(n16),
# (n21)-[:subClassOf]->(n61),
# (n21)-[:subClassOf]->(n37),
# (n22)-[:subClassOf]->(n16),
# (n23)-[:subClassOf]->(n64),
# (n23)-[:subClassOf]->(n8),
# (n24)-[:subClassOf]->(n0),
# (n25)-[:subClassOf]->(n26),
# (n25)-[:subClassOf]->(n27),
# (n25)-[:subClassOf]->(n24),
# (n25)-[:subClassOf]->(n56),
# (n26)-[:subClassOf]->(n0),
# (n27)-[:subClassOf]->(n4),
# (n28)-[:subClassOf]->(n39),
# (n28)-[:subClassOf]->(n68),
# (n29)-[:subClassOf]->(n4),
# (n30)-[:subClassOf]->(n29),
# (n31)-[:subClassOf]->(n29),
# (n32)-[:subClassOf]->(n33),
# (n32)-[:subClassOf]->(n12),
# (n33)-[:subClassOf]->(n24),
# (n34)-[:subClassOf]->(n31),
# (n34)-[:subClassOf]->(n8),
# (n34)-[:subClassOf]->(n7),
# (n35)-[:subClassOf]->(n0),
# (n36)-[:subClassOf]->(n0),
# (n37)-[:subClassOf]->(n6),
# (n37)-[:subClassOf]->(n36),
# (n37)-[:subClassOf]->(n58),
# (n38)-[:subClassOf]->(n41),
# (n38)-[:subClassOf]->(n61),
# (n38)-[:subClassOf]->(n37),
# (n38)-[:subClassOf]->(n11),
# (n39)-[:subClassOf]->(n13),
# (n39)-[:subClassOf]->(n36),
# (n40)-[:subClassOf]->(n36),
# (n40)-[:subClassOf]->(n56),
# (n40)-[:subClassOf]->(n24),
# (n41)-[:subClassOf]->(n36),
# (n42)-[:subClassOf]->(n4),
# (n43)-[:subClassOf]->(n61),
# (n43)-[:subClassOf]->(n37),
# (n44)-[:subClassOf]->(n45),
# (n44)-[:subClassOf]->(n56),
# (n44)-[:subClassOf]->(n68),
# (n45)-[:subClassOf]->(n61),
# (n45)-[:subClassOf]->(n39),
# (n45)-[:subClassOf]->(n37),
# (n46)-[:subClassOf]->(n59),
# (n46)-[:subClassOf]->(n8),
# (n46)-[:subClassOf]->(n42),
# (n46)-[:subClassOf]->(n5),
# (n47)-[:subClassOf]->(n10),
# (n47)-[:subClassOf]->(n56),
# (n48)-[:subClassOf]->(n61),
# (n48)-[:subClassOf]->(n37),
# (n49)-[:subClassOf]->(n36),
# (n50)-[:subClassOf]->(n45),
# (n50)-[:subClassOf]->(n48),
# (n51)-[:subClassOf]->(n0),
# (n52)-[:subClassOf]->(n0),
# (n53)-[:subClassOf]->(n4),
# (n53)-[:subClassOf]->(n26),
# (n53)-[:subClassOf]->(n33),
# (n54)-[:subClassOf]->(n0),
# (n55)-[:subClassOf]->(n0),
# (n56)-[:subClassOf]->(n0),
# (n57)-[:subClassOf]->(n0),
# (n58)-[:subClassOf]->(n0),
# (n59)-[:subClassOf]->(n6),
# (n59)-[:subClassOf]->(n7),
# (n59)-[:subClassOf]->(n58),
# (n60)-[:subClassOf]->(n27),
# (n60)-[:subClassOf]->(n59),
# (n60)-[:subClassOf]->(n5),
# (n61)-[:subClassOf]->(n6),
# (n61)-[:subClassOf]->(n36),
# (n61)-[:subClassOf]->(n58),
# (n62)-[:subClassOf]->(n38),
# (n63)-[:subClassOf]->(n52),
# (n63)-[:subClassOf]->(n61),
# (n63)-[:subClassOf]->(n37),
# (n64)-[:subClassOf]->(n7),
# (n65)-[:subClassOf]->(n4),
# (n66)-[:subClassOf]->(n0),
# (n67)-[:subClassOf]->(n0),
# (n68)-[:subClassOf]->(n61),
# (n68)-[:subClassOf]->(n37),
# (n69)-[:subClassOf]->(n61),
# (n69)-[:subClassOf]->(n37),
# (n70)-[:subClassOf]->(n61),
# (n70)-[:subClassOf]->(n55),
# (n70)-[:subClassOf]->(n37),
# (n71)-[:subClassOf]->(n9),
# (n71)-[:subClassOf]->(n35),
# (n72)-[:subClassOf]->(n0),
# (n73)-[:subClassOf]->(n0),
# (n15)-[:hasDomain]->(n74),
# (n0)-[:hasDomain]->(n76),
# (n76)-[:hasRange]->(n3),
# (n77)-[:hasRange]->(n17),
# (n78)-[:hasRange]->(n19),
# (n79)-[:hasRange]->(n18),
# (n0)-[:hasDomain]->(n80),
# (n80)-[:hasRange]->(n20),
# (n81)-[:hasRange]->(n14),
# (n2)-[:hasDomain]->(n82),
# (n82)-[:hasRange]->(n15),
# (n14)-[:hasDomain]->(n83),
# (n83)-[:hasRange]->(n14),
# (n0)-[:hasDomain]->(n85),
# (n85)-[:hasRange]->(n16)
# CPU times: user 40.7 ms, sys: 5.01 ms, total: 45.7 ms
# Wall time: 1.21 s
# * Owlready2 * Pellet took 1.1736650466918945 seconds
# * Owlready * Equivalenting: wine#.DryRedWine wine#.RedTableWine
# * Owlready * Equivalenting: wine#.DryRedWine wine#.RedTableWine
# * Owlready * Equivalenting: wine#.RedTableWine wine#.DryRedWine
# * Owlready * Equivalenting: wine#.RedTableWine wine#.DryRedWine
# * Owlready * Equivalenting: wine#.DryWine wine#.TableWine
# * Owlready * Equivalenting: wine#.TableWine wine#.DryWine
# * Owlready * Equivalenting: wine#.DryWhiteWine wine#.WhiteTableWine
# * Owlready * Equivalenting: wine#.DryWhiteWine wine#.WhiteTableWine
# * Owlready * Equivalenting: wine#.WhiteTableWine wine#.DryWhiteWine
# * Owlready * Equivalenting: wine#.WhiteTableWine wine#.DryWhiteWine
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %% [markdown]
# # Create graph using `turingdb` python package

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         See <a href="https://docs.turingdb.ai/quickstart">TuringDB Get started documentation</a> for the important steps to follow :
#     </h2>
#     <h3>
#         <ul>
#             <li>Create your TuringDB account</li>
#             <li>Create your instance in the <a href="https://console.turingdb.ai/auth">TuringDB Cloud UI</a></li>
#             <li>Copy your Instance ID from the Database Instances management page</li>
#             <li>Get API Key from the Settings in UI</li>
#         </ul>
#         Remember to have your instance active while working in this notebook !
#     </h3>
# </div>

# %%
from turingdb import TuringDB

# Create TuringDB client
client = TuringDB(
    host="http://localhost:6666"  # Remove this parameter and set the two parameters below
    # instance_id=os.getenv("INSTANCE_ID"),
    # auth_token=os.getenv("AUTH_TOKEN"),
)

# %%
# %%time

client.s3_connect(
    bucket_name="turing-internal",
    region="eu-west-2",
    access_key=os.getenv("AWS_ACCESS_KEY"),
    secret_key=os.getenv("AWS_SECRET_KEY"),
)
# Out:
# CPU times: user 86.3 ms, sys: 41.4 ms, total: 128 ms
# Wall time: 199 ms

# %%
# Get list of loaded graphs
list_graphs = client.list_loaded_graphs()
list_graphs
# Out:
# ['wine_ontology5',
#  'wine_ontology3',
#  'wine_ontology2',
#  'wine_ontology1',
#  'wine_ontology4',
#  'people',
#  'default']

# %%
# Set graph name
graph_name_prefix = example_name
graph_name_nb_suffix = str(
    max(
        [
            int(re.sub(graph_name_prefix, "", g))
            for g in list_graphs
            if g.startswith(graph_name_prefix)
            and re.sub(graph_name_prefix, "", g).isdigit()
        ]
        + [0]
    )
    + 1
)
graph_name = graph_name_prefix + graph_name_nb_suffix
graph_name = re.sub("-", "_", graph_name)
print(f"graph_name: {graph_name}")
# Out:
# graph_name: wine_ontology6

# %%
from turingdb.exceptions import TuringDBException

# %%
# %%time

# Set graph
try:
    client.create_graph(graph_name)
except TuringDBException as e:
    print(e)

# Set working graph
client.set_graph(graph_name)
# Out:
# CPU times: user 3.07 ms, sys: 1.02 ms, total: 4.08 ms
# Wall time: 19.3 ms

# %%
# %%time

# Create a new change on the graph
client.checkout()
change = client.new_change()
print(f"Current change {change}")

# Checkout into the change
client.checkout(change=change)
# Out:
# Current change 0
# CPU times: user 2.3 ms, sys: 1.05 ms, total: 3.34 ms
# Wall time: 2.69 ms

# %%
# Sanitise query for v1
def sanitise_for_v1(query):
    query = query.replace("->", "-")
    
    return query

graph_CREATE_command_owlready = sanitise_for_v1(graph_CREATE_command_owlready)
#print(graph_CREATE_command_owlready)

# %%
# %%time

# Run CREATE command
print("\nExecuting query on TuringDB...")
start_time = time.time()
result = client.query(graph_CREATE_command_owlready)
execution_time = time.time() - start_time
print(f"✓ Graph created successfully in {execution_time:.2f} seconds")

# Commit the change
client.query("COMMIT")
client.query("CHANGE SUBMIT")

# Checkout into main
client.checkout()
# Out:
# Executing query on TuringDB...
# ✓ Graph created successfully in 0.01 seconds
# CPU times: user 6.98 ms, sys: 0 ns, total: 6.98 ms
# Wall time: 103 ms

# %% [markdown]
# # Query TuringDB

# %% [markdown]
# ## Use metaqueries to have insight on graph overall structure
#
# <h3>
#     To learn more about 📮 Metaqueries, please check TuringDB documentation on this <a href="https://turingdb.mintlify.app/query/cypher_subset#%F0%9F%93%AE-metaqueries">link</a>
# </h3>

# %%
# %%time

# CALL PROPERTIES() - returns a column of all the different node and edge properties and their types in the database
command = """
CALL PROPERTIES()
"""
df_PROPERTIES = client.query(command)
if df_PROPERTIES.empty:
    print("No result found")
else:
    df_PROPERTIES.columns = ["Property_ID", "Property_name", "Property_type"]
    display(df_PROPERTIES)
# Out:
#    Property_ID  Property_name Property_type
# 0            0            uri        String
# 1            1           name        String
# 2            2           type        String
# 3            3     rdfs_label        String
# 4            4        parents        String
# 5            5        comment        String
# 6            6  property_type        String
# CPU times: user 7.81 ms, sys: 3.13 ms, total: 10.9 ms
# Wall time: 9.09 ms

# %%
# Get node properties
nodes_properties = df_PROPERTIES["Property_name"].values.tolist()
print(f"Node properties: {nodes_properties}")
# Out:
# Node properties: ['uri', 'name', 'type', 'rdfs_label', 'parents', 'comment', 'property_type']

# %%
# %%time

# CALL LABELS () - returns a column of all the different node labels
command = """
CALL LABELS()
"""
df_LABELS = client.query(command)
if df_LABELS.empty:
    print("No result found")
else:
    df_LABELS.columns = ["Node_type_ID", "Node_label"]
    display(df_LABELS)
# Out:
#     Node_type_ID                Node_label
# 0              0             PotableLiquid
# 1              1                    Winery
# 2              2                   Vintage
# 3              3                     Grape
# 4              4                 WhiteWine
# 5              5                     Loire
# 6              6              DryWhiteWine
# 7              7                   DryWine
# 8              8  SemillonOrSauvignonBlanc
# 9              9                    Region
# 10            10               VintageYear
# 11            11            WineDescriptor
# 12            12         WhiteNonSweetWine
# 13            13               DessertWine
# 14            14               RedBordeaux
# 15            15               LateHarvest
# 16            16                   RedWine
# 17            17                      Wine
# 18            18               RedBurgundy
# 19            19                  RoseWine
# 20            20                  Property
# CPU times: user 7.1 ms, sys: 1.91 ms, total: 9.01 ms
# Wall time: 7.73 ms

# %%
# %%time

# CALL EDGETYPES() - returns a column of all the different edge types (edge equivalent of node labels)
command = """
CALL EDGETYPES()
"""
df_EDGETYPES = client.query(command)
if df_EDGETYPES.empty:
    print("No result found")
else:
    df_EDGETYPES.columns = ["Edge_type_ID", "Edge_label"]
    display(df_EDGETYPES)
# Out:
#    Edge_type_ID  Edge_label
# 0             0  subClassOf
# 1             1   hasDomain
# 2             2    hasRange
# CPU times: user 7.25 ms, sys: 1.03 ms, total: 8.28 ms
# Wall time: 6.92 ms

# %%
# %%time

# CALL LABELSETS() - returns a two columns describing combinations of node labels
command = """
CALL LABELSETS()
"""
df_LABELSETS = client.query(command)
if df_LABELSETS.empty:
    print("No result found")
else:
    df_LABELSETS.columns = ["Node_type_ID", "Node_label"]
    display(df_LABELSETS)
# Out:
#     Node_type_ID                Node_label
# 0              0             PotableLiquid
# 1              1                    Winery
# 2              2                   Vintage
# 3              3                     Grape
# 4              4                 WhiteWine
# 5              5                     Loire
# 6              6              DryWhiteWine
# 7              7                   DryWine
# 8              8  SemillonOrSauvignonBlanc
# 9              9                    Region
# 10            10               VintageYear
# 11            11            WineDescriptor
# 12            12         WhiteNonSweetWine
# 13            13               DessertWine
# 14            14               RedBordeaux
# 15            15               LateHarvest
# 16            16                   RedWine
# 17            17                      Wine
# 18            18               RedBurgundy
# 19            19                  RoseWine
# 20            20                  Property
# CPU times: user 6.8 ms, sys: 1.87 ms, total: 8.67 ms
# Wall time: 7.59 ms

# %%
# %%time

# Find number of nodes and number of edges in the graph
n_nodes = len(client.query("MATCH (n) RETURN n"))
n_edges = len(client.query("MATCH (n)--(m) RETURN n, m"))
print(f"Graph: {n_nodes:,} nodes and {n_edges:,} edges")
# Out:
# Graph: 87 nodes and 133 edges
# CPU times: user 5.33 ms, sys: 29 μs, total: 5.36 ms
# Wall time: 4.17 ms

# %% [markdown]
# ## Simple queries

# %%
from turingdb_examples.utils import get_return_statements

# %%
# %%time

# Match all edges and return them
command = """
MATCH (n)-[e]-(m)
RETURN n.name, n.type, e, m.name, m.type
"""
df_all_edges = client.query(command)
if df_all_edges.empty:
    print("No result found")
else:
    df_all_edges.columns = get_return_statements(command)
    display(df_all_edges)
# Out:
#              n.name    n.type    e      m.name m.type
# 0           DryWine     Class    0        Wine  Class
# 1         SweetWine     Class    1        Wine  Class
# 2       DessertWine     Class    2        Wine  Class
# 3    FullBodiedWine     Class    3        Wine  Class
# 4             Gamay     Class    4        Wine  Class
# ..              ...       ...  ...         ...    ...
# 128        hasColor  Property  128   WineColor  Class
# 129         hasBody  Property  129    WineBody  Class
# 130       hasFlavor  Property  130  WineFlavor  Class
# 131        hasSugar  Property  131   WineSugar  Class
# 132   madeFromGrape  Property  132   WineGrape  Class
#
# [133 rows x 5 columns]
# CPU times: user 13 ms, sys: 1.15 ms, total: 14.2 ms
# Wall time: 12.4 ms

# %%
# Get all nodes by label type
for label in df_LABELS["Node_label"]:
    print(100 * "#")
    print(f"label: {label}")
    display(client.query(f"MATCH (n:{label}) RETURN n.name"))

print(100 * "#")
# Out:
# ####################################################################################################
# label: PotableLiquid
#                  0
# 0          DryWine
# 1        SweetWine
# 2      DessertWine
# 3   FullBodiedWine
# 4            Gamay
# 5   CaliforniaWine
# 6        TexasWine
# 7       GermanWine
# 8      ItalianWine
# 9      LateHarvest
# 10        Bordeaux
# 11    AmericanWine
# 12    AlsatianWine
# 13        RoseWine
# 14           Loire
# 15         RedWine
# 16    EarlyHarvest
# 17       TableWine
# 18       WhiteWine
# 19            Wine
# ####################################################################################################
# label: Winery
#         0
# 0  Winery
# ####################################################################################################
# label: Vintage
#          0
# 0  Vintage
# ####################################################################################################
# label: Grape
#            0
# 0  WineGrape
# ####################################################################################################
# label: WhiteWine
#                           0
# 0                PinotBlanc
# 1  SemillonOrSauvignonBlanc
# 2                  Riesling
# 3            WhiteTableWine
# 4         WhiteNonSweetWine
# 5                Chardonnay
# 6              DryWhiteWine
# ####################################################################################################
# label: Loire
#             0
# 0    Sancerre
# 1  WhiteLoire
# 2    Muscadet
# ####################################################################################################
# label: DryWhiteWine
#                0
# 0  WhiteBurgundy
# 1    DryRiesling
# 2      Meursault
# ####################################################################################################
# label: DryWine
#                     0
# 0             Chianti
# 1          DryRedWine
# 2   CabernetSauvignon
# 3       CabernetFranc
# 4          Beaujolais
# 5              Merlot
# 6         PetiteSyrah
# 7            Burgundy
# 8           Zinfandel
# 9        RedTableWine
# 10        RedBurgundy
# ####################################################################################################
# label: SemillonOrSauvignonBlanc
#                 0
# 0        Semillon
# 1  SauvignonBlanc
# 2   WhiteBordeaux
# ####################################################################################################
# label: Region
#         0
# 0  Region
# ####################################################################################################
# label: VintageYear
#              0
# 0  VintageYear
# ####################################################################################################
# label: WineDescriptor
#                 0
# 0        WineBody
# 1      WineFlavor
# 2       WineColor
# 3       WineSugar
# 4       WineTaste
# 5  WineDescriptor
# ####################################################################################################
# label: WhiteNonSweetWine
#              0
# 0        Tours
# 1  CheninBlanc
# ####################################################################################################
# label: DessertWine
#                0
# 0  SweetRiesling
# ####################################################################################################
# label: RedBordeaux
#            0
# 0  StEmilion
# 1   Pauillac
# 2      Medoc
# 3    Margaux
# ####################################################################################################
# label: LateHarvest
#            0
# 0    IceWine
# 1  Sauternes
# ####################################################################################################
# label: RedWine
#              0
# 0     Meritage
# 1  RedBordeaux
# 2         Port
# 3    PinotNoir
# ####################################################################################################
# label: Wine
#             0
# 0  FrenchWine
# ####################################################################################################
# label: RedBurgundy
#           0
# 0  CotesDOr
# ####################################################################################################
# label: RoseWine
#        0
# 0  Anjou
# ####################################################################################################
# label: Property
#                     0
# 0        producesWine
# 1   hasWineDescriptor
# 2        madeIntoWine
# 3      adjacentRegion
# 4      hasVintageYear
# 5           locatedIn
# 6            hasColor
# 7             hasBody
# 8           hasFlavor
# 9            hasSugar
# 10      madeFromGrape
# 11           hasMaker
# 12          yearValue
# ####################################################################################################

# %% [markdown]
# ## More complex queries

# %%
# %%time

# 1. Get all wine types (classes that are subclasses of Wine/PotableLiquid)
#command = """
#MATCH (wine:PotableLiquid)
#WHERE wine.type = 'Class'
#RETURN wine.name, wine.parents
#LIMIT 20
#"""
command = """
MATCH (wine:PotableLiquid {type: 'Class'})
RETURN wine.name, wine.parents
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#          wine.name wine.parents
# 0          DryWine         Wine
# 1        SweetWine         Wine
# 2      DessertWine         Wine
# 3   FullBodiedWine         Wine
# 4            Gamay         Wine
# 5   CaliforniaWine         Wine
# 6        TexasWine         Wine
# 7       GermanWine         Wine
# 8      ItalianWine         Wine
# 9      LateHarvest    SweetWine
# 10        Bordeaux         Wine
# 11    AmericanWine         Wine
# 12    AlsatianWine         Wine
# 13        RoseWine         Wine
# 14           Loire         Wine
# 15         RedWine         Wine
# 16    EarlyHarvest         Wine
# 17       TableWine         Wine
# 18       WhiteWine         Wine
# 19            Wine         None
# CPU times: user 8.74 ms, sys: 2.11 ms, total: 10.8 ms
# Wall time: 9.07 ms

# %%
# %%time

# 2. Find all properties and their domains/ranges
#command = """
#MATCH (domain)-[:hasDomain]->(prop:Property)-[:hasRange]->(range)
#RETURN domain.name, prop.name, prop.property_type, range.name
#"""
command = """
MATCH (domain)-[:hasDomain]-(prop:Property)-[:hasRange]-(range)
RETURN domain.name, prop.name, prop.property_type, range.name
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#   domain.name          prop.name prop.property_type      range.name
# 0        Wine           hasColor       DataProperty       WineColor
# 1        Wine      madeFromGrape       DataProperty       WineGrape
# 2        Wine  hasWineDescriptor       DataProperty  WineDescriptor
# 3     Vintage     hasVintageYear       DataProperty     VintageYear
# 4      Region     adjacentRegion       DataProperty          Region
# CPU times: user 8.09 ms, sys: 2.03 ms, total: 10.1 ms
# Wall time: 8.72 ms

# %%
# %%time

# 3. Get the complete class hierarchy for a specific wine (e.g., Chardonnay)
#command = """
#MATCH path = (leaf)-[:subClassOf*]->(root)
#WHERE leaf.name = 'Chardonnay'
#RETURN leaf.name, root.name, LENGTH(path) AS depth
#ORDER BY depth DESC
#"""
command = """
MATCH (leaf {name: 'Chardonnay'})-[:subClassOf]-(root)
RETURN leaf.name, root.name
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#     leaf.name  root.name
# 0  Chardonnay  WhiteWine
# CPU times: user 7.8 ms, sys: 2 ms, total: 9.8 ms
# Wall time: 7.95 ms

# %%
# %%time

# 4. Find all red wines (wines that are subclass of RedWine)
#command = """
#MATCH (wine)-[:subClassOf*]->(parent)
#WHERE parent.name = 'RedWine'
#RETURN wine.name, wine.parents
#"""
command = """
MATCH (wine)-[:subClassOf]-(parent {name: 'RedWine'})
RETURN wine.name, wine.parents
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#       wine.name                        wine.parents
# 0    DryRedWine         TableWine, RedWine, DryWine
# 1  RedTableWine         TableWine, RedWine, DryWine
# 2      Meritage                             RedWine
# 3   RedBordeaux                   Bordeaux, RedWine
# 4          Port  RedWine, FullBodiedWine, SweetWine
# 5     PinotNoir                             RedWine
# CPU times: user 8.1 ms, sys: 2.04 ms, total: 10.1 ms
# Wall time: 8.41 ms

# %%
# %%time

# 5. Find all direct children of Wine class
#command = """
#MATCH (child)-[:subClassOf]->(parent)
#WHERE parent.name = 'Wine'
#RETURN child.name, child.type
#"""
command = """
MATCH (child)-[:subClassOf]-(parent {name: 'Wine'})
RETURN child.name, child.type
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#         child.name child.type
# 0          DryWine      Class
# 1        SweetWine      Class
# 2      DessertWine      Class
# 3   FullBodiedWine      Class
# 4            Gamay      Class
# 5   CaliforniaWine      Class
# 6        TexasWine      Class
# 7       GermanWine      Class
# 8      ItalianWine      Class
# 9         Bordeaux      Class
# 10    AmericanWine      Class
# 11    AlsatianWine      Class
# 12        RoseWine      Class
# 13           Loire      Class
# 14         RedWine      Class
# 15    EarlyHarvest      Class
# 16       TableWine      Class
# 17       WhiteWine      Class
# 18      FrenchWine      Class
# CPU times: user 9.61 ms, sys: 1.07 ms, total: 10.7 ms
# Wall time: 9.08 ms

# %%
# %%time

# 6. Get all properties that Wine class can have
#command = """
#MATCH (wine)-[:hasDomain]->(prop:Property)
#WHERE wine.name = 'Wine'
#RETURN prop.name, prop.property_type
#"""
command = """
MATCH (wine {name: 'Wine'})-[:hasDomain]-(prop:Property)
RETURN prop.name, prop.property_type
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#            prop.name prop.property_type
# 0           hasColor       DataProperty
# 1      madeFromGrape       DataProperty
# 2  hasWineDescriptor       DataProperty
# CPU times: user 7.28 ms, sys: 2.84 ms, total: 10.1 ms
# Wall time: 8.4 ms

# %%
# %%time

# 7. Find wine classes that have the most parent classes (complex definitions)
#command = """
#MATCH (wine)-[:subClassOf]->(parent)
#WHERE wine.type = 'Class'
#WITH wine.name AS wine_name, COUNT(parent) AS parent_count
#RETURN wine_name, parent_count
#ORDER BY parent_count DESC
#LIMIT 10
#"""
command = """
MATCH (wine {type: 'Class'})-[:subClassOf]-(parent)
RETURN wine.name, parent.name
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#           wine.name  parent.name
# 0           DryWine         Wine
# 1         SweetWine         Wine
# 2       DessertWine         Wine
# 3    FullBodiedWine         Wine
# 4             Gamay         Wine
# ..              ...          ...
# 113       PinotNoir      RedWine
# 114      FrenchWine         Wine
# 115        CotesDOr  RedBurgundy
# 116           Anjou     RoseWine
# 117           Anjou        Loire
#
# [118 rows x 2 columns]
# CPU times: user 7.39 ms, sys: 1.05 ms, total: 8.44 ms
# Wall time: 7.18 ms

# %%
# %%time

# 8. Find all French wine types
#command = """
#MATCH (wine)-[:subClassOf*]->(parent)
#WHERE parent.name = 'FrenchWine'
#RETURN wine.name
#"""
command = """
MATCH (wine)-[:subClassOf]-(parent {name: 'FrenchWine'})
RETURN wine.name
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
# No result found
# CPU times: user 1.69 ms, sys: 980 μs, total: 2.67 ms
# Wall time: 1.66 ms

# %%
# %%time

# 9. Find properties that point to WineDescriptor classes
#command = """
#MATCH (prop:Property)-[:hasRange]->(desc)
#WHERE desc.name CONTAINS 'Wine' AND desc.type = 'Class'
#RETURN prop.name, desc.name
#"""
command = """
MATCH (prop:Property)-[:hasRange]-(desc {name ~= 'Wine'})
RETURN prop.name, desc.name
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#            prop.name       desc.name
# 0  hasWineDescriptor  WineDescriptor
# 1           hasColor       WineColor
# 2            hasBody        WineBody
# 3          hasFlavor      WineFlavor
# 4           hasSugar       WineSugar
# 5      madeFromGrape       WineGrape
# CPU times: user 7.84 ms, sys: 2 ms, total: 9.85 ms
# Wall time: 8.08 ms

# %%
# %%time

# 10. Get the full subclass tree depth for all wine types
#command = """
#MATCH path = (wine)-[:subClassOf*]->(root:PotableLiquid)
#WHERE wine.type = 'Class' AND root.name = 'Wine'
#RETURN wine.name, LENGTH(path) AS hierarchy_depth
#ORDER BY hierarchy_depth DESC
#LIMIT 15
#"""
command = """
MATCH (wine {type: 'Class'})-[:subClassOf]-(root:PotableLiquid {name: 'Wine'})
RETURN wine.name, root.name
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#          wine.name root.name
# 0          DryWine      Wine
# 1        SweetWine      Wine
# 2      DessertWine      Wine
# 3   FullBodiedWine      Wine
# 4            Gamay      Wine
# 5   CaliforniaWine      Wine
# 6        TexasWine      Wine
# 7       GermanWine      Wine
# 8      ItalianWine      Wine
# 9         Bordeaux      Wine
# 10    AmericanWine      Wine
# 11    AlsatianWine      Wine
# 12        RoseWine      Wine
# 13           Loire      Wine
# 14         RedWine      Wine
# 15    EarlyHarvest      Wine
# 16       TableWine      Wine
# 17       WhiteWine      Wine
# 18      FrenchWine      Wine
# CPU times: user 10.3 ms, sys: 911 μs, total: 11.2 ms
# Wall time: 9.39 ms

# %%
print("Notebook finished !")
# Out:
# Notebook finished !
