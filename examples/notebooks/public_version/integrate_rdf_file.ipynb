# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>
#         Example notebook - Integrate RDF file
#     </h1>
#     <p>
#         Link to dataset : <a href="TR/owl-guide/wine.rdf">Link to Wine RDF file download</a>
#     </p>
# </div>

# %% [markdown]
# # Import modules and functions

# %%
from rdflib import Graph as RDFGraph
import re
import time

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %% [markdown]
# # Check data files are available

# %%
example_name = "wine_ontology"
path_data = f"{os.getcwd()}/data/{example_name}"
if not os.path.exists(path_data):
    print(f"{path_data} does not exist")
    os.makedirs(path_data)
    print(f"{path_data} folder created ✔")

list_files = sorted(os.listdir(path_data))
rdf_filename = "wine_ontology.rdf"
if not rdf_filename in list_files:
    print(f"Wine ontology RDF file is not available in {path_data}. \n")
    url_rdf = "https://www.w3.org/TR/owl-guide/wine.rdf"
    print(
        f"Downloading from: {url_rdf}"
        "\n...\n"
    )
    os.system(f"wget {url_rdf} -O {path_data}/{rdf_filename}")

# %% [markdown]
# # Load dataset

# %%
# RDF graph loading
path_rdf = f"{path_data}/{rdf_filename}"

rg = RDFGraph()
rg.parse(path_rdf)
print(f"RDF file successfully loaded with {len(rg)} triples")
# Out:
# RDF file successfully loaded with 1839 triples

# %%
for obj in list(rg.objects())[:10]:
    print(f"Object: {obj}")
    print(f"Type:   {type(obj)}")
    print()
# Out:
# Object: N0ec1443eadc947789b0d7d13e4632a40
# Type:   <class 'rdflib.term.BNode'>
#
# Object: N0010c8c1b9ab45f58c1cc4ce69fcdc6e
# Type:   <class 'rdflib.term.BNode'>
#
# Object: Na7352b3d797b414da857bc84cf2a7a29
# Type:   <class 'rdflib.term.BNode'>
#
# Object: 1
# Type:   <class 'rdflib.term.Literal'>
#
# Object: http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#locatedIn
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: N7fc2483dc1c244249c02fcb4ffbb01c3
# Type:   <class 'rdflib.term.BNode'>
#
# Object: http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlancGrape
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medium
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: http://www.w3.org/2002/07/owl#Class
# Type:   <class 'rdflib.term.URIRef'>
#
# Object: Naf7eddada1f64cf8a458e5d27025a4d3
# Type:   <class 'rdflib.term.BNode'>

# %% [markdown]
# # Graph Creation in TuringDB

# %% [markdown]
# ## Build Cypher CREATE Commands

# %% [markdown]
# ### Sanitize Cypher query

# %%
def sanitize_cypher_query(query):
    query = query.replace("#", "_")
    query = query.replace("-", "_")

    return query

# %% [markdown]
# ### TuringDB v2 (not implemented yet)

# %%
def rdf_to_cypher_v2(rdf_file, batch_size=1000):
    from rdflib import Graph
    
    g = Graph()
    g.parse(rdf_file)
    
    nodes = {str(s) for s, _, _ in g} | {str(o) for _, _, o in g if not isinstance(o, str) or o.startswith('http')}
    
    for i in range(0, len(nodes), batch_size):
        batch = list(nodes)[i:i+batch_size]
        yield "CREATE " + ",\n".join(
            f"(:{node.split('/')[-1]} {{uri: '{node}'}})" 
            for node in batch
        )
    
    for s, p, o in g:
        if not isinstance(o, str) or o.startswith('http'):
            yield f"MATCH (a {{uri: '{s}'}}), (b {{uri: '{o}'}}) CREATE (a)-[:{str(p).split('/')[-1]}]->(b)"

# %%
# %%time

# Create Cypher CREATE command for TuringDB v2
graph_CREATE_command_v2 = '\n'.join(rdf_to_cypher_v2(path_rdf))
graph_CREATE_command_v2 = sanitize_cypher_query(graph_CREATE_command_v2)
print(graph_CREATE_command_v2)
# Out:
# CREATE (:Neb69f27c00024affa20d7d46aa189b4d {uri: 'Neb69f27c00024affa20d7d46aa189b4d'}),
# (:wine_McGuinnesso {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_McGuinnesso'}),
# (:wine_WineFlavor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineFlavor'}),
# (:wine_hasWineDescriptor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasWineDescriptor'}),
# (:wine_WhiteBordeaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteBordeaux'}),
# (:N6d21f21d839d4497984b6def49294aef {uri: 'N6d21f21d839d4497984b6def49294aef'}),
# (:N1c03afab90354b008b2843c1e98c32f9 {uri: 'N1c03afab90354b008b2843c1e98c32f9'}),
# (:Ne81ddf040f2d404cb2615eee4e25356b {uri: 'Ne81ddf040f2d404cb2615eee4e25356b'}),
# (:N3afdfb73da3541f3b61524f6bd243764 {uri: 'N3afdfb73da3541f3b61524f6bd243764'}),
# (:N2806345706fc42f39cb481868688f967 {uri: 'N2806345706fc42f39cb481868688f967'}),
# (:wine_MountEdenVineyardEstatePinotNoir {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountEdenVineyardEstatePinotNoir'}),
# (:Nd9993533dc8742919f8e8354ac8a430a {uri: 'Nd9993533dc8742919f8e8354ac8a430a'}),
# (:wine_VintageYear {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_VintageYear'}),
# (:N5b6962a7a57048ed85e4900e988e3651 {uri: 'N5b6962a7a57048ed85e4900e988e3651'}),
# (:Nb8a9c50554484029ad3796b26893bfa0 {uri: 'Nb8a9c50554484029ad3796b26893bfa0'}),
# (:N3e78926421854f13aefa8d50e8d89d07 {uri: 'N3e78926421854f13aefa8d50e8d89d07'}),
# (:wine_Medoc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medoc'}),
# (:Nc61dc0addcb84a6b8521a68c9f8292b3 {uri: 'Nc61dc0addcb84a6b8521a68c9f8292b3'}),
# (:N23947597941d42d08c6c3c3fbcfdcb2b {uri: 'N23947597941d42d08c6c3c3fbcfdcb2b'}),
# (:N30dc901624c94f74bf5b678332227460 {uri: 'N30dc901624c94f74bf5b678332227460'}),
# (:Nc399ded65be94f7fadf32decfc0450a0 {uri: 'Nc399ded65be94f7fadf32decfc0450a0'}),
# (:wine_hasBody {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasBody'}),
# (:wine_DAnjou {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DAnjou'}),
# (:N442275455a49486eb6c14aea8f885465 {uri: 'N442275455a49486eb6c14aea8f885465'}),
# (:N2340fec772814a23ba9fa13444de99cc {uri: 'N2340fec772814a23ba9fa13444de99cc'}),
# (:wine_Margaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Margaux'}),
# (:wine_ChateauChevalBlancStEmilion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauChevalBlancStEmilion'}),
# (:Nd8ab4aa84c774d4f84d6e539f7cf3e66 {uri: 'Nd8ab4aa84c774d4f84d6e539f7cf3e66'}),
# (:wine_CabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetSauvignon'}),
# (:wine_TableWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_TableWine'}),
# (:Ne4f8be04c5ce4021bbff5660dc9f14c8 {uri: 'Ne4f8be04c5ce4021bbff5660dc9f14c8'}),
# (:N7b4205a61bb1464f8c08b8ec11745a49 {uri: 'N7b4205a61bb1464f8c08b8ec11745a49'}),
# (:wine_ChateauDYchem {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauDYchem'}),
# (:Nc40401e245414562baec61a1bcf44c53 {uri: 'Nc40401e245414562baec61a1bcf44c53'}),
# (:N2cefd1421f15493187730d853f071544 {uri: 'N2cefd1421f15493187730d853f071544'}),
# (:Ne90dd08535664e67b08155b051d33e16 {uri: 'Ne90dd08535664e67b08155b051d33e16'}),
# (:N3bcc9b35b20647589622d69736f78eb7 {uri: 'N3bcc9b35b20647589622d69736f78eb7'}),
# (:N88f1c4e9c7904cbf9ce7a058f39f280c {uri: 'N88f1c4e9c7904cbf9ce7a058f39f280c'}),
# (:wine_ChateauDYchemSauterne {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauDYchemSauterne'}),
# (:wine_MountadamPinotNoir {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamPinotNoir'}),
# (:wine_MeursaultRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MeursaultRegion'}),
# (:wine_hasFlavor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasFlavor'}),
# (:Na50ea092806b47d7aaeb50f3075ec659 {uri: 'Na50ea092806b47d7aaeb50f3075ec659'}),
# (:N5c6abb82370c4ca989ae90b993bd09e5 {uri: 'N5c6abb82370c4ca989ae90b993bd09e5'}),
# (:Nc16142155a024b36a349c26b9bd764ac {uri: 'Nc16142155a024b36a349c26b9bd764ac'}),
# (:N411f76ee06e14ca19260700ad14ebaa1 {uri: 'N411f76ee06e14ca19260700ad14ebaa1'}),
# (:wine_Stonleigh {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Stonleigh'}),
# (:wine_ChateauDeMeursault {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauDeMeursault'}),
# (:N068bc8d122c64715a9fea4e54a699213 {uri: 'N068bc8d122c64715a9fea4e54a699213'}),
# (:wine_ClosDeLaPoussie {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeLaPoussie'}),
# (:N1aa08f801c804a318d797d93cd84cc4b {uri: 'N1aa08f801c804a318d797d93cd84cc4b'}),
# (:wine_BancroftChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BancroftChardonnay'}),
# (:Nbb7a5da103ea46c38c5513206a881650 {uri: 'Nbb7a5da103ea46c38c5513206a881650'}),
# (:N8056da74aae6450ba07dd085b778c5e0 {uri: 'N8056da74aae6450ba07dd085b778c5e0'}),
# (:N8fc02498e8dc4b6ebd9c89c2d3e510ac {uri: 'N8fc02498e8dc4b6ebd9c89c2d3e510ac'}),
# (:N74f2e9cc87604ab5bf652dc46a93be2e {uri: 'N74f2e9cc87604ab5bf652dc46a93be2e'}),
# (:wine_TexasWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_TexasWine'}),
# (:N30379e41f23943ea8ebdc35b1c4d674a {uri: 'N30379e41f23943ea8ebdc35b1c4d674a'}),
# (:wine_StGenevieve {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StGenevieve'}),
# (:wine_FrenchRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FrenchRegion'}),
# (:wine_PauillacRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PauillacRegion'}),
# (:N6f87d2ecff1346588a56090f9a8c9c70 {uri: 'N6f87d2ecff1346588a56090f9a8c9c70'}),
# (:N341ad5cccd234e5e9b9dd43ca2b368d5 {uri: 'N341ad5cccd234e5e9b9dd43ca2b368d5'}),
# (:Nca50e4e415e646aa8e918579c7670953 {uri: 'Nca50e4e415e646aa8e918579c7670953'}),
# (:N1279e7ffa08a440884f4abb51df6e4d1 {uri: 'N1279e7ffa08a440884f4abb51df6e4d1'}),
# (:Ndd9c553cc29045759e0dd779252d7c03 {uri: 'Ndd9c553cc29045759e0dd779252d7c03'}),
# (:wine_EdnaValleyRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_EdnaValleyRegion'}),
# (:N500ab110baf24a0995ec38f9d3482cca {uri: 'N500ab110baf24a0995ec38f9d3482cca'}),
# (:wine_StGenevieveTexasWhite {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StGenevieveTexasWhite'}),
# (:wine_CorbansPrivateBinSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansPrivateBinSauvignonBlanc'}),
# (:Nc7430043aefb4e38a37384265c4e342f {uri: 'Nc7430043aefb4e38a37384265c4e342f'}),
# (:Nceb9cacd0c7041198682297eedace708 {uri: 'Nceb9cacd0c7041198682297eedace708'}),
# (:wine_PageMillWinery {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PageMillWinery'}),
# (:N92538837ee81459fbd592562920bbbb9 {uri: 'N92538837ee81459fbd592562920bbbb9'}),
# (:N5fde37fd5772470a969c7e95a353ede6 {uri: 'N5fde37fd5772470a969c7e95a353ede6'}),
# (:N3771799c9cb64991a0b67104129d9d29 {uri: 'N3771799c9cb64991a0b67104129d9d29'}),
# (:wine_MariettaOldVinesRed {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaOldVinesRed'}),
# (:N6e1dd2126c62474b96da4e213782e8c7 {uri: 'N6e1dd2126c62474b96da4e213782e8c7'}),
# (:N98393a79c1af4d48844e948554bf72be {uri: 'N98393a79c1af4d48844e948554bf72be'}),
# (:Nefc6688707b0468d9aa54e1fdf106417 {uri: 'Nefc6688707b0468d9aa54e1fdf106417'}),
# (:Nc62d153e02c244a09fb6670e16d1a36a {uri: 'Nc62d153e02c244a09fb6670e16d1a36a'}),
# (:N3b8f5a829f9e4ba9b658dd61d5650ab6 {uri: 'N3b8f5a829f9e4ba9b658dd61d5650ab6'}),
# (:N21a9cfe91c4a49e6ab011879fa0d5890 {uri: 'N21a9cfe91c4a49e6ab011879fa0d5890'}),
# (:wine_Semillon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Semillon'}),
# (:N170594a133794c37af0bf124ddcc012c {uri: 'N170594a133794c37af0bf124ddcc012c'}),
# (:N7d798ebe22794a3d9a1b55609f1c4034 {uri: 'N7d798ebe22794a3d9a1b55609f1c4034'}),
# (:food_madeFromFruit {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/food_madeFromFruit'}),
# (:N1509340d32de4da69607913572a7b517 {uri: 'N1509340d32de4da69607913572a7b517'}),
# (:N68a43f163f1249109d036a36cd3d34f1 {uri: 'N68a43f163f1249109d036a36cd3d34f1'}),
# (:N5f885152740a4cf09c040706dca6c59a {uri: 'N5f885152740a4cf09c040706dca6c59a'}),
# (:Nff215041645b4065bc0b1ce41b5c6651 {uri: 'Nff215041645b4065bc0b1ce41b5c6651'}),
# (:Nb4cbba2b7a2542de8c94e6eacb02498d {uri: 'Nb4cbba2b7a2542de8c94e6eacb02498d'}),
# (:N028e45c5829c40738672b9c412b757fa {uri: 'N028e45c5829c40738672b9c412b757fa'}),
# (:N08a8e32c792940128590b27382523be6 {uri: 'N08a8e32c792940128590b27382523be6'}),
# (:N9441feaf923149cfb7fc7d44ff1806df {uri: 'N9441feaf923149cfb7fc7d44ff1806df'}),
# (:Ne0311856f25a4a578e4ba9808fdace4f {uri: 'Ne0311856f25a4a578e4ba9808fdace4f'}),
# (:wine_CheninBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CheninBlanc'}),
# (:wine_SancerreRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SancerreRegion'}),
# (:N14bb678c46c847a99b455d057be027d4 {uri: 'N14bb678c46c847a99b455d057be027d4'}),
# (:N60d7c639f95a47378be7ff8dd40a2c3d {uri: 'N60d7c639f95a47378be7ff8dd40a2c3d'}),
# (:N47da020ea82e4da8948a26da79090d5a {uri: 'N47da020ea82e4da8948a26da79090d5a'}),
# (:wine_WhiteTableWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteTableWine'}),
# (:Ne0cf84f0d59449818a68c9bf8b5a125f {uri: 'Ne0cf84f0d59449818a68c9bf8b5a125f'}),
# (:Ndcd1b72f55f5463d88c21bdf700254ff {uri: 'Ndcd1b72f55f5463d88c21bdf700254ff'}),
# (:Nf2719e0f9c2a489c81fd7a1bf654cb33 {uri: 'Nf2719e0f9c2a489c81fd7a1bf654cb33'}),
# (:wine_StonleighSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StonleighSauvignonBlanc'}),
# (:N875ab269381c4097bc2459e1c977a54d {uri: 'N875ab269381c4097bc2459e1c977a54d'}),
# (:wine_SangioveseGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SangioveseGrape'}),
# (:wine_ArroyoGrandeRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ArroyoGrandeRegion'}),
# (:wine_CabernetSauvignonGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetSauvignonGrape'}),
# (:wine_ClosDeVougeot {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeVougeot'}),
# (:wine_BordeauxRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BordeauxRegion'}),
# (:N0e85ef81bf2047b8bf1835461840a41d {uri: 'N0e85ef81bf2047b8bf1835461840a41d'}),
# (:wine_AlsaceRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AlsaceRegion'}),
# (:N7ec3c8494465417f9d350c8b576c0de0 {uri: 'N7ec3c8494465417f9d350c8b576c0de0'}),
# (:wine_Tours {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Tours'}),
# (:wine_ChateauLafiteRothschild {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauLafiteRothschild'}),
# (:wine_Sancerre {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sancerre'}),
# (:Nb3a40db83bdf4110969588e23c72b3b7 {uri: 'Nb3a40db83bdf4110969588e23c72b3b7'}),
# (:wine_Beringer {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Beringer'}),
# (:Ne5b8ce2a236d41c9b083094144d0886a {uri: 'Ne5b8ce2a236d41c9b083094144d0886a'}),
# (:wine_CabernetFranc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetFranc'}),
# (:wine_GamayGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GamayGrape'}),
# (:wine_AnjouRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AnjouRegion'}),
# (:wine_GermanWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GermanWine'}),
# (:wine_LateHarvest {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LateHarvest'}),
# (:Na5d0083610104bb7a48c72625d5f6103 {uri: 'Na5d0083610104bb7a48c72625d5f6103'}),
# (:wine_PulignyMontrachetWhiteBurgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PulignyMontrachetWhiteBurgundy'}),
# (:N713b0e42080345f3a9028e90292421e0 {uri: 'N713b0e42080345f3a9028e90292421e0'}),
# (:Nff719ce4bc8b4a798d28627fc3059e8b {uri: 'Nff719ce4bc8b4a798d28627fc3059e8b'}),
# (:N3dd60fed93c848d4b8528447e2dfeab7 {uri: 'N3dd60fed93c848d4b8528447e2dfeab7'}),
# (:Ne99b4bcdbf6f45a1a5eee89e2a48aa79 {uri: 'Ne99b4bcdbf6f45a1a5eee89e2a48aa79'}),
# (:N48fcff63015c40df8fdf06d9a00f17cc {uri: 'N48fcff63015c40df8fdf06d9a00f17cc'}),
# (:wine_LongridgeMerlot {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LongridgeMerlot'}),
# (:N07507a7f403449c595c8ea38bbfac14d {uri: 'N07507a7f403449c595c8ea38bbfac14d'}),
# (:wine_SevreEtMaineMuscadet {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SevreEtMaineMuscadet'}),
# (:Nca532db954cc470f923f1b33d3a7725c {uri: 'Nca532db954cc470f923f1b33d3a7725c'}),
# (:wine_hasVintageYear {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasVintageYear'}),
# (:wine_RedBurgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RedBurgundy'}),
# (:N9a1950dda9a5471699a59623e837db11 {uri: 'N9a1950dda9a5471699a59623e837db11'}),
# (:N1e0cc05cbcaf47298c98aed1a6830ec3 {uri: 'N1e0cc05cbcaf47298c98aed1a6830ec3'}),
# (:wine_Full {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Full'}),
# (:wine_WhitehallLaneCabernetFranc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhitehallLaneCabernetFranc'}),
# (:Ne4bc749d586b405882014bd141ef32f2 {uri: 'Ne4bc749d586b405882014bd141ef32f2'}),
# (:Nf7c3e4fd2d514b32aee8bee06a8ad587 {uri: 'Nf7c3e4fd2d514b32aee8bee06a8ad587'}),
# (:N7126fbcb0c40411f97badd78321d25c6 {uri: 'N7126fbcb0c40411f97badd78321d25c6'}),
# (:wine_Ventana {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Ventana'}),
# (:Ne84822c764d74b8fa0492a6e97838e55 {uri: 'Ne84822c764d74b8fa0492a6e97838e55'}),
# (:N598a801deb5e4c85b53598f295434053 {uri: 'N598a801deb5e4c85b53598f295434053'}),
# (:wine_EarlyHarvest {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_EarlyHarvest'}),
# (:Nac58637316d64218a396582eb1ad0344 {uri: 'Nac58637316d64218a396582eb1ad0344'}),
# (:N28abef100b624ea1a1eeb3600261261c {uri: 'N28abef100b624ea1a1eeb3600261261c'}),
# (:Nec4ca14abef84f588d9c29fe67600c39 {uri: 'Nec4ca14abef84f588d9c29fe67600c39'}),
# (:wine_MariettaPetiteSyrah {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaPetiteSyrah'}),
# (:wine_SelaksSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SelaksSauvignonBlanc'}),
# (:wine_SantaCruzMountainVineyardCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SantaCruzMountainVineyardCabernetSauvignon'}),
# (:Nd8f3b8172fab41959f87dc5ddc95ecf9 {uri: 'Nd8f3b8172fab41959f87dc5ddc95ecf9'}),
# (:N947261bbd3b4400db25794e5caf8e0d9 {uri: 'N947261bbd3b4400db25794e5caf8e0d9'}),
# (:Nd8d55b3f8a6341ecbe17246a8aee0fbb {uri: 'Nd8d55b3f8a6341ecbe17246a8aee0fbb'}),
# (:wine_PinotBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotBlanc'}),
# (:wine_Elyse {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Elyse'}),
# (:N1c15ee51f5de46b9a7eeeb9c71318b07 {uri: 'N1c15ee51f5de46b9a7eeeb9c71318b07'}),
# (:N2a93f3d4bde14c3ba84c8d6e025c034f {uri: 'N2a93f3d4bde14c3ba84c8d6e025c034f'}),
# (:wine_USRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_USRegion'}),
# (:wine_Burgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Burgundy'}),
# (:N1eb49bc126624f3eb60318a4a2c8c069 {uri: 'N1eb49bc126624f3eb60318a4a2c8c069'}),
# (:N7e4b49960b1d453698602915cbe6da2c {uri: 'N7e4b49960b1d453698602915cbe6da2c'}),
# (:N8e561ca1658644fda51a5352ea12a2bd {uri: 'N8e561ca1658644fda51a5352ea12a2bd'}),
# (:wine_Year1998 {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Year1998'}),
# (:Nce907ab7b1e74f5aada59a3313c3017e {uri: 'Nce907ab7b1e74f5aada59a3313c3017e'}),
# (:Ne9475fa80d2949dfb97ff15a8880dc07 {uri: 'Ne9475fa80d2949dfb97ff15a8880dc07'}),
# (:Nd6ecd166df4b4126bdc53e589416809d {uri: 'Nd6ecd166df4b4126bdc53e589416809d'}),
# (:wine_SauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SauvignonBlanc'}),
# (:N4db5b0d203244c39a5f31317b40635fe {uri: 'N4db5b0d203244c39a5f31317b40635fe'}),
# (:N4934e28e28664cee8b6f47bc7396d461 {uri: 'N4934e28e28664cee8b6f47bc7396d461'}),
# (:wine_ClosDeVougeotCotesDOr {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeVougeotCotesDOr'}),
# (:wine_ItalianRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ItalianRegion'}),
# (:N47c0572bf5ba46308b797adf5ca35a7d {uri: 'N47c0572bf5ba46308b797adf5ca35a7d'}),
# (:Nf6b01110795248bb9e0f4f2f271c8fa9 {uri: 'Nf6b01110795248bb9e0f4f2f271c8fa9'}),
# (:N3b99c55c1e5747109628d0144f6bb7a7 {uri: 'N3b99c55c1e5747109628d0144f6bb7a7'}),
# (:N0442ad547b0d4423b7755db145ece758 {uri: 'N0442ad547b0d4423b7755db145ece758'}),
# (:Ncf4528a9c5f948e4bb43bd566f7a18de {uri: 'Ncf4528a9c5f948e4bb43bd566f7a18de'}),
# (:N2a0f0e2bbe7f404f9b9a460b9e6f881e {uri: 'N2a0f0e2bbe7f404f9b9a460b9e6f881e'}),
# (:N0d94935999554949836ff4eec6a19f21 {uri: 'N0d94935999554949836ff4eec6a19f21'}),
# (:wine_SweetWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SweetWine'}),
# (:wine_RoseDAnjou {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RoseDAnjou'}),
# (:Ne4ae9c6b970844109b53aa1a02419e2e {uri: 'Ne4ae9c6b970844109b53aa1a02419e2e'}),
# (:wine_CentralCoastRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CentralCoastRegion'}),
# (:N05668efd1d4f4bfaa4e94987c176f1c7 {uri: 'N05668efd1d4f4bfaa4e94987c176f1c7'}),
# (:Nde0de72efcec440aa682d256544d2d8e {uri: 'Nde0de72efcec440aa682d256544d2d8e'}),
# (:N7f9fb37f718241a4ad375c8a67dd249a {uri: 'N7f9fb37f718241a4ad375c8a67dd249a'}),
# (:wine_FormanChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FormanChardonnay'}),
# (:22_rdf_syntax_ns_nil {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}),
# (:wine_ChateauMorgon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMorgon'}),
# (:N0ffea5a6b233462ab1c318ff3bd5d703 {uri: 'N0ffea5a6b233462ab1c318ff3bd5d703'}),
# (:Na73b161ec9314287a47c88a21fa0a2d5 {uri: 'Na73b161ec9314287a47c88a21fa0a2d5'}),
# (:wine_KalinCellars {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_KalinCellars'}),
# (:wine_FullBodiedWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FullBodiedWine'}),
# (:N01ec2a370b294683bcc13ec6525628c3 {uri: 'N01ec2a370b294683bcc13ec6525628c3'}),
# (:Nd237953742a94b3fb27496bdae58afd2 {uri: 'Nd237953742a94b3fb27496bdae58afd2'}),
# (:N7cd50c0d8dda4b0a8516fc60cc81c691 {uri: 'N7cd50c0d8dda4b0a8516fc60cc81c691'}),
# (:wine_SouthAustraliaRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SouthAustraliaRegion'}),
# (:N2690373ec1c2499b83519e7cf42a0403 {uri: 'N2690373ec1c2499b83519e7cf42a0403'}),
# (:Nf7bdf96a92ba41889876fd945159260c {uri: 'Nf7bdf96a92ba41889876fd945159260c'}),
# (:wine_ElyseZinfandel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ElyseZinfandel'}),
# (:N2a57b7ff489845ec9bc092f04622e924 {uri: 'N2a57b7ff489845ec9bc092f04622e924'}),
# (:N5c474a83ef034febbba4b7e7edc7ba72 {uri: 'N5c474a83ef034febbba4b7e7edc7ba72'}),
# (:N27ab7bfe71d143f78089eeb67bbbeb67 {uri: 'N27ab7bfe71d143f78089eeb67bbbeb67'}),
# (:owl_Class {uri: 'http://www.w3.org/2002/07/owl_Class'}),
# (:Nba0a6ff6cbfb40bab36b2b160160dd1f {uri: 'Nba0a6ff6cbfb40bab36b2b160160dd1f'}),
# (:wine_ChiantiRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChiantiRegion'}),
# (:wine_WhiteWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteWine'}),
# (:N011970b67f1a43278b1b072ef88e623a {uri: 'N011970b67f1a43278b1b072ef88e623a'}),
# (:Nd37a217c5fd54148b5cd26dbbf39c54f {uri: 'Nd37a217c5fd54148b5cd26dbbf39c54f'}),
# (:wine_GermanyRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GermanyRegion'}),
# (:N3f839140ae9b4ffb9e7f1068731edd01 {uri: 'N3f839140ae9b4ffb9e7f1068731edd01'}),
# (:N292c4598c6a74b39ae881fb3e0ffd248 {uri: 'N292c4598c6a74b39ae881fb3e0ffd248'}),
# (:N3a9aa095f66048b7afb03bffb13434c3 {uri: 'N3a9aa095f66048b7afb03bffb13434c3'}),
# (:Nfdcec98cf133456881da02436ec41d70 {uri: 'Nfdcec98cf133456881da02436ec41d70'}),
# (:N16eb4eb197e74621a2dbdaa99b024d0b {uri: 'N16eb4eb197e74621a2dbdaa99b024d0b'}),
# (:N6c03dc7bfa4a4de0b2d42c07bd5450ab {uri: 'N6c03dc7bfa4a4de0b2d42c07bd5450ab'}),
# (:Nc5dfa76b397d4ac8ad8ed5d6721f46c9 {uri: 'Nc5dfa76b397d4ac8ad8ed5d6721f46c9'}),
# (:wine_SeanThackrey {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SeanThackrey'}),
# (:N2ad2696c84af438d93d9abd4842f7ce0 {uri: 'N2ad2696c84af438d93d9abd4842f7ce0'}),
# (:wine_CongressSpringsSemillon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CongressSpringsSemillon'}),
# (:N795d745c835c4bb0a7af42e992c6352d {uri: 'N795d745c835c4bb0a7af42e992c6352d'}),
# (:N88ec373a99a54d3cb6d58f68d720bffb {uri: 'N88ec373a99a54d3cb6d58f68d720bffb'}),
# (:N7c895060c0694b9ab38aaf18cab3c950 {uri: 'N7c895060c0694b9ab38aaf18cab3c950'}),
# (:N63e839aacd634029a3aa56eb71d0e07b {uri: 'N63e839aacd634029a3aa56eb71d0e07b'}),
# (:wine_AustralianRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AustralianRegion'}),
# (:wine_SauterneRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SauterneRegion'}),
# (:N48fe69ebf33d4a96a4f098dd10446373 {uri: 'N48fe69ebf33d4a96a4f098dd10446373'}),
# (:Nf157927f1ef647ea9886dd08e1c2d9a9 {uri: 'Nf157927f1ef647ea9886dd08e1c2d9a9'}),
# (:wine_CorbansSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansSauvignonBlanc'}),
# (:wine_CheninBlancGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CheninBlancGrape'}),
# (:Nae0204594ac1418781d4268c22257d72 {uri: 'Nae0204594ac1418781d4268c22257d72'}),
# (:Nb8e6d6ca917a4d4b8f5e0841f3e1bba2 {uri: 'Nb8e6d6ca917a4d4b8f5e0841f3e1bba2'}),
# (:N596c1b676b72414094277bfcbb31f1ee {uri: 'N596c1b676b72414094277bfcbb31f1ee'}),
# (:wine_Anjou {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Anjou'}),
# (:Nf2e284794f4a45b5a433fa7d1a61d63a {uri: 'Nf2e284794f4a45b5a433fa7d1a61d63a'}),
# (:N16524fd61b704908bb7769f93c567155 {uri: 'N16524fd61b704908bb7769f93c567155'}),
# (:Nd809fec5ccd64eb997a20c811f563149 {uri: 'Nd809fec5ccd64eb997a20c811f563149'}),
# (:Ne60f1a1a9e2446df8948ec3ea38ab105 {uri: 'Ne60f1a1a9e2446df8948ec3ea38ab105'}),
# (:food_Grape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/food_Grape'}),
# (:wine_Bordeaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Bordeaux'}),
# (:wine_SweetRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SweetRiesling'}),
# (:Ncde2f3902dac4bebb2c2dacdf0fd077c {uri: 'Ncde2f3902dac4bebb2c2dacdf0fd077c'}),
# (:wine_ChateauMargauxWinery {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMargauxWinery'}),
# (:N67bc8a463aa2426e9376aa75e0b398bf {uri: 'N67bc8a463aa2426e9376aa75e0b398bf'}),
# (:N071ab38be9cb490a97d7369a462bd51e {uri: 'N071ab38be9cb490a97d7369a462bd51e'}),
# (:N88bd56e7d5a641d2a85af0be97273534 {uri: 'N88bd56e7d5a641d2a85af0be97273534'}),
# (:wine_hasMaker {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasMaker'}),
# (:Nf31ee115564347e5927a81db5185fbd4 {uri: 'Nf31ee115564347e5927a81db5185fbd4'}),
# (:N1294d78373a2406da31cd2a0b3768362 {uri: 'N1294d78373a2406da31cd2a0b3768362'}),
# (:Ne80598fdf909403e94cc1d15918b2944 {uri: 'Ne80598fdf909403e94cc1d15918b2944'}),
# (:N65ca038984f647feadf5b1b92b9aee03 {uri: 'N65ca038984f647feadf5b1b92b9aee03'}),
# (:Nd36eec8daacb4243b0aa10bfc6c97977 {uri: 'Nd36eec8daacb4243b0aa10bfc6c97977'}),
# (:N822b0a18e5e04eb6b48e69ac753a0bcf {uri: 'N822b0a18e5e04eb6b48e69ac753a0bcf'}),
# (:N3d816d31864d4158a347e0fb253146e4 {uri: 'N3d816d31864d4158a347e0fb253146e4'}),
# (:N93db40d48f15484883c357aa93ebe3d8 {uri: 'N93db40d48f15484883c357aa93ebe3d8'}),
# (:Nbdba647b8a0648c5bdf74b548c9a2732 {uri: 'Nbdba647b8a0648c5bdf74b548c9a2732'}),
# (:N5be30a5b1352493ea2b05aab21ce1afe {uri: 'N5be30a5b1352493ea2b05aab21ce1afe'}),
# (:N0494955d184c4f099f4b645bc2f62b9c {uri: 'N0494955d184c4f099f4b645bc2f62b9c'}),
# (:wine_ChateauDeMeursaultMeursault {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauDeMeursaultMeursault'}),
# (:N31829232060644ba8243610a06d91d8a {uri: 'N31829232060644ba8243610a06d91d8a'}),
# (:N5dcffd9678d547a2b362ad594c7b21c0 {uri: 'N5dcffd9678d547a2b362ad594c7b21c0'}),
# (:wine_MountadamChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamChardonnay'}),
# (:wine_LoireRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LoireRegion'}),
# (:N5fd756fe5a784c75a861bf9acee9d8ea {uri: 'N5fd756fe5a784c75a861bf9acee9d8ea'}),
# (:N47f6f91a2290416ab11c5f05b5fea6cf {uri: 'N47f6f91a2290416ab11c5f05b5fea6cf'}),
# (:N962fcb2e5a90433f9550c3f67cf05a26 {uri: 'N962fcb2e5a90433f9550c3f67cf05a26'}),
# (:wine_Beaujolais {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Beaujolais'}),
# (:N3033a667e0c14d86806944c7322d1c0c {uri: 'N3033a667e0c14d86806944c7322d1c0c'}),
# (:wine_MendocinoRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MendocinoRegion'}),
# (:wine_RedBordeaux {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RedBordeaux'}),
# (:wine_WineGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineGrape'}),
# (:Nbd9960475d024d59af202545fd96c098 {uri: 'Nbd9960475d024d59af202545fd96c098'}),
# (:N9cc43e14dec641c496d6db9015a55dd8 {uri: 'N9cc43e14dec641c496d6db9015a55dd8'}),
# (:N02efdef61ebf42cd9b5142b0c1b6a446 {uri: 'N02efdef61ebf42cd9b5142b0c1b6a446'}),
# (:wine_ClosDeLaPoussieSancerre {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ClosDeLaPoussieSancerre'}),
# (:wine_DryRedWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryRedWine'}),
# (:N50493e478d6547d29e30c6dc0a76f480 {uri: 'N50493e478d6547d29e30c6dc0a76f480'}),
# (:N62ec5298de2842c981831c4635588b3e {uri: 'N62ec5298de2842c981831c4635588b3e'}),
# (:wine_MuscadetRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MuscadetRegion'}),
# (:N555381227e6d48d887628d98189155a3 {uri: 'N555381227e6d48d887628d98189155a3'}),
# (:N0515c388e8fa4573b46dcaa3019cdd2d {uri: 'N0515c388e8fa4573b46dcaa3019cdd2d'}),
# (:Nfc192ea3e59047ec97a151e3739eb3b6 {uri: 'Nfc192ea3e59047ec97a151e3739eb3b6'}),
# (:N4ed98526e32545be88f24291c62c9c9f {uri: 'N4ed98526e32545be88f24291c62c9c9f'}),
# (:Nae6aed6353a844088232cd5b7b22a700 {uri: 'Nae6aed6353a844088232cd5b7b22a700'}),
# (:Na6adb2090dad49be9abe333d8ed929f6 {uri: 'Na6adb2090dad49be9abe333d8ed929f6'}),
# (:N2fc971c4283d4452831db2d29e80d456 {uri: 'N2fc971c4283d4452831db2d29e80d456'}),
# (:N8bb5fc8f28be4c219f8a5405ba763ca2 {uri: 'N8bb5fc8f28be4c219f8a5405ba763ca2'}),
# (:N9c0905aa460a49c1a274701e54ede05f {uri: 'N9c0905aa460a49c1a274701e54ede05f'}),
# (:Naf1e4206e8824ac5bd424f233e33da66 {uri: 'Naf1e4206e8824ac5bd424f233e33da66'}),
# (:N24cf71fde2374509938781637132fa9d {uri: 'N24cf71fde2374509938781637132fa9d'}),
# (:wine_MariettaZinfandel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaZinfandel'}),
# (:N7115be10ffe94019bcb47775b67e67a2 {uri: 'N7115be10ffe94019bcb47775b67e67a2'}),
# (:Ne3b088c65f564338a345ef870c818db8 {uri: 'Ne3b088c65f564338a345ef870c818db8'}),
# (:wine_SantaCruzMountainsRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SantaCruzMountainsRegion'}),
# (:wine_CaliforniaRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CaliforniaRegion'}),
# (:Ne8550ddba0b64f6ab2a309bbf9176b66 {uri: 'Ne8550ddba0b64f6ab2a309bbf9176b66'}),
# (:N48af6f2da73441379e84b34f9e6e7eef {uri: 'N48af6f2da73441379e84b34f9e6e7eef'}),
# (:wine_FrenchWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FrenchWine'}),
# (:wine_yearValue {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_yearValue'}),
# (:N24e1933734bc467f8d51feb018b0a05d {uri: 'N24e1933734bc467f8d51feb018b0a05d'}),
# (:Nda78eeb6b9ec4da0ab205fa0ee9f7398 {uri: 'Nda78eeb6b9ec4da0ab205fa0ee9f7398'}),
# (:N6ddff17d1af8461788a33529432d22d8 {uri: 'N6ddff17d1af8461788a33529432d22d8'}),
# (:owl_DatatypeProperty {uri: 'http://www.w3.org/2002/07/owl_DatatypeProperty'}),
# (:N68e1ee4c3a5041a6b752f41b68a16a4c {uri: 'N68e1ee4c3a5041a6b752f41b68a16a4c'}),
# (:wine_Pauillac {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Pauillac'}),
# (:owl_FunctionalProperty {uri: 'http://www.w3.org/2002/07/owl_FunctionalProperty'}),
# (:N169ef3aea55f4980810eaf32354da807 {uri: 'N169ef3aea55f4980810eaf32354da807'}),
# (:Na7d30bf2eb224da58a996a6c05abb313 {uri: 'Na7d30bf2eb224da58a996a6c05abb313'}),
# (:wine_NewZealandRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_NewZealandRegion'}),
# (:XMLSchema_positiveInteger {uri: 'http://www.w3.org/2001/XMLSchema_positiveInteger'}),
# (:N5220c46249f9408e962de7f43cf8129f {uri: 'N5220c46249f9408e962de7f43cf8129f'}),
# (:Nf5072038131d4c2bb04798b882c1105f {uri: 'Nf5072038131d4c2bb04798b882c1105f'}),
# (:Nbf9035ef096e4a4a8a5e78e755a8e77e {uri: 'Nbf9035ef096e4a4a8a5e78e755a8e77e'}),
# (:wine_SeanThackreySiriusPetiteSyrah {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SeanThackreySiriusPetiteSyrah'}),
# (:N70bfb40427744fbfabf63d47e02dc35d {uri: 'N70bfb40427744fbfabf63d47e02dc35d'}),
# (:Nb8ff6a333aef4653bd8f3b97d6ac6d57 {uri: 'Nb8ff6a333aef4653bd8f3b97d6ac6d57'}),
# (:wine_ChateauLafiteRothschildPauillac {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauLafiteRothschildPauillac'}),
# (:N687d74b617604658b4c6d97f234b2283 {uri: 'N687d74b617604658b4c6d97f234b2283'}),
# (:Nc3d468d9317a41e299b81113912114f2 {uri: 'Nc3d468d9317a41e299b81113912114f2'}),
# (:Nb270ac22054e4803af0aa23143b98f67 {uri: 'Nb270ac22054e4803af0aa23143b98f67'}),
# (:Ne9b335ce4f034e688e86bd2fc00d49de {uri: 'Ne9b335ce4f034e688e86bd2fc00d49de'}),
# (:wine_CotesDOrRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CotesDOrRegion'}),
# (:wine_Cotturi {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Cotturi'}),
# (:Nbdb780b86aa34a2792e9b20dbdabd369 {uri: 'Nbdb780b86aa34a2792e9b20dbdabd369'}),
# (:wine_ChateauMorgonBeaujolais {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMorgonBeaujolais'}),
# (:Na142108333d747468559b71cf9ea6c50 {uri: 'Na142108333d747468559b71cf9ea6c50'}),
# (:Ncdac230c1aca4852b617e1cde7dfc550 {uri: 'Ncdac230c1aca4852b617e1cde7dfc550'}),
# (:N3b8dc27cc65a43e1b43f4283eae81c3b {uri: 'N3b8dc27cc65a43e1b43f4283eae81c3b'}),
# (:owl_Ontology {uri: 'http://www.w3.org/2002/07/owl_Ontology'}),
# (:wine_Chardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Chardonnay'}),
# (:Nb7074549bdef474a9fb21366a04a89cb {uri: 'Nb7074549bdef474a9fb21366a04a89cb'}),
# (:Ndd7064f0f7ff4014b7aee66fb2e4cfa0 {uri: 'Ndd7064f0f7ff4014b7aee66fb2e4cfa0'}),
# (:wine_RieslingGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RieslingGrape'}),
# (:N81e543ba652c4221a585f8d84197ef38 {uri: 'N81e543ba652c4221a585f8d84197ef38'}),
# (:Nf62ca286797b41ac92eb4c7ae5e28384 {uri: 'Nf62ca286797b41ac92eb4c7ae5e28384'}),
# (:Nd69dd99a2b5346a9ae610c3f599d30a6 {uri: 'Nd69dd99a2b5346a9ae610c3f599d30a6'}),
# (:wine_SaucelitoCanyonZinfandel1998 {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SaucelitoCanyonZinfandel1998'}),
# (:N29e6f11c923241f39812b31249b1b8d0 {uri: 'N29e6f11c923241f39812b31249b1b8d0'}),
# (:N5dae850eb89e4fa9b86eee71151f3887 {uri: 'N5dae850eb89e4fa9b86eee71151f3887'}),
# (:Ne2968187ee124e1798eed788da155818 {uri: 'Ne2968187ee124e1798eed788da155818'}),
# (:wine_Longridge {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Longridge'}),
# (:N9fb3e43a44ec493ebf87654c1e1b2869 {uri: 'N9fb3e43a44ec493ebf87654c1e1b2869'}),
# (:wine_Chianti {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Chianti'}),
# (:wine_MedocRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MedocRegion'}),
# (:N1bce79fd05334d3091e6b9117f4ff62d {uri: 'N1bce79fd05334d3091e6b9117f4ff62d'}),
# (:Nc57e6a9ee419486a8d90efcbc183ae68 {uri: 'Nc57e6a9ee419486a8d90efcbc183ae68'}),
# (:N5fe67269695c475086519b9f7eb45cb5 {uri: 'N5fe67269695c475086519b9f7eb45cb5'}),
# (:wine_CortonMontrachetWhiteBurgundy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CortonMontrachetWhiteBurgundy'}),
# (:N3f2d0037e6fc412a81cdbb6afbfb87b0 {uri: 'N3f2d0037e6fc412a81cdbb6afbfb87b0'}),
# (:Nfa155d0746ce4bfc9b39f6229bf04767 {uri: 'Nfa155d0746ce4bfc9b39f6229bf04767'}),
# (:N4b4eda87e992408d8b9b1c817051b84d {uri: 'N4b4eda87e992408d8b9b1c817051b84d'}),
# (:wine_Dry {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Dry'}),
# (:owl_SymmetricProperty {uri: 'http://www.w3.org/2002/07/owl_SymmetricProperty'}),
# (:N6ad0c7cfb51d40ee8eb58551abb9e616 {uri: 'N6ad0c7cfb51d40ee8eb58551abb9e616'}),
# (:N47761808e06f411f8a733fd22e082ccd {uri: 'N47761808e06f411f8a733fd22e082ccd'}),
# (:N1d837e9fb3a34afc9ac537a4633ce53e {uri: 'N1d837e9fb3a34afc9ac537a4633ce53e'}),
# (:wine_Winery {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Winery'}),
# (:Ncd7a4953b9ce43eba07526dd2aee9e27 {uri: 'Ncd7a4953b9ce43eba07526dd2aee9e27'}),
# (:N6fa01213b60e4ad38b7270bf5b7a3fee {uri: 'N6fa01213b60e4ad38b7270bf5b7a3fee'}),
# (:N7ea5241bd290424b9b4ee97be1de9171 {uri: 'N7ea5241bd290424b9b4ee97be1de9171'}),
# (:wine_CentralTexasRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CentralTexasRegion'}),
# (:wine_WineColor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineColor'}),
# (:N791159118f634de28105c7b3e6866990 {uri: 'N791159118f634de28105c7b3e6866990'}),
# (:N40be0d0579ff4e95bc78f7956a1a6515 {uri: 'N40be0d0579ff4e95bc78f7956a1a6515'}),
# (:Nbb1d7b00c71449b9bc62479334877e0e {uri: 'Nbb1d7b00c71449b9bc62479334877e0e'}),
# (:N29b533c361f74c1f9439de068a59c9b4 {uri: 'N29b533c361f74c1f9439de068a59c9b4'}),
# (:N701c10b19e944340ac0d038db4222324 {uri: 'N701c10b19e944340ac0d038db4222324'}),
# (:Ncab56d3e033f43cab4dc0c824c4582dd {uri: 'Ncab56d3e033f43cab4dc0c824c4582dd'}),
# (:N5cc5f175c42a46f692ab3d21d6f72738 {uri: 'N5cc5f175c42a46f692ab3d21d6f72738'}),
# (:N6838aaf5fb0c4d06b6d955cff2f82fef {uri: 'N6838aaf5fb0c4d06b6d955cff2f82fef'}),
# (:N1f747b389c6c46608af88c65eb92b3ae {uri: 'N1f747b389c6c46608af88c65eb92b3ae'}),
# (:N603344f7b6ff4ca6a67e61f81d8aeede {uri: 'N603344f7b6ff4ca6a67e61f81d8aeede'}),
# (:N66d2f862a8a64518a67cb2295858d11d {uri: 'N66d2f862a8a64518a67cb2295858d11d'}),
# (:wine_MountadamRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamRiesling'}),
# (:Nb292fdc1bfe94c70b048ccc90d57eb7f {uri: 'Nb292fdc1bfe94c70b048ccc90d57eb7f'}),
# (:N044b419e4c6a4156aa8663846b9239db {uri: 'N044b419e4c6a4156aa8663846b9239db'}),
# (:Nd433c56594f54755a8c026eef420e88e {uri: 'Nd433c56594f54755a8c026eef420e88e'}),
# (:Nfee4c60783674060906470cd54f1ed64 {uri: 'Nfee4c60783674060906470cd54f1ed64'}),
# (:N884ff19ce9e0451e89467a1ebd8d778d {uri: 'N884ff19ce9e0451e89467a1ebd8d778d'}),
# (:Ndf54f804bc93493c86b53a49f6930aed {uri: 'Ndf54f804bc93493c86b53a49f6930aed'}),
# (:N244ab0ceb766418f87c5e77925f8c985 {uri: 'N244ab0ceb766418f87c5e77925f8c985'}),
# (:N2cc95f5ec329480e84d606ce472cf046 {uri: 'N2cc95f5ec329480e84d606ce472cf046'}),
# (:wine_NapaRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_NapaRegion'}),
# (:wine_SchlossRothermelTrochenbierenausleseRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossRothermelTrochenbierenausleseRiesling'}),
# (:Ncb99a28cc3db48a3a86b7f777be993d5 {uri: 'Ncb99a28cc3db48a3a86b7f777be993d5'}),
# (:wine_FoxenCheninBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FoxenCheninBlanc'}),
# (:N2066a5c2448f4d9d9a63f6cc08f35e17 {uri: 'N2066a5c2448f4d9d9a63f6cc08f35e17'}),
# (:N6270ce4061a24d10b69ce10094db6441 {uri: 'N6270ce4061a24d10b69ce10094db6441'}),
# (:Nb2ed515965aa429fa7e3a7988905f3fd {uri: 'Nb2ed515965aa429fa7e3a7988905f3fd'}),
# (:N4751149bf7f743a79c159be21f8d2c5e {uri: 'N4751149bf7f743a79c159be21f8d2c5e'}),
# (:wine_PeterMccoy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PeterMccoy'}),
# (:Nc012deaf07ff4e098f25e1b8d604bfd1 {uri: 'Nc012deaf07ff4e098f25e1b8d604bfd1'}),
# (:Nf85b5014adfa4e6696434ed566daae2c {uri: 'Nf85b5014adfa4e6696434ed566daae2c'}),
# (:N8424122ec8834228a63c4faac1248a07 {uri: 'N8424122ec8834228a63c4faac1248a07'}),
# (:wine_PinotBlancGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotBlancGrape'}),
# (:wine_Gamay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Gamay'}),
# (:wine_GaryFarrell {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_GaryFarrell'}),
# (:wine_Corbans {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Corbans'}),
# (:Nd4d2b55688114a879c251bbdb0a72996 {uri: 'Nd4d2b55688114a879c251bbdb0a72996'}),
# (:wine_WineSugar {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineSugar'}),
# (:wine_Light {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Light'}),
# (:N17a670eecd1d4b549c5715d07e4b33b9 {uri: 'N17a670eecd1d4b549c5715d07e4b33b9'}),
# (:Nf61654f16d804c30adee404a00cd4e40 {uri: 'Nf61654f16d804c30adee404a00cd4e40'}),
# (:Na643a1c9382b4b988617ca16f80ea6b4 {uri: 'Na643a1c9382b4b988617ca16f80ea6b4'}),
# (:wine_FormanCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_FormanCabernetSauvignon'}),
# (:wine_Loire {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Loire'}),
# (:N9fd167f735c44daa8e3b2b903b4d6532 {uri: 'N9fd167f735c44daa8e3b2b903b4d6532'}),
# (:N1be750c67e15464bb0896d20ae963604 {uri: 'N1be750c67e15464bb0896d20ae963604'}),
# (:Ne15e5b3f1ed54af2a6bc2643121b1d37 {uri: 'Ne15e5b3f1ed54af2a6bc2643121b1d37'}),
# (:N631c8df5efe643fb8d112cdae2f6113a {uri: 'N631c8df5efe643fb8d112cdae2f6113a'}),
# (:wine_PeterMccoyChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PeterMccoyChardonnay'}),
# (:N7c848629ab9140e6aeca898b90272d37 {uri: 'N7c848629ab9140e6aeca898b90272d37'}),
# (:wine_SevreEtMaine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SevreEtMaine'}),
# (:Nfde6d21315b446408a07802767be014b {uri: 'Nfde6d21315b446408a07802767be014b'}),
# (:N019c826630eb406c8e141077c5412c0b {uri: 'N019c826630eb406c8e141077c5412c0b'}),
# (:N49fa75f506e94234bd0eecfb889ea032 {uri: 'N49fa75f506e94234bd0eecfb889ea032'}),
# (:N968c0e172c5a4630bdb4933bd0a65fe2 {uri: 'N968c0e172c5a4630bdb4933bd0a65fe2'}),
# (:Nc2883abbddba41c6ac80680d5c63f5ad {uri: 'Nc2883abbddba41c6ac80680d5c63f5ad'}),
# (:Nfc02b89628c14768b48d9cd158115bba {uri: 'Nfc02b89628c14768b48d9cd158115bba'}),
# (:N51e1e83e7f504e40a68cf77554ad7c40 {uri: 'N51e1e83e7f504e40a68cf77554ad7c40'}),
# (:Nd065b41c2e8048e4bde37bfb8b21c78e {uri: 'Nd065b41c2e8048e4bde37bfb8b21c78e'}),
# (:wine_TexasRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_TexasRegion'}),
# (:N6e6ecba19c66489dbc97042f5bc9fa5b {uri: 'N6e6ecba19c66489dbc97042f5bc9fa5b'}),
# (:N197dbdb0c01a4bb1afa79561267fdc05 {uri: 'N197dbdb0c01a4bb1afa79561267fdc05'}),
# (:N063961f1bcaf43978adadeb222dcfc63 {uri: 'N063961f1bcaf43978adadeb222dcfc63'}),
# (:Nb3ab3814508b43d59bf798380e46e022 {uri: 'Nb3ab3814508b43d59bf798380e46e022'}),
# (:N08108f39d71146ce89df9fa776def46e {uri: 'N08108f39d71146ce89df9fa776def46e'}),
# (:wine_White {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_White'}),
# (:Naba7d755d3f346d58830a92dfa1173e0 {uri: 'Naba7d755d3f346d58830a92dfa1173e0'}),
# (:wine_LaneTanner {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LaneTanner'}),
# (:wine_DryRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryRiesling'}),
# (:Nc89e9ab4ea324a178451a835d94c1d0a {uri: 'Nc89e9ab4ea324a178451a835d94c1d0a'}),
# (:N7d2621a6689f4899abbcdcd5bb48dd8b {uri: 'N7d2621a6689f4899abbcdcd5bb48dd8b'}),
# (:wine_SchlossVolrad {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossVolrad'}),
# (:N51223a360ddc4f38b6bd48245e3d9cad {uri: 'N51223a360ddc4f38b6bd48245e3d9cad'}),
# (:wine_Handley {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Handley'}),
# (:wine_CorbansDryWhiteRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansDryWhiteRiesling'}),
# (:N13852706505242dbbf07d0228672ff5f {uri: 'N13852706505242dbbf07d0228672ff5f'}),
# (:N220558905a3d43d88282f206041f74d0 {uri: 'N220558905a3d43d88282f206041f74d0'}),
# (:Ne7751b76392c497887d65a2ec44d3f75 {uri: 'Ne7751b76392c497887d65a2ec44d3f75'}),
# (:wine_AlsatianWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AlsatianWine'}),
# (:owl_AllDifferent {uri: 'http://www.w3.org/2002/07/owl_AllDifferent'}),
# (:N16cf97c6ed1b4a0e99c2833d8108d335 {uri: 'N16cf97c6ed1b4a0e99c2833d8108d335'}),
# (:wine_MariettaCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaCabernetSauvignon'}),
# (:Ne5dc03deab9e40398de283f66db4538f {uri: 'Ne5dc03deab9e40398de283f66db4538f'}),
# (:wine_SchlossRothermel {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossRothermel'}),
# (:N31aafeb3bc7d407cb9408694dc817f85 {uri: 'N31aafeb3bc7d407cb9408694dc817f85'}),
# (:N1203916c912b41bb959ba700c769d27a {uri: 'N1203916c912b41bb959ba700c769d27a'}),
# (:wine_DryWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryWine'}),
# (:Nc28e30873b3844779c14a979ff191876 {uri: 'Nc28e30873b3844779c14a979ff191876'}),
# (:N80da0ad2a8fc4dfb87b63a4a27bea531 {uri: 'N80da0ad2a8fc4dfb87b63a4a27bea531'}),
# (:N742a940a8c1f47b58be03c0f45fb2708 {uri: 'N742a940a8c1f47b58be03c0f45fb2708'}),
# (:Ne01ab73eea0346dcb774d714d75a6245 {uri: 'Ne01ab73eea0346dcb774d714d75a6245'}),
# (:wine_MargauxRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MargauxRegion'}),
# (:wine_Red {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Red'}),
# (:wine_Sauternes {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sauternes'}),
# (:wine_LaneTannerPinotNoir {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LaneTannerPinotNoir'}),
# (:N8355df41e0174681a149dd27917f2bc8 {uri: 'N8355df41e0174681a149dd27917f2bc8'}),
# (:N6ca849a658a444bd9abbc1fb70389024 {uri: 'N6ca849a658a444bd9abbc1fb70389024'}),
# (:N87b2d2ad0e0b43a8ba09d1e907111ac2 {uri: 'N87b2d2ad0e0b43a8ba09d1e907111ac2'}),
# (:N0d6fd29068c941348b7667dcb84728b8 {uri: 'N0d6fd29068c941348b7667dcb84728b8'}),
# (:N17f42c40cbe54b39844cc8350e299e7b {uri: 'N17f42c40cbe54b39844cc8350e299e7b'}),
# (:wine_Rose {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Rose'}),
# (:N7a47eb4725034c8792eb9d65189c7c93 {uri: 'N7a47eb4725034c8792eb9d65189c7c93'}),
# (:wine_Forman {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Forman'}),
# (:wine_DryWhiteWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryWhiteWine'}),
# (:Nf79f0a107afb498b900f25fcc95ef7c6 {uri: 'Nf79f0a107afb498b900f25fcc95ef7c6'}),
# (:N8c1991c6e6f3492a84897e2639a2cbfc {uri: 'N8c1991c6e6f3492a84897e2639a2cbfc'}),
# (:wine_CortonMontrachet {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CortonMontrachet'}),
# (:N02e8b5ab78b74cdc8f230261215f0bd3 {uri: 'N02e8b5ab78b74cdc8f230261215f0bd3'}),
# (:N3152cbbb1ce54062a4081afe2e4e7ebb {uri: 'N3152cbbb1ce54062a4081afe2e4e7ebb'}),
# (:N108d2c06713a4d07a398bc5ac0acbcbc {uri: 'N108d2c06713a4d07a398bc5ac0acbcbc'}),
# (:N749f4ee950a74e64a5dbd17cdda59b59 {uri: 'N749f4ee950a74e64a5dbd17cdda59b59'}),
# (:Nfbd5a162c1d1461ba0585fecf24c2d07 {uri: 'Nfbd5a162c1d1461ba0585fecf24c2d07'}),
# (:wine_Riesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Riesling'}),
# (:wine_CongressSprings {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CongressSprings'}),
# (:wine_VentanaCheninBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_VentanaCheninBlanc'}),
# (:N6a0a47b7a94146b88fa0a5f2d7b6accd {uri: 'N6a0a47b7a94146b88fa0a5f2d7b6accd'}),
# (:Ne49587979f674e69a717c5c3bdf9f757 {uri: 'Ne49587979f674e69a717c5c3bdf9f757'}),
# (:Na5844c951cda4b5a8460e1d9a2fdfa58 {uri: 'Na5844c951cda4b5a8460e1d9a2fdfa58'}),
# (:N08df977039784a3f9de04d304d88bba6 {uri: 'N08df977039784a3f9de04d304d88bba6'}),
# (:N9cfe5c94f00546baa60d09e217741484 {uri: 'N9cfe5c94f00546baa60d09e217741484'}),
# (:Nad494a8a2ca74ac98af6ccacd4d8de62 {uri: 'Nad494a8a2ca74ac98af6ccacd4d8de62'}),
# (:Nd13ea102023246b8bd8002b479eaec8a {uri: 'Nd13ea102023246b8bd8002b479eaec8a'}),
# (:Nc6aa19bcf72548678cb606c186ad6b11 {uri: 'Nc6aa19bcf72548678cb606c186ad6b11'}),
# (:N861f00c6b2264a86931214236df1ee15 {uri: 'N861f00c6b2264a86931214236df1ee15'}),
# (:N33e7f92f78084b2b9612329584b0e183 {uri: 'N33e7f92f78084b2b9612329584b0e183'}),
# (:wine_RoseWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RoseWine'}),
# (:wine_AmericanWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AmericanWine'}),
# (:Nc20bb2e1ee0b4e2cae567ba6e37091f0 {uri: 'Nc20bb2e1ee0b4e2cae567ba6e37091f0'}),
# (:Nd045d3fdb54a43ffb5a7f2a0f4cabefe {uri: 'Nd045d3fdb54a43ffb5a7f2a0f4cabefe'}),
# (:N6a57ab8b06e64eabaaf1601edec7dd78 {uri: 'N6a57ab8b06e64eabaaf1601edec7dd78'}),
# (:N834d15fd44d4483ea389dee7064ab951 {uri: 'N834d15fd44d4483ea389dee7064ab951'}),
# (:wine_Delicate {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Delicate'}),
# (:Na8267814b12443d992c53da1b21c3906 {uri: 'Na8267814b12443d992c53da1b21c3906'}),
# (:N05cfd36f18254509a70fe55b35aaed9f {uri: 'N05cfd36f18254509a70fe55b35aaed9f'}),
# (:N6ef0f1161f8d40b898bb6b410d40be7d {uri: 'N6ef0f1161f8d40b898bb6b410d40be7d'}),
# (:N3f9366403470407c8d64d7fe70e16259 {uri: 'N3f9366403470407c8d64d7fe70e16259'}),
# (:wine_Selaks {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Selaks'}),
# (:wine_CaliforniaWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CaliforniaWine'}),
# (:owl_Restriction {uri: 'http://www.w3.org/2002/07/owl_Restriction'}),
# (:wine_Port {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Port'}),
# (:wine {uri: 'http://www.w3.org/TR/2003/CR_owl_guide_20030818/wine'}),
# (:wine_PageMillWineryCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PageMillWineryCabernetSauvignon'}),
# (:wine_hasColor {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasColor'}),
# (:wine_PetiteSyrahGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PetiteSyrahGrape'}),
# (:wine_MountEdenVineyardEdnaValleyChardonnay {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountEdenVineyardEdnaValleyChardonnay'}),
# (:N7e2645276bb5469da50851310ea12e73 {uri: 'N7e2645276bb5469da50851310ea12e73'}),
# (:Nc03c1bd9959b4f65a4f17d289bf04d53 {uri: 'Nc03c1bd9959b4f65a4f17d289bf04d53'}),
# (:N2caaf83da1a14c03919806fd6b71dfc1 {uri: 'N2caaf83da1a14c03919806fd6b71dfc1'}),
# (:wine_KathrynKennedy {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_KathrynKennedy'}),
# (:wine_IceWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_IceWine'}),
# (:wine_locatedIn {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_locatedIn'}),
# (:Nf845164d9d6c403c8574ccdf0d444cdf {uri: 'Nf845164d9d6c403c8574ccdf0d444cdf'}),
# (:N717a727cf10f4e8fab3f912902cab58a {uri: 'N717a727cf10f4e8fab3f912902cab58a'}),
# (:N7aaede17a6e547f1a21cbc9e952a0b94 {uri: 'N7aaede17a6e547f1a21cbc9e952a0b94'}),
# (:wine_PinotNoirGrape {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotNoirGrape'}),
# (:N5c91d6bbe49246f997519ffacf6234d6 {uri: 'N5c91d6bbe49246f997519ffacf6234d6'}),
# (:wine_SchlossVolradTrochenbierenausleseRiesling {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossVolradTrochenbierenausleseRiesling'}),
# (:food_PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/food_PotableLiquid'}),
# (:Nc66c601eca424af78edd7df444f70c9b {uri: 'Nc66c601eca424af78edd7df444f70c9b'}),
# (:wine_ChateauChevalBlanc {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauChevalBlanc'}),
# (:wine_Medium {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}),
# (:N94a3a910fdff46adbf4815e9282f0b63 {uri: 'N94a3a910fdff46adbf4815e9282f0b63'}),
# (:N5894981f87df48d382c77a3b8cd85ab1 {uri: 'N5894981f87df48d382c77a3b8cd85ab1'}),
# (:N06397807b57f46c2bc17befa81fe9b74 {uri: 'N06397807b57f46c2bc17befa81fe9b74'}),
# (:N79b62b080a564ea491b8ca6def63a7c0 {uri: 'N79b62b080a564ea491b8ca6def63a7c0'}),
# (:wine_producesWine {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_producesWine'}),
# (:Nde6195c0e3dd49088a202e00c42ffe71 {uri: 'Nde6195c0e3dd49088a202e00c42ffe71'}),
# (:Nef3589005445466792bc72ea4c7219fa {uri: 'Nef3589005445466792bc72ea4c7219fa'}),
# (:wine_SonomaRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SonomaRegion'}),
# (:wine_WhiteLoire {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteLoire'}),
# (:wine_CotesDOr {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CotesDOr'}),
# (:wine_WhitehallLanePrimavera {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhitehallLanePrimavera'}),
# (:N3b1168278bf8428395d6c66786c8aa97 {uri: 'N3b1168278bf8428395d6c66786c8aa97'}),
# (:Ned4fade479f242dfa5f245a2b166972d {uri: 'Ned4fade479f242dfa5f245a2b166972d'}),
# (:Na0312c7d8b46479695df533ab1488fa7 {uri: 'Na0312c7d8b46479695df533ab1488fa7'}),
# (:wine_Merlot {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Merlot'}),
# (:wine_Vintage {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Vintage'}),
# (:wine_BeaujolaisRegion {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_BeaujolaisRegion'}),
# ...
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CongressSpringsSemillon'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}) CREATE (a)_[:wine_hasBody]_>(b)
# MATCH (a {uri: 'Nd9993533dc8742919f8e8354ac8a430a'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Red'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_DryWhiteWine'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossVolradTrochenbierenausleseRiesling'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sweet'}) CREATE (a)_[:wine_hasSugar]_>(b)
# MATCH (a {uri: 'N6d21f21d839d4497984b6def49294aef'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StEmilionRegion'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountadamPinotNoir'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Moderate'}) CREATE (a)_[:wine_hasFlavor]_>(b)
# MATCH (a {uri: 'Nb2ed515965aa429fa7e3a7988905f3fd'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_adjacentRegion'}), (b {uri: 'http://www.w3.org/2002/07/owl_SymmetricProperty'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N58dc921fd71a4fdb814f9f494acb3cd8'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_locatedIn'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'Nc350f1d10d0e452c95535d39a7dfc973'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'N6838aaf5fb0c4d06b6d955cff2f82fef'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'N5f885152740a4cf09c040706dca6c59a'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineColor'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PinotBlanc'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PageMillWinery'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Winery'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N95d72ecb24004832a33fd2af533e068d'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SauvignonBlancGrape'}), (b {uri: 'http://www.w3.org/2002/07/owl_Thing'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Ne5dc03deab9e40398de283f66db4538f'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'N1bce79fd05334d3091e6b9117f4ff62d'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PageMillWinery'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'N4b4eda87e992408d8b9b1c817051b84d'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'N5cc5f175c42a46f692ab3d21d6f72738'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'N1aa08f801c804a318d797d93cd84cc4b'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_RedWine'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetSauvignonGrape'}), (b {uri: 'http://www.w3.org/2002/07/owl_Thing'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N97182d57d9d247c98bc6828adcb469bb'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Wine'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'Nde0de72efcec440aa682d256544d2d8e'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'N9cc43e14dec641c496d6db9015a55dd8'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasBody'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Bancroft'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Winery'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N415ded5ceeef451c9e52ee2cab660b2e'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_White'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'N68a43f163f1249109d036a36cd3d34f1'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Strong'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StonleighSauvignonBlanc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}) CREATE (a)_[:wine_hasBody]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_AmericanWine'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Pauillac'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N95d72ecb24004832a33fd2af533e068d'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'Na7d30bf2eb224da58a996a6c05abb313'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_locatedIn'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'Nfa155d0746ce4bfc9b39f6229bf04767'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CheninBlancGrape'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'N068bc8d122c64715a9fea4e54a699213'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineColor'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MuscadetRegion'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_LoireRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'Nd69dd99a2b5346a9ae610c3f599d30a6'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medoc'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_White'}), (b {uri: 'http://www.w3.org/2002/07/owl_Thing'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N5fde37fd5772470a969c7e95a353ede6'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Red'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'N80bf91242011448b881f451c29ddb767'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Moderate'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_StEmilion'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MuscadetRegion'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Region'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N5c474a83ef034febbba4b7e7edc7ba72'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CotturiZinfandel'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SonomaRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SauvignonBlancGrape'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineGrape'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_yearValue'}), (b {uri: 'http://www.w3.org/2001/XMLSchema_positiveInteger'}) CREATE (a)_[:rdf_schema_range]_>(b)
# MATCH (a {uri: 'Nd8d55b3f8a6341ecbe17246a8aee0fbb'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Wine'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WhiteLoire'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N3152cbbb1ce54062a4081afe2e4e7ebb'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'Nf157927f1ef647ea9886dd08e1c2d9a9'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasColor'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CabernetSauvignonGrape'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_WineGrape'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'Nf2e284794f4a45b5a433fa7d1a61d63a'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansPrivateBinSauvignonBlanc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Corbans'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Foxen'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Winery'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Margaux'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N5c474a83ef034febbba4b7e7edc7ba72'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Red'}), (b {uri: 'http://www.w3.org/2002/07/owl_Thing'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N8c83e2468a764b1ab9af534a90eed0a5'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasFlavor'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'Nfde6d21315b446408a07802767be014b'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_CorbansSauvignonBlanc'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_NewZealandRegion'}) CREATE (a)_[:wine_locatedIn]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SancerreRegion'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Region'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N244ab0ceb766418f87c5e77925f8c985'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasFlavor'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SemillonGrape'}), (b {uri: 'http://www.w3.org/2002/07/owl_Thing'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_PulignyMontrachetWhiteBurgundy'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}) CREATE (a)_[:wine_hasBody]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MariettaZinfandel'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Marietta'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SaucelitoCanyonZinfandel1998'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}) CREATE (a)_[:wine_hasBody]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Riesling'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N3b99c55c1e5747109628d0144f6bb7a7'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Medium'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'Ncf4528a9c5f948e4bb43bd566f7a18de'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Dry'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountEdenVineyardEstatePinotNoir'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_MountEdenVineyard'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'N197dbdb0c01a4bb1afa79561267fdc05'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N50493e478d6547d29e30c6dc0a76f480'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasSugar'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SevreEtMaineMuscadet'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SevreEtMaine'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_SchlossRothermelTrochenbierenausleseRiesling'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Sweet'}) CREATE (a)_[:wine_hasSugar]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_locatedIn'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Region'}) CREATE (a)_[:rdf_schema_range]_>(b)
# MATCH (a {uri: 'Nfde6d21315b446408a07802767be014b'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'N071ab38be9cb490a97d7369a462bd51e'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMargaux'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauMargauxWinery'}) CREATE (a)_[:wine_hasMaker]_>(b)
# MATCH (a {uri: 'N3bcc9b35b20647589622d69736f78eb7'}), (b {uri: 'http://www.w3.org/2002/07/owl_Restriction'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N1f747b389c6c46608af88c65eb92b3ae'}), (b {uri: 'http://www.w3.org/1999/02/22_rdf_syntax_ns_nil'}) CREATE (a)_[:22_rdf_syntax_ns_rest]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_KalinCellarsSemillon'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Full'}) CREATE (a)_[:wine_hasBody]_>(b)
# MATCH (a {uri: 'Ndcd1b72f55f5463d88c21bdf700254ff'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_madeFromGrape'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'N598a801deb5e4c85b53598f295434053'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Rose'}) CREATE (a)_[:owl_hasValue]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Burgundy'}), (b {uri: 'http://www.w3.org/2002/07/owl_Class'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_ChateauDeMeursaultMeursault'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Meursault'}) CREATE (a)_[:22_rdf_syntax_ns_type]_>(b)
# MATCH (a {uri: 'N2a0f0e2bbe7f404f9b9a460b9e6f881e'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_hasBody'}) CREATE (a)_[:owl_onProperty]_>(b)
# MATCH (a {uri: 'N6ddff17d1af8461788a33529432d22d8'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_TableWine'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# MATCH (a {uri: 'Nca532db954cc470f923f1b33d3a7725c'}), (b {uri: 'http://www.w3.org/TR/2003/PR_owl_guide_20031209/wine_Moderate'}) CREATE (a)_[:22_rdf_syntax_ns_first]_>(b)
# CPU times: user 90.6 ms, sys: 4.65 ms, total: 95.3 ms
# Wall time: 87.9 ms

# %% [markdown]
# ### TuringDB v1

# %%
def rdf_to_cypher_v1(rdf_file):
    from rdflib import Graph
    
    g = Graph()
    g.parse(rdf_file)
    
    # Collect nodes
    nodes = {str(s) for s, _, _ in g} | {str(o) for _, _, o in g if not isinstance(o, str) or o.startswith('http')}
    node_to_var = {node: f"n{i}" for i, node in enumerate(nodes)}
    
    parts = []
    
    # Add all nodes
    for node in nodes:
        var = node_to_var[node]
        label = node.split('/')[-1]
        # Prefix label with underscore if it starts with a digit
        if label and label[0].isdigit():
            label = 'ID_' + label
        parts.append(f"({var}:{label} {{uri: '{node}'}})")
    
    # Add all edges
    for s, p, o in g:
        if not isinstance(o, str) or o.startswith('http'):
            s_var = node_to_var[str(s)]
            o_var = node_to_var[str(o)]
            pred = str(p).split('/')[-1]
            # Prefix predicate with underscore if it starts with a digit
            if pred and pred[0].isdigit():
                pred = 'ID_' + pred
            parts.append(f"({s_var})-[:{pred}]->({o_var})")
    
    return "CREATE " + ",\n".join(parts)

# %%
def sanitize_identifier(s):
    """Sanitize identifiers (labels, relationship types, property names)"""
    if not s:
        return "ID_empty"
    
    # Replace invalid characters with underscores
    s = s.replace('#', '_').replace('-', '_').replace('/', '_').replace('.', '_')
    
    # Prefix with ID_ if starts with digit or underscore
    if s[0].isdigit() or s[0] == '_':
        s = 'ID_' + s
    
    # Remove any other non-alphanumeric characters except underscores
    s = ''.join(c if c.isalnum() or c == '_' else '_' for c in s)
    
    return s

def sanitize_value(s):
    """Sanitize property values (escape quotes)"""
    return s.replace("'", "\\'").replace('"', '\\"')

def rdf_to_cypher_v1(rdf_file):
    from rdflib import Graph
    
    g = Graph()
    g.parse(rdf_file)
    
    # Collect nodes
    nodes = {str(s) for s, _, _ in g} | {str(o) for _, _, o in g if not isinstance(o, str) or o.startswith('http')}
    node_to_var = {node: f"n{i}" for i, node in enumerate(nodes)}
    
    parts = []
    
    # Add all nodes
    for node in nodes:
        var = node_to_var[node]
        label = sanitize_identifier(node.split('/')[-1])
        uri_value = sanitize_value(node)
        parts.append(f"({var}:{label} {{uri: '{uri_value}'}})")
    
    # Add all edges
    for s, p, o in g:
        if not isinstance(o, str) or o.startswith('http'):
            s_var = node_to_var[str(s)]
            o_var = node_to_var[str(o)]
            pred = sanitize_identifier(str(p).split('/')[-1])
            parts.append(f"({s_var})-[:{pred}]-({o_var})")
    
    return "CREATE " + ",\n".join(parts)

# %%
#%%time

# Create Cypher CREATE command for TuringDB v1
graph_CREATE_command_v1 = rdf_to_cypher_v1(path_rdf)
#graph_CREATE_command_v1 = sanitize_cypher_query(graph_CREATE_command_v1)
print(graph_CREATE_command_v1)
# Out:
# CREATE (n0:wine_McGuinnesso {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#McGuinnesso'}),
# (n1:N45afd4d09aed44c18260becab9e5f776 {uri: 'N45afd4d09aed44c18260becab9e5f776'}),
# (n2:N2d32403080e5464089334ccba8627853 {uri: 'N2d32403080e5464089334ccba8627853'}),
# (n3:N685a68eabbbf46b4915436530266012d {uri: 'N685a68eabbbf46b4915436530266012d'}),
# (n4:wine_WineFlavor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineFlavor'}),
# (n5:N7ef77ac676ff494ab724062aad8e4763 {uri: 'N7ef77ac676ff494ab724062aad8e4763'}),
# (n6:wine_hasWineDescriptor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasWineDescriptor'}),
# (n7:wine_WhiteBordeaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteBordeaux'}),
# (n8:N61981cfaf03b4aa783a51c607c080109 {uri: 'N61981cfaf03b4aa783a51c607c080109'}),
# (n9:wine_Wine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Wine'}),
# (n10:Ndbf0bacf82d14217a6b8e0f630e4ef22 {uri: 'Ndbf0bacf82d14217a6b8e0f630e4ef22'}),
# (n11:N9b97dbf8fbd14a4182608fdfd72f7c05 {uri: 'N9b97dbf8fbd14a4182608fdfd72f7c05'}),
# (n12:Ne482cf799ae847398d91409d38dfce49 {uri: 'Ne482cf799ae847398d91409d38dfce49'}),
# (n13:Nf13a8b3367eb4176abacdcade29a16b2 {uri: 'Nf13a8b3367eb4176abacdcade29a16b2'}),
# (n14:wine_MountEdenVineyardEstatePinotNoir {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountEdenVineyardEstatePinotNoir'}),
# (n15:Nacecea0296e8418aaa25b8abd38eeaa4 {uri: 'Nacecea0296e8418aaa25b8abd38eeaa4'}),
# (n16:wine_VintageYear {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#VintageYear'}),
# (n17:Na729e16d1a1748cdaafd6b8caf7324af {uri: 'Na729e16d1a1748cdaafd6b8caf7324af'}),
# (n18:N3aabbd3da1ae4c76aed7a6cb8e022508 {uri: 'N3aabbd3da1ae4c76aed7a6cb8e022508'}),
# (n19:N1089ca4ea67148ad80cc5385526bc13a {uri: 'N1089ca4ea67148ad80cc5385526bc13a'}),
# (n20:wine_Medoc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Medoc'}),
# (n21:N9cccbfd25d97497c800f72cdf552a1e8 {uri: 'N9cccbfd25d97497c800f72cdf552a1e8'}),
# (n22:wine_DAnjou {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DAnjou'}),
# (n23:wine_hasBody {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasBody'}),
# (n24:wine_Margaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Margaux'}),
# (n25:wine_ChateauChevalBlancStEmilion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauChevalBlancStEmilion'}),
# (n26:wine_CabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignon'}),
# (n27:wine_TableWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TableWine'}),
# (n28:N57514b1c75f6446282fefa02db99ef25 {uri: 'N57514b1c75f6446282fefa02db99ef25'}),
# (n29:N9f5b0d799fc64dc8947eb7d484203f97 {uri: 'N9f5b0d799fc64dc8947eb7d484203f97'}),
# (n30:wine_ChateauDYchem {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDYchem'}),
# (n31:N36265fc259e84028b87c3c23ea6e1ec4 {uri: 'N36265fc259e84028b87c3c23ea6e1ec4'}),
# (n32:Ne6be897d6aa844528ea82512b1157db1 {uri: 'Ne6be897d6aa844528ea82512b1157db1'}),
# (n33:N7df7f62a4aba4946ab528c4a9a8daf4a {uri: 'N7df7f62a4aba4946ab528c4a9a8daf4a'}),
# (n34:Nf088116047e64bca86734571b2d3e4e4 {uri: 'Nf088116047e64bca86734571b2d3e4e4'}),
# (n35:wine_ChateauDYchemSauterne {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDYchemSauterne'}),
# (n36:wine_MountadamPinotNoir {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamPinotNoir'}),
# (n37:Nee4cc866ea0b440194e91c141431b64b {uri: 'Nee4cc866ea0b440194e91c141431b64b'}),
# (n38:N15d8df0a01b248d2b68edfddc18074f7 {uri: 'N15d8df0a01b248d2b68edfddc18074f7'}),
# (n39:wine_MeursaultRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MeursaultRegion'}),
# (n40:wine_hasFlavor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasFlavor'}),
# (n41:Nc0af6a02318a445ab9269227bff7d7bb {uri: 'Nc0af6a02318a445ab9269227bff7d7bb'}),
# (n42:N3666caf665394ccaaf7b9c4e511912eb {uri: 'N3666caf665394ccaaf7b9c4e511912eb'}),
# (n43:wine_Stonleigh {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Stonleigh'}),
# (n44:Na24a559e18e6448ba5893326620575f2 {uri: 'Na24a559e18e6448ba5893326620575f2'}),
# (n45:wine_ChateauDeMeursault {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDeMeursault'}),
# (n46:N815b369aec1d499884902847b0224859 {uri: 'N815b369aec1d499884902847b0224859'}),
# (n47:wine_ClosDeLaPoussie {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeLaPoussie'}),
# (n48:wine_BancroftChardonnay {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BancroftChardonnay'}),
# (n49:N62895f0b362e4adda853fa292e297d69 {uri: 'N62895f0b362e4adda853fa292e297d69'}),
# (n50:N9698412921b8407c81c5b66eaaa5ebfa {uri: 'N9698412921b8407c81c5b66eaaa5ebfa'}),
# (n51:Nfd1cf1cf1bbf48328b3082df4e046b62 {uri: 'Nfd1cf1cf1bbf48328b3082df4e046b62'}),
# (n52:N85ff9702666449eca0fd87051d82a380 {uri: 'N85ff9702666449eca0fd87051d82a380'}),
# (n53:N7ae7a81744f6456abfc911cbb9f8fea0 {uri: 'N7ae7a81744f6456abfc911cbb9f8fea0'}),
# (n54:N412f20cac82c4dd38e4a3270103de7fc {uri: 'N412f20cac82c4dd38e4a3270103de7fc'}),
# (n55:N322249c1bfa043edb5e6bf661b68049e {uri: 'N322249c1bfa043edb5e6bf661b68049e'}),
# (n56:wine_TexasWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TexasWine'}),
# (n57:N02fa48be87a449709d4d385fb136a72f {uri: 'N02fa48be87a449709d4d385fb136a72f'}),
# (n58:N25eb8a9d95b643458391cb6fd47f2d54 {uri: 'N25eb8a9d95b643458391cb6fd47f2d54'}),
# (n59:wine_StGenevieve {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StGenevieve'}),
# (n60:wine_FrenchRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FrenchRegion'}),
# (n61:wine_PauillacRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PauillacRegion'}),
# (n62:Nc8ce34a1b2a047dc8ad855e708a9d04f {uri: 'Nc8ce34a1b2a047dc8ad855e708a9d04f'}),
# (n63:Nfaaf7b3488434f16b2f7abdc698c7a33 {uri: 'Nfaaf7b3488434f16b2f7abdc698c7a33'}),
# (n64:N910216fc65324c66940a5ab32c9ccc67 {uri: 'N910216fc65324c66940a5ab32c9ccc67'}),
# (n65:N328714bc5b774adb93c7ac4e93221c44 {uri: 'N328714bc5b774adb93c7ac4e93221c44'}),
# (n66:N3c069d62798b4b8f97c0722f1bf21014 {uri: 'N3c069d62798b4b8f97c0722f1bf21014'}),
# (n67:Nfcb5be67b36c4af9a5cd70bc3f5de94b {uri: 'Nfcb5be67b36c4af9a5cd70bc3f5de94b'}),
# (n68:Ncdbd504f81b942ada9169f9198e3463e {uri: 'Ncdbd504f81b942ada9169f9198e3463e'}),
# (n69:N81f7c079bfc243159289dacb1829502a {uri: 'N81f7c079bfc243159289dacb1829502a'}),
# (n70:N1f3a997c795848e48d625b33db759f7c {uri: 'N1f3a997c795848e48d625b33db759f7c'}),
# (n71:N5d910aac7b1a49519b935bed02641bb4 {uri: 'N5d910aac7b1a49519b935bed02641bb4'}),
# (n72:Nf43d88defb2046c397616cff0b74de4d {uri: 'Nf43d88defb2046c397616cff0b74de4d'}),
# (n73:N0d2a8ec89e4d43fcbad87735f24eddae {uri: 'N0d2a8ec89e4d43fcbad87735f24eddae'}),
# (n74:N4edd556e9d2a4bbb83387090b9749bfd {uri: 'N4edd556e9d2a4bbb83387090b9749bfd'}),
# (n75:wine_EdnaValleyRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EdnaValleyRegion'}),
# (n76:Naf89f1fe551e4b3a8b9acf9f6f180a01 {uri: 'Naf89f1fe551e4b3a8b9acf9f6f180a01'}),
# (n77:N621082847c6645bd9828565a509296d2 {uri: 'N621082847c6645bd9828565a509296d2'}),
# (n78:wine_StGenevieveTexasWhite {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StGenevieveTexasWhite'}),
# (n79:wine_CorbansPrivateBinSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansPrivateBinSauvignonBlanc'}),
# (n80:N84030a039ec2427496d9c901820bb097 {uri: 'N84030a039ec2427496d9c901820bb097'}),
# (n81:wine_PageMillWinery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PageMillWinery'}),
# (n82:N6dfa9e347d844147bb93adfff79fc676 {uri: 'N6dfa9e347d844147bb93adfff79fc676'}),
# (n83:N273e14549bd84592a85f7e9b511bae9f {uri: 'N273e14549bd84592a85f7e9b511bae9f'}),
# (n84:Nc6239952973442fbae3f197ba8b63f01 {uri: 'Nc6239952973442fbae3f197ba8b63f01'}),
# (n85:N6ae4107a102249039b02d8c419c571df {uri: 'N6ae4107a102249039b02d8c419c571df'}),
# (n86:wine_MariettaOldVinesRed {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaOldVinesRed'}),
# (n87:wine_Semillon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Semillon'}),
# (n88:food_madeFromFruit {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#madeFromFruit'}),
# (n89:Ne84d79103ee647388fa6c05287ebf6d6 {uri: 'Ne84d79103ee647388fa6c05287ebf6d6'}),
# (n90:N4a46ebc8c56e4d08b51ad9389142dbac {uri: 'N4a46ebc8c56e4d08b51ad9389142dbac'}),
# (n91:Nc688bd5e5fb845b0b60b1fca09e12873 {uri: 'Nc688bd5e5fb845b0b60b1fca09e12873'}),
# (n92:N251a4eede6874c448f315b2c451cfdf6 {uri: 'N251a4eede6874c448f315b2c451cfdf6'}),
# (n93:N54cf4289a85d4a3f83c4945d906e98e5 {uri: 'N54cf4289a85d4a3f83c4945d906e98e5'}),
# (n94:N161aa1c320fe4617b4491cdbd8eeebe7 {uri: 'N161aa1c320fe4617b4491cdbd8eeebe7'}),
# (n95:wine_CheninBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlanc'}),
# (n96:wine_SancerreRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SancerreRegion'}),
# (n97:N5469f78e31b4493397c3d545f1c39dc8 {uri: 'N5469f78e31b4493397c3d545f1c39dc8'}),
# (n98:N1f3fa1fe7ea440e8858adc479cf742a4 {uri: 'N1f3fa1fe7ea440e8858adc479cf742a4'}),
# (n99:N51a6d341212245848fe4147b81205979 {uri: 'N51a6d341212245848fe4147b81205979'}),
# (n100:N199fc52c41f84ab1961a6e233bb61a16 {uri: 'N199fc52c41f84ab1961a6e233bb61a16'}),
# (n101:Nbfa0388255ba48f3ae00aa6059015053 {uri: 'Nbfa0388255ba48f3ae00aa6059015053'}),
# (n102:Nd48a4b52089b4981a7fed006e5c9355e {uri: 'Nd48a4b52089b4981a7fed006e5c9355e'}),
# (n103:Nf8eb5fd6a6f3490eba57e0abaceb6999 {uri: 'Nf8eb5fd6a6f3490eba57e0abaceb6999'}),
# (n104:wine_WhiteTableWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteTableWine'}),
# (n105:wine_StonleighSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#StonleighSauvignonBlanc'}),
# (n106:wine_SangioveseGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SangioveseGrape'}),
# (n107:N38cb0ba3ced84b70a82bfb07a2e57f70 {uri: 'N38cb0ba3ced84b70a82bfb07a2e57f70'}),
# (n108:Nc107f295ae97401785669aa8aab67220 {uri: 'Nc107f295ae97401785669aa8aab67220'}),
# (n109:N7ba1b398390f4d1bb50188dc4955d55d {uri: 'N7ba1b398390f4d1bb50188dc4955d55d'}),
# (n110:wine_ArroyoGrandeRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ArroyoGrandeRegion'}),
# (n111:N28511cdaf9b24bbe99edf723582a5d9b {uri: 'N28511cdaf9b24bbe99edf723582a5d9b'}),
# (n112:N0a789644eba34afc83367482dd755884 {uri: 'N0a789644eba34afc83367482dd755884'}),
# (n113:wine_CabernetSauvignonGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetSauvignonGrape'}),
# (n114:N7acafcf6a1134b2784b6407cebbf6362 {uri: 'N7acafcf6a1134b2784b6407cebbf6362'}),
# (n115:wine_ClosDeVougeot {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeVougeot'}),
# (n116:wine_BordeauxRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#BordeauxRegion'}),
# (n117:N15a5c3c082594b6b85c5244b17ddd873 {uri: 'N15a5c3c082594b6b85c5244b17ddd873'}),
# (n118:Nba6349d17f0c40dca74eca430adc1f81 {uri: 'Nba6349d17f0c40dca74eca430adc1f81'}),
# (n119:wine_AlsaceRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AlsaceRegion'}),
# (n120:Nd660d0d8d8a34df7a12e965085eb9ca5 {uri: 'Nd660d0d8d8a34df7a12e965085eb9ca5'}),
# (n121:N7bd440b7a9d94d3dafd8c03ccabf48c5 {uri: 'N7bd440b7a9d94d3dafd8c03ccabf48c5'}),
# (n122:wine_Tours {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Tours'}),
# (n123:wine_ChateauLafiteRothschild {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauLafiteRothschild'}),
# (n124:N60ce2c7d958d4f589eaee19f4feaaa3a {uri: 'N60ce2c7d958d4f589eaee19f4feaaa3a'}),
# (n125:wine_Sancerre {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sancerre'}),
# (n126:wine_Beringer {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Beringer'}),
# (n127:wine_CabernetFranc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CabernetFranc'}),
# (n128:wine_GamayGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GamayGrape'}),
# (n129:wine_AnjouRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AnjouRegion'}),
# (n130:wine_GermanWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GermanWine'}),
# (n131:wine_LateHarvest {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LateHarvest'}),
# (n132:N4f0fac2442754058b25970d00b3b0365 {uri: 'N4f0fac2442754058b25970d00b3b0365'}),
# (n133:wine_PulignyMontrachetWhiteBurgundy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PulignyMontrachetWhiteBurgundy'}),
# (n134:Neab517d48c34450f93f9f8bedf256dee {uri: 'Neab517d48c34450f93f9f8bedf256dee'}),
# (n135:Nd51ec05f41594c34b5615bf3ad4d0109 {uri: 'Nd51ec05f41594c34b5615bf3ad4d0109'}),
# (n136:Ne1eb0f34ebf44e20a9ba7ff02d07885f {uri: 'Ne1eb0f34ebf44e20a9ba7ff02d07885f'}),
# (n137:N0d232190a2294e759a471b4ae19443dc {uri: 'N0d232190a2294e759a471b4ae19443dc'}),
# (n138:N9970bb5f542448d598845bd05d684f1a {uri: 'N9970bb5f542448d598845bd05d684f1a'}),
# (n139:wine_LongridgeMerlot {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LongridgeMerlot'}),
# (n140:Ndf0d3ef47c5e4849bc74313db29ed4d2 {uri: 'Ndf0d3ef47c5e4849bc74313db29ed4d2'}),
# (n141:Ne510f1d45b3a42cda63f7ca68e16ae1c {uri: 'Ne510f1d45b3a42cda63f7ca68e16ae1c'}),
# (n142:wine_SevreEtMaineMuscadet {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaineMuscadet'}),
# (n143:N7d87a79ec4004868a47c65c7ce1b532e {uri: 'N7d87a79ec4004868a47c65c7ce1b532e'}),
# (n144:wine_hasVintageYear {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasVintageYear'}),
# (n145:wine_RedBurgundy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedBurgundy'}),
# (n146:wine_Full {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Full'}),
# (n147:wine_WhitehallLaneCabernetFranc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhitehallLaneCabernetFranc'}),
# (n148:N77dcf40483c749faafa3158c3c282e9c {uri: 'N77dcf40483c749faafa3158c3c282e9c'}),
# (n149:N4e44a2d53e8b4094b453c4e494d6d2f5 {uri: 'N4e44a2d53e8b4094b453c4e494d6d2f5'}),
# (n150:N1a41749c3f0a4326b5ec5db26939647b {uri: 'N1a41749c3f0a4326b5ec5db26939647b'}),
# (n151:N03c1f351c3084826913a9702aa20a0b6 {uri: 'N03c1f351c3084826913a9702aa20a0b6'}),
# (n152:wine_Ventana {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Ventana'}),
# (n153:N9944ba24320a4e6e8daf8917f9f195ad {uri: 'N9944ba24320a4e6e8daf8917f9f195ad'}),
# (n154:Nf0fd1fed18f64a54ac7c344c5f12aa1e {uri: 'Nf0fd1fed18f64a54ac7c344c5f12aa1e'}),
# (n155:wine_EarlyHarvest {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#EarlyHarvest'}),
# (n156:wine_MariettaPetiteSyrah {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaPetiteSyrah'}),
# (n157:wine_SelaksSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SelaksSauvignonBlanc'}),
# (n158:wine_SantaCruzMountainVineyardCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaCruzMountainVineyardCabernetSauvignon'}),
# (n159:wine_PinotBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotBlanc'}),
# (n160:N6d353bd579bc43558923bb3d541a44c5 {uri: 'N6d353bd579bc43558923bb3d541a44c5'}),
# (n161:wine_Elyse {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Elyse'}),
# (n162:N8fd305f9520f41afb7f347b859b1cfd6 {uri: 'N8fd305f9520f41afb7f347b859b1cfd6'}),
# (n163:N44779ba8554e40ebadd15868c91bb3d1 {uri: 'N44779ba8554e40ebadd15868c91bb3d1'}),
# (n164:Nfc934c044b6a4471afbec6867ff6bd5f {uri: 'Nfc934c044b6a4471afbec6867ff6bd5f'}),
# (n165:wine_USRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#USRegion'}),
# (n166:wine_Burgundy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Burgundy'}),
# (n167:wine_Year1998 {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Year1998'}),
# (n168:N61a40dd4298f4aa3b3e9cb306f8599a5 {uri: 'N61a40dd4298f4aa3b3e9cb306f8599a5'}),
# (n169:wine_SauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauvignonBlanc'}),
# (n170:N812bd592305f4d3d959e1b20e9091fbd {uri: 'N812bd592305f4d3d959e1b20e9091fbd'}),
# (n171:N689bc6404bd4416e92eec62d58ca5737 {uri: 'N689bc6404bd4416e92eec62d58ca5737'}),
# (n172:wine_ClosDeVougeotCotesDOr {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeVougeotCotesDOr'}),
# (n173:N6d811d47592f4fad84fb3f8ef5eae9b4 {uri: 'N6d811d47592f4fad84fb3f8ef5eae9b4'}),
# (n174:Nf1bcc5eabf944b32811f8d64a8e7e9c4 {uri: 'Nf1bcc5eabf944b32811f8d64a8e7e9c4'}),
# (n175:N6c29feacd97c46d9bedba5d518c926b8 {uri: 'N6c29feacd97c46d9bedba5d518c926b8'}),
# (n176:wine_ItalianRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ItalianRegion'}),
# (n177:Nc906fccfa4c94d8c92bc27bdbe7e40b2 {uri: 'Nc906fccfa4c94d8c92bc27bdbe7e40b2'}),
# (n178:Ne11052cf73074122a41ca1cfb234aaba {uri: 'Ne11052cf73074122a41ca1cfb234aaba'}),
# (n179:N11b9977174f2476690f6f08d5aba966b {uri: 'N11b9977174f2476690f6f08d5aba966b'}),
# (n180:N4febe0301b6747a88d214cebfeb86351 {uri: 'N4febe0301b6747a88d214cebfeb86351'}),
# (n181:wine_SweetWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SweetWine'}),
# (n182:wine_RoseDAnjou {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RoseDAnjou'}),
# (n183:Nca1a224a6df549b68e64d293cf3972b8 {uri: 'Nca1a224a6df549b68e64d293cf3972b8'}),
# (n184:wine_CentralCoastRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CentralCoastRegion'}),
# (n185:Nf03d0e50d9fb41b987acf425717ecf80 {uri: 'Nf03d0e50d9fb41b987acf425717ecf80'}),
# (n186:N5c555245625f4a3f9a4501a6d1ced891 {uri: 'N5c555245625f4a3f9a4501a6d1ced891'}),
# (n187:wine_FormanChardonnay {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FormanChardonnay'}),
# (n188:ID_22_rdf_syntax_ns_nil {uri: 'http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'}),
# (n189:wine_ChateauMorgon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMorgon'}),
# (n190:Ncc254430e3394b3382c00cdf5a9d9927 {uri: 'Ncc254430e3394b3382c00cdf5a9d9927'}),
# (n191:wine_KalinCellars {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KalinCellars'}),
# (n192:N11d0085ba7a04f5eb9441070b6a9d716 {uri: 'N11d0085ba7a04f5eb9441070b6a9d716'}),
# (n193:N9919d637e7b5485abc8a1cf585914e1c {uri: 'N9919d637e7b5485abc8a1cf585914e1c'}),
# (n194:N84165acba0064a1588699d596e833331 {uri: 'N84165acba0064a1588699d596e833331'}),
# (n195:wine_FullBodiedWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FullBodiedWine'}),
# (n196:Nae5b526a4cb04d27b5d4db586e798521 {uri: 'Nae5b526a4cb04d27b5d4db586e798521'}),
# (n197:Nfa1047820ca5400a9d29268943ce0f1b {uri: 'Nfa1047820ca5400a9d29268943ce0f1b'}),
# (n198:N670b42238cf24dd99a6c6470573c8391 {uri: 'N670b42238cf24dd99a6c6470573c8391'}),
# (n199:Na7e8a01da19b4670922afa2f8bff0b34 {uri: 'Na7e8a01da19b4670922afa2f8bff0b34'}),
# (n200:N2608f12692a747bda279a9755ae519bb {uri: 'N2608f12692a747bda279a9755ae519bb'}),
# (n201:N810e3291328344d49b1e46c04f2561ed {uri: 'N810e3291328344d49b1e46c04f2561ed'}),
# (n202:wine_SouthAustraliaRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SouthAustraliaRegion'}),
# (n203:N6a2b1ffb91e74856a85434ef1f219bbb {uri: 'N6a2b1ffb91e74856a85434ef1f219bbb'}),
# (n204:N16327cbaf8bd4f97a0ed707609bb3dd1 {uri: 'N16327cbaf8bd4f97a0ed707609bb3dd1'}),
# (n205:wine_ElyseZinfandel {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ElyseZinfandel'}),
# (n206:N5521888a533944ebaed7d28fc103fa36 {uri: 'N5521888a533944ebaed7d28fc103fa36'}),
# (n207:N3201602952244328a4628fa1e5221fc0 {uri: 'N3201602952244328a4628fa1e5221fc0'}),
# (n208:N4b03babe4ca4459b9f5f72fcf5d64dad {uri: 'N4b03babe4ca4459b9f5f72fcf5d64dad'}),
# (n209:N4b2f6eb1e81a47358c626c083fb9de65 {uri: 'N4b2f6eb1e81a47358c626c083fb9de65'}),
# (n210:owl_Class {uri: 'http://www.w3.org/2002/07/owl#Class'}),
# (n211:wine_ChiantiRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChiantiRegion'}),
# (n212:wine_WhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WhiteWine'}),
# (n213:Ncad28c8955974566a617d56b6bb412ce {uri: 'Ncad28c8955974566a617d56b6bb412ce'}),
# (n214:N21ee52306a6448c2987621b420fdb383 {uri: 'N21ee52306a6448c2987621b420fdb383'}),
# (n215:Nea58088de7514060b60d12ddf7b928aa {uri: 'Nea58088de7514060b60d12ddf7b928aa'}),
# (n216:Nff76f0f6d1ac427a92c44e8e7f64def5 {uri: 'Nff76f0f6d1ac427a92c44e8e7f64def5'}),
# (n217:wine_GermanyRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GermanyRegion'}),
# (n218:Ne0385405077d4947b1fa25237ffa2130 {uri: 'Ne0385405077d4947b1fa25237ffa2130'}),
# (n219:N7a431f0e7b3e4726b9152fe17d5204f1 {uri: 'N7a431f0e7b3e4726b9152fe17d5204f1'}),
# (n220:Na9719c93a6ba4fae97e6fe8a69ff8359 {uri: 'Na9719c93a6ba4fae97e6fe8a69ff8359'}),
# (n221:N15b2b252fbd44e6ba71dbcd99a46608e {uri: 'N15b2b252fbd44e6ba71dbcd99a46608e'}),
# (n222:N690ec1370b474fde878bde790a42341e {uri: 'N690ec1370b474fde878bde790a42341e'}),
# (n223:N04c03792a7234630a44ba23274146ab6 {uri: 'N04c03792a7234630a44ba23274146ab6'}),
# (n224:wine_SeanThackrey {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SeanThackrey'}),
# (n225:Ne857643a75b648f481711f4bdb3ff07f {uri: 'Ne857643a75b648f481711f4bdb3ff07f'}),
# (n226:wine_CongressSpringsSemillon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CongressSpringsSemillon'}),
# (n227:N699b8b3efe3f4cca9ef3bbab8b24b45f {uri: 'N699b8b3efe3f4cca9ef3bbab8b24b45f'}),
# (n228:N2b271e821704481c9eb13e9cad3741c3 {uri: 'N2b271e821704481c9eb13e9cad3741c3'}),
# (n229:wine_AustralianRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AustralianRegion'}),
# (n230:wine_SauterneRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SauterneRegion'}),
# (n231:Need9a45b78734f90ba760367d15b48e6 {uri: 'Need9a45b78734f90ba760367d15b48e6'}),
# (n232:N350e45a6a68843788397ba4fc1ed669e {uri: 'N350e45a6a68843788397ba4fc1ed669e'}),
# (n233:wine_CorbansSauvignonBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansSauvignonBlanc'}),
# (n234:N5dbd24bf71cf448cbec8987d493cfb7b {uri: 'N5dbd24bf71cf448cbec8987d493cfb7b'}),
# (n235:N8ed6d03967454dbcafe36ffafdafd5ef {uri: 'N8ed6d03967454dbcafe36ffafdafd5ef'}),
# (n236:wine_CheninBlancGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CheninBlancGrape'}),
# (n237:N43549d0c8ec24e8c80853f67baae3e31 {uri: 'N43549d0c8ec24e8c80853f67baae3e31'}),
# (n238:N0ba86d07511045eab83eb6de098dc62a {uri: 'N0ba86d07511045eab83eb6de098dc62a'}),
# (n239:N2a2d04252ca74265bee4ee7b14ba9d79 {uri: 'N2a2d04252ca74265bee4ee7b14ba9d79'}),
# (n240:N0b14fb07e5f34560b1579947c6d19c81 {uri: 'N0b14fb07e5f34560b1579947c6d19c81'}),
# (n241:N4f76199e81c0482c8385d8958027b9e6 {uri: 'N4f76199e81c0482c8385d8958027b9e6'}),
# (n242:N160d38e9d9084b7a982a598967862c7d {uri: 'N160d38e9d9084b7a982a598967862c7d'}),
# (n243:N481f947c452843fc84e156962860324f {uri: 'N481f947c452843fc84e156962860324f'}),
# (n244:Nae0eb7f2fa9843d38f48dbd30b11051e {uri: 'Nae0eb7f2fa9843d38f48dbd30b11051e'}),
# (n245:wine_Anjou {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Anjou'}),
# (n246:food_Grape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#Grape'}),
# (n247:wine_Bordeaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Bordeaux'}),
# (n248:wine_SweetRiesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SweetRiesling'}),
# (n249:wine_ChateauMargauxWinery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMargauxWinery'}),
# (n250:Nbc59288f8ef744d79d5434800c245ba5 {uri: 'Nbc59288f8ef744d79d5434800c245ba5'}),
# (n251:N56349e5fa43249b99d962774433301e4 {uri: 'N56349e5fa43249b99d962774433301e4'}),
# (n252:wine_hasMaker {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasMaker'}),
# (n253:N2e420563e1fd41dc9d119e6b9f4aea33 {uri: 'N2e420563e1fd41dc9d119e6b9f4aea33'}),
# (n254:N9815f0792f8948c4901f17a0c0e6e2ff {uri: 'N9815f0792f8948c4901f17a0c0e6e2ff'}),
# (n255:N4a23d461c742480b9665b29399f5fccf {uri: 'N4a23d461c742480b9665b29399f5fccf'}),
# (n256:Nbd701b664a73491a8851f8ec210943dd {uri: 'Nbd701b664a73491a8851f8ec210943dd'}),
# (n257:N787dd67f16774681a9000893b8359e56 {uri: 'N787dd67f16774681a9000893b8359e56'}),
# (n258:Ndb3a9903db774f7b947f6940701d6dd6 {uri: 'Ndb3a9903db774f7b947f6940701d6dd6'}),
# (n259:Nb8f613c0078a40a68670aabc71423aaa {uri: 'Nb8f613c0078a40a68670aabc71423aaa'}),
# (n260:N40ea3b862bd0446aa2e725fb1171b768 {uri: 'N40ea3b862bd0446aa2e725fb1171b768'}),
# (n261:Ndd616ab57ad249e8a053fc9c68c27f22 {uri: 'Ndd616ab57ad249e8a053fc9c68c27f22'}),
# (n262:wine_ChateauDeMeursaultMeursault {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauDeMeursaultMeursault'}),
# (n263:wine_MountadamChardonnay {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamChardonnay'}),
# (n264:N807a4d2a543643f19186ed175e1e6bff {uri: 'N807a4d2a543643f19186ed175e1e6bff'}),
# (n265:N6433409ac7314b76868099eda16a9cb1 {uri: 'N6433409ac7314b76868099eda16a9cb1'}),
# (n266:N9dac7ddf7eb14b0e9e476d3519a8af48 {uri: 'N9dac7ddf7eb14b0e9e476d3519a8af48'}),
# (n267:wine_LoireRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LoireRegion'}),
# (n268:Nf93bf80c19f649aeb12166c9d585ad1d {uri: 'Nf93bf80c19f649aeb12166c9d585ad1d'}),
# (n269:N5a881c9133a8486182d09fe0424eb36c {uri: 'N5a881c9133a8486182d09fe0424eb36c'}),
# (n270:N38609a00c00e4696bbd9e3bf29d08689 {uri: 'N38609a00c00e4696bbd9e3bf29d08689'}),
# (n271:N5831a3c1d4604e8183ffa5a0e754fa2d {uri: 'N5831a3c1d4604e8183ffa5a0e754fa2d'}),
# (n272:N7c3293c044c64dc0ad3c7991dac687bd {uri: 'N7c3293c044c64dc0ad3c7991dac687bd'}),
# (n273:N52394d7fe93e4af4bb185bacc2a680eb {uri: 'N52394d7fe93e4af4bb185bacc2a680eb'}),
# (n274:wine_Beaujolais {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Beaujolais'}),
# (n275:N23a20dc2d5bf4371a69fab3c754e9d52 {uri: 'N23a20dc2d5bf4371a69fab3c754e9d52'}),
# (n276:wine_MendocinoRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MendocinoRegion'}),
# (n277:wine_RedBordeaux {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RedBordeaux'}),
# (n278:Na36a182e130145f88d73c50ef1facf29 {uri: 'Na36a182e130145f88d73c50ef1facf29'}),
# (n279:N2648d4bffd8a499b95c07483bd13640e {uri: 'N2648d4bffd8a499b95c07483bd13640e'}),
# (n280:wine_WineGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineGrape'}),
# (n281:wine_DryRedWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryRedWine'}),
# (n282:N3c82a384c3ad416693b703f407459108 {uri: 'N3c82a384c3ad416693b703f407459108'}),
# (n283:wine_ClosDeLaPoussieSancerre {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ClosDeLaPoussieSancerre'}),
# (n284:wine_MuscadetRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MuscadetRegion'}),
# (n285:N412d2400b00e451ea8ba6441597c256d {uri: 'N412d2400b00e451ea8ba6441597c256d'}),
# (n286:Nefde1320772c4fe8bcf0d68b465d8d8c {uri: 'Nefde1320772c4fe8bcf0d68b465d8d8c'}),
# (n287:Ncf980583ed3d49f9acd5e8bf104f8d13 {uri: 'Ncf980583ed3d49f9acd5e8bf104f8d13'}),
# (n288:wine_MariettaZinfandel {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaZinfandel'}),
# (n289:wine_SantaCruzMountainsRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SantaCruzMountainsRegion'}),
# (n290:wine_CaliforniaRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaRegion'}),
# (n291:N20107cc9133d4c4aa15794482a118510 {uri: 'N20107cc9133d4c4aa15794482a118510'}),
# (n292:N44f6b79128734ae9be943ee78b455835 {uri: 'N44f6b79128734ae9be943ee78b455835'}),
# (n293:wine_FrenchWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FrenchWine'}),
# (n294:wine_yearValue {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#yearValue'}),
# (n295:N9322889f697742309816e084065f6fcc {uri: 'N9322889f697742309816e084065f6fcc'}),
# (n296:owl_DatatypeProperty {uri: 'http://www.w3.org/2002/07/owl#DatatypeProperty'}),
# (n297:Ne13831e5f59249d98736cede706eddb7 {uri: 'Ne13831e5f59249d98736cede706eddb7'}),
# (n298:wine_Pauillac {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Pauillac'}),
# (n299:Ndc040ef2b27c4374977020bcf136fdd6 {uri: 'Ndc040ef2b27c4374977020bcf136fdd6'}),
# (n300:N85d4411c52d94da3a2afc19622604ef9 {uri: 'N85d4411c52d94da3a2afc19622604ef9'}),
# (n301:owl_FunctionalProperty {uri: 'http://www.w3.org/2002/07/owl#FunctionalProperty'}),
# (n302:wine_NewZealandRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#NewZealandRegion'}),
# (n303:XMLSchema_positiveInteger {uri: 'http://www.w3.org/2001/XMLSchema#positiveInteger'}),
# (n304:N9d9a3a657b8c4bd6adbaefe890d8b070 {uri: 'N9d9a3a657b8c4bd6adbaefe890d8b070'}),
# (n305:Nb8aa5775ceed4822a6d4b19d8cfe9911 {uri: 'Nb8aa5775ceed4822a6d4b19d8cfe9911'}),
# (n306:N3daf77bd616543cd9b55470c31c8d4cb {uri: 'N3daf77bd616543cd9b55470c31c8d4cb'}),
# (n307:wine_SeanThackreySiriusPetiteSyrah {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SeanThackreySiriusPetiteSyrah'}),
# (n308:wine_ChateauLafiteRothschildPauillac {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauLafiteRothschildPauillac'}),
# (n309:N4e9de1c5beb542fdbe099ed0a16c7043 {uri: 'N4e9de1c5beb542fdbe099ed0a16c7043'}),
# (n310:N049f8202724b4b9ea07aef6d91fef52e {uri: 'N049f8202724b4b9ea07aef6d91fef52e'}),
# (n311:N1706913ec59340e1845d261fe536f726 {uri: 'N1706913ec59340e1845d261fe536f726'}),
# (n312:Nc8e06b6387f94874b42552b6de42e936 {uri: 'Nc8e06b6387f94874b42552b6de42e936'}),
# (n313:wine_CotesDOrRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CotesDOrRegion'}),
# (n314:Nf3e92d856d894c67ada47b3ae37868af {uri: 'Nf3e92d856d894c67ada47b3ae37868af'}),
# (n315:wine_Cotturi {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Cotturi'}),
# (n316:N1c309301a4a54ea694afbe23296c8db9 {uri: 'N1c309301a4a54ea694afbe23296c8db9'}),
# (n317:N0004c72ad2394a4fb8666973b79b0872 {uri: 'N0004c72ad2394a4fb8666973b79b0872'}),
# (n318:Ncab3b78581d244049714a46689afa2a8 {uri: 'Ncab3b78581d244049714a46689afa2a8'}),
# (n319:wine_ChateauMorgonBeaujolais {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#ChateauMorgonBeaujolais'}),
# (n320:owl_Ontology {uri: 'http://www.w3.org/2002/07/owl#Ontology'}),
# (n321:wine_Chardonnay {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chardonnay'}),
# (n322:wine_RieslingGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#RieslingGrape'}),
# (n323:N983828b46b3641ba9b2601359ed7b7cd {uri: 'N983828b46b3641ba9b2601359ed7b7cd'}),
# (n324:N4a524a7896274e3e9759b4c48e7fd7f8 {uri: 'N4a524a7896274e3e9759b4c48e7fd7f8'}),
# (n325:Nda410c8a062b41ef80218a49c7d97210 {uri: 'Nda410c8a062b41ef80218a49c7d97210'}),
# (n326:Nfe980f08626547f49027fcf0649d60b7 {uri: 'Nfe980f08626547f49027fcf0649d60b7'}),
# (n327:wine_SaucelitoCanyonZinfandel1998 {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SaucelitoCanyonZinfandel1998'}),
# (n328:N58ddaf7701054a1c8fa2a52a0167b3dd {uri: 'N58ddaf7701054a1c8fa2a52a0167b3dd'}),
# (n329:Ne4e19e181174490e864ee57f7a04532c {uri: 'Ne4e19e181174490e864ee57f7a04532c'}),
# (n330:N98e549f68e414165a0015937c1c91acf {uri: 'N98e549f68e414165a0015937c1c91acf'}),
# (n331:N2c175dc6d19743888d8292f5c9c6d277 {uri: 'N2c175dc6d19743888d8292f5c9c6d277'}),
# (n332:wine_Chianti {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Chianti'}),
# (n333:wine_Longridge {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Longridge'}),
# (n334:Nd741a9755acb4a078be06c4416b61088 {uri: 'Nd741a9755acb4a078be06c4416b61088'}),
# (n335:wine_MedocRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MedocRegion'}),
# (n336:Nd05ffc9236f241b7a6215ae523f14833 {uri: 'Nd05ffc9236f241b7a6215ae523f14833'}),
# (n337:N1a6ee20fa2104cdb826c4cdfc769771a {uri: 'N1a6ee20fa2104cdb826c4cdfc769771a'}),
# (n338:N0c35b494b6ac44f3b2fee3c9dbe9499a {uri: 'N0c35b494b6ac44f3b2fee3c9dbe9499a'}),
# (n339:wine_CortonMontrachetWhiteBurgundy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CortonMontrachetWhiteBurgundy'}),
# (n340:Nf09fc73df8ea458badc876c8a0777071 {uri: 'Nf09fc73df8ea458badc876c8a0777071'}),
# (n341:N3876aee410554470a7d82d92024c3673 {uri: 'N3876aee410554470a7d82d92024c3673'}),
# (n342:Nb9b4b297c6194ea1ac41eefa9fb9c787 {uri: 'Nb9b4b297c6194ea1ac41eefa9fb9c787'}),
# (n343:wine_Dry {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Dry'}),
# (n344:N8882c534c8bf4a07abd8c9b12078f83e {uri: 'N8882c534c8bf4a07abd8c9b12078f83e'}),
# (n345:Nfa41acef6001460baf1ca8915c63e378 {uri: 'Nfa41acef6001460baf1ca8915c63e378'}),
# (n346:owl_SymmetricProperty {uri: 'http://www.w3.org/2002/07/owl#SymmetricProperty'}),
# (n347:N697cb2eb36b9496c80f8da92a943f3e4 {uri: 'N697cb2eb36b9496c80f8da92a943f3e4'}),
# (n348:N1d915da5b4cc4a3b94abcea966bd9cf2 {uri: 'N1d915da5b4cc4a3b94abcea966bd9cf2'}),
# (n349:wine_Winery {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Winery'}),
# (n350:N2891c1b49e044949b5dfe004a238ec6a {uri: 'N2891c1b49e044949b5dfe004a238ec6a'}),
# (n351:wine_CentralTexasRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CentralTexasRegion'}),
# (n352:N69cf8d0f65de43e3a3f57f13c960490c {uri: 'N69cf8d0f65de43e3a3f57f13c960490c'}),
# (n353:N566a830fb28b4b4fb9298444d8a708fa {uri: 'N566a830fb28b4b4fb9298444d8a708fa'}),
# (n354:wine_WineColor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineColor'}),
# (n355:N2942f16e52034a1082a9c7c24b5ef885 {uri: 'N2942f16e52034a1082a9c7c24b5ef885'}),
# (n356:N9567e0f4d3594166b56982e27248bf6e {uri: 'N9567e0f4d3594166b56982e27248bf6e'}),
# (n357:N8ab7724a93ca48189d4d09bc58fb817b {uri: 'N8ab7724a93ca48189d4d09bc58fb817b'}),
# (n358:Nb7f9972c27e44c0a8204d9f0bf2721ac {uri: 'Nb7f9972c27e44c0a8204d9f0bf2721ac'}),
# (n359:Nb0a4a2c127e04a1c84df19b86f27cfee {uri: 'Nb0a4a2c127e04a1c84df19b86f27cfee'}),
# (n360:N023822b0ac394eac9ae1b0c760c9df67 {uri: 'N023822b0ac394eac9ae1b0c760c9df67'}),
# (n361:Nd4e822073a934af0bbc1a3b3edae291d {uri: 'Nd4e822073a934af0bbc1a3b3edae291d'}),
# (n362:Na7fa290289f844b4ac7009ba2537f2be {uri: 'Na7fa290289f844b4ac7009ba2537f2be'}),
# (n363:N4ad6c02464284cdb97ac296b469b0dcc {uri: 'N4ad6c02464284cdb97ac296b469b0dcc'}),
# (n364:Nfff3f652f97d4bc086768a333507116d {uri: 'Nfff3f652f97d4bc086768a333507116d'}),
# (n365:N2578de42a8f147dd81d978de1a07a011 {uri: 'N2578de42a8f147dd81d978de1a07a011'}),
# (n366:N0262c7057253463d84b56ba8f03b0e90 {uri: 'N0262c7057253463d84b56ba8f03b0e90'}),
# (n367:N672e8c97b9e44c1682cea79b28e1a5e9 {uri: 'N672e8c97b9e44c1682cea79b28e1a5e9'}),
# (n368:Nf22c535f32904024890ce4fc80860826 {uri: 'Nf22c535f32904024890ce4fc80860826'}),
# (n369:N8f0e017fcec64725a9cba9825a94b342 {uri: 'N8f0e017fcec64725a9cba9825a94b342'}),
# (n370:wine_MountadamRiesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountadamRiesling'}),
# (n371:N1b9f05974ef948c8a85015db49b50c05 {uri: 'N1b9f05974ef948c8a85015db49b50c05'}),
# (n372:wine_NapaRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#NapaRegion'}),
# (n373:wine_SchlossRothermelTrochenbierenausleseRiesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossRothermelTrochenbierenausleseRiesling'}),
# (n374:N2a06cc429c0a4733a2cb9f4252e0ea9c {uri: 'N2a06cc429c0a4733a2cb9f4252e0ea9c'}),
# (n375:wine_FoxenCheninBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FoxenCheninBlanc'}),
# (n376:Na2ff0aba130447bfa96625c6fc53b085 {uri: 'Na2ff0aba130447bfa96625c6fc53b085'}),
# (n377:wine_PeterMccoy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PeterMccoy'}),
# (n378:Nea5f96334bff41c0a72601ea6144e0ab {uri: 'Nea5f96334bff41c0a72601ea6144e0ab'}),
# (n379:N256343f799db4b1b9ccb9437c70dfa28 {uri: 'N256343f799db4b1b9ccb9437c70dfa28'}),
# (n380:Ncb430f9dc91647ed97376cb677d23b7c {uri: 'Ncb430f9dc91647ed97376cb677d23b7c'}),
# (n381:Nc0702e9e3af748f09f71f7534f827e66 {uri: 'Nc0702e9e3af748f09f71f7534f827e66'}),
# (n382:Nf3a097d94dac4fc9a5deda0af65ad43e {uri: 'Nf3a097d94dac4fc9a5deda0af65ad43e'}),
# (n383:wine_Gamay {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Gamay'}),
# (n384:wine_PinotBlancGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotBlancGrape'}),
# (n385:Nb4176c2021d64738b5263603e280686c {uri: 'Nb4176c2021d64738b5263603e280686c'}),
# (n386:N1efe576f8e5c41949efb29ab559581fa {uri: 'N1efe576f8e5c41949efb29ab559581fa'}),
# (n387:Naf5dfd3b6e6847619fbea2e47e3b2aa1 {uri: 'Naf5dfd3b6e6847619fbea2e47e3b2aa1'}),
# (n388:wine_GaryFarrell {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#GaryFarrell'}),
# (n389:N22d1abdef55b45ecbd2e9cbdab23350c {uri: 'N22d1abdef55b45ecbd2e9cbdab23350c'}),
# (n390:wine_Corbans {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Corbans'}),
# (n391:N89e1a0dde6274d25975ac8351a1f2c64 {uri: 'N89e1a0dde6274d25975ac8351a1f2c64'}),
# (n392:wine_WineSugar {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#WineSugar'}),
# (n393:Nac49cdc3019346c6886cc5ba30f7e8fa {uri: 'Nac49cdc3019346c6886cc5ba30f7e8fa'}),
# (n394:wine_Light {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Light'}),
# (n395:Nf7d77d905abb4b1aad0d6c62da13f396 {uri: 'Nf7d77d905abb4b1aad0d6c62da13f396'}),
# (n396:N3b6cf9f9d02445adb23355112d2d56a1 {uri: 'N3b6cf9f9d02445adb23355112d2d56a1'}),
# (n397:N03c5df4e8c6e45a48fda03f6ce607360 {uri: 'N03c5df4e8c6e45a48fda03f6ce607360'}),
# (n398:N43b8a0ec71524f88b81d6ead406f1b80 {uri: 'N43b8a0ec71524f88b81d6ead406f1b80'}),
# (n399:N6af2582a8e0a44a9a87044f90f3e388f {uri: 'N6af2582a8e0a44a9a87044f90f3e388f'}),
# (n400:Nab4dc296aafb4786be58daafa99bcf3e {uri: 'Nab4dc296aafb4786be58daafa99bcf3e'}),
# (n401:wine_FormanCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#FormanCabernetSauvignon'}),
# (n402:wine_Loire {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Loire'}),
# (n403:N93e037efb2b04839a73f3e64a0ff276a {uri: 'N93e037efb2b04839a73f3e64a0ff276a'}),
# (n404:wine_PeterMccoyChardonnay {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PeterMccoyChardonnay'}),
# (n405:N0f37d35460ce4fcea0600a276b2bfa11 {uri: 'N0f37d35460ce4fcea0600a276b2bfa11'}),
# (n406:N6f0584db889546659239c521c747b5a7 {uri: 'N6f0584db889546659239c521c747b5a7'}),
# (n407:wine_SevreEtMaine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SevreEtMaine'}),
# (n408:N39aae634c5a1488a8a0da45b6e2481be {uri: 'N39aae634c5a1488a8a0da45b6e2481be'}),
# (n409:Ne854c5d3f7a74896a69961afe3b5490b {uri: 'Ne854c5d3f7a74896a69961afe3b5490b'}),
# (n410:Nfc66a5c17fba410c81e624e5fdb42deb {uri: 'Nfc66a5c17fba410c81e624e5fdb42deb'}),
# (n411:N21dd56a9205d4aadbb0ad944365fe9cb {uri: 'N21dd56a9205d4aadbb0ad944365fe9cb'}),
# (n412:Nade9c15f69804318b4176b5ff355bcf2 {uri: 'Nade9c15f69804318b4176b5ff355bcf2'}),
# (n413:wine_TexasRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#TexasRegion'}),
# (n414:N55f3cfd28ca74af29fd18edc6a87a2b6 {uri: 'N55f3cfd28ca74af29fd18edc6a87a2b6'}),
# (n415:N725bbe456de24613bc2cf37e5b0e4136 {uri: 'N725bbe456de24613bc2cf37e5b0e4136'}),
# (n416:Na6ebe53ecaff4150ba5351ec29b2df60 {uri: 'Na6ebe53ecaff4150ba5351ec29b2df60'}),
# (n417:wine_White {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#White'}),
# (n418:N3b744668c49d451aacaff5b0643db065 {uri: 'N3b744668c49d451aacaff5b0643db065'}),
# (n419:N999f6eb539444c1fbaa3621670759a1c {uri: 'N999f6eb539444c1fbaa3621670759a1c'}),
# (n420:wine_LaneTanner {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTanner'}),
# (n421:N959bf3ff479f4f4cb7db4a70b281e878 {uri: 'N959bf3ff479f4f4cb7db4a70b281e878'}),
# (n422:N22f3e53aa8c140b7977a75bfcf110236 {uri: 'N22f3e53aa8c140b7977a75bfcf110236'}),
# (n423:Nf329dbbb072a48e3aecd0acb7508f10f {uri: 'Nf329dbbb072a48e3aecd0acb7508f10f'}),
# (n424:N54948635535d4b88a7da25ceccaba0d8 {uri: 'N54948635535d4b88a7da25ceccaba0d8'}),
# (n425:wine_DryRiesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryRiesling'}),
# (n426:N53e27724be3f458e9d4814cffda61d7e {uri: 'N53e27724be3f458e9d4814cffda61d7e'}),
# (n427:Nfd2b743705924eca835816e4cd715b34 {uri: 'Nfd2b743705924eca835816e4cd715b34'}),
# (n428:wine_SchlossVolrad {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossVolrad'}),
# (n429:Nc386875f080944f280f3dbfbeb0ba18a {uri: 'Nc386875f080944f280f3dbfbeb0ba18a'}),
# (n430:N46fe8f4b784942b687cfb6399c9ae272 {uri: 'N46fe8f4b784942b687cfb6399c9ae272'}),
# (n431:Nfef54bb6570e45758462f55b20fc5827 {uri: 'Nfef54bb6570e45758462f55b20fc5827'}),
# (n432:wine_Handley {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Handley'}),
# (n433:wine_CorbansDryWhiteRiesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CorbansDryWhiteRiesling'}),
# (n434:Nd70d10ca75da4c2dbaad5c491d9dbd22 {uri: 'Nd70d10ca75da4c2dbaad5c491d9dbd22'}),
# (n435:Nf9b51c2980314b23aced4c2aa11b5197 {uri: 'Nf9b51c2980314b23aced4c2aa11b5197'}),
# (n436:wine_AlsatianWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AlsatianWine'}),
# (n437:owl_AllDifferent {uri: 'http://www.w3.org/2002/07/owl#AllDifferent'}),
# (n438:Ne99ed0921be24962a9d717492a7e7f61 {uri: 'Ne99ed0921be24962a9d717492a7e7f61'}),
# (n439:wine_MariettaCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MariettaCabernetSauvignon'}),
# (n440:wine_DryWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryWine'}),
# (n441:Nef7783d371f0450a81ed348f53e7e7ae {uri: 'Nef7783d371f0450a81ed348f53e7e7ae'}),
# (n442:wine_SchlossRothermel {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossRothermel'}),
# (n443:N85709525c5134ec1b8b1f85b4e09ca58 {uri: 'N85709525c5134ec1b8b1f85b4e09ca58'}),
# (n444:N234725c2e57b415187941e0c7b1f65c4 {uri: 'N234725c2e57b415187941e0c7b1f65c4'}),
# (n445:N5c667aac7ca34f5aabbb56ebcd8b10a2 {uri: 'N5c667aac7ca34f5aabbb56ebcd8b10a2'}),
# (n446:wine_MargauxRegion {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MargauxRegion'}),
# (n447:Nc0793fba16344a40b97e7780079caab0 {uri: 'Nc0793fba16344a40b97e7780079caab0'}),
# (n448:N140e0fb7a3a6492abc83e2069136145a {uri: 'N140e0fb7a3a6492abc83e2069136145a'}),
# (n449:wine_Red {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Red'}),
# (n450:Nfc557770fdb4417f94ac255f7af5d775 {uri: 'Nfc557770fdb4417f94ac255f7af5d775'}),
# (n451:N82078ee93e7b420e94a507ae23e34207 {uri: 'N82078ee93e7b420e94a507ae23e34207'}),
# (n452:N0f95792e45804844ab006a224fbd83e0 {uri: 'N0f95792e45804844ab006a224fbd83e0'}),
# (n453:wine_Sauternes {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Sauternes'}),
# (n454:wine_LaneTannerPinotNoir {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#LaneTannerPinotNoir'}),
# (n455:Ne78c0c2eb66543ddb98244cdc94aab6a {uri: 'Ne78c0c2eb66543ddb98244cdc94aab6a'}),
# (n456:N3aa11a305a6042738767eab6709fad90 {uri: 'N3aa11a305a6042738767eab6709fad90'}),
# (n457:N92aa4211692c4356b5e55059bf812428 {uri: 'N92aa4211692c4356b5e55059bf812428'}),
# (n458:N5d875fda957d47a6a5dfea3da8cd67dc {uri: 'N5d875fda957d47a6a5dfea3da8cd67dc'}),
# (n459:N3718f449ccdc43269fc1f10060c0019c {uri: 'N3718f449ccdc43269fc1f10060c0019c'}),
# (n460:N401f2a5e0c134c08bddd6024d9af0812 {uri: 'N401f2a5e0c134c08bddd6024d9af0812'}),
# (n461:wine_Rose {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Rose'}),
# (n462:wine_Forman {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Forman'}),
# (n463:wine_DryWhiteWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#DryWhiteWine'}),
# (n464:N713b47f92ea84cdfa1748170d6b269a1 {uri: 'N713b47f92ea84cdfa1748170d6b269a1'}),
# (n465:N38c938c10ca3456d8990fd1ed7bbac57 {uri: 'N38c938c10ca3456d8990fd1ed7bbac57'}),
# (n466:wine_CortonMontrachet {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CortonMontrachet'}),
# (n467:N24b159e23bbc4343ab68f5a55796fd8b {uri: 'N24b159e23bbc4343ab68f5a55796fd8b'}),
# (n468:N9757aadc4c2242509f46c7c2b233565e {uri: 'N9757aadc4c2242509f46c7c2b233565e'}),
# (n469:N6b29a56b25cf40678302e680c04a7a03 {uri: 'N6b29a56b25cf40678302e680c04a7a03'}),
# (n470:N2f23f502d6e54090bed15eac72711f06 {uri: 'N2f23f502d6e54090bed15eac72711f06'}),
# (n471:Neb041d208e2b4c2db7136c683843a882 {uri: 'Neb041d208e2b4c2db7136c683843a882'}),
# (n472:Na088dfc25c02407791ea29042d279c63 {uri: 'Na088dfc25c02407791ea29042d279c63'}),
# (n473:N6387d5693beb4673adb8d0734742359b {uri: 'N6387d5693beb4673adb8d0734742359b'}),
# (n474:N63894765b88440ca96ca1298e050cdc0 {uri: 'N63894765b88440ca96ca1298e050cdc0'}),
# (n475:N9adc028f036c4c1f9288b37e4d8651a7 {uri: 'N9adc028f036c4c1f9288b37e4d8651a7'}),
# (n476:Nbefc57b1a0594ab482f414baf848d5f7 {uri: 'Nbefc57b1a0594ab482f414baf848d5f7'}),
# (n477:wine_Riesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Riesling'}),
# (n478:wine_VentanaCheninBlanc {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#VentanaCheninBlanc'}),
# (n479:wine_CongressSprings {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CongressSprings'}),
# (n480:N09e1504a66614465b1610ecb6797ff7a {uri: 'N09e1504a66614465b1610ecb6797ff7a'}),
# (n481:N8a15286f81a6450eb5fee2aaa4efcfcc {uri: 'N8a15286f81a6450eb5fee2aaa4efcfcc'}),
# (n482:N1cfe330d0aa446cd950afc28d39b4d50 {uri: 'N1cfe330d0aa446cd950afc28d39b4d50'}),
# (n483:N7c9c34d179fc4b5dbab0d39c7f751ee4 {uri: 'N7c9c34d179fc4b5dbab0d39c7f751ee4'}),
# (n484:N2047fe85775349ff80f8db3d0b947b2c {uri: 'N2047fe85775349ff80f8db3d0b947b2c'}),
# (n485:N4b40fe0c846f4387b2351bbde182a3b4 {uri: 'N4b40fe0c846f4387b2351bbde182a3b4'}),
# (n486:Na440d0fcf376404d96729fc25cfd4055 {uri: 'Na440d0fcf376404d96729fc25cfd4055'}),
# (n487:wine_AmericanWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#AmericanWine'}),
# (n488:Nd408a705e7a04e169af6a271ef3ee782 {uri: 'Nd408a705e7a04e169af6a271ef3ee782'}),
# (n489:wine_Delicate {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Delicate'}),
# (n490:N2e520dd75482476c98363ea047762c2d {uri: 'N2e520dd75482476c98363ea047762c2d'}),
# (n491:N1838a2304eee4fd197ad6c67fbc190ec {uri: 'N1838a2304eee4fd197ad6c67fbc190ec'}),
# (n492:N8395f665b19b48c7b55787074e7a79fc {uri: 'N8395f665b19b48c7b55787074e7a79fc'}),
# (n493:wine_Selaks {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Selaks'}),
# (n494:Nbf55eb9e798f4de8932d756fb62f4ce3 {uri: 'Nbf55eb9e798f4de8932d756fb62f4ce3'}),
# (n495:wine_CaliforniaWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#CaliforniaWine'}),
# (n496:N7e5d0c41cf024f3291905fd5e1aa1a38 {uri: 'N7e5d0c41cf024f3291905fd5e1aa1a38'}),
# (n497:wine_Port {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#Port'}),
# (n498:wine {uri: 'http://www.w3.org/TR/2003/CR-owl-guide-20030818/wine'}),
# (n499:owl_Restriction {uri: 'http://www.w3.org/2002/07/owl#Restriction'}),
# (n500:wine_PageMillWineryCabernetSauvignon {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PageMillWineryCabernetSauvignon'}),
# (n501:Ne78c2bbd730044d780afc5179f50d2a7 {uri: 'Ne78c2bbd730044d780afc5179f50d2a7'}),
# (n502:wine_hasColor {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#hasColor'}),
# (n503:wine_PetiteSyrahGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PetiteSyrahGrape'}),
# (n504:wine_MountEdenVineyardEdnaValleyChardonnay {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#MountEdenVineyardEdnaValleyChardonnay'}),
# (n505:wine_KathrynKennedy {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#KathrynKennedy'}),
# (n506:N64186c2fbe23474c928a54e66b09c0d5 {uri: 'N64186c2fbe23474c928a54e66b09c0d5'}),
# (n507:wine_IceWine {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#IceWine'}),
# (n508:wine_locatedIn {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#locatedIn'}),
# (n509:Nc450335b222c4249862cc3308bbd5101 {uri: 'Nc450335b222c4249862cc3308bbd5101'}),
# (n510:N686b83ab3b244b428d795a4f07eb724a {uri: 'N686b83ab3b244b428d795a4f07eb724a'}),
# (n511:N3cd87b9e66d14d53878f86df35911b60 {uri: 'N3cd87b9e66d14d53878f86df35911b60'}),
# (n512:N248f3bf15a3a41009abce89063360815 {uri: 'N248f3bf15a3a41009abce89063360815'}),
# (n513:wine_PinotNoirGrape {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#PinotNoirGrape'}),
# (n514:N8d83a660b2534b45aae4c0948661559d {uri: 'N8d83a660b2534b45aae4c0948661559d'}),
# (n515:Nb18d82d481a047f9a856de50101b4fba {uri: 'Nb18d82d481a047f9a856de50101b4fba'}),
# (n516:N51f02e302d19420dbfeefe35e3d1eab8 {uri: 'N51f02e302d19420dbfeefe35e3d1eab8'}),
# (n517:N09bcac80571d4f038f6ac5e40b26a3e7 {uri: 'N09bcac80571d4f038f6ac5e40b26a3e7'}),
# (n518:wine_SchlossVolradTrochenbierenausleseRiesling {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/wine#SchlossVolradTrochenbierenausleseRiesling'}),
# (n519:food_PotableLiquid {uri: 'http://www.w3.org/TR/2003/PR-owl-guide-20031209/food#PotableLiquid'}),
# (n520:Ncfebf1ebbdc04cb185148fe257e76179 {uri: 'Ncfebf1ebbdc04cb185148fe257e76179'}),
# (n521:N3ed466e1ec164d32b31ca17f9d6435fb {uri: 'N3ed466e1ec164d32b31ca17f9d6435fb'}),
# (n522:N28227cd6548c456e95b52a2e34110262 {uri: 'N28227cd6548c456e95b52a2e34110262'}),
# ...
# (n539)-[:wine_locatedIn]-(n372),
# (n4)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n554)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n638)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n472)-[:owl_onProperty]-(n502),
# (n182)-[:wine_hasMaker]-(n22),
# (n388)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n141)-[:owl_onProperty]-(n712),
# (n38)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n75)-[:ID_22_rdf_syntax_ns_type]-(n573),
# (n493)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n356)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n116)-[:ID_22_rdf_syntax_ns_type]-(n573),
# (n167)-[:ID_22_rdf_syntax_ns_type]-(n16),
# (n513)-[:ID_22_rdf_syntax_ns_type]-(n280),
# (n86)-[:ID_22_rdf_syntax_ns_type]-(n603),
# (n208)-[:ID_22_rdf_syntax_ns_first]-(n394),
# (n147)-[:wine_hasMaker]-(n559),
# (n237)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n28)-[:ID_22_rdf_syntax_ns_first]-(n402),
# (n43)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n708)-[:ID_22_rdf_syntax_ns_type]-(n280),
# (n337)-[:owl_hasValue]-(n605),
# (n611)-[:owl_onProperty]-(n23),
# (n664)-[:owl_hasValue]-(n417),
# (n356)-[:owl_onProperty]-(n712),
# (n332)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n314)-[:ID_22_rdf_syntax_ns_first]-(n212),
# (n722)-[:ID_22_rdf_syntax_ns_first]-(n576),
# (n219)-[:owl_hasValue]-(n343),
# (n646)-[:ID_22_rdf_syntax_ns_first]-(n709),
# (n396)-[:owl_onProperty]-(n643),
# (n139)-[:wine_hasFlavor]-(n561),
# (n360)-[:owl_onProperty]-(n23),
# (n77)-[:ID_22_rdf_syntax_ns_first]-(n493),
# (n378)-[:owl_hasValue]-(n449),
# (n40)-[:ID_22_rdf_syntax_ns_type]-(n613),
# (n552)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n51)-[:ID_22_rdf_syntax_ns_first]-(n477),
# (n192)-[:ID_22_rdf_syntax_ns_first]-(n9),
# (n668)-[:owl_hasValue]-(n449),
# (n74)-[:owl_hasValue]-(n343),
# (n20)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n520)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n8)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n448)-[:owl_onProperty]-(n23),
# (n68)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n273)-[:owl_hasValue]-(n576),
# (n75)-[:wine_locatedIn]-(n290),
# (n695)-[:owl_hasValue]-(n417),
# (n508)-[:ID_22_rdf_syntax_ns_type]-(n700),
# (n331)-[:ID_22_rdf_syntax_ns_first]-(n608),
# (n86)-[:wine_hasFlavor]-(n561),
# (n424)-[:owl_hasValue]-(n417),
# (n579)-[:owl_onProperty]-(n23),
# (n8)-[:owl_onProperty]-(n712),
# (n202)-[:ID_22_rdf_syntax_ns_type]-(n573),
# (n510)-[:owl_onProperty]-(n23),
# (n90)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n151)-[:owl_hasValue]-(n343),
# (n328)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n660)-[:owl_onProperty]-(n508),
# (n73)-[:ID_22_rdf_syntax_ns_first]-(n145),
# (n630)-[:ID_22_rdf_syntax_ns_type]-(n596),
# (n662)-[:owl_onProperty]-(n502),
# (n79)-[:wine_hasBody]-(n146),
# (n211)-[:ID_22_rdf_syntax_ns_type]-(n573),
# (n502)-[:ID_22_rdf_syntax_ns_type]-(n613),
# (n529)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n295)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n702)-[:wine_hasFlavor]-(n561),
# (n676)-[:owl_hasValue]-(n449),
# (n206)-[:owl_hasValue]-(n128),
# (n225)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n687)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n500)-[:wine_hasBody]-(n524),
# (n145)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n8)-[:owl_hasValue]-(n578),
# (n501)-[:owl_hasValue]-(n489),
# (n64)-[:owl_hasValue]-(n572),
# (n698)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n263)-[:ID_22_rdf_syntax_ns_type]-(n321),
# (n319)-[:ID_22_rdf_syntax_ns_type]-(n274),
# (n175)-[:ID_22_rdf_syntax_ns_first]-(n247),
# (n131)-[:rdf_schema_subClassOf]-(n9),
# (n99)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n212)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n630)-[:wine_hasBody]-(n146),
# (n37)-[:owl_onProperty]-(n40),
# (n557)-[:rdf_schema_range]-(n573),
# (n304)-[:ID_22_rdf_syntax_ns_first]-(n548),
# (n344)-[:ID_22_rdf_syntax_ns_first]-(n115),
# (n22)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n171)-[:owl_hasValue]-(n60),
# (n62)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n141)-[:owl_hasValue]-(n113),
# (n456)-[:owl_onProperty]-(n712),
# (n469)-[:owl_hasValue]-(n176),
# (n560)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n714)-[:wine_hasFlavor]-(n561),
# (n64)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n372)-[:wine_locatedIn]-(n290),
# (n243)-[:ID_22_rdf_syntax_ns_first]-(n27),
# (n31)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n453)-[:rdf_schema_subClassOf]-(n131),
# (n139)-[:ID_22_rdf_syntax_ns_type]-(n544),
# (n720)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n62)-[:owl_onProperty]-(n712),
# (n23)-[:rdf_schema_subPropertyOf]-(n6),
# (n560)-[:owl_onProperty]-(n712),
# (n245)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n663)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n290)-[:ID_22_rdf_syntax_ns_type]-(n573),
# (n64)-[:owl_onProperty]-(n712),
# (n555)-[:ID_22_rdf_syntax_ns_first]-(n9),
# (n233)-[:wine_hasFlavor]-(n576),
# (n480)-[:ID_22_rdf_syntax_ns_first]-(n417),
# (n329)-[:ID_22_rdf_syntax_ns_first]-(n9),
# (n147)-[:ID_22_rdf_syntax_ns_type]-(n127),
# (n221)-[:owl_onProperty]-(n23),
# (n369)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n425)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n400)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n187)-[:wine_hasFlavor]-(n561),
# (n652)-[:ID_22_rdf_syntax_ns_type]-(n437),
# (n108)-[:ID_22_rdf_syntax_ns_first]-(n9),
# (n704)-[:ID_22_rdf_syntax_ns_type]-(n507),
# (n562)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n448)-[:owl_hasValue]-(n394),
# (n406)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n431)-[:owl_hasValue]-(n449),
# (n196)-[:owl_hasValue]-(n699),
# (n74)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n400)-[:owl_onProperty]-(n712),
# (n486)-[:owl_onProperty]-(n23),
# (n484)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n234)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n233)-[:wine_hasSugar]-(n343),
# (n711)-[:owl_hasValue]-(n489),
# (n58)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n335)-[:wine_locatedIn]-(n116),
# (n261)-[:ID_22_rdf_syntax_ns_first]-(n212),
# (n316)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n376)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n342)-[:owl_onProperty]-(n712),
# (n41)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n324)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n574)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n71)-[:ID_22_rdf_syntax_ns_first]-(n9),
# (n484)-[:owl_onProperty]-(n712),
# (n447)-[:owl_onProperty]-(n508),
# (n26)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n248)-[:rdf_schema_subClassOf]-(n640),
# (n151)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n187)-[:wine_hasBody]-(n146),
# (n420)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n14)-[:ID_22_rdf_syntax_ns_type]-(n606),
# (n438)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n504)-[:wine_hasBody]-(n524),
# (n316)-[:owl_onProperty]-(n712),
# (n140)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n540)-[:owl_onProperty]-(n23),
# (n41)-[:owl_onProperty]-(n712),
# (n601)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n324)-[:owl_onProperty]-(n712),
# (n359)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n279)-[:ID_22_rdf_syntax_ns_first]-(n718),
# (n120)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n283)-[:wine_hasMaker]-(n47),
# (n147)-[:wine_hasSugar]-(n343),
# (n334)-[:ID_22_rdf_syntax_ns_first]-(n718),
# (n17)-[:ID_22_rdf_syntax_ns_first]-(n9),
# (n626)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n276)-[:wine_locatedIn]-(n290),
# (n48)-[:wine_hasBody]-(n524),
# (n539)-[:wine_hasFlavor]-(n489),
# (n280)-[:rdf_schema_subClassOf]-(n246),
# (n40)-[:rdf_schema_range]-(n4),
# (n36)-[:wine_hasSugar]-(n343),
# (n156)-[:wine_locatedIn]-(n536),
# (n447)-[:owl_hasValue]-(n96),
# (n248)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n195)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n684)-[:owl_onProperty]-(n502),
# (n180)-[:ID_22_rdf_syntax_ns_first]-(n576),
# (n156)-[:ID_22_rdf_syntax_ns_type]-(n623),
# (n370)-[:wine_hasSugar]-(n343),
# (n49)-[:ID_22_rdf_syntax_ns_first]-(n524),
# (n254)-[:owl_onProperty]-(n502),
# (n417)-[:ID_22_rdf_syntax_ns_type]-(n354),
# (n694)-[:ID_22_rdf_syntax_ns_first]-(n417),
# (n252)-[:ID_22_rdf_syntax_ns_type]-(n613),
# (n99)-[:owl_onProperty]-(n508),
# (n156)-[:wine_hasSugar]-(n343),
# (n340)-[:owl_onProperty]-(n508),
# (n87)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n323)-[:ID_22_rdf_syntax_ns_first]-(n9),
# (n309)-[:ID_22_rdf_syntax_ns_first]-(n247),
# (n186)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n575)-[:ID_22_rdf_syntax_ns_first]-(n524),
# (n433)-[:wine_hasBody]-(n524),
# (n602)-[:owl_inverseOf]-(n712),
# (n76)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n440)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n85)-[:ID_22_rdf_syntax_ns_first]-(n449),
# (n79)-[:ID_22_rdf_syntax_ns_type]-(n169),
# (n234)-[:owl_hasValue]-(n394),
# (n643)-[:ID_22_rdf_syntax_ns_type]-(n613),
# (n86)-[:wine_hasMaker]-(n679),
# (n392)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n517)-[:ID_22_rdf_syntax_ns_first]-(n440),
# (n147)-[:wine_locatedIn]-(n372),
# (n449)-[:ID_22_rdf_syntax_ns_type]-(n354),
# (n605)-[:ID_22_rdf_syntax_ns_type]-(n573),
# (n584)-[:ID_22_rdf_syntax_ns_first]-(n524),
# (n682)-[:ID_22_rdf_syntax_ns_first]-(n561),
# (n604)-[:ID_22_rdf_syntax_ns_type]-(n573),
# (n34)-[:ID_22_rdf_syntax_ns_first]-(n524),
# (n76)-[:owl_onProperty]-(n712),
# (n426)-[:owl_hasValue]-(n384),
# (n591)-[:ID_22_rdf_syntax_ns_type]-(n573),
# (n100)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n11)-[:owl_someValuesFrom]-(n573),
# (n707)-[:owl_onProperty]-(n23),
# (n278)-[:owl_hasValue]-(n449),
# (n623)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n535)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n240)-[:owl_hasValue]-(n489),
# (n177)-[:owl_onProperty]-(n23),
# (n338)-[:owl_hasValue]-(n524),
# (n428)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n158)-[:wine_hasMaker]-(n553),
# (n273)-[:owl_onProperty]-(n40),
# (n577)-[:wine_hasBody]-(n524),
# (n500)-[:wine_locatedIn]-(n372),
# (n360)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n139)-[:wine_hasBody]-(n394),
# (n197)-[:owl_onProperty]-(n502),
# (n686)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n599)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n668)-[:owl_onProperty]-(n502),
# (n644)-[:wine_hasFlavor]-(n576),
# (n124)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n712)-[:rdf_schema_range]-(n280),
# (n211)-[:wine_locatedIn]-(n176),
# (n535)-[:owl_onProperty]-(n712),
# (n270)-[:ID_22_rdf_syntax_ns_first]-(n152),
# (n712)-[:ID_22_rdf_syntax_ns_type]-(n613),
# (n216)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n714)-[:wine_hasSugar]-(n343),
# (n401)-[:ID_22_rdf_syntax_ns_type]-(n26),
# (n470)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n203)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n681)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n502)-[:rdf_schema_domain]-(n9),
# (n404)-[:wine_hasBody]-(n524),
# (n550)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n177)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n490)-[:owl_hasValue]-(n211),
# (n604)-[:wine_locatedIn]-(n116),
# (n687)-[:owl_hasValue]-(n343),
# (n308)-[:wine_hasMaker]-(n123),
# (n0)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n416)-[:owl_onProperty]-(n643),
# (n541)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n205)-[:ID_22_rdf_syntax_ns_type]-(n596),
# (n644)-[:wine_hasSugar]-(n343),
# (n41)-[:owl_hasValue]-(n113),
# (n510)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n485)-[:ID_22_rdf_syntax_ns_type]-(n437),
# (n231)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n702)-[:wine_hasMaker]-(n681),
# (n701)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n294)-[:rdf_schema_domain]-(n16),
# (n469)-[:owl_onProperty]-(n508),
# (n288)-[:ID_22_rdf_syntax_ns_type]-(n596),
# (n607)-[:owl_onProperty]-(n508),
# (n12)-[:owl_hasValue]-(n561),
# (n197)-[:owl_hasValue]-(n449),
# (n525)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n131)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n589)-[:ID_22_rdf_syntax_ns_first]-(n626),
# (n689)-[:owl_onProperty]-(n40),
# (n670)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n205)-[:wine_hasBody]-(n146),
# (n139)-[:wine_hasMaker]-(n333),
# (n593)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n676)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n383)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n3)-[:owl_hasValue]-(n417),
# (n654)-[:wine_hasMaker]-(n666),
# (n598)-[:ID_22_rdf_syntax_ns_first]-(n377),
# (n54)-[:owl_onProperty]-(n40),
# (n5)-[:ID_22_rdf_syntax_ns_first]-(n146),
# (n209)-[:ID_22_rdf_syntax_ns_first]-(n9),
# (n539)-[:wine_hasSugar]-(n587),
# (n419)-[:ID_22_rdf_syntax_ns_first]-(n402),
# (n494)-[:owl_hasValue]-(n417),
# (n536)-[:wine_locatedIn]-(n290),
# (n706)-[:owl_hasValue]-(n546),
# (n196)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n723)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n439)-[:wine_locatedIn]-(n536),
# (n620)-[:owl_onProperty]-(n712),
# (n382)-[:owl_hasValue]-(n343),
# (n200)-[:owl_onProperty]-(n502),
# (n6)-[:rdf_schema_range]-(n685),
# (n401)-[:wine_hasMaker]-(n462),
# (n36)-[:wine_hasBody]-(n524),
# (n67)-[:ID_22_rdf_syntax_ns_first]-(n477),
# (n92)-[:ID_22_rdf_syntax_ns_first]-(n343),
# (n644)-[:ID_22_rdf_syntax_ns_type]-(n87),
# (n170)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n578)-[:ID_22_rdf_syntax_ns_type]-(n280),
# (n362)-[:owl_onProperty]-(n23),
# (n219)-[:owl_onProperty]-(n643),
# (n156)-[:wine_hasFlavor]-(n561),
# (n102)-[:ID_22_rdf_syntax_ns_first]-(n505),
# (n313)-[:wine_locatedIn]-(n721),
# (n689)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n47)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n324)-[:owl_hasValue]-(n503),
# (n478)-[:ID_22_rdf_syntax_ns_type]-(n95),
# (n250)-[:ID_22_rdf_syntax_ns_first]-(n524),
# (n622)-[:ID_22_rdf_syntax_ns_type]-(n280),
# (n18)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n335)-[:ID_22_rdf_syntax_ns_type]-(n573),
# (n124)-[:owl_onProperty]-(n508),
# (n551)-[:ID_22_rdf_syntax_ns_first]-(n524),
# (n597)-[:ID_22_rdf_syntax_ns_first]-(n45),
# (n479)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n193)-[:ID_22_rdf_syntax_ns_first]-(n189),
# (n127)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n363)-[:owl_onProperty]-(n712),
# (n454)-[:wine_hasBody]-(n394),
# (n226)-[:wine_hasBody]-(n524),
# (n463)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n631)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n518)-[:wine_hasSugar]-(n587),
# (n719)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n36)-[:wine_hasFlavor]-(n561),
# (n557)-[:ID_22_rdf_syntax_ns_type]-(n346),
# (n474)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n159)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n171)-[:owl_onProperty]-(n508),
# (n476)-[:owl_hasValue]-(n709),
# (n81)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n673)-[:owl_hasValue]-(n721),
# (n699)-[:ID_22_rdf_syntax_ns_type]-(n715),
# (n488)-[:owl_hasValue]-(n417),
# (n178)-[:ID_22_rdf_syntax_ns_first]-(n249),
# (n719)-[:owl_onProperty]-(n712),
# (n113)-[:ID_22_rdf_syntax_ns_type]-(n715),
# (n92)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n563)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n358)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n347)-[:ID_22_rdf_syntax_ns_first]-(n561),
# (n105)-[:wine_hasBody]-(n524),
# (n427)-[:owl_hasValue]-(n561),
# (n228)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n114)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n487)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n298)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n575)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n80)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n610)-[:ID_22_rdf_syntax_ns_first]-(n576),
# (n568)-[:owl_onProperty]-(n23),
# (n526)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n354)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n66)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n284)-[:wine_locatedIn]-(n267),
# (n399)-[:owl_hasValue]-(n699),
# (n490)-[:owl_onProperty]-(n508),
# (n358)-[:owl_onProperty]-(n712),
# (n66)-[:owl_hasValue]-(n587),
# (n417)-[:ID_22_rdf_syntax_ns_type]-(n715),
# (n200)-[:owl_hasValue]-(n449),
# (n627)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n284)-[:ID_22_rdf_syntax_ns_type]-(n573),
# (n630)-[:wine_locatedIn]-(n536),
# (n137)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n526)-[:owl_onProperty]-(n712),
# (n699)-[:ID_22_rdf_syntax_ns_type]-(n280),
# (n294)-[:rdf_schema_range]-(n303),
# (n542)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n692)-[:owl_onProperty]-(n712),
# (n5)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n537)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n194)-[:ID_22_rdf_syntax_ns_first]-(n212),
# (n113)-[:ID_22_rdf_syntax_ns_type]-(n280),
# (n79)-[:wine_hasMaker]-(n390),
# (n337)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n632)-[:ID_22_rdf_syntax_ns_type]-(n349),
# (n24)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n382)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n449)-[:ID_22_rdf_syntax_ns_type]-(n715),
# (n657)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n297)-[:ID_22_rdf_syntax_ns_rest]-(n188),
# (n233)-[:wine_locatedIn]-(n302),
# (n96)-[:ID_22_rdf_syntax_ns_type]-(n573),
# (n718)-[:ID_22_rdf_syntax_ns_type]-(n715),
# (n133)-[:wine_hasBody]-(n524),
# (n288)-[:wine_hasMaker]-(n679),
# (n327)-[:wine_hasBody]-(n524),
# (n477)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n278)-[:owl_onProperty]-(n502),
# (n14)-[:wine_hasMaker]-(n548),
# (n154)-[:owl_hasValue]-(n313),
# (n142)-[:wine_hasMaker]-(n407),
# (n373)-[:wine_hasSugar]-(n587),
# (n508)-[:rdf_schema_range]-(n573),
# (n633)-[:wine_hasMaker]-(n249),
# (n644)-[:wine_hasBody]-(n146),
# (n624)-[:ID_22_rdf_syntax_ns_first]-(n524),
# (n166)-[:ID_22_rdf_syntax_ns_type]-(n210),
# (n543)-[:ID_22_rdf_syntax_ns_type]-(n499),
# (n554)-[:owl_onProperty]-(n40),
# (n311)-[:owl_onProperty]-(n643),
# (n262)-[:ID_22_rdf_syntax_ns_type]-(n698),
# (n241)-[:ID_22_rdf_syntax_ns_type]-(n210)

# %%
# %%time

# Save Cypher query to file
with open(f"{path_data}/{example_name}.cypher", "w") as f:
    f.write(graph_CREATE_command_v1)
# Out:
# CPU times: user 1.73 ms, sys: 0 ns, total: 1.73 ms
# Wall time: 943 μs

# %% [markdown]
# # Create graph using `turingdb` python package

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         See <a href="https://docs.turingdb.ai/quickstart">TuringDB Get started documentation</a> for the important steps to follow :
#     </h2>
#     <h3>
#         <ul>
#             <li>Create your TuringDB account</li>
#             <li>Create your instance in the <a href="https://console.turingdb.ai/auth">TuringDB Cloud UI</a></li>
#             <li>Copy your Instance ID from the Database Instances management page</li>
#             <li>Get API Key from the Settings in UI</li>
#         </ul>
#         Remember to have your instance active while working in this notebook !
#     </h3>
# </div>

# %%
from turingdb import TuringDB

# Create TuringDB client
client = TuringDB(
    host="http://localhost:6666"  # Remove this parameter and set the two parameters below
    # instance_id=os.getenv("INSTANCE_ID"),
    # auth_token=os.getenv("AUTH_TOKEN"),
)

# %%
# %%time

client.s3_connect(
    bucket_name="turing-internal",
    region="eu-west-2",
    access_key=os.getenv("AWS_ACCESS_KEY"),
    secret_key=os.getenv("AWS_SECRET_KEY"),
)
# Out:
# CPU times: user 151 ms, sys: 52.1 ms, total: 203 ms
# Wall time: 274 ms

# %%
# Get list of loaded graphs
list_graphs = client.list_loaded_graphs()
list_graphs
# Out:
# ['default']

# %%
# Set graph name
graph_name_prefix = example_name
graph_name_nb_suffix = str(
    max(
        [
            int(re.sub(graph_name_prefix, "", g))
            for g in list_graphs
            if g.startswith(graph_name_prefix)
            and re.sub(graph_name_prefix, "", g).isdigit()
        ]
        + [0]
    )
    + 1
)
graph_name = graph_name_prefix + graph_name_nb_suffix
graph_name = re.sub("-", "_", graph_name)
print(f"graph_name: {graph_name}")
# Out:
# graph_name: wine_ontology1

# %%
from turingdb.exceptions import TuringDBException

# %%
# %%time

# Set graph
try:
    client.create_graph(graph_name)
except TuringDBException as e:
    print(e)

# Set working graph
client.set_graph(graph_name)
# Out:
# CPU times: user 1.37 ms, sys: 91 μs, total: 1.46 ms
# Wall time: 10.8 ms

# %%
# %%time

# Create a new change on the graph
client.checkout()
change = client.new_change()
print(f"Current change {change}")

# Checkout into the change
client.checkout(change=change)
# Out:
# Current change 0
# CPU times: user 2.02 ms, sys: 1e+03 ns, total: 2.02 ms
# Wall time: 1.62 ms

# %%
# %%time

# Run CREATE command
print("\nExecuting query on TuringDB...")
start_time = time.time()
result = client.query(graph_CREATE_command_v1)
execution_time = time.time() - start_time
print(f"✓ Graph created successfully in {execution_time:.2f} seconds")

# Commit the change
client.query("COMMIT")
client.query("CHANGE SUBMIT")

# Checkout into main
client.checkout()
# Out:
# Executing query on TuringDB...
# CPU times: user 1.63 ms, sys: 42 μs, total: 1.67 ms
# Wall time: 127 ms
# ---------------------------------------------------------------------------
# RemoteProtocolError                       Traceback (most recent call last)
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpx/_transports/default.py:127, in ResponseStream.__iter__(self)
#     126 with map_httpcore_exceptions():
# --> 127     for part in self._httpcore_stream:
#     128         yield part
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:407, in PoolByteStream.__iter__(self)
#     406 self.close()
# --> 407 raise exc from None
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:403, in PoolByteStream.__iter__(self)
#     402 try:
# --> 403     for part in self._stream:
#     404         yield part
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpcore/_sync/http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     341     self.close()
# --> 342 raise exc
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpcore/_sync/http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     333 with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334     for chunk in self._connection._receive_response_body(**kwargs):
#     335         yield chunk
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpcore/_sync/http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpcore/_sync/http11.py:213, in HTTP11Connection._receive_event(self, timeout)
#     212 while True:
# --> 213     with map_exceptions({h11.RemoteProtocolError: RemoteProtocolError}):
#     214         event = self._h11_state.next_event()
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# RemoteProtocolError: peer closed connection without sending complete message body (incomplete chunked read)
#
# The above exception was the direct cause of the following exception:
#
# RemoteProtocolError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '\n# Run CREATE command\nprint("\\nExecuting query on TuringDB...")\nstart_time = time.time()\nresult = client.query(graph_CREATE_command_v1)\nexecution_time = time.time() - start_time\nprint(f"✓ Graph created successfully in {execution_time:.2f} seconds")\n\n# Commit the change\nclient.query("COMMIT")\nclient.query("CHANGE SUBMIT")\n\n# Checkout into main\nclient.checkout()\n')
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/IPython/core/magics/execution.py:1470, in ExecutionMagics.time(self, line, cell, local_ns)
#    1468 if interrupt_occured:
#    1469     if exit_on_interrupt and captured_exception:
# -> 1470         raise captured_exception
#    1471     return
#    1472 return out
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/IPython/core/magics/execution.py:1434, in ExecutionMagics.time(self, line, cell, local_ns)
#    1432 st = clock2()
#    1433 try:
# -> 1434     exec(code, glob, local_ns)
#    1435     out = None
#    1436     # multi-line %%time case
#
# File <timed exec>:4
#
# File ~/turingdb-examples/.venv/lib/python3.13/site-packages/turingdb/turingdb.py:82, in TuringDB.query(self, query)
#      81 def query(self, query: str):
# ---> 82     json = self._send_request("query", data=query, params=self._params)
#      84     if not isinstance(json, dict):
#      85         raise TuringDBException("Invalid response from the server")
#
# File ~/turingdb-examples/.venv/lib/python3.13/site-packages/turingdb/turingdb.py:171, in TuringDB._send_request(self, path, data, params)
#     167     response = self._client.post(
#     168         url, json=data, params=params, headers=self._headers
#     169     )
#     170 else:
# --> 171     response = self._client.post(
#     172         url, content=data, params=params, headers=self._headers
#     173     )
#     174 response.raise_for_status()
#     176 json = orjson.loads(response.text)
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpx/_client.py:1144, in Client.post(self, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1123 def post(
#    1124     self,
#    1125     url: URL | str,
#    (...)   1137     extensions: RequestExtensions | None = None,
#    1138 ) -> Response:
#    1139     """
#    1140     Send a `POST` request.
#    1141
#    1142     **Parameters**: See `httpx.request`.
#    1143     """
# -> 1144     return self.request(
#    1145         "POST",
#    1146         url,
#    1147         content=content,
#    1148         data=data,
#    1149         files=files,
#    1150         json=json,
#    1151         params=params,
#    1152         headers=headers,
#    1153         cookies=cookies,
#    1154         auth=auth,
#    1155         follow_redirects=follow_redirects,
#    1156         timeout=timeout,
#    1157         extensions=extensions,
#    1158     )
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpx/_client.py:928, in Client.send(self, request, stream, auth, follow_redirects)
#     926 except BaseException as exc:
#     927     response.close()
# --> 928     raise exc
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpx/_client.py:922, in Client.send(self, request, stream, auth, follow_redirects)
#     920 try:
#     921     if not stream:
# --> 922         response.read()
#     924     return response
#     926 except BaseException as exc:
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpx/_models.py:881, in Response.read(self)
#     877 """
#     878 Read and return the response content.
#     879 """
#     880 if not hasattr(self, "_content"):
# --> 881     self._content = b"".join(self.iter_bytes())
#     882 return self._content
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpx/_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpx/_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpx/_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpx/_transports/default.py:126, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
# --> 126     with map_httpcore_exceptions():
#     127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     160     value = typ()
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#     167     return exc is not value
#
# File ~/.cache/uv/archive-v0/uoMDvcSv12x-Y1wgksNgT/lib/python3.13/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# RemoteProtocolError: peer closed connection without sending complete message body (incomplete chunked read)

# %% [markdown]
# # Query TuringDB

# %% [markdown]
# ## Use metaqueries to have insight on graph overall structure
#
# <h3>
#     To learn more about 📮 Metaqueries, please check TuringDB documentation on this <a href="https://turingdb.mintlify.app/query/cypher_subset#%F0%9F%93%AE-metaqueries">link</a>
# </h3>

# %%
# %%time

# CALL PROPERTIES() - returns a column of all the different node and edge properties and their types in the database
command = """
CALL PROPERTIES()
"""
df_PROPERTIES = client.query(command)
if df_PROPERTIES.empty:
    print("No result found")
else:
    df_PROPERTIES.columns = ["Property_ID", "Property_name", "Property_type"]
    display(df_PROPERTIES)
# Out:
# No result found
# CPU times: user 3.26 ms, sys: 1.94 ms, total: 5.2 ms
# Wall time: 3.55 ms

# %%
# Get node properties
nodes_properties = df_PROPERTIES["Property_name"].values.tolist()
print(f"Node properties: {nodes_properties}")
# Out:
# Node properties: ['id', 'type', 'amount', 'step', 'is_fraud', 'is_flagged', 'oldbalance', 'newbalance']

# %%
# %%time

# CALL LABELS () - returns a column of all the different node labels
command = """
CALL LABELS()
"""
df_LABELS = client.query(command)
if df_LABELS.empty:
    print("No result found")
else:
    df_LABELS.columns = ["Node_type_ID", "Node_label"]
    display(df_LABELS)
# Out:
#    Node_type_ID   Node_label
# 0             0      Account
# 1             1  Transaction
# CPU times: user 6.76 ms, sys: 1.98 ms, total: 8.74 ms
# Wall time: 7.3 ms

# %%
# %%time

# CALL EDGETYPES() - returns a column of all the different edge types (edge equivalent of node labels)
command = """
CALL EDGETYPES()
"""
df_EDGETYPES = client.query(command)
if df_EDGETYPES.empty:
    print("No result found")
else:
    df_EDGETYPES.columns = ["Edge_type_ID", "Edge_label"]
    display(df_EDGETYPES)
# Out:
#    Edge_type_ID Edge_label
# 0             0       SENT
# 1             1   RECEIVED
# CPU times: user 4.69 ms, sys: 3.96 ms, total: 8.65 ms
# Wall time: 7.18 ms

# %%
# %%time

# CALL LABELSETS() - returns a two columns describing combinations of node labels
command = """
CALL LABELSETS()
"""
df_LABELSETS = client.query(command)
if df_LABELSETS.empty:
    print("No result found")
else:
    df_LABELSETS.columns = ["Node_type_ID", "Node_label"]
    display(df_LABELSETS)
# Out:
#    Node_type_ID   Node_label
# 0             0      Account
# 1             1  Transaction
# CPU times: user 7.24 ms, sys: 1.02 ms, total: 8.26 ms
# Wall time: 7.05 ms

# %%
# %%time

# Find number of nodes and number of edges in the graph
n_nodes = len(client.query("MATCH (n) RETURN n"))
n_edges = len(client.query("MATCH (n)--(m) RETURN n, m"))
print(f"Graph: {n_nodes:,} nodes and {n_edges:,} edges")
# Out:
# Graph: 1,572 nodes and 1,472 edges
# CPU times: user 3.66 ms, sys: 2.99 ms, total: 6.65 ms
# Wall time: 5.03 ms

# %% [markdown]
# ## Simple queries

# %%
from turingdb_examples.utils import get_return_statements

# %%
# %%time

# Match all edges and return them
command = """
MATCH (n)-[e]-(m)
RETURN n.id, n.type, e, m.id, m.type
"""
df_all_edges = client.query(command)
if df_all_edges.empty:
    print("No result found")
else:
    df_all_edges.columns = get_return_statements(command)
    display(df_all_edges)
# Out:
#              n.id    n.type     e         m.id    m.type
# 0     C1958260831  customer     0        TX307  CASH_OUT
# 1      C693207385  customer     1        TX592  CASH_OUT
# 2     C1108687791  customer     2        TX308  CASH_OUT
# 3     C2048633894  customer     3        TX309  TRANSFER
# 4      C436378709  customer     4        TX312  CASH_OUT
# ...           ...       ...   ...          ...       ...
# 1467        TX340  TRANSFER  1467    C19673653  customer
# 1468        TX341  CASH_OUT  1468  C1241266786  customer
# 1469        TX342  CASH_OUT  1469  C1241266786  customer
# 1470        TX343   CASH_IN  1470  C1241266786  customer
# 1471        TX344  CASH_OUT  1471  C1241266786  customer
#
# [1472 rows x 5 columns]
# CPU times: user 18.8 ms, sys: 1.03 ms, total: 19.8 ms
# Wall time: 18.5 ms
