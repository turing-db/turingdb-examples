# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>
#         Example notebook - Healthcare
#     </h1>
#     <p>
#         Link to dataset : <a href="https://www.kaggle.com/datasets/prasad22/healthcare-dataset">Kaggle link</a>
#     </p>
# </div>

# %% [markdown]
# # Import modules and functions

# %%
# %load_ext autoreload
# %autoreload 2

import os
import pandas as pd

import sys
sys.path.insert(1, f"{os.getenv('HOME')}/turingdb-examples/examples/functions")

from functions import *

# %% [markdown]
# # Set paths

# %%
path_data = f"{os.getenv('HOME')}/turingdb-examples/examples/data"
folder = "clinical_healthcare"

# %% [markdown]
# # Import and format data

# %%
df = pd.read_csv(f"{path_data}/{folder}/healthcare_dataset.csv")
df['Name'] = df['Name'].apply(lambda x: f"{x.split(' ')[0].capitalize()} {x.split(' ')[1].upper()}")
df['Doctor'] = df['Doctor'].apply(lambda x: f"{x.split(' ')[0].capitalize()} {x.split(' ')[1].upper()}")
df = create_ID_column(df)

df = df.iloc[:10,:]

df
# Out:
#   Patient ID                Name  Age  Gender Blood Type Medical Condition  \
# 0      00000       Bobby JACKSON   30    Male         B-            Cancer
# 1      00001        Leslie TERRY   62    Male         A+           Obesity
# 2      00002         Danny SMITH   76  Female         A-           Obesity
# 3      00003        Andrew WATTS   28  Female         O+          Diabetes
# 4      00004       Adrienne BELL   43  Female        AB+            Cancer
# 5      00005       Emily JOHNSON   36    Male         A+            Asthma
# 6      00006      Edward EDWARDS   21  Female        AB-          Diabetes
# 7      00007  Christina MARTINEZ   20  Female         A+            Cancer
# 8      00008     Jasmine AGUILAR   82    Male        AB+            Asthma
# 9      00009    Christopher BERG   58  Female        AB-            Cancer
#
#   Date of Admission            Doctor                     Hospital  \
# 0        2024-01-31     Matthew SMITH              Sons and Miller
# 1        2019-08-20   Samantha DAVIES                      Kim Inc
# 2        2022-09-22  Tiffany MITCHELL                     Cook PLC
# 3        2020-11-18       Kevin WELLS   Hernandez Rogers and Vang,
# 4        2022-09-19    Kathleen HANNA                  White-White
# 5        2023-12-20     Taylor NEWTON               Nunez-Humphrey
# 6        2020-11-03       Kelly OLSON              Group Middleton
# 7        2021-12-28    Suzanne THOMAS  Powell Robinson and Valdez,
# 8        2020-07-01   Daniel FERGUSON                Sons Rich and
# 9        2021-05-23       Heather DAY               Padilla-Walker
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0         Blue Cross    18856.281306          328         Urgent
# 1           Medicare    33643.327287          265      Emergency
# 2              Aetna    27955.096079          205      Emergency
# 3           Medicare    37909.782410          450       Elective
# 4              Aetna    14238.317814          458         Urgent
# 5   UnitedHealthcare    48145.110951          389         Urgent
# 6           Medicare    19580.872345          389      Emergency
# 7              Cigna    45820.462722          277      Emergency
# 8              Cigna    50119.222792          316       Elective
# 9   UnitedHealthcare    19784.631062          249       Elective
#
#   Discharge Date   Medication  Test Results
# 0     2024-02-02  Paracetamol        Normal
# 1     2019-08-26    Ibuprofen  Inconclusive
# 2     2022-10-07      Aspirin        Normal
# 3     2020-12-18    Ibuprofen      Abnormal
# 4     2022-10-09   Penicillin      Abnormal
# 5     2023-12-24    Ibuprofen        Normal
# 6     2020-11-15  Paracetamol  Inconclusive
# 7     2022-01-07  Paracetamol  Inconclusive
# 8     2020-07-14      Aspirin      Abnormal
# 9     2021-06-22  Paracetamol  Inconclusive

# %% [markdown]
# # Create graph from dataframe

# %%
label_str = 'displayName'

G = create_graph_from_df(
    df,
    directed=True,
    
    source_node_col={
        'id': 'Patient ID',
        label_str: 'Name',
        'type': 'Patient'
    },
    attributes_source_node_cols=['Age', 'Date of Admission', 'Discharge Date'],
    optional_nodes_cols={
        'Gender': {
            'id': 'Gender',
            'link_to_source': True
        },
        'Blood Type': {
            'id': 'Blood Type',
            'link_to_source': True
        },
        'Medical Condition': {
            'id': 'Medical Condition',
            'link_to_source': True
        },
        'Doctor': {
            'id': 'Doctor',
            'link_to_source': True
        },
        'Hospital': {
            'id': 'Hospital',
            'attributes': ['Room Number'],
            'link_to_source': True
        },
        'Insurance Provider': {
            'id': 'Insurance Provider',
            'attributes': ['Billing Amount'],
            'link_to_source': True
        },
        'Admission Type': {
            'id': 'Admission Type',
            'link_to_source': True
        },
        'Medication': {
            'id': 'Medication',
            'link_to_source': True
        },
        'Test Results': {
            'id': 'Test Results',
            'link_to_source': True
        }
    }
)
print(f"Resulting graph : {G}")
# Out:
# Resulting graph : DiGraph with 57 nodes and 90 edges

# %%
for node in list(G.nodes(data=True))[:20]:
    print(node)
# Out:
# ('00000', {'displayName': 'Bobby JACKSON', 'type': 'Patient', 'Age': 30, 'Date of Admission': '2024-01-31', 'Discharge Date': '2024-02-02'})
# ('Male', {'displayName': 'Male'})
# ('B-', {'displayName': 'B-'})
# ('Cancer', {'displayName': 'Cancer'})
# ('Matthew SMITH', {'displayName': 'Matthew SMITH'})
# ('Sons and Miller', {'displayName': 'Sons and Miller', 'Room Number': 328})
# ('Blue Cross', {'displayName': 'Blue Cross', 'Billing Amount': 18856.281305978155})
# ('Urgent', {'displayName': 'Urgent'})
# ('Paracetamol', {'displayName': 'Paracetamol'})
# ('Normal', {'displayName': 'Normal'})
# ('00001', {'displayName': 'Leslie TERRY', 'type': 'Patient', 'Age': 62, 'Date of Admission': '2019-08-20', 'Discharge Date': '2019-08-26'})
# ('A+', {'displayName': 'A+'})
# ('Obesity', {'displayName': 'Obesity'})
# ('Samantha DAVIES', {'displayName': 'Samantha DAVIES'})
# ('Kim Inc', {'displayName': 'Kim Inc', 'Room Number': 265})
# ('Medicare', {'displayName': 'Medicare', 'Billing Amount': 33643.327286577885})
# ('Emergency', {'displayName': 'Emergency'})
# ('Ibuprofen', {'displayName': 'Ibuprofen'})
# ('Inconclusive', {'displayName': 'Inconclusive'})
# ('00002', {'displayName': 'Danny SMITH', 'type': 'Patient', 'Age': 76, 'Date of Admission': '2022-09-22', 'Discharge Date': '2022-10-07'})

# %%
for edge in list(G.edges(data=True))[:20]:
    print(edge)
# Out:
# ('00000', 'Male', {})
# ('00000', 'B-', {})
# ('00000', 'Cancer', {})
# ('00000', 'Matthew SMITH', {})
# ('00000', 'Sons and Miller', {})
# ('00000', 'Blue Cross', {})
# ('00000', 'Urgent', {})
# ('00000', 'Paracetamol', {})
# ('00000', 'Normal', {})
# ('00001', 'Male', {})
# ('00001', 'A+', {})
# ('00001', 'Obesity', {})
# ('00001', 'Samantha DAVIES', {})
# ('00001', 'Kim Inc', {})
# ('00001', 'Medicare', {})
# ('00001', 'Emergency', {})
# ('00001', 'Ibuprofen', {})
# ('00001', 'Inconclusive', {})
# ('00002', 'Female', {})
# ('00002', 'A-', {})

# %% [markdown]
# # Create graph using `turingdb` python package

# %%
# Set graph name
graph_name = "patient_network"

# %%
from turingdb import TuringDB

# Create TuringDB client
client = TuringDB(host="http://localhost:6666")

# Create a new graph
client.query(f"CREATE GRAPH {graph_name}")
client.set_graph(graph_name)

# Create a new change on the graph
change = client.query("CHANGE NEW")["Change ID"][0]

# Checkout into the change
client.checkout(change=change)

# %%
# Build CREATE command from networkx object
create_command = build_create_command_from_networkx(G)
print(f"Cypher CREATE command :\n\n{100 * '*'}\n{create_command}\n{100 * '*'}")
# Out:
# Cypher CREATE command :
#
# ****************************************************************************************************
# CREATE (n0:Patient {id:"00000", "displayName":"Bobby JACKSON", "type":"Patient", "Age":"30", "Date of Admission":"2024-01-31", "Discharge Date":"2024-02-02"}),
# (n1:Node {id:"Male", "displayName":"Male"}),
# (n2:Node {id:"B-", "displayName":"B-"}),
# (n3:Node {id:"Cancer", "displayName":"Cancer"}),
# (n4:Node {id:"Matthew SMITH", "displayName":"Matthew SMITH"}),
# (n5:Node {id:"Sons and Miller", "displayName":"Sons and Miller", "Room Number":"328"}),
# (n6:Node {id:"Blue Cross", "displayName":"Blue Cross", "Billing Amount":"18856.281305978155"}),
# (n7:Node {id:"Urgent", "displayName":"Urgent"}),
# (n8:Node {id:"Paracetamol", "displayName":"Paracetamol"}),
# (n9:Node {id:"Normal", "displayName":"Normal"}),
# (n10:Patient {id:"00001", "displayName":"Leslie TERRY", "type":"Patient", "Age":"62", "Date of Admission":"2019-08-20", "Discharge Date":"2019-08-26"}),
# (n11:Node {id:"A+", "displayName":"A+"}),
# (n12:Node {id:"Obesity", "displayName":"Obesity"}),
# (n13:Node {id:"Samantha DAVIES", "displayName":"Samantha DAVIES"}),
# (n14:Node {id:"Kim Inc", "displayName":"Kim Inc", "Room Number":"265"}),
# (n15:Node {id:"Medicare", "displayName":"Medicare", "Billing Amount":"33643.327286577885"}),
# (n16:Node {id:"Emergency", "displayName":"Emergency"}),
# (n17:Node {id:"Ibuprofen", "displayName":"Ibuprofen"}),
# (n18:Node {id:"Inconclusive", "displayName":"Inconclusive"}),
# (n19:Patient {id:"00002", "displayName":"Danny SMITH", "type":"Patient", "Age":"76", "Date of Admission":"2022-09-22", "Discharge Date":"2022-10-07"}),
# (n20:Node {id:"Female", "displayName":"Female"}),
# (n21:Node {id:"A-", "displayName":"A-"}),
# (n22:Node {id:"Tiffany MITCHELL", "displayName":"Tiffany MITCHELL"}),
# (n23:Node {id:"Cook PLC", "displayName":"Cook PLC", "Room Number":"205"}),
# (n24:Node {id:"Aetna", "displayName":"Aetna", "Billing Amount":"27955.096078842456"}),
# (n25:Node {id:"Aspirin", "displayName":"Aspirin"}),
# (n26:Patient {id:"00003", "displayName":"Andrew WATTS", "type":"Patient", "Age":"28", "Date of Admission":"2020-11-18", "Discharge Date":"2020-12-18"}),
# (n27:Node {id:"O+", "displayName":"O+"}),
# (n28:Node {id:"Diabetes", "displayName":"Diabetes"}),
# (n29:Node {id:"Kevin WELLS", "displayName":"Kevin WELLS"}),
# (n30:Node {id:"Hernandez Rogers and Vang,", "displayName":"Hernandez Rogers and Vang,", "Room Number":"450"}),
# (n31:Node {id:"Elective", "displayName":"Elective"}),
# (n32:Node {id:"Abnormal", "displayName":"Abnormal"}),
# (n33:Patient {id:"00004", "displayName":"Adrienne BELL", "type":"Patient", "Age":"43", "Date of Admission":"2022-09-19", "Discharge Date":"2022-10-09"}),
# (n34:Node {id:"AB+", "displayName":"AB+"}),
# (n35:Node {id:"Kathleen HANNA", "displayName":"Kathleen HANNA"}),
# (n36:Node {id:"White-White", "displayName":"White-White", "Room Number":"458"}),
# (n37:Node {id:"Penicillin", "displayName":"Penicillin"}),
# (n38:Patient {id:"00005", "displayName":"Emily JOHNSON", "type":"Patient", "Age":"36", "Date of Admission":"2023-12-20", "Discharge Date":"2023-12-24"}),
# (n39:Node {id:"Asthma", "displayName":"Asthma"}),
# (n40:Node {id:"Taylor NEWTON", "displayName":"Taylor NEWTON"}),
# (n41:Node {id:"Nunez-Humphrey", "displayName":"Nunez-Humphrey", "Room Number":"389"}),
# (n42:Node {id:"UnitedHealthcare", "displayName":"UnitedHealthcare", "Billing Amount":"48145.11095104189"}),
# (n43:Patient {id:"00006", "displayName":"Edward EDWARDS", "type":"Patient", "Age":"21", "Date of Admission":"2020-11-03", "Discharge Date":"2020-11-15"}),
# (n44:Node {id:"AB-", "displayName":"AB-"}),
# (n45:Node {id:"Kelly OLSON", "displayName":"Kelly OLSON"}),
# (n46:Node {id:"Group Middleton", "displayName":"Group Middleton", "Room Number":"389"}),
# (n47:Patient {id:"00007", "displayName":"Christina MARTINEZ", "type":"Patient", "Age":"20", "Date of Admission":"2021-12-28", "Discharge Date":"2022-01-07"}),
# (n48:Node {id:"Suzanne THOMAS", "displayName":"Suzanne THOMAS"}),
# (n49:Node {id:"Powell Robinson and Valdez,", "displayName":"Powell Robinson and Valdez,", "Room Number":"277"}),
# (n50:Node {id:"Cigna", "displayName":"Cigna", "Billing Amount":"45820.46272159459"}),
# (n51:Patient {id:"00008", "displayName":"Jasmine AGUILAR", "type":"Patient", "Age":"82", "Date of Admission":"2020-07-01", "Discharge Date":"2020-07-14"}),
# (n52:Node {id:"Daniel FERGUSON", "displayName":"Daniel FERGUSON"}),
# (n53:Node {id:"Sons Rich and", "displayName":"Sons Rich and", "Room Number":"316"}),
# (n54:Patient {id:"00009", "displayName":"Christopher BERG", "type":"Patient", "Age":"58", "Date of Admission":"2021-05-23", "Discharge Date":"2021-06-22"}),
# (n55:Node {id:"Heather DAY", "displayName":"Heather DAY"}),
# (n56:Node {id:"Padilla-Walker", "displayName":"Padilla-Walker", "Room Number":"249"}),
# (n0)-[:CONNECTED]-(n1),
# (n0)-[:CONNECTED]-(n2),
# (n0)-[:CONNECTED]-(n3),
# (n0)-[:CONNECTED]-(n4),
# (n0)-[:CONNECTED]-(n5),
# (n0)-[:CONNECTED]-(n6),
# (n0)-[:CONNECTED]-(n7),
# (n0)-[:CONNECTED]-(n8),
# (n0)-[:CONNECTED]-(n9),
# (n10)-[:CONNECTED]-(n1),
# (n10)-[:CONNECTED]-(n11),
# (n10)-[:CONNECTED]-(n12),
# (n10)-[:CONNECTED]-(n13),
# (n10)-[:CONNECTED]-(n14),
# (n10)-[:CONNECTED]-(n15),
# (n10)-[:CONNECTED]-(n16),
# (n10)-[:CONNECTED]-(n17),
# (n10)-[:CONNECTED]-(n18),
# (n19)-[:CONNECTED]-(n20),
# (n19)-[:CONNECTED]-(n21),
# (n19)-[:CONNECTED]-(n12),
# (n19)-[:CONNECTED]-(n22),
# (n19)-[:CONNECTED]-(n23),
# (n19)-[:CONNECTED]-(n24),
# (n19)-[:CONNECTED]-(n16),
# (n19)-[:CONNECTED]-(n25),
# (n19)-[:CONNECTED]-(n9),
# (n26)-[:CONNECTED]-(n20),
# (n26)-[:CONNECTED]-(n27),
# (n26)-[:CONNECTED]-(n28),
# (n26)-[:CONNECTED]-(n29),
# (n26)-[:CONNECTED]-(n30),
# (n26)-[:CONNECTED]-(n15),
# (n26)-[:CONNECTED]-(n31),
# (n26)-[:CONNECTED]-(n17),
# (n26)-[:CONNECTED]-(n32),
# (n33)-[:CONNECTED]-(n20),
# (n33)-[:CONNECTED]-(n34),
# (n33)-[:CONNECTED]-(n3),
# (n33)-[:CONNECTED]-(n35),
# (n33)-[:CONNECTED]-(n36),
# (n33)-[:CONNECTED]-(n24),
# (n33)-[:CONNECTED]-(n7),
# (n33)-[:CONNECTED]-(n37),
# (n33)-[:CONNECTED]-(n32),
# (n38)-[:CONNECTED]-(n1),
# (n38)-[:CONNECTED]-(n11),
# (n38)-[:CONNECTED]-(n39),
# (n38)-[:CONNECTED]-(n40),
# (n38)-[:CONNECTED]-(n41),
# (n38)-[:CONNECTED]-(n42),
# (n38)-[:CONNECTED]-(n7),
# (n38)-[:CONNECTED]-(n17),
# (n38)-[:CONNECTED]-(n9),
# (n43)-[:CONNECTED]-(n20),
# (n43)-[:CONNECTED]-(n44),
# (n43)-[:CONNECTED]-(n28),
# (n43)-[:CONNECTED]-(n45),
# (n43)-[:CONNECTED]-(n46),
# (n43)-[:CONNECTED]-(n15),
# (n43)-[:CONNECTED]-(n16),
# (n43)-[:CONNECTED]-(n8),
# (n43)-[:CONNECTED]-(n18),
# (n47)-[:CONNECTED]-(n20),
# (n47)-[:CONNECTED]-(n11),
# (n47)-[:CONNECTED]-(n3),
# (n47)-[:CONNECTED]-(n48),
# (n47)-[:CONNECTED]-(n49),
# (n47)-[:CONNECTED]-(n50),
# (n47)-[:CONNECTED]-(n16),
# (n47)-[:CONNECTED]-(n8),
# (n47)-[:CONNECTED]-(n18),
# (n51)-[:CONNECTED]-(n1),
# (n51)-[:CONNECTED]-(n34),
# (n51)-[:CONNECTED]-(n39),
# (n51)-[:CONNECTED]-(n52),
# (n51)-[:CONNECTED]-(n53),
# (n51)-[:CONNECTED]-(n50),
# (n51)-[:CONNECTED]-(n31),
# (n51)-[:CONNECTED]-(n25),
# (n51)-[:CONNECTED]-(n32),
# (n54)-[:CONNECTED]-(n20),
# (n54)-[:CONNECTED]-(n44),
# (n54)-[:CONNECTED]-(n3),
# (n54)-[:CONNECTED]-(n55),
# (n54)-[:CONNECTED]-(n56),
# (n54)-[:CONNECTED]-(n42),
# (n54)-[:CONNECTED]-(n31),
# (n54)-[:CONNECTED]-(n8),
# (n54)-[:CONNECTED]-(n18)
# ****************************************************************************************************

# %%
# Run CREATE command
client.query(create_command)

# Commit the change
client.query("COMMIT")
client.query("CHANGE SUBMIT")

# Checkout into main
client.checkout()

# %% [markdown]
# # Show link to open visualiser

# %%
show_link(link_str="https://8080--main--newmain--maximevincent.work.turing.bio/")
# Out:
#     <div class="alert alert-block alert-success">
#         <p style="font-size:20px; ">
#             <b><a href="https://8080--main--newmain--maximevincent.work.turing.bio/" target="_blank">Click to visualise graphs in Turing UI</a></b>
#         </p>
#     </div>
